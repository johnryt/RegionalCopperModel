# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Load-scenario-results" data-toc-modified-id="Load-scenario-results-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load scenario results</a></span><ul class="toc-item"><li><span><a href="#Baselines" data-toc-modified-id="Baselines-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Baselines</a></span></li><li><span><a href="#Scenarios" data-toc-modified-id="Scenarios-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Scenarios</a></span></li><li><span><a href="#Importing-Data" data-toc-modified-id="Importing-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Importing Data</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Systematic-Linear-Imports" data-toc-modified-id="Systematic-Linear-Imports-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Systematic Linear Imports</a></span></li><li><span><a href="#Linear-ramp-scenarios" data-toc-modified-id="Linear-ramp-scenarios-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Linear ramp scenarios</a></span></li></ul></li><li><span><a href="#Displacement" data-toc-modified-id="Displacement-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Displacement</a></span></li><li><span><a href="#Environmental-Impacts" data-toc-modified-id="Environmental-Impacts-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Environmental Impacts</a></span><ul class="toc-item"><li><span><a href="#Import-ban" data-toc-modified-id="Import-ban-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Import ban</a></span></li><li><span><a href="#Old-scenario-environmental-impacts" data-toc-modified-id="Old-scenario-environmental-impacts-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Old scenario environmental impacts</a></span></li><li><span><a href="#Displacement-investigations" data-toc-modified-id="Displacement-investigations-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Displacement investigations</a></span></li><li><span><a href="#Fruity-environmental-impacts" data-toc-modified-id="Fruity-environmental-impacts-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Fruity environmental impacts</a></span></li></ul></li><li><span><a href="#Fruity-Presentation-Rebound" data-toc-modified-id="Fruity-Presentation-Rebound-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Fruity Presentation Rebound</a></span></li></ul></li><li><span><a href="#Visual-analysis" data-toc-modified-id="Visual-analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Visual analysis</a></span><ul class="toc-item"><li><span><a href="#S&amp;D-snalysis" data-toc-modified-id="S&amp;D-snalysis-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>S&amp;D snalysis</a></span><ul class="toc-item"><li><span><a href="#S&amp;D-Data-Import" data-toc-modified-id="S&amp;D-Data-Import-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>S&amp;D Data Import</a></span></li><li><span><a href="#Mining-S&amp;D" data-toc-modified-id="Mining-S&amp;D-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Mining S&amp;D</a></span></li><li><span><a href="#Cathode-S&amp;D" data-toc-modified-id="Cathode-S&amp;D-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Cathode S&amp;D</a></span></li><li><span><a href="#Scrap-S&amp;D" data-toc-modified-id="Scrap-S&amp;D-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Scrap S&amp;D</a></span><ul class="toc-item"><li><span><a href="#Fruity-RRs" data-toc-modified-id="Fruity-RRs-3.1.4.1"><span class="toc-item-num">3.1.4.1&nbsp;&nbsp;</span>Fruity RRs</a></span></li><li><span><a href="#China-import-scenarios-scrap-response" data-toc-modified-id="China-import-scenarios-scrap-response-3.1.4.2"><span class="toc-item-num">3.1.4.2&nbsp;&nbsp;</span>China import scenarios scrap response</a></span></li><li><span><a href="#Zeng-linear-import-decrease" data-toc-modified-id="Zeng-linear-import-decrease-3.1.4.3"><span class="toc-item-num">3.1.4.3&nbsp;&nbsp;</span>Zeng linear import decrease</a></span></li><li><span><a href="#PIR-/-PCR-Scrap-Analysis" data-toc-modified-id="PIR-/-PCR-Scrap-Analysis-3.1.4.4"><span class="toc-item-num">3.1.4.4&nbsp;&nbsp;</span>PIR / PCR Scrap Analysis</a></span></li></ul></li><li><span><a href="#Refinery-evolution" data-toc-modified-id="Refinery-evolution-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Refinery evolution</a></span><ul class="toc-item"><li><span><a href="#Fruity-refining" data-toc-modified-id="Fruity-refining-3.1.5.1"><span class="toc-item-num">3.1.5.1&nbsp;&nbsp;</span>Fruity refining</a></span></li><li><span><a href="#China-import-Scenarios" data-toc-modified-id="China-import-Scenarios-3.1.5.2"><span class="toc-item-num">3.1.5.2&nbsp;&nbsp;</span>China import Scenarios</a></span></li></ul></li></ul></li><li><span><a href="#Price-analysis" data-toc-modified-id="Price-analysis-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Price analysis</a></span><ul class="toc-item"><li><span><a href="#China-import-price-response-scenarios" data-toc-modified-id="China-import-price-response-scenarios-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>China import price response scenarios</a></span></li><li><span><a href="#Zeng-Price" data-toc-modified-id="Zeng-Price-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Zeng Price</a></span></li><li><span><a href="#Fruity-price-data" data-toc-modified-id="Fruity-price-data-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Fruity price data</a></span></li><li><span><a href="#Price-Response-for-Linear-Approaches" data-toc-modified-id="Price-Response-for-Linear-Approaches-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Price Response for Linear Approaches</a></span></li><li><span><a href="#Price-Responses-for-SP2E-High-100%-Shock-Linear-Ramps" data-toc-modified-id="Price-Responses-for-SP2E-High-100%-Shock-Linear-Ramps-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Price Responses for SP2E High 100% Shock Linear Ramps</a></span></li></ul></li><li><span><a href="#Displacement" data-toc-modified-id="Displacement-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Displacement</a></span><ul class="toc-item"><li><span><a href="#Displacement-China:-Fruity-recycling-rates" data-toc-modified-id="Displacement-China:-Fruity-recycling-rates-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Displacement China: Fruity recycling rates</a></span></li><li><span><a href="#Displacement-Fruity" data-toc-modified-id="Displacement-Fruity-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Displacement Fruity</a></span></li><li><span><a href="#Displacement-for-Initial-Linear-Approaches" data-toc-modified-id="Displacement-for-Initial-Linear-Approaches-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Displacement for Initial Linear Approaches</a></span></li><li><span><a href="#Displacement-for-SP2E-High-(100%-Shock---Linear-Ramp)" data-toc-modified-id="Displacement-for-SP2E-High-(100%-Shock---Linear-Ramp)-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Displacement for SP2E High (100% Shock - Linear Ramp)</a></span></li><li><span><a href="#Fill-Between-Plots" data-toc-modified-id="Fill-Between-Plots-3.3.5"><span class="toc-item-num">3.3.5&nbsp;&nbsp;</span>Fill-Between Plots</a></span></li><li><span><a href="#Fill-Between:-Mine-Production-Elasticity" data-toc-modified-id="Fill-Between:-Mine-Production-Elasticity-3.3.6"><span class="toc-item-num">3.3.6&nbsp;&nbsp;</span>Fill Between: Mine Production Elasticity</a></span></li><li><span><a href="#Fill-Between:-SSDE" data-toc-modified-id="Fill-Between:-SSDE-3.3.7"><span class="toc-item-num">3.3.7&nbsp;&nbsp;</span>Fill Between: SSDE</a></span></li><li><span><a href="#Fill-Between:-Demand-Elasticity" data-toc-modified-id="Fill-Between:-Demand-Elasticity-3.3.8"><span class="toc-item-num">3.3.8&nbsp;&nbsp;</span>Fill Between: Demand Elasticity</a></span></li></ul></li><li><span><a href="#Mining-response" data-toc-modified-id="Mining-response-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Mining response</a></span><ul class="toc-item"><li><span><a href="#China-Import-Scenarios-Mining-Response" data-toc-modified-id="China-Import-Scenarios-Mining-Response-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>China Import Scenarios Mining Response</a></span></li><li><span><a href="#COVID-Scenarios" data-toc-modified-id="COVID-Scenarios-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>COVID Scenarios</a></span></li><li><span><a href="#COVID-IMF-Shock" data-toc-modified-id="COVID-IMF-Shock-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>COVID IMF Shock</a></span></li><li><span><a href="#Fruity-mining-response" data-toc-modified-id="Fruity-mining-response-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Fruity mining response</a></span></li><li><span><a href="#Mining-Response-for-Total-2X" data-toc-modified-id="Mining-Response-for-Total-2X-3.4.5"><span class="toc-item-num">3.4.5&nbsp;&nbsp;</span>Mining Response for Total-2X</a></span></li><li><span><a href="#Mining-Response-for-Initial-Linear-Approaches" data-toc-modified-id="Mining-Response-for-Initial-Linear-Approaches-3.4.6"><span class="toc-item-num">3.4.6&nbsp;&nbsp;</span>Mining Response for Initial Linear Approaches</a></span></li></ul></li><li><span><a href="#Mine-level-investigation" data-toc-modified-id="Mine-level-investigation-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Mine level investigation</a></span></li></ul></li><li><span><a href="#Plots-for-China-Paper" data-toc-modified-id="Plots-for-China-Paper-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Plots for China Paper</a></span><ul class="toc-item"><li><span><a href="#Figure-1:-Import-Changes" data-toc-modified-id="Figure-1:-Import-Changes-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Figure 1: Import Changes</a></span></li><li><span><a href="#Figure-2:-China-Shock" data-toc-modified-id="Figure-2:-China-Shock-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Figure 2: China Shock</a></span></li><li><span><a href="#Figure-3:-Import-Changes" data-toc-modified-id="Figure-3:-Import-Changes-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Figure 3: Import Changes</a></span></li><li><span><a href="#Figure-4:-COVID-Results" data-toc-modified-id="Figure-4:-COVID-Results-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Figure 4: COVID Results</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from datetime import datetime
from dateutil.relativedelta import relativedelta
idx = pd.IndexSlice
import random 
from scipy import stats
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
from sklearn import preprocessing as pre
from matplotlib import patches
from matplotlib.path import Path
from matplotlib.patches import PathPatch
import matplotlib.colors

# %% [markdown]
# # Functions

# %%
import brewer2mpl as b2m
bmap = b2m.get_map('Dark2','qualitative',5)
# bmap = b2m.get_map('Paired','qualitative',4)
colors = bmap.mpl_colors
# from pylab import *
import matplotlib as mpl
# b2m.print_maps()
color_08 = 'darkblue'
color_10 = 'tab:green'
c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
c2 = ['#8dd3c7','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd','#ffffb3']
c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2']
c5 = ['#d73027','#f46d43','#fdae61','#fee090', '#abd9e9','#74add1','#4575b4']
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c5)

def init_plot(fontsize=16,linewidth=3,figwidth=8,ax=0,figheight=5.5):
    params = {
       'axes.labelsize': fontsize,
       'font.size': fontsize,
       'legend.fontsize': fontsize,
       'xtick.labelsize': fontsize,
       'ytick.labelsize': fontsize,
       'text.usetex': False,
       'figure.figsize': [figwidth, figheight],
       'lines.linewidth': linewidth,
       'legend.framealpha': 1,
       'legend.frameon': False,
       'mathtext.default': 'regular'
       }

    mpl.rcParams.update(params)
    mpl.rcParams['axes.spines.left'] = False
    mpl.rcParams['axes.spines.right'] = False
    mpl.rcParams['axes.spines.top'] = False
    mpl.rcParams['axes.spines.bottom'] = False
    mpl.rcParams['axes.axisbelow'] = True
    mpl.rcParams['axes.grid'] = True
    mpl.rcParams['axes.grid.axis'] = 'y'
    mpl.rcParams['grid.color'] = '0.9'
    mpl.rcParams['grid.linewidth'] = 1
    mpl.rcParams['grid.linestyle'] = '-'
    # %config InlineBackend.figure_format ='retina'

def pplot(y, label, color='tab:pink', x=0, fontsize=16, linewidth=3, firstcall=0):
    if firstcall==1:
        plt.figure()
        params = {
           'axes.labelsize': fontsize,
           'font.size': fontsize,
           'legend.fontsize': fontsize,
           'xtick.labelsize': fontsize,
           'ytick.labelsize': fontsize,
           'text.usetex': False,
           'figure.figsize': [8, 5.5],
           'lines.linewidth': linewidth
           }
        mpl.rcParams.update(params)
        plt.rc('axes', axisbelow=True)
        plt.axes(frameon=0)
        plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

    plt.plot(y, color = color, label = label, linewidth = linewidth)
    legend = plt.legend()
    frame = legend.get_frame()
    frame.set_facecolor('1.0')
    frame.set_edgecolor('1.0')
    # %config InlineBackend.figure_format ='retina'
    
def psubplot(ax, y, label, color='tab:pink', x=0, fontsize=16, linewidth=3, firstcall=0, width = 16):
    '''Takes the axes, pandas series, and label and gives prettier subplot, width recommended in multiples of 8 for number of subplots'''
    if firstcall == 1:
        params = {
        'axes.labelsize': 12,
        'font.size': 12,
        'legend.fontsize': 12,
        'xtick.labelsize': 12,
        'ytick.labelsize': 12,
        'text.usetex': False,
        'figure.figsize': [width, 5.5],
        'lines.linewidth': 3
        }
        mpl.rcParams.update(params)
        mpl.rcParams['axes.spines.left'] = False
        mpl.rcParams['axes.spines.right'] = False
        mpl.rcParams['axes.spines.top'] = False
        mpl.rcParams['axes.spines.bottom'] = False
    # %config InlineBackend.figure_format ='retina'

    ax.plot(y, label=label,color=color,linewidth=linewidth)
    legend = ax.legend()
    frame = legend.get_frame()
    frame.set_facecolor('1.0')
    frame.set_edgecolor('1.0')
    ax.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax.set_axisbelow(True)

# %%
def displacement_estimate(sd_scenario, scrap_baseline, 
                          mining_baseline):
    scrap_supply_scenario=sd_scenario.loc['19600101':, 'Scrap production']
    mining_supply_scenario=sd_scenario.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
    shock_scenario=scrap_supply_scenario-scrap_baseline
    mining_response_scenario=mining_supply_scenario-mining_baseline
    displacement_scenario=mining_response_scenario.cumsum().div(shock_scenario.cumsum()).mul(-1)
    
    dis_results=pd.DataFrame({'Shock': shock_scenario, 'Mining response': mining_response_scenario, 
                              'Displacement': displacement_scenario, 'Scrap %Increase': shock_scenario.cumsum()/scrap_baseline.cumsum(),
                              'Mining %Increase': mining_response_scenario.cumsum()/mining_baseline.cumsum(),
                              'Scrap %Increase 2020': shock_scenario.cumsum()/scrap_baseline.loc['20200101'],
                              'Mining %Increase 2020': mining_response_scenario.cumsum()/mining_baseline.loc['20200101']})
    return dis_results

# %%
def calculate_impacts(sd_simulated_cn, sd_simulated_rw, sd_simulated, mine_life_stats_all_tp,
                     direct_melt_demand_cn, direct_melt_demand_rw):
    '''Calculates environmental impacts based on production, returns total impacts, unit impacts, and quantities'''
    idx = pd.IndexSlice
    mine_life_stats_all = mine_life_stats_all_tp.transpose()
    sxew_id_operating = [i for i in mine_life_stats_all.columns.levels[0] if 
                    round(mine_life_stats_all.loc[:, idx[i,'Recovered metal production (kt)']].mean()/
                     mine_life_stats_all.loc[:, idx[i,'Paid metal production (kt)']].mean(),6) <= 1
                     and 'Inc_' not in str(i)]
    conc_id_operating = [i for i in mine_life_stats_all.columns.levels[0] if 
                    i not in sxew_id_operating and 'Inc_' not in str(i)]
    sxew_id_new = [i for i in mine_life_stats_all.columns.levels[0] if 
                    round(mine_life_stats_all.loc[:, idx[i,'Recovered metal production (kt)']].mean()/
                     mine_life_stats_all.loc[:, idx[i,'Paid metal production (kt)']].mean(),6) <= 1
                     and 'Inc_' in str(i)]
    conc_id_new = [i for i in mine_life_stats_all.columns.levels[0] if 
                    i not in sxew_id_new and 'Inc_' in str(i)]
    id_new = [i for i in mine_life_stats_all.columns.levels[0] if 'Inc_' in str(i)]
    id_op = [i for i in mine_life_stats_all.columns.levels[0] if 'Inc_' not in str(i)]
    mine_life_stats_panel_operating = mine_life_stats_all.loc[:,idx[id_op,:]].copy()
    mine_life_stats_panel_new = mine_life_stats_all.loc[:,idx[id_new,:]].copy()
    
    # Loading data:
    import os
    directory = os.path.dirname(os.path.dirname(os.getcwd()))
    semis_distribution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Semis Distribution', index_col=0).loc[:'Latin America',:'Fraction Semis Production']
    semis_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Semis', index_col=0)
    mod_semis_distribution = semis_distribution / (1 - semis_distribution.loc['China'])

    refinery_primary_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Primary Refinery Ecoinvent', index_col=0).iloc[:,1:]
    refinery_secondary_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Scrap Ecoinvent', index_col=0, skiprows = 12).loc[:,:'Water use (m3)']
    refinery_distribution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Primary Refinery Ecoinvent', index_col=0).iloc[:,0]
    mod_refinery_distribution = refinery_distribution / (1 - refinery_distribution.loc['China'])

    conc_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Conc Ecoinvent', index_col=0).loc[:,'Ozone depletion (kg CFC-kk)':'Water use (m3)']
    conc_mult = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Conc Mult', index_col=0).loc[:,'Ozone depletion (kg CFC-kk)':'Water use (m3)']
    conc_distribution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Conc Ecoinvent', index_col=0).iloc[:,0]
    conc_scale = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Conc Ecoinvent', index_col=0).loc[:,'TRACI Scale':]
    sxew_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'SX-EW Ecoinvent', index_col=0).loc[:,'Ozone depletion (kg CFC-kk)':'Water use (m3)']
    sxew_mult = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'SX-EW Mult', index_col=0).loc[:,'Ozone depletion (kg CFC-kk)':'Water use (m3)']
    sxew_distribution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'SX-EW Ecoinvent', index_col=0).iloc[:,0]/100
    sxew_scale = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'SX-EW Ecoinvent', index_col=0).loc[:,'TRACI Scale':]
    mining_evolution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Conc Ecoinvent', index_col=0).loc[:,['Fraction','Identified Resources','Undiscovered Resources']]
    mine_eqn_coefficients = pd.DataFrame([[1.5777, -0.626], [2.0621, -1.208], [15.697, -0.573], [36.529, -0.351], 
                                          [0.073378, -0.094], [0.041232, -0.34]], 
                                         index = ['Conc TRACI', 'SX-EW TRACI','Conc Energy','SX-EW Energy',
                                                  'Conc Water','SX-EW Water'], columns = ['A','B'])
    mine_eqn_coefficients.index.name = '(A*ore_grade^B) * scale'

    scrap_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Scrap Ecoinvent', index_col=0, skiprows = 1).loc[:'No1',:'Water use (m3)']
    # direct_melt_distribution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Semis Distribution', index_col=0).loc[:'Latin America',:'Fraction Semis Production']
    refined_metal_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Ref_Metals', index_col=0).iloc[:,2:]
    refined_metal_impacts.index = ['Ref_Zn','Ref_Pb','Ref_Sn','Ref_Ni','Ref_Al','Ref_Mn','Ref_Fe']
    mine_regionality = pd.read_excel(directory+'/Data/primary supply/Operating mine pool - countries.xlsx', index_col=0)

    # Mining evolution
    new_conc_dist = pd.DataFrame(np.array((list(mining_evolution.loc[:,'Fraction'])*23)).reshape(23, 7), index = mine_life_stats_panel_operating.index, columns = mining_evolution.index)
    new_sxew_dist = pd.DataFrame(np.array((list(sxew_distribution)*23)).reshape(23, 7), index = mine_life_stats_panel_operating.index, columns = sxew_distribution.index)

    # Other initialization
    # Semis first (excluding refined metals, those will be last so we have that year's copper impacts)
    countries = refinery_primary_impacts.index
    impacts = refinery_primary_impacts.columns
    traci_impacts = impacts[:10]
    energy_impacts = impacts[10:-1]
    water_impacts = list([impacts[-1]])
    colss = pd.MultiIndex.from_product([countries, impacts])
    idxs = pd.MultiIndex.from_product([direct_melt_demand_cn.index, \
                ['Direct Melt Scrap', 'Direct Melt Other', 'Fabrication', 'New SX-EW Mines',
                 'New Traditional Mines', 'Operating SX-EW Mines', 'Operating Traditional Mines', 
                 'Primary Refinery', 'Secondary Refinery', 'Refined Metals']])
    country_impacts = pd.DataFrame(0, index = idxs, columns = colss)
    country_unit_impacts = pd.DataFrame(0, index = idxs, columns = colss)
    country_quantities = pd.DataFrame(0, index = idxs, columns = countries)

    # Mine and SX-EW preliminary calculations
    op_mines_traci = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    new_mines_traci = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    op_sxew_traci = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    new_sxew_traci = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    op_mines_energy = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    new_mines_energy = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    op_sxew_energy = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    new_sxew_energy = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    op_mines_water = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    new_mines_water = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    op_sxew_water = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)
    new_sxew_water = pd.DataFrame(0, index = direct_melt_demand_cn.loc['20180101':].index, columns = countries)

    for c in countries:
        ####### Mining #######
        conc_op_region_id = [i for i in conc_id_operating if c in mine_regionality.loc[i,'Region']]
        sxew_op_region_id = [i for i in sxew_id_operating if c in mine_regionality.loc[i,'Region']]
        conc_cutoff_traci = 10
        sxew_cutoff_traci = 28
        conc_cutoff_energy = 150
        sxew_cutoff_energy = 450
        conc_cutoff_water = 0.27
        sxew_cutoff_water = 0.1

        # Operating Concentrate Mines - TRACI
        intermediate1 = (mine_eqn_coefficients.loc['Conc TRACI','A'] * mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc TRACI','B']) * conc_scale.loc[c,'TRACI Scale']
        intermediate1[intermediate1>conc_cutoff_traci] = conc_cutoff_traci
        op_mines_traci.loc[:,c] = (intermediate1 * \
         mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New Concentrate Mines - TRACI
        intermediate2 = ((mine_eqn_coefficients.loc['Conc TRACI','A'] * mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc TRACI','B']) * conc_scale.loc[c,'TRACI Scale']).apply(\
         lambda x: x * new_conc_dist.loc[:,c])
        intermediate2[intermediate2>conc_cutoff_traci] = conc_cutoff_traci
        new_mines_traci.loc[:,c] = (intermediate2 * \
         mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 
        # Operating SX-EW - TRACI
        intermediate3 = (mine_eqn_coefficients.loc['SX-EW TRACI','A'] * mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW TRACI','B']) * sxew_scale.loc[c,'TRACI Scale']
        intermediate3[intermediate3>sxew_cutoff_traci] = sxew_cutoff_traci
        op_sxew_traci.loc[:,c] = (intermediate3 * \
         mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New SX-EW - TRACI
        intermediate4 = ((mine_eqn_coefficients.loc['SX-EW TRACI','A'] * mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW TRACI','B']) * sxew_scale.loc[c,'TRACI Scale']).apply(\
         lambda x: x * new_sxew_dist.loc[:,c])
        intermediate4[intermediate4>sxew_cutoff_traci] = sxew_cutoff_traci
        new_sxew_traci.loc[:,c] = (intermediate4 * \
         mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 
        # Operating Concentrate Mines - Energy
        intermediate5 = (mine_eqn_coefficients.loc['Conc Energy','A'] * mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc Energy','B'] ) * conc_scale.loc[c,'Energy Scale']
        intermediate5[intermediate5>conc_cutoff_energy] = conc_cutoff_energy
        op_mines_energy.loc[:,c] = (intermediate5 * \
         mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New Concentrate Mines - Energy
        intermediate6 = ((mine_eqn_coefficients.loc['Conc Energy','A'] * mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc Energy','B']) * conc_scale.loc[c,'Energy Scale']).apply(\
         lambda x: x * new_conc_dist.loc[:,c])
        intermediate6[intermediate6>conc_cutoff_energy] = conc_cutoff_energy
        new_mines_energy.loc[:,c] = (intermediate6 * \
         mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 
        # Operating SX-EW - Energy
        intermediate7 = (mine_eqn_coefficients.loc['SX-EW Energy','A'] * mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW Energy','B']) * sxew_scale.loc[c,'Energy Scale']
        intermediate7[intermediate7>sxew_cutoff_energy] = sxew_cutoff_energy
        op_sxew_energy.loc[:,c] = (intermediate7 * \
         mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New SX-EW - Energy
        intermediate8 = ((mine_eqn_coefficients.loc['SX-EW Energy','A'] * mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW Energy','B']) * sxew_scale.loc[c,'Energy Scale']).apply(\
         lambda x: x * new_sxew_dist.loc[:,c])
        intermediate8[intermediate8>sxew_cutoff_energy] = sxew_cutoff_energy
        new_sxew_energy.loc[:,c] = (intermediate8 * \
         mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 
        # Operating Concentrate Mines - Water
        intermediate9 = (mine_eqn_coefficients.loc['Conc Water','A'] * mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc Water','B'] ) * conc_scale.loc[c,'Water Scale']
        intermediate9[intermediate9>conc_cutoff_water] = conc_cutoff_water
        op_mines_water.loc[:,c] = (intermediate9 * \
         mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New Concentrate Mines - Water
        intermediate10 = ((mine_eqn_coefficients.loc['Conc Water','A'] * mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc Water','B']) * conc_scale.loc[c,'Water Scale']).apply(\
         lambda x: x * new_conc_dist.loc[:,c])
        intermediate10[intermediate10>conc_cutoff_water] = conc_cutoff_water
        new_mines_water.loc[:,c] = (intermediate10 * \
         mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 
        # Operating SX-EW - Water
        intermediate11 = (mine_eqn_coefficients.loc['SX-EW Water','A'] * mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW Water','B']) * sxew_scale.loc[c,'Water Scale']
        intermediate11[intermediate11>sxew_cutoff_water] = sxew_cutoff_water
        op_sxew_water.loc[:,c] = (intermediate11 * \
         mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New SX-EW - Water
        intermediate12 = ((mine_eqn_coefficients.loc['SX-EW Water','A'] * mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW Water','B']) * sxew_scale.loc[c,'Water Scale']).apply(\
         lambda x: x * new_sxew_dist.loc[:,c])
        intermediate12[intermediate12>sxew_cutoff_water] = sxew_cutoff_water
        new_sxew_water.loc[:,c] = (intermediate12 * \
         mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 

        country_impacts.loc[idx['20180101':,'Operating Traditional Mines'],idx[c,traci_impacts]] = op_mines_traci.loc[:,c].apply(lambda x: x*conc_mult.loc[c,traci_impacts]).values
        country_impacts.loc[idx['20180101':,'Operating Traditional Mines'],idx[c,energy_impacts]] = op_mines_energy.loc[:,c].apply(lambda x: x*conc_mult.loc[c,energy_impacts]).values
        country_impacts.loc[idx['20180101':,'Operating Traditional Mines'],idx[c,water_impacts]] = op_mines_water.loc[:,c].values
        country_impacts.loc[idx['20180101':,'Operating SX-EW Mines'],idx[c,traci_impacts]] = op_sxew_traci.loc[:,c].apply(lambda x: x*conc_mult.loc[c,traci_impacts]).values
        country_impacts.loc[idx['20180101':,'Operating SX-EW Mines'],idx[c,energy_impacts]] = op_sxew_energy.loc[:,c].apply(lambda x: x*conc_mult.loc[c,energy_impacts]).values
        country_impacts.loc[idx['20180101':,'Operating SX-EW Mines'],idx[c,water_impacts]] = op_sxew_water.loc[:,c].values

        country_impacts.loc[idx['20180101':,'New Traditional Mines'],idx[c,traci_impacts]] = new_mines_traci.loc[:,c].apply(lambda x: x*conc_mult.loc[c,traci_impacts]).values
        country_impacts.loc[idx['20180101':,'New Traditional Mines'],idx[c,energy_impacts]] = new_mines_energy.loc[:,c].apply(lambda x: x*conc_mult.loc[c,energy_impacts]).values
        country_impacts.loc[idx['20180101':,'New Traditional Mines'],idx[c,water_impacts]] = new_mines_water.loc[:,c].values
        country_impacts.loc[idx['20180101':,'New SX-EW Mines'],idx[c,traci_impacts]] = new_sxew_traci.loc[:,c].apply(lambda x: x*conc_mult.loc[c,traci_impacts]).values
        country_impacts.loc[idx['20180101':,'New SX-EW Mines'],idx[c,energy_impacts]] = new_sxew_energy.loc[:,c].apply(lambda x: x*conc_mult.loc[c,energy_impacts]).values
        country_impacts.loc[idx['20180101':,'New SX-EW Mines'],idx[c,water_impacts]] = new_sxew_water.loc[:,c].values

        country_quantities.loc[idx['20180101':, 'Operating Traditional Mines'],c] = mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Recovered metal production (kt)']].sum(axis=1).values
        country_quantities.loc[idx['20180101':, 'Operating SX-EW Mines'],c] = mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Recovered metal production (kt)']].sum(axis=1).values
        country_quantities.loc[idx['20180101':, 'New Traditional Mines'],c] = new_conc_dist.loc['20180101',c]*mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Recovered metal production (kt)']].sum(axis=1).values
        country_quantities.loc[idx['20180101':, 'New SX-EW Mines'],c] = new_sxew_dist.loc['20180101',c]*mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Recovered metal production (kt)']].sum(axis=1).values

        # Historical Mines
        country_quantities.loc[idx[:'20170101', 'Operating Traditional Mines'],c] = (sd_simulated.loc['19600101':'20170101','Concentrate production']\
            * conc_distribution.loc[c]).values
        country_quantities.loc[idx[:'20170101', 'Operating SX-EW Mines'],c] = (sd_simulated.loc['19600101':'20170101','SX-EW production']\
            * sxew_distribution.loc[c]).values
        country_impacts.loc[idx[:'20170101', 'Operating Traditional Mines'],idx[c,:]] = \
            (country_quantities.loc[idx[:'20170101', 'Operating Traditional Mines'],c].apply(lambda x: x*conc_impacts.loc[c,:])).values
        country_impacts.loc[idx[:'20170101', 'Operating SX-EW Mines'],idx[c,:]] = \
            (country_quantities.loc[idx[:'20170101', 'Operating SX-EW Mines'],c].apply(lambda x: x*sxew_impacts.loc[c,:])).values

        ###### Fabrication ######
        if c == 'China':
            country_impacts.loc[idx[:,'Fabrication'],idx[c,:]] = ((direct_melt_demand_cn.sum(axis=1))\
                .apply(lambda x: x * semis_impacts.loc['Metal working RoW (Conseq)', :])).values
            country_quantities.loc[idx[:,'Fabrication'],c] = (direct_melt_demand_cn.sum(axis=1)).values
        elif c == 'Europe' or c == 'North America':
            country_impacts.loc[idx[:,'Fabrication'],idx[c,:]] = ((direct_melt_demand_rw.sum(axis=1) * 
                mod_semis_distribution.loc[c].values)\
                .apply(lambda x: x * semis_impacts.loc['Metal working RER (Conseq)', :])).values
            country_quantities.loc[idx[:,'Fabrication'],c] = (direct_melt_demand_rw.sum(axis=1) * 
                mod_semis_distribution.loc[c].values).values
        else:
            country_impacts.loc[idx[:,'Fabrication'],idx[c,:]] = ((direct_melt_demand_rw.sum(axis=1) * 
                mod_semis_distribution.loc[c].values)\
                .apply(lambda x: x * semis_impacts.loc['Metal working RoW (Conseq)', :])).values
            country_quantities.loc[idx[:,'Fabrication'],c] = (direct_melt_demand_rw.sum(axis=1) * 
                mod_semis_distribution.loc[c].values).values

        ###### Direct Melt of Scrap and Other ######
        if c == 'China':
            country_impacts.loc[idx[:,'Direct Melt Scrap'], idx[c,:]] = (\
                direct_melt_demand_cn.loc[:, 'Yellow_Brass':'Red_Brass'].sum(axis=1).apply(lambda x : x * scrap_impacts.loc['Brass', :]) + \
                direct_melt_demand_cn.loc[:, 'Mn_Bronze':'Cartridge'].sum(axis=1).apply(lambda x : x * scrap_impacts.loc['Low Grade', :]) + \
                direct_melt_demand_cn.loc[:, 'No.1'].apply(lambda x : x * scrap_impacts.loc['No1', :]) + \
                direct_melt_demand_cn.loc[:, 'No.2'].apply(lambda x: x * scrap_impacts.loc['No2', :])).values
            country_impacts.loc[idx[:,'Direct Melt Other'], idx[c,:]] = ((\
                direct_melt_demand_cn.loc[:,:'Ref_Fe'].sum(axis=1)).apply(lambda x: x * scrap_impacts.loc['No1', :])).values # assuming that all the refined metals can be melted with the same impacts as No1 scrap
            country_quantities.loc[idx[:,'Direct Melt Scrap'],c] = (direct_melt_demand_cn.loc[:, 'Yellow_Brass':].sum(axis=1)).values
            country_quantities.loc[idx[:,'Direct Melt Other'],c] = (direct_melt_demand_cn.loc[:, :'Ref_Fe'].sum(axis=1)).values
        else:
            country_impacts.loc[idx[:,'Direct Melt Scrap'], idx[c,:]] = ((\
                direct_melt_demand_rw.loc[:, 'Yellow_Brass':'Red_Brass'].sum(axis=1).apply(lambda x : x * scrap_impacts.loc['Brass', :]) + \
                direct_melt_demand_rw.loc[:, 'Mn_Bronze':'Cartridge'].sum(axis=1).apply(lambda x : x * scrap_impacts.loc['Low Grade', :]) + \
                direct_melt_demand_rw.loc[:, 'No.1'].apply(lambda x : x * scrap_impacts.loc['No1', :]) + \
                direct_melt_demand_rw.loc[:, 'No.2'].apply(lambda x: x * scrap_impacts.loc['No2', :])) *\
                mod_semis_distribution.loc[c].values[0]).values
            country_impacts.loc[idx[:,'Direct Melt Other'], idx[c,:]] = ((\
                direct_melt_demand_rw.loc[:,:'Ref_Fe'].sum(axis=1)).apply(lambda x: x * scrap_impacts.loc['No1', :]) *
                mod_semis_distribution.loc[c].values[0]).values # assuming that all the refined metals can be melted with the same impacts as No1 scrap
            country_quantities.loc[idx[:,'Direct Melt Scrap'],c] = (direct_melt_demand_rw.loc[:, 'Yellow_Brass':].sum(axis=1)*mod_semis_distribution.loc[c].values[0]).values
            country_quantities.loc[idx[:,'Direct Melt Other'],c] = (direct_melt_demand_rw.loc[:, :'Ref_Fe'].sum(axis=1)*mod_semis_distribution.loc[c].values[0]).values

        ###### Refineries ###### 
        if c == 'China':
            country_impacts.loc[idx[:,'Primary Refinery'],idx[c,:]] = (sd_simulated_cn.loc['19600101':, 'Primary refining production']\
                .apply(lambda x: x * refinery_primary_impacts.loc[c, :])).values
            country_impacts.loc[idx[:,'Secondary Refinery'],idx[c,:]] = (sd_simulated_cn.loc['19600101':, 'Secondary refining production']\
                .apply(lambda x: x * refinery_secondary_impacts.loc[c, :])).values
            country_quantities.loc[idx[:,'Primary Refinery'],c] = (sd_simulated_cn.loc['19600101':, 'Primary refining production']).values
            country_quantities.loc[idx[:,'Secondary Refinery'],c] = (sd_simulated_cn.loc['19600101':, 'Secondary refining production']).values
        else:
            country_impacts.loc[idx[:,'Primary Refinery'],idx[c,:]] = ((sd_simulated_rw.loc['19600101':, 'Primary refining production'] * \
                mod_refinery_distribution.loc[c]).apply(lambda x: x * refinery_primary_impacts.loc[c, :])).values
            country_impacts.loc[idx[:,'Secondary Refinery'],idx[c,:]] = ((sd_simulated_rw.loc['19600101':, 'Secondary refining production'] * \
                mod_refinery_distribution.loc[c]).apply(lambda x: x * refinery_secondary_impacts.loc[c, :])).values
            country_quantities.loc[idx[:,'Primary Refinery'],c] = (sd_simulated_rw.loc['19600101':, 'Primary refining production']\
                * mod_refinery_distribution.loc[c]).values
            country_quantities.loc[idx[:,'Secondary Refinery'],c] = (sd_simulated_rw.loc['19600101':, 'Secondary refining production']\
                * mod_refinery_distribution.loc[c]).values

        ###### Refined metals' contributions ###### 
        if c == 'China':
            for m in refined_metal_impacts.index:
                country_impacts.loc[idx[:,'Refined Metals'],idx[c,:]] += ((direct_melt_demand_cn.loc[:,m])\
                    .apply(lambda x: x * refined_metal_impacts.loc[m, :])).values
            country_quantities.loc[idx[:,'Refined Metals'],c] = (\
                direct_melt_demand_cn.loc[:,refined_metal_impacts.index].sum(axis=1)).values
        else:
            for m in refined_metal_impacts.index:
                country_impacts.loc[idx[:,'Refined Metals'],idx[c,:]] += ((direct_melt_demand_rw.loc[:,m] * 
                    mod_semis_distribution.loc[c].values)\
                    .apply(lambda x: x * refined_metal_impacts.loc[m, :])).values
            country_quantities.loc[idx[:,'Refined Metals'],c] = (\
                direct_melt_demand_rw.loc[:,refined_metal_impacts.index].sum(axis=1)*
                mod_semis_distribution.loc[c].values).values

    colsss = pd.MultiIndex.from_product([countries, ['Direct Melt Scrap', 'Direct Melt Other', 
                 'Fabrication', 'New SX-EW Mines',
                 'New Traditional Mines', 'Operating SX-EW Mines', 'Operating Traditional Mines', 
                 'Primary Refinery', 'Secondary Refinery', 'Refined Metals']])
    idxss = pd.MultiIndex.from_product([direct_melt_demand_cn.index, impacts])
    new_country_impacts = pd.DataFrame(0, index = idxss, columns = colsss)
    new_country_unit_impacts = pd.DataFrame(0, index = idxss, columns = colsss)

    for y in country_impacts.index.levels[0]:
        for c in countries:
            new_country_impacts.loc[idx[y,:],idx[c,:]] = country_impacts.loc[idx[y,:],idx[c,:]].transpose().values
    
    # Getting country unit impacts
    for i in impacts:
        country_unit_impacts.loc[:, idx[:, i]] = (country_impacts.loc[:, idx[:, i]] / country_quantities.values).fillna(0)

    # Updating the columns to have the correct units (all the impacts imported were in kg X/kg Cu and we're multiplying by kt)
    impacts_units = dict()
    for i in impacts:
        impacts_units.update({i: i.replace('kg','kt').replace('CTU','kCTU').replace('MJ','GJ').replace('m3','ML')
                         .replace('Total','Total energy')})
#     print('Done')
    return [new_country_impacts.rename(index = impacts_units), 
            country_unit_impacts.rename(columns = impacts_units),
            country_quantities.rename(columns = impacts_units)]

def calculate_impacts_lin(sd_simulated, mine_life_stats_all_tp):
    '''Calculates environmental impacts based on production, returns total impacts, unit impacts, and quantities'''
    sd_simulated = sd_simulated.loc['19600101':].copy()
    idx = pd.IndexSlice
    mine_life_stats_all = mine_life_stats_all_tp.transpose()
    sxew_id_operating = [i for i in mine_life_stats_all.columns.levels[0] if 
                    round(mine_life_stats_all.loc[:, idx[i,'Recovered metal production (kt)']].mean()/
                     mine_life_stats_all.loc[:, idx[i,'Paid metal production (kt)']].mean(),6) <= 1
                     and 'Inc_' not in str(i)]
    conc_id_operating = [i for i in mine_life_stats_all.columns.levels[0] if 
                    i not in sxew_id_operating and 'Inc_' not in str(i)]
    sxew_id_new = [i for i in mine_life_stats_all.columns.levels[0] if 
                    round(mine_life_stats_all.loc[:, idx[i,'Recovered metal production (kt)']].mean()/
                     mine_life_stats_all.loc[:, idx[i,'Paid metal production (kt)']].mean(),6) <= 1
                     and 'Inc_' in str(i)]
    conc_id_new = [i for i in mine_life_stats_all.columns.levels[0] if 
                    i not in sxew_id_new and 'Inc_' in str(i)]
    id_new = [i for i in mine_life_stats_all.columns.levels[0] if 'Inc_' in str(i)]
    id_op = [i for i in mine_life_stats_all.columns.levels[0] if 'Inc_' not in str(i)]
    mine_life_stats_panel_operating = mine_life_stats_all.loc[:,idx[id_op,:]].copy()
    mine_life_stats_panel_new = mine_life_stats_all.loc[:,idx[id_new,:]].copy()
    
    # Loading data:
    import os
    directory = os.path.dirname(os.path.dirname(os.getcwd()))
    semis_distribution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Semis Distribution', index_col=0).loc[:'Latin America',:'Fraction Semis Production']
    semis_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Semis', index_col=0)
    mod_semis_distribution = semis_distribution / (1 - semis_distribution.loc['China'])
    scrap_distribution = pd.Series([0.25,0.251969,0.348425,0.149606], index=['No1','No2','Brass','Low Grade'])
    
    refinery_primary_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Primary Refinery Ecoinvent', index_col=0).iloc[:,1:]
    refinery_secondary_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Scrap Ecoinvent', index_col=0, skiprows = 12).loc[:,:'Water use (m3)']
    refinery_distribution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Primary Refinery Ecoinvent', index_col=0).iloc[:,0]
    mod_refinery_distribution = refinery_distribution / (1 - refinery_distribution.loc['China'])

    conc_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Conc Ecoinvent', index_col=0).loc[:,'Ozone depletion (kg CFC-kk)':'Water use (m3)']
    conc_mult = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Conc Mult', index_col=0).loc[:,'Ozone depletion (kg CFC-kk)':'Water use (m3)']
    conc_distribution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Conc Ecoinvent', index_col=0).iloc[:,0]
    conc_scale = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Conc Ecoinvent', index_col=0).loc[:,'TRACI Scale':]
    sxew_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'SX-EW Ecoinvent', index_col=0).loc[:,'Ozone depletion (kg CFC-kk)':'Water use (m3)']
    sxew_mult = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'SX-EW Mult', index_col=0).loc[:,'Ozone depletion (kg CFC-kk)':'Water use (m3)']
    sxew_distribution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'SX-EW Ecoinvent', index_col=0).iloc[:,0]/100
    sxew_scale = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'SX-EW Ecoinvent', index_col=0).loc[:,'TRACI Scale':]
    mining_evolution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Conc Ecoinvent', index_col=0).loc[:,['Fraction','Identified Resources','Undiscovered Resources']]
    mine_eqn_coefficients = pd.DataFrame([[1.5777, -0.626], [2.0621, -1.208], [15.697, -0.573], [36.529, -0.351], 
                                          [0.073378, -0.094], [0.041232, -0.34]], 
                                         index = ['Conc TRACI', 'SX-EW TRACI','Conc Energy','SX-EW Energy',
                                                  'Conc Water','SX-EW Water'], columns = ['A','B'])
    mine_eqn_coefficients.index.name = '(A*ore_grade^B) * scale'

    scrap_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Scrap Ecoinvent', index_col=0, skiprows = 1).loc[:'No1',:'Water use (m3)']
    # direct_melt_distribution = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Semis Distribution', index_col=0).loc[:'Latin America',:'Fraction Semis Production']
    refined_metal_impacts = pd.read_excel(directory+'/Data/SimaPro Data.xlsx', sheet_name = 'Ref_Metals', index_col=0).iloc[:,2:]
    refined_metal_impacts.index = ['Ref_Zn','Ref_Pb','Ref_Sn','Ref_Ni','Ref_Al','Ref_Mn','Ref_Fe']
    mine_regionality = pd.read_excel(directory+'/Data/primary supply/Operating mine pool - countries.xlsx', index_col=0)

    # Mining evolution
    new_conc_dist = pd.DataFrame(np.array((list(mining_evolution.loc[:,'Fraction'])*23)).reshape(23, 7), index = mine_life_stats_panel_operating.index, columns = mining_evolution.index)
    new_sxew_dist = pd.DataFrame(np.array((list(sxew_distribution)*23)).reshape(23, 7), index = mine_life_stats_panel_operating.index, columns = sxew_distribution.index)

    # Other initialization
    # Semis first (excluding refined metals, those will be last so we have that year's copper impacts)
    countries = refinery_primary_impacts.index
    impacts = refinery_primary_impacts.columns
    traci_impacts = impacts[:10]
    energy_impacts = impacts[10:-1]
    water_impacts = list([impacts[-1]])
    colss = pd.MultiIndex.from_product([countries, impacts])
    idxs = pd.MultiIndex.from_product([sd_simulated.loc['19600101':].index, \
                ['Direct Melt Scrap', 'Direct Melt Other', 'Fabrication', 'New SX-EW Mines',
                 'New Traditional Mines', 'Operating SX-EW Mines', 'Operating Traditional Mines', 
                 'Primary Refinery', 'Secondary Refinery', 'Refined Metals']])
    country_impacts = pd.DataFrame(0, index = idxs, columns = colss)
    country_unit_impacts = pd.DataFrame(0, index = idxs, columns = colss)
    country_quantities = pd.DataFrame(0, index = idxs, columns = countries)

    # Mine and SX-EW preliminary calculations
    op_mines_traci = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    new_mines_traci = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    op_sxew_traci = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    new_sxew_traci = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    op_mines_energy = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    new_mines_energy = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    op_sxew_energy = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    new_sxew_energy = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    op_mines_water = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    new_mines_water = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    op_sxew_water = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)
    new_sxew_water = pd.DataFrame(0, index = sd_simulated.loc['20180101':].index, columns = countries)

    direct_melt_demand_rw = sd_simulated.loc['19600101':,['Refined demand','Direct melt scrap']].copy()
    sd_simulated_rw = sd_simulated.loc['19600101':].copy()
        
    for c in countries:
        ####### Mining #######
        conc_op_region_id = [i for i in conc_id_operating if c in mine_regionality.loc[i,'Region']]
        sxew_op_region_id = [i for i in sxew_id_operating if c in mine_regionality.loc[i,'Region']]
        conc_cutoff_traci = 10
        sxew_cutoff_traci = 28
        conc_cutoff_energy = 150
        sxew_cutoff_energy = 450
        conc_cutoff_water = 0.27
        sxew_cutoff_water = 0.1

        # Operating Concentrate Mines - TRACI
        intermediate1 = (mine_eqn_coefficients.loc['Conc TRACI','A'] * mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc TRACI','B']) * conc_scale.loc[c,'TRACI Scale']
        intermediate1[intermediate1>conc_cutoff_traci] = conc_cutoff_traci
        op_mines_traci.loc[:,c] = (intermediate1 * \
         mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New Concentrate Mines - TRACI
        intermediate2 = ((mine_eqn_coefficients.loc['Conc TRACI','A'] * mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc TRACI','B']) * conc_scale.loc[c,'TRACI Scale']).apply(\
         lambda x: x * new_conc_dist.loc[:,c])
        intermediate2[intermediate2>conc_cutoff_traci] = conc_cutoff_traci
        new_mines_traci.loc[:,c] = (intermediate2 * \
         mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 
        # Operating SX-EW - TRACI
        intermediate3 = (mine_eqn_coefficients.loc['SX-EW TRACI','A'] * mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW TRACI','B']) * sxew_scale.loc[c,'TRACI Scale']
        intermediate3[intermediate3>sxew_cutoff_traci] = sxew_cutoff_traci
        op_sxew_traci.loc[:,c] = (intermediate3 * \
         mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New SX-EW - TRACI
        intermediate4 = ((mine_eqn_coefficients.loc['SX-EW TRACI','A'] * mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW TRACI','B']) * sxew_scale.loc[c,'TRACI Scale']).apply(\
         lambda x: x * new_sxew_dist.loc[:,c])
        intermediate4[intermediate4>sxew_cutoff_traci] = sxew_cutoff_traci
        new_sxew_traci.loc[:,c] = (intermediate4 * \
         mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 
        # Operating Concentrate Mines - Energy
        intermediate5 = (mine_eqn_coefficients.loc['Conc Energy','A'] * mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc Energy','B'] ) * conc_scale.loc[c,'Energy Scale']
        intermediate5[intermediate5>conc_cutoff_energy] = conc_cutoff_energy
        op_mines_energy.loc[:,c] = (intermediate5 * \
         mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New Concentrate Mines - Energy
        intermediate6 = ((mine_eqn_coefficients.loc['Conc Energy','A'] * mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc Energy','B']) * conc_scale.loc[c,'Energy Scale']).apply(\
         lambda x: x * new_conc_dist.loc[:,c])
        intermediate6[intermediate6>conc_cutoff_energy] = conc_cutoff_energy
        new_mines_energy.loc[:,c] = (intermediate6 * \
         mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 
        # Operating SX-EW - Energy
        intermediate7 = (mine_eqn_coefficients.loc['SX-EW Energy','A'] * mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW Energy','B']) * sxew_scale.loc[c,'Energy Scale']
        intermediate7[intermediate7>sxew_cutoff_energy] = sxew_cutoff_energy
        op_sxew_energy.loc[:,c] = (intermediate7 * \
         mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New SX-EW - Energy
        intermediate8 = ((mine_eqn_coefficients.loc['SX-EW Energy','A'] * mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW Energy','B']) * sxew_scale.loc[c,'Energy Scale']).apply(\
         lambda x: x * new_sxew_dist.loc[:,c])
        intermediate8[intermediate8>sxew_cutoff_energy] = sxew_cutoff_energy
        new_sxew_energy.loc[:,c] = (intermediate8 * \
         mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 
        # Operating Concentrate Mines - Water
        intermediate9 = (mine_eqn_coefficients.loc['Conc Water','A'] * mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc Water','B'] ) * conc_scale.loc[c,'Water Scale']
        intermediate9[intermediate9>conc_cutoff_water] = conc_cutoff_water
        op_mines_water.loc[:,c] = (intermediate9 * \
         mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New Concentrate Mines - Water
        intermediate10 = ((mine_eqn_coefficients.loc['Conc Water','A'] * mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['Conc Water','B']) * conc_scale.loc[c,'Water Scale']).apply(\
         lambda x: x * new_conc_dist.loc[:,c])
        intermediate10[intermediate10>conc_cutoff_water] = conc_cutoff_water
        new_mines_water.loc[:,c] = (intermediate10 * \
         mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 
        # Operating SX-EW - Water
        intermediate11 = (mine_eqn_coefficients.loc['SX-EW Water','A'] * mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW Water','B']) * sxew_scale.loc[c,'Water Scale']
        intermediate11[intermediate11>sxew_cutoff_water] = sxew_cutoff_water
        op_sxew_water.loc[:,c] = (intermediate11 * \
         mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Recovered metal production (kt)']].values).sum(axis=1).values
        # New SX-EW - Water
        intermediate12 = ((mine_eqn_coefficients.loc['SX-EW Water','A'] * mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Head grade (%)']]**\
         mine_eqn_coefficients.loc['SX-EW Water','B']) * sxew_scale.loc[c,'Water Scale']).apply(\
         lambda x: x * new_sxew_dist.loc[:,c])
        intermediate12[intermediate12>sxew_cutoff_water] = sxew_cutoff_water
        new_sxew_water.loc[:,c] = (intermediate12 * \
         mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Recovered metal production (kt)']].values).sum(axis=1).values 

        country_impacts.loc[idx['20180101':,'Operating Traditional Mines'],idx[c,traci_impacts]] = op_mines_traci.loc[:,c].apply(lambda x: x*conc_mult.loc[c,traci_impacts]).values
        country_impacts.loc[idx['20180101':,'Operating Traditional Mines'],idx[c,energy_impacts]] = op_mines_energy.loc[:,c].apply(lambda x: x*conc_mult.loc[c,energy_impacts]).values
        country_impacts.loc[idx['20180101':,'Operating Traditional Mines'],idx[c,water_impacts]] = op_mines_water.loc[:,c].values
        country_impacts.loc[idx['20180101':,'Operating SX-EW Mines'],idx[c,traci_impacts]] = op_sxew_traci.loc[:,c].apply(lambda x: x*conc_mult.loc[c,traci_impacts]).values
        country_impacts.loc[idx['20180101':,'Operating SX-EW Mines'],idx[c,energy_impacts]] = op_sxew_energy.loc[:,c].apply(lambda x: x*conc_mult.loc[c,energy_impacts]).values
        country_impacts.loc[idx['20180101':,'Operating SX-EW Mines'],idx[c,water_impacts]] = op_sxew_water.loc[:,c].values

        country_impacts.loc[idx['20180101':,'New Traditional Mines'],idx[c,traci_impacts]] = new_mines_traci.loc[:,c].apply(lambda x: x*conc_mult.loc[c,traci_impacts]).values
        country_impacts.loc[idx['20180101':,'New Traditional Mines'],idx[c,energy_impacts]] = new_mines_energy.loc[:,c].apply(lambda x: x*conc_mult.loc[c,energy_impacts]).values
        country_impacts.loc[idx['20180101':,'New Traditional Mines'],idx[c,water_impacts]] = new_mines_water.loc[:,c].values
        country_impacts.loc[idx['20180101':,'New SX-EW Mines'],idx[c,traci_impacts]] = new_sxew_traci.loc[:,c].apply(lambda x: x*conc_mult.loc[c,traci_impacts]).values
        country_impacts.loc[idx['20180101':,'New SX-EW Mines'],idx[c,energy_impacts]] = new_sxew_energy.loc[:,c].apply(lambda x: x*conc_mult.loc[c,energy_impacts]).values
        country_impacts.loc[idx['20180101':,'New SX-EW Mines'],idx[c,water_impacts]] = new_sxew_water.loc[:,c].values

        country_quantities.loc[idx['20180101':, 'Operating Traditional Mines'],c] = mine_life_stats_panel_operating.loc[:,idx[conc_op_region_id,'Recovered metal production (kt)']].sum(axis=1).values
        country_quantities.loc[idx['20180101':, 'Operating SX-EW Mines'],c] = mine_life_stats_panel_operating.loc[:,idx[sxew_op_region_id,'Recovered metal production (kt)']].sum(axis=1).values
        country_quantities.loc[idx['20180101':, 'New Traditional Mines'],c] = mine_life_stats_panel_new.loc[:,idx[conc_id_new,'Recovered metal production (kt)']].sum(axis=1).values
        country_quantities.loc[idx['20180101':, 'New SX-EW Mines'],c] = mine_life_stats_panel_new.loc[:,idx[sxew_id_new,'Recovered metal production (kt)']].sum(axis=1).values

        # Historical Mines
        country_quantities.loc[idx[:'20170101', 'Operating Traditional Mines'],c] = (sd_simulated.loc['19600101':'20170101','Concentrate production']\
            * conc_distribution.loc[c]).values
        country_quantities.loc[idx[:'20170101', 'Operating SX-EW Mines'],c] = (sd_simulated.loc['19600101':'20170101','SX-EW production']\
            * sxew_distribution.loc[c]).values
        country_impacts.loc[idx[:'20170101', 'Operating Traditional Mines'],idx[c,:]] = \
            (country_quantities.loc[idx[:'20170101', 'Operating Traditional Mines'],c].apply(lambda x: x*conc_impacts.loc[c,:])).values
        country_impacts.loc[idx[:'20170101', 'Operating SX-EW Mines'],idx[c,:]] = \
            (country_quantities.loc[idx[:'20170101', 'Operating SX-EW Mines'],c].apply(lambda x: x*sxew_impacts.loc[c,:])).values

        ###### Fabrication ######
        if c == 'Europe' or c == 'North America':
            country_impacts.loc[idx[:,'Fabrication'],idx[c,:]] = ((direct_melt_demand_rw.sum(axis=1) * 
                semis_distribution.loc[c].values)\
                .apply(lambda x: x * semis_impacts.loc['Metal working RER (Conseq)', :])).values
            country_quantities.loc[idx[:,'Fabrication'],c] = (direct_melt_demand_rw.sum(axis=1) * 
                semis_distribution.loc[c].values).values
        else:
            country_impacts.loc[idx[:,'Fabrication'],idx[c,:]] = ((direct_melt_demand_rw.sum(axis=1) * 
                semis_distribution.loc[c].values)\
                .apply(lambda x: x * semis_impacts.loc['Metal working RoW (Conseq)', :])).values
            country_quantities.loc[idx[:,'Fabrication'],c] = (direct_melt_demand_rw.sum(axis=1) * 
                semis_distribution.loc[c].values).values

        ###### Direct Melt of Scrap and Other ######
        country_impacts.loc[idx[:,'Direct Melt Scrap'], idx[c,:]] = ((\
            (scrap_distribution.loc['Brass']*sd_simulated.loc[:,'Direct melt scrap']).apply(lambda x : x * scrap_impacts.loc['Brass', :]) + \
            (scrap_distribution.loc['Low Grade']*sd_simulated.loc[:,'Direct melt scrap']).apply(lambda x : x * scrap_impacts.loc['Low Grade', :]) + \
            (scrap_distribution.loc['No1']*sd_simulated.loc[:,'Direct melt scrap']).apply(lambda x : x * scrap_impacts.loc['No1', :]) + \
            (scrap_distribution.loc['No2']*sd_simulated.loc[:,'Direct melt scrap']).apply(lambda x: x * scrap_impacts.loc['No2', :])) *\
            semis_distribution.loc[c].values[0]).values
        country_impacts.loc[idx[:,'Direct Melt Other'], idx[c,:]] = ((\
            sd_simulated.loc[:,'Refined demand']).apply(lambda x: x * scrap_impacts.loc['No1', :]) *
            semis_distribution.loc[c].values[0]).values # assuming that all the refined metals can be melted with the same impacts as No1 scrap
        country_quantities.loc[idx[:,'Direct Melt Scrap'],c] = (sd_simulated.loc[:,'Direct melt scrap']*semis_distribution.loc[c].values[0]).values
        country_quantities.loc[idx[:,'Direct Melt Other'],c] = (sd_simulated.loc[:,'Refined demand']*semis_distribution.loc[c].values[0]).values

        ###### Refineries ###### 
        country_impacts.loc[idx[:,'Primary Refinery'],idx[c,:]] = ((sd_simulated_rw.loc['19600101':, 'Primary refining production'] * \
            refinery_distribution.loc[c]).apply(lambda x: x * refinery_primary_impacts.loc[c, :])).values
        country_impacts.loc[idx[:,'Secondary Refinery'],idx[c,:]] = ((sd_simulated_rw.loc['19600101':, 'Secondary refining production'] * \
            refinery_distribution.loc[c]).apply(lambda x: x * refinery_secondary_impacts.loc[c, :])).values
        country_quantities.loc[idx[:,'Primary Refinery'],c] = (sd_simulated_rw.loc['19600101':, 'Primary refining production']\
            * refinery_distribution.loc[c]).values
        country_quantities.loc[idx[:,'Secondary Refinery'],c] = (sd_simulated_rw.loc['19600101':, 'Secondary refining production']\
            * refinery_distribution.loc[c]).values

        ###### Refined metals' contributions ###### 
#         if c == 'China':
#             for m in refined_metal_impacts.index:
#                 country_impacts.loc[idx[:,'Refined Metals'],idx[c,:]] += ((direct_melt_demand_cn.loc[:,m])\
#                     .apply(lambda x: x * refined_metal_impacts.loc[m, :])).values
#             country_quantities.loc[idx[:,'Refined Metals'],c] = (\
#                 direct_melt_demand_cn.loc[:,refined_metal_impacts.index].sum(axis=1)).values
#         else:
#             for m in refined_metal_impacts.index:
#                 country_impacts.loc[idx[:,'Refined Metals'],idx[c,:]] += ((direct_melt_demand_rw.loc[:,m] * 
#                     mod_semis_distribution.loc[c].values)\
#                     .apply(lambda x: x * refined_metal_impacts.loc[m, :])).values
#             country_quantities.loc[idx[:,'Refined Metals'],c] = (\
#                 direct_melt_demand_rw.loc[:,refined_metal_impacts.index].sum(axis=1)*
#                 mod_semis_distribution.loc[c].values).values

    colsss = pd.MultiIndex.from_product([countries, ['Direct Melt Scrap', 'Direct Melt Other', 
                 'Fabrication', 'New SX-EW Mines',
                 'New Traditional Mines', 'Operating SX-EW Mines', 'Operating Traditional Mines', 
                 'Primary Refinery', 'Secondary Refinery', 'Refined Metals']])
    idxss = pd.MultiIndex.from_product([sd_simulated.loc['19600101':].index, impacts])
    new_country_impacts = pd.DataFrame(0, index = idxss, columns = colsss)
    new_country_unit_impacts = pd.DataFrame(0, index = idxss, columns = colsss)

    for y in country_impacts.index.levels[0]:
        for c in countries:
            new_country_impacts.loc[idx[y,:],idx[c,:]] = country_impacts.loc[idx[y,:],idx[c,:]].transpose().values
    
    # Getting country unit impacts
    for i in impacts:
        country_unit_impacts.loc[:, idx[:, i]] = (country_impacts.loc[:, idx[:, i]] / country_quantities.values).fillna(0)

    # Updating the columns to have the correct units (all the impacts imported were in kg X/kg Cu and we're multiplying by kt)
    impacts_units = dict()
    for i in impacts:
        impacts_units.update({i: i.replace('kg','kt').replace('CTU','kCTU').replace('MJ','GJ').replace('m3','ML')
                         .replace('Total','Total energy')})
    print('Done')
    return [new_country_impacts.rename(index = impacts_units), 
            country_unit_impacts.rename(columns = impacts_units),
            country_quantities.rename(columns = impacts_units)]

file_name = 'blend CN baseline 20200414_1'
sd_pir_baseline = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx',sheet_name = 'Original',index_col=0)
sd_pir_baseline_gl = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', sheet_name='Global',index_col=0)
sd_pir_baseline_cn = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', sheet_name='China',index_col=0)
sd_pir_baseline_rw = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', sheet_name='RoW',index_col=0)
direct_melt_demand_pir_baseline_gl = sd_pir_baseline_gl.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
direct_melt_demand_pir_baseline_cn = sd_pir_baseline_cn.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
direct_melt_demand_pir_baseline_rw = sd_pir_baseline_rw.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
direct_melt_demand_pir_baseline_gl.columns = [i.split('\'')[3] for i in direct_melt_demand_pir_baseline_gl.columns]
direct_melt_demand_pir_baseline_cn.columns = direct_melt_demand_pir_baseline_gl.columns
direct_melt_demand_pir_baseline_rw.columns = direct_melt_demand_pir_baseline_gl.columns

file_name = 'blend CN baseline 20200414_1'
mine_life_stats_pir_baseline = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_pir_baseline, unit_impacts_pir_baseline, quantities_pir_baseline = calculate_impacts(
    sd_pir_baseline_cn, sd_pir_baseline_rw, sd_pir_baseline, mine_life_stats_pir_baseline,
    direct_melt_demand_pir_baseline_cn, direct_melt_demand_pir_baseline_rw)
    
def pct_inc(impact_change,metric,baseline=total_impacts_pir_baseline):
    '''Returns, global, China, and RoW responses'''
    ph_series1 = impact_change.groupby(axis=1,level=1).sum().loc[idx[:,metric],:].reset_index(level=1,drop=True)
    ph_series2 = impact_change.loc[idx[:,metric],idx['China', :]].reset_index(level=1,drop=True).T.reset_index(level=0,drop=True).T
    ph_series3 = impact_change.loc[idx[:,metric],idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().reset_index(level=1,drop=True)
    ph_series1 = ph_series1.cumsum().loc[:,categories]/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100
    ph_series2 = ph_series2.cumsum().loc[:,categories]/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100
    ph_series3 = ph_series3.cumsum().loc[:,categories]/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100
    return ph_series1,ph_series2,ph_series3

def abs_inc(impact_change,metric,baseline=total_impacts_pir_baseline):
    '''Returns, global, China, and RoW responses'''
    ph_series1 = impact_change.groupby(axis=1,level=1).sum().loc[idx[:,metric],:].reset_index(level=1,drop=True)
    ph_series2 = impact_change.loc[idx[:,metric],idx['China', :]].reset_index(level=1,drop=True).T.reset_index(level=0,drop=True).T
    ph_series3 = impact_change.loc[idx[:,metric],idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().reset_index(level=1,drop=True)
    ph_series1 = ph_series1.cumsum().loc[:,categories]
    ph_series2 = ph_series2.cumsum().loc[:,categories]
    ph_series3 = ph_series3.cumsum().loc[:,categories]
    return ph_series1,ph_series2,ph_series3

categories = ['Direct Melt Scrap', 'Direct Melt Other', 'Fabrication', 'New SX-EW Mines',
                 'New Traditional Mines', 'Operating SX-EW Mines', 'Operating Traditional Mines', 
                 'Primary Refinery', 'Secondary Refinery', 'Refined Metals']
print('All done')
# Out:
# All done

# %%
os.getcwd()

# %%
fig,[ax1,ax2] = plt.subplots(1,2)
psubplot(ax1, scrap_supply_baseline_baseline,'Scrap baseline','#66a61e',0,linewidth=3, firstcall=1)
psubplot(ax1, mining_supply_baseline_baseline,'Mining baseline', colors[0])
psubplot(ax2, mining_supply_baseline_baseline,'Mining baseline', colors[0])

# %%
init_plot()
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c1)
plt.plot([0,1],[0,1])
plt.plot([0,1],[0,2])
plt.plot([0,1],[0,3])
plt.plot([0,1],[0,4])
plt.plot([0,1],[0,5])
plt.plot([0,1],[0,6])
plt.plot([0,1],[0,7])
plt.plot([0,1],[0,8])
plt.plot([0,1],[0,9])
plt.plot([0,1],[0,10])

plt.figure()
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c2)
plt.plot([0,1],[0,1])
plt.plot([0,1],[0,2])
plt.plot([0,1],[0,3])
plt.plot([0,1],[0,4])
plt.plot([0,1],[0,5])
plt.plot([0,1],[0,6])
plt.plot([0,1],[0,7])
plt.plot([0,1],[0,8])
plt.plot([0,1],[0,9])
plt.plot([0,1],[0,10])

plt.figure()
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c3)
plt.plot([0,1],[0,1])
plt.plot([0,1],[0,2])
plt.plot([0,1],[0,3])
plt.plot([0,1],[0,4])
plt.plot([0,1],[0,5])
plt.plot([0,1],[0,6])
plt.plot([0,1],[0,7])
plt.plot([0,1],[0,8])
plt.plot([0,1],[0,9])
plt.plot([0,1],[0,10])

plt.figure()
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4)
plt.plot([0,1],[0,1])
plt.plot([0,1],[0,2])
plt.plot([0,1],[0,3])
plt.plot([0,1],[0,4])
plt.plot([0,1],[0,5])
plt.plot([0,1],[0,6])
plt.plot([0,1],[0,7])
plt.plot([0,1],[0,8])
plt.plot([0,1],[0,9])
plt.plot([0,1],[0,10])

# %% [markdown]
# # Load scenario results

# %% [markdown]
# ## Baselines

# %% [markdown]
# Baseline baseline

# %%
sd_baseline_baseline=pd.read_excel('S&D baseline_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_baseline_baseline=sd_baseline_baseline.loc['19600101':, 'Scrap production']
mining_supply_baseline_baseline=sd_baseline_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_baseline_baseline=pd.read_excel('price baseline_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_baseline=price_baseline_baseline.loc[:, 'Cathode']
sp2_series_baseline_baseline=price_baseline_baseline.loc[:, 'No.2 spread']
tcrc_series_baseline_baseline=price_baseline_baseline.loc[:, 'TCRC']

# %%
sp2_series_baseline_baseline.plot().grid(axis='x')

# %% [markdown]
# Mining production elasticity (MPE)

# %%
sd_low_mpe_baseline=pd.read_excel('S&D low_mpe_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_low_mpe_baseline=sd_low_mpe_baseline.loc['19600101':, 'Scrap production']
mining_supply_low_mpe_baseline=sd_low_mpe_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %%
sd_high_mpe_baseline=pd.read_excel('S&D high_mpe_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_high_mpe_baseline=sd_high_mpe_baseline.loc['19600101':, 'Scrap production']
mining_supply_high_mpe_baseline=sd_high_mpe_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %% [markdown]
# Refinery production elasticity (RPE)

# %%
sd_low_rpe_baseline=pd.read_excel('S&D low_rpe_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_low_rpe_baseline=sd_low_rpe_baseline.loc['19600101':, 'Scrap production']
mining_supply_low_rpe_baseline=sd_low_rpe_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %%
sd_high_rpe_baseline=pd.read_excel('S&D high_rpe_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_high_rpe_baseline=sd_high_rpe_baseline.loc['19600101':, 'Scrap production']
mining_supply_high_rpe_baseline=sd_high_rpe_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %% [markdown]
# Secondary ratio elasticity (SRE)

# %%
sd_low_sre_baseline=pd.read_excel('S&D low_sre_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_low_sre_baseline=sd_low_sre_baseline.loc['19600101':, 'Scrap production']
mining_supply_low_sre_baseline=sd_low_sre_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %%
sd_high_sre_baseline=pd.read_excel('S&D high_sre_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_high_sre_baseline=sd_high_sre_baseline.loc['19600101':, 'Scrap production']
mining_supply_high_sre_baseline=sd_high_sre_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %% [markdown]
# Demand elasticity (DE)

# %%
sd_200_de_baseline=pd.read_excel('S&D 200_de_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_200_de_baseline=sd_200_de_baseline.loc['19600101':, 'Scrap production']
mining_supply_200_de_baseline=sd_200_de_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %%
sd_400_de_baseline=pd.read_excel('S&D 400_de_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_400_de_baseline=sd_400_de_baseline.loc['19600101':, 'Scrap production']
mining_supply_400_de_baseline=sd_400_de_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %% [markdown]
# Scrap S&D elasticity (SSDE)

# %%
sd_low_ssde_baseline=pd.read_excel('S&D low_ssde_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_low_ssde_baseline=sd_low_ssde_baseline.loc['19600101':, 'Scrap production']
mining_supply_low_ssde_baseline=sd_low_ssde_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %%
sd_high_ssde_baseline=pd.read_excel('S&D high_ssde_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_high_ssde_baseline=sd_high_ssde_baseline.loc['19600101':, 'Scrap production']
mining_supply_high_ssde_baseline=sd_high_ssde_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %% [markdown]
# ## Scenarios

# %% [markdown]
# Initializing China-RoW model

# %% [markdown]
# Duration of marginal shocks

# %%
sd_baseline_sm=pd.read_excel('S&D baseline_sm.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_baseline_sm=sd_baseline_sm.loc['19600101':, 'Scrap production']
mining_supply_baseline_sm=sd_baseline_sm.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %%
sd_baseline_lsm=pd.read_excel('S&D baseline_lsm.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_baseline_lsm=sd_baseline_lsm.loc['19600101':, 'Scrap production']
mining_supply_baseline_lsm=sd_baseline_lsm.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %%
sd_baseline_psm=pd.read_excel('S&D baseline_psm.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_baseline_psm=sd_baseline_psm.loc['19600101':, 'Scrap production']
mining_supply_baseline_psm=sd_baseline_psm.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %% [markdown]
# Size of shock

# %%
sd_baseline_irs100=pd.read_excel('S&D baseline_irs100.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_baseline_irs100=sd_baseline_irs100.loc['19600101':, 'Scrap production']
mining_supply_baseline_irs100=sd_baseline_irs100.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)

# %% [markdown]
# ## Importing Data

# %% [markdown]
# ### Functions

# %%
sd_baseline_baseline
# Out:
#             Concentrate production  SX-EW production  Concentrate demand  \
# 1950-01-01             2385.732850          0.000000                 NaN
# 1951-01-01             2491.702356          0.000000                 NaN
# 1952-01-01             2565.865066          0.000000                 NaN
# 1953-01-01             2586.994559          0.000000                 NaN
# 1954-01-01             2639.940230          0.000000                 NaN
# ...                            ...               ...                 ...
# 2036-01-01            21662.145240       3151.005933        21016.291943
# 2037-01-01            21837.884887       3214.738557        21507.103770
# 2038-01-01            22055.807007       3292.060461        21782.501816
# 2039-01-01            22340.630929       3601.249254        22064.533907
# 2040-01-01            22197.696896       4135.033493        22488.476879
#
#             Primary refining production  Secondary refining production  \
# ...

# %%
def baseline_import_lin(file_name):
    '''outputs sd, sd_gl price, total_impacts, quantities'''
    sd_fn_baseline = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx',index_col=0, sheet_name = 'Original')
    price_fn_baseline=pd.read_excel('John/05 China/price '+file_name+'.xlsx', index_col=0, sheet_name='Sheet1')
    sd_fn_baseline.loc[:,'Total refining production'] = sd_fn_baseline.loc[:,'Primary refining production'] + sd_fn_baseline.loc[:,'Secondary refining production']
    
    mine_life_stats_fn_baseline = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
    total_impacts_fn_baseline, unit_impacts_fn_baseline, quantities_fn_baseline = calculate_impacts(
        sd_fn_baseline_cn, sd_fn_baseline_rw, sd_fn_baseline, mine_life_stats_fn_baseline,
        direct_melt_demand_fn_baseline_cn, direct_melt_demand_fn_baseline_rw)
    
    return sd_fn_baseline, sd_fn_baseline_gl, sd_fn_baseline_cn, sd_fn_baseline_rw, price_fn_baseline,\
        total_impacts_fn_baseline, quantities_fn_baseline

sd_lin1yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin1yr=sd_lin1yr.loc['19600101':, 'Scrap production']
mining_supply_lin1yr=sd_lin1yr.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin1yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin1yr=price_lin1yr.loc[:, 'Cathode']
sp2_series_lin1yr=price_lin1yr.loc[:, 'No.2 spread']
tcrc_series_lin1yr=price_lin1yr.loc[:, 'TCRC']
shock_lin1yr = displacement_estimate(sd_lin1yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin1yr = displacement_estimate(sd_lin1yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin1yr = displacement_estimate(sd_lin1yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin1yr=sd_lin1yr.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin1yr = (demand_lin1yr - demand_baseline_baseline).cumsum()

def changes_lin(file_name, sd_fn_baseline, sd_fn_baseline_gl, sd_fn_baseline_cn, sd_fn_baseline_rw, price_fn_baseline,\
           total_impacts_fn_baseline, quantities_fn_baseline):
    '''outputs global, china, and row result dataframes, and multi-indexed impacts for stackplots'''
    fn_scenario_gl = pd.DataFrame(0, index = sd_fn_baseline.loc['20180101':].index, columns = ['Displacement'])
    fn_scenario_cn = pd.DataFrame(0, index = sd_fn_baseline.loc['20180101':].index, columns = ['Displacement'])
    fn_scenario_rw = pd.DataFrame(0, index = sd_fn_baseline.loc['20180101':].index, columns = ['Displacement'])
    
    sd_fn_scenario = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx',index_col=0, sheet_name = 'Original')
    sd_fn_scenario_gl = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', index_col=0, sheet_name='Global')
    sd_fn_scenario_cn = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', index_col=0, sheet_name='China')
    sd_fn_scenario_rw = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', index_col=0, sheet_name='RoW')
    
    direct_melt_demand_fn_scenario_gl = sd_fn_scenario_gl.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
    direct_melt_demand_fn_scenario_cn = sd_fn_scenario_cn.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
    direct_melt_demand_fn_scenario_rw = sd_fn_scenario_rw.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
    direct_melt_demand_fn_scenario_gl.columns = [i.split('\'')[3] for i in direct_melt_demand_fn_scenario_gl.columns]
    direct_melt_demand_fn_scenario_cn.columns = direct_melt_demand_fn_scenario_gl.columns
    direct_melt_demand_fn_scenario_rw.columns = direct_melt_demand_fn_scenario_gl.columns
    direct_melt_demand_fn_baseline_gl = sd_fn_baseline_gl.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
    direct_melt_demand_fn_baseline_cn = sd_fn_baseline_cn.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
    direct_melt_demand_fn_baseline_rw = sd_fn_baseline_rw.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
    direct_melt_demand_fn_baseline_gl.columns = [i.split('\'')[3] for i in direct_melt_demand_fn_baseline_gl.columns]
    direct_melt_demand_fn_baseline_cn.columns = direct_melt_demand_fn_baseline_gl.columns
    direct_melt_demand_fn_baseline_rw.columns = direct_melt_demand_fn_baseline_gl.columns
    
    price_fn_scenario=pd.read_excel('John/05 China/price '+file_name+'.xlsx', index_col=0, sheet_name='Sheet1')
    
    mine_life_stats_fn_scenario = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
    total_impacts_fn_scenario, unit_impacts_fn_scenario, quantities_fn_scenario = calculate_impacts(
        sd_fn_scenario_cn, sd_fn_scenario_rw, sd_fn_scenario, mine_life_stats_fn_scenario,
        direct_melt_demand_fn_scenario_cn, direct_melt_demand_fn_scenario_rw)
    impact_change_fn_scenario = total_impacts_fn_scenario - total_impacts_fn_baseline
    quantity_change_fn_scenario = quantities_fn_scenario - quantities_fn_baseline

    fn_scenario_gl.loc[:,'Displacement'] = displacement_estimate(sd_fn_scenario,scrap_baseline=sd_fn_baseline.loc['19600101':, 'Scrap production'],mining_baseline=sd_fn_baseline.loc['19600101':,['Concentrate production', 'SX-EW production']].sum(axis=1)).loc['20180101':,'Displacement']
    fn_scenario_gl.loc[:,'Mining kt'] = displacement_estimate(sd_fn_scenario,scrap_baseline=sd_fn_baseline.loc['19600101':, 'Scrap production'],mining_baseline=sd_fn_baseline.loc['19600101':,['Concentrate production', 'SX-EW production']].sum(axis=1)).loc['20180101':,'Mining response'].cumsum()
    fn_scenario_gl.loc[:,'Shock kt'] = displacement_estimate(sd_fn_scenario,scrap_baseline=sd_fn_baseline.loc['19600101':, 'Scrap production'],mining_baseline=sd_fn_baseline.loc['19600101':,['Concentrate production', 'SX-EW production']].sum(axis=1)).loc['20180101':,'Shock'].cumsum()
    fn_scenario_gl.loc[:,'Mining %'] = displacement_estimate(sd_fn_scenario,scrap_baseline=sd_fn_baseline.loc['19600101':, 'Scrap production'],mining_baseline=sd_fn_baseline.loc['19600101':,['Concentrate production', 'SX-EW production']].sum(axis=1)).loc['20180101':,'Mining %Increase 2020']*100
    fn_scenario_gl.loc[:,'Shock %'] = displacement_estimate(sd_fn_scenario,scrap_baseline=sd_fn_baseline.loc['19600101':, 'Scrap production'],mining_baseline=sd_fn_baseline.loc['19600101':,['Concentrate production', 'SX-EW production']].sum(axis=1)).loc['20180101':,'Scrap %Increase 2020']*100
    fn_scenario_gl.loc[:,'Demand Displacement'] = -fn_scenario_gl.loc[:,'Mining kt']/fn_scenario_gl.loc[:,'Shock kt']
    
    fn_scenario_gl.loc[:,'Copper absolute'] = direct_melt_demand_fn_scenario_gl.loc['20180101':,'Ref_Cu']+direct_melt_demand_fn_scenario_gl.loc['20180101':,'Yellow_Brass':'Mainboard-Alloy'].sum(axis=1)
    fn_scenario_cn.loc[:,'Copper absolute'] = direct_melt_demand_fn_scenario_cn.loc['20180101':,'Ref_Cu']+direct_melt_demand_fn_scenario_cn.loc['20180101':,'Yellow_Brass':'Mainboard-Alloy'].sum(axis=1)
    fn_scenario_rw.loc[:,'Copper absolute'] = direct_melt_demand_fn_scenario_rw.loc['20180101':,'Ref_Cu']+direct_melt_demand_fn_scenario_rw.loc['20180101':,'Yellow_Brass':'Mainboard-Alloy'].sum(axis=1)
    
    fn_scenario_gl.loc[:,'Scrap kt'] = sd_fn_scenario_gl.loc['20180101':,'(\'Direct melt demand\', \'Yellow_Brass\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')'].sum(axis=1).cumsum()-\
        sd_fn_baseline_gl.loc['20180101':,'(\'Direct melt demand\', \'Yellow_Brass\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')'].sum(axis=1).cumsum()
    fn_scenario_gl.loc[:,'Scrap %'] = (sd_fn_scenario_gl.loc['20180101':,'(\'Direct melt demand\', \'Yellow_Brass\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')'].sum(axis=1).cumsum()-\
        sd_fn_baseline_gl.loc['20180101':,'(\'Direct melt demand\', \'Yellow_Brass\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')'].sum(axis=1).cumsum())/\
        sd_fn_baseline_gl.loc['20200101','(\'Direct melt demand\', \'Yellow_Brass\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')'].sum()*100
    
    q_fn_baseline_cn = quantities_fn_baseline.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum()

    fn_scenario_cn.loc[:,'Mining %'] = quantity_change_fn_scenario.loc[
        idx['20180101':,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_fn_baseline_cn.loc['20200101']*100
    fn_scenario_cn.loc[:,'Mining kt'] = quantity_change_fn_scenario.loc[
        idx['20180101':,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()
    
    row = [i for i in quantities_fn_baseline.columns if i != 'China']

    q_fn_baseline_rw = quantities_fn_baseline.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum()

    fn_scenario_rw.loc[:,'Mining %'] = quantity_change_fn_scenario.loc[
            idx['20180101':,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
            row].sum(axis=1).groupby(level=0).sum().cumsum()/q_fn_baseline_rw.loc['20200101']*100
    fn_scenario_rw.loc[:,'Mining kt'] = quantity_change_fn_scenario.loc[
            idx['20180101':,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
            row].sum(axis=1).groupby(level=0).sum().cumsum()
    
    for prop in ['Primary refining','Secondary refining','Refined demand']:
        if prop != 'Refined demand':
            prop2 = prop+' production'
        fn_scenario_gl.loc[:,prop+' kt'] = sd_fn_scenario_gl.loc['20180101':,prop2].cumsum() - sd_fn_baseline_gl.loc['20180101':,prop2].cumsum()
        fn_scenario_gl.loc[:,prop+' %'] = 100*fn_scenario_gl.loc[:,prop+' kt']/sd_fn_baseline_gl.loc['20200101',prop2]
        
        if prop == 'Refined demand':
            prop2 = 'CN Refined demand'
        fn_scenario_cn.loc[:,prop+' kt'] = sd_fn_scenario_cn.loc['20180101':,prop2].cumsum() - sd_fn_baseline_cn.loc['20180101':,prop2].cumsum()
        fn_scenario_cn.loc[:,prop+' %'] = 100*fn_scenario_cn.loc[:,prop+' kt']/sd_fn_baseline_cn.loc['20200101',prop2]
        
        if prop == 'Refined demand':
            prop2 = 'RoW Refined demand'
        fn_scenario_rw.loc[:,prop+' kt'] = sd_fn_scenario_rw.loc['20180101':,prop2].cumsum() - sd_fn_baseline_rw.loc['20180101':,prop2].cumsum()
        fn_scenario_rw.loc[:,prop+' %'] = 100*fn_scenario_rw.loc[:,prop+' kt']/sd_fn_baseline_rw.loc['20200101',prop2]
        
        if prop != 'Refined demand':
            fn_scenario_cn.loc[:,prop+' % tot'] = 100*fn_scenario_cn.loc[:,prop+' kt']/sd_fn_baseline_cn.loc['20200101','Total refining production']
            fn_scenario_rw.loc[:,prop+' % tot'] = 100*fn_scenario_rw.loc[:,prop+' kt']/sd_fn_baseline_rw.loc['20200101','Total refining production']
            fn_scenario_gl.loc[:,prop+' % tot'] = 100*fn_scenario_gl.loc[:,prop+' kt']/sd_fn_baseline_gl.loc['20200101','Total refining production']
            
    fn_scenario_gl.loc[:,'Total refining kt'] = fn_scenario_gl.loc['20180101':,'Primary refining kt'] + fn_scenario_gl.loc['20180101':,'Secondary refining kt']
    fn_scenario_cn.loc[:,'Total refining kt'] = fn_scenario_cn.loc['20180101':,'Primary refining kt'] + fn_scenario_cn.loc['20180101':,'Secondary refining kt']
    fn_scenario_rw.loc[:,'Total refining kt'] = fn_scenario_rw.loc['20180101':,'Primary refining kt'] + fn_scenario_rw.loc['20180101':,'Secondary refining kt']
    
    fn_scenario_gl.loc[:,'Total refining %'] = 100*fn_scenario_gl.loc[:,'Total refining kt']/sd_fn_baseline_gl.loc['20200101','Total refining production']   
    fn_scenario_cn.loc[:,'Total refining %'] = 100*fn_scenario_cn.loc[:,'Total refining kt']/sd_fn_baseline_cn.loc['20200101','Total refining production']   
    fn_scenario_rw.loc[:,'Total refining %'] = 100*fn_scenario_rw.loc[:,'Total refining kt']/sd_fn_baseline_rw.loc['20200101','Total refining production']   
    
    pha_gl, pha_cn, pha_rw = \
        abs_inc(impact_change_fn_scenario,'Global warming (kt CO2 eq)',total_impacts_fn_baseline)
    fn_scenario_gl.loc[:,'CO2 kt'], fn_scenario_cn.loc[:,'CO2 kt'], fn_scenario_rw.loc[:,'CO2 kt']\
        = pha_gl.loc['20180101':].sum(axis=1),pha_cn.loc['20180101':].sum(axis=1),pha_rw.loc['20180101':].sum(axis=1)
    ph_gl, ph_cn, ph_rw = \
        pct_inc(impact_change_fn_scenario,'Global warming (kt CO2 eq)',total_impacts_fn_baseline)
    fn_scenario_gl.loc[:,'CO2 %'], fn_scenario_cn.loc[:,'CO2 %'], fn_scenario_rw.loc[:,'CO2 %']\
        = ph_gl.loc['20180101':].sum(axis=1),ph_cn.loc['20180101':].sum(axis=1),ph_rw.loc['20180101':].sum(axis=1)
    stacker = pd.concat([pha_gl.loc['20180101':], pha_cn.loc['20180101':], pha_rw.loc['20180101':],
                        ph_gl.loc['20180101':], ph_cn.loc['20180101':], ph_rw.loc['20180101':],
                        total_impacts_fn_scenario.groupby(level=1, axis=1).sum().loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].reset_index(drop=True,level=1)],
                       keys=['Global kt','China kt','RoW kt','Global %','China %','RoW %','Absolute kt'], axis=0)
    itera = 0
    for metric in [i for i in impact_change_fn_scenario.index.levels[1] if 'Renewable' not in i and 'renewable' not in i and 'warming' not in i]:
        pha_gl, pha_cn, pha_rw = \
            abs_inc(impact_change_fn_scenario,metric,total_impacts_fn_baseline)
        ph_gl, ph_cn, ph_rw = \
            pct_inc(impact_change_fn_scenario,metric,total_impacts_fn_baseline)
        stacker_ph = pd.concat([pha_gl.loc['20180101':], pha_cn.loc['20180101':], pha_rw.loc['20180101':],
                            ph_gl.loc['20180101':], ph_cn.loc['20180101':], ph_rw.loc['20180101':],
                            total_impacts_fn_scenario.groupby(level=1, axis=1).sum().loc[idx['20180101':,metric],:].reset_index(drop=True,level=1)],
                           keys=['Global kt','China kt','RoW kt','Global %','China %','RoW %','Absolute kt'], axis=0)
        stacker_ph.index = pd.MultiIndex.from_product([[metric],stacker_ph.index.levels[0],stacker_ph.index.levels[1]])
        if itera == 0:
            other_impacts = stacker_ph.copy()
        else:
            other_impacts = pd.concat([other_impacts,stacker_ph])
        itera += 1
    
    # Cathode price
    fn_scenario_gl.loc[:,'Cathode price'] = price_fn_scenario.loc['20180101':,'Cathode']
    fn_scenario_gl.loc[:,'Cathode price diff'] = price_fn_scenario.loc['20180101':,'Cathode'] - price_fn_baseline.loc['20180101':,'Cathode']
    # TCRC
    fn_scenario_gl.loc[:,'TCRC'] = price_fn_scenario.loc['20180101':,'TCRC']
    fn_scenario_gl.loc[:,'TCRC diff'] = price_fn_scenario.loc['20180101':,'TCRC'] - price_fn_baseline.loc['20180101':,'TCRC']
    # No.2 price
    fn_scenario_gl.loc[:,'No.2 price'] = price_fn_scenario.loc['20180101':,'Cathode'] - price_fn_scenario.loc['20180101':,'No.2 spread']
    fn_scenario_gl.loc[:,'No.2 price diff'] = (price_fn_scenario.loc['20180101':,'Cathode']-price_fn_scenario.loc['20180101':,'No.2 spread'])\
        - (price_fn_baseline.loc['20180101':,'Cathode']-price_fn_baseline.loc['20180101':,'No.2 spread'])
    fn_scenario_cn.loc[:,'No.2 price'] = price_fn_scenario.loc['20180101':,'Cathode'] - price_fn_scenario.loc['20180101':,'No.2 spread CN']
    fn_scenario_cn.loc[:,'No.2 price diff'] = (price_fn_scenario.loc['20180101':,'Cathode']-price_fn_scenario.loc['20180101':,'No.2 spread CN'])\
        - (price_fn_baseline.loc['20180101':,'Cathode']-price_fn_baseline.loc['20180101':,'No.2 spread CN'])
    fn_scenario_rw.loc[:,'No.2 price'] = price_fn_scenario.loc['20180101':,'Cathode'] - price_fn_scenario.loc['20180101':,'No.2 spread RoW']
    fn_scenario_rw.loc[:,'No.2 price diff'] = (price_fn_scenario.loc['20180101':,'Cathode']-price_fn_scenario.loc['20180101':,'No.2 spread RoW'])\
        - (price_fn_baseline.loc['20180101':,'Cathode']-price_fn_baseline.loc['20180101':,'No.2 spread RoW'])
    
    fn_scenario_gl.loc[:,'No.2 spread'] = price_fn_scenario.loc['20180101':,'No.2 spread']
    fn_scenario_gl.loc[:,'No.2 spread diff'] = price_fn_scenario.loc['20180101':,'No.2 spread']\
        -price_fn_baseline.loc['20180101':,'No.2 spread']
    fn_scenario_cn.loc[:,'No.2 spread'] = price_fn_scenario.loc['20180101':,'No.2 spread CN']
    fn_scenario_cn.loc[:,'No.2 spread diff'] = price_fn_scenario.loc['20180101':,'No.2 spread CN']\
        -price_fn_baseline.loc['20180101':,'No.2 spread CN']
    fn_scenario_rw.loc[:,'No.2 spread'] = price_fn_scenario.loc['20180101':,'No.2 spread RoW']
    fn_scenario_rw.loc[:,'No.2 spread diff'] = price_fn_scenario.loc['20180101':,'No.2 spread RoW']\
        -price_fn_baseline.loc['20180101':,'No.2 spread RoW']
    
    
    return fn_scenario_gl, fn_scenario_cn, fn_scenario_rw, stacker, other_impacts

print('woo')
# Out:
# woo

# %% [markdown]
# ### Systematic Linear Imports

# %%
sd_baseline_baseline,price_baseline_baseline, total_impacts_baseline_baseline, quantities_baseline_baseline\
    = baseline_import_lin(scenarios[0])

lin_gl, lin_stack, lin_other = changes_lin(scenarios[1], sd_baseline_baseline,\
    price_baseline_baseline, total_impacts_baseline_baseline, quantities_baseline_baseline)

lin_gl.index = pd.MultiIndex.from_product([[0],lin_gl.index])
lin_gl = pd.concat([lin_gl],keys=[0])
lin_gl = pd.concat([lin_gl],keys=[0])
lin_gl = pd.concat([lin_gl],keys=[0])
lin_gl = pd.concat([lin_gl],keys=[2.45])
lin_stack = pd.concat([lin_stack],keys=[0])
lin_stack = pd.concat([lin_stack],keys=[0])
lin_stack = pd.concat([lin_stack],keys=[0])
lin_stack = pd.concat([lin_stack],keys=[0])
lin_stack = pd.concat([lin_stack],keys=[2.45])
lin_other = pd.concat([lin_other],keys=[0])
lin_other = pd.concat([lin_other],keys=[0])
lin_other = pd.concat([lin_other],keys=[0])
lin_other = pd.concat([lin_other],keys=[0])
lin_other = pd.concat([lin_other],keys=[2.45])

print('start')
x = 0
itera = scenarios[2:]+scenarios_200
# for scenario in scenarios[2:]:
for scenario in itera:
    if 'refcu' in scenario:
        ref_cu_pct_change = float(scenario.split('refcu')[-1].split()[0])
    else:
        ref_cu_pct_change = 0
    if 'nsr' in scenario:
        ref_cu_pct_change = str(ref_cu_pct_change)+' nsr'
        
    if 'minecu' in scenario:
        mine_cu_pct_change = float(scenario.split('minecu')[-1].split()[0])
    else:
        mine_cu_pct_change = 0

    if 'gdpc' in scenario:
        gdp_pct_change = float(scenario.split('gdpc')[-1].split()[0])
    else:
        gdp_pct_change = 0
    
    if '50yoy' in scenario or '_50' in scenario:
        yoy = '50yoy'
    elif '25yoy' in scenario:
        yoy = '25yoy'
    elif '75yoy' in scenario:
        yoy = '75yoy'
    else:
        yoy=0
    if '200' in scenario:
        yoy = yoy+'200'
        
    if 'both' in scenario or 'b_' in scenario:
        ban = 'both'
    elif 'no2' in scenario or 'n_' in scenario:
        ban = 'no2'
    elif 'alloyed' in scenario:
        ban = 'alloyed'
    else:
        ban = 0
        
    if 'allshock' in scenario:
        ref_cu_pct_change = 2.29
        mine_cu_pct_change = 2.62
        gdp_pct_change = 2.45
        
    ph_lin_gl, ph_lin_cn, ph_lin_rw, ph_lin_stack, ph_lin_other = changes_lin(scenario, sd_baseline_baseline, \
        price_baseline_baseline, total_impacts_baseline_baseline, quantities_baseline_baseline)
 
    ph_lin_gl.index = pd.MultiIndex.from_product([[yoy],ph_lin_gl.index])
#     ph_lin_gl = pd.concat([ph_lin_gl],keys=[yoy])
    ph_lin_gl = pd.concat([ph_lin_gl],keys=[ban])
    ph_lin_gl = pd.concat([ph_lin_gl],keys=[ref_cu_pct_change])
    ph_lin_gl = pd.concat([ph_lin_gl],keys=[mine_cu_pct_change])
    ph_lin_gl = pd.concat([ph_lin_gl],keys=[gdp_pct_change])
    ph_lin_stack = pd.concat([ph_lin_stack],keys=[yoy])
    ph_lin_stack = pd.concat([ph_lin_stack],keys=[ban])
    ph_lin_stack = pd.concat([ph_lin_stack],keys=[ref_cu_pct_change])
    ph_lin_stack = pd.concat([ph_lin_stack],keys=[mine_cu_pct_change])
    ph_lin_stack = pd.concat([ph_lin_stack],keys=[gdp_pct_change])
    ph_lin_other = pd.concat([ph_lin_other],keys=[yoy])
    ph_lin_other = pd.concat([ph_lin_other],keys=[ban])
    ph_lin_other = pd.concat([ph_lin_other],keys=[ref_cu_pct_change])
    ph_lin_other = pd.concat([ph_lin_other],keys=[mine_cu_pct_change])
    ph_lin_other = pd.concat([ph_lin_other],keys=[gdp_pct_change])

    lin_gl = pd.concat([lin_gl, ph_lin_gl])
    lin_stack = pd.concat([lin_stack, ph_lin_stack])
    lin_other = pd.concat([lin_other, ph_lin_other])
    
    x+=1
    if x % 10 == 0:
        print(str(x)+'/'+str(len(itera)))
        
lin_gl.index.set_names('GDP',level=0,inplace=True)
lin_gl.index.set_names('Mines',level=1,inplace=True)
lin_gl.index.set_names('Ref.',level=2,inplace=True)
lin_gl.index.set_names('Ban',level=3,inplace=True)
lin_gl.index.set_names('Rate',level=4,inplace=True)
lin_gl = lin_gl.sort_index()
        
lin_stack.index.set_names('GDP',level=0,inplace=True)
lin_stack.index.set_names('Mines',level=1,inplace=True)
lin_stack.index.set_names('Ref.',level=2,inplace=True)
lin_stack.index.set_names('Ban',level=3,inplace=True)
lin_stack.index.set_names('Rate',level=4,inplace=True)
lin_stack = lin_stack.sort_index()
print('Finito')

# %% [markdown]
# ### Linear ramp scenarios

# %%
filename = 'baseline_baseline'
sd_baseline_baseline=pd.read_excel('S&D baseline_baseline.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_baseline_baseline=sd_baseline_baseline.loc['19600101':, 'Scrap production']
mining_supply_baseline_baseline=sd_baseline_baseline.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_baseline_baseline=pd.read_excel('price baseline_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_baseline=price_baseline_baseline.loc[:, 'Cathode']
sp2_series_baseline_baseline=price_baseline_baseline.loc[:, 'No.2 spread']
tcrc_series_baseline_baseline=price_baseline_baseline.loc[:, 'TCRC']
demand_baseline_baseline=sd_baseline_baseline.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
mine_life_stats_baseline_baseline = pd.read_excel('Mine level info/mine life '+filename+'.xlsx', index_col=[0,1])

total_impacts_baseline_baseline, unit_impacts_baseline_baseline, quantities_baseline_baseline = calculate_impacts_lin(sd_baseline_baseline, mine_life_stats_baseline_baseline)
# Out:
# Done

# %%
filename = 'linshock1yr-sp2-1'
sd_lin1yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin1yr=sd_lin1yr.loc['19600101':, 'Scrap production']
mining_supply_lin1yr=sd_lin1yr.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin1yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin1yr=price_lin1yr.loc[:, 'Cathode']
sp2_series_lin1yr=price_lin1yr.loc[:, 'No.2 spread']
tcrc_series_lin1yr=price_lin1yr.loc[:, 'TCRC']
shock_lin1yr = displacement_estimate(sd_lin1yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin1yr = displacement_estimate(sd_lin1yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin1yr = displacement_estimate(sd_lin1yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin1yr=sd_lin1yr.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin1yr = (demand_lin1yr - demand_baseline_baseline).cumsum()

# %%
sd_lin1yr.columns

# %%
init_plot()
scrap_demand = 100*(sd_lin1yr.loc[:,'Direct melt scrap':'Refined scrap'].sum(axis=1)-sd_baseline_baseline.loc[:,'Direct melt scrap':'Refined scrap'].sum(axis=1)).cumsum()/sd_lin1yr.loc['20180101','Direct melt scrap':'Refined scrap'].sum()
cathode_price = 100*(cathode_price_series_lin1yr/cathode_price_series_baseline_baseline-1)
cathode_price1 = 100*(cathode_price_series_lin1yr-cathode_price_series_baseline_baseline)/cathode_price_series_lin1yr.loc['20180101']
tcrc_price1 = 100*(tcrc_series_lin1yr-tcrc_series_baseline_baseline)/tcrc_series_lin1yr.loc['20180101']
scrap_price = 100*((cathode_price_series_lin1yr-sp2_series_lin1yr)/(cathode_price_series_baseline_baseline-sp2_series_baseline_baseline)-1)
scrap_price1 = 100*((cathode_price_series_lin1yr-sp2_series_lin1yr)-(cathode_price_series_baseline_baseline-sp2_series_baseline_baseline))/(cathode_price_series_lin1yr-sp2_series_lin1yr).loc['20180101']
refin = ['Primary refining production','Secondary refining production']
refinery_response = 100*(sd_lin1yr.loc[:,refin].sum(axis=1)-sd_baseline_baseline.loc[:,refin].sum(axis=1)).cumsum()/sd_lin1yr.loc['20180101',refin].sum()
pri_refinery_response = 100*(sd_lin1yr.loc[:,'Primary refining production']-sd_baseline_baseline.loc[:,'Primary refining production']).cumsum()/sd_lin1yr.loc['20180101','Primary refining production']
plt.plot(pri_refinery_response.loc['20180101':],color=colors[3],label='Scrap demand')
plt.plot(cathode_price1.loc['20180101':],color=colors[1],label='Cathode price')
# plt.plot(scrap_price1.loc['20180101':],color=colors[2],label='Scrap price')
plt.plot(100*mining_response_lin1yr.cumsum().loc['20180101':]/mining_supply_baseline_baseline.loc['20180101'],color=colors[0],label='Mining')
plt.plot(tcrc_price1.loc['20180101':],color=colors[2],label='TCRC')
# plt.legend()
plt.title('Massive Scrap Shock System Propagation')
plt.ylabel('Percent increase above 2020 value')
plt.xlabel('Year')

# %%
filename = 'linshock1yr10-sp2'
sd_lin1yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin1yr10=sd_lin1yr10.loc['19600101':, 'Scrap production']
mining_supply_lin1yr10=sd_lin1yr10.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin1yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin1yr10=price_lin1yr10.loc[:, 'Cathode']
sp2_series_lin1yr10=price_lin1yr10.loc[:, 'No.2 spread']
tcrc_series_lin1yr10=price_lin1yr10.loc[:, 'TCRC']
shock_lin1yr10 = displacement_estimate(sd_lin1yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin1yr10 = displacement_estimate(sd_lin1yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin1yr10 = displacement_estimate(sd_lin1yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin1yr10=sd_lin1yr10.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin1yr10 = (demand_lin1yr10 - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock1yr20-sp2'
sd_lin1yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin1yr20=sd_lin1yr20.loc['19600101':, 'Scrap production']
mining_supply_lin1yr20=sd_lin1yr20.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin1yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin1yr20=price_lin1yr20.loc[:, 'Cathode']
sp2_series_lin1yr20=price_lin1yr20.loc[:, 'No.2 spread']
tcrc_series_lin1yr20=price_lin1yr20.loc[:, 'TCRC']
shock_lin1yr20 = displacement_estimate(sd_lin1yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin1yr20 = displacement_estimate(sd_lin1yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin1yr20 = displacement_estimate(sd_lin1yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin1yr20=sd_lin1yr20.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin1yr20 = (demand_lin1yr20 - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock1yr50-sp2'
sd_lin1yr50=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin1yr50=sd_lin1yr50.loc['19600101':, 'Scrap production']
mining_supply_lin1yr50=sd_lin1yr50.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin1yr50=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin1yr50=price_lin1yr50.loc[:, 'Cathode']
sp2_series_lin1yr50=price_lin1yr50.loc[:, 'No.2 spread']
tcrc_series_lin1yr50=price_lin1yr50.loc[:, 'TCRC']
shock_lin1yr50 = displacement_estimate(sd_lin1yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin1yr50 = displacement_estimate(sd_lin1yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin1yr50 = displacement_estimate(sd_lin1yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin1yr50=sd_lin1yr50.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin1yr50 = (demand_lin1yr50 - demand_baseline_baseline).cumsum()

# %% [markdown]
# 5-year shocks

# %%
filename = 'linshock5yr-sp2-1'
sd_lin5yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin5yr=sd_lin5yr.loc['19600101':, 'Scrap production']
mining_supply_lin5yr=sd_lin5yr.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin5yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin5yr=price_lin5yr.loc[:, 'Cathode']
sp2_series_lin5yr=price_lin5yr.loc[:, 'No.2 spread']
tcrc_series_lin5yr=price_lin5yr.loc[:, 'TCRC']
shock_lin5yr = displacement_estimate(sd_lin5yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin5yr = displacement_estimate(sd_lin5yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin5yr = displacement_estimate(sd_lin5yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin5yr=sd_lin5yr.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin5yr = (demand_lin5yr - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock5yr10-sp2'
sd_lin5yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin5yr10=sd_lin5yr10.loc['19600101':, 'Scrap production']
mining_supply_lin5yr10=sd_lin5yr10.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin5yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin5yr10=price_lin5yr10.loc[:, 'Cathode']
sp2_series_lin5yr10=price_lin5yr10.loc[:, 'No.2 spread']
tcrc_series_lin5yr10=price_lin5yr10.loc[:, 'TCRC']
shock_lin5yr10 = displacement_estimate(sd_lin5yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin5yr10 = displacement_estimate(sd_lin5yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin5yr10 = displacement_estimate(sd_lin5yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin5yr10=sd_lin5yr10.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin5yr10 = (demand_lin5yr10 - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock5yr20-sp2'
sd_lin5yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin5yr20=sd_lin5yr20.loc['19600101':, 'Scrap production']
mining_supply_lin5yr20=sd_lin5yr20.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin5yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin5yr20=price_lin5yr20.loc[:, 'Cathode']
sp2_series_lin5yr20=price_lin5yr20.loc[:, 'No.2 spread']
tcrc_series_lin5yr20=price_lin5yr20.loc[:, 'TCRC']
shock_lin5yr20 = displacement_estimate(sd_lin5yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin5yr20 = displacement_estimate(sd_lin5yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin5yr20 = displacement_estimate(sd_lin5yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin5yr20=sd_lin5yr20.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin5yr20 = (demand_lin5yr20 - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock5yr50-sp2'
sd_lin5yr50=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin5yr50=sd_lin5yr50.loc['19600101':, 'Scrap production']
mining_supply_lin5yr50=sd_lin5yr50.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin5yr50=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin5yr50=price_lin5yr50.loc[:, 'Cathode']
sp2_series_lin5yr50=price_lin5yr50.loc[:, 'No.2 spread']
tcrc_series_lin5yr50=price_lin5yr50.loc[:, 'TCRC']
shock_lin5yr50 = displacement_estimate(sd_lin5yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin5yr50 = displacement_estimate(sd_lin5yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin5yr50 = displacement_estimate(sd_lin5yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin5yr50=sd_lin5yr50.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin5yr50 = (demand_lin5yr50 - demand_baseline_baseline).cumsum()

# %% [markdown]
# 10-year shocks

# %%
filename = 'linshock10yr-sp2-1'
sd_lin10yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin10yr=sd_lin10yr.loc['19600101':, 'Scrap production']
mining_supply_lin10yr=sd_lin10yr.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin10yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin10yr=price_lin10yr.loc[:, 'Cathode']
sp2_series_lin10yr=price_lin10yr.loc[:, 'No.2 spread']
tcrc_series_lin10yr=price_lin10yr.loc[:, 'TCRC']
shock_lin10yr = displacement_estimate(sd_lin10yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin10yr = displacement_estimate(sd_lin10yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin10yr = displacement_estimate(sd_lin10yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin10yr=sd_lin10yr.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin10yr = (demand_lin10yr - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock10yr10-sp2'
sd_lin10yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin10yr10=sd_lin10yr10.loc['19600101':, 'Scrap production']
mining_supply_lin10yr10=sd_lin10yr10.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin10yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin10yr10=price_lin10yr10.loc[:, 'Cathode']
sp2_series_lin10yr10=price_lin10yr10.loc[:, 'No.2 spread']
tcrc_series_lin10yr10=price_lin10yr10.loc[:, 'TCRC']
shock_lin10yr10 = displacement_estimate(sd_lin10yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin10yr10 = displacement_estimate(sd_lin10yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin10yr10 = displacement_estimate(sd_lin10yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin10yr10=sd_lin10yr10.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin10yr10 = (demand_lin10yr10 - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock10yr20-sp2'
sd_lin10yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin10yr20=sd_lin10yr20.loc['19600101':, 'Scrap production']
mining_supply_lin10yr20=sd_lin10yr20.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin10yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin10yr20=price_lin10yr20.loc[:, 'Cathode']
sp2_series_lin10yr20=price_lin10yr20.loc[:, 'No.2 spread']
tcrc_series_lin10yr20=price_lin10yr20.loc[:, 'TCRC']
shock_lin10yr20 = displacement_estimate(sd_lin10yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin10yr20 = displacement_estimate(sd_lin10yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin10yr20 = displacement_estimate(sd_lin10yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin10yr20=sd_lin10yr20.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin10yr20 = (demand_lin10yr20 - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock10yr50-sp2'
sd_lin10yr50=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin10yr50=sd_lin10yr50.loc['19600101':, 'Scrap production']
mining_supply_lin10yr50=sd_lin10yr50.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin10yr50=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin10yr50=price_lin10yr50.loc[:, 'Cathode']
sp2_series_lin10yr50=price_lin10yr50.loc[:, 'No.2 spread']
tcrc_series_lin10yr50=price_lin10yr50.loc[:, 'TCRC']
shock_lin10yr50 = displacement_estimate(sd_lin10yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin10yr50 = displacement_estimate(sd_lin10yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin10yr50 = displacement_estimate(sd_lin10yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin10yr50=sd_lin10yr50.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin10yr50 = (demand_lin10yr50 - demand_baseline_baseline).cumsum()

# %% [markdown]
# 20-year ramps

# %%
filename = 'linshock20yr-sp2-1'
sd_lin20yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin20yr=sd_lin20yr.loc['19600101':, 'Scrap production']
mining_supply_lin20yr=sd_lin20yr.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin20yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin20yr=price_lin20yr.loc[:, 'Cathode']
sp2_series_lin20yr=price_lin20yr.loc[:, 'No.2 spread']
tcrc_series_lin20yr=price_lin20yr.loc[:, 'TCRC']
shock_lin20yr = displacement_estimate(sd_lin20yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin20yr = displacement_estimate(sd_lin20yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin20yr = displacement_estimate(sd_lin20yr, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin20yr=sd_lin20yr.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin20yr = (demand_lin20yr - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock20yr10-sp2'
sd_lin20yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin20yr10=sd_lin20yr10.loc['19600101':, 'Scrap production']
mining_supply_lin20yr10=sd_lin20yr10.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin20yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin20yr10=price_lin20yr10.loc[:, 'Cathode']
sp2_series_lin20yr10=price_lin20yr10.loc[:, 'No.2 spread']
tcrc_series_lin20yr10=price_lin20yr10.loc[:, 'TCRC']
shock_lin20yr10 = displacement_estimate(sd_lin20yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin20yr10 = displacement_estimate(sd_lin20yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin20yr10 = displacement_estimate(sd_lin20yr10, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin20yr10=sd_lin20yr10.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin20yr10 = (demand_lin20yr10 - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock20yr20-sp2'
sd_lin20yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin20yr20=sd_lin20yr20.loc['19600101':, 'Scrap production']
mining_supply_lin20yr20=sd_lin20yr20.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin20yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin20yr20=price_lin20yr20.loc[:, 'Cathode']
sp2_series_lin20yr20=price_lin20yr20.loc[:, 'No.2 spread']
tcrc_series_lin20yr20=price_lin20yr20.loc[:, 'TCRC']
shock_lin20yr20 = displacement_estimate(sd_lin20yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin20yr20 = displacement_estimate(sd_lin20yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin20yr20 = displacement_estimate(sd_lin20yr20, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin20yr20=sd_lin20yr20.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin20yr20 = (demand_lin20yr20 - demand_baseline_baseline).cumsum()

# %%
filename = 'linshock20yr50-sp2'
sd_lin20yr50=pd.read_excel('John/00 Initial Linear Ramp Shocks/S&D '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
scrap_supply_lin20yr50=sd_lin20yr50.loc['19600101':, 'Scrap production']
mining_supply_lin20yr50=sd_lin20yr50.loc['19600101':, ['Concentrate production', 'SX-EW production']].sum(axis=1)
price_lin20yr50=pd.read_excel('John/00 Initial Linear Ramp Shocks/price '+filename+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin20yr50=price_lin20yr50.loc[:, 'Cathode']
sp2_series_lin20yr50=price_lin20yr50.loc[:, 'No.2 spread']
tcrc_series_lin20yr50=price_lin20yr50.loc[:, 'TCRC']
shock_lin20yr50 = displacement_estimate(sd_lin20yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Shock']
mining_response_lin20yr50 = displacement_estimate(sd_lin20yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Mining response']
displacement_lin20yr50 = displacement_estimate(sd_lin20yr50, 
    scrap_supply_baseline_baseline, mining_supply_baseline_baseline).loc[:,'Displacement']
demand_lin20yr50=sd_lin20yr50.loc[:,['Refined demand','Direct melt scrap']].sum(axis=1)
demand_shock_lin20yr50 = (demand_lin20yr50 - demand_baseline_baseline).cumsum()

# %%
print(displacement_lin1yr10.loc['20400101'],';', displacement_lin1yr20.loc['20400101'],';', displacement_lin1yr50.loc['20400101'],';', displacement_lin1yr.loc['20400101'])
print(displacement_lin5yr10.loc['20400101'],';', displacement_lin5yr20.loc['20400101'],';', displacement_lin5yr50.loc['20400101'],';', displacement_lin5yr.loc['20400101'])
print(displacement_lin10yr10.loc['20400101'],';', displacement_lin10yr20.loc['20400101'],';', displacement_lin10yr50.loc['20400101'],';', displacement_lin10yr.loc['20400101'])
print(displacement_lin20yr10.loc['20400101'],';', displacement_lin20yr20.loc['20400101'],';', displacement_lin20yr50.loc['20400101'],';', displacement_lin20yr.loc['20400101'])

# %%
file_name = 'new baseline_baseline'
sd_other_baseline = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx',sheet_name = 'Original')
sd_other_baseline_gl = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', sheet_name='Global')
sd_other_baseline_cn = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', sheet_name='China')
sd_other_baseline_rw = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', sheet_name='RoW')
scrap_supply_other_baseline = sd_other_baseline.loc['19600101':, 'Scrap production']
mining_supply_other_baseline = sd_other_baseline.loc['19600101':,['Concentrate production', 'SX-EW production']].sum(axis=1)
price_other_baseline=pd.read_excel('John/05 China/price '+file_name+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_other_baseline=price_other_baseline.loc[:, 'Cathode']
sp2_series_other_baseline_gl=price_other_baseline.loc[:, 'No.2 spread']
sp2_series_other_baseline_cn=price_other_baseline.loc[:, 'No.2 spread CN']
sp2_series_other_baseline_rw=price_other_baseline.loc[:, 'No.2 spread RoW']
spa_series_other_baseline_gl=price_other_baseline.loc[:, 'Yellow brass spread']
spa_series_other_baseline_cn=price_other_baseline.loc[:, 'Yellow brass spread CN']
spa_series_other_baseline_rw=price_other_baseline.loc[:, 'Yellow brass spread RoW']
tcrc_series_other_baseline=price_other_baseline.loc[:, 'TCRC']
ref_props_other_baseline_gl = sd_other_baseline_gl.loc[:,'Primary refining production':'Secondary ratio'].copy().copy()
ref_props_other_baseline_cn = sd_other_baseline_cn.loc[:,'Primary refining production':'Secondary ratio'].copy().copy()
ref_props_other_baseline_rw = sd_other_baseline_rw.loc[:,'Primary refining production':'Secondary ratio'].copy().copy()
all_scrap_available_other_baseline_gl = sd_other_baseline_gl.loc['19600101':,'(\'All scrap available\', \'No.1\')':'(\'All scrap available\', \'Mainboard-Alloy\')']
all_scrap_available_other_baseline_cn = sd_other_baseline_cn.loc['19600101':,'(\'All scrap available\', \'No.1\')':'(\'All scrap available\', \'Mainboard-Alloy\')']
all_scrap_available_other_baseline_rw = sd_other_baseline_rw.loc['19600101':,'(\'All scrap available\', \'No.1\')':'(\'All scrap available\', \'Mainboard-Alloy\')']
all_scrap_available_other_baseline_gl.columns = [i.split('\'')[3] for i in all_scrap_available_other_baseline_gl.columns]
all_scrap_available_other_baseline_cn.columns = all_scrap_available_other_baseline_gl.columns
all_scrap_available_other_baseline_rw.columns = all_scrap_available_other_baseline_gl.columns
all_scrap_available_no_accumulation_other_baseline_gl = sd_other_baseline_gl.loc['19600101':,'(\'All scrap available no accumulation\', \'No.1\')':'(\'All scrap available no accumulation\', \'Mainboard-Alloy\')']
all_scrap_available_no_accumulation_other_baseline_cn = sd_other_baseline_cn.loc['19600101':,'(\'All scrap available no accumulation\', \'No.1\')':'(\'All scrap available no accumulation\', \'Mainboard-Alloy\')']
all_scrap_available_no_accumulation_other_baseline_rw = sd_other_baseline_rw.loc['19600101':,'(\'All scrap available no accumulation\', \'No.1\')':'(\'All scrap available no accumulation\', \'Mainboard-Alloy\')']
all_scrap_available_no_accumulation_other_baseline_gl.columns = all_scrap_available_other_baseline_gl.columns
all_scrap_available_no_accumulation_other_baseline_cn.columns = all_scrap_available_other_baseline_gl.columns
all_scrap_available_no_accumulation_other_baseline_rw.columns = all_scrap_available_other_baseline_gl.columns
direct_melt_demand_other_baseline_gl = sd_other_baseline_gl.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
direct_melt_demand_other_baseline_cn = sd_other_baseline_cn.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
direct_melt_demand_other_baseline_rw = sd_other_baseline_rw.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
direct_melt_demand_other_baseline_gl.columns = [i.split('\'')[3] for i in direct_melt_demand_other_baseline_gl.columns]
direct_melt_demand_other_baseline_cn.columns = direct_melt_demand_other_baseline_gl.columns
direct_melt_demand_other_baseline_rw.columns = direct_melt_demand_other_baseline_gl.columns

file_name = 'new linshock1yr10'
sd_new_lin1yr10 = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx',sheet_name = 'Original')
sd_new_lin1yr10_gl = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', sheet_name='Global')
sd_new_lin1yr10_cn = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', sheet_name='China')
sd_new_lin1yr10_rw = pd.read_excel('John/05 China/S&D '+file_name+'.xlsx', sheet_name='RoW')
scrap_supply_new_lin1yr10 = sd_new_lin1yr10.loc['19600101':, 'Scrap production']
mining_supply_new_lin1yr10 = sd_new_lin1yr10.loc['19600101':,['Concentrate production', 'SX-EW production']].sum(axis=1)
price_new_lin1yr10=pd.read_excel('John/05 China/price '+file_name+'.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_new_lin1yr10=price_new_lin1yr10.loc[:, 'Cathode']
sp2_series_new_lin1yr10_gl=price_new_lin1yr10.loc[:, 'No.2 spread']
sp2_series_new_lin1yr10_cn=price_new_lin1yr10.loc[:, 'No.2 spread CN']
sp2_series_new_lin1yr10_rw=price_new_lin1yr10.loc[:, 'No.2 spread RoW']
spa_series_new_lin1yr10_gl=price_new_lin1yr10.loc[:, 'Yellow brass spread']
spa_series_new_lin1yr10_cn=price_new_lin1yr10.loc[:, 'Yellow brass spread CN']
spa_series_new_lin1yr10_rw=price_new_lin1yr10.loc[:, 'Yellow brass spread RoW']
tcrc_series_new_lin1yr10=price_new_lin1yr10.loc[:, 'TCRC']
ref_props_new_lin1yr10_gl = sd_new_lin1yr10_gl.loc[:,'Primary refining production':'Secondary ratio'].copy().copy()
ref_props_new_lin1yr10_cn = sd_new_lin1yr10_cn.loc[:,'Primary refining production':'Secondary ratio'].copy().copy()
ref_props_new_lin1yr10_rw = sd_new_lin1yr10_rw.loc[:,'Primary refining production':'Secondary ratio'].copy().copy()
all_scrap_available_new_lin1yr10_gl = sd_new_lin1yr10_gl.loc['19600101':,'(\'All scrap available\', \'No.1\')':'(\'All scrap available\', \'Mainboard-Alloy\')']
all_scrap_available_new_lin1yr10_cn = sd_new_lin1yr10_cn.loc['19600101':,'(\'All scrap available\', \'No.1\')':'(\'All scrap available\', \'Mainboard-Alloy\')']
all_scrap_available_new_lin1yr10_rw = sd_new_lin1yr10_rw.loc['19600101':,'(\'All scrap available\', \'No.1\')':'(\'All scrap available\', \'Mainboard-Alloy\')']
all_scrap_available_new_lin1yr10_gl.columns = [i.split('\'')[3] for i in all_scrap_available_new_lin1yr10_gl.columns]
all_scrap_available_new_lin1yr10_cn.columns = all_scrap_available_new_lin1yr10_gl.columns
all_scrap_available_new_lin1yr10_rw.columns = all_scrap_available_new_lin1yr10_gl.columns
all_scrap_available_no_accumulation_new_lin1yr10_gl = sd_new_lin1yr10_gl.loc['19600101':,'(\'All scrap available no accumulation\', \'No.1\')':'(\'All scrap available no accumulation\', \'Mainboard-Alloy\')']
all_scrap_available_no_accumulation_new_lin1yr10_cn = sd_new_lin1yr10_cn.loc['19600101':,'(\'All scrap available no accumulation\', \'No.1\')':'(\'All scrap available no accumulation\', \'Mainboard-Alloy\')']
all_scrap_available_no_accumulation_new_lin1yr10_rw = sd_new_lin1yr10_rw.loc['19600101':,'(\'All scrap available no accumulation\', \'No.1\')':'(\'All scrap available no accumulation\', \'Mainboard-Alloy\')']
all_scrap_available_no_accumulation_new_lin1yr10_gl.columns = all_scrap_available_new_lin1yr10_gl.columns
all_scrap_available_no_accumulation_new_lin1yr10_cn.columns = all_scrap_available_new_lin1yr10_gl.columns
all_scrap_available_no_accumulation_new_lin1yr10_rw.columns = all_scrap_available_new_lin1yr10_gl.columns
direct_melt_demand_new_lin1yr10_gl = sd_new_lin1yr10_gl.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
direct_melt_demand_new_lin1yr10_cn = sd_new_lin1yr10_cn.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
direct_melt_demand_new_lin1yr10_rw = sd_new_lin1yr10_rw.loc['19600101':,'(\'Direct melt demand\', \'Ref_Cu\')':'(\'Direct melt demand\', \'Mainboard-Alloy\')']
direct_melt_demand_new_lin1yr10_gl.columns = [i.split('\'')[3] for i in direct_melt_demand_new_lin1yr10_gl.columns]
direct_melt_demand_new_lin1yr10_cn.columns = direct_melt_demand_new_lin1yr10_gl.columns
direct_melt_demand_new_lin1yr10_rw.columns = direct_melt_demand_new_lin1yr10_gl.columns

displacement_new_lin1yr10 = displacement_estimate(sd_new_lin1yr10,scrap_baseline=scrap_supply_other_baseline,mining_baseline=mining_supply_other_baseline).loc[:,'Displacement']
mining_response_new_lin1yr10 = displacement_estimate(sd_new_lin1yr10,scrap_baseline=scrap_supply_other_baseline,mining_baseline=mining_supply_other_baseline).loc[:,'Mining response']
shock_new_lin1yr10 = displacement_estimate(sd_new_lin1yr10,scrap_baseline=scrap_supply_other_baseline,mining_baseline=mining_supply_other_baseline).loc[:,'Shock']
mining_pctinc_new_lin1yr10 = displacement_estimate(sd_new_lin1yr10,scrap_baseline=scrap_supply_other_baseline,mining_baseline=mining_supply_other_baseline).loc[:,'Mining %Increase']*100
mining_pctinc2020_new_lin1yr10 = displacement_estimate(sd_new_lin1yr10,scrap_baseline=scrap_supply_other_baseline,mining_baseline=mining_supply_other_baseline).loc[:,'Mining %Increase 2020']*100
scrap_pctinc_new_lin1yr10 = displacement_estimate(sd_new_lin1yr10,scrap_baseline=scrap_supply_other_baseline,mining_baseline=mining_supply_other_baseline).loc[:,'Scrap %Increase']*100
scrap_pctinc2020_new_lin1yr10 = displacement_estimate(sd_new_lin1yr10,scrap_baseline=scrap_supply_other_baseline,mining_baseline=mining_supply_other_baseline).loc[:,'Scrap %Increase 2020']*100
scrap_noacc_response_new_lin1yr10_gl = all_scrap_available_no_accumulation_new_lin1yr10_gl.loc['20180101':].sum(axis=1).cumsum()-all_scrap_available_no_accumulation_other_baseline_gl.loc['20180101':].sum(axis=1).cumsum()
scrap_noacc_response_new_lin1yr10_cn = all_scrap_available_no_accumulation_new_lin1yr10_cn.loc['20180101':].sum(axis=1).cumsum()-all_scrap_available_no_accumulation_other_baseline_cn.loc['20180101':].sum(axis=1).cumsum()
scrap_noacc_response_new_lin1yr10_rw = all_scrap_available_no_accumulation_new_lin1yr10_rw.loc['20180101':].sum(axis=1).cumsum()-all_scrap_available_no_accumulation_other_baseline_rw.loc['20180101':].sum(axis=1).cumsum()
scrap_noacc_pctinc_new_lin1yr10_gl = scrap_noacc_response_new_lin1yr10_gl/all_scrap_available_no_accumulation_other_baseline_gl.loc['20180101':].sum(axis=1).cumsum()*100
scrap_noacc_pctinc_new_lin1yr10_cn = scrap_noacc_response_new_lin1yr10_cn/all_scrap_available_no_accumulation_other_baseline_cn.loc['20180101':].sum(axis=1).cumsum()*100
scrap_noacc_pctinc_new_lin1yr10_rw = scrap_noacc_response_new_lin1yr10_rw/all_scrap_available_no_accumulation_other_baseline_rw.loc['20180101':].sum(axis=1).cumsum()*100
scrap_noacc_pctinc2020_new_lin1yr10_gl = scrap_noacc_response_new_lin1yr10_gl/all_scrap_available_no_accumulation_other_baseline_gl.loc['20200101'].sum()*100
scrap_noacc_pctinc2020_new_lin1yr10_cn = scrap_noacc_response_new_lin1yr10_cn/all_scrap_available_no_accumulation_other_baseline_cn.loc['20200101'].sum()*100
scrap_noacc_pctinc2020_new_lin1yr10_rw = scrap_noacc_response_new_lin1yr10_rw/all_scrap_available_no_accumulation_other_baseline_rw.loc['20200101'].sum()*100
noacc_displacement_new_lin1yr10 = -mining_response_new_lin1yr10.cumsum() / scrap_noacc_response_new_lin1yr10_gl
scrap_demand_response_new_lin1yr10_gl = direct_melt_demand_new_lin1yr10_gl.loc['20180101':,'Yellow_Brass':].sum(axis=1).cumsum()-direct_melt_demand_other_baseline_gl.loc['20180101':,'Yellow_Brass':].sum(axis=1).cumsum()
scrap_demand_response_new_lin1yr10_cn = direct_melt_demand_new_lin1yr10_cn.loc['20180101':,'Yellow_Brass':].sum(axis=1).cumsum()-direct_melt_demand_other_baseline_cn.loc['20180101':,'Yellow_Brass':].sum(axis=1).cumsum()
scrap_demand_response_new_lin1yr10_rw = direct_melt_demand_new_lin1yr10_rw.loc['20180101':,'Yellow_Brass':].sum(axis=1).cumsum()-direct_melt_demand_other_baseline_rw.loc['20180101':,'Yellow_Brass':].sum(axis=1).cumsum()
scrap_demand_pctinc_new_lin1yr10_gl = scrap_demand_response_new_lin1yr10_gl/direct_melt_demand_other_baseline_gl.loc['20180101':,'Yellow_Brass':].sum(axis=1).cumsum()*100
scrap_demand_pctinc_new_lin1yr10_cn = scrap_demand_response_new_lin1yr10_cn/direct_melt_demand_other_baseline_cn.loc['20180101':,'Yellow_Brass':].sum(axis=1).cumsum()*100
scrap_demand_pctinc_new_lin1yr10_rw = scrap_demand_response_new_lin1yr10_rw/direct_melt_demand_other_baseline_rw.loc['20180101':,'Yellow_Brass':].sum(axis=1).cumsum()*100
scrap_demand_pctinc2020_new_lin1yr10_gl = scrap_demand_response_new_lin1yr10_gl/direct_melt_demand_other_baseline_gl.loc['20200101','Yellow_Brass':].sum()*100
scrap_demand_pctinc2020_new_lin1yr10_cn = scrap_demand_response_new_lin1yr10_cn/direct_melt_demand_other_baseline_cn.loc['20200101','Yellow_Brass':].sum()*100
scrap_demand_pctinc2020_new_lin1yr10_rw = scrap_demand_response_new_lin1yr10_rw/direct_melt_demand_other_baseline_rw.loc['20200101','Yellow_Brass':].sum()*100
demand_displacement_new_lin1yr10 = mining_response_new_lin1yr10.cumsum() / scrap_demand_response_new_lin1yr10_gl * -1
print(str(datetime.now()))

# %%
plt.plot(displacement_lin1yr10, label='Old')
plt.plot(displacement_new_lin1yr10, label='New',color=colors[2])
plt.legend()

# %% [markdown]
# ## Displacement

# %%
all_scrap_available_fruity1rr11_gl

# %%
print('Mining decrease:')
print(-mining_response_fruity1rr11.cumsum().loc['20220101'])
print(-mining_response_fruity1rr50.cumsum().loc['20220101'])
print(-mining_response_fruity1rr90.cumsum().loc['20220101'])
print(-mining_response_fruity1rr100.cumsum().loc['20220101'])
print(-mining_response_fruity_pct1rr11.cumsum().loc['20220101'])
print(-mining_response_fruity_pct1rr50.cumsum().loc['20220101'])
print(-mining_response_fruity_pct1rr90.cumsum().loc['20220101'])
print(-mining_response_fruity_pct1rr100.cumsum().loc['20220101'])
print(-mining_response_fruity_pct5rr11.cumsum().loc['20220101'])
print(-mining_response_fruity_pct5rr50.cumsum().loc['20220101'])
print(-mining_response_fruity_pct5rr90.cumsum().loc['20220101'])
print(-mining_response_fruity_pct5rr100.cumsum().loc['20220101'])
print(-mining_response_fruity_pct10rr11.cumsum().loc['20220101'])
print(-mining_response_fruity_pct10rr50.cumsum().loc['20220101'])
print(-mining_response_fruity_pct10rr70.cumsum().loc['20220101'])
print(-mining_response_fruity_pct10rr90.cumsum().loc['20220101'])
print(' ')

print('Scrap supply increase:')
print(all_scrap_available_fruity1rr11_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity1rr50_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity1rr90_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity1rr100_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct1rr11_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct1rr50_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct1rr90_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct1rr100_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct5rr11_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct5rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct5rr50_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct5rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct5rr90_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct5rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct5rr100_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct5rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct10rr11_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct10rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct10rr50_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct10rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct10rr70_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct10rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(all_scrap_available_fruity_pct10rr90_gl.sum(axis=1).cumsum().loc['20220101'] - all_scrap_available_fruity_pct10rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(' ')

print('Scrap demand increase:')
print(direct_melt_demand_fruity1rr11_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity1rr50_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity1rr90_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity1rr100_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr11_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr50_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr90_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr100_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr11_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr50_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr90_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr100_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr11_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr50_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr70_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr90_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20220101'])
print(' ')

print('Refined production increase:')
print(ref_props_fruity1rr11_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity1rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity1rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity1rr100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct1rr11_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct1rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct1rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct1rr100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct5rr11_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct5rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct5rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct5rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct5rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct5rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct5rr100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct5rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct10rr11_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct10rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct10rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct10rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct10rr70_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct10rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(ref_props_fruity_pct10rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'] - ref_props_fruity_pct10rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20220101'])
print(' ')

print('Refined demand increase:')
print(ref_props_fruity1rr11_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity1rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity1rr50_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity1rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity1rr90_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity1rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity1rr100_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity1rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct1rr11_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct1rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct1rr50_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct1rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct1rr90_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct1rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct1rr100_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct1rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct5rr11_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct5rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct5rr50_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct5rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct5rr90_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct5rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct5rr100_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct5rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct10rr11_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct10rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct10rr50_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct10rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct10rr70_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct10rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(ref_props_fruity_pct10rr90_gl.loc[:,'Refined demand'].cumsum().loc['20220101'] - ref_props_fruity_pct10rr0_gl.loc[:,'Refined demand'].cumsum().loc['20220101'])
print(' ')

print('Semis production increase:')
print(direct_melt_demand_fruity1rr11_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity1rr50_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity1rr90_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity1rr100_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr11_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr50_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr90_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr100_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr11_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr50_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr90_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr100_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr11_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr50_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr70_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr90_gl.sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.sum(axis=1).cumsum().loc['20220101'])
print(' ')

print('Other refined metals increase:')
print(direct_melt_demand_fruity1rr11_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity1rr50_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity1rr90_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity1rr100_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity1rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr11_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr50_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr90_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct1rr100_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct1rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr11_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr50_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr90_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct5rr100_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct5rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr11_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr50_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr70_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])
print(direct_melt_demand_fruity_pct10rr90_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'] - direct_melt_demand_fruity_pct10rr0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20220101'])

# %%
print('Mining decrease:')
print(-mining_response_fruity1rr100var0.cumsum().loc['20240101'])
print(-mining_response_fruity1rr100var30.cumsum().loc['20240101'])
print(-mining_response_fruity1rr100var70.cumsum().loc['20240101'])
print(-mining_response_fruity1rr100var90.cumsum().loc['20240101'])
print(-mining_response_fruity_pct10rr50var10.cumsum().loc['20240101'])
print(-mining_response_fruity_pct10rr50var20.cumsum().loc['20240101'])
print(-mining_response_fruity_pct10rr50var30.cumsum().loc['20240101'])
print(-mining_response_fruity_pct10rr50var40.cumsum().loc['20240101'])
print(-mining_response_fruity_pct10rr50var50.cumsum().loc['20240101'])
print(-mining_response_fruity_pct10rr50var60.cumsum().loc['20240101'])
print(-mining_response_fruity_pct10rr50var70.cumsum().loc['20240101'])
print(' ')

print('Scrap supply increase:')
print(all_scrap_available_fruity1rr100var0_gl.sum(axis=1).cumsum().loc['20240101'] - all_scrap_available_fruity1rr0var0_gl.sum(axis=1).cumsum().loc['20240101'])
print(all_scrap_available_fruity1rr100var30_gl.sum(axis=1).cumsum().loc['20240101'] - all_scrap_available_fruity1rr0var0_gl.sum(axis=1).cumsum().loc['20240101'])
print(all_scrap_available_fruity1rr100var70_gl.sum(axis=1).cumsum().loc['20240101'] - all_scrap_available_fruity1rr0var0_gl.sum(axis=1).cumsum().loc['20240101'])
print(all_scrap_available_fruity1rr100var90_gl.sum(axis=1).cumsum().loc['20240101'] - all_scrap_available_fruity1rr0var0_gl.sum(axis=1).cumsum().loc['20240101'])
print(all_scrap_available_fruity_pct10rr50var10_gl.sum(axis=1).cumsum().loc['20240101'] - all_scrap_available_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(all_scrap_available_fruity_pct10rr50var30_gl.sum(axis=1).cumsum().loc['20240101'] - all_scrap_available_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(all_scrap_available_fruity_pct10rr50var50_gl.sum(axis=1).cumsum().loc['20240101'] - all_scrap_available_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(all_scrap_available_fruity_pct10rr50var70_gl.sum(axis=1).cumsum().loc['20240101'] - all_scrap_available_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(' ')

print('Scrap demand increase:')
print(direct_melt_demand_fruity1rr100var0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity1rr100var30_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity1rr100var70_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity1rr100var90_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var10_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var30_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var50_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var70_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.loc[:,'Yellow_Brass':].sum(axis=1).cumsum().loc['20240101'])
print(' ')

print('Refined production increase:')
print(ref_props_fruity1rr100var0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'] - ref_props_fruity1rr0var0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'])
print(ref_props_fruity1rr100var30_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'] - ref_props_fruity1rr0var0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'])
print(ref_props_fruity1rr100var70_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'] - ref_props_fruity1rr0var0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'])
print(ref_props_fruity1rr100var90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'] - ref_props_fruity1rr0var0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'])
print(ref_props_fruity_pct10rr50var10_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'] - ref_props_fruity_pct10rr0_1_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'])
print(ref_props_fruity_pct10rr50var30_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'] - ref_props_fruity_pct10rr0_1_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'])
print(ref_props_fruity_pct10rr50var50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'] - ref_props_fruity_pct10rr0_1_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'])
print(ref_props_fruity_pct10rr50var70_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'] - ref_props_fruity_pct10rr0_1_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1).cumsum().loc['20240101'])
print(' ')

print('Refined demand increase:')
print(ref_props_fruity1rr100var0_gl.loc[:,'Refined demand'].cumsum().loc['20240101'] - ref_props_fruity1rr0var0_gl.loc[:,'Refined demand'].cumsum().loc['20240101'])
print(ref_props_fruity1rr100var30_gl.loc[:,'Refined demand'].cumsum().loc['20240101'] - ref_props_fruity1rr0var0_gl.loc[:,'Refined demand'].cumsum().loc['20240101'])
print(ref_props_fruity1rr100var70_gl.loc[:,'Refined demand'].cumsum().loc['20240101'] - ref_props_fruity1rr0var0_gl.loc[:,'Refined demand'].cumsum().loc['20240101'])
print(ref_props_fruity1rr100var90_gl.loc[:,'Refined demand'].cumsum().loc['20240101'] - ref_props_fruity1rr0var0_gl.loc[:,'Refined demand'].cumsum().loc['20240101'])
print(ref_props_fruity_pct10rr50var10_gl.loc[:,'Refined demand'].cumsum().loc['20240101'] - ref_props_fruity_pct10rr0_1_gl.loc[:,'Refined demand'].cumsum().loc['20240101'])
print(ref_props_fruity_pct10rr50var30_gl.loc[:,'Refined demand'].cumsum().loc['20240101'] - ref_props_fruity_pct10rr0_1_gl.loc[:,'Refined demand'].cumsum().loc['20240101'])
print(ref_props_fruity_pct10rr50var50_gl.loc[:,'Refined demand'].cumsum().loc['20240101'] - ref_props_fruity_pct10rr0_1_gl.loc[:,'Refined demand'].cumsum().loc['20240101'])
print(ref_props_fruity_pct10rr50var70_gl.loc[:,'Refined demand'].cumsum().loc['20240101'] - ref_props_fruity_pct10rr0_1_gl.loc[:,'Refined demand'].cumsum().loc['20240101'])
print(' ')

print('Semis production increase:')
print(direct_melt_demand_fruity1rr100var0_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity1rr100var30_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity1rr100var70_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity1rr100var90_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var10_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var20_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var30_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var40_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var50_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var60_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var70_gl.sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1).cumsum().loc['20240101'])
print(' ')

print('Other refined metals increase:')
print(direct_melt_demand_fruity1rr100var0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity1rr100var30_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity1rr100var70_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity1rr100var90_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity1rr0var0_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var10_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var30_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var50_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'])
print(direct_melt_demand_fruity_pct10rr50var70_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'] - direct_melt_demand_fruity_pct10rr0_1_gl.loc[:,'Ref_Zn':'Ref_Fe'].sum(axis=1).cumsum().loc['20240101'])

# %% [markdown]
# Round 1 - Initial-2X
# 1. 1, 5, 10, and 20 year shocks where the total amount of scrap shock is the same, but spread out over varying number of years - constant shock, varying duration - initial

# %%
displacement_unalloyed_availupdate=displacement_estimate(sd_unalloyed_availupdate).loc[:,'Displacement']
mining_response_unalloyed_availupdate=displacement_estimate(sd_unalloyed_availupdate).loc[:,'Mining response']
shock_unalloyed_availupdate=displacement_estimate(sd_unalloyed_availupdate).loc[:, 'Shock']

# %%
displacement_unalloyed_availupdate_Pb=displacement_estimate(sd_unalloyed_availupdate_Pb).loc[:,'Displacement']
mining_response_unalloyed_availupdate_Pb=displacement_estimate(sd_unalloyed_availupdate_Pb).loc[:,'Mining response']
shock_unalloyed_availupdate_Pb=displacement_estimate(sd_unalloyed_availupdate_Pb).loc[:, 'Shock']

# %%
displacement_unalloyed_availupdate_Ref_Cu=displacement_estimate(sd_unalloyed_availupdate_Ref_Cu).loc[:,'Displacement']
mining_response_unalloyed_availupdate_Ref_Cu=displacement_estimate(sd_unalloyed_availupdate_Ref_Cu).loc[:,'Mining response']
shock_unalloyed_availupdate_Ref_Cu=displacement_estimate(sd_unalloyed_availupdate_Ref_Cu).loc[:, 'Shock']

# %% [markdown]
# ## Environmental Impacts

# %% [markdown]
# ### Import ban

# %%
file_name = 'blend CN baseline 20200414_1'
mine_life_stats_pir_baseline = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_pir_baseline, unit_impacts_pir_baseline, quantities_pir_baseline = calculate_impacts(
    sd_pir_baseline_cn, sd_pir_baseline_rw, sd_pir_baseline, mine_life_stats_pir_baseline,
    direct_melt_demand_pir_baseline_cn, direct_melt_demand_pir_baseline_rw)
print('Done')

# %%
file_name = 'blend CN baseline 20200414_1'
mine_life_stats_pir_baseline = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_pir_baseline, unit_impacts_pir_baseline, quantities_pir_baseline = calculate_impacts(
    sd_pir_baseline_cn, sd_pir_baseline_rw, sd_pir_baseline, mine_life_stats_pir_baseline,
    direct_melt_demand_pir_baseline_cn, direct_melt_demand_pir_baseline_rw)

file_name = 'blend CN alloyed 50yoy 20200414_1'
mine_life_stats_alloyed_50yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_50yoy, unit_impacts_alloyed_50yoy, quantities_alloyed_50yoy = calculate_impacts(
    sd_alloyed_50yoy_cn, sd_alloyed_50yoy_rw, sd_alloyed_50yoy, mine_life_stats_alloyed_50yoy,
    direct_melt_demand_alloyed_50yoy_cn, direct_melt_demand_alloyed_50yoy_rw)
impact_change_alloyed_50yoy = total_impacts_alloyed_50yoy - total_impacts_pir_baseline
quantity_change_alloyed_50yoy = quantities_alloyed_50yoy - quantities_pir_baseline

file_name = 'blend CN No.2 50yoy 20200414_1'
mine_life_stats_no2_50yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_50yoy, unit_impacts_no2_50yoy, quantities_no2_50yoy = calculate_impacts(
    sd_no2_50yoy_cn, sd_no2_50yoy_rw, sd_no2_50yoy, mine_life_stats_no2_50yoy,
    direct_melt_demand_no2_50yoy_cn, direct_melt_demand_no2_50yoy_rw)
impact_change_no2_50yoy = total_impacts_no2_50yoy - total_impacts_pir_baseline
quantity_change_no2_50yoy = quantities_no2_50yoy - quantities_pir_baseline

file_name = 'blend CN both 50yoy 20200414_1'
mine_life_stats_both_50yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_50yoy, unit_impacts_both_50yoy, quantities_both_50yoy = calculate_impacts(
    sd_both_50yoy_cn, sd_both_50yoy_rw, sd_both_50yoy, mine_life_stats_both_50yoy,
    direct_melt_demand_both_50yoy_cn, direct_melt_demand_both_50yoy_rw)
impact_change_both_50yoy = total_impacts_both_50yoy - total_impacts_pir_baseline
quantity_change_both_50yoy = quantities_both_50yoy - quantities_pir_baseline

file_name = 'blend CN both 50yoy inc 20200414'
mine_life_stats_both_50yoy_inc100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_50yoy_inc100, unit_impacts_both_50yoy_inc100, quantities_both_50yoy_inc100 = calculate_impacts(
    sd_both_50yoy_inc100_cn, sd_both_50yoy_inc100_rw, sd_both_50yoy_inc100, mine_life_stats_both_50yoy_inc100,
    direct_melt_demand_both_50yoy_inc100_cn, direct_melt_demand_both_50yoy_inc100_rw)
impact_change_both_50yoy_inc100 = total_impacts_both_50yoy_inc100 - total_impacts_pir_baseline
quantity_change_both_50yoy_inc100 = quantities_both_50yoy_inc100 - quantities_pir_baseline

file_name = 'blend CN both 50yoy 200 inc 20200414'
mine_life_stats_both_50yoy_inc200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_50yoy_inc200, unit_impacts_both_50yoy_inc200, quantities_both_50yoy_inc200 = calculate_impacts(
    sd_both_50yoy_inc200_cn, sd_both_50yoy_inc200_rw, sd_both_50yoy_inc200, mine_life_stats_both_50yoy_inc200,
    direct_melt_demand_both_50yoy_inc200_cn, direct_melt_demand_both_50yoy_inc200_rw)
impact_change_both_50yoy_inc200 = total_impacts_both_50yoy_inc200 - total_impacts_pir_baseline
quantity_change_both_50yoy_inc200 = quantities_both_50yoy_inc200 - quantities_pir_baseline

file_name = 'blend CN both 50yoy dec 20200414'
mine_life_stats_both_50yoy_dec100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_50yoy_dec100, unit_impacts_both_50yoy_dec100, quantities_both_50yoy_dec100 = calculate_impacts(
    sd_both_50yoy_dec100_cn, sd_both_50yoy_dec100_rw, sd_both_50yoy_dec100, mine_life_stats_both_50yoy_dec100,
    direct_melt_demand_both_50yoy_dec100_cn, direct_melt_demand_both_50yoy_dec100_rw)
impact_change_both_50yoy_dec100 = total_impacts_both_50yoy_dec100 - total_impacts_pir_baseline
quantity_change_both_50yoy_dec100 = quantities_both_50yoy_dec100 - quantities_pir_baseline

file_name = 'blend CN both 50yoy 200 dec 20200414'
mine_life_stats_both_50yoy_dec200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_50yoy_dec200, unit_impacts_both_50yoy_dec200, quantities_both_50yoy_dec200 = calculate_impacts(
    sd_both_50yoy_dec200_cn, sd_both_50yoy_dec200_rw, sd_both_50yoy_dec200, mine_life_stats_both_50yoy_dec200,
    direct_melt_demand_both_50yoy_dec200_cn, direct_melt_demand_both_50yoy_dec200_rw)
impact_change_both_50yoy_dec200 = total_impacts_both_50yoy_dec200 - total_impacts_pir_baseline
quantity_change_both_50yoy_dec200 = quantities_both_50yoy_dec200 - quantities_pir_baseline

file_name = 'blend CN No.2 50yoy inc 20200414'
mine_life_stats_no2_50yoy_inc100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_50yoy_inc100, unit_impacts_no2_50yoy_inc100, quantities_no2_50yoy_inc100 = calculate_impacts(
    sd_no2_50yoy_inc100_cn, sd_no2_50yoy_inc100_rw, sd_no2_50yoy_inc100, mine_life_stats_no2_50yoy_inc100,
    direct_melt_demand_no2_50yoy_inc100_cn, direct_melt_demand_no2_50yoy_inc100_rw)
impact_change_no2_50yoy_inc100 = total_impacts_no2_50yoy_inc100 - total_impacts_pir_baseline
quantity_change_no2_50yoy_inc100 = quantities_no2_50yoy_inc100 - quantities_pir_baseline

file_name = 'blend CN No.2 50yoy 200 inc 20200414'
mine_life_stats_no2_50yoy_inc200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_50yoy_inc200, unit_impacts_no2_50yoy_inc200, quantities_no2_50yoy_inc200 = calculate_impacts(
    sd_no2_50yoy_inc200_cn, sd_no2_50yoy_inc200_rw, sd_no2_50yoy_inc200, mine_life_stats_no2_50yoy_inc200,
    direct_melt_demand_no2_50yoy_inc200_cn, direct_melt_demand_no2_50yoy_inc200_rw)
impact_change_no2_50yoy_inc200 = total_impacts_no2_50yoy_inc200 - total_impacts_pir_baseline
quantity_change_no2_50yoy_inc200 = quantities_no2_50yoy_inc200 - quantities_pir_baseline

file_name = 'blend CN No.2 50yoy dec 20200414'
mine_life_stats_no2_50yoy_dec100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_50yoy_dec100, unit_impacts_no2_50yoy_dec100, quantities_no2_50yoy_dec100 = calculate_impacts(
    sd_no2_50yoy_dec100_cn, sd_no2_50yoy_dec100_rw, sd_no2_50yoy_dec100, mine_life_stats_no2_50yoy_dec100,
    direct_melt_demand_no2_50yoy_dec100_cn, direct_melt_demand_no2_50yoy_dec100_rw)
impact_change_no2_50yoy_dec100 = total_impacts_no2_50yoy_dec100 - total_impacts_pir_baseline
quantity_change_no2_50yoy_dec100 = quantities_no2_50yoy_dec100 - quantities_pir_baseline

file_name = 'blend CN No.2 50yoy 200 dec 20200414'
mine_life_stats_no2_50yoy_dec200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_50yoy_dec200, unit_impacts_no2_50yoy_dec200, quantities_no2_50yoy_dec200 = calculate_impacts(
    sd_no2_50yoy_dec200_cn, sd_no2_50yoy_dec200_rw, sd_no2_50yoy_dec200, mine_life_stats_no2_50yoy_dec200,
    direct_melt_demand_no2_50yoy_dec200_cn, direct_melt_demand_no2_50yoy_dec200_rw)
impact_change_no2_50yoy_dec200 = total_impacts_no2_50yoy_dec200 - total_impacts_pir_baseline
quantity_change_no2_50yoy_dec200 = quantities_no2_50yoy_dec200 - quantities_pir_baseline

categories = ['Direct Melt Scrap', 'Direct Melt Other', 'Fabrication', 'New SX-EW Mines',
                 'New Traditional Mines', 'Operating SX-EW Mines', 'Operating Traditional Mines', 
                 'Primary Refinery', 'Secondary Refinery', 'Refined Metals']
print('All Done')

# %%
file_name = 'blend CN alloyed 50yoy inc 20200414'
mine_life_stats_alloyed_50yoy_inc100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_50yoy_inc100, unit_impacts_alloyed_50yoy_inc100, quantities_alloyed_50yoy_inc100 = calculate_impacts(
    sd_alloyed_50yoy_inc100_cn, sd_alloyed_50yoy_inc100_rw, sd_alloyed_50yoy_inc100, mine_life_stats_alloyed_50yoy_inc100,
    direct_melt_demand_alloyed_50yoy_inc100_cn, direct_melt_demand_alloyed_50yoy_inc100_rw)
impact_change_alloyed_50yoy_inc100 = total_impacts_alloyed_50yoy_inc100 - total_impacts_pir_baseline
quantity_change_alloyed_50yoy_inc100 = quantities_alloyed_50yoy_inc100 - quantities_pir_baseline

file_name = 'blend CN alloyed 50yoy 200 inc 20200414'
mine_life_stats_alloyed_50yoy_inc200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_50yoy_inc200, unit_impacts_alloyed_50yoy_inc200, quantities_alloyed_50yoy_inc200 = calculate_impacts(
    sd_alloyed_50yoy_inc200_cn, sd_alloyed_50yoy_inc200_rw, sd_alloyed_50yoy_inc200, mine_life_stats_alloyed_50yoy_inc200,
    direct_melt_demand_alloyed_50yoy_inc200_cn, direct_melt_demand_alloyed_50yoy_inc200_rw)
impact_change_alloyed_50yoy_inc200 = total_impacts_alloyed_50yoy_inc200 - total_impacts_pir_baseline
quantity_change_alloyed_50yoy_inc200 = quantities_alloyed_50yoy_inc200 - quantities_pir_baseline

file_name = 'blend CN alloyed 50yoy dec 20200414'
mine_life_stats_alloyed_50yoy_dec100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_50yoy_dec100, unit_impacts_alloyed_50yoy_dec100, quantities_alloyed_50yoy_dec100 = calculate_impacts(
    sd_alloyed_50yoy_dec100_cn, sd_alloyed_50yoy_dec100_rw, sd_alloyed_50yoy_dec100, mine_life_stats_alloyed_50yoy_dec100,
    direct_melt_demand_alloyed_50yoy_dec100_cn, direct_melt_demand_alloyed_50yoy_dec100_rw)
impact_change_alloyed_50yoy_dec100 = total_impacts_alloyed_50yoy_dec100 - total_impacts_pir_baseline
quantity_change_alloyed_50yoy_dec100 = quantities_alloyed_50yoy_dec100 - quantities_pir_baseline

file_name = 'blend CN alloyed 50yoy 200 dec 20200414'
mine_life_stats_alloyed_50yoy_dec200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_50yoy_dec200, unit_impacts_alloyed_50yoy_dec200, quantities_alloyed_50yoy_dec200 = calculate_impacts(
    sd_alloyed_50yoy_dec200_cn, sd_alloyed_50yoy_dec200_rw, sd_alloyed_50yoy_dec200, mine_life_stats_alloyed_50yoy_dec200,
    direct_melt_demand_alloyed_50yoy_dec200_cn, direct_melt_demand_alloyed_50yoy_dec200_rw)
impact_change_alloyed_50yoy_dec200 = total_impacts_alloyed_50yoy_dec200 - total_impacts_pir_baseline
quantity_change_alloyed_50yoy_dec200 = quantities_alloyed_50yoy_dec200 - quantities_pir_baseline
print('Dooo doo dooooooooo')

# %%
file_name = 'blend CN both 25yoy 20200414'
mine_life_stats_both_25yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_25yoy, unit_impacts_both_25yoy, quantities_both_25yoy = calculate_impacts(
    sd_both_25yoy_cn, sd_both_25yoy_rw, sd_both_25yoy, mine_life_stats_both_25yoy,
    direct_melt_demand_both_25yoy_cn, direct_melt_demand_both_25yoy_rw)
impact_change_both_25yoy = total_impacts_both_25yoy - total_impacts_pir_baseline
quantity_change_both_25yoy = quantities_both_25yoy - quantities_pir_baseline

file_name = 'blend CN both 75yoy 20200414'
mine_life_stats_both_75yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_75yoy, unit_impacts_both_75yoy, quantities_both_75yoy = calculate_impacts(
    sd_both_75yoy_cn, sd_both_75yoy_rw, sd_both_75yoy, mine_life_stats_both_75yoy,
    direct_melt_demand_both_75yoy_cn, direct_melt_demand_both_75yoy_rw)
impact_change_both_75yoy = total_impacts_both_75yoy - total_impacts_pir_baseline
quantity_change_both_75yoy = quantities_both_75yoy - quantities_pir_baseline

file_name = 'blend CN alloyed 25yoy 20200414'
mine_life_stats_alloyed_25yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_25yoy, unit_impacts_alloyed_25yoy, quantities_alloyed_25yoy = calculate_impacts(
    sd_alloyed_25yoy_cn, sd_alloyed_25yoy_rw, sd_alloyed_25yoy, mine_life_stats_alloyed_25yoy,
    direct_melt_demand_alloyed_25yoy_cn, direct_melt_demand_alloyed_25yoy_rw)
impact_change_alloyed_25yoy = total_impacts_alloyed_25yoy - total_impacts_pir_baseline
quantity_change_alloyed_25yoy = quantities_alloyed_25yoy - quantities_pir_baseline

file_name = 'blend CN alloyed 75yoy 20200414'
mine_life_stats_alloyed_75yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_75yoy, unit_impacts_alloyed_75yoy, quantities_alloyed_75yoy = calculate_impacts(
    sd_alloyed_75yoy_cn, sd_alloyed_75yoy_rw, sd_alloyed_75yoy, mine_life_stats_alloyed_75yoy,
    direct_melt_demand_alloyed_75yoy_cn, direct_melt_demand_alloyed_75yoy_rw)
impact_change_alloyed_75yoy = total_impacts_alloyed_75yoy - total_impacts_pir_baseline
quantity_change_alloyed_75yoy = quantities_alloyed_75yoy - quantities_pir_baseline

file_name = 'blend CN No.2 25yoy 20200414'
mine_life_stats_no2_25yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_25yoy, unit_impacts_no2_25yoy, quantities_no2_25yoy = calculate_impacts(
    sd_no2_25yoy_cn, sd_no2_25yoy_rw, sd_no2_25yoy, mine_life_stats_no2_25yoy,
    direct_melt_demand_no2_25yoy_cn, direct_melt_demand_no2_25yoy_rw)
impact_change_no2_25yoy = total_impacts_no2_25yoy - total_impacts_pir_baseline
quantity_change_no2_25yoy = quantities_no2_25yoy - quantities_pir_baseline

file_name = 'blend CN No.2 75yoy 20200414'
mine_life_stats_no2_75yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_75yoy, unit_impacts_no2_75yoy, quantities_no2_75yoy = calculate_impacts(
    sd_no2_75yoy_cn, sd_no2_75yoy_rw, sd_no2_75yoy, mine_life_stats_no2_75yoy,
    direct_melt_demand_no2_75yoy_cn, direct_melt_demand_no2_75yoy_rw)
impact_change_no2_75yoy = total_impacts_no2_75yoy - total_impacts_pir_baseline
quantity_change_no2_75yoy = quantities_no2_75yoy - quantities_pir_baseline
print('Done-zo')

# %% [markdown]
# Baseline annual impacts

# %%
c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
c2 = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd']
c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2']
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4)
ph_series = pd.DataFrame(0, index = total_impacts_pir_baseline.index.levels[0], columns = categories)
for metric in total_impacts_pir_baseline.index.levels[1]:
    ph_series.loc[:] = total_impacts_pir_baseline.groupby(axis=1,level=1).sum().loc[idx[:,metric],:].reset_index(level=1,drop=True)
    ph_series = ph_series.loc[:,categories]
    #     ph_series = ph_series.cumsum()
    init_plot(figwidth=16)
    plt.stackplot(ph_series.loc['19600101':,:].index, 0.001*ph_series[ph_series>0].fillna(0).loc['19600101':].transpose(), 
              labels=ph_series.columns)
    plt.legend()
    plt.stackplot(ph_series.loc['19600101':,:].index, 0.001*ph_series[ph_series<0].fillna(0).loc['19600101':].transpose(), 
              labels=ph_series.columns)
    plt.plot([pd.datetime(2018,1,1),pd.datetime(2018,1,1)], [0,0.001*ph_series.loc['20340101'].sum()],'k--')
    plt.title('Baseline Annual '+metric.split('(')[0].title()+'Impact')
#     plt.ylabel('Cumulative increase, % of 2020 value')
    plt.ylabel(metric.split('(')[0]+' ('+metric.replace('kt','Mt').replace('GJ','TJ')
               .replace('ML','billion liters').split('(')[1][:-1]+')')
    
    plt.show()

# (total_impacts_alloyed_50yoy - total_impacts_pir_baseline).groupby(axis=1,level=1).sum().groupby(axis=0,level=0).sum().loc['19600101':,'Global warming (kt CO2 eq)'].plot()

# %% [markdown]
# Change in impacts, regional for No.2 banned

# %%
c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
c2 = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd']
c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2']
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4)
ph_series1 = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_alloyed_50yoy.columns.levels[1])
ph_series2 = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_alloyed_50yoy.columns.levels[1])
ph_series3 = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_alloyed_50yoy.columns.levels[1])

for metric in impact_change_alloyed_50yoy.index.levels[1]:
    fig,[ax1,ax2,ax3] = plt.subplots(1,3, sharey=True)
#         ph_series1 = impact_change_alloyed_50yoy.groupby(axis=1,level=1).sum().loc[idx[:,metric],:].reset_index(level=1,drop=True)
#         ph_series2 = impact_change_no2_50yoy.groupby(axis=1,level=1).sum().loc[idx[:,metric],:].reset_index(level=1,drop=True)
#     ph_series3 = impact_change_both_50yoy.groupby(axis=1,level=1).sum().loc[idx[:,metric],:].reset_index(level=1,drop=True)
#         ph_series1 = impact_change_alloyed_50yoy.loc[idx[:,metric],idx['China', :]].reset_index(level=1,drop=True)
#         ph_series2 = impact_change_no2_50yoy.loc[idx[:,metric],idx['China', :]].reset_index(level=1,drop=True)
#     ph_series3 = impact_change_both_50yoy.loc[idx[:,metric],idx['China', :]].reset_index(level=1,drop=True).T.reset_index(level=0,drop=True).T
#         ph_series1 = impact_change_alloyed_50yoy.loc[idx[:,metric],idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().reset_index(level=1,drop=True)
#         ph_series2 = impact_change_no2_50yoy.loc[idx[:,metric],idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().reset_index(level=1,drop=True)
#     ph_series3 = impact_change_both_50yoy.loc[idx[:,metric],idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().reset_index(level=1,drop=True)
    ph_series1,ph_series2,ph_series3 = pct_inc(impact_change_no2_50yoy,metric)
    
    normalizer = total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()
    ph_series1 = ph_series1.cumsum().loc[:,categories]
    ph_series2 = ph_series2.cumsum().loc[:,categories]
    ph_series3 = ph_series3.cumsum().loc[:,categories]
    init_plot(figwidth=24,ax=ax1)
    init_plot(figwidth=24,ax=ax2)
    init_plot(figwidth=24,ax=ax3)
    ax1.stackplot(ph_series1.loc['20180101':,:].index, ph_series1[ph_series1>0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100, 
              labels=ph_series1.columns)
#     ax1.legend()
    ax1.stackplot(ph_series1.loc['20180101':,:].index, ph_series1[ph_series1<0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100, 
              labels=ph_series1.columns)
    ax1.plot(ph_series1.loc['20180101':].sum(axis=1)/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100,'k')
    
    ax2.stackplot(ph_series1.loc['20180101':,:].index, ph_series2[ph_series2>0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100, 
              labels=ph_series2.columns)
#     ax2.legend()
    ax2.stackplot(ph_series1.loc['20180101':,:].index, ph_series2[ph_series2<0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100, 
              labels=ph_series2.columns)
    ax2.plot(ph_series2.loc['20180101':].sum(axis=1)/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100,'k')
    
    
    ax3.stackplot(ph_series1.loc['20180101':,:].index, ph_series3[ph_series3>0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100, 
            labels=ph_series3.columns)
#     ax3.legend()
    ax3.stackplot(ph_series1.loc['20180101':,:].index, ph_series3[ph_series3<0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100, 
            labels=ph_series3.columns)
    ax3.plot(ph_series3.loc['20180101':].sum(axis=1)/total_impacts_pir_baseline.loc[idx['20200101',metric]].sum()*100,'k')
#     ax1.legend(loc='upper left')
    ax1.set_title('Global '+metric.split('(')[0].title()+'Change')
    ax2.set_title('China '+metric.split('(')[0].title()+'Change')
    ax3.set_title('Rest of World '+metric.split('(')[0].title()+'Change')
#     plt.xlabel('Year')
    ax1.set_ylabel('Cumulative increase, % of 2020 value')
    ax2.set_ylabel('Cumulative increase, % of 2020 value')
    ax3.set_ylabel('Cumulative increase, % of 2020 value')
#     plt.ylabel(metric.split('(')[1][:-1])
    plt.show()

# (total_impacts_alloyed_50yoy - total_impacts_pir_baseline).groupby(axis=1,level=1).sum().groupby(axis=0,level=0).sum().loc['20180101':,'Global warming (kt CO2 eq)'].plot()

# %% [markdown]
# Change in impacts, regional for both banned with refined import changes

# %%
c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
c2 = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd']
c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2']
colorn = ['#eff3ff','#bdd7e7','#6baed6','#3182bd','#08519c'][::-1]
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4)

ph_series_base = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
ph_series_inc100 = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc100.index.levels[1])
ph_series_inc200 = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
ph_series_dec100 = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])
ph_series_dec200 = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec200.index.levels[1])
ph_series_base_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
ph_series_inc100_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc100.index.levels[1])
ph_series_inc200_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
ph_series_dec100_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])
ph_series_dec200_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec200.index.levels[1])
ph_series_base_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
ph_series_inc100_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc100.index.levels[1])
ph_series_inc200_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
ph_series_dec100_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])
ph_series_dec200_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec200.index.levels[1])

for metric in [i for i in impact_change_alloyed_50yoy.index.levels[1] if 'Renewable' not in i]:
    ph_series_inc100,ph_series_inc100_cn,ph_series_inc100_rw = pct_inc(impact_change_no2_50yoy_inc100,metric)
    ph_series_inc200,ph_series_inc200_cn,ph_series_inc200_rw = pct_inc(impact_change_no2_50yoy_inc200,metric)
    ph_series_dec100,ph_series_dec100_cn,ph_series_dec100_rw = pct_inc(impact_change_no2_50yoy_dec100,metric)
    ph_series_dec200,ph_series_dec200_cn,ph_series_dec200_rw = pct_inc(impact_change_no2_50yoy_dec200,metric)
    ph_series_base,  ph_series_base_cn,  ph_series_base_rw   = pct_inc(impact_change_no2_50yoy,metric)
    
    init_plot(figwidth=60,ax=ax1)
    fig,[ax1,ax2,ax3,ax4,ax5] = plt.subplots(1,5, sharey=True)
    
    ax1.stackplot(ph_series_inc200.loc['20180101':,:].index, ph_series_inc200_cn[ph_series_inc200_cn>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_inc200.columns)
    ax1.stackplot(ph_series_inc200.loc['20180101':,:].index, ph_series_inc200_cn[ph_series_inc200_cn<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_inc200.columns)
    ax1.plot(ph_series_inc200.loc['20180101':].sum(axis=1),'k')
    
    ax2.stackplot(ph_series_inc100.loc['20180101':,:].index, ph_series_inc100_cn[ph_series_inc100_cn>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_inc100.columns)
    ax2.stackplot(ph_series_inc100.loc['20180101':,:].index, ph_series_inc100_cn[ph_series_inc100_cn<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_inc100.columns)
    ax2.plot(ph_series_inc100.loc['20180101':].sum(axis=1),'k')
    
    ax3.stackplot(ph_series_base.loc['20180101':,:].index, ph_series_base[ph_series_base>0].fillna(0).loc['20180101':].transpose(), 
            labels=ph_series_base.columns)
    ax3.stackplot(ph_series_base.loc['20180101':,:].index, ph_series_base[ph_series_base<0].fillna(0).loc['20180101':].transpose(), 
            labels=ph_series_base.columns)
    ax3.plot(ph_series_base.loc['20180101':].sum(axis=1),'k')
    
    ax4.stackplot(ph_series_dec100.loc['20180101':,:].index, ph_series_dec100_cn[ph_series_dec100_cn>0].fillna(0).loc['20180101':].transpose(), 
            labels=ph_series_inc100.columns)
    ax4.stackplot(ph_series_dec100.loc['20180101':,:].index, ph_series_dec100_cn[ph_series_dec100_cn<0].fillna(0).loc['20180101':].transpose(), 
            labels=ph_series_inc100.columns)
    ax4.plot(ph_series_dec100.loc['20180101':].sum(axis=1),'k')

    ax5.stackplot(ph_series_dec200.loc['20180101':,:].index, ph_series_dec200_cn[ph_series_dec200_cn>0].fillna(0).loc['20180101':].transpose(), 
            labels=ph_series_dec200.columns)
    ax5.stackplot(ph_series_dec200.loc['20180101':,:].index, ph_series_dec200_cn[ph_series_dec200_cn<0].fillna(0).loc['20180101':].transpose(), 
            labels=ph_series_dec200.columns)
    ax5.plot(ph_series_dec200.loc['20180101':].sum(axis=1),'k')

    #     ax1.legend(loc='upper left')
    ax1.set_title('Global '+metric.split('(')[0].title()+'Change\nIncreased Refined Imports 200 kt/year')
    ax2.set_title('Global '+metric.split('(')[0].title()+'Change\nIncreased Refined Imports 100 kt/year')
    ax3.set_title('Global '+metric.split('(')[0].title()+'Change\nConstant Refined Imports')
    ax4.set_title('Global '+metric.split('(')[0].title()+'Change\nDecreased Refined Imports 100 kt/year')
    ax5.set_title('Global '+metric.split('(')[0].title()+'Change\nDecreased Refined Imports 200 kt/year')
    
    #     plt.xlabel('Year')
    ax1.set_ylabel('Cumulative increase, % of 2020 value')
    ax2.set_ylabel('Cumulative increase, % of 2020 value')
    ax3.set_ylabel('Cumulative increase, % of 2020 value')
    ax4.set_ylabel('Cumulative increase, % of 2020 value')
    ax5.set_ylabel('Cumulative increase, % of 2020 value')
#     plt.ylabel(metric.split('(')[1][:-1])
    plt.show()
    
    init_plot(figwidth=24,ax=ax1)
    fig,[ax1,ax2,ax3] = plt.subplots(1,3, sharey=False)
    
    ax1.plot(ph_series_inc200.loc['20180101':].sum(axis=1), color=colorn[0], label='Inc 200')
#     ax1.plot(ph_series_inc100.loc['20180101':].sum(axis=1), color=colorn[1], label='Inc 100')
    ax1.plot(ph_series_base.loc['20180101':].sum(axis=1), color=colors[2], label='No Change')
#     ax1.plot(ph_series_dec100.loc['20180101':].sum(axis=1), color=colorn[3], label='Dec 100')
    ax1.plot(ph_series_dec200.loc['20180101':].sum(axis=1), color=colorn[4], label='Dec 200')
    ax1.fill_between(ph_series_inc100.loc['20180101':].index,
                    ph_series_inc100.loc['20180101':].sum(axis=1),
                    ph_series_dec100.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
    ax1.fill_between(ph_series_inc100.loc['20180101':].index,
                    ph_series_inc200.loc['20180101':].sum(axis=1),
                    ph_series_dec200.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
    ax1.legend()
    
#     ax2.plot(ph_series_inc200_cn.loc['20180101':].sum(axis=1), color=colorn[0], label='Inc 200')
#     ax2.plot(ph_series_inc100_cn.loc['20180101':].sum(axis=1), color=colorn[1], label='Inc 100')
    ax2.plot(ph_series_base_cn.loc['20180101':].sum(axis=1), color=colors[2], label='No Change')
#     ax2.plot(ph_series_dec100_cn.loc['20180101':].sum(axis=1), color=colorn[3], label='Dec 100')
#     ax2.plot(ph_series_dec200_cn.loc['20180101':].sum(axis=1), color=colorn[4], label='Dec 200')
    ax2.fill_between(ph_series_inc100.loc['20180101':].index,
                    ph_series_inc100_cn.loc['20180101':].sum(axis=1),
                    ph_series_dec100_cn.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
    ax2.fill_between(ph_series_inc100.loc['20180101':].index,
                    ph_series_inc200_cn.loc['20180101':].sum(axis=1),
                    ph_series_dec200_cn.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
    
#     ax3.plot(ph_series_inc200_rw.loc['20180101':].sum(axis=1), color=colorn[0], label='Inc 200')
#     ax3.plot(ph_series_inc100_rw.loc['20180101':].sum(axis=1), color=colorn[1], label='Inc 100')
    ax3.plot(ph_series_base_rw.loc['20180101':].sum(axis=1), color=colors[2], label='No Change')
#     ax3.plot(ph_series_dec100_rw.loc['20180101':].sum(axis=1), color=colorn[3], label='Dec 100')
#     ax3.plot(ph_series_dec200_rw.loc['20180101':].sum(axis=1), color=colorn[4], label='Dec 200')
    ax3.fill_between(ph_series_inc100.loc['20180101':].index,
                    ph_series_inc100_rw.loc['20180101':].sum(axis=1),
                    ph_series_dec100_rw.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
    ax3.fill_between(ph_series_inc100.loc['20180101':].index,
                    ph_series_inc200_rw.loc['20180101':].sum(axis=1),
                    ph_series_dec200_rw.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
    
    ax1.set_title('Global '+metric.split('(')[0].title()+'Change')
    ax2.set_title('China '+metric.split('(')[0].title()+'Change')
    ax3.set_title('Rest of World '+metric.split('(')[0].title()+'Change')
#     plt.xlabel('Year')
    ax1.set_ylabel('Cumulative increase, % of 2020 value')
    ax2.set_ylabel('Cumulative increase, % of 2020 value')
    ax3.set_ylabel('Cumulative increase, % of 2020 value')
    plt.show()
# (total_impacts_alloyed_50yoy - total_impacts_pir_baseline).groupby(axis=1,level=1).sum().groupby(axis=0,level=0).sum().loc['20180101':,'Global warming (kt CO2 eq)'].plot()

# %% [markdown]
# Ban Rate Sensitivity

# %%
c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
c2 = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd']
c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2']
colorn = ['#eff3ff','#bdd7e7','#6baed6','#3182bd','#08519c'][::-1]
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4)

ph_series_base = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
ph_series_alloyed_25yoy = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
ph_series_alloyed_75yoy = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])
ph_series_base_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
ph_series_alloyed_25yoy_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
ph_series_alloyed_75yoy_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])
ph_series_base_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
ph_series_alloyed_25yoy_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
ph_series_alloyed_75yoy_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])

for metric in ['Global warming (kt CO2 eq)']:#[i for i in impact_change_alloyed_50yoy.index.levels[1] if 'Renewable' not in i]:
    ph_series_alloyed_50yoy,ph_series_alloyed_50yoy_cn, ph_series_alloyed_50yoy_rw   = pct_inc(impact_change_alloyed_50yoy,metric)
    ph_series_alloyed_25yoy,ph_series_alloyed_25yoy_cn,ph_series_alloyed_25yoy_rw = pct_inc(impact_change_alloyed_25yoy,metric)
    ph_series_alloyed_75yoy,ph_series_alloyed_75yoy_cn,ph_series_alloyed_75yoy_rw = pct_inc(impact_change_alloyed_75yoy,metric)
    ph_series_no2_50yoy,    ph_series_no2_50yoy_cn,    ph_series_no2_50yoy_rw   = pct_inc(impact_change_no2_50yoy,metric)
    ph_series_no2_25yoy,    ph_series_no2_25yoy_cn,    ph_series_no2_25yoy_rw = pct_inc(impact_change_no2_25yoy,metric)
    ph_series_no2_75yoy,    ph_series_no2_75yoy_cn,    ph_series_no2_75yoy_rw = pct_inc(impact_change_no2_75yoy,metric)
    ph_series_both_50yoy,ph_series_both_50yoy_cn, ph_series_both_50yoy_rw   = pct_inc(impact_change_both_50yoy,metric)
    ph_series_both_25yoy,ph_series_both_25yoy_cn,ph_series_both_25yoy_rw = pct_inc(impact_change_both_25yoy,metric)
    ph_series_both_75yoy,ph_series_both_75yoy_cn,ph_series_both_75yoy_rw = pct_inc(impact_change_both_75yoy,metric)
    
    
    init_plot(figwidth=24)
    fig,[ax1,ax2,ax3] = plt.subplots(1,3)
    
    ax1.plot(ph_series_alloyed_50yoy.loc['20180101':].sum(axis=1), color=colors[0], label='Alloyed 50yoy')
    ax1.plot(ph_series_no2_50yoy.loc['20180101':].sum(axis=1), color=colors[1], label='No.2 50yoy')
    ax1.plot(ph_series_both_50yoy.loc['20180101':].sum(axis=1), color=colors[2], label='Both 50yoy')
    ax1.fill_between(ph_series_alloyed_50yoy.loc['20180101':].index,
                     pd.concat([ph_series_alloyed_25yoy.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy.loc['20180101':].sum(axis=1),ph_series_alloyed_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_alloyed_25yoy.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy.loc['20180101':].sum(axis=1),ph_series_alloyed_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=colors[0], alpha=0.3)
    ax1.fill_between(ph_series_no2_50yoy.loc['20180101':].index,
                     pd.concat([ph_series_no2_25yoy.loc['20180101':].sum(axis=1),ph_series_no2_50yoy.loc['20180101':].sum(axis=1),ph_series_no2_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_no2_25yoy.loc['20180101':].sum(axis=1),ph_series_no2_50yoy.loc['20180101':].sum(axis=1),ph_series_no2_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=colors[1], alpha=0.3)
    ax1.fill_between(ph_series_both_50yoy.loc['20180101':].index,
                     pd.concat([ph_series_both_25yoy.loc['20180101':].sum(axis=1),ph_series_both_50yoy.loc['20180101':].sum(axis=1),ph_series_both_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_both_25yoy.loc['20180101':].sum(axis=1),ph_series_both_50yoy.loc['20180101':].sum(axis=1),ph_series_both_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=colors[2], alpha=0.3)
    ax1.set_ylabel(r'Increase in $CO_2$-equivalent emissions'+'\n(Cumulative, % of 2020 value)')
    ax1.set_title(r'Global Increase in $CO_2$-Equivalent Emissions')
    
    ax2.plot(ph_series_alloyed_50yoy_cn.loc['20180101':].sum(axis=1), color=colors[0], label='Alloyed 50yoy_cn')
    ax2.plot(ph_series_no2_50yoy_cn.loc['20180101':].sum(axis=1), color=colors[1], label='No.2 50yoy_cn')
    ax2.plot(ph_series_both_50yoy_cn.loc['20180101':].sum(axis=1), color=colors[2], label='Both 50yoy_cn')
    ax2.fill_between(ph_series_alloyed_50yoy_cn.loc['20180101':].index,
                     pd.concat([ph_series_alloyed_25yoy_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_75yoy_cn.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_alloyed_25yoy_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_75yoy_cn.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=colors[0], alpha=0.3)
    ax2.fill_between(ph_series_no2_50yoy_cn.loc['20180101':].index,
                     pd.concat([ph_series_no2_25yoy_cn.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_no2_75yoy_cn.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_no2_25yoy_cn.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_no2_75yoy_cn.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=colors[1], alpha=0.3)
    ax2.fill_between(ph_series_both_50yoy_cn.loc['20180101':].index,
                     pd.concat([ph_series_both_25yoy_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_both_75yoy_cn.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_both_25yoy_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_both_75yoy_cn.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=colors[2], alpha=0.3)
    ax2.set_ylabel(r'Increase in $CO_2$-equivalent emissions'+'\n(Cumulative, % of 2020 value)')
    ax2.set_title(r'China Increase in $CO_2$-Equivalent Emissions')
    
    ax3.plot(ph_series_alloyed_50yoy_rw.loc['20180101':].sum(axis=1), color=colors[0], label='Alloyed 50yoy_rw')
    ax3.plot(ph_series_no2_50yoy_rw.loc['20180101':].sum(axis=1), color=colors[1], label='No.2 50yoy_rw')
    ax3.plot(ph_series_both_50yoy_rw.loc['20180101':].sum(axis=1), color=colors[2], label='Both 50yoy_rw')
    ax3.fill_between(ph_series_alloyed_50yoy_rw.loc['20180101':].index,
                     pd.concat([ph_series_alloyed_25yoy_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_75yoy_rw.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_alloyed_25yoy_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_75yoy_rw.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=colors[0], alpha=0.3)
    ax3.fill_between(ph_series_no2_50yoy_rw.loc['20180101':].index,
                     pd.concat([ph_series_no2_25yoy_rw.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_no2_75yoy_rw.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_no2_25yoy_rw.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_no2_75yoy_rw.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=colors[1], alpha=0.3)
    ax3.fill_between(ph_series_both_50yoy_rw.loc['20180101':].index,
                     pd.concat([ph_series_both_25yoy_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_both_75yoy_rw.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_both_25yoy_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_both_75yoy_rw.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=colors[2], alpha=0.3)
    ax3.set_ylabel(r'Increase in $CO_2$-equivalent emissions'+'\n(Cumulative, % of 2020 value)')
    ax3.set_title(r'Rest of World Increase in $CO_2$-Equivalent Emissions')
    
    
    fig,[ax1,ax2,ax3] = plt.subplots(1,3)
    ax1.stackplot(ph_series_no2_50yoy.loc['20180101':,:].index, ph_series_no2_50yoy[ph_series_no2_50yoy>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_no2_50yoy.columns)
    ax1.plot(ph_series_no2_50yoy.loc['20180101':].sum(axis=1), color='k', label='Total')
    ax1.legend(loc='upper left',fontsize=12)
    ax1.stackplot(ph_series_no2_50yoy.loc['20180101':,:].index, ph_series_no2_50yoy[ph_series_no2_50yoy<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_no2_50yoy.columns)
    ax1.set_title(r'Global Increase in $CO_2$-Equivalent Emissions')
#     plt.ylabel('Cumulative increase, % of 2020 value')
    ax1.set_ylabel(r'Increase in $CO_2$-equivalent emissions'+'\n(Cumulative, % of 2020 value)');
    
    ax2.stackplot(ph_series_no2_50yoy_cn.loc['20180101':,:].index, ph_series_no2_50yoy_cn[ph_series_no2_50yoy_cn>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_no2_50yoy_cn.columns)
    ax2.plot(ph_series_no2_50yoy_cn.loc['20180101':].sum(axis=1), color='k', label='Total')
    ax2.legend(loc='upper left',fontsize=12)
#     ax2.plot([pd.datetime(2018,1,1),pd.datetime(2040,1,1)],[0,0], color='white', linewidth=2)
    ax2.stackplot(ph_series_no2_50yoy_cn.loc['20180101':,:].index, ph_series_no2_50yoy_cn[ph_series_no2_50yoy_cn<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_no2_50yoy_cn.columns)
    
    ax2.set_title(r'China Increase in $CO_2$-Equivalent Emissions')
#     plt.ylabel('Cumulative increase, % of 2020 value')
    ax2.set_ylabel(r'Increase in $CO_2$-equivalent emissions'+'\n(Cumulative, % of 2020 value)');
    
    ax3.stackplot(ph_series_no2_50yoy_rw.loc['20180101':,:].index, ph_series_no2_50yoy_rw[ph_series_no2_50yoy_rw>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_no2_50yoy_rw.columns)
    ax3.plot(ph_series_no2_50yoy_rw.loc['20180101':].sum(axis=1), color='k', label='Total')
    ax3.legend(loc='upper left',fontsize=12)
    ax3.stackplot(ph_series_no2_50yoy_rw.loc['20180101':,:].index, ph_series_no2_50yoy_rw[ph_series_no2_50yoy_rw<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_no2_50yoy_rw.columns)
    ax3.set_title(r'China Increase in $CO_2$-Equivalent Emissions')
#     plt.ylabel('Cumulative increase, % of 2020 value')
    ax3.set_ylabel(r'Increase in $CO_2$-equivalent emissions'+'\n(Cumulative, % of 2020 value)');

# %%
for metric in impact_change_alloyed_50yoy.columns.levels[1]:
    for y in ph_series_inc100.index:
        ph_series_inc100.loc[y] = impact_change_no2_50yoy_inc100.groupby(axis=1,level=1).sum().loc[idx[y,:],metric].reset_index(level=0,drop=True)
        ph_series_inc200.loc[y] = impact_change_no2_50yoy_inc200.groupby(axis=1,level=1).sum().loc[idx[y,:],metric].reset_index(level=0,drop=True)
        ph_series_dec100.loc[y] = impact_change_no2_50yoy_dec100.groupby(axis=1,level=1).sum().loc[idx[y,:],metric].reset_index(level=0,drop=True)
        ph_series_dec200.loc[y] = impact_change_no2_50yoy_dec200.groupby(axis=1,level=1).sum().loc[idx[y,:],metric].reset_index(level=0,drop=True)
        ph_series_base.loc[y] = impact_change_no2_50yoy.groupby(axis=1,level=1).sum().loc[idx[y,:],metric].reset_index(level=0,drop=True)
        ph_series_inc100_rw.loc[y] = impact_change_no2_50yoy_inc100.loc[:,idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().loc[idx[y,:],metric].reset_index(level=0,drop=True)
        ph_series_inc200_rw.loc[y] = impact_change_no2_50yoy_inc200.loc[:,idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().loc[idx[y,:],metric].reset_index(level=0,drop=True)
        ph_series_dec100_rw.loc[y] = impact_change_no2_50yoy_dec100.loc[:,idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().loc[idx[y,:],metric].reset_index(level=0,drop=True)
        ph_series_dec200_rw.loc[y] = impact_change_no2_50yoy_dec200.loc[:,idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().loc[idx[y,:],metric].reset_index(level=0,drop=True)
        ph_series_base_rw.loc[y] = impact_change_no2_50yoy.loc[:,idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().loc[idx[y,:],metric].reset_index(level=0,drop=True)
        ph_series_inc100_cn.loc[y] = impact_change_no2_50yoy_inc100.loc[idx[y,:],idx['China',metric]].reset_index(level=0,drop=True)
        ph_series_inc200_cn.loc[y] = impact_change_no2_50yoy_inc200.loc[idx[y,:],idx['China',metric]].reset_index(level=0,drop=True)
        ph_series_dec100_cn.loc[y] = impact_change_no2_50yoy_dec100.loc[idx[y,:],idx['China',metric]].reset_index(level=0,drop=True)
        ph_series_dec200_cn.loc[y] = impact_change_no2_50yoy_dec200.loc[idx[y,:],idx['China',metric]].reset_index(level=0,drop=True)
        ph_series_base_cn.loc[y] = impact_change_no2_50yoy.loc[idx[y,:],idx['China', metric]].reset_index(level=0,drop=True)

    fig,[ax1,ax2,ax3,ax4,ax5] = plt.subplots(1,5, sharey=True)
    init_plot(figwidth=40,ax=ax1)
    init_plot(figwidth=40,ax=ax2)
    init_plot(figwidth=40,ax=ax3)
    init_plot(figwidth=40,ax=ax4)
    init_plot(figwidth=40,ax=ax5)

    ax1.stackplot(ph_series_inc200_cn.loc['20180101':,:].index, ph_series_inc200_cn[ph_series_inc200_cn>0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100, 
              labels=ph_series_inc200_cn.columns)
    ax1.stackplot(ph_series_inc200_cn.loc['20180101':,:].index, ph_series_inc200_cn[ph_series_inc200_cn<0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100, 
              labels=ph_series_inc200_cn.columns)
    ax1.plot(ph_series_inc200_cn.loc['20180101':].sum(axis=1)/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100,'k')
    
    ax2.stackplot(ph_series_inc100_cn.loc['20180101':,:].index, ph_series_inc100_cn[ph_series_inc100_cn>0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100, 
              labels=ph_series_inc100_cn.columns)
    ax2.stackplot(ph_series_inc100_cn.loc['20180101':,:].index, ph_series_inc100_cn[ph_series_inc100_cn<0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100, 
              labels=ph_series_inc100_cn.columns)
    ax2.plot(ph_series_inc100_cn.loc['20180101':].sum(axis=1)/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100,'k')
    
    ax3.stackplot(ph_series_base_cn.loc['20180101':,:].index, ph_series_base_cn[ph_series_base_cn>0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100, 
            labels=ph_series_base_cn.columns)
    ax3.stackplot(ph_series_base_cn.loc['20180101':,:].index, ph_series_base_cn[ph_series_base_cn<0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100, 
            labels=ph_series_base_cn.columns)
    ax3.plot(ph_series_base_cn.loc['20180101':].sum(axis=1)/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100,'k')
    
    ax4.stackplot(ph_series_dec100_cn.loc['20180101':,:].index, ph_series_dec100_cn[ph_series_dec100_cn>0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100, 
            labels=ph_series_inc100_cn.columns)
    ax4.stackplot(ph_series_dec100_cn.loc['20180101':,:].index, ph_series_dec100_cn[ph_series_dec100_cn<0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100, 
            labels=ph_series_inc100_cn.columns)
    ax4.plot(ph_series_dec100_cn.loc['20180101':].sum(axis=1)/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100,'k')

    ax5.stackplot(ph_series_dec200_cn.loc['20180101':,:].index, ph_series_dec200_cn[ph_series_dec200_cn>0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100, 
            labels=ph_series_dec200_cn.columns)
    ax5.stackplot(ph_series_dec200_cn.loc['20180101':,:].index, ph_series_dec200_cn[ph_series_dec200_cn<0].fillna(0).loc['20180101':].transpose()/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100, 
            labels=ph_series_dec200_cn.columns)
    ax5.plot(ph_series_dec200_cn.loc['20180101':].sum(axis=1)/total_impacts_pir_baseline.groupby(axis=0,level=0).sum().groupby(axis=1,level=1).sum().loc['20200101',metric]*100,'k')

    ax1.set_title('Global '+metric.split('(')[0].title()+'Change\nIncreased Refined Imports 200 kt/year')
    ax2.set_title('Global '+metric.split('(')[0].title()+'Change\nIncreased Refined Imports 100 kt/year')
    ax3.set_title('Global '+metric.split('(')[0].title()+'Change\nConstant Refined Imports')
    ax4.set_title('Global '+metric.split('(')[0].title()+'Change\nDecreased Refined Imports 100 kt/year')
    ax5.set_title('Global '+metric.split('(')[0].title()+'Change\nDecreased Refined Imports 200 kt/year')
    
    #     plt.xlabel('Year')
    ax1.set_ylabel('Cumulative increase, % of 2020 value')
    ax2.set_ylabel('Cumulative increase, % of 2020 value')
    ax3.set_ylabel('Cumulative increase, % of 2020 value')
    ax4.set_ylabel('Cumulative increase, % of 2020 value')
    ax5.set_ylabel('Cumulative increase, % of 2020 value')
#     plt.ylabel(metric.split('(')[1][:-1])
    plt.show()

# %% [markdown]
# Change in quantities, regional for both banned

# %%
c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
c2 = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd']
c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2']
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4)
ph_series4 = pd.DataFrame(0, index = quantity_change_alloyed_50yoy.index.levels[0], columns = quantity_change_alloyed_50yoy.index.levels[1])
ph_series5 = pd.DataFrame(0, index = quantity_change_alloyed_50yoy.index.levels[0], columns = quantity_change_alloyed_50yoy.index.levels[1])
ph_series6 = pd.DataFrame(0, index = quantity_change_alloyed_50yoy.index.levels[0], columns = quantity_change_alloyed_50yoy.index.levels[1])
fig,[ax1,ax2,ax3] = plt.subplots(1,3, sharey=True)
for y in ph_series4.index:
#         ph_series4.loc[y] = quantity_change_alloyed_50yoy.sum(axis=1).loc[idx[y,:]].reset_index(level=0,drop=True)
#         ph_series5.loc[y] = quantity_change_no2_50yoy.sum(axis=1).loc[idx[y,:]].reset_index(level=0,drop=True)
    ph_series4.loc[y] = quantity_change_both_50yoy.sum(axis=1).loc[idx[y,:]].reset_index(level=0,drop=True)
#         ph_series4.loc[y] = quantity_change_alloyed_50yoy.loc[idx[y,:],'China'].reset_index(level=0,drop=True)
#         ph_series5.loc[y] = quantity_change_no2_50yoy.loc[idx[y,:],'China'].reset_index(level=0,drop=True)
    ph_series5.loc[y] = quantity_change_both_50yoy.loc[idx[y,:],'China'].reset_index(level=0,drop=True)
#         ph_series4.loc[y] = quantity_change_alloyed_50yoy.loc[:,['Oceania','Africa','Europe','North America','Latin America','Other Asia']].sum(axis=1).loc[idx[y,:]].reset_index(level=0,drop=True)
#         ph_series5.loc[y] = quantity_change_no2_50yoy.loc[:,['Oceania','Africa','Europe','North America','Latin America','Other Asia']].sum(axis=1).loc[idx[y,:]].reset_index(level=0,drop=True)
    ph_series6.loc[y] = quantity_change_both_50yoy.loc[:,['Oceania','Africa','Europe','North America','Latin America','Other Asia']].sum(axis=1).loc[idx[y,:]].reset_index(level=0,drop=True)
init_plot(figwidth=24,ax=ax1)
init_plot(figwidth=24,ax=ax2)
init_plot(figwidth=24,ax=ax3)
ax1.stackplot(ph_series4.loc['20180101':,:].index, ph_series4.loc['20180101':,:].cumsum().transpose()/quantities_pir_baseline.sum(axis=1).groupby(axis=0,level=0).sum().loc['20200101']*100, 
          labels=ph_series4.columns)
ax1.plot(ph_series4.loc['20180101':].sum(axis=1).cumsum()/quantities_pir_baseline.sum(axis=1).groupby(axis=0,level=0).sum().loc['20200101']*100,'k')
ax2.stackplot(ph_series4.loc['20180101':,:].index, ph_series5.loc['20180101':,:].cumsum().transpose()/quantities_pir_baseline.sum(axis=1).groupby(axis=0,level=0).sum().loc['20200101']*100, 
          labels=ph_series4.columns)
ax2.plot(ph_series5.loc['20180101':].sum(axis=1).cumsum()/quantities_pir_baseline.sum(axis=1).groupby(axis=0,level=0).sum().loc['20200101']*100,'k')
ax3.stackplot(ph_series4.loc['20180101':,:].index, ph_series6.loc['20180101':,:].cumsum().transpose()/quantities_pir_baseline.sum(axis=1).groupby(axis=0,level=0).sum().loc['20200101']*100, 
          labels=ph_series4.columns)
ax3.plot(ph_series6.loc['20180101':].sum(axis=1).cumsum()/quantities_pir_baseline.sum(axis=1).groupby(axis=0,level=0).sum().loc['20200101']*100,'k')
#     ax1.legend(loc='upper left')
ax1.set_title('Global Change in Quantity')
ax2.set_title('China Change in Quantity ')
ax3.set_title('RoW Change in Quantity ')
#     plt.xlabel('Year')
ax1.set_ylabel('Cumulative increase as a percent of 2020 value')
ax2.set_ylabel('Cumulative increase as a percent of 2020 value')
ax3.set_ylabel('Cumulative increase as a percent of 2020 value')
#     plt.ylabel(metric.split('(')[1][:-1])
plt.show()

# (quantities_alloyed_50yoy - quantities_pir_baseline.sum(axis=1)).groupby(axis=0,level=0).sum().cumsum().loc['20180101':,'Global warming (kt CO2 eq)'].plot()

# %%
ph_series1.sum(axis=1).cumsum()#/quantities_pir_baseline.groupby(axis=0,level=0).sum().loc['20200101']*100

# %% [markdown]
# ### Old scenario environmental impacts

# %%
file_name = 'baseline_baseline'
mine_life_stats_baseline_baseline = pd.read_excel('Mine level info/mine life '+file_name+'.xlsx', index_col=[0,1])
total_impacts_baseline_baseline, unit_impacts_baseline_baseline, quantities_baseline_baseline = \
    calculate_impacts_old_scenarios(sd_baseline_baseline.loc['19600101':],mine_life_stats_baseline_baseline)

file_name = 'linshock1yr-sp2-1'
mine_life_stats_lin1yr = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine life '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin1yr, unit_impacts_lin1yr, quantities_lin1yr = \
    calculate_impacts_old_scenarios(sd_lin1yr.loc['19600101':],mine_life_stats_lin1yr)
impact_change_lin1yr = total_impacts_lin1yr - total_impacts_baseline_baseline
quantity_change_lin1yr = quantities_lin1yr - quantities_baseline_baseline

file_name = 'linshock1yr10-sp2'
mine_life_stats_lin1yr10 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine life '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin1yr10, unit_impacts_lin1yr10, quantities_lin1yr10 = \
    calculate_impacts_old_scenarios(sd_lin1yr10.loc['19600101':],mine_life_stats_lin1yr10)
impact_change_lin1yr10 = total_impacts_lin1yr10 - total_impacts_baseline_baseline
quantity_change_lin1yr10 = quantities_lin1yr10 - quantities_baseline_baseline

file_name = 'linshock1yr20-sp2'
mine_life_stats_lin1yr20 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine life '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin1yr20, unit_impacts_lin1yr20, quantities_lin1yr20 = \
    calculate_impacts_old_scenarios(sd_lin1yr20.loc['19600101':],mine_life_stats_lin1yr20)
impact_change_lin1yr20 = total_impacts_lin1yr20 - total_impacts_baseline_baseline
quantity_change_lin1yr20 = quantities_lin1yr20 - quantities_baseline_baseline

file_name = 'linshock1yr50-sp2'
mine_life_stats_lin1yr50 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine life '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin1yr50, unit_impacts_lin1yr50, quantities_lin1yr50 = \
    calculate_impacts_old_scenarios(sd_lin1yr50.loc['19600101':],mine_life_stats_lin1yr50)
impact_change_lin1yr50 = total_impacts_lin1yr50 - total_impacts_baseline_baseline
quantity_change_lin1yr50 = quantities_lin1yr50 - quantities_baseline_baseline

file_name = 'linshock5yr-sp2-1'
mine_life_stats_lin5yr = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine life '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin5yr, unit_impacts_lin5yr, quantities_lin5yr = \
    calculate_impacts_old_scenarios(sd_lin5yr.loc['19600101':],mine_life_stats_lin5yr)
impact_change_lin5yr = total_impacts_lin5yr - total_impacts_baseline_baseline
quantity_change_lin5yr = quantities_lin5yr - quantities_baseline_baseline

file_name = 'linshock5yr10-sp2'
mine_life_stats_lin5yr10 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine life '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin5yr10, unit_impacts_lin5yr10, quantities_lin5yr10 = \
    calculate_impacts_old_scenarios(sd_lin5yr10.loc['19600101':],mine_life_stats_lin5yr10)
impact_change_lin5yr10 = total_impacts_lin5yr10 - total_impacts_baseline_baseline
quantity_change_lin5yr10 = quantities_lin5yr10 - quantities_baseline_baseline

file_name = 'linshock5yr20-sp2'
mine_life_stats_lin5yr20 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine life '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin5yr20, unit_impacts_lin5yr20, quantities_lin5yr20 = \
    calculate_impacts_old_scenarios(sd_lin5yr20.loc['19600101':],mine_life_stats_lin5yr20)
impact_change_lin5yr20 = total_impacts_lin5yr20 - total_impacts_baseline_baseline
quantity_change_lin5yr20 = quantities_lin5yr20 - quantities_baseline_baseline

file_name = 'linshock5yr50-sp2'
mine_life_stats_lin5yr50 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine life '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin5yr50, unit_impacts_lin5yr50, quantities_lin5yr50 = \
    calculate_impacts_old_scenarios(sd_lin5yr50.loc['19600101':],mine_life_stats_lin5yr50)
impact_change_lin5yr50 = total_impacts_lin5yr50 - total_impacts_baseline_baseline
quantity_change_lin5yr50 = quantities_lin5yr50 - quantities_baseline_baseline

file_name = 'linshock10yr-sp2-1'
mine_life_stats_lin10yr = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin10yr, unit_impacts_lin10yr, quantities_lin10yr = \
    calculate_impacts_old_scenarios(sd_lin10yr.loc['19600101':],mine_life_stats_lin10yr)
impact_change_lin10yr = total_impacts_lin10yr - total_impacts_baseline_baseline
quantity_change_lin10yr = quantities_lin10yr - quantities_baseline_baseline

file_name = 'linshock10yr10-sp2'
mine_life_stats_lin10yr10 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin10yr10, unit_impacts_lin10yr10, quantities_lin10yr10 = \
    calculate_impacts_old_scenarios(sd_lin10yr10.loc['19600101':],mine_life_stats_lin10yr10)
impact_change_lin10yr10 = total_impacts_lin10yr10 - total_impacts_baseline_baseline
quantity_change_lin10yr10 = quantities_lin10yr10 - quantities_baseline_baseline

file_name = 'linshock10yr20-sp2'
mine_life_stats_lin10yr20 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin10yr20, unit_impacts_lin10yr20, quantities_lin10yr20 = \
    calculate_impacts_old_scenarios(sd_lin10yr20.loc['19600101':],mine_life_stats_lin10yr20)
impact_change_lin10yr20 = total_impacts_lin10yr20 - total_impacts_baseline_baseline
quantity_change_lin10yr20 = quantities_lin10yr20 - quantities_baseline_baseline

file_name = 'linshock10yr50-sp2'
mine_life_stats_lin10yr50 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin10yr50, unit_impacts_lin10yr50, quantities_lin10yr50 = \
    calculate_impacts_old_scenarios(sd_lin10yr50.loc['19600101':],mine_life_stats_lin10yr50)
impact_change_lin10yr50 = total_impacts_lin10yr50 - total_impacts_baseline_baseline
quantity_change_lin10yr50 = quantities_lin10yr50 - quantities_baseline_baseline

file_name = 'linshock20yr-sp2-1'
mine_life_stats_lin20yr = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin20yr, unit_impacts_lin20yr, quantities_lin20yr = \
    calculate_impacts_old_scenarios(sd_lin20yr.loc['19600101':],mine_life_stats_lin20yr)
impact_change_lin20yr = total_impacts_lin20yr - total_impacts_baseline_baseline
quantity_change_lin20yr = quantities_lin20yr - quantities_baseline_baseline

file_name = 'linshock20yr10-sp2'
mine_life_stats_lin20yr10 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin20yr10, unit_impacts_lin20yr10, quantities_lin20yr10 = \
    calculate_impacts_old_scenarios(sd_lin20yr10.loc['19600101':],mine_life_stats_lin20yr10)
impact_change_lin20yr10 = total_impacts_lin20yr10 - total_impacts_baseline_baseline
quantity_change_lin20yr10 = quantities_lin20yr10 - quantities_baseline_baseline

file_name = 'linshock20yr20-sp2'
mine_life_stats_lin20yr20 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin20yr20, unit_impacts_lin20yr20, quantities_lin20yr20 = \
    calculate_impacts_old_scenarios(sd_lin20yr20.loc['19600101':],mine_life_stats_lin20yr20)
impact_change_lin20yr20 = total_impacts_lin20yr20 - total_impacts_baseline_baseline
quantity_change_lin20yr20 = quantities_lin20yr20 - quantities_baseline_baseline

file_name = 'linshock20yr50-sp2'
mine_life_stats_lin20yr50 = pd.read_excel('John/00 Initial Linear Ramp Shocks/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_lin20yr50, unit_impacts_lin20yr50, quantities_lin20yr50 = \
    calculate_impacts_old_scenarios(sd_lin20yr50.loc['19600101':],mine_life_stats_lin20yr50)
impact_change_lin20yr50 = total_impacts_lin20yr50 - total_impacts_baseline_baseline
quantity_change_lin20yr50 = quantities_lin20yr50 - quantities_baseline_baseline

print('All done')

# %%
print(pct_inc(impact_change_lin1yr10,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin1yr20,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin1yr50,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin1yr,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum())
print(pct_inc(impact_change_lin5yr10,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin5yr20,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin5yr50,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin5yr,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum())
print(pct_inc(impact_change_lin10yr10,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin10yr20,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin10yr50,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin10yr,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum())
print(pct_inc(impact_change_lin20yr10,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin20yr20,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin20yr50,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum(),
    pct_inc(impact_change_lin20yr,metric,baseline=total_impacts_baseline_baseline)[0].loc['20400101'].sum())
total_impacts_baseline_baseline.sum(axis=1).loc['20200101','Global warming (kt CO2 eq)']

# %%
c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
c2 = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd']
c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2']
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4)
ph_series1 = pd.DataFrame(0, index = impact_change_lin20yr20.index.levels[0], columns = impact_change_alloyed_50yoy.columns.levels[1])
ph_series2 = pd.DataFrame(0, index = impact_change_lin20yr20.index.levels[0], columns = impact_change_alloyed_50yoy.columns.levels[1])
ph_series3 = pd.DataFrame(0, index = impact_change_lin20yr20.index.levels[0], columns = impact_change_alloyed_50yoy.columns.levels[1])
# ['Global warming (kt CO2 eq)']:
for metric in impact_change_alloyed_50yoy.index.levels[1]:
    fig,[ax1,ax2,ax3,ax4] = plt.subplots(1,4, sharey=True)
#         ph_series1 = impact_change_alloyed_50yoy.groupby(axis=1,level=1).sum().loc[idx[:,metric],:].reset_index(level=1,drop=True)
#         ph_series2 = impact_change_no2_50yoy.groupby(axis=1,level=1).sum().loc[idx[:,metric],:].reset_index(level=1,drop=True)
#     ph_series3 = impact_change_both_50yoy.groupby(axis=1,level=1).sum().loc[idx[:,metric],:].reset_index(level=1,drop=True)
#         ph_series1 = impact_change_alloyed_50yoy.loc[idx[:,metric],idx['China', :]].reset_index(level=1,drop=True)
#         ph_series2 = impact_change_no2_50yoy.loc[idx[:,metric],idx['China', :]].reset_index(level=1,drop=True)
#     ph_series3 = impact_change_both_50yoy.loc[idx[:,metric],idx['China', :]].reset_index(level=1,drop=True).T.reset_index(level=0,drop=True).T
#         ph_series1 = impact_change_alloyed_50yoy.loc[idx[:,metric],idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().reset_index(level=1,drop=True)
#         ph_series2 = impact_change_no2_50yoy.loc[idx[:,metric],idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().reset_index(level=1,drop=True)
#     ph_series3 = impact_change_both_50yoy.loc[idx[:,metric],idx[['Oceania','Africa','Europe','North America','Latin America','Other Asia'],:]].groupby(axis=1,level=1).sum().reset_index(level=1,drop=True)
    ph_series1yr,ph_series2,ph_series3 = pct_inc(impact_change_lin1yr,metric,baseline=total_impacts_baseline_baseline)
    ph_series1yr10,ph_series2,ph_series3 = pct_inc(impact_change_lin1yr10,metric,baseline=total_impacts_baseline_baseline)
    ph_series1yr20,ph_series2,ph_series3 = pct_inc(impact_change_lin1yr20,metric,baseline=total_impacts_baseline_baseline)
    ph_series1yr50,ph_series2,ph_series3 = pct_inc(impact_change_lin1yr50,metric,baseline=total_impacts_baseline_baseline)
    
    ph_series5yr,ph_series2,ph_series3 = pct_inc(impact_change_lin5yr,metric,baseline=total_impacts_baseline_baseline)
    ph_series5yr10,ph_series2,ph_series3 = pct_inc(impact_change_lin5yr10,metric,baseline=total_impacts_baseline_baseline)
    ph_series5yr20,ph_series2,ph_series3 = pct_inc(impact_change_lin5yr20,metric,baseline=total_impacts_baseline_baseline)
    ph_series5yr50,ph_series2,ph_series3 = pct_inc(impact_change_lin5yr50,metric,baseline=total_impacts_baseline_baseline)
    
    ph_series10yr,ph_series2,ph_series3 = pct_inc(impact_change_lin10yr,metric,baseline=total_impacts_baseline_baseline)
    ph_series10yr10,ph_series2,ph_series3 = pct_inc(impact_change_lin10yr10,metric,baseline=total_impacts_baseline_baseline)
    ph_series10yr20,ph_series2,ph_series3 = pct_inc(impact_change_lin10yr20,metric,baseline=total_impacts_baseline_baseline)
    ph_series10yr50,ph_series2,ph_series3 = pct_inc(impact_change_lin10yr50,metric,baseline=total_impacts_baseline_baseline)
    
    ph_series20yr,ph_series2,ph_series3 = pct_inc(impact_change_lin20yr,metric,baseline=total_impacts_baseline_baseline)
    ph_series20yr10,ph_series2,ph_series3 = pct_inc(impact_change_lin20yr10,metric,baseline=total_impacts_baseline_baseline)
    ph_series20yr20,ph_series2,ph_series3 = pct_inc(impact_change_lin20yr20,metric,baseline=total_impacts_baseline_baseline)
    ph_series20yr50,ph_series2,ph_series3 = pct_inc(impact_change_lin20yr50,metric,baseline=total_impacts_baseline_baseline)
    
    init_plot(figwidth=24,ax=ax1)
    init_plot(figwidth=24,ax=ax2)
    init_plot(figwidth=24,ax=ax3)
    
    ax1.stackplot(ph_series1yr10.loc['20180101':,:].index, ph_series1yr10[ph_series1yr10>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1yr10.columns)
    ax1.legend()
    ax1.stackplot(ph_series1yr10.loc['20180101':,:].index, ph_series1yr10[ph_series1yr10<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1yr10.columns)
    ax1.plot(ph_series1yr10.loc['20180101':].sum(axis=1),'k')    
    
    ax2.stackplot(ph_series1yr20.loc['20180101':,:].index, ph_series1yr20[ph_series1yr20>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1yr20.columns)
#     ax2.legend()
    ax2.stackplot(ph_series1yr20.loc['20180101':,:].index, ph_series1yr20[ph_series1yr20<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1yr20.columns)
    ax2.plot(ph_series1yr20.loc['20180101':].sum(axis=1),'k')
    
    ax3.stackplot(ph_series1yr50.loc['20180101':,:].index, ph_series1yr50[ph_series1yr50>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1yr50.columns)
#     ax3.legend()
    ax3.stackplot(ph_series1yr50.loc['20180101':,:].index, ph_series1yr50[ph_series1yr50<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1yr50.columns)
    ax3.plot(ph_series1yr50.loc['20180101':].sum(axis=1),'k')

    ax4.stackplot(ph_series1yr.loc['20180101':,:].index, ph_series1yr[ph_series1yr>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1yr.columns)
#     ax4.legend()
    ax4.stackplot(ph_series1yr.loc['20180101':,:].index, ph_series1yr[ph_series1yr<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1yr.columns)
    ax4.plot(ph_series1yr.loc['20180101':].sum(axis=1),'k')

    plt.suptitle('1-Year Linear Ramps\n\n\n\n ')
    ax1.set_title('10% of Opportunity\n'+metric.split('(')[0].title()+'Change')
    ax2.set_title('20% of Opportunity\n'+metric.split('(')[0].title()+'Change')
    ax3.set_title('50% of Opportunity\n'+metric.split('(')[0].title()+'Change')
    ax4.set_title('100% of Opportunity\n'+metric.split('(')[0].title()+'Change')
    ax1.set_ylabel('Cumulative increase, % of 2020 value')
    ax2.set_ylabel('Cumulative increase, % of 2020 value')
    ax3.set_ylabel('Cumulative increase, % of 2020 value')
    ax4.set_ylabel('Cumulative increase, % of 2020 value')
    plt.show()
    
#     fig,[ax1,ax2,ax3,ax4] = plt.subplots(1,4, sharey=True)
    

# (total_impacts_alloyed_50yoy - total_impacts_pir_baseline).groupby(axis=1,level=1).sum().groupby(axis=0,level=0).sum().loc['20180101':,'Global warming (kt CO2 eq)'].plot()

# %% [markdown]
# ### Displacement investigations

# %%
# all_points = 
pd.read_excel('All data points.xlsx', index_col=0, header = [0,1,2])

# %%
impact_change_lin5yr20.index.levels[1]

# %%
# Writing results to excel
for i in ['One']:
    all_points = pd.concat([pd.concat([pd.concat([pd.concat([shock_lin1yr10.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin5yr10.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin10yr10.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin20yr10.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([shock_lin1yr20.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin5yr20.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin10yr20.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin20yr20.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([shock_lin1yr50.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin5yr50.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin10yr50.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin20yr50.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([shock_lin1yr.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin5yr.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin10yr.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin20yr.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20'])],axis=1,keys=['10%','20%','50%','100%'])\
    .T.reset_index(level=2,drop=True).T,
    pd.concat([pd.concat([pd.concat([-mining_response_lin1yr10.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin5yr10.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin10yr10.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin20yr10.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-mining_response_lin1yr20.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin5yr20.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin10yr20.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin20yr20.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-mining_response_lin1yr50.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin5yr50.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin10yr50.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin20yr50.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-mining_response_lin1yr.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin5yr.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin10yr.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin20yr.loc['20180101':].cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20'])],axis=1,keys=['10%','20%','50%','100%'])\
    .T.reset_index(level=2,drop=True).T,
    pd.concat([pd.concat([pd.concat([-impact_change_lin1yr10.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin5yr10.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin10yr10.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin20yr10.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-impact_change_lin1yr20.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin5yr20.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin10yr20.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin20yr20.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-impact_change_lin1yr50.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin5yr50.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin10yr50.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin20yr50.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-impact_change_lin1yr.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin5yr.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin10yr.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin20yr.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=1,keys=['Cumulative scrap supply increase'])],axis=1, keys = ['1','5','10','20'])],axis=1,keys=['10%','20%','50%','100%'])\
    .T.reset_index(level=2,drop=True).T,
    pd.concat([pd.concat([pd.concat([demand_shock_lin1yr10.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin5yr10.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin10yr10.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin20yr10.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([demand_shock_lin1yr20.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin5yr20.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin10yr20.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin20yr20.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([demand_shock_lin1yr50.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin5yr50.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin10yr50.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin20yr50.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase'])],axis=1, keys = ['1','5','10','20']),
    pd.concat([pd.concat([demand_shock_lin1yr.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin5yr.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin10yr.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin20yr.loc['20180101':]/1000],axis=1,keys=['Cumulative demand increase'])],axis=1, keys = ['1','5','10','20'])],axis=1,keys=['10%','20%','50%','100%'])\
    .T.reset_index(level=2,drop=True).T],axis=1,keys=['Cumulative scrap supply increase','Cumulative mining reduction','Cumulative $CO_2$ emissions reduction','Cumulative demand increase'])
    all_points.to_excel('All data points.xlsx')

    all_points_rs = pd.concat([pd.concat([pd.concat([pd.concat([shock_lin1yr10.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin5yr10.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin10yr10.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin20yr10.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([shock_lin1yr20.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin5yr20.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin10yr20.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin20yr20.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([shock_lin1yr50.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin5yr50.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin10yr50.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin20yr50.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([shock_lin1yr.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin5yr.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin10yr.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([shock_lin20yr.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20'])],axis=0,keys=['10%','20%','50%','100%'])\
    .T.reset_index(level=2,drop=True).T,
    pd.concat([pd.concat([pd.concat([-mining_response_lin1yr10.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin5yr10.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin10yr10.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin20yr10.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-mining_response_lin1yr20.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin5yr20.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin10yr20.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin20yr20.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-mining_response_lin1yr50.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin5yr50.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin10yr50.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin20yr50.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-mining_response_lin1yr.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin5yr.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin10yr.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-mining_response_lin20yr.loc['20180101':].cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20'])],axis=0,keys=['10%','20%','50%','100%'])\
    .T.reset_index(level=2,drop=True).T,
    pd.concat([pd.concat([pd.concat([-impact_change_lin1yr10.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin5yr10.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin10yr10.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin20yr10.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-impact_change_lin1yr20.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin5yr20.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin10yr20.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin20yr20.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-impact_change_lin1yr50.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin5yr50.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin10yr50.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin20yr50.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([-impact_change_lin1yr.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin5yr.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin10yr.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase']),
    pd.concat([-impact_change_lin20yr.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True).cumsum()/1000],axis=0,keys=['Cumulative scrap supply increase'])],axis=0, keys = ['1','5','10','20'])],axis=0,keys=['10%','20%','50%','100%'])\
    .T.reset_index(level=2,drop=True).T,
    pd.concat([pd.concat([pd.concat([demand_shock_lin1yr10.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin5yr10.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin10yr10.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin20yr10.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([demand_shock_lin1yr20.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin5yr20.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin10yr20.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin20yr20.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([demand_shock_lin1yr50.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin5yr50.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin10yr50.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin20yr50.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase'])],axis=0, keys = ['1','5','10','20']),
    pd.concat([pd.concat([demand_shock_lin1yr.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin5yr.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin10yr.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase']),
    pd.concat([demand_shock_lin20yr.loc['20180101':]/1000],axis=0,keys=['Cumulative demand increase'])],axis=0, keys = ['1','5','10','20'])],axis=0,keys=['10%','20%','50%','100%'])\
    .T.reset_index(level=2,drop=True).T],axis=1,keys=['Cumulative scrap supply increase','Cumulative mining reduction','Cumulative $CO_2$ emissions reduction','Cumulative demand increase'])
    all_points_rs.to_excel('All data points - reshaped.xlsx')




all_points_rs.loc[:,'$CO_2$ emissions-based displacement'] = (all_points_rs.loc[:,'Cumulative $CO_2$ emissions reduction']/all_points_rs.loc[:,'Cumulative scrap supply increase']).fillna(0)
all_points_rs.loc[:,'Mining-based displacement'] = (all_points_rs.loc[:,'Cumulative mining reduction']/all_points_rs.loc[:,'Cumulative scrap supply increase']).fillna(0)
all_points_rs.loc[:,'Demand-based displacement'] = (all_points_rs.loc[:,'Cumulative demand increase']/all_points_rs.loc[:,'Cumulative scrap supply increase']).fillna(0)
all_points_rs.loc[:,'kt $CO_2$ emissions per kt mining reduction'] = (all_points_rs.loc[:,'Cumulative $CO_2$ emissions reduction']/all_points_rs.loc[:,'Cumulative mining reduction']).fillna(0)
all_points_rs[all_points_rs==-np.inf]=0
all_points = pd.concat([all_points,(all_points.loc[:,idx['Cumulative mining reduction',:,:]]/all_points.loc[:,idx['Cumulative scrap supply increase',:,:]].values).fillna(0).rename(columns={'Cumulative mining reduction':'Mining-based displacement'}),
(all_points.loc[:,idx['Cumulative $CO_2$ emissions reduction',:,:]]/all_points.loc[:,idx['Cumulative scrap supply increase',:,:]].values).fillna(0).rename(columns={'Cumulative $CO_2$ emissions reduction':'$CO_2$ emissions-based displacement'}),
(all_points.loc[:,idx['Cumulative $CO_2$ emissions reduction',:,:]]/all_points.loc[:,idx['Cumulative mining reduction',:,:]].values).fillna(0).rename(columns={'Cumulative $CO_2$ emissions reduction':'kt $CO_2$ emissions per kt mining reduction'}),
(all_points.loc[:,idx['Cumulative demand increase',:,:]]/all_points.loc[:,idx['Cumulative scrap supply increase',:,:]].values).fillna(0).rename(columns={'Cumulative demand increase':'Demand-based displacement'})],axis=1)
all_points[all_points==-np.inf]=0
all_points.loc[:,idx['Year','Year','Year']]=np.arange(2018,2041)
all_points_rs.loc[:,'Year'] = np.tile(np.arange(2018,2041),16)

# %%
all_points_rs.columns
demand_shock_lin5yr/demand_baseline_baseline.loc['20200101']
total_impacts_lin10yr20.sum(axis=1).loc[idx['20180101':,'Global warming (kt CO2 eq)']].reset_index(level=1,drop=True)/\
(total_impacts_baseline_baseline.sum(axis=1).loc[idx['20180101','Global warming (kt CO2 eq)']])


# impact_change_lin5yr.loc[idx['20180101':,'Global warming (kt CO2 eq)'],:].sum(axis=1).reset_index(level=1,drop=True)

# %%
init_plot()
import statsmodels.api as sm
yr = '20180101'
cees = colors[2]
x_label = 'Cumulative $CO_2$ emissions reduction'
y_label = 'Cumulative demand increase'
y = all_points_rs.loc[idx[:,:,yr:],y_label].values
x = all_points_rs.loc[idx[:,:,yr:],x_label].values
X = sm.add_constant(x)
m = sm.OLS(y, X).fit()
# m.summary()
plt.figure()
plt.scatter(x,y,color=cees)
plt.plot(x, m.params[0]+m.params[1]*x, color=cees)
plt.ylabel(y_label+' (Mt)')
# plt.ylabel(y_label)
plt.xlabel(x_label)#+' (Mt)')
# plt.xlim(0,1)
if m.params[0] >= 0:
    plt.text(np.mean(x)*1,0.02*np.mean(y),'y = '+str(round(m.params[1],3))+'x + '+str(round(m.params[0],3))+
         '\nR-squared: '+str(round(m.rsquared,3)))
else:
    plt.text(np.mean(x)*1,0.95*np.mean(y),'y = '+str(round(m.params[1],3))+'x - '+str(round(abs(m.params[0]),3))+
         '\nR-squared: '+str(round(m.rsquared,3)))
plt.title('Correlation between '+y_label+' and\n'+x_label)
plt.show()



plt.figure()
for k in all_points.columns.levels[1][:-1]:
    for m in all_points.columns.levels[2][:-1]:
        plt.scatter(all_points_rs.loc[idx[k,m,yr:],x_label].values, all_points_rs.loc[idx[k,m,yr:],y_label], color = pct_colors.loc[k,m])
#     y = all_points_rs.loc[idx[k,:,yr:],y_label].values
#     y = y.reshape(y.size,1)
#     x = all_points_rs.loc[idx[k,:,yr:],x_label].values
#     x = x.reshape(x.size,1)
#     X = sm.add_constant(x)
#     mod = sm.OLS(y, X).fit()
#     plt.plot(x, mod.params[0]+mod.params[1]*x, color=pct_colors.loc[k,'10'],alpha=0.5)
k,m = ['20%','10']
plt.plot(all_points_rs.loc[idx[k,m,yr:],x_label].values, all_points_rs.loc[idx[k,m,yr:],y_label], color=pct_colors.loc[k,m], alpha=0.5)
k,m = ['50%','1']
plt.plot(all_points_rs.loc[idx[k,m,yr:],x_label].values, all_points_rs.loc[idx[k,m,yr:],y_label], color=pct_colors.loc[k,m], alpha=0.5)
k,m = ['100%','1']
plt.plot(all_points_rs.loc[idx[k,m,yr:],x_label].values, all_points_rs.loc[idx[k,m,yr:],y_label], color=pct_colors.loc[k,m], alpha=0.5)
k,m = ['100%','5']
plt.plot(all_points_rs.loc[idx[k,m,yr:],x_label].values, all_points_rs.loc[idx[k,m,yr:],y_label], color=pct_colors.loc[k,m], alpha=0.5)
k,m = ['10%','20']
plt.plot(all_points_rs.loc[idx[k,m,yr:],x_label].values, all_points_rs.loc[idx[k,m,yr:],y_label], color=pct_colors.loc[k,m], alpha=0.5)
# plt.xlabel(x_label)
plt.xlabel(x_label+' (Mt)')
# plt.ylabel(y_label)
plt.ylabel(y_label+' (Mt)')
plt.title(y_label+' vs. \n'+x_label)
plt.show()

# %%
all_points.columns.levels[0]
disp_plots
pct_colors
np.mean(x)

# %%
init_plot(fontsize=14,figwidth=24,figheight=24)
i_row = [0,0,0,1,1,1,2,2,2]
i_col = [0,1,2,0,1,2,0,1,2]
plots = ['Cumulative scrap supply increase','Cumulative mining reduction','Cumulative $CO_2$ emissions reduction']
disp_plots = all_points_rs.columns[3:]
plot_titles = ['Scrap Supply Increase','Mining Reduction','$CO_2$ Emissions Reduction']
plot_labels = ['Cumulative scrap supply increase','Cumulative mining reduction','Cumulative $CO_2$ emissions reduction']
disp_plot_labels = ['Scrap supply increase','Mining reduction','$CO_2$ emissions reduction']
pct_colors = pd.DataFrame([['#bdd7e7','#6baed6','#3182bd','#08519c'],
              ['#bae4b3','#74c476','#31a354','#006d2c'],
              ['#cccccc','#969696','#636363','#252525'],
              ['#fcae91','#fb6a4a','#de2d26','#a50f15']], 
             index=['10%','20%','50%','100%'], columns=['1','5','10','20'])

# fig,subs = plt.subplots(3,3)
# it = -1
# for i in plots:
#     for j in plots:
#         it += 1
#         subs[i_row[it]][i_col[it]].scatter(all_points_rs.loc[:,i].values, all_points_rs.loc[:,j].values, color=c1[it])
#         subs[i_row[it]][i_col[it]].set_xlabel(i+' (Mt)')
#         subs[i_row[it]][i_col[it]].set_ylabel(j+' (Mt)')
#         subs[i_row[it]][i_col[it]].set_title(' '.join(j.split()[1:]).title()+' vs. '+' '.join(i.split()[1:]).title())

# fig,subs = plt.subplots(3,3)
# it = -1
# for i in plots:
#     for j in plots:
#         it += 1
#         subs[i_row[it]][i_col[it]].scatter(all_points_rs.loc[:,i].values, (all_points_rs.loc[:,j]/all_points_rs.loc[:,plots[0]]).values, color=c1[it])
#         subs[i_row[it]][i_col[it]].set_xlabel(i+' (Mt)')
#         subs[i_row[it]][i_col[it]].set_ylabel(j+'-based displacement')
#         subs[i_row[it]][i_col[it]].set_title(' '.join(j.split()[1:]).title()+'-Based\nDisplacement vs. '+' '.join(i.split()[1:]).title())

# Values, same but colors
fig,subs = plt.subplots(3,3)
it = -1
i_it = -1
j_it = -1
for i in plots:
    i_it += 1
    if i_it == 3:
        i_it = 0
    for j in plots:
        it += 1
        j_it += 1
        if j_it == 3:
            j_it = 0
        for k in all_points.columns.levels[1]:
            for m in all_points.columns.levels[2]:
                subs[i_row[it]][i_col[it]].scatter(all_points.loc[:,idx[i,k,m]].values, all_points.loc[:,idx[j,k,m]].values, color = pct_colors.loc[k,m])
#                 subs[i_row[it]][i_col[it]].scatter(all_points.index, all_points.loc[:,idx[j,k,m]].values, color = pct_colors.loc[k,m])
            y = all_points.loc[:,idx[j,k,:]].values
            y = y.reshape(y.size,1)
            x = all_points.loc[:,idx[i,k,:]].values
            x = x.reshape(x.size,1)
            X = sm.add_constant(x)
            mod = sm.OLS(y, X).fit()
            Y = mod.params[0]+mod.params[1]*x
            subs[i_row[it]][i_col[it]].plot(x[Y>0], Y[Y>0], color=pct_colors.loc[k,'10'],alpha=0.5)

        subs[i_row[it]][i_col[it]].set_xlabel(plot_labels[i_it]+' (Mt)')
#         subs[i_row[it]][i_col[it]].set_xlabel('Year')
        subs[i_row[it]][i_col[it]].set_ylabel(plot_labels[j_it]+' (Mt)')
        subs[i_row[it]][i_col[it]].set_title(plot_titles[j_it]+' vs. '+plot_titles[i_it])
#         subs[i_row[it]][i_col[it]].set_ylim(subs[i_row[it]][i_col[it]].get_ylim()[0],subs[i_row[it]][i_col[it]].get_ylim()[1]/4)
#         subs[i_row[it]][i_col[it]].set_xlim(subs[i_row[it]][i_col[it]].get_xlim()[0],subs[i_row[it]][i_col[it]].get_xlim()[1]/4)

# Displacement, same but colors
fig,subs = plt.subplots(3,3)
it = -1
i_it = -1
j_it = -1
for i in plots:
    i_it += 1
    if i_it == 3:
        i_it = 0
    for j in disp_plots:
        it += 1
        j_it += 1
        if j_it == 3:
            j_it = 0
        for k in all_points.columns.levels[1]:
            for m in all_points.columns.levels[2]:
                subs[i_row[it]][i_col[it]].scatter(all_points.loc[:,idx[i,k,m]], (all_points.loc[:,idx[j,k,m]]), color = pct_colors.loc[k,m])
#                 subs[i_row[it]][i_col[it]].scatter(all_points.index, (all_points.loc[:,idx[j,k,m]]/all_points.loc[:,idx[plots[0],k,m]].values), color = pct_colors.loc[k,m])
            y = all_points.loc[:,idx[j,k,:]].values
            y = y.reshape(y.size,1)
            x = all_points.loc[:,idx[i,k,:]].values
            x = x.reshape(x.size,1)
            X = sm.add_constant(x)
            mod = sm.OLS(y, X).fit()
            Y = mod.params[0]+mod.params[1]*x
            subs[i_row[it]][i_col[it]].plot(x[Y>0], Y[Y>0], color=pct_colors.loc[k,'10'],alpha=0.5)

        subs[i_row[it]][i_col[it]].set_xlabel(plot_labels[i_it]+' (Mt)')
#         subs[i_row[it]][i_col[it]].set_xlabel('Year')
        subs[i_row[it]][i_col[it]].set_ylabel(disp_plots[j_it])
        subs[i_row[it]][i_col[it]].set_title(disp_plots[j_it]+'\nvs. '+plot_titles[i_it])
#         subs[i_row[it]][i_col[it]].set_ylim(subs[i_row[it]][i_col[it]].get_ylim()[0],subs[i_row[it]][i_col[it]].get_ylim()[1]/4)
#         subs[i_row[it]][i_col[it]].set_xlim(subs[i_row[it]][i_col[it]].get_xlim()[0],subs[i_row[it]][i_col[it]].get_xlim()[1]/4)

# init_plot()
# plt.figure()
# ind = all_points_rs.loc[:,'Cumulative scrap supply increase']<15
# plt.scatter(all_points_rs.loc[ind,'Cumulative scrap supply increase'].values, all_points_rs.loc[ind,'Cumulative mining reduction'].values)
# plt.xlabel('Cumulative scrap supply increase (Mt)')
# plt.ylabel('Cumulative mining reduction (Mt)')
# plt.title('Mining reduction vs. scrap supply increase, starting in 2021\nfor shock values under 15 Mt')

init_plot()
plt.figure()
plt.scatter((all_points_rs.loc[:,plots[1]]/all_points_rs.loc[:,plots[0]]).values,
           (all_points_rs.loc[:,plots[2]]/all_points_rs.loc[:,plots[0]]).values)
plt.ylabel('CO2 emissions-based displacement')
plt.xlabel('Mining-based displacement')
plt.show()

init_plot()
plt.figure()
for k in all_points.columns.levels[1]:
    for m in all_points.columns.levels[2]:
        plt.scatter(all_points.loc[:,idx[plots[1],k,m]]/all_points.loc[:,idx[plots[0],k,m]].values, 
                                           all_points.loc[:,idx[plots[2],k,m]]/all_points.loc[:,idx[plots[0],k,m]].values, color = pct_colors.loc[k,m])
plt.ylabel('$CO_2$ emissions-based displacement')
plt.xlabel('Mining-based displacement')
plt.show()   

init_plot()
plt.figure()
for k in all_points.columns.levels[1]:
    for m in all_points.columns.levels[2]:
#         plt.scatter(all_points.loc[:,idx[plots[0],k,m]].values, 
#                     all_points.loc[:,idx[plots[2],k,m]]/all_points.loc[:,idx[plots[1],k,m]].values, color = pct_colors.loc[k,m])
        plt.scatter(all_points.index, 
                    all_points.loc[:,idx[plots[2],k,m]]/all_points.loc[:,idx[plots[1],k,m]].values, color = pct_colors.loc[k,m])
plt.ylabel('kt $CO_2$ emissions reduced per kt mining reduced')
plt.xlabel('Cumulative scrap supply increase (Mt)')
plt.ylim(0,25)
plt.show()

# %%
init_plot(fontsize=14,figwidth=24,figheight=24)
i_row = [0,0,0,1,1,1,2,2,2]
i_col = [0,1,2,0,1,2,0,1,2]
plots = ['Cumulative scrap supply increase','Cumulative mining reduction','Cumulative $CO_2$ emissions reduction']
disp_plots = all_points_rs.columns[3:]
plot_titles = ['Scrap Supply Increase','Mining Reduction','$CO_2$ Emissions Reduction']
plot_labels = ['Cumulative scrap supply increase','Cumulative mining reduction','Cumulative $CO_2$ emissions reduction']
disp_plot_labels = ['Scrap supply increase','Mining reduction','$CO_2$ emissions reduction']
pct_colors = pd.DataFrame([['#bdd7e7','#6baed6','#3182bd','#08519c'],
              ['#bae4b3','#74c476','#31a354','#006d2c'],
              ['#cccccc','#969696','#636363','#252525'],
              ['#fcae91','#fb6a4a','#de2d26','#a50f15']], 
             index=['10%','20%','50%','100%'], columns=['1','5','10','20'])

# fig,subs = plt.subplots(3,3)
# it = -1
# for i in plots:
#     for j in plots:
#         it += 1
#         subs[i_row[it]][i_col[it]].scatter(all_points_rs.loc[:,i].values, all_points_rs.loc[:,j].values, color=c1[it])
#         subs[i_row[it]][i_col[it]].set_xlabel(i+' (Mt)')
#         subs[i_row[it]][i_col[it]].set_ylabel(j+' (Mt)')
#         subs[i_row[it]][i_col[it]].set_title(' '.join(j.split()[1:]).title()+' vs. '+' '.join(i.split()[1:]).title())

# fig,subs = plt.subplots(3,3)
# it = -1
# for i in plots:
#     for j in plots:
#         it += 1
#         subs[i_row[it]][i_col[it]].scatter(all_points_rs.loc[:,i].values, (all_points_rs.loc[:,j]/all_points_rs.loc[:,plots[0]]).values, color=c1[it])
#         subs[i_row[it]][i_col[it]].set_xlabel(i+' (Mt)')
#         subs[i_row[it]][i_col[it]].set_ylabel(j+'-based displacement')
#         subs[i_row[it]][i_col[it]].set_title(' '.join(j.split()[1:]).title()+'-Based\nDisplacement vs. '+' '.join(i.split()[1:]).title())

# Values, same but colors
fig,subs = plt.subplots(3,3)
it = -1
i_it = -1
j_it = -1
for i in plots:
    i_it += 1
    if i_it == 3:
        i_it = 0
    for j in plots:
        it += 1
        j_it += 1
        if j_it == 3:
            j_it = 0
        for k in all_points.columns.levels[1]:
            for m in all_points.columns.levels[2]:
#                 subs[i_row[it]][i_col[it]].scatter(all_points.loc[:,idx[i,k,m]].values, all_points.loc[:,idx[j,k,m]].values, color = pct_colors.loc[k,m])
                subs[i_row[it]][i_col[it]].scatter(all_points.index, all_points.loc[:,idx[j,k,m]].values, color = pct_colors.loc[k,m])
#             y = all_points.loc[:,idx[j,k,:]].values
#             y = y.reshape(y.size,1)
#             x = all_points.loc[:,idx[i,k,:]].values
#             x = x.reshape(x.size,1)
#             X = sm.add_constant(x)
#             mod = sm.OLS(y, X).fit()
#             Y = mod.params[0]+mod.params[1]*x
#             subs[i_row[it]][i_col[it]].plot(x[Y>0], Y[Y>0], color=pct_colors.loc[k,'10'],alpha=0.5)

#         subs[i_row[it]][i_col[it]].set_xlabel(plot_labels[i_it]+' (Mt)')
        subs[i_row[it]][i_col[it]].set_xlabel('Year')
        subs[i_row[it]][i_col[it]].set_ylabel(plot_labels[j_it]+' (Mt)')
        subs[i_row[it]][i_col[it]].set_title(plot_titles[j_it]+' vs. '+plot_titles[i_it])
#         subs[i_row[it]][i_col[it]].set_ylim(subs[i_row[it]][i_col[it]].get_ylim()[0],subs[i_row[it]][i_col[it]].get_ylim()[1]/4)
#         subs[i_row[it]][i_col[it]].set_xlim(subs[i_row[it]][i_col[it]].get_xlim()[0],subs[i_row[it]][i_col[it]].get_xlim()[1]/4)

# Displacement, same but colors
fig,subs = plt.subplots(3,3)
it = -1
i_it = -1
j_it = -1
for i in plots:
    i_it += 1
    if i_it == 3:
        i_it = 0
    for j in disp_plots:
        it += 1
        j_it += 1
        if j_it == 3:
            j_it = 0
        for k in all_points.columns.levels[1]:
            for m in all_points.columns.levels[2]:
#                 subs[i_row[it]][i_col[it]].scatter(all_points.loc[:,idx[i,k,m]], (all_points.loc[:,idx[j,k,m]]), color = pct_colors.loc[k,m])
                subs[i_row[it]][i_col[it]].scatter(np.arange(2018,2041), (all_points.loc[:,idx[j,k,m]]), color = pct_colors.loc[k,m])
            y = all_points.loc[:,idx[j,k,:]].values
            y = y.reshape(y.size,1)
            x = all_points.loc[:,idx[i,k,:]].values
            x = np.repeat(np.arange(2018,2041),4)
            x = x.reshape(x.size,1)
            X = sm.add_constant(x)
            mod = sm.OLS(y, X).fit()
            Y = mod.params[0]+mod.params[1]*x
            subs[i_row[it]][i_col[it]].plot(x[Y>0], Y[Y>0], color=pct_colors.loc[k,'10'],alpha=0.5)

#         subs[i_row[it]][i_col[it]].set_xlabel(plot_labels[i_it]+' (Mt)')
        subs[i_row[it]][i_col[it]].set_xlabel('Year')
        subs[i_row[it]][i_col[it]].set_ylabel(disp_plots[j_it])
        subs[i_row[it]][i_col[it]].set_title(disp_plots[j_it]+'\nvs. Time')#+plot_titles[i_it])
#         subs[i_row[it]][i_col[it]].set_ylim(subs[i_row[it]][i_col[it]].get_ylim()[0],subs[i_row[it]][i_col[it]].get_ylim()[1]/4)
#         subs[i_row[it]][i_col[it]].set_xlim(subs[i_row[it]][i_col[it]].get_xlim()[0],subs[i_row[it]][i_col[it]].get_xlim()[1]/4)

# init_plot()
# plt.figure()
# ind = all_points_rs.loc[:,'Cumulative scrap supply increase']<15
# plt.scatter(all_points_rs.loc[ind,'Cumulative scrap supply increase'].values, all_points_rs.loc[ind,'Cumulative mining reduction'].values)
# plt.xlabel('Cumulative scrap supply increase (Mt)')
# plt.ylabel('Cumulative mining reduction (Mt)')
# plt.title('Mining reduction vs. scrap supply increase, starting in 2021\nfor shock values under 15 Mt')

init_plot()
plt.figure()
plt.scatter((all_points_rs.loc[:,plots[1]]/all_points_rs.loc[:,plots[0]]).values,
           (all_points_rs.loc[:,plots[2]]/all_points_rs.loc[:,plots[0]]).values)
plt.ylabel('CO2 emissions-based displacement')
plt.xlabel('Mining-based displacement')
plt.show()

init_plot()
plt.figure()
for k in all_points.columns.levels[1]:
    for m in all_points.columns.levels[2]:
        plt.scatter(all_points.loc[:,idx[plots[1],k,m]]/all_points.loc[:,idx[plots[0],k,m]].values, 
                                           all_points.loc[:,idx[plots[2],k,m]]/all_points.loc[:,idx[plots[0],k,m]].values, color = pct_colors.loc[k,m])
plt.ylabel('$CO_2$ emissions-based displacement')
plt.xlabel('Mining-based displacement')
plt.show()   

init_plot()
plt.figure()
for k in all_points.columns.levels[1]:
    for m in all_points.columns.levels[2]:
#         plt.scatter(all_points.loc[:,idx[plots[0],k,m]].values, 
#                     all_points.loc[:,idx[plots[2],k,m]]/all_points.loc[:,idx[plots[1],k,m]].values, color = pct_colors.loc[k,m])
        plt.scatter(all_points.index, 
                    all_points.loc[:,idx[plots[2],k,m]]/all_points.loc[:,idx[plots[1],k,m]].values, color = pct_colors.loc[k,m])
plt.ylabel('kt $CO_2$ emissions reduced per kt mining reduced')
plt.xlabel('Cumulative scrap supply increase (Mt)')
plt.ylim(0,25)
plt.show()

# %%
subs[0]

# %% [markdown]
# ### Fruity environmental impacts

# %%
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':] - sp2_series_fruity1rr0var0_gl.loc['20180101':], label = 'None', color='k')
plt.plot(cathode_price_series_fruity1rr100var0.loc['20180101':] - sp2_series_fruity1rr100var0_gl.loc['20180101':], label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':] - sp2_series_fruity1rr100var30_gl.loc['20180101':], label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':] - sp2_series_fruity1rr100var70_gl.loc['20180101':], label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var90.loc['20180101':] - sp2_series_fruity1rr100var90_gl.loc['20180101':], label = 'None', color=colors[3])

plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':] - sp2_series_fruity_pct10rr0_1_gl.loc['20180101':], label = 'None', color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':] - sp2_series_fruity_pct10rr50var10_gl.loc['20180101':], label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':] - sp2_series_fruity_pct10rr50var30_gl.loc['20180101':], label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':] - sp2_series_fruity_pct10rr50var50_gl.loc['20180101':], label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':] - sp2_series_fruity_pct10rr50var70_gl.loc['20180101':], label = 'None', color=colors[3])
'blend fruity 10 pct rr0_1'
'blend fruity 10 pct rr50 var30'
'blend fruity times 1 rr0 20200513'
'blend fruity times 1 rr100 var70 20200513'

# %%
# 0.08% of market
file_name = 'blend fruity times 1 rr0 20200513'
mine_life_stats_fruity1rr0var0 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_fruity1rr0var0, unit_impacts_fruity1rr0var0, quantities_fruity1rr0var0 = calculate_impacts(
    sd_fruity1rr0var0_cn, sd_fruity1rr0var0_rw, sd_fruity1rr0var0, mine_life_stats_fruity1rr0var0,
    direct_melt_demand_fruity1rr0var0_cn, direct_melt_demand_fruity1rr0var0_rw)

file_name = 'blend fruity times 1 rr100 var10 20200513'
mine_life_stats_fruity1rr100var10 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_fruity1rr100var10, unit_impacts_fruity1rr100var10, quantities_fruity1rr100var10 = calculate_impacts(
    sd_fruity1rr100var10_cn, sd_fruity1rr100var10_rw, sd_fruity1rr100var10, mine_life_stats_fruity1rr100var10,
    direct_melt_demand_fruity1rr100var10_cn, direct_melt_demand_fruity1rr100var10_rw)
impact_change_fruity1rr100var10 = total_impacts_fruity1rr100var10 - total_impacts_fruity1rr0var0
quantity_change_fruity1rr100var10 = quantities_fruity1rr100var10 - quantities_fruity1rr0var0

file_name = 'blend fruity times 1 rr100 var30 20200513'
mine_life_stats_fruity1rr100var30 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_fruity1rr100var30, unit_impacts_fruity1rr100var30, quantities_fruity1rr100var30 = calculate_impacts(
    sd_fruity1rr100var30_cn, sd_fruity1rr100var30_rw, sd_fruity1rr100var30, mine_life_stats_fruity1rr100var30,
    direct_melt_demand_fruity1rr100var30_cn, direct_melt_demand_fruity1rr100var30_rw)
impact_change_fruity1rr100var30 = total_impacts_fruity1rr100var30 - total_impacts_fruity1rr0var0
quantity_change_fruity1rr100var30 = quantities_fruity1rr100var30 - quantities_fruity1rr0var0

file_name = 'blend fruity times 1 rr100 var50 20200513'
mine_life_stats_fruity1rr100var50 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_fruity1rr100var50, unit_impacts_fruity1rr100var50, quantities_fruity1rr100var50 = calculate_impacts(
    sd_fruity1rr100var50_cn, sd_fruity1rr100var50_rw, sd_fruity1rr100var50, mine_life_stats_fruity1rr100var50,
    direct_melt_demand_fruity1rr100var50_cn, direct_melt_demand_fruity1rr100var50_rw)
impact_change_fruity1rr100var50 = total_impacts_fruity1rr100var50 - total_impacts_fruity1rr0var0
quantity_change_fruity1rr100var50 = quantities_fruity1rr100var50 - quantities_fruity1rr0var0

file_name = 'blend fruity times 1 rr100 var70 20200513'
mine_life_stats_fruity1rr100var70 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_fruity1rr100var70, unit_impacts_fruity1rr100var70, quantities_fruity1rr100var70 = calculate_impacts(
    sd_fruity1rr100var70_cn, sd_fruity1rr100var70_rw, sd_fruity1rr100var70, mine_life_stats_fruity1rr100var70,
    direct_melt_demand_fruity1rr100var70_cn, direct_melt_demand_fruity1rr100var70_rw)
impact_change_fruity1rr100var70 = total_impacts_fruity1rr100var70 - total_impacts_fruity1rr0var0
quantity_change_fruity1rr100var70 = quantities_fruity1rr100var70 - quantities_fruity1rr0var0

# 10% of market
file_name = 'blend fruity 10 pct rr0_1'
mine_life_stats_fruity_pct10rr0var0 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_fruity_pct10rr0var0, unit_impacts_fruity_pct10rr0var0, quantities_fruity_pct10rr0var0 = calculate_impacts(
    sd_fruity_pct10rr0_1_cn, sd_fruity_pct10rr0_1_rw, sd_fruity_pct10rr0_1, mine_life_stats_fruity_pct10rr0var0,
    direct_melt_demand_fruity_pct10rr0_1_cn, direct_melt_demand_fruity_pct10rr0_1_rw)

file_name = 'blend fruity 10 pct rr50 var10'
mine_life_stats_fruity_pct10rr50var10 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_fruity_pct10rr50var10, unit_impacts_fruity_pct10rr50var10, quantities_fruity_pct10rr50var10 = calculate_impacts(
    sd_fruity_pct10rr50var10_cn, sd_fruity_pct10rr50var10_rw, sd_fruity_pct10rr50var10, mine_life_stats_fruity_pct10rr50var10,
    direct_melt_demand_fruity_pct10rr50var10_cn, direct_melt_demand_fruity_pct10rr50var10_rw)
impact_change_fruity_pct10rr50var10 = total_impacts_fruity_pct10rr50var10 - total_impacts_fruity_pct10rr0var0
quantity_change_fruity_pct10rr50var10 = quantities_fruity_pct10rr50var10 - quantities_fruity_pct10rr0var0

file_name = 'blend fruity 10 pct rr50 var30'
mine_life_stats_fruity_pct10rr50var30 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_fruity_pct10rr50var30, unit_impacts_fruity_pct10rr50var30, quantities_fruity_pct10rr50var30 = calculate_impacts(
    sd_fruity_pct10rr50var30_cn, sd_fruity_pct10rr50var30_rw, sd_fruity_pct10rr50var30, mine_life_stats_fruity_pct10rr50var30,
    direct_melt_demand_fruity_pct10rr50var30_cn, direct_melt_demand_fruity_pct10rr50var30_rw)
impact_change_fruity_pct10rr50var30 = total_impacts_fruity_pct10rr50var30 - total_impacts_fruity_pct10rr0var0
quantity_change_fruity_pct10rr50var30 = quantities_fruity_pct10rr50var30 - quantities_fruity_pct10rr0var0

file_name = 'blend fruity 10 pct rr50 var50'
mine_life_stats_fruity_pct10rr50var50 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_fruity_pct10rr50var50, unit_impacts_fruity_pct10rr50var50, quantities_fruity_pct10rr50var50 = calculate_impacts(
    sd_fruity_pct10rr50var50_cn, sd_fruity_pct10rr50var50_rw, sd_fruity_pct10rr50var50, mine_life_stats_fruity_pct10rr50var50,
    direct_melt_demand_fruity_pct10rr50var50_cn, direct_melt_demand_fruity_pct10rr50var50_rw)
impact_change_fruity_pct10rr50var50 = total_impacts_fruity_pct10rr50var50 - total_impacts_fruity_pct10rr0var0
quantity_change_fruity_pct10rr50var50 = quantities_fruity_pct10rr50var50 - quantities_fruity_pct10rr0var0

file_name = 'blend fruity 10 pct rr50 var70'
mine_life_stats_fruity_pct10rr50var70 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_fruity_pct10rr50var70, unit_impacts_fruity_pct10rr50var70, quantities_fruity_pct10rr50var70 = calculate_impacts(
    sd_fruity_pct10rr50var70_cn, sd_fruity_pct10rr50var70_rw, sd_fruity_pct10rr50var70, mine_life_stats_fruity_pct10rr50var70,
    direct_melt_demand_fruity_pct10rr50var70_cn, direct_melt_demand_fruity_pct10rr50var70_rw)
impact_change_fruity_pct10rr50var70 = total_impacts_fruity_pct10rr50var70 - total_impacts_fruity_pct10rr0var0
quantity_change_fruity_pct10rr50var70 = quantities_fruity_pct10rr50var70 - quantities_fruity_pct10rr0var0

print(str(datetime.now()))

# %%
quantities_fruity_pct10rr50var70

# %% [markdown]
# Quantities for the somewhat anomalous 10%, max 30% reduction in recycled content scenario, since mining increases pretty substantially but overall demand decreases

# %%
quant_ph = pd.DataFrame(0,index = quantity_change_fruity_pct10rr50var70.loc['20180101':].index.levels[0],columns=quantity_change_fruity_pct10rr50var70.loc['20180101':].index.levels[1])
for i in quant_ph.loc['20180101':].index:
    quant_ph.loc[i,:] = quantity_change_fruity_pct10rr50var70.sum(axis=1).loc[i]
quant_ph = quant_ph.cumsum()/1000
plt.stackplot(quant_ph.loc['20180101':].index,quant_ph[quant_ph>0].fillna(0).loc['20180101':].T,labels=quant_ph.columns)
# plt.legend(loc='lower left',fontsize=12)
plt.stackplot(quant_ph.loc['20180101':].index,quant_ph[quant_ph<0].fillna(0).loc['20180101':].T,labels=quant_ph.columns)
plt.ylabel('Change in Quantity (Mt)')
plt.title('Change in Quantity for Each Environmental Impact Sector')
plt.show()

# %%
c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
c2 = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd']
c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2']
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4)
ph_series1 = pd.DataFrame(0, index = impact_change_fruity1rr100var10.index.levels[0], columns = impact_change_fruity1rr100var10.columns.levels[1])
ph_series2 = pd.DataFrame(0, index = impact_change_fruity1rr100var10.index.levels[0], columns = impact_change_fruity1rr100var10.columns.levels[1])
ph_series3 = pd.DataFrame(0, index = impact_change_fruity1rr100var10.index.levels[0], columns = impact_change_fruity1rr100var10.columns.levels[1])
# ['Global warming (kt CO2 eq)']:
# for metric in impact_change_fruity1rr100var10.index.levels[1]:
for metric in ['Global warming (kt CO2 eq)','Total energy (GJ)', 'Water use (ML)']:
    ph_series1var10,ph_series2,ph_series3 = pct_inc(impact_change_fruity1rr100var10,metric,baseline=total_impacts_fruity1rr0var0)
    ph_series1var30,ph_series2,ph_series3 = pct_inc(impact_change_fruity1rr100var30,metric,baseline=total_impacts_fruity1rr0var0)
    ph_series1var50,ph_series2,ph_series3 = pct_inc(impact_change_fruity1rr100var50,metric,baseline=total_impacts_fruity1rr0var0)
    ph_series1var70,ph_series2,ph_series3 = pct_inc(impact_change_fruity1rr100var70,metric,baseline=total_impacts_fruity1rr0var0)
    
    ph_series10var10,ph_series2,ph_series3 = pct_inc(impact_change_fruity_pct10rr50var10,metric,baseline=total_impacts_fruity_pct10rr0var0)
    ph_series10var30,ph_series2,ph_series3 = pct_inc(impact_change_fruity_pct10rr50var30,metric,baseline=total_impacts_fruity_pct10rr0var0)
    ph_series10var50,ph_series2,ph_series3 = pct_inc(impact_change_fruity_pct10rr50var50,metric,baseline=total_impacts_fruity_pct10rr0var0)
    ph_series10var70,ph_series2,ph_series3 = pct_inc(impact_change_fruity_pct10rr50var70,metric,baseline=total_impacts_fruity_pct10rr0var0)
    
    init_plot(figwidth=24)
    fig,[ax1,ax2,ax3,ax4] = plt.subplots(1,4, sharey=True)
    init_plot(figwidth=24,ax=ax1)
    init_plot(figwidth=24,ax=ax2)
    init_plot(figwidth=24,ax=ax3)
    init_plot(figwidth=24,ax=ax4)

    ax1.stackplot(ph_series10var10.loc['20180101':,:].index, ph_series10var10[ph_series10var10>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series10var10.columns)
#     ax1.legend()
    ax1.stackplot(ph_series10var10.loc['20180101':,:].index, ph_series10var10[ph_series10var10<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series10var10.columns)
    ax1.plot(ph_series10var10.loc['20180101':].sum(axis=1),linewidth=4,color=colors[0])    

    ax2.stackplot(ph_series10var30.loc['20180101':,:].index, ph_series10var30[ph_series10var30>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series10var30.columns)
    #     ax2.legend()
    ax2.stackplot(ph_series10var30.loc['20180101':,:].index, ph_series10var30[ph_series10var30<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series10var30.columns)
    ax2.plot(ph_series10var30.loc['20180101':].sum(axis=1),linewidth=4,color=colors[1])

    ax3.stackplot(ph_series10var50.loc['20180101':,:].index, ph_series10var50[ph_series10var50>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series10var50.columns)
    #     ax3.legend()
    ax3.stackplot(ph_series10var50.loc['20180101':,:].index, ph_series10var50[ph_series10var50<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series10var50.columns)
    ax3.plot(ph_series10var50.loc['20180101':].sum(axis=1),linewidth=4,color=colors[2])

    ax4.stackplot(ph_series10var70.loc['20180101':,:].index, ph_series10var70[ph_series10var70>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series10var70.columns)
    #     ax4.legend()
    ax4.stackplot(ph_series10var70.loc['20180101':,:].index, ph_series10var70[ph_series10var70<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series10var70.columns)
    ax4.plot(ph_series10var70.loc['20180101':].sum(axis=1),linewidth=4,color=colors[3])

    ax1.set_title('Change in '+metric.split('(')[0].title()+'Impacts')
    ax2.set_title('Change in '+metric.split('(')[0].title()+'Impacts')
    ax3.set_title('Change in '+metric.split('(')[0].title()+'Impacts')
    ax4.set_title('Change in '+metric.split('(')[0].title()+'Impacts')
#     fig.suptitle('10% of Copper Market',color=color_10)
    ax1.set_ylabel('Cumulative increase, % of 2020 value')
    ax2.set_ylabel('Cumulative increase, % of 2020 value')
    ax3.set_ylabel('Cumulative increase, % of 2020 value')
    ax4.set_ylabel('Cumulative increase, % of 2020 value')
    plt.tight_layout()
    plt.show()
    ylims = ax1.get_ylim()
    
    fig,[ax1,ax2,ax3,ax4] = plt.subplots(1,4, sharey=True)
    init_plot(figwidth=24,ax=ax1)
    init_plot(figwidth=24,ax=ax2)
    init_plot(figwidth=24,ax=ax3)
    init_plot(figwidth=24,ax=ax4)
    
    ax1.stackplot(ph_series1var10.loc['20180101':,:].index, ph_series1var10[ph_series1var10>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1var10.columns)
#     ax1.legend()
    ax1.stackplot(ph_series1var10.loc['20180101':,:].index, ph_series1var10[ph_series1var10<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1var10.columns)
    ax1.plot(ph_series1var10.loc['20180101':].sum(axis=1),linewidth=4,color=colors[0])    
    
    ax2.stackplot(ph_series1var30.loc['20180101':,:].index, ph_series1var30[ph_series1var30>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1var30.columns)
#     ax2.legend()
    ax2.stackplot(ph_series1var30.loc['20180101':,:].index, ph_series1var30[ph_series1var30<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1var30.columns)
    ax2.plot(ph_series1var30.loc['20180101':].sum(axis=1),linewidth=4,color=colors[1])
    
    ax3.stackplot(ph_series1var50.loc['20180101':,:].index, ph_series1var50[ph_series1var50>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1var50.columns)
#     ax3.legend()
    ax3.stackplot(ph_series1var50.loc['20180101':,:].index, ph_series1var50[ph_series1var50<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1var50.columns)
    ax3.plot(ph_series1var50.loc['20180101':].sum(axis=1),linewidth=4,color=colors[2])

    ax4.stackplot(ph_series1var70.loc['20180101':,:].index, ph_series1var70[ph_series1var70>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1var70.columns)
#     ax4.legend()
    ax4.stackplot(ph_series1var70.loc['20180101':,:].index, ph_series1var70[ph_series1var70<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series1var70.columns)
    ax4.plot(ph_series1var70.loc['20180101':].sum(axis=1),linewidth=4,color=colors[3])

    ax1.set_title('Change in '+metric.split('(')[0].title()+'Impacts')
    ax2.set_title('Change in '+metric.split('(')[0].title()+'Impacts')
    ax3.set_title('Change in '+metric.split('(')[0].title()+'Impacts')
    ax4.set_title('Change in '+metric.split('(')[0].title()+'Impacts')
#     fig.suptitle('0.08% of Copper Market',color=color_08)
    ax1.set_ylabel('Cumulative increase, % of 2020 value')
    ax2.set_ylabel('Cumulative increase, % of 2020 value')
    ax3.set_ylabel('Cumulative increase, % of 2020 value')
    ax4.set_ylabel('Cumulative increase, % of 2020 value')
    ax1.set_ylim(ylims)
    ax2.set_ylim(ylims)
    ax3.set_ylim(ylims)
    ax4.set_ylim(ylims)
    plt.tight_layout()
    plt.show()
    plt.close()
    
    
    init_plot(figwidth=8)
    plt.figure()
    init_plot(figwidth=8)
    plt.plot(ph_series10var10.loc['20180101':].sum(axis=1),color=colors[0])
    plt.plot(ph_series10var30.loc['20180101':].sum(axis=1),color=colors[1])
    plt.plot(ph_series10var50.loc['20180101':].sum(axis=1),color=colors[2])
    plt.plot(ph_series10var70.loc['20180101':].sum(axis=1),color=colors[3])
    plt.suptitle('Global Change in '+metric.split('(')[0].title()+'Impacts')
    plt.title('10% of Copper Market',color=color_10)
#     plt.tight_layout()
    plt.ylim(min(ph_series10var70.sum(axis=1).values)*1.1,max(ph_series1var70.sum(axis=1).values)*1.1)
    
    plt.figure()
    init_plot(figwidth=8)
    plt.plot(ph_series1var10.loc['20180101':].sum(axis=1),color=colors[0])
    plt.plot(ph_series1var30.loc['20180101':].sum(axis=1),color=colors[1])
    plt.plot(ph_series1var50.loc['20180101':].sum(axis=1),color=colors[2])
    plt.plot(ph_series1var70.loc['20180101':].sum(axis=1),color=colors[3])
    plt.suptitle('Global Change in '+metric.split('(')[0].title()+'Impacts')
    plt.title('0.08% of Copper Market',color=color_08)
    plt.ylim(min(ph_series10var70.sum(axis=1).values)*1.1,max(ph_series1var70.sum(axis=1).values)*1.1)
#     plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Fruity Presentation Rebound

# %%
sd_fruity_pct10rr0_1.columns

# %%
init_plot(figwidth=16)
fig,[ax1,ax2] = plt.subplots(1,2,sharey=False)
# ax1.plot(mining_pctinc2020_fruity_pct10rr50.loc['20180101':])
cathode_price_series_pctinc2020_fruity_pct10rr50var70 = (cathode_price_series_fruity_pct10rr50var70-cathode_price_series_fruity_pct10rr0_1)/cathode_price_series_fruity_pct10rr0_1.loc['20200101']*100
cathode_price_series_pctinc2020_fruity_pct10rr50var701 = (cathode_price_series_fruity_pct10rr50var70/cathode_price_series_fruity_pct10rr0_1.loc['20180101']-1)*100
scrap_price_series_pctinc2020_fruity_pct10rr50var70 = -(sp2_series_fruity_pct10rr50var70_gl-sp2_series_fruity_pct10rr0_1_gl)/(cathode_price_series_fruity_pct10rr0_1.loc['20200101']-sp2_series_fruity_pct10rr0_1_gl.loc['20200101'])*100
scrap_price_series_pctinc2020_fruity_pct10rr50var70 = ((cathode_price_series_fruity_pct10rr50var70-sp2_series_fruity_pct10rr50var70_gl)/(cathode_price_series_fruity_pct10rr0_1.loc['20180101']-sp2_series_fruity_pct10rr0_1_gl.loc['20180101'])-1)*100
tcrc_series_pctinc2020_fruity_pct10rr50var70 = (tcrc_series_fruity_pct10rr50var70-tcrc_series_fruity_pct10rr0_1)/tcrc_series_fruity_pct10rr0_1.loc['20200101']*100
# tcrc_series_pctinc2020_fruity_pct10rr50var70 = (tcrc_series_fruity_pct10rr50var70/tcrc_series_fruity_pct10rr0_1.loc['20180101']-1)*100
tot_ref_pctinc2020_fruity_pct10rr50var70 = (sd_fruity_pct10rr50var70.loc[:,'Primary refining production':'SX-EW production.1'].sum(axis=1)-sd_fruity_pct10rr0_1.loc[:,'Primary refining production':'SX-EW production.1'].sum(axis=1)).cumsum()/sd_fruity_pct10rr0_1.loc['20200101','Primary refining production':'SX-EW production.1'].sum()*100
pri_ref_pctinc2020_fruity_pct10rr50var70 = (sd_fruity_pct10rr50var70.loc[:,'Primary refining production']-sd_fruity_pct10rr0_1.loc[:,'Primary refining production']).cumsum()/sd_fruity_pct10rr0_1.loc['20200101','Primary refining production']*100
sec_ref_pctinc2020_fruity_pct10rr50var70 = (sd_fruity_pct10rr50var70.loc[:,'Secondary refining production']-sd_fruity_pct10rr0_1.loc[:,'Secondary refining production']).cumsum()/sd_fruity_pct10rr0_1.loc['20200101','Secondary refining production']*100
conc_pctinc2020_fruity_pct10rr50var70 = (sd_fruity_pct10rr50var70.loc[:,'Concentrate production']-sd_fruity_pct10rr0_1.loc[:,'Concentrate production']).cumsum()/sd_fruity_pct10rr0_1.loc['20200101','Concentrate production']*100
sxew_pctinc2020_fruity_pct10rr50var70 = (sd_fruity_pct10rr50var70.loc[:,'SX-EW production']-sd_fruity_pct10rr0_1.loc[:,'SX-EW production']).cumsum()/sd_fruity_pct10rr0_1.loc['20200101','SX-EW production']*100
ref_demand_pctinc2020_fruity_pct10rr50var70 = (direct_melt_demand_fruity_pct10rr50var70_gl.loc[:,'Ref_Cu'] - direct_melt_demand_fruity_pct10rr0_1_gl.loc[:,'Ref_Cu']).cumsum()/direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1).loc['20200101']*100
tot_demand_pctinc2020_fruity_pct10rr50var70 = (direct_melt_demand_fruity_pct10rr50var70_gl.sum(axis=1) - direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1)).cumsum()/direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1).loc['20200101']*100
scrap_demand_pctinc2020_fruity_pct10rr50var70 = (direct_melt_demand_fruity_pct10rr50var70_gl.loc[:,'Yellow_Brass':].sum(axis=1) - direct_melt_demand_fruity_pct10rr0_1_gl.loc[:,'Yellow_Brass':].sum(axis=1)).cumsum()/direct_melt_demand_fruity_pct10rr0_1_gl.sum(axis=1).loc['20200101']*100

ax1.plot(mining_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Mining Response', color=colors[0])
# ax1.plot(conc_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Concentrate Response')
# ax1.plot(sxew_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='SX-EW Response')
ax1.plot(cathode_price_series_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Cathode Price', color=colors[1])
ax1.plot(tcrc_series_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='TCRC Response', color=colors[2])
ax2.plot(scrap_price_series_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='No.2 Scrap Price')
ax1.plot(tot_ref_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Refinery Response', color=colors[3])
ax2.plot(tot_ref_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Refinery Response')
ax2.plot(ref_demand_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Refined Demand Response')
ax2.plot(tot_demand_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Total Demand Response')
# ax2.plot(scrap_demand_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Direct Melt Response')

ax1.set_title('System Propagation')
ax1.set_ylabel('Percent increase above 2020 value')
# ax1.legend()
ax2.legend()
print('The cathode price increase is equivalent to reaching two spikes where price is 10% above 2020 value,')
print('where in the base case there are two price spikes of 9 and 14% above 2020 value. This scenario represents')
print('a 4% increase then 4% decrease of those two spikes')

fig,[ax1,ax2] = plt.subplots(1,2,sharey=False)
ax1.plot(scrap_price_series_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='No.2 Scrap Price')
ax1.plot(cathode_price_series_pctinc2020_fruity_pct10rr50var701.loc['20180101':],label='Cathode Price')
ax1.plot(tot_ref_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Refinery Response')
ax1.plot(pri_ref_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Pri Refinery Response')
ax1.plot(sec_ref_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Sec Refinery Response')
ax1.plot(mining_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Mining Response')
ax1.set_ylim(-9,ax1.get_ylim()[1])
ax1.legend()

tot_ref_pctinc2020_fruity_pct10rr50var70 = (sd_fruity_pct10rr50var70.loc[:,'Primary refining production':'SX-EW production.1'].sum(axis=1))
ref_demand_pctinc2020_fruity_pct10rr50var70 = (direct_melt_demand_fruity_pct10rr50var70_gl.loc[:,'Ref_Cu'])
ax2.plot(tot_ref_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Refinery Response',color=color_10)
ax2.plot(ref_demand_pctinc2020_fruity_pct10rr50var70.loc['20180101':],label='Refined Demand Response',color=color_08)
ax2.legend()
plt.show()
# ax1.plot(cathode_price_series_pctinc2020_fruity_pct10rr50.loc['20180101':])

# %%
(sp2_series_fruity_pct10rr50var70_gl-sp2_series_fruity_pct10rr0_1_gl).loc['20170101':]

# %% [markdown]
# # Visual analysis

# %% [markdown]
# ## S&D snalysis

# %%
sd_mining_baseline_baseline=sd_baseline_baseline.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_baseline=sd_baseline_baseline.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_baseline=sd_baseline_baseline.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_sm=sd_baseline_sm.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_sm=sd_baseline_sm.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_sm=sd_baseline_sm.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_lsm=sd_baseline_lsm.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_lsm=sd_baseline_lsm.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_lsm=sd_baseline_lsm.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_psm=sd_baseline_psm.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_psm=sd_baseline_psm.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_psm=sd_baseline_psm.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_rs10=sd_baseline_rs10.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_rs10=sd_baseline_rs10.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_rs10=sd_baseline_rs10.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_rs20=sd_baseline_rs20.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_rs20=sd_baseline_rs20.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_rs20=sd_baseline_rs20.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_rs50=sd_baseline_rs50.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_rs50=sd_baseline_rs50.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_rs50=sd_baseline_rs50.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_rs100=sd_baseline_rs100.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_rs100=sd_baseline_rs100.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_rs100=sd_baseline_rs100.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_prs10=sd_baseline_prs10.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_prs10=sd_baseline_prs10.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_prs10=sd_baseline_prs10.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_prs20=sd_baseline_prs20.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_prs20=sd_baseline_prs20.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_prs20=sd_baseline_prs20.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_prs50=sd_baseline_prs50.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_prs50=sd_baseline_prs50.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_prs50=sd_baseline_prs50.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_prs100=sd_baseline_prs100.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_prs100=sd_baseline_prs100.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_prs100=sd_baseline_prs100.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_baseline_irs100=sd_baseline_irs100.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_baseline_irs100=sd_baseline_irs100.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_baseline_irs100=sd_baseline_irs100.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_400_de_baseline=sd_400_de_baseline.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_400_de_baseline=sd_400_de_baseline.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_400_de_baseline=sd_400_de_baseline.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %%
sd_mining_john1=sd_john1.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_john1=sd_john1.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_john1=sd_john1.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

sd_mining_john5=sd_john5.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_john5=sd_john5.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_john5=sd_john5.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %% [markdown]
# ### S&D Data Import

# %%
sd_mining_scrapbal_noavail=sd_scrapbal_noavail.loc[:, ['Concentrate production', 'SX-EW production', 'Concentrate demand']]
sd_cathode_scrapbal_noavail=sd_scrapbal_noavail.loc[:, ['Primary refining production', 'Secondary refining production', 
                                                  'SX-EW production.1', 'Refined demand']]
sd_scrap_scrapbal_noavail=sd_scrapbal_noavail.loc[:, ['Scrap production', 'Direct melt scrap', 'Refined scrap']]

# %% [markdown]
# ### Mining S&D

# %%
# 
# 
plt.stackplot(sd_mining_scrapbal_noavail.iloc[10:, :2].index, sd_mining_scrapbal_noavail.iloc[10:, :2].transpose(), 
              labels=sd_mining_scrapbal_noavail.iloc[10:, :2].columns)
pplot(sd_mining_scrapbal_noavail.iloc[10:, 2], 'k', label='Concentrate consumption')

pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [20531, 25663], 'purple', label='Future mining benchmark')
pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [1000, 29000], 'k--')

plt.legend(loc=2)
plt.xlabel('Year')
plt.ylabel('Mining production and consumption (kt)')
plt.show()

# %% [markdown]
# ### Cathode S&D

# %%
pplot(100*(direct_melt_demand_fruity_pct10rr50var10_gl.loc['20190101':,'Ref_Cu'].cumsum() - direct_melt_demand_fruity_pct10rr0_1_gl.loc['20190101':,'Ref_Cu'].cumsum()) / direct_melt_demand_fruity_pct10rr0_1_gl.loc['20200101','Ref_Cu'], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(100*(direct_melt_demand_fruity_pct10rr50var30_gl.loc['20190101':,'Ref_Cu'].cumsum() - direct_melt_demand_fruity_pct10rr0_1_gl.loc['20190101':,'Ref_Cu'].cumsum()) / direct_melt_demand_fruity_pct10rr0_1_gl.loc['20200101','Ref_Cu'], label='10mrk% 50% RR, var30',color=colors[1])
pplot(100*(direct_melt_demand_fruity_pct10rr50var50_gl.loc['20190101':,'Ref_Cu'].cumsum() - direct_melt_demand_fruity_pct10rr0_1_gl.loc['20190101':,'Ref_Cu'].cumsum()) / direct_melt_demand_fruity_pct10rr0_1_gl.loc['20200101','Ref_Cu'], label='10mrk% 50% RR, var50',color=colors[2])
pplot(100*(direct_melt_demand_fruity_pct10rr50var70_gl.loc['20190101':,'Ref_Cu'].cumsum() - direct_melt_demand_fruity_pct10rr0_1_gl.loc['20190101':,'Ref_Cu'].cumsum()) / direct_melt_demand_fruity_pct10rr0_1_gl.loc['20200101','Ref_Cu'], label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
plt.yticks([0, -0.8,-1.6,-2.4])
# plt.ylim(-16,5)
plt.ylabel('Cathode demand response above baseline \n(% of 2020 production)')
plt.title('Global Cathode Demand Response above Baseline \n10% of Copper Market')

# %%
pplot(100*(direct_melt_demand_fruity1rr100var0_gl.loc['20190101':,'Ref_Cu'].cumsum() - direct_melt_demand_fruity1rr0var0_gl.loc['20190101':,'Ref_Cu'].cumsum()) / direct_melt_demand_fruity1rr0var0_gl.loc['20200101','Ref_Cu'], label='10mrk% 50% RR, var0',color=colors[0],firstcall=1)
pplot(100*(direct_melt_demand_fruity1rr100var30_gl.loc['20190101':,'Ref_Cu'].cumsum() - direct_melt_demand_fruity1rr0var0_gl.loc['20190101':,'Ref_Cu'].cumsum()) / direct_melt_demand_fruity1rr0var0_gl.loc['20200101','Ref_Cu'], label='10mrk% 50% RR, var30',color=colors[1])
pplot(100*(direct_melt_demand_fruity1rr100var70_gl.loc['20190101':,'Ref_Cu'].cumsum() - direct_melt_demand_fruity1rr0var0_gl.loc['20190101':,'Ref_Cu'].cumsum()) / direct_melt_demand_fruity1rr0var0_gl.loc['20200101','Ref_Cu'], label='10mrk% 50% RR, var70',color=colors[2])
pplot(100*(direct_melt_demand_fruity1rr100var90_gl.loc['20190101':,'Ref_Cu'].cumsum() - direct_melt_demand_fruity1rr0var0_gl.loc['20190101':,'Ref_Cu'].cumsum()) / direct_melt_demand_fruity1rr0var0_gl.loc['20200101','Ref_Cu'], label='10mrk% 50% RR, var90',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
plt.yticks([0, 0.8,1.6,2.4])
# plt.ylim(-16,5)
plt.ylabel('Cathode demand response above baseline \n(% of 2020 production)')
plt.title('Global Cathode Demand Response above Baseline \n0.08% of Copper Market')

# %%
# 
# 
plt.stackplot(sd_cathode_scrapbal_noavail.iloc[10:, :3].index, sd_cathode_scrapbal_noavail.iloc[10:, :3].transpose(), 
              labels=['Primary refined production', 'Secondary refined production', 'SX-EW production'])
pplot(sd_cathode_scrapbal_noavail.iloc[10:, 3], 'k', label='Cathode consumption')

pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [1000, 33000], 'k--')
plt.legend(loc=2)
plt.xlabel('Year')
plt.ylabel('Cathode production and consumption (kt)')
plt.title('Cathode S&D (ktonnes)')
plt.show()

# %%
pplot(sd_cathode_baseline_baseline.iloc[10:, 1].div(sd_cathode_baseline_baseline.iloc[10:, :3].sum(axis=1)))

# %% [markdown]
# ### Scrap S&D

# %% [markdown]
# #### Fruity RRs
# Scrap response for Fruity recycling rates

# %%
pplot(shock_fruity1rr11.loc['20190101':].cumsum(), label='fruity 1X 0.1% recycling rate',color='tab:gray')
pplot(shock_fruity1rr50.loc['20190101':].cumsum(), label='fruity 1X 50% recycling rate',color='tab:blue')
pplot(shock_fruity1rr90.loc['20190101':].cumsum(), label='fruity 1X 90% recycling rate',color='tab:green')
pplot(shock_fruity1rr100.loc['20190101':].cumsum(), label='fruity 1X 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap response above baseline (kt)')
plt.title('Scrap Response above Baseline \n(Fruity Alloys)')

plt.figure()
pplot(shock_fruity_pct1rr11.loc['20190101':].cumsum(), label='1mrk% 0.1% recycling rate',color='tab:gray')
pplot(shock_fruity_pct1rr50.loc['20190101':].cumsum(), label='1mrk% 50% recycling rate',color='tab:blue')
pplot(shock_fruity_pct1rr90.loc['20190101':].cumsum(), label='1mrk% 90% recycling rate',color='tab:green')
pplot(shock_fruity_pct1rr100.loc['20190101':].cumsum(), label='1mrk% 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap response above baseline (kt)')
plt.title('Scrap Response above Baseline \n(Fruity Alloys)')

plt.figure()
pplot(shock_fruity_pct5rr11.loc['20190101':].cumsum(), label='5mrk% 0.1% recycling rate',color='tab:gray')
pplot(shock_fruity_pct5rr50.loc['20190101':].cumsum(), label='5mrk% 50% recycling rate',color='tab:blue')
pplot(shock_fruity_pct5rr90.loc['20190101':].cumsum(), label='5mrk% 90% recycling rate',color='tab:green')
pplot(shock_fruity_pct5rr100.loc['20190101':].cumsum(), label='5mrk% 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap response above baseline (kt)')
plt.title('Scrap Response above Baseline \n(Fruity Alloys)')

plt.figure()
pplot(shock_fruity_pct10rr11.loc['20190101':].cumsum(), label='10mrk% 0.1% recycling rate',color='tab:gray')
pplot(shock_fruity_pct10rr50.loc['20190101':].cumsum(), label='10mrk% 50% recycling rate',color='tab:blue')
pplot(shock_fruity_pct10rr70.loc['20190101':].cumsum(), label='10mrk% 70% recycling rate',color='tab:green')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap response above baseline (kt)')
plt.title('Scrap Response above Baseline \n(Fruity Alloys)')

plt.figure()
pplot(shock_fruity1rr90.loc['20190101':].cumsum(), label='fruity 1X 90% recycling rate',color='tab:blue')
pplot(shock_fruity_pct1rr90.loc['20190101':].cumsum(), label='1mrk% 90% recycling rate',color='tab:green')
pplot(shock_fruity_pct5rr90.loc['20190101':].cumsum(), label='5mrk% 90% recycling rate',color='tab:red')
pplot(shock_fruity_pct10rr70.loc['20190101':].cumsum(), label='10mrk% 70% recycling rate',color='tab:gray')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap response above baseline (kt)')
plt.title('Scrap Response above Baseline \n(Fruity Alloys)')
plt.show()

# %%
pplot(scrap_demand_pctinc2020_fruity1rr11_gl.loc['20180101':], label='fruity 1X 0.1% recycling rate',color='tab:gray', firstcall=1)
pplot(scrap_demand_pctinc2020_fruity1rr50_gl.loc['20180101':], label='fruity 1X 50% recycling rate',color='tab:blue')
pplot(scrap_demand_pctinc2020_fruity1rr90_gl.loc['20180101':], label='fruity 1X 90% recycling rate',color='tab:green')
pplot(scrap_demand_pctinc2020_fruity1rr100_gl.loc['20180101':], label='fruity 1X 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand pctinc2020 above baseline (%)')
plt.title('Scrap demand pctinc2020 above baseline \n(Fruity Alloys)')

plt.figure()
pplot(scrap_demand_pctinc2020_fruity_pct1rr11_gl.loc['20180101':], label='1mrk% 0.1% recycling rate',color='tab:gray', firstcall=1)
pplot(scrap_demand_pctinc2020_fruity_pct1rr50_gl.loc['20180101':], label='1mrk% 50% recycling rate',color='tab:blue')
pplot(scrap_demand_pctinc2020_fruity_pct1rr90_gl.loc['20180101':], label='1mrk% 90% recycling rate',color='tab:green')
pplot(scrap_demand_pctinc2020_fruity_pct1rr100_gl.loc['20180101':], label='1mrk% 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand pctinc2020 above baseline (%)')
plt.title('Scrap demand pctinc2020 above baseline \n(Fruity Alloys)')

plt.figure()
pplot(scrap_demand_pctinc2020_fruity_pct5rr11_gl.loc['20180101':], label='5mrk% 0.1% recycling rate',color='tab:gray', firstcall=1)
pplot(scrap_demand_pctinc2020_fruity_pct5rr50_gl.loc['20180101':], label='5mrk% 50% recycling rate',color='tab:blue')
pplot(scrap_demand_pctinc2020_fruity_pct5rr90_gl.loc['20180101':], label='5mrk% 90% recycling rate',color='tab:green')
pplot(scrap_demand_pctinc2020_fruity_pct5rr100_gl.loc['20180101':], label='5mrk% 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand pctinc2020 above baseline (%)')
plt.title('Scrap demand pctinc2020 above baseline \n(Fruity Alloys)')

plt.figure()
pplot(scrap_demand_pctinc2020_fruity_pct10rr11_gl.loc['20180101':], label='10mrk% 0.1% recycling rate',color='tab:gray', firstcall=1)
pplot(scrap_demand_pctinc2020_fruity_pct10rr50_gl.loc['20180101':], label='10mrk% 50% recycling rate',color='tab:blue')
pplot(scrap_demand_pctinc2020_fruity_pct10rr70_gl.loc['20180101':], label='10mrk% 70% recycling rate',color='tab:green')
pplot(scrap_demand_pctinc2020_fruity_pct10rr90_gl.loc['20180101':], label='10mrk% 90% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand pctinc2020 above baseline (%)')
plt.title('Scrap demand pctinc2020 above baseline \n(Fruity Alloys)')

plt.figure()
pplot(scrap_demand_pctinc2020_fruity1rr90_gl.loc['20180101':], label='fruity 1X 90% recycling rate',color='tab:blue', firstcall=1)
pplot(scrap_demand_pctinc2020_fruity_pct1rr90_gl.loc['20180101':], label='1mrk% 90% recycling rate',color='tab:green')
pplot(scrap_demand_pctinc2020_fruity_pct5rr90_gl.loc['20180101':], label='5mrk% 90% recycling rate',color='tab:red')
pplot(scrap_demand_pctinc2020_fruity_pct10rr90_gl.loc['20180101':], label='10mrk% 90% recycling rate',color='tab:gray')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand pctinc2020 above baseline (%)')
plt.title('Scrap demand pctinc2020 above baseline \n(Fruity Alloys)')
plt.show()

# %%
pplot(direct_melt_demand_fruity_pct10rr11_gl.loc['20180101':,'Ref_Cu']-direct_melt_demand_fruity_pct10rr0_gl.loc['20180101':,'Ref_Cu'], label='fruity 10mkt% 1% recycling rate',color='tab:gray')
pplot(direct_melt_demand_fruity_pct10rr50_gl.loc['20180101':,'Ref_Cu']-direct_melt_demand_fruity_pct10rr0_gl.loc['20180101':,'Ref_Cu'], label='fruity 10mkt% 50% recycling rate',color='tab:blue')
pplot(direct_melt_demand_fruity_pct10rr70_gl.loc['20180101':,'Ref_Cu']-direct_melt_demand_fruity_pct10rr0_gl.loc['20180101':,'Ref_Cu'], label='fruity 10mkt% 70% recycling rate',color='tab:green')
pplot(direct_melt_demand_fruity_pct10rr90_gl.loc['20180101':,'Ref_Cu']-direct_melt_demand_fruity_pct10rr0_gl.loc['20180101':,'Ref_Cu'], label='fruity 10mkt% 90% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Refined copper consumption above baseline (kt)')
plt.title('Refined copper consumption above baseline \n(Fruity Alloys, 10% of market)')
plt.show()

plt.figure()
pplot(direct_melt_demand_fruity_pct10rr11_gl.loc['20180101':,'Ref_Zn':'Ref_Fe'].sum(axis=1)-direct_melt_demand_fruity_pct10rr0_gl.loc['20180101':,'Ref_Zn':'Ref_Fe'].sum(axis=1), label='fruity 10mkt% 1% recycling rate',color='tab:gray')
pplot(direct_melt_demand_fruity_pct10rr50_gl.loc['20180101':,'Ref_Zn':'Ref_Fe'].sum(axis=1)-direct_melt_demand_fruity_pct10rr0_gl.loc['20180101':,'Ref_Zn':'Ref_Fe'].sum(axis=1), label='fruity 10mkt% 50% recycling rate',color='tab:blue')
pplot(direct_melt_demand_fruity_pct10rr70_gl.loc['20180101':,'Ref_Zn':'Ref_Fe'].sum(axis=1)-direct_melt_demand_fruity_pct10rr0_gl.loc['20180101':,'Ref_Zn':'Ref_Fe'].sum(axis=1), label='fruity 10mkt% 70% recycling rate',color='tab:green')
pplot(direct_melt_demand_fruity_pct10rr90_gl.loc['20180101':,'Ref_Zn':'Ref_Fe'].sum(axis=1)-direct_melt_demand_fruity_pct10rr0_gl.loc['20180101':,'Ref_Zn':'Ref_Fe'].sum(axis=1), label='fruity 10mkt% 90% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Refined non-copper consumption above baseline (kt)')
plt.title('Refined non-copper consumption above baseline \n(Fruity Alloys, 10% of market)')
plt.show()

plt.figure()
scrap_subset = list(['Yellow_Brass','Cartridge', 'No.1', 'No.2', 'Pb_Yellow_Brass', 'Ocean', 
                     'Red_Brass', 'Al_Bronze', 'Ni_Ag'])
pplot(-direct_melt_demand_fruity_pct10rr11_gl.loc['20180101':,scrap_subset].sum(axis=1)/0.928+all_scrap_available_no_accumulation_fruity_pct10rr11_gl.loc['20180101':,scrap_subset].sum(axis=1), label='fruity 10mkt% 1% recycling rate',color='tab:gray')
pplot(-direct_melt_demand_fruity_pct10rr50_gl.loc['20180101':,scrap_subset].sum(axis=1)/0.928+all_scrap_available_no_accumulation_fruity_pct10rr50_gl.loc['20180101':,scrap_subset].sum(axis=1), label='fruity 10mkt% 50% recycling rate',color='tab:blue')
pplot(-direct_melt_demand_fruity_pct10rr70_gl.loc['20180101':,scrap_subset].sum(axis=1)/0.928+all_scrap_available_no_accumulation_fruity_pct10rr70_gl.loc['20180101':,scrap_subset].sum(axis=1), label='fruity 10mkt% 70% recycling rate',color='tab:green')
pplot(-direct_melt_demand_fruity_pct10rr90_gl.loc['20180101':,scrap_subset].sum(axis=1)/0.928+all_scrap_available_no_accumulation_fruity_pct10rr90_gl.loc['20180101':,scrap_subset].sum(axis=1), label='fruity 10mkt% 90% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap balance (kt)')
plt.title('Scrap balance, 10% of market \n(Fruity Alloys)')
plt.show()

# %%
pplot(scrap_demand_pctinc2020_fruity_pct10rr50var10_cn.loc['20180101':], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(scrap_demand_pctinc2020_fruity_pct10rr50var30_cn.loc['20180101':], label='10mrk% 50% RR, var30',color=colors[1])
pplot(scrap_demand_pctinc2020_fruity_pct10rr50var50_cn.loc['20180101':], label='10mrk% 50% RR, var50',color=colors[2])
pplot(scrap_demand_pctinc2020_fruity_pct10rr50var70_cn.loc['20180101':], label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
plt.yticks([0, 50,100,150,200])
# plt.ylim(-16,5)
plt.ylabel('Scrap demand response above baseline \n(Cumulative, % of 2020 China production)')
plt.title('China Scrap Demand Response above Baseline \n10% of Copper Market')
ylims_cn=plt.ylim()

pplot(scrap_demand_pctinc2020_fruity_pct10rr50var10_rw.loc['20180101':], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(scrap_demand_pctinc2020_fruity_pct10rr50var30_rw.loc['20180101':], label='10mrk% 50% RR, var30',color=colors[1])
pplot(scrap_demand_pctinc2020_fruity_pct10rr50var50_rw.loc['20180101':], label='10mrk% 50% RR, var50',color=colors[2])
pplot(scrap_demand_pctinc2020_fruity_pct10rr50var70_rw.loc['20180101':], label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([0, 50,100,150,200])
# plt.ylim(-16,5)
plt.ylabel('Scrap demand response above baseline \n(Cumulative, % of 2020 RoW production)')
plt.title('Rest of World Scrap Demand Response above Baseline \n10% of Copper Market')
ylims_rw=plt.ylim()

pplot(scrap_demand_pctinc2020_fruity_pct10rr50var10_gl.loc['20180101':], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(scrap_demand_pctinc2020_fruity_pct10rr50var30_gl.loc['20180101':], label='10mrk% 50% RR, var30',color=colors[1])
pplot(scrap_demand_pctinc2020_fruity_pct10rr50var50_gl.loc['20180101':], label='10mrk% 50% RR, var50',color=colors[2])
pplot(scrap_demand_pctinc2020_fruity_pct10rr50var70_gl.loc['20180101':], label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
plt.yticks([-20, -15,-10,-5,0,5])
plt.ylim(-21,6)
plt.ylabel('Scrap demand response above baseline \n(Cumulative, % of 2020 global production)')
plt.suptitle('Global Scrap Demand Response above Baseline')
plt.title('10% of Copper Market', color = color_10)
ylims_gl=plt.ylim()

# %%
n = np.arange(0,len(scrap_imports_cn_all.loc[2018:].index)+1)
scrap_imports_cn_all.loc[2018].sum() - scrap_imports_cn_all.loc[2018,'Al_Bronze':].sum() * (0.25**n)

# %%
pplot(scrap_demand_pctinc2020_fruity1rr100var10_cn.loc['20180101':], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(scrap_demand_pctinc2020_fruity1rr100var30_cn.loc['20180101':], label='10mrk% 50% RR, var30',color=colors[1])
pplot(scrap_demand_pctinc2020_fruity1rr100var50_cn.loc['20180101':], label='10mrk% 50% RR, var50',color=colors[2])
pplot(scrap_demand_pctinc2020_fruity1rr100var70_cn.loc['20180101':], label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([0, 50,100,150,200])
# plt.ylim(-16,5)
plt.ylabel('Scrap demand response above baseline \n(Cumulative, % of China 2020 production)')
plt.title('China Scrap Demand Response above Baseline \n0.08% of Copper Market')
plt.ylim(ylims_cn)

pplot(scrap_demand_pctinc2020_fruity1rr100var10_rw.loc['20180101':], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(scrap_demand_pctinc2020_fruity1rr100var30_rw.loc['20180101':], label='10mrk% 50% RR, var30',color=colors[1])
pplot(scrap_demand_pctinc2020_fruity1rr100var50_rw.loc['20180101':], label='10mrk% 50% RR, var50',color=colors[2])
pplot(scrap_demand_pctinc2020_fruity1rr100var70_rw.loc['20180101':], label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([0, 50,100,150,200])
# plt.ylim(-16,5)
plt.ylabel('Scrap demand response above baseline \n(Cumulative, % of 2020 RoW production)')
plt.title('Rest of World Scrap Demand Response above Baseline \n0.08% of Copper Market')
plt.ylim(ylims_rw)

pplot(scrap_demand_pctinc2020_fruity1rr100var10_gl.loc['20180101':], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(scrap_demand_pctinc2020_fruity1rr100var30_gl.loc['20180101':], label='10mrk% 50% RR, var30',color=colors[1])
pplot(scrap_demand_pctinc2020_fruity1rr100var50_gl.loc['20180101':], label='10mrk% 50% RR, var50',color=colors[2])
pplot(scrap_demand_pctinc2020_fruity1rr100var70_gl.loc['20180101':], label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([0, 50,100,150,200])
# plt.ylim(-16,5)
plt.ylabel('Scrap demand response above baseline \n(Cumulative, % of 2020 global production)')
plt.suptitle('Global Scrap Demand Response above Baseline')
plt.title('0.08% of Copper Market', color = color_08)
plt.ylim(ylims_gl)

# %%
pplot(all_scrap_available_no_accumulation_fruity1rr11_gl.loc['20190101':], label='fruity 1X 0.1% recycling rate',color='tab:gray')
pplot(all_scrap_available_no_accumulation_fruity1rr50_gl.loc['20190101':], label='fruity 1X 50% recycling rate',color='tab:blue')
pplot(all_scrap_available_no_accumulation_fruity1rr90_gl.loc['20190101':], label='fruity 1X 90% recycling rate',color='tab:green')
pplot(all_scrap_available_no_accumulation_fruity1rr100_gl.loc['20190101':], label='fruity 1X 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand response above baseline (kt)')
plt.title('Scrap demand response above baseline \n(Fruity Alloys)')

plt.figure()
pplot(all_scrap_available_no_accumulation_fruity_pct1rr11_gl.loc['20190101':]-direct_melt_demand_fruity1rr11_gl.loc['20190101'], label='1mrk% 0.1% recycling rate',color='tab:gray')
pplot(all_scrap_available_no_accumulation_fruity_pct1rr50_gl.loc['20190101':]-direct_melt_demand_fruity1rr50_gl.loc['20190101'], label='1mrk% 50% recycling rate',color='tab:blue')
pplot(all_scrap_available_no_accumulation_fruity_pct1rr90_gl.loc['20190101':]-direct_melt_demand_fruity1rr90_gl.loc['20190101'], label='1mrk% 90% recycling rate',color='tab:green')
pplot(all_scrap_available_no_accumulation_fruity_pct1rr100_gl.loc['20190101':]-direct_melt_demand_fruity1rr1000_gl.loc['20190101'], label='1mrk% 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand response above baseline (kt)')
plt.title('Scrap demand response above baseline \n(Fruity Alloys)')

plt.figure()
pplot(all_scrap_available_no_accumulation_fruity_pct5rr11_gl.loc['20190101':]-direct_melt_demand_fruity1rr11_gl.loc['20190101'], label='5mrk% 0.1% recycling rate',color='tab:gray')
pplot(all_scrap_available_no_accumulation_fruity_pct5rr50_gl.loc['20190101':]-direct_melt_demand_fruity1rr50_gl.loc['20190101'], label='5mrk% 50% recycling rate',color='tab:blue')
pplot(all_scrap_available_no_accumulation_fruity_pct5rr90_gl.loc['20190101':]-direct_melt_demand_fruity1rr90_gl.loc['20190101'], label='5mrk% 90% recycling rate',color='tab:green')
pplot(all_scrap_available_no_accumulation_fruity_pct5rr100_gl.loc['20190101':]-direct_melt_demand_fruity1rr1000_gl.loc['20190101'], label='5mrk% 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand response above baseline (kt)')
plt.title('Scrap demand response above baseline \n(Fruity Alloys)')

plt.figure()
pplot(all_scrap_available_no_accumulation_fruity_pct10rr11_gl.loc['20190101':]-direct_melt_demand_fruity1rr11_gl.loc['20190101'], label='10mrk% 0.1% recycling rate',color='tab:gray')
pplot(all_scrap_available_no_accumulation_fruity_pct10rr50_gl.loc['20190101':]-direct_melt_demand_fruity1rr50_gl.loc['20190101'], label='10mrk% 50% recycling rate',color='tab:blue')
pplot(all_scrap_available_no_accumulation_fruity_pct10rr70_gl.loc['20190101':]-direct_melt_demand_fruity1rr90_gl.loc['20190101'], label='10mrk% 70% recycling rate',color='tab:green')
pplot(all_scrap_available_no_accumulation_fruity_pct10rr90_gl.loc['20190101':]-direct_melt_demand_fruity1rr1000_gl.loc['20190101'], label='10mrk% 90% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand response above baseline (kt)')
plt.title('Scrap demand response above baseline \n(Fruity Alloys)')

plt.figure()
pplot(all_scrap_available_no_accumulation_fruity1rr90_gl.loc['20190101':]-direct_melt_demand_fruity1rr11_gl.loc['20190101'], label='fruity 1X 90% recycling rate',color='tab:blue')
pplot(all_scrap_available_no_accumulation_fruity_pct1rr90_gl.loc['20190101':]-direct_melt_demand_fruity1rr50_gl.loc['20190101'], label='1mrk% 90% recycling rate',color='tab:green')
pplot(all_scrap_available_no_accumulation_fruity_pct5rr90_gl.loc['20190101':]-direct_melt_demand_fruity1rr70_gl.loc['20190101'], label='5mrk% 90% recycling rate',color='tab:red')
pplot(all_scrap_available_no_accumulation_fruity_pct10rr90_gl.loc['20190101':]-direct_melt_demand_fruity1rr1000_gl.loc['20190101'], label='10mrk% 90% recycling rate',color='tab:gray')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand response above baseline (kt)')
plt.title('Scrap demand response above baseline \n(Fruity Alloys)')
plt.show()

# %%
pplot(scrap_demand_response_fruity1rr001_gl, label='fruity 1X 0.1% recycling rate',color='tab:gray')
pplot(scrap_demand_response_fruity1rr50_gl, label='fruity 1X 50% recycling rate',color='tab:blue')
pplot(scrap_demand_response_fruity1rr90_gl, label='fruity 1X 90% recycling rate',color='tab:green')
pplot(scrap_demand_response_fruity1rr100_gl, label='fruity 1X 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand response above baseline (kt)')
plt.title('Scrap demand response above Baseline \n(Fruity Alloys)')

plt.figure()
pplot(scrap_demand_response_fruity10rr001_gl, label='fruity 10X 0.1% recycling rate',color='tab:gray')
pplot(scrap_demand_response_fruity10rr50_gl, label='fruity 10X 50% recycling rate',color='tab:blue')
pplot(scrap_demand_response_fruity10rr90_gl, label='fruity 10X 90% recycling rate',color='tab:green')
pplot(scrap_demand_response_fruity10rr100_gl, label='fruity 10X 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand response above baseline (kt)')
plt.title('Scrap demand response above Baseline \n(Fruity Alloys)')

plt.figure()
pplot(scrap_demand_response_fruity100rr001_gl, label='fruity 100X 0.1% recycling rate',color='tab:gray')
pplot(scrap_demand_response_fruity100rr50_gl, label='fruity 100X 50% recycling rate',color='tab:blue')
pplot(scrap_demand_response_fruity100rr90_gl, label='fruity 100X 90% recycling rate',color='tab:green')
pplot(scrap_demand_response_fruity100rr100_gl, label='fruity 100X 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand response above baseline (kt)')
plt.title('Scrap demand response above Baseline \n(Fruity Alloys)')

plt.figure()
pplot(scrap_demand_response_fruity1rr100_gl, label='fruity 1X 100% recycling rate',color='tab:blue')
pplot(scrap_demand_response_fruity10rr100_gl, label='fruity 10X 100% recycling rate',color='tab:green')
pplot(scrap_demand_response_fruity100rr100_gl, label='fruity 100X 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Scrap demand response above baseline (kt)')
plt.title('Scrap demand response above Baseline \n(Fruity Alloys)')
plt.show()

# %%
# shock_alloyed_imports_50yoy.cumsum().loc['20180101':].plot(label='50% reduction in alloyed CN imports', color='tab:green')
# shock_alloyed_no2_50yoy.cumsum().loc['20180101':].plot(label='50% reduction in No.2 and alloyed CN imports',color='tab:red')

shock_fruity100rr100niag.cumsum().loc['20180101':].plot(label='50% reduction in alloyed CN imports', color='tab:green')
shock_fruity10rr100niag.cumsum().loc['20180101':].plot(label='50% reduction in No.2 and alloyed CN imports',color='tab:red')
shock_fruity1rr100niag.cumsum().loc['20180101':].plot(label='50% reduction in No.2 and alloyed CN imports',color='tab:blue')

plt.title('Scrap Response above Baseline \n(China Scenarios)')
plt.ylabel('Scrap response above baseline (kt)')
plt.xlabel('Year')
# plt.legend(loc='upper left')
plt.show()

# %%
# ((scrap_demand_response_fruity100rr100niag_gl)/(direct_melt_demand_fruity100rr100niag_gl.loc['20180101':,'Ref_Cu'].cumsum()-direct_melt_demand_fruity100rr0niag_gl.loc['20180101':,'Ref_Cu'].cumsum())).plot(label = 'Global')
# ((scrap_demand_response_fruity100rr100niag_cn)/(direct_melt_demand_fruity100rr100niag_cn.loc['20180101':,'Ref_Cu'].cumsum()-direct_melt_demand_fruity100rr0niag_cn.loc['20180101':,'Ref_Cu'].cumsum())).plot(label = 'China')
# ((scrap_demand_response_fruity100rr100niag_rw)/(direct_melt_demand_fruity100rr100niag_rw.loc['20180101':,'Ref_Cu'].cumsum()-direct_melt_demand_fruity100rr0niag_rw.loc['20180101':,'Ref_Cu'].cumsum())).plot(label = 'Rest of World', color = 'tab:green')

scrap_demand_response_fruity100rr100niag_gl.plot(label = '100X')
scrap_demand_response_fruity10rr100niag_gl.plot(label = '10X')
scrap_demand_response_fruity1rr100niag_gl.plot(label = 'Original', color = 'tab:green')

plt.legend()
plt.title('Scrap demand response above baseline\n(China Scenarios)')
plt.show()

# %%
(direct_melt_demand_fruity100rr100niag_gl.loc['20180101':,'Ref_Cu'].cumsum()-direct_melt_demand_fruity100rr0niag_gl.loc['20180101':,'Ref_Cu'].cumsum()).plot(label='Global')
(direct_melt_demand_fruity100rr100niag_cn.loc['20180101':,'Ref_Cu'].cumsum()-direct_melt_demand_fruity100rr0niag_cn.loc['20180101':,'Ref_Cu'].cumsum()).plot(label='China')
(direct_melt_demand_fruity100rr100niag_rw.loc['20180101':,'Ref_Cu'].cumsum()-direct_melt_demand_fruity100rr0niag_rw.loc['20180101':,'Ref_Cu'].cumsum()).plot(label='RoW',color='tab:green')
plt.legend()
plt.show()

# %% [markdown]
# #### China import scenarios scrap response

# %%
shock_alloyed_imports_50yoy

# %%
pplot(shock_no2_50yoy.cumsum().loc['20170101':], label='Scrap avail: No.2 banned',color=colors[0],firstcall=1)
pplot(shock_both_50yoy.cumsum().loc['20170101':], label='Scrap avail: alloyed+No.2 banned',color=colors[1])
pplot(shock_alloyed_50yoy.cumsum().loc['20170101':], label='Scrap avail: alloyed banned',color=colors[2])
plt.title('Scrap Availability Response above Baseline \n(China import scenarios)')
plt.ylabel('Cumulative scrap response above baseline (kt)')
# plt.xlabel('Year')
# plt.legend()

plt.figure()
pplot(scrap_pctinc_no2_50yoy.loc['20170101':], label='Scrap avail: No.2 banned',color=colors[0],firstcall=1)
pplot(scrap_pctinc_both_50yoy.loc['20170101':], label='Scrap avail: alloyed+No.2 banned',color=colors[1])
pplot(scrap_pctinc_alloyed_50yoy.loc['20170101':], label='Scrap avail: alloyed banned',color=colors[2])
plt.title('Scrap Availability Response above Baseline \n(China import scenarios)')
plt.ylabel('Cumulative scrap response above baseline 2040 value (%)')
# plt.xlabel('Year')
plt.legend()

plt.figure()
pplot(scrap_cumpctinc_no2_50yoy.loc['20170101':], label='Scrap avail: No.2 banned',color=colors[0],firstcall=1)
pplot(scrap_cumpctinc_both_50yoy.loc['20170101':], label='Scrap avail: alloyed+No.2 banned',color=colors[1])
pplot(scrap_cumpctinc_alloyed_50yoy.loc['20170101':], label='Scrap avail: alloyed banned',color=colors[2])
plt.title('Scrap Availability Response above Baseline \n(China import scenarios)')
plt.ylabel('Cumulative scrap response above cumulative baseline (%)')
# plt.xlabel('Year')
plt.legend()

plt.figure()
pplot(scrap_demand_response_no2_50yoy_gl.loc['20170101':], label='Scrap demand: No.2 banned',color=colors[0],firstcall=1)
pplot(scrap_demand_response_both_50yoy_gl.loc['20170101':], label='Scrap demand: alloyed+No.2 banned',color=colors[1])
pplot(scrap_demand_response_alloyed_50yoy_gl.loc['20170101':], label='Scrap demand: alloyed banned',color=colors[2])
# pplot(scrap_demand_response_both_50yoy_cn.loc['20170101':], label='CN Scrap demand: alloyed+No.2 banned',color='red')
# pplot(scrap_demand_response_both_50yoy_rw.loc['20170101':], label='RoW Scrap demand: alloyed+No.2 banned',color='blue')
plt.title('Scrap Demand Response above Baseline \nGlobal')
plt.ylabel('Cumulative scrap response above baseline (kt)')
plt.yticks([200, 0,-200,-400, -600])
plt.ylim(-650, 250)
# plt.xlabel('Year')
plt.legend().set_visible(False)

plt.figure()
pplot(scrap_demand_pctinc_no2_50yoy_gl.loc['20170101':], label='Scrap demand: No.2 banned',color=colors[0],firstcall=1)
pplot(scrap_demand_pctinc_both_50yoy_gl.loc['20170101':], label='Scrap demand: alloyed+No.2 banned',color=colors[1])
pplot(scrap_demand_pctinc_alloyed_50yoy_gl.loc['20170101':], label='Scrap demand: alloyed banned',color=colors[2])
plt.title('Scrap Demand Response above Baseline \nGlobal')
plt.ylabel('Cumulative scrap response above baseline 2040 value (%)')
# plt.xlabel('Year')
plt.legend().set_visible(False)

plt.figure()
pplot(scrap_demand_cumpctinc_no2_50yoy_gl.loc['20170101':], label='Scrap demand: No.2 banned',color=colors[0],firstcall=1)
pplot(scrap_demand_cumpctinc_both_50yoy_gl.loc['20170101':], label='Scrap demand: alloyed+No.2 banned',color=colors[1])
pplot(scrap_demand_cumpctinc_alloyed_50yoy_gl.loc['20170101':], label='Scrap demand: alloyed banned',color=colors[2])
plt.title('Scrap Demand Response above Baseline \nGlobal')
plt.ylabel('Cumulative scrap response above cumulative baseline (%)')
# plt.xlabel('Year')
plt.legend().set_visible(False)
plt.show()

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [16, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'


fig1,(ax1,ax2) = plt.subplots(1,2, frameon=False)
ax1.plot(shock_no2_50yoy_cn.cumsum().loc['20170101':], label='Scrap avail: No.2 banned',color=colors[0])
ax1.plot(shock_both_50yoy_cn.cumsum().loc['20170101':], label='Scrap avail: alloyed+No.2 banned',color=colors[1])
ax1.plot(shock_alloyed_50yoy_cn.cumsum().loc['20170101':], label='Scrap avail: alloyed banned',color=colors[2])
ax1.set_title('Scrap Availability Response above Baseline \nChina')
ax1.set_ylabel('Cumulative scrap response above baseline (kt)')
ax1.set_xlabel('Year')
# ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(shock_no2_50yoy_rw.cumsum().loc['20170101':], label='Scrap avail: No.2 banned',color=colors[0])
ax2.plot(shock_both_50yoy_rw.cumsum().loc['20170101':], label='Scrap avail: alloyed+No.2 banned',color=colors[1])
ax2.plot(shock_alloyed_50yoy_rw.cumsum().loc['20170101':], label='Scrap avail: alloyed banned',color=colors[2])
ax2.set_title('Scrap Availability Response above Baseline \nRest of World')
# ax2.set_ylabel('Cumulative scrap response above baseline (kt)')
ax2.set_xlabel('Year')
ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig3, (ax1,ax2) = plt.subplots(1,2, frameon=0)
ax1.plot(scrap_demand_response_no2_50yoy_cn.loc['20170101':], label='Scrap demand: No.2 banned',color=colors[0])
ax1.plot(scrap_demand_response_both_50yoy_cn.loc['20170101':], label='Scrap demand: alloyed+No.2 banned',color=colors[1])
ax1.plot(scrap_demand_response_alloyed_50yoy_cn.loc['20170101':], label='Scrap demand: alloyed banned',color=colors[2])
ax1.set_title('Scrap Demand Response above Baseline \nChina')
ax1.set_ylabel('Cumulative scrap response above baseline (kt)')
ax1.set_yticks(np.arange(0,-14000,-4000))
ax1.legend().set_visible(False)
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(scrap_demand_response_no2_50yoy_rw.loc['20170101':], label='Scrap demand: No.2 banned',color=colors[0])
ax2.plot(scrap_demand_response_both_50yoy_rw.loc['20170101':], label='Scrap demand: alloyed+No.2 banned',color=colors[1])
ax2.plot(scrap_demand_response_alloyed_50yoy_rw.loc['20170101':], label='Scrap demand: alloyed banned',color=colors[2])
ax2.set_title('Scrap Demand Response above Baseline \nRest of World')
# ax2.set_ylabel('Cumulative scrap response above baseline (kt)')
ax2.set_yticks(np.arange(0,14000,4000))
ax2.legend().set_visible(False)
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig4, (ax1,ax2) = plt.subplots(1,2, frameon=0)
ax1.plot(scrap_demand_cumpctinc_no2_50yoy_cn.loc['20170101':], label='Scrap demand: No.2 banned',color=colors[0])
ax1.plot(scrap_demand_cumpctinc_both_50yoy_cn.loc['20170101':], label='Scrap demand: alloyed+No.2 banned',color=colors[1])
ax1.plot(scrap_demand_cumpctinc_alloyed_50yoy_cn.loc['20170101':], label='Scrap demand: alloyed banned',color=colors[2])
ax1.set_title('Scrap Demand Response above Baseline \nChina')
ax1.set_ylabel('Cumulative scrap response above cumulative baseline (%)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(scrap_demand_cumpctinc_no2_50yoy_rw.loc['20170101':], label='Scrap demand: No.2 banned',color=colors[0])
ax2.plot(scrap_demand_cumpctinc_both_50yoy_rw.loc['20170101':], label='Scrap demand: alloyed+No.2 banned',color=colors[1])
ax2.plot(scrap_demand_cumpctinc_alloyed_50yoy_rw.loc['20170101':], label='Scrap demand: alloyed banned',color=colors[2])
ax2.set_title('Scrap Demand Response above Baseline \nRest of World')
# ax2.set_ylabel('Cumulative scrap response above cumulative baseline (%)')
ax2.set_xlabel('Year')
ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
# plt.show()

# %% [markdown]
# Demand response, refined import sensitivities

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'


fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(scrap_demand_response_no2_50yoy_gl.loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax1.plot(scrap_demand_response_no2_50yoy_inc100_gl.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax1.plot(scrap_demand_response_no2_50yoy_dec100_gl.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax1.plot(scrap_demand_response_no2_50yoy_inc200_gl.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax1.plot(scrap_demand_response_no2_50yoy_dec200_gl.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax1.set_title('Scrap Demand Response \nGlobal, No.2 Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(scrap_demand_response_no2_50yoy_cn.loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax2.plot(scrap_demand_response_no2_50yoy_inc100_cn.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax2.plot(scrap_demand_response_no2_50yoy_dec100_cn.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax2.plot(scrap_demand_response_no2_50yoy_inc200_cn.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax2.plot(scrap_demand_response_no2_50yoy_dec200_cn.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax2.set_title('Scrap Demand Response \nChina, No.2 Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(scrap_demand_response_no2_50yoy_rw.loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax3.plot(scrap_demand_response_no2_50yoy_inc100_rw.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax3.plot(scrap_demand_response_no2_50yoy_dec100_rw.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax3.plot(scrap_demand_response_no2_50yoy_inc200_rw.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax3.plot(scrap_demand_response_no2_50yoy_dec200_rw.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax3.set_title('Scrap Demand Response \nRoW, No.2 Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig2,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(scrap_demand_response_alloyed_50yoy_gl.loc['20170101':], label='Alloyed Ban Baseline',color=colors[0])
ax1.plot(scrap_demand_response_alloyed_50yoy_inc100_gl.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax1.plot(scrap_demand_response_alloyed_50yoy_dec100_gl.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax1.plot(scrap_demand_response_alloyed_50yoy_inc200_gl.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax1.plot(scrap_demand_response_alloyed_50yoy_dec200_gl.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax1.set_title('Scrap Demand Response \nGlobal, Alloyed Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(scrap_demand_response_alloyed_50yoy_cn.loc['20170101':], label='Alloyed Ban Baseline',color=colors[0])
ax2.plot(scrap_demand_response_alloyed_50yoy_inc100_cn.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax2.plot(scrap_demand_response_alloyed_50yoy_dec100_cn.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax2.plot(scrap_demand_response_alloyed_50yoy_inc200_cn.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax2.plot(scrap_demand_response_alloyed_50yoy_dec200_cn.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax2.set_title('Scrap Demand Response \nChina, Alloyed Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(scrap_demand_response_alloyed_50yoy_rw.loc['20170101':], label='Alloyed Ban Baseline',color=colors[0])
ax3.plot(scrap_demand_response_alloyed_50yoy_inc100_rw.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax3.plot(scrap_demand_response_alloyed_50yoy_dec100_rw.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax3.plot(scrap_demand_response_alloyed_50yoy_inc200_rw.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax3.plot(scrap_demand_response_alloyed_50yoy_dec200_rw.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax3.set_title('Scrap Demand Response \nRoW, Alloyed Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig3,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(scrap_demand_response_both_50yoy_gl.loc['20170101':], label='Both Ban Baseline',color=colors[0])
ax1.plot(scrap_demand_response_both_50yoy_inc100_gl.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax1.plot(scrap_demand_response_both_50yoy_dec100_gl.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax1.plot(scrap_demand_response_both_50yoy_inc200_gl.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax1.plot(scrap_demand_response_both_50yoy_dec200_gl.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax1.set_title('Scrap Demand Response \nGlobal, Both Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(scrap_demand_response_both_50yoy_cn.loc['20170101':], label='Both Ban Baseline',color=colors[0])
ax2.plot(scrap_demand_response_both_50yoy_inc100_cn.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax2.plot(scrap_demand_response_both_50yoy_dec100_cn.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax2.plot(scrap_demand_response_both_50yoy_inc200_cn.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax2.plot(scrap_demand_response_both_50yoy_dec200_cn.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax2.set_title('Scrap Demand Response \nChina, Both Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(scrap_demand_response_both_50yoy_rw.loc['20170101':], label='Both Ban Baseline',color=colors[0])
ax3.plot(scrap_demand_response_both_50yoy_inc100_rw.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax3.plot(scrap_demand_response_both_50yoy_dec100_rw.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax3.plot(scrap_demand_response_both_50yoy_inc200_rw.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax3.plot(scrap_demand_response_both_50yoy_dec200_rw.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax3.set_title('Scrap Demand Response \nRoW, Both Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Demand response, ban rate sensitivities

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'


fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(scrap_demand_response_no2_50yoy_gl.loc['20170101':], label='50% YOY',color=colors[0])
ax1.plot(scrap_demand_response_no2_25yoy_gl.loc['20170101':], label='25% YOY',color=colors[1])
ax1.plot(scrap_demand_response_no2_75yoy_gl.loc['20170101':], label='75% YOY',color=colors[2])
ax1.set_title('Scrap Demand Response \nGlobal, No.2 Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(scrap_demand_response_no2_50yoy_cn.loc['20170101':], label='50% YOY',color=colors[0])
ax2.plot(scrap_demand_response_no2_25yoy_cn.loc['20170101':], label='25% YOY',color=colors[1])
ax2.plot(scrap_demand_response_no2_75yoy_cn.loc['20170101':], label='75% YOY',color=colors[2])
ax2.set_title('Scrap Demand Response \nChina, No.2 Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(scrap_demand_response_no2_50yoy_rw.loc['20170101':], label='50% YOY',color=colors[0])
ax3.plot(scrap_demand_response_no2_25yoy_rw.loc['20170101':], label='25% YOY',color=colors[1])
ax3.plot(scrap_demand_response_no2_75yoy_rw.loc['20170101':], label='75% YOY',color=colors[2])
ax3.set_title('Scrap Demand Response \nRoW, No.2 Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig2,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(scrap_demand_response_alloyed_50yoy_gl.loc['20170101':], label='50% YOY',color=colors[0])
ax1.plot(scrap_demand_response_alloyed_25yoy_gl.loc['20170101':], label='25% YOY',color=colors[1])
ax1.plot(scrap_demand_response_alloyed_75yoy_gl.loc['20170101':], label='75% YOY',color=colors[2])
ax1.set_title('Scrap Demand Response \nGlobal, Alloyed Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(scrap_demand_response_alloyed_50yoy_cn.loc['20170101':], label='50% YOY',color=colors[0])
ax2.plot(scrap_demand_response_alloyed_25yoy_cn.loc['20170101':], label='25% YOY',color=colors[1])
ax2.plot(scrap_demand_response_alloyed_75yoy_cn.loc['20170101':], label='75% YOY',color=colors[2])
ax2.set_title('Scrap Demand Response \nChina, Alloyed Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(scrap_demand_response_alloyed_50yoy_rw.loc['20170101':], label='50% YOY',color=colors[0])
ax3.plot(scrap_demand_response_alloyed_25yoy_rw.loc['20170101':], label='25% YOY',color=colors[1])
ax3.plot(scrap_demand_response_alloyed_75yoy_rw.loc['20170101':], label='75% YOY',color=colors[2])
ax3.set_title('Scrap Demand Response \nRoW, Alloyed Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig3,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(scrap_demand_response_both_50yoy_gl.loc['20170101':], label='50% YOY',color=colors[0])
ax1.plot(scrap_demand_response_both_25yoy_gl.loc['20170101':], label='25% YOY',color=colors[1])
ax1.plot(scrap_demand_response_both_75yoy_gl.loc['20170101':], label='75% YOY',color=colors[2])
ax1.set_title('Scrap Demand Response \nGlobal, Both Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(scrap_demand_response_both_50yoy_cn.loc['20170101':], label='50% YOY',color=colors[0])
ax2.plot(scrap_demand_response_both_25yoy_cn.loc['20170101':], label='25% YOY',color=colors[1])
ax2.plot(scrap_demand_response_both_75yoy_cn.loc['20170101':], label='75% YOY',color=colors[2])
ax2.set_title('Scrap Demand Response \nChina, Both Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(scrap_demand_response_both_50yoy_rw.loc['20170101':], label='50% YOY',color=colors[0])
ax3.plot(scrap_demand_response_both_25yoy_rw.loc['20170101':], label='25% YOY',color=colors[1])
ax3.plot(scrap_demand_response_both_75yoy_rw.loc['20170101':], label='75% YOY',color=colors[2])
ax3.set_title('Scrap Demand Response \nRoW, Both Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Scrap entering inventory response, refined import sensitivities

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'


fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(all_scrap_available_no_accumulation_no2_50yoy_inc200_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +200',color=colors[3])
ax1.plot(all_scrap_available_no_accumulation_no2_50yoy_inc100_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +100',color=colors[1])
ax1.plot(all_scrap_available_no_accumulation_no2_50yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Constant Refined Imports',color=colors[0])
ax1.plot(all_scrap_available_no_accumulation_no2_50yoy_dec100_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -100',color=colors[2])
ax1.plot(all_scrap_available_no_accumulation_no2_50yoy_dec200_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -200',color=colors[4])
ax1.set_title('Scrap Entering Inventory Response \nGlobal, No.2 Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(all_scrap_available_no_accumulation_no2_50yoy_inc200_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +200',color=colors[3])
ax2.plot(all_scrap_available_no_accumulation_no2_50yoy_inc100_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +100',color=colors[1])
ax2.plot(all_scrap_available_no_accumulation_no2_50yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Constant Refined Imports',color=colors[0])
ax2.plot(all_scrap_available_no_accumulation_no2_50yoy_dec100_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -100',color=colors[2])
ax2.plot(all_scrap_available_no_accumulation_no2_50yoy_dec200_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -200',color=colors[4])
ax2.set_title('Scrap Entering Inventory Response \nChina, No.2 Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(all_scrap_available_no_accumulation_no2_50yoy_inc200_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +200',color=colors[3])
ax3.plot(all_scrap_available_no_accumulation_no2_50yoy_inc100_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +100',color=colors[1])
ax3.plot(all_scrap_available_no_accumulation_no2_50yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Constant Refined Imports',color=colors[0])
ax3.plot(all_scrap_available_no_accumulation_no2_50yoy_dec100_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -100',color=colors[2])
ax3.plot(all_scrap_available_no_accumulation_no2_50yoy_dec200_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -200',color=colors[4])
ax3.set_title('Scrap Entering Inventory Response \nRoW, No.2 Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig2,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(all_scrap_available_no_accumulation_alloyed_50yoy_inc200_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +200',color=colors[3])
ax1.plot(all_scrap_available_no_accumulation_alloyed_50yoy_inc100_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +100',color=colors[1])
ax1.plot(all_scrap_available_no_accumulation_alloyed_50yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Alloyed Ban Baseline',color=colors[0])
ax1.plot(all_scrap_available_no_accumulation_alloyed_50yoy_dec100_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -100',color=colors[2])
ax1.plot(all_scrap_available_no_accumulation_alloyed_50yoy_dec200_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -200',color=colors[4])
ax1.set_title('Scrap Entering Inventory Response \nGlobal, Alloyed Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(all_scrap_available_no_accumulation_alloyed_50yoy_inc200_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +200',color=colors[3])
ax2.plot(all_scrap_available_no_accumulation_alloyed_50yoy_inc100_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +100',color=colors[1])
ax2.plot(all_scrap_available_no_accumulation_alloyed_50yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Alloyed Ban Baseline',color=colors[0])
ax2.plot(all_scrap_available_no_accumulation_alloyed_50yoy_dec100_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -100',color=colors[2])
ax2.plot(all_scrap_available_no_accumulation_alloyed_50yoy_dec200_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -200',color=colors[4])
ax2.set_title('Scrap Entering Inventory Response \nChina, Alloyed Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(all_scrap_available_no_accumulation_alloyed_50yoy_inc200_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +200',color=colors[3])
ax3.plot(all_scrap_available_no_accumulation_alloyed_50yoy_inc100_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +100',color=colors[1])
ax3.plot(all_scrap_available_no_accumulation_alloyed_50yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Alloyed Ban Baseline',color=colors[0])
ax3.plot(all_scrap_available_no_accumulation_alloyed_50yoy_dec100_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -100',color=colors[2])
ax3.plot(all_scrap_available_no_accumulation_alloyed_50yoy_dec200_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -200',color=colors[4])
ax3.set_title('Scrap Entering Inventory Response \nRoW, Alloyed Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig3,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(all_scrap_available_no_accumulation_both_50yoy_inc200_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +200',color=colors[3])
ax1.plot(all_scrap_available_no_accumulation_both_50yoy_inc100_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +100',color=colors[1])
ax1.plot(all_scrap_available_no_accumulation_both_50yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Both Ban Baseline',color=colors[0])
ax1.plot(all_scrap_available_no_accumulation_both_50yoy_dec100_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -100',color=colors[2])
ax1.plot(all_scrap_available_no_accumulation_both_50yoy_dec200_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -200',color=colors[4])
ax1.set_title('Scrap Entering Inventory Response \nGlobal, Both Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(all_scrap_available_no_accumulation_both_50yoy_inc200_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +200',color=colors[3])
ax2.plot(all_scrap_available_no_accumulation_both_50yoy_inc100_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +100',color=colors[1])
ax2.plot(all_scrap_available_no_accumulation_both_50yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Both Ban Baseline',color=colors[0])
ax2.plot(all_scrap_available_no_accumulation_both_50yoy_dec100_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -100',color=colors[2])
ax2.plot(all_scrap_available_no_accumulation_both_50yoy_dec200_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -200',color=colors[4])
ax2.set_title('Scrap Entering Inventory Response \nChina, Both Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(all_scrap_available_no_accumulation_both_50yoy_inc200_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +200',color=colors[3])
ax3.plot(all_scrap_available_no_accumulation_both_50yoy_inc100_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import +100',color=colors[1])
ax3.plot(all_scrap_available_no_accumulation_both_50yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Both Ban Baseline',color=colors[0])
ax3.plot(all_scrap_available_no_accumulation_both_50yoy_dec100_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -100',color=colors[2])
ax3.plot(all_scrap_available_no_accumulation_both_50yoy_dec200_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='Ref. Import -200',color=colors[4])
ax3.set_title('Scrap Entering Inventory Response \nRoW, Both Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Scrap entering inventory response, ban rate sensitivities

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'


fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(all_scrap_available_no_accumulation_no2_50yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='50% YOY',color=colors[0])
ax1.plot(all_scrap_available_no_accumulation_no2_25yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='25% YOY',color=colors[1])
ax1.plot(all_scrap_available_no_accumulation_no2_75yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='75% YOY',color=colors[2])
ax1.set_title('Scrap Entering Inventory Response \nGlobal, No.2 Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(all_scrap_available_no_accumulation_no2_50yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='50% YOY',color=colors[0])
ax2.plot(all_scrap_available_no_accumulation_no2_25yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='25% YOY',color=colors[1])
ax2.plot(all_scrap_available_no_accumulation_no2_75yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='75% YOY',color=colors[2])
ax2.set_title('Scrap Entering Inventory Response \nChina, No.2 Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(all_scrap_available_no_accumulation_no2_50yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='50% YOY',color=colors[0])
ax3.plot(all_scrap_available_no_accumulation_no2_25yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='25% YOY',color=colors[1])
ax3.plot(all_scrap_available_no_accumulation_no2_75yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='75% YOY',color=colors[2])
ax3.set_title('Scrap Entering Inventory Response \nRoW, No.2 Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig2,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(all_scrap_available_no_accumulation_alloyed_50yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='50% YOY',color=colors[0])
ax1.plot(all_scrap_available_no_accumulation_alloyed_25yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='25% YOY',color=colors[1])
ax1.plot(all_scrap_available_no_accumulation_alloyed_75yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='75% YOY',color=colors[2])
ax1.set_title('Scrap Entering Inventory Response \nGlobal, Alloyed Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(all_scrap_available_no_accumulation_alloyed_50yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='50% YOY',color=colors[0])
ax2.plot(all_scrap_available_no_accumulation_alloyed_25yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='25% YOY',color=colors[1])
ax2.plot(all_scrap_available_no_accumulation_alloyed_75yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='75% YOY',color=colors[2])
ax2.set_title('Scrap Entering Inventory Response \nChina, Alloyed Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(all_scrap_available_no_accumulation_alloyed_50yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='50% YOY',color=colors[0])
ax3.plot(all_scrap_available_no_accumulation_alloyed_25yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='25% YOY',color=colors[1])
ax3.plot(all_scrap_available_no_accumulation_alloyed_75yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='75% YOY',color=colors[2])
ax3.set_title('Scrap Entering Inventory Response \nRoW, Alloyed Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig3,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(all_scrap_available_no_accumulation_both_50yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='50% YOY',color=colors[0])
ax1.plot(all_scrap_available_no_accumulation_both_25yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='25% YOY',color=colors[1])
ax1.plot(all_scrap_available_no_accumulation_both_75yoy_gl.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1).cumsum(), label='75% YOY',color=colors[2])
ax1.set_title('Scrap Entering Inventory Response \nGlobal, Both Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(all_scrap_available_no_accumulation_both_50yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='50% YOY',color=colors[0])
ax2.plot(all_scrap_available_no_accumulation_both_25yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='25% YOY',color=colors[1])
ax2.plot(all_scrap_available_no_accumulation_both_75yoy_cn.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1).cumsum(), label='75% YOY',color=colors[2])
ax2.set_title('Scrap Entering Inventory Response \nChina, Both Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(all_scrap_available_no_accumulation_both_50yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='50% YOY',color=colors[0])
ax3.plot(all_scrap_available_no_accumulation_both_25yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='25% YOY',color=colors[1])
ax3.plot(all_scrap_available_no_accumulation_both_75yoy_rw.loc['20170101':].sum(axis=1).cumsum() - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1).cumsum(), label='75% YOY',color=colors[2])
ax3.set_title('Scrap Entering Inventory Response \nRoW, Both Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Shock, refined import sensitivities

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'


fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(shock_no2_50yoy.loc['20170101':].cumsum(), label='No.2 Ban Baseline',color=colors[0])
ax1.plot(shock_no2_50yoy_inc100.loc['20170101':].cumsum(), label='Ref. Import +100',color=colors[1])
ax1.plot(shock_no2_50yoy_dec100.loc['20170101':].cumsum(), label='Ref. Import -100',color=colors[2])
ax1.plot(shock_no2_50yoy_inc200.loc['20170101':].cumsum(), label='Ref. Import +200',color=colors[3])
ax1.plot(shock_no2_50yoy_dec200.loc['20170101':].cumsum(), label='Ref. Import -200',color=colors[4])
ax1.set_title('Total Scrap Availability Response\nGlobal, No.2 Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(shock_no2_50yoy_cn.loc['20170101':].cumsum(), label='No.2 Ban Baseline',color=colors[0])
ax2.plot(shock_no2_50yoy_inc100_cn.loc['20170101':].cumsum(), label='Ref. Import +100',color=colors[1])
ax2.plot(shock_no2_50yoy_dec100_cn.loc['20170101':].cumsum(), label='Ref. Import -100',color=colors[2])
ax2.plot(shock_no2_50yoy_inc200_cn.loc['20170101':].cumsum(), label='Ref. Import +200',color=colors[3])
ax2.plot(shock_no2_50yoy_dec200_cn.loc['20170101':].cumsum(), label='Ref. Import -200',color=colors[4])
ax2.set_title('Total Scrap Availability Response\nChina, No.2 Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(shock_no2_50yoy_rw.loc['20170101':].cumsum(), label='No.2 Ban Baseline',color=colors[0])
ax3.plot(shock_no2_50yoy_inc100_rw.loc['20170101':].cumsum(), label='Ref. Import +100',color=colors[1])
ax3.plot(shock_no2_50yoy_dec100_rw.loc['20170101':].cumsum(), label='Ref. Import -100',color=colors[2])
ax3.plot(shock_no2_50yoy_inc200_rw.loc['20170101':].cumsum(), label='Ref. Import +200',color=colors[3])
ax3.plot(shock_no2_50yoy_dec200_rw.loc['20170101':].cumsum(), label='Ref. Import -200',color=colors[4])
ax3.set_title('Total Scrap Availability Response\nRoW, No.2 Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig2,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(shock_alloyed_50yoy.loc['20170101':].cumsum(), label='Constant Refined Imports',color=colors[0])
ax1.plot(shock_alloyed_50yoy_inc100.loc['20170101':].cumsum(), label='Ref. Import +100',color=colors[1])
ax1.plot(shock_alloyed_50yoy_dec100.loc['20170101':].cumsum(), label='Ref. Import -100',color=colors[2])
ax1.plot(shock_alloyed_50yoy_inc200.loc['20170101':].cumsum(), label='Ref. Import +200',color=colors[3])
ax1.plot(shock_alloyed_50yoy_dec200.loc['20170101':].cumsum(), label='Ref. Import -200',color=colors[4])
ax1.set_title('Total Scrap Availability Response\nGlobal, Alloyed Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(shock_alloyed_50yoy_cn.loc['20170101':].cumsum(), label='Constant Refined Imports',color=colors[0])
ax2.plot(shock_alloyed_50yoy_inc100_cn.loc['20170101':].cumsum(), label='Ref. Import +100',color=colors[1])
ax2.plot(shock_alloyed_50yoy_dec100_cn.loc['20170101':].cumsum(), label='Ref. Import -100',color=colors[2])
ax2.plot(shock_alloyed_50yoy_inc200_cn.loc['20170101':].cumsum(), label='Ref. Import +200',color=colors[3])
ax2.plot(shock_alloyed_50yoy_dec200_cn.loc['20170101':].cumsum(), label='Ref. Import -200',color=colors[4])
ax2.set_title('Total Scrap Availability Response\nChina, Alloyed Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(shock_alloyed_50yoy_rw.loc['20170101':].cumsum(), label='Constant Refined Imports',color=colors[0])
ax3.plot(shock_alloyed_50yoy_inc100_rw.loc['20170101':].cumsum(), label='Ref. Import +100',color=colors[1])
ax3.plot(shock_alloyed_50yoy_dec100_rw.loc['20170101':].cumsum(), label='Ref. Import -100',color=colors[2])
ax3.plot(shock_alloyed_50yoy_inc200_rw.loc['20170101':].cumsum(), label='Ref. Import +200',color=colors[3])
ax3.plot(shock_alloyed_50yoy_dec200_rw.loc['20170101':].cumsum(), label='Ref. Import -200',color=colors[4])
ax3.set_title('Total Scrap Availability Response\nRoW, Alloyed Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig3,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(shock_both_50yoy.loc['20170101':].cumsum(), label='Constant Refined Imports',color=colors[0])
ax1.plot(shock_both_50yoy_inc100.loc['20170101':].cumsum(), label='Ref. Import +100',color=colors[1])
ax1.plot(shock_both_50yoy_dec100.loc['20170101':].cumsum(), label='Ref. Import -100',color=colors[2])
ax1.plot(shock_both_50yoy_inc200.loc['20170101':].cumsum(), label='Ref. Import +200',color=colors[3])
ax1.plot(shock_both_50yoy_dec200.loc['20170101':].cumsum(), label='Ref. Import -200',color=colors[4])
ax1.set_title('Total Scrap Availability Response\nGlobal, Both Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(shock_both_50yoy_cn.loc['20170101':].cumsum(), label='Constant Refined Imports',color=colors[0])
ax2.plot(shock_both_50yoy_inc100_cn.loc['20170101':].cumsum(), label='Ref. Import +100',color=colors[1])
ax2.plot(shock_both_50yoy_dec100_cn.loc['20170101':].cumsum(), label='Ref. Import -100',color=colors[2])
ax2.plot(shock_both_50yoy_inc200_cn.loc['20170101':].cumsum(), label='Ref. Import +200',color=colors[3])
ax2.plot(shock_both_50yoy_dec200_cn.loc['20170101':].cumsum(), label='Ref. Import -200',color=colors[4])
ax2.set_title('Total Scrap Availability Response\nChina, Both Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(shock_both_50yoy_rw.loc['20170101':].cumsum(), label='Constant Refined Imports',color=colors[0])
ax3.plot(shock_both_50yoy_inc100_rw.loc['20170101':].cumsum(), label='Ref. Import +100',color=colors[1])
ax3.plot(shock_both_50yoy_dec100_rw.loc['20170101':].cumsum(), label='Ref. Import -100',color=colors[2])
ax3.plot(shock_both_50yoy_inc200_rw.loc['20170101':].cumsum(), label='Ref. Import +200',color=colors[3])
ax3.plot(shock_both_50yoy_dec200_rw.loc['20170101':].cumsum(), label='Ref. Import -200',color=colors[4])
ax3.set_title('Total Scrap Availability Response\nRoW, Both Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Shock, ban rate sensitivities

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'


fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(shock_no2_50yoy.loc['20170101':].cumsum(), label='50% YOY',color=colors[0])
ax1.plot(shock_no2_25yoy.loc['20170101':].cumsum(), label='25% YOY',color=colors[1])
ax1.plot(shock_no2_75yoy.loc['20170101':].cumsum(), label='75% YOY',color=colors[2])
ax1.set_title('Total Scrap Availability Response \nGlobal, No.2 Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(shock_no2_50yoy_cn.loc['20170101':].cumsum(), label='50% YOY',color=colors[0])
ax2.plot(shock_no2_25yoy_cn.loc['20170101':].cumsum(), label='25% YOY',color=colors[1])
ax2.plot(shock_no2_75yoy_cn.loc['20170101':].cumsum(), label='75% YOY',color=colors[2])
ax2.set_title('Total Scrap Availability Response \nChina, No.2 Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(shock_no2_50yoy_rw.loc['20170101':].cumsum(), label='50% YOY',color=colors[0])
ax3.plot(shock_no2_25yoy_rw.loc['20170101':].cumsum(), label='25% YOY',color=colors[1])
ax3.plot(shock_no2_75yoy_rw.loc['20170101':].cumsum(), label='75% YOY',color=colors[2])
ax3.set_title('Total Scrap Availability Response \nRoW, No.2 Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig2,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(shock_alloyed_50yoy.loc['20170101':].cumsum(), label='50% YOY',color=colors[0])
ax1.plot(shock_alloyed_25yoy.loc['20170101':].cumsum(), label='25% YOY',color=colors[1])
ax1.plot(shock_alloyed_75yoy.loc['20170101':].cumsum(), label='75% YOY',color=colors[2])
ax1.set_title('Total Scrap Availability Response \nGlobal, Alloyed Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(shock_alloyed_50yoy_cn.loc['20170101':].cumsum(), label='50% YOY',color=colors[0])
ax2.plot(shock_alloyed_25yoy_cn.loc['20170101':].cumsum(), label='25% YOY',color=colors[1])
ax2.plot(shock_alloyed_75yoy_cn.loc['20170101':].cumsum(), label='75% YOY',color=colors[2])
ax2.set_title('Total Scrap Availability Response \nChina, Alloyed Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(shock_alloyed_50yoy_rw.loc['20170101':].cumsum(), label='50% YOY',color=colors[0])
ax3.plot(shock_alloyed_25yoy_rw.loc['20170101':].cumsum(), label='25% YOY',color=colors[1])
ax3.plot(shock_alloyed_75yoy_rw.loc['20170101':].cumsum(), label='75% YOY',color=colors[2])
ax3.set_title('Total Scrap Availability Response \nRoW, Alloyed Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig3,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(shock_both_50yoy.loc['20170101':].cumsum(), label='50% YOY',color=colors[0])
ax1.plot(shock_both_25yoy.loc['20170101':].cumsum(), label='25% YOY',color=colors[1])
ax1.plot(shock_both_75yoy.loc['20170101':].cumsum(), label='75% YOY',color=colors[2])
ax1.set_title('Total Scrap Availability Response \nGlobal, Both Ban 50% YOY')
ax1.set_ylabel('Cumulative scrap response (kt)')
ax1.set_xlabel('Year')
ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(shock_both_50yoy_cn.loc['20170101':].cumsum(), label='50% YOY',color=colors[0])
ax2.plot(shock_both_25yoy_cn.loc['20170101':].cumsum(), label='25% YOY',color=colors[1])
ax2.plot(shock_both_75yoy_cn.loc['20170101':].cumsum(), label='75% YOY',color=colors[2])
ax2.set_title('Total Scrap Availability Response \nChina, Both Ban 50% YOY')
ax2.set_ylabel('Cumulative scrap response (kt)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(shock_both_50yoy_rw.loc['20170101':].cumsum(), label='50% YOY',color=colors[0])
ax3.plot(shock_both_25yoy_rw.loc['20170101':].cumsum(), label='25% YOY',color=colors[1])
ax3.plot(shock_both_75yoy_rw.loc['20170101':].cumsum(), label='75% YOY',color=colors[2])
ax3.set_title('Total Scrap Availability Response \nRoW, Both Ban 50% YOY')
ax3.set_ylabel('Cumulative scrap response (kt)')
ax3.set_xlabel('Year')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Fill between plots for refined import sensitivities

# %%
plt.figure()
pplot(scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':], '<99% Ban', colors[2], firstcall=1)
plt.fill_between(scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':].index, 
                 np.sort(pd.concat([scrap_demand_pctinc2020_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,0], 
                 np.sort(pd.concat([scrap_demand_pctinc2020_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,-1], 
                 color = colors[2], alpha=0.3)
plt.fill_between(scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':].index, 
                 np.sort(pd.concat([scrap_demand_pctinc2020_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,1], 
                 np.sort(pd.concat([scrap_demand_pctinc2020_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,-2], 
                 color = colors[2], alpha=0.3)
# pplot(scrap_demand_pctinc2020_both_50yoy_inc200_gl.loc['20180101':], '<99% Ban', 'limegreen')

plt.title('Scrap Consumption Response Above Baseline')
plt.legend().set_visible(False)
plt.ylabel('Scrap consumption response \n(Cumulative, % of 2020 value)')
plt.yticks([-20,-10,0,10])
plt.show()

# %% [markdown]
# Fill between plots for refined import sensitivities, extras

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'

fig4,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(scrap_demand_response_alloyed_50yoy_gl.loc['20170101':], label='Alloyed Ban',color=colors[0])
ax1.plot(scrap_demand_response_no2_50yoy_gl.loc['20170101':], label='No.2 Ban',color=colors[1])
ax1.plot(scrap_demand_response_both_50yoy_gl.loc['20170101':], label='Both Ban',color=colors[2])

ax1.fill_between(scrap_demand_response_alloyed_50yoy_gl.loc['20170101':].index, 
                 scrap_demand_response_alloyed_50yoy_inc100_gl.loc['20170101':], 
                 scrap_demand_response_alloyed_50yoy_dec100_gl.loc['20170101':], 
                 color = colors[0], alpha=0.2)
ax1.fill_between(scrap_demand_response_no2_50yoy_gl.loc['20170101':].index, 
                 scrap_demand_response_no2_50yoy_inc100_gl.loc['20170101':], 
                 scrap_demand_response_no2_50yoy_dec100_gl.loc['20170101':], 
                 color = colors[1], alpha=0.2)
ax1.fill_between(scrap_demand_response_both_50yoy_gl.loc['20170101':].index, 
                 scrap_demand_response_both_50yoy_inc100_gl.loc['20170101':], 
                 scrap_demand_response_both_50yoy_dec100_gl.loc['20170101':], 
                 color = colors[2], alpha=0.2)

ax1.set_title('Scrap Demand Response \nGlobal, 50% YOY Refined Import Sensitivity')
ax1.set_ylabel('Cumulative scrap response (kt)')

# ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
ax1.set_axisbelow(True)

ax2.plot(scrap_demand_response_alloyed_50yoy_cn.loc['20170101':], label='Alloyed Ban',color=colors[0])
ax2.plot(scrap_demand_response_no2_50yoy_cn.loc['20170101':], label='No.2 Ban',color=colors[1])
ax2.plot(scrap_demand_response_both_50yoy_cn.loc['20170101':], label='Both Ban',color=colors[2])

ax2.fill_between(scrap_demand_response_alloyed_50yoy_cn.loc['20170101':].index, 
                 scrap_demand_response_alloyed_50yoy_inc100_cn.loc['20170101':], 
                 scrap_demand_response_alloyed_50yoy_dec100_cn.loc['20170101':], 
                 color = colors[0], alpha=0.3)
ax2.fill_between(scrap_demand_response_no2_50yoy_cn.loc['20170101':].index, 
                 scrap_demand_response_no2_50yoy_inc100_cn.loc['20170101':], 
                 scrap_demand_response_no2_50yoy_dec100_cn.loc['20170101':], 
                 color = colors[1], alpha=0.3)
ax2.fill_between(scrap_demand_response_both_50yoy_cn.loc['20170101':].index, 
                 scrap_demand_response_both_50yoy_inc100_cn.loc['20170101':], 
                 scrap_demand_response_both_50yoy_dec100_cn.loc['20170101':], 
                 color = colors[2], alpha=0.3)
ax2.fill_between(scrap_demand_response_alloyed_50yoy_cn.loc['20170101':].index, 
                 scrap_demand_response_alloyed_50yoy_inc200_cn.loc['20170101':], 
                 scrap_demand_response_alloyed_50yoy_dec200_cn.loc['20170101':], 
                 color = colors[0], alpha=0.3)
ax2.fill_between(scrap_demand_response_no2_50yoy_cn.loc['20170101':].index, 
                 scrap_demand_response_no2_50yoy_inc200_cn.loc['20170101':], 
                 scrap_demand_response_no2_50yoy_dec200_cn.loc['20170101':], 
                 color = colors[1], alpha=0.3)
ax2.fill_between(scrap_demand_response_both_50yoy_cn.loc['20170101':].index, 
                 scrap_demand_response_both_50yoy_inc200_cn.loc['20170101':], 
                 scrap_demand_response_both_50yoy_dec200_cn.loc['20170101':], 
                 color = colors[2], alpha=0.3)


ax2.set_title('Scrap Demand Response \nChina, 50% YOY Refined Import Sensitivity')
ax2.set_ylabel('Cumulative scrap response (kt)')

# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
ax2.set_axisbelow(True)

ax3.plot(scrap_demand_response_alloyed_50yoy_rw.loc['20170101':], label='Alloyed Ban',color=colors[0])
ax3.plot(scrap_demand_response_no2_50yoy_rw.loc['20170101':], label='No.2 Ban',color=colors[1])
ax3.plot(scrap_demand_response_both_50yoy_rw.loc['20170101':], label='Both Ban',color=colors[2])

ax3.fill_between(scrap_demand_response_alloyed_50yoy_rw.loc['20170101':].index, 
                 scrap_demand_response_alloyed_50yoy_inc100_rw.loc['20170101':], 
                 scrap_demand_response_alloyed_50yoy_dec100_rw.loc['20170101':], 
                 color = colors[0], alpha=0.3)
ax3.fill_between(scrap_demand_response_no2_50yoy_rw.loc['20170101':].index, 
                 scrap_demand_response_no2_50yoy_inc100_rw.loc['20170101':], 
                 scrap_demand_response_no2_50yoy_dec100_rw.loc['20170101':], 
                 color = colors[1], alpha=0.3)
ax3.fill_between(scrap_demand_response_both_50yoy_rw.loc['20170101':].index, 
                 scrap_demand_response_both_50yoy_inc100_rw.loc['20170101':], 
                 scrap_demand_response_both_50yoy_dec100_rw.loc['20170101':], 
                 color = colors[2], alpha=0.3)
ax3.fill_between(scrap_demand_response_alloyed_50yoy_rw.loc['20170101':].index, 
                 scrap_demand_response_alloyed_50yoy_inc200_rw.loc['20170101':], 
                 scrap_demand_response_alloyed_50yoy_dec200_rw.loc['20170101':], 
                 color = colors[0], alpha=0.3)
ax3.fill_between(scrap_demand_response_no2_50yoy_rw.loc['20170101':].index, 
                 scrap_demand_response_no2_50yoy_inc200_rw.loc['20170101':], 
                 scrap_demand_response_no2_50yoy_dec200_rw.loc['20170101':], 
                 color = colors[1], alpha=0.3)
ax3.fill_between(scrap_demand_response_both_50yoy_rw.loc['20170101':].index, 
                 scrap_demand_response_both_50yoy_inc200_rw.loc['20170101':], 
                 scrap_demand_response_both_50yoy_dec200_rw.loc['20170101':], 
                 color = colors[2], alpha=0.3)

ax3.set_title('Scrap Demand Response \nRoW, 50% YOY Refined Import Sensitivity')
ax3.set_ylabel('Cumulative scrap response (kt)')

# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
ax3.set_axisbelow(True)

# %% [markdown]
# Fill between plots for ban rate sensitivities

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [15, 5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'

fig5,(ax2,ax3) = plt.subplots(1,2, frameon=False)
ax2.plot(scrap_demand_pctinc2020_alloyed_50yoy_cn.loc['20170101':], label='Alloyed Ban',color=colors[0])
ax2.plot(scrap_demand_pctinc2020_no2_50yoy_cn.loc['20170101':], label='No.2 Ban',color=colors[1])
ax2.plot(scrap_demand_pctinc2020_both_50yoy_cn.loc['20170101':], label='Both Ban',color=colors[2])

ax2.fill_between(scrap_demand_pctinc2020_alloyed_50yoy_cn.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[0], alpha=0.3)
ax2.fill_between(scrap_demand_pctinc2020_no2_50yoy_cn.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[1], alpha=0.3)
ax2.fill_between(scrap_demand_pctinc2020_both_50yoy_cn.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[2], alpha=0.3)

ax2.set_title('China Scrap Consumption Response')
ax2.set_ylabel('Cumulative scrap response (% of 2020 value)')

# ax2.legend()
ax2.set_yticks(ax2.get_yticks()[::2])
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
ax2.set_axisbelow(True)

ax3.plot(scrap_demand_pctinc2020_alloyed_50yoy_rw.loc['20170101':], label='Alloyed Ban',color=colors[0])
ax3.plot(scrap_demand_pctinc2020_no2_50yoy_rw.loc['20170101':], label='No.2 Ban',color=colors[1])
ax3.plot(scrap_demand_pctinc2020_both_50yoy_rw.loc['20170101':], label='Both Ban',color=colors[2])

ax3.fill_between(scrap_demand_pctinc2020_alloyed_50yoy_rw.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[0], alpha=0.3)
ax3.fill_between(scrap_demand_pctinc2020_no2_50yoy_rw.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[1], alpha=0.3)
ax3.fill_between(scrap_demand_pctinc2020_both_50yoy_rw.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[2], alpha=0.3)

ax3.set_title('Rest of World Scrap Consumption Response')
ax3.set_ylabel('Cumulative scrap response (% of 2020 value)')

# ax3.legend()
ax3.set_yticks(ax3.get_yticks()[1::2])
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
ax3.set_axisbelow(True)


mpl.rcParams.update({'figure.figsize': [8, 4]})
fig, ax1 = plt.subplots()
ax1.plot(scrap_demand_pctinc2020_alloyed_50yoy_gl.loc['20170101':], label='Alloyed Ban',color=colors[0])
ax1.plot(scrap_demand_pctinc2020_no2_50yoy_gl.loc['20170101':], label='No.2 Ban',color=colors[1])
ax1.plot(scrap_demand_pctinc2020_both_50yoy_gl.loc['20170101':], label='Both Ban',color=colors[2])

ax1.fill_between(scrap_demand_pctinc2020_alloyed_50yoy_gl.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[0], alpha=0.3)
ax1.fill_between(scrap_demand_pctinc2020_no2_50yoy_gl.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[1], alpha=0.3)
ax1.fill_between(scrap_demand_pctinc2020_both_50yoy_gl.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[2], alpha=0.3)

ax1.set_title('Global Scrap Consumption Response')
ax1.set_ylabel('Cumulative scrap response (% of 2020 value)')
ax1.set_yticks(ax1.get_yticks()[::2])
# ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
ax1.set_axisbelow(True)

# %% [markdown]
# #### Zeng linear import decrease

# %%
plt.figure()
plt.rc('axes', axisbelow=True)
# pplot(shock_ban_zeng_low_gl.loc['20170101':], label='Scrap demand: Zeng, lower bound',color='springgreen')
pplot(0.001*shock_ban_zeng_mean.loc['20170101':], label='Global Scrap demand',color=colors[0], firstcall=1)
# pplot(shock_ban_zeng_high_gl.loc['20170101':], label='Scrap demand: Zeng, upper bound',color='darkgreen')
pplot(0.001*shock_ban_zeng_mean_cn.loc['20170101':], label='CN Scrap demand',color=colors[1])
pplot(0.001*shock_ban_zeng_mean_rw.loc['20170101':], label='RoW Scrap demand',color=colors[2])
plt.fill_between(shock_ban_zeng_mean.loc['20170101':].index,
                0.001*shock_ban_zeng_low.loc['20170101':],
                0.001*shock_ban_zeng_high.loc['20170101':], color = colors[0], alpha=0.3)
plt.fill_between(shock_ban_zeng_mean.loc['20170101':].index,
                0.001*shock_ban_zeng_low_cn.loc['20170101':],
                0.001*shock_ban_zeng_high_cn.loc['20170101':], color = colors[1], alpha=0.3)
plt.fill_between(shock_ban_zeng_mean.loc['20170101':].index,
                0.001*shock_ban_zeng_low_rw.loc['20170101':],
                0.001*shock_ban_zeng_high_rw.loc['20170101':], color = colors[2], alpha=0.3)
plt.title('Scrap Availability Response above Baseline \nSensitivity to Zeng Paper Projections')
plt.ylabel('Scrap response above baseline (Mt)')
plt.xlabel('Year')
# plt.legend().set_visible(False)

# plt.figure()
plt.rc('axes', axisbelow=True)
pplot(0.001*(all_scrap_available_no_accumulation_ban_zeng_mean_gl.loc['20170101':].sum(axis=1) - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1)), label='Scrap demand: Zeng, mean value',color=colors[0], firstcall=1)
pplot(0.001*(all_scrap_available_no_accumulation_ban_zeng_mean_cn.loc['20170101':].sum(axis=1) - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1)), label='CN Scrap demand: Zeng, mean value',color=colors[1])
pplot(0.001*(all_scrap_available_no_accumulation_ban_zeng_mean_rw.loc['20170101':].sum(axis=1) - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1)), label='RoW Scrap demand: Zeng, mean value',color=colors[2])
plt.fill_between(all_scrap_available_no_accumulation_ban_zeng_mean_gl.loc['20170101':].sum(axis=1).index,
                0.001*(all_scrap_available_no_accumulation_ban_zeng_low_gl.loc['20170101':].sum(axis=1) - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1)),
                0.001*(all_scrap_available_no_accumulation_ban_zeng_high_gl.loc['20170101':].sum(axis=1) - all_scrap_available_no_accumulation_pir_baseline_gl.loc['20170101':].sum(axis=1)), color = colors[0], alpha=0.3)
plt.fill_between(all_scrap_available_no_accumulation_ban_zeng_mean_cn.loc['20170101':].sum(axis=1).index,
                0.001*(all_scrap_available_no_accumulation_ban_zeng_low_cn.loc['20170101':].sum(axis=1) - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1)),
                0.001*(all_scrap_available_no_accumulation_ban_zeng_high_cn.loc['20170101':].sum(axis=1) - all_scrap_available_no_accumulation_pir_baseline_cn.loc['20170101':].sum(axis=1)), color = colors[1], alpha=0.3)
plt.fill_between(all_scrap_available_no_accumulation_ban_zeng_mean_rw.loc['20170101':].sum(axis=1).index,
                0.001*(all_scrap_available_no_accumulation_ban_zeng_low_rw.loc['20170101':].sum(axis=1) - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1)),
                0.001*(all_scrap_available_no_accumulation_ban_zeng_high_rw.loc['20170101':].sum(axis=1) - all_scrap_available_no_accumulation_pir_baseline_rw.loc['20170101':].sum(axis=1)), color = colors[2], alpha=0.3)
plt.title('Scrap Entering Inventory Response above Baseline \nSensitivity to Zeng Paper Projections')
plt.ylabel('Scrap response above baseline (Mt)')
plt.xlabel('Year')
plt.legend().set_visible(False)


plt.figure()
plt.rc('axes', axisbelow=True)
# pplot(scrap_demand_response_ban_zeng_low_gl.loc['20170101':], label='Scrap demand: Zeng, lower bound',color='springgreen')
pplot(0.001*scrap_demand_response_ban_zeng_mean_gl.loc['20170101':], label='Scrap demand: Zeng, mean value',color=colors[0], firstcall=1)
# pplot(scrap_demand_response_ban_zeng_high_gl.loc['20170101':], label='Scrap demand: Zeng, upper bound',color='darkgreen')
pplot(0.001*scrap_demand_response_ban_zeng_mean_cn.loc['20170101':], label='CN Scrap demand: Zeng, mean value',color=colors[1])
pplot(0.001*scrap_demand_response_ban_zeng_mean_rw.loc['20170101':], label='RoW Scrap demand: Zeng, mean value',color=colors[2])
plt.fill_between(scrap_demand_response_ban_zeng_mean_gl.loc['20170101':].index,
                0.001*scrap_demand_response_ban_zeng_low_gl.loc['20170101':],
                0.001*scrap_demand_response_ban_zeng_high_gl.loc['20170101':], color = colors[0], alpha=0.3)
plt.fill_between(scrap_demand_response_ban_zeng_mean_gl.loc['20170101':].index,
                0.001*scrap_demand_response_ban_zeng_low_cn.loc['20170101':],
                0.001*scrap_demand_response_ban_zeng_high_cn.loc['20170101':], color = colors[1], alpha=0.3)
plt.fill_between(scrap_demand_response_ban_zeng_mean_gl.loc['20170101':].index,
                0.001*scrap_demand_response_ban_zeng_low_rw.loc['20170101':],
                0.001*scrap_demand_response_ban_zeng_high_rw.loc['20170101':], color = colors[2], alpha=0.3)
plt.title('Scrap Demand Response above Baseline \nSensitivity to Zeng Paper Projections')
plt.ylabel('Scrap response above baseline (Mt)')
plt.xlabel('Year')
plt.legend().set_visible(False)

# %% [markdown]
# Scrap response for Linear Approach to 20% Base Shock

# %%
pplot(shock_lin1yr20.cumsum().loc['20180101':], label='1 year ramp',color='tab:blue')
pplot(shock_lin5yr20.cumsum().loc['20180101':], label='5 year ramp',color='tab:orange')
pplot(shock_lin10yr20.cumsum().loc['20180101':], label='10 year ramp',color='lightseagreen')
pplot(shock_lin20yr20.cumsum().loc['20180101':], label='20 year ramp',color='tab:brown')
# pplot(-shock_john1.cumsum().loc['20190101':], label='1 year, 2600')
# pplot(-shock_john5.cumsum().loc['20190101':], label='4 year, 2600')

plt.title('Scrap Response above Baseline \n(Linear Ramp to 20% Base Shock)')
plt.ylabel('Scrap response above baseline (kt)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %% [markdown]
# Scrap response for Linear Approach to 50% Base Shock

# %%
displacement_lin20yr50.loc['20400101']

# %% [markdown]
# Unknown...

# %%
pplot(sd_scrap_baseline_baseline.iloc[10:, 0], 'k', label='Scrap supply')
plt.stackplot(sd_scrap_baseline_baseline.iloc[10:, 1:].index, sd_scrap_baseline_baseline.iloc[10:, 1:].transpose(), 
              labels=['Direct melt scrap consumption', 'Refined scrap consumption'])

pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [500, 15500], 'k--')
plt.xlabel('Year')
plt.ylabel('Scrap supply and consumption (kt)')
plt.legend()
plt.show()

# %%
pplot(sd_scrap_baseline_baseline.iloc[10:, 2].div(sd_scrap_baseline_baseline.iloc[10:, 1:2].sum(axis=1)))

# %% [markdown]
# #### PIR / PCR Scrap Analysis

# %%
# fig, [ax1, ax2, ax3, ax4] = plt.subplots(1,4)
# psubplot(ax1, scrap_pctinc2020_pir85.loc['20180101':], label='PIR price 0.85',color='tab:gray', firstcall=1, width = 24)
# psubplot(ax1, scrap_pctinc2020_pir80.loc['20180101':], label='PIR price 0.80',color=colors[0])
# psubplot(ax1, scrap_pctinc2020_pir75.loc['20180101':], label='PIR price 0.75',color=colors[1])
# psubplot(ax1, scrap_pctinc2020_pir70.loc['20180101':], label='PIR price 0.70',color=colors[2])
# psubplot(ax1, scrap_pctinc2020_pir65.loc['20180101':], label='PIR price 0.65',color=colors[3])
# psubplot(ax1, scrap_pctinc2020_pir60.loc['20180101':], label='PIR price 0.60',color=colors[4])
# psubplot(ax2, scrap_pctinc2020_pcr101.loc['20180101':], label='PCR recovery 1.01',color='tab:gray', firstcall=1, width = 24)
# psubplot(ax2, scrap_pctinc2020_pcr102.loc['20180101':], label='PCR recovery 1.02',color=colors[0])
# psubplot(ax2, scrap_pctinc2020_pcr103.loc['20180101':], label='PCR recovery 1.03',color=colors[1])
# psubplot(ax2, scrap_pctinc2020_pcr104.loc['20180101':], label='PCR recovery 1.04',color=colors[2])
# psubplot(ax2, scrap_pctinc2020_pcr105.loc['20180101':], label='PCR recovery 1.05',color=colors[3])
# # psubplot(ax2, scrap_pctinc2020_pcr110.loc['20180101':], label='PCR recovery 1.10',color=colors[4])
# psubplot(ax3, scrap_pctinc2020_pir_home09.loc['20180101':], label='pir_home scrap X 0.9',color=colors[0], firstcall=1, width = 24)
# psubplot(ax3, scrap_pctinc2020_pir_home08.loc['20180101':], label='pir_home scrap X 0.8',color=colors[1])
# psubplot(ax3, scrap_pctinc2020_pir_home07.loc['20180101':], label='pir_home scrap X 0.7',color=colors[2])
# psubplot(ax3, scrap_pctinc2020_pir_home06.loc['20180101':], label='pir_home scrap X 0.6',color=colors[3])
# psubplot(ax3, scrap_pctinc2020_pir_home05.loc['20180101':], label='pir_home scrap X 0.5',color=colors[4])
# psubplot(ax3, scrap_pctinc2020_pir_home04.loc['20180101':], label='pir_home scrap X 0.4',color='tab:gray')
# ax1.set_title('Scrap Supply Response above Baseline')
# ax1.set_ylabel('Scrap response above baseline \n(Cumulative, % of 2020 value)')
# ax2.set_title('Scrap Supply Response above Baseline')
# ax2.set_ylabel('Scrap response above baseline \n(Cumulative, % of 2020 value)')
# ax3.set_title('Scrap Supply Response above Baseline')
# ax3.set_ylabel('Scrap response above baseline \n(Cumulative, % of 2020 value)')

fig, [ax1, ax2, ax3, ax4] = plt.subplots(1,4)
psubplot(ax1, 0.001 * scrap_noacc_response_pir85_gl.loc['20180101':], label='PIR price 0.85',color='tab:gray', firstcall=1, width = 24)
psubplot(ax1, 0.001 * scrap_noacc_response_pir80_gl.loc['20180101':], label='PIR price 0.80',color=colors[0])
psubplot(ax1, 0.001 * scrap_noacc_response_pir75_gl.loc['20180101':], label='PIR price 0.75',color=colors[1])
psubplot(ax1, 0.001 * scrap_noacc_response_pir70_gl.loc['20180101':], label='PIR price 0.70',color=colors[2])
psubplot(ax1, 0.001 * scrap_noacc_response_pir65_gl.loc['20180101':], label='PIR price 0.65',color=colors[3])
psubplot(ax1, 0.001 * scrap_noacc_response_pir60_gl.loc['20180101':], label='PIR price 0.60',color=colors[4])
psubplot(ax2, 0.001 * scrap_noacc_response_pcr101_gl.loc['20180101':], label='PCR recovery 1.01',color='tab:gray', firstcall=1, width = 24)
psubplot(ax2, 0.001 * scrap_noacc_response_pcr102_gl.loc['20180101':], label='PCR recovery 1.02',color=colors[0])
psubplot(ax2, 0.001 * scrap_noacc_response_pcr103_gl.loc['20180101':], label='PCR recovery 1.03',color=colors[1])
psubplot(ax2, 0.001 * scrap_noacc_response_pcr104_gl.loc['20180101':], label='PCR recovery 1.04',color=colors[2])
psubplot(ax2, 0.001 * scrap_noacc_response_pcr105_gl.loc['20180101':], label='PCR recovery 1.05',color=colors[3])
# psubplot(ax2, 0.001 * scrap_noacc_response_pcr110_gl.loc['20180101':], label='PCR recovery 1.10',color=colors[4])
psubplot(ax3, 0.001 * scrap_noacc_response_pir_home09_gl.loc['20180101':], label='pir_home scrap X 0.9',color=colors[0], firstcall=1, width = 24)
psubplot(ax3, 0.001 * scrap_noacc_response_pir_home08_gl.loc['20180101':], label='pir_home scrap X 0.8',color=colors[1])
psubplot(ax3, 0.001 * scrap_noacc_response_pir_home07_gl.loc['20180101':], label='pir_home scrap X 0.7',color=colors[2])
psubplot(ax3, 0.001 * scrap_noacc_response_pir_home06_gl.loc['20180101':], label='pir_home scrap X 0.6',color=colors[3])
psubplot(ax3, 0.001 * scrap_noacc_response_pir_home05_gl.loc['20180101':], label='pir_home scrap X 0.5',color=colors[4])
psubplot(ax3, 0.001 * scrap_noacc_response_pir_home04_gl.loc['20180101':], label='pir_home scrap X 0.4',color='tab:gray')
psubplot(ax4, 0.001 * scrap_noacc_response_pcr_bal950_gl.loc['20180101':], label='PCR Scrap bal 0.950',color=colors[0], firstcall=1, width = 24)
psubplot(ax4, 0.001 * scrap_noacc_response_pcr_bal955_gl.loc['20180101':], label='PCR Scrap bal 0.955',color=colors[1])
psubplot(ax4, 0.001 * scrap_noacc_response_pcr_bal960_gl.loc['20180101':], label='PCR Scrap bal 0.960',color=colors[2])
psubplot(ax4, 0.001 * scrap_noacc_response_pcr_bal965_gl.loc['20180101':], label='PCR Scrap bal 0.965',color=colors[3])
psubplot(ax4, 0.001 * scrap_noacc_response_pcr_bal970_gl.loc['20180101':], label='PCR Scrap bal 0.970',color=colors[4])
psubplot(ax4, 0.001 * scrap_noacc_response_pcr_bal975_gl.loc['20180101':], label='PCR Scrap bal 0.975',color='tab:gray')
ax1.set_title('Scrap Supply Response above Baseline')
ax1.set_ylabel('Scrap response above baseline (Mt)')
ax2.set_title('Scrap Supply Response above Baseline')
ax2.set_ylabel('Scrap response above baseline (Mt)')
ax3.set_title('Scrap Supply Response above Baseline')
ax3.set_ylabel('Scrap response above baseline (Mt)')
ax4.set_title('Scrap Supply Response above Baseline')
ax4.set_ylabel('Scrap response above baseline (Mt)')
scrap_demand_pctinc_pcr_bal975_gl

# fig, [ax1, ax2, ax3, ax4] = plt.subplots(1,4)
# psubplot(ax1, scrap_demand_pctinc2020_pir85_gl.loc['20180101':], label='PIR price 0.85',color='tab:gray', firstcall=1, width = 24)
# psubplot(ax1, scrap_demand_pctinc2020_pir80_gl.loc['20180101':], label='PIR price 0.80',color=colors[0])
# psubplot(ax1, scrap_demand_pctinc2020_pir75_gl.loc['20180101':], label='PIR price 0.75',color=colors[1])
# psubplot(ax1, scrap_demand_pctinc2020_pir70_gl.loc['20180101':], label='PIR price 0.70',color=colors[2])
# psubplot(ax1, scrap_demand_pctinc2020_pir65_gl.loc['20180101':], label='PIR price 0.65',color=colors[3])
# psubplot(ax1, scrap_demand_pctinc2020_pir60_gl.loc['20180101':], label='PIR price 0.60',color=colors[4])
# psubplot(ax2, scrap_demand_pctinc2020_pcr101_gl.loc['20180101':], label='PCR recovery 1.01',color='tab:gray', firstcall=1, width = 24)
# psubplot(ax2, scrap_demand_pctinc2020_pcr102_gl.loc['20180101':], label='PCR recovery 1.02',color=colors[0])
# psubplot(ax2, scrap_demand_pctinc2020_pcr103_gl.loc['20180101':], label='PCR recovery 1.03',color=colors[1])
# psubplot(ax2, scrap_demand_pctinc2020_pcr104_gl.loc['20180101':], label='PCR recovery 1.04',color=colors[2])
# psubplot(ax2, scrap_demand_pctinc2020_pcr105_gl.loc['20180101':], label='PCR recovery 1.05',color=colors[3])
# # psubplot(ax2, scrap_demand_pctinc2020_pcr110_gl.loc['20180101':], label='PCR recovery 1.10',color=colors[4])
# psubplot(ax3, scrap_demand_pctinc2020_pir_home09_gl.loc['20180101':], label='pir_home scrap X 0.9',color=colors[0], firstcall=1, width = 24)
# psubplot(ax3, scrap_demand_pctinc2020_pir_home08_gl.loc['20180101':], label='pir_home scrap X 0.8',color=colors[1])
# psubplot(ax3, scrap_demand_pctinc2020_pir_home07_gl.loc['20180101':], label='pir_home scrap X 0.7',color=colors[2])
# psubplot(ax3, scrap_demand_pctinc2020_pir_home06_gl.loc['20180101':], label='pir_home scrap X 0.6',color=colors[3])
# psubplot(ax3, scrap_demand_pctinc2020_pir_home05_gl.loc['20180101':], label='pir_home scrap X 0.5',color=colors[4])
# psubplot(ax3, scrap_demand_pctinc2020_pir_home04_gl.loc['20180101':], label='pir_home scrap X 0.4',color='tab:gray')
# ax1.set_title('Scrap Demand Response above Baseline')
# ax1.set_ylabel('Scrap response above baseline \n(Cumulative, % of 2020 value)')
# ax2.set_title('Scrap Demand Response above Baseline')
# ax2.set_ylabel('Scrap response above baseline \n(Cumulative, % of 2020 value)')
# ax3.set_title('Scrap Demand Response above Baseline')
# ax3.set_ylabel('Scrap response above baseline \n(Cumulative, % of 2020 value)')

fig, [ax1, ax2, ax3, ax4] = plt.subplots(1,4)
psubplot(ax1, 0.001 * scrap_demand_response_pir85_gl.loc['20180101':], label='PIR price 0.85',color='tab:gray', firstcall=1, width = 24)
psubplot(ax1, 0.001 * scrap_demand_response_pir80_gl.loc['20180101':], label='PIR price 0.80',color=colors[0])
psubplot(ax1, 0.001 * scrap_demand_response_pir75_gl.loc['20180101':], label='PIR price 0.75',color=colors[1])
psubplot(ax1, 0.001 * scrap_demand_response_pir70_gl.loc['20180101':], label='PIR price 0.70',color=colors[2])
psubplot(ax1, 0.001 * scrap_demand_response_pir65_gl.loc['20180101':], label='PIR price 0.65',color=colors[3])
psubplot(ax1, 0.001 * scrap_demand_response_pir60_gl.loc['20180101':], label='PIR price 0.60',color=colors[4])
psubplot(ax2, 0.001 * scrap_demand_response_pcr101_gl.loc['20180101':], label='PCR recovery 1.01',color='tab:gray', firstcall=1, width = 24)
psubplot(ax2, 0.001 * scrap_demand_response_pcr102_gl.loc['20180101':], label='PCR recovery 1.02',color=colors[0])
psubplot(ax2, 0.001 * scrap_demand_response_pcr103_gl.loc['20180101':], label='PCR recovery 1.03',color=colors[1])
psubplot(ax2, 0.001 * scrap_demand_response_pcr104_gl.loc['20180101':], label='PCR recovery 1.04',color=colors[2])
psubplot(ax2, 0.001 * scrap_demand_response_pcr105_gl.loc['20180101':], label='PCR recovery 1.05',color=colors[3])
# psubplot(ax2, 0.001 * scrap_demand_response_pcr110_gl.loc['20180101':], label='PCR recovery 1.10',color=colors[4])
psubplot(ax3, 0.001 * scrap_demand_response_pir_home09_gl.loc['20180101':], label='pir_home scrap X 0.9',color=colors[0], firstcall=1, width = 24)
psubplot(ax3, 0.001 * scrap_demand_response_pir_home08_gl.loc['20180101':], label='pir_home scrap X 0.8',color=colors[1])
psubplot(ax3, 0.001 * scrap_demand_response_pir_home07_gl.loc['20180101':], label='pir_home scrap X 0.7',color=colors[2])
psubplot(ax3, 0.001 * scrap_demand_response_pir_home06_gl.loc['20180101':], label='pir_home scrap X 0.6',color=colors[3])
psubplot(ax3, 0.001 * scrap_demand_response_pir_home05_gl.loc['20180101':], label='pir_home scrap X 0.5',color=colors[4])
psubplot(ax3, 0.001 * scrap_demand_response_pir_home04_gl.loc['20180101':], label='pir_home scrap X 0.4',color='tab:gray')
psubplot(ax4, 0.001 * scrap_demand_response_pcr_bal950_gl.loc['20180101':], label='PCR Scrap bal 0.950',color=colors[0], firstcall=1, width = 24)
psubplot(ax4, 0.001 * scrap_demand_response_pcr_bal955_gl.loc['20180101':], label='PCR Scrap bal 0.955',color=colors[1])
psubplot(ax4, 0.001 * scrap_demand_response_pcr_bal960_gl.loc['20180101':], label='PCR Scrap bal 0.960',color=colors[2])
psubplot(ax4, 0.001 * scrap_demand_response_pcr_bal965_gl.loc['20180101':], label='PCR Scrap bal 0.965',color=colors[3])
psubplot(ax4, 0.001 * scrap_demand_response_pcr_bal970_gl.loc['20180101':], label='PCR Scrap bal 0.970',color=colors[4])
psubplot(ax4, 0.001 * scrap_demand_response_pcr_bal975_gl.loc['20180101':], label='PCR Scrap bal 0.975',color='tab:gray')
ax1.set_title('Scrap Demand Response above Baseline')
ax1.set_ylabel('Scrap response above baseline (Mt)')
ax2.set_title('Scrap Demand Response above Baseline')
ax2.set_ylabel('Scrap response above baseline (Mt)')
ax3.set_title('Scrap Demand Response above Baseline')
ax3.set_ylabel('Scrap response above baseline (Mt)')
ax4.set_title('Scrap Demand Response above Baseline')
ax4.set_ylabel('Scrap response above baseline (Mt)')


# fig, [ax1, ax2, ax3, ax4] = plt.subplots(1,4)
# psubplot(ax1, mining_pctinc2020_pir85.loc['20180101':], label='PIR price 0.85',color='tab:gray', firstcall=1, width = 24)
# psubplot(ax1, mining_pctinc2020_pir80.loc['20180101':], label='PIR price 0.80',color=colors[0])
# psubplot(ax1, mining_pctinc2020_pir75.loc['20180101':], label='PIR price 0.75',color=colors[1])
# psubplot(ax1, mining_pctinc2020_pir70.loc['20180101':], label='PIR price 0.70',color=colors[2])
# psubplot(ax1, mining_pctinc2020_pir65.loc['20180101':], label='PIR price 0.65',color=colors[3])
# psubplot(ax1, mining_pctinc2020_pir60.loc['20180101':], label='PIR price 0.60',color=colors[4])
# psubplot(ax2, mining_pctinc2020_pcr101.loc['20180101':], label='PCR recovery 1.01',color='tab:gray', firstcall=1, width = 24)
# psubplot(ax2, mining_pctinc2020_pcr102.loc['20180101':], label='PCR recovery 1.02',color=colors[0])
# psubplot(ax2, mining_pctinc2020_pcr103.loc['20180101':], label='PCR recovery 1.03',color=colors[1])
# psubplot(ax2, mining_pctinc2020_pcr104.loc['20180101':], label='PCR recovery 1.04',color=colors[2])
# psubplot(ax2, mining_pctinc2020_pcr105.loc['20180101':], label='PCR recovery 1.05',color=colors[3])
# # psubplot(ax2, mining_pctinc2020_pcr110.loc['20180101':], label='PCR recovery 1.10',color=colors[4])
# psubplot(ax3, mining_pctinc2020_pir_home09.loc['20180101':], label='pir_home scrap X 0.9',color=colors[0], firstcall=1, width = 24)
# psubplot(ax3, mining_pctinc2020_pir_home08.loc['20180101':], label='pir_home scrap X 0.8',color=colors[1])
# psubplot(ax3, mining_pctinc2020_pir_home07.loc['20180101':], label='pir_home scrap X 0.7',color=colors[2])
# psubplot(ax3, mining_pctinc2020_pir_home06.loc['20180101':], label='pir_home scrap X 0.6',color=colors[3])
# psubplot(ax3, mining_pctinc2020_pir_home05.loc['20180101':], label='pir_home scrap X 0.5',color=colors[4])
# psubplot(ax3, mining_pctinc2020_pir_home04.loc['20180101':], label='pir_home scrap X 0.4',color='tab:gray')
# ax1.set_title('Mining Response above Baseline')
# ax1.set_ylabel('Mining response above baseline \n(Cumulative, % of 2020 value)')
# ax2.set_title('Mining Response above Baseline')
# ax2.set_ylabel('Mining response above baseline \n(Cumulative, % of 2020 value)')
# ax3.set_title('Mining Response above Baseline')
# ax3.set_ylabel('Mining response above baseline \n(Cumulative, % of 2020 value)')

fig, [ax1, ax2, ax3, ax4] = plt.subplots(1,4)
psubplot(ax1, 0.001 * mining_response_pir85.cumsum().loc['20180101':], label='PIR price 0.85',color='tab:gray', firstcall=1, width = 24)
psubplot(ax1, 0.001 * mining_response_pir80.cumsum().loc['20180101':], label='PIR price 0.80',color=colors[0])
psubplot(ax1, 0.001 * mining_response_pir75.cumsum().loc['20180101':], label='PIR price 0.75',color=colors[1])
psubplot(ax1, 0.001 * mining_response_pir70.cumsum().loc['20180101':], label='PIR price 0.70',color=colors[2])
psubplot(ax1, 0.001 * mining_response_pir65.cumsum().loc['20180101':], label='PIR price 0.65',color=colors[3])
psubplot(ax1, 0.001 * mining_response_pir60.cumsum().loc['20180101':], label='PIR price 0.60',color=colors[4])
psubplot(ax2, 0.001 * mining_response_pcr101.cumsum().loc['20180101':], label='PCR recovery 1.01',color='tab:gray', firstcall=1, width = 24)
psubplot(ax2, 0.001 * mining_response_pcr102.cumsum().loc['20180101':], label='PCR recovery 1.02',color=colors[0])
psubplot(ax2, 0.001 * mining_response_pcr103.cumsum().loc['20180101':], label='PCR recovery 1.03',color=colors[1])
psubplot(ax2, 0.001 * mining_response_pcr104.cumsum().loc['20180101':], label='PCR recovery 1.04',color=colors[2])
psubplot(ax2, 0.001 * mining_response_pcr105.cumsum().loc['20180101':], label='PCR recovery 1.05',color=colors[3])
# psubplot(ax2, 0.001 * mining_response_pcr110.cumsum().loc['20180101':], label='PCR recovery 1.10',color=colors[4]) ###
psubplot(ax3, 0.001 * mining_response_pir_home09.cumsum().loc['20180101':], label='pir_home scrap X 0.9',color=colors[0], firstcall=1, width = 24)
psubplot(ax3, 0.001 * mining_response_pir_home08.cumsum().loc['20180101':], label='pir_home scrap X 0.8',color=colors[1])
psubplot(ax3, 0.001 * mining_response_pir_home07.cumsum().loc['20180101':], label='pir_home scrap X 0.7',color=colors[2])
psubplot(ax3, 0.001 * mining_response_pir_home06.cumsum().loc['20180101':], label='pir_home scrap X 0.6',color=colors[3])
psubplot(ax3, 0.001 * mining_response_pir_home05.cumsum().loc['20180101':], label='pir_home scrap X 0.5',color=colors[4])
psubplot(ax3, 0.001 * mining_response_pir_home04.cumsum().loc['20180101':], label='pir_home scrap X 0.4',color='tab:gray')
psubplot(ax4, 0.001 * mining_response_pcr_bal950.cumsum().loc['20180101':], label='PCR Scrap bal 0.950',color=colors[0], firstcall=1, width = 24)
psubplot(ax4, 0.001 * mining_response_pcr_bal955.cumsum().loc['20180101':], label='PCR Scrap bal 0.955',color=colors[1])
psubplot(ax4, 0.001 * mining_response_pcr_bal960.cumsum().loc['20180101':], label='PCR Scrap bal 0.960',color=colors[2])
psubplot(ax4, 0.001 * mining_response_pcr_bal965.cumsum().loc['20180101':], label='PCR Scrap bal 0.965',color=colors[3])
psubplot(ax4, 0.001 * mining_response_pcr_bal970.cumsum().loc['20180101':], label='PCR Scrap bal 0.970',color=colors[4])
psubplot(ax4, 0.001 * mining_response_pcr_bal975.cumsum().loc['20180101':], label='PCR Scrap bal 0.975',color='tab:gray')
ax1.set_title('Mining Response above Baseline')
ax1.set_ylabel('Mining response above baseline (Mt)')
ax2.set_title('Mining Response above Baseline')
ax2.set_ylabel('Mining response above baseline (Mt)')
ax3.set_title('Mining Response above Baseline')
ax3.set_ylabel('Mining response above baseline (Mt)')
ax4.set_title('Mining Response above Baseline')
ax4.set_ylabel('Mining response above baseline (Mt)')

fig, [ax1, ax2, ax3, ax4] = plt.subplots(1,4)
psubplot(ax1, demand_displacement_pir85.loc['20190101':], label='PIR price 0.85',color='tab:gray', firstcall=1, width = 24)
psubplot(ax1, demand_displacement_pir80.loc['20190101':], label='PIR price 0.80',color=colors[0])
psubplot(ax1, demand_displacement_pir75.loc['20190101':], label='PIR price 0.75',color=colors[1])
psubplot(ax1, demand_displacement_pir70.loc['20190101':], label='PIR price 0.70',color=colors[2])
psubplot(ax1, demand_displacement_pir65.loc['20190101':], label='PIR price 0.65',color=colors[3])
psubplot(ax1, demand_displacement_pir60.loc['20190101':], label='PIR price 0.60',color=colors[4])
psubplot(ax2, demand_displacement_pcr101.loc['20190101':], label='PCR recovery 1.01',color='tab:gray', firstcall=1, width = 24)
psubplot(ax2, demand_displacement_pcr102.loc['20190101':], label='PCR recovery 1.02',color=colors[0])
psubplot(ax2, demand_displacement_pcr103.loc['20190101':], label='PCR recovery 1.03',color=colors[1])
psubplot(ax2, demand_displacement_pcr104.loc['20190101':], label='PCR recovery 1.04',color=colors[2])
psubplot(ax2, demand_displacement_pcr105.loc['20190101':], label='PCR recovery 1.05',color=colors[3])
# psubplot(ax2, demand_displacement_pcr110.loc['20190101':], label='PCR recovery 1.10',color=colors[4])
psubplot(ax3, demand_displacement_pir_home09.loc['20190101':], label='pir_home scrap X 0.9',color=colors[0], firstcall=1, width = 24)
psubplot(ax3, demand_displacement_pir_home08.loc['20190101':], label='pir_home scrap X 0.8',color=colors[1])
psubplot(ax3, demand_displacement_pir_home07.loc['20190101':], label='pir_home scrap X 0.7',color=colors[2])
psubplot(ax3, demand_displacement_pir_home06.loc['20190101':], label='pir_home scrap X 0.6',color=colors[3])
psubplot(ax3, demand_displacement_pir_home05.loc['20190101':], label='pir_home scrap X 0.5',color=colors[4])
# psubplot(ax3, demand_displacement_pir_home04.loc['20190101':], label='pir_home scrap X 0.4',color='tab:gray')
psubplot(ax4, demand_displacement_pcr_bal950.loc['20190101':], label='PCR Scrap bal 0.950',color=colors[0], firstcall=1, width = 24)
psubplot(ax4, demand_displacement_pcr_bal955.loc['20190101':], label='PCR Scrap bal 0.955',color=colors[1])
psubplot(ax4, demand_displacement_pcr_bal960.loc['20190101':], label='PCR Scrap bal 0.960',color=colors[2])
psubplot(ax4, demand_displacement_pcr_bal965.loc['20190101':], label='PCR Scrap bal 0.965',color=colors[3])
psubplot(ax4, demand_displacement_pcr_bal970.loc['20190101':], label='PCR Scrap bal 0.970',color=colors[4])
psubplot(ax4, demand_displacement_pcr_bal975.loc['20190101':], label='PCR Scrap bal 0.975',color='tab:gray')
ax1.set_title('Demand-Based Displacement')
ax1.set_ylabel('Demand-Based Displacement')
ax2.set_title('Demand-Based Displacement')
ax2.set_ylabel('Demand-Based Displacement')
ax3.set_title('Demand-Based Displacement')
ax3.set_ylabel('Demand-Based Displacement')
ax4.set_title('Demand-Based Displacement')
ax4.set_ylabel('Demand-Based Displacement')

fig, [ax1, ax2, ax3, ax4] = plt.subplots(1,4)
psubplot(ax1, noacc_displacement_pir85.loc['20190101':], label='PIR price 0.85',color='tab:gray', firstcall=1, width = 24)
psubplot(ax1, noacc_displacement_pir80.loc['20190101':], label='PIR price 0.80',color=colors[0])
psubplot(ax1, noacc_displacement_pir75.loc['20190101':], label='PIR price 0.75',color=colors[1])
psubplot(ax1, noacc_displacement_pir70.loc['20190101':], label='PIR price 0.70',color=colors[2])
# psubplot(ax1, noacc_displacement_pir65.loc['20190101':], label='PIR price 0.65',color=colors[3])
psubplot(ax1, noacc_displacement_pir60.loc['20190101':], label='PIR price 0.60',color=colors[4])
psubplot(ax2, noacc_displacement_pcr101.loc['20190101':], label='PCR recovery 1.01',color='tab:gray', firstcall=1, width = 24)
psubplot(ax2, noacc_displacement_pcr102.loc['20190101':], label='PCR recovery 1.02',color=colors[0])
psubplot(ax2, noacc_displacement_pcr103.loc['20190101':], label='PCR recovery 1.03',color=colors[1])
psubplot(ax2, noacc_displacement_pcr104.loc['20190101':], label='PCR recovery 1.04',color=colors[2])
psubplot(ax2, noacc_displacement_pcr105.loc['20190101':], label='PCR recovery 1.05',color=colors[3])
psubplot(ax2, noacc_displacement_pcr110.loc['20190101':], label='PCR recovery 1.10',color=colors[4])
psubplot(ax3, noacc_displacement_pir_home09.loc['20190101':], label='pir_home scrap X 0.9',color=colors[0], firstcall=1, width = 24)
psubplot(ax3, noacc_displacement_pir_home08.loc['20190101':], label='pir_home scrap X 0.8',color=colors[1])
psubplot(ax3, noacc_displacement_pir_home07.loc['20190101':], label='pir_home scrap X 0.7',color=colors[2])
psubplot(ax3, noacc_displacement_pir_home06.loc['20190101':], label='pir_home scrap X 0.6',color=colors[3])
psubplot(ax3, noacc_displacement_pir_home05.loc['20190101':], label='pir_home scrap X 0.5',color=colors[4])
# psubplot(ax3, displacement_pir_home04.loc['20190101':], label='pir_home scrap X 0.4',color='tab:gray')
psubplot(ax4, noacc_displacement_pcr_bal950.loc['20190101':], label='PCR Scrap bal 0.950',color=colors[0], firstcall=1, width = 24)
psubplot(ax4, noacc_displacement_pcr_bal955.loc['20190101':], label='PCR Scrap bal 0.955',color=colors[1])
psubplot(ax4, noacc_displacement_pcr_bal960.loc['20190101':], label='PCR Scrap bal 0.960',color=colors[2])
psubplot(ax4, noacc_displacement_pcr_bal965.loc['20190101':], label='PCR Scrap bal 0.965',color=colors[3])
psubplot(ax4, noacc_displacement_pcr_bal970.loc['20190101':], label='PCR Scrap bal 0.970',color=colors[4])
psubplot(ax4, noacc_displacement_pcr_bal975.loc['20190101':], label='PCR Scrap bal 0.975',color='tab:gray')
ax1.set_title('Supply-Based Displacement')
ax1.set_ylabel('Supply-Based Displacement')
ax2.set_title('Supply-Based Displacement')
ax2.set_ylabel('Supply-Based Displacement')
ax3.set_title('Supply-Based Displacement')
ax3.set_ylabel('Supply-Based Displacement')
ax4.set_title('Supply-Based Displacement')
ax4.set_ylabel('Supply-Based Displacement')

# %%
supply_pct_increase = [scrap_pctinc2020_pir85.loc['20400101'], scrap_pctinc2020_pir80.loc['20400101'], 
 scrap_pctinc2020_pir75.loc['20400101'], scrap_pctinc2020_pir70.loc['20400101'], 
 scrap_pctinc2020_pir65.loc['20400101'], scrap_pctinc2020_pir60.loc['20400101'], 
 scrap_pctinc2020_pir_home09.loc['20400101'], scrap_pctinc2020_pir_home08.loc['20400101'], 
 scrap_pctinc2020_pir_home07.loc['20400101'], scrap_pctinc2020_pir_home06.loc['20400101'], 
 scrap_pctinc2020_pir_home05.loc['20400101'], scrap_pctinc2020_pir_home04.loc['20400101'], 
 scrap_pctinc2020_pcr101.loc['20400101'], scrap_pctinc2020_pcr102.loc['20400101'], 
 scrap_pctinc2020_pcr103.loc['20400101'], scrap_pctinc2020_pcr104.loc['20400101'], 
 scrap_pctinc2020_pcr105.loc['20400101'], scrap_pctinc2020_pcr110.loc['20400101']]
demand_pct_increase = [scrap_demand_pctinc2020_pir85_gl.loc['20400101'], scrap_demand_pctinc2020_pir80_gl.loc['20400101'], 
 scrap_demand_pctinc2020_pir75_gl.loc['20400101'], scrap_demand_pctinc2020_pir70_gl.loc['20400101'], 
 scrap_demand_pctinc2020_pir65_gl.loc['20400101'], scrap_demand_pctinc2020_pir60_gl.loc['20400101'], 
 scrap_demand_pctinc2020_pir_home09_gl.loc['20400101'], scrap_demand_pctinc2020_pir_home08_gl.loc['20400101'], 
 scrap_demand_pctinc2020_pir_home07_gl.loc['20400101'], scrap_demand_pctinc2020_pir_home06_gl.loc['20400101'], 
 scrap_demand_pctinc2020_pir_home05_gl.loc['20400101'], scrap_demand_pctinc2020_pir_home04_gl.loc['20400101'], 
 scrap_demand_pctinc2020_pcr101_gl.loc['20400101'], scrap_demand_pctinc2020_pcr102_gl.loc['20400101'], 
 scrap_demand_pctinc2020_pcr103_gl.loc['20400101'], scrap_demand_pctinc2020_pcr104_gl.loc['20400101'], 
 scrap_demand_pctinc2020_pcr105_gl.loc['20400101'], scrap_demand_pctinc2020_pcr110_gl.loc['20400101']]
mining_pct_decrease = [-mining_pctinc2020_pir85.loc['20400101'], -mining_pctinc2020_pir80.loc['20400101'], 
 -mining_pctinc2020_pir75.loc['20400101'], -mining_pctinc2020_pir70.loc['20400101'], 
 -mining_pctinc2020_pir65.loc['20400101'], -mining_pctinc2020_pir60.loc['20400101'], 
 -mining_pctinc2020_pir_home09.loc['20400101'], -mining_pctinc2020_pir_home08.loc['20400101'], 
 -mining_pctinc2020_pir_home07.loc['20400101'], -mining_pctinc2020_pir_home06.loc['20400101'], 
 -mining_pctinc2020_pir_home05.loc['20400101'], -mining_pctinc2020_pir_home04.loc['20400101'], 
 -mining_pctinc2020_pcr101.loc['20400101'], -mining_pctinc2020_pcr102.loc['20400101'], 
 -mining_pctinc2020_pcr103.loc['20400101'], -mining_pctinc2020_pcr104.loc['20400101'], 
 -mining_pctinc2020_pcr105.loc['20400101'], -mining_pctinc2020_pcr110.loc['20400101']]
demand_displacement = [demand_displacement_pir85.loc['20400101'], demand_displacement_pir80.loc['20400101'], 
 demand_displacement_pir75.loc['20400101'], demand_displacement_pir70.loc['20400101'], 
 demand_displacement_pir65.loc['20400101'], demand_displacement_pir60.loc['20400101'], 
 demand_displacement_pir_home09.loc['20400101'], demand_displacement_pir_home08.loc['20400101'], 
 demand_displacement_pir_home07.loc['20400101'], demand_displacement_pir_home06.loc['20400101'], 
 demand_displacement_pir_home05.loc['20400101'], demand_displacement_pir_home04.loc['20400101'], 
 demand_displacement_pcr101.loc['20400101'], demand_displacement_pcr102.loc['20400101'], 
 demand_displacement_pcr103.loc['20400101'], demand_displacement_pcr104.loc['20400101'], 
 demand_displacement_pcr105.loc['20400101'], demand_displacement_pcr110.loc['20400101']]
supply_displacement = [ displacement_pir85.loc['20400101'], displacement_pir80.loc['20400101'], 
 displacement_pir75.loc['20400101'], displacement_pir70.loc['20400101'], 
 displacement_pir65.loc['20400101'], displacement_pir60.loc['20400101'], 
 displacement_pir_home09.loc['20400101'], displacement_pir_home08.loc['20400101'], 
 displacement_pir_home07.loc['20400101'], displacement_pir_home06.loc['20400101'], 
 displacement_pir_home05.loc['20400101'], displacement_pir_home04.loc['20400101'], 
 displacement_pcr101.loc['20400101'], displacement_pcr102.loc['20400101'], 
 displacement_pcr103.loc['20400101'], displacement_pcr104.loc['20400101'], 
 displacement_pcr105.loc['20400101'], displacement_pcr110.loc['20400101']]

def barbar(scrap_change, mining_change, displacement, title, ylabels):
    fonty_font = 18
    params = {
        'axes.labelsize': fonty_font,
        'font.size': fonty_font,
        'legend.fontsize': fonty_font,
        'xtick.labelsize': fonty_font,
        'ytick.labelsize': fonty_font,
        'text.usetex': False,
        'figure.figsize': [24, 8],
        'lines.linewidth': 3
        }
    mpl.rcParams.update(params)
    mpl.rcParams['axes.spines.left'] = False
    mpl.rcParams['axes.spines.right'] = False
    mpl.rcParams['axes.spines.top'] = False
    mpl.rcParams['axes.spines.bottom'] = False
    # %config InlineBackend.figure_format ='retina'

    label_array = ['\nPIR Price Decrease (%)', '\nPIR Availability Increase (%)', '\nPCR Availability Increase (%)']

    labels = ['5.5', '11', '16.5', label_array[0], '22', '27.5', '33',
             '8', '14', '20', label_array[1], '24', '28', '32',
             '1', '2', '3', label_array[2], '4', '5', '10']

    x = np.arange(len(labels)-3)  # the label locations
    width = 0.35  # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(x - width/2, scrap_change, width, label='Scrap Increase', color = 'tab:gray')
    rects2 = ax.bar(x + width/2, mining_change, width, label='Mining Production Decrease', color = colors[1])

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel(ylabels[0])
    ax.set_title(title)
    ax.set_xticks([0,1,2,2.5,3,4,5,6,7,8,8.5,9,10,11,12,13,14,14.5,15,16,17])
    ax.set_xticks([5.5,11.5], minor = True)
    ax.set_xticklabels(labels)
    ax.grid(False, axis='x' )
    ax.grid(False, axis='x', which='minor' )

    ax.tick_params(axis='x', which='minor', direction='out', length=30 )
    ax.tick_params(axis='x', which='major', bottom=False, top=False )

    ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis
    color = colors[2]
    ax2.set_ylabel(ylabels[1], color=color)  # we already handled the x-label with ax1
    ax2.plot(x, displacement, marker = 'o', markersize = 12, linewidth = 4, color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    # def autolabel(rects):
    #     """Attach a text label above each bar in *rects*, displaying its height."""
    #     for rect in rects:
    #         height = rect.get_height()
    #         ax.annotate('{}'.format(height),
    #                     xy=(rect.get_x() + rect.get_width() / 2, height),
    #                     xytext=(0, 3),  # 3 points vertical offset
    #                     textcoords="offset points",
    #                     ha='center', va='bottom')


    # autolabel(rects1)
    # autolabel(rects2)

    fig.tight_layout()

    plt.show()
    
ylabels1 = ['Scrap supply increase and mining decrease \n(Cumulative through 2040, % of 2020 production)',
            'Scrap supply-based displacement ratio']
title1 = 'Cumulative Mining Production Reduction, Scrap Supply Increase, and Displacement\nRatio due to Increase in PCR Availability'
barbar(supply_pct_increase, mining_pct_decrease, supply_displacement, title1, ylabels1)

ylabels2 = ['Scrap demand increase and mining decrease \n(Cumulative through 2040, % of 2020 production)',
            'Scrap demand-based displacement ratio']
title2 = 'Cumulative Mining Production Reduction, Scrap Demand Increase, and Displacement\nRatio due to Increase in PCR Availability'
barbar(demand_pct_increase, mining_pct_decrease, demand_displacement, title2, ylabels2)

# %%
print('pcr_bal Availability; 1.01;', scrap_noacc_pctinc2020_pcr_bal950_gl.loc['20400101'],';', scrap_demand_pctinc2020_pcr_bal950_gl.loc['20400101'],';', -mining_pctinc2020_pcr_bal950.loc['20400101'],';', demand_displacement_pcr_bal950.loc['20400101'],';', noacc_displacement_pcr_bal950.loc['20400101'])
print('pcr_bal Availability; 1.02;', scrap_noacc_pctinc2020_pcr_bal955_gl.loc['20400101'],';', scrap_demand_pctinc2020_pcr_bal955_gl.loc['20400101'],';', -mining_pctinc2020_pcr_bal955.loc['20400101'],';', demand_displacement_pcr_bal955.loc['20400101'],';', noacc_displacement_pcr_bal955.loc['20400101'])
print('pcr_bal Availability; 1.03;', scrap_noacc_pctinc2020_pcr_bal960_gl.loc['20400101'],';', scrap_demand_pctinc2020_pcr_bal960_gl.loc['20400101'],';', -mining_pctinc2020_pcr_bal960.loc['20400101'],';', demand_displacement_pcr_bal960.loc['20400101'],';', noacc_displacement_pcr_bal960.loc['20400101'])
print('pcr_bal Availability; 1.04;', scrap_noacc_pctinc2020_pcr_bal965_gl.loc['20400101'],';', scrap_demand_pctinc2020_pcr_bal965_gl.loc['20400101'],';', -mining_pctinc2020_pcr_bal965.loc['20400101'],';', demand_displacement_pcr_bal965.loc['20400101'],';', noacc_displacement_pcr_bal965.loc['20400101'])
print('pcr_bal Availability; 1.05;', scrap_noacc_pctinc2020_pcr_bal970_gl.loc['20400101'],';', scrap_demand_pctinc2020_pcr_bal970_gl.loc['20400101'],';', -mining_pctinc2020_pcr_bal970.loc['20400101'],';', demand_displacement_pcr_bal970.loc['20400101'],';', noacc_displacement_pcr_bal970.loc['20400101'])
print('pcr_bal Availability; 1.10;', scrap_noacc_pctinc2020_pcr_bal975_gl.loc['20400101'],';', scrap_demand_pctinc2020_pcr_bal975_gl.loc['20400101'],';', -mining_pctinc2020_pcr_bal975.loc['20400101'],';', demand_displacement_pcr_bal975.loc['20400101'],';', noacc_displacement_pcr_bal975.loc['20400101'])

# %%
# print('PIR Price; 0.85;', scrap_noacc_response_pir85_gl.loc['20400101'],';', scrap_demand_response_pir85_gl.loc['20400101'],';', -mining_response_pir85.cumsum().loc['20400101'],';', demand_displacement_pir85.loc['20400101'],';', noacc_displacement_pir85.loc['20400101'])
# print('PIR Price; 0.80;', scrap_noacc_response_pir80_gl.loc['20400101'],';', scrap_demand_response_pir80_gl.loc['20400101'],';', -mining_response_pir80.cumsum().loc['20400101'],';', demand_displacement_pir80.loc['20400101'],';', noacc_displacement_pir80.loc['20400101'])
# print('PIR Price; 0.75;', scrap_noacc_response_pir75_gl.loc['20400101'],';', scrap_demand_response_pir75_gl.loc['20400101'],';', -mining_response_pir75.cumsum().loc['20400101'],';', demand_displacement_pir75.loc['20400101'],';', noacc_displacement_pir75.loc['20400101'])
# print('PIR Price; 0.70;', scrap_noacc_response_pir70_gl.loc['20400101'],';', scrap_demand_response_pir70_gl.loc['20400101'],';', -mining_response_pir70.cumsum().loc['20400101'],';', demand_displacement_pir70.loc['20400101'],';', noacc_displacement_pir70.loc['20400101'])
# print('PIR Price; 0.65;', scrap_noacc_response_pir65_gl.loc['20400101'],';', scrap_demand_response_pir65_gl.loc['20400101'],';', -mining_response_pir65.cumsum().loc['20400101'],';', demand_displacement_pir65.loc['20400101'],';', noacc_displacement_pir65.loc['20400101'])
# print('PIR Price; 0.60;', scrap_noacc_response_pir60_gl.loc['20400101'],';', scrap_demand_response_pir60_gl.loc['20400101'],';', -mining_response_pir60.cumsum().loc['20400101'],';', demand_displacement_pir60.loc['20400101'],';', noacc_displacement_pir60.loc['20400101'])

print('PIR Availability; 0.90;', scrap_noacc_response_pir_home09_gl.loc['20400101'],';', scrap_demand_response_pir_home09_gl.loc['20400101'],';', -mining_response_pir_home09.cumsum().loc['20400101'],';', demand_displacement_pir_home09.loc['20400101'],';', noacc_displacement_pir_home09.loc['20400101'])
print('PIR Availability; 0.80;', scrap_noacc_response_pir_home08_gl.loc['20400101'],';', scrap_demand_response_pir_home08_gl.loc['20400101'],';', -mining_response_pir_home08.cumsum().loc['20400101'],';', demand_displacement_pir_home08.loc['20400101'],';', noacc_displacement_pir_home08.loc['20400101'])
print('PIR Availability; 0.70;', scrap_noacc_response_pir_home07_gl.loc['20400101'],';', scrap_demand_response_pir_home07_gl.loc['20400101'],';', -mining_response_pir_home07.cumsum().loc['20400101'],';', demand_displacement_pir_home07.loc['20400101'],';', noacc_displacement_pir_home07.loc['20400101'])
print('PIR Availability; 0.60;', scrap_noacc_response_pir_home06_gl.loc['20400101'],';', scrap_demand_response_pir_home06_gl.loc['20400101'],';', -mining_response_pir_home06.cumsum().loc['20400101'],';', demand_displacement_pir_home06.loc['20400101'],';', noacc_displacement_pir_home06.loc['20400101'])
print('PIR Availability; 0.50;', scrap_noacc_response_pir_home05_gl.loc['20400101'],';', scrap_demand_response_pir_home05_gl.loc['20400101'],';', -mining_response_pir_home05.cumsum().loc['20400101'],';', demand_displacement_pir_home05.loc['20400101'],';', noacc_displacement_pir_home05.loc['20400101'])
print('PIR Availability; 0.40;', scrap_noacc_response_pir_home04_gl.loc['20400101'],';', scrap_demand_response_pir_home04_gl.loc['20400101'],';', -mining_response_pir_home04.cumsum().loc['20400101'],';', demand_displacement_pir_home04.loc['20400101'],';', noacc_displacement_pir_home04.loc['20400101'])

# print('PCR Availability; 1.01;', scrap_noacc_response_pcr101_gl.loc['20400101'],';', scrap_demand_response_pcr101_gl.loc['20400101'],';', -mining_response_pcr101.cumsum().loc['20400101'],';', demand_displacement_pcr101.loc['20400101'],';', noacc_displacement_pcr101.loc['20400101'])
# print('PCR Availability; 1.02;', scrap_noacc_response_pcr102_gl.loc['20400101'],';', scrap_demand_response_pcr102_gl.loc['20400101'],';', -mining_response_pcr102.cumsum().loc['20400101'],';', demand_displacement_pcr102.loc['20400101'],';', noacc_displacement_pcr102.loc['20400101'])
# print('PCR Availability; 1.03;', scrap_noacc_response_pcr103_gl.loc['20400101'],';', scrap_demand_response_pcr103_gl.loc['20400101'],';', -mining_response_pcr103.cumsum().loc['20400101'],';', demand_displacement_pcr103.loc['20400101'],';', noacc_displacement_pcr103.loc['20400101'])
# print('PCR Availability; 1.04;', scrap_noacc_response_pcr104_gl.loc['20400101'],';', scrap_demand_response_pcr104_gl.loc['20400101'],';', -mining_response_pcr104.cumsum().loc['20400101'],';', demand_displacement_pcr104.loc['20400101'],';', noacc_displacement_pcr104.loc['20400101'])
# print('PCR Availability; 1.05;', scrap_noacc_response_pcr105_gl.loc['20400101'],';', scrap_demand_response_pcr105_gl.loc['20400101'],';', -mining_response_pcr105.cumsum().loc['20400101'],';', demand_displacement_pcr105.loc['20400101'],';', noacc_displacement_pcr105.loc['20400101'])
# print('PCR Availability; 1.10;', scrap_noacc_response_pcr110_gl.loc['20400101'],';', scrap_demand_response_pcr110_gl.loc['20400101'],';', -mining_response_pcr110.cumsum().loc['20400101'],';', demand_displacement_pcr110.loc['20400101'],';', noacc_displacement_pcr110.loc['20400101'])

# %% [markdown]
# ### Refinery evolution

# %%
for value in ref_props_pir_baseline_gl.loc[:,'Primary CU':].columns:
#     ref_props_pir_baseline_gl.loc[:,value] = 0
#     ref_props_alloyed_50yoy_gl.loc[:,value] = 0
#     ref_props_no2_50yoy_gl.loc[:,value] = 0
#     ref_props_both_50yoy_gl.loc[:,value] = 0
#     ref_props_ban_zeng_low_gl.loc[:,value] = 0
#     ref_props_ban_zeng_mean_gl.loc[:,value] = 0
#     ref_props_ban_zeng_high_gl.loc[:,value] = 0
#     ref_props_fruity1rr0_gl.loc[:,value] = 0
#     ref_props_fruity1rr50_gl.loc[:,value] = 0
#     ref_props_fruity1rr90_gl.loc[:,value] = 0
#     ref_props_fruity1rr100_gl.loc[:,value] = 0
#     ref_props_fruity_pct1rr0_gl.loc[:,value] = 0
#     ref_props_fruity_pct1rr50_gl.loc[:,value] = 0
#     ref_props_fruity_pct1rr90_gl.loc[:,value] = 0
#     ref_props_fruity_pct1rr100_gl.loc[:,value] = 0
#     ref_props_fruity_pct5rr0_gl.loc[:,value] = 0
#     ref_props_fruity_pct5rr50_gl.loc[:,value] = 0
#     ref_props_fruity_pct5rr90_gl.loc[:,value] = 0
#     ref_props_fruity_pct5rr100_gl.loc[:,value] = 0
#     ref_props_fruity_pct10rr0_gl.loc[:,value] = 0
#     ref_props_fruity_pct10rr50_gl.loc[:,value] = 0
#     ref_props_fruity_pct10rr90_gl.loc[:,value] = 0

    ref_props_pir_baseline_gl.loc[:,value] = (ref_props_pir_baseline_cn.loc[:,value]*ref_props_pir_baseline_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_pir_baseline_rw.loc[:,value]*ref_props_pir_baseline_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_pir_baseline_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_alloyed_50yoy_gl.loc[:,value] = (ref_props_alloyed_50yoy_cn.loc[:,value]*ref_props_alloyed_50yoy_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_alloyed_50yoy_rw.loc[:,value]*ref_props_alloyed_50yoy_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_alloyed_50yoy_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_no2_50yoy_gl.loc[:,value] = (ref_props_no2_50yoy_cn.loc[:,value]*ref_props_no2_50yoy_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_no2_50yoy_rw.loc[:,value]*ref_props_no2_50yoy_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_no2_50yoy_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_both_50yoy_gl.loc[:,value] = (ref_props_both_50yoy_cn.loc[:,value]*ref_props_both_50yoy_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_both_50yoy_rw.loc[:,value]*ref_props_both_50yoy_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_both_50yoy_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    
    ref_props_pir_baseline_inc100_gl.loc[:,value] = (ref_props_pir_baseline_inc100_cn.loc[:,value]*ref_props_pir_baseline_inc100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_pir_baseline_inc100_rw.loc[:,value]*ref_props_pir_baseline_inc100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_pir_baseline_inc100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_alloyed_50yoy_inc100_gl.loc[:,value] = (ref_props_alloyed_50yoy_inc100_cn.loc[:,value]*ref_props_alloyed_50yoy_inc100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_alloyed_50yoy_inc100_rw.loc[:,value]*ref_props_alloyed_50yoy_inc100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_alloyed_50yoy_inc100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_no2_50yoy_inc100_gl.loc[:,value] = (ref_props_no2_50yoy_inc100_cn.loc[:,value]*ref_props_no2_50yoy_inc100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_no2_50yoy_inc100_rw.loc[:,value]*ref_props_no2_50yoy_inc100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_no2_50yoy_inc100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_both_50yoy_inc100_gl.loc[:,value] = (ref_props_both_50yoy_inc100_cn.loc[:,value]*ref_props_both_50yoy_inc100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_both_50yoy_inc100_rw.loc[:,value]*ref_props_both_50yoy_inc100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_both_50yoy_inc100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_pir_baseline_inc200_gl.loc[:,value] = (ref_props_pir_baseline_inc200_cn.loc[:,value]*ref_props_pir_baseline_inc200_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_pir_baseline_inc200_rw.loc[:,value]*ref_props_pir_baseline_inc200_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_pir_baseline_inc200_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_alloyed_50yoy_inc200_gl.loc[:,value] = (ref_props_alloyed_50yoy_inc200_cn.loc[:,value]*ref_props_alloyed_50yoy_inc200_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_alloyed_50yoy_inc200_rw.loc[:,value]*ref_props_alloyed_50yoy_inc200_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_alloyed_50yoy_inc200_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_no2_50yoy_inc200_gl.loc[:,value] = (ref_props_no2_50yoy_inc200_cn.loc[:,value]*ref_props_no2_50yoy_inc200_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_no2_50yoy_inc200_rw.loc[:,value]*ref_props_no2_50yoy_inc200_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_no2_50yoy_inc200_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_both_50yoy_inc200_gl.loc[:,value] = (ref_props_both_50yoy_inc200_cn.loc[:,value]*ref_props_both_50yoy_inc200_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_both_50yoy_inc200_rw.loc[:,value]*ref_props_both_50yoy_inc200_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_both_50yoy_inc200_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_pir_baseline_dec100_gl.loc[:,value] = (ref_props_pir_baseline_dec100_cn.loc[:,value]*ref_props_pir_baseline_dec100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_pir_baseline_dec100_rw.loc[:,value]*ref_props_pir_baseline_dec100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_pir_baseline_dec100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_alloyed_50yoy_dec100_gl.loc[:,value] = (ref_props_alloyed_50yoy_dec100_cn.loc[:,value]*ref_props_alloyed_50yoy_dec100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_alloyed_50yoy_dec100_rw.loc[:,value]*ref_props_alloyed_50yoy_dec100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_alloyed_50yoy_dec100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_no2_50yoy_dec100_gl.loc[:,value] = (ref_props_no2_50yoy_dec100_cn.loc[:,value]*ref_props_no2_50yoy_dec100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_no2_50yoy_dec100_rw.loc[:,value]*ref_props_no2_50yoy_dec100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_no2_50yoy_dec100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_both_50yoy_dec100_gl.loc[:,value] = (ref_props_both_50yoy_dec100_cn.loc[:,value]*ref_props_both_50yoy_dec100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_both_50yoy_dec100_rw.loc[:,value]*ref_props_both_50yoy_dec100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_both_50yoy_dec100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_pir_baseline_dec200_gl.loc[:,value] = (ref_props_pir_baseline_dec200_cn.loc[:,value]*ref_props_pir_baseline_dec200_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_pir_baseline_dec200_rw.loc[:,value]*ref_props_pir_baseline_dec200_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_pir_baseline_dec200_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_alloyed_50yoy_dec200_gl.loc[:,value] = (ref_props_alloyed_50yoy_dec200_cn.loc[:,value]*ref_props_alloyed_50yoy_dec200_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_alloyed_50yoy_dec200_rw.loc[:,value]*ref_props_alloyed_50yoy_dec200_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_alloyed_50yoy_dec200_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_no2_50yoy_dec200_gl.loc[:,value] = (ref_props_no2_50yoy_dec200_cn.loc[:,value]*ref_props_no2_50yoy_dec200_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_no2_50yoy_dec200_rw.loc[:,value]*ref_props_no2_50yoy_dec200_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_no2_50yoy_dec200_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_both_50yoy_dec200_gl.loc[:,value] = (ref_props_both_50yoy_dec200_cn.loc[:,value]*ref_props_both_50yoy_dec200_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_both_50yoy_dec200_rw.loc[:,value]*ref_props_both_50yoy_dec200_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_both_50yoy_dec200_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    
    ref_props_alloyed_25yoy_gl.loc[:,value] = (ref_props_alloyed_25yoy_cn.loc[:,value]*ref_props_alloyed_25yoy_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_alloyed_25yoy_rw.loc[:,value]*ref_props_alloyed_25yoy_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_alloyed_25yoy_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_no2_25yoy_gl.loc[:,value] = (ref_props_no2_25yoy_cn.loc[:,value]*ref_props_no2_25yoy_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_no2_25yoy_rw.loc[:,value]*ref_props_no2_25yoy_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_no2_25yoy_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_both_25yoy_gl.loc[:,value] = (ref_props_both_25yoy_cn.loc[:,value]*ref_props_both_25yoy_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_both_25yoy_rw.loc[:,value]*ref_props_both_25yoy_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_both_25yoy_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_alloyed_75yoy_gl.loc[:,value] = (ref_props_alloyed_75yoy_cn.loc[:,value]*ref_props_alloyed_75yoy_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_alloyed_75yoy_rw.loc[:,value]*ref_props_alloyed_75yoy_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_alloyed_75yoy_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_no2_75yoy_gl.loc[:,value] = (ref_props_no2_75yoy_cn.loc[:,value]*ref_props_no2_75yoy_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_no2_75yoy_rw.loc[:,value]*ref_props_no2_75yoy_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_no2_75yoy_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_both_75yoy_gl.loc[:,value] = (ref_props_both_75yoy_cn.loc[:,value]*ref_props_both_75yoy_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_both_75yoy_rw.loc[:,value]*ref_props_both_75yoy_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_both_75yoy_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    
    ref_props_ban_zeng_low_gl.loc[:,value] = (ref_props_ban_zeng_low_cn.loc[:,value]*ref_props_ban_zeng_low_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_ban_zeng_low_rw.loc[:,value]*ref_props_ban_zeng_low_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_ban_zeng_low_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_ban_zeng_mean_gl.loc[:,value] = (ref_props_ban_zeng_mean_cn.loc[:,value]*ref_props_ban_zeng_mean_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_ban_zeng_mean_rw.loc[:,value]*ref_props_ban_zeng_mean_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_ban_zeng_mean_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_ban_zeng_high_gl.loc[:,value] = (ref_props_ban_zeng_high_cn.loc[:,value]*ref_props_ban_zeng_high_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_ban_zeng_high_rw.loc[:,value]*ref_props_ban_zeng_high_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_ban_zeng_high_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity1rr0_gl.loc[:,value] = (ref_props_fruity1rr0_cn.loc[:,value]*ref_props_fruity1rr0_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity1rr0_rw.loc[:,value]*ref_props_fruity1rr0_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity1rr50_gl.loc[:,value] = (ref_props_fruity1rr50_cn.loc[:,value]*ref_props_fruity1rr50_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity1rr50_rw.loc[:,value]*ref_props_fruity1rr50_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity1rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity1rr90_gl.loc[:,value] = (ref_props_fruity1rr90_cn.loc[:,value]*ref_props_fruity1rr90_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity1rr90_rw.loc[:,value]*ref_props_fruity1rr90_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity1rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity1rr100_gl.loc[:,value] = (ref_props_fruity1rr100_cn.loc[:,value]*ref_props_fruity1rr100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity1rr100_rw.loc[:,value]*ref_props_fruity1rr100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity1rr100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct1rr0_gl.loc[:,value] = (ref_props_fruity_pct1rr0_cn.loc[:,value]*ref_props_fruity_pct1rr0_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct1rr0_rw.loc[:,value]*ref_props_fruity_pct1rr0_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct1rr50_gl.loc[:,value] = (ref_props_fruity_pct1rr50_cn.loc[:,value]*ref_props_fruity_pct1rr50_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct1rr50_rw.loc[:,value]*ref_props_fruity_pct1rr50_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct1rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct1rr90_gl.loc[:,value] = (ref_props_fruity_pct1rr90_cn.loc[:,value]*ref_props_fruity_pct1rr90_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct1rr90_rw.loc[:,value]*ref_props_fruity_pct1rr90_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct1rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct1rr100_gl.loc[:,value] = (ref_props_fruity_pct1rr100_cn.loc[:,value]*ref_props_fruity_pct1rr100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct1rr100_rw.loc[:,value]*ref_props_fruity_pct1rr100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct1rr100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct5rr0_gl.loc[:,value] = (ref_props_fruity_pct5rr0_cn.loc[:,value]*ref_props_fruity_pct5rr0_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct5rr0_rw.loc[:,value]*ref_props_fruity_pct5rr0_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct5rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct5rr50_gl.loc[:,value] = (ref_props_fruity_pct5rr50_cn.loc[:,value]*ref_props_fruity_pct5rr50_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct5rr50_rw.loc[:,value]*ref_props_fruity_pct5rr50_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct5rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct5rr90_gl.loc[:,value] = (ref_props_fruity_pct5rr90_cn.loc[:,value]*ref_props_fruity_pct5rr90_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct5rr90_rw.loc[:,value]*ref_props_fruity_pct5rr90_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct5rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct5rr100_gl.loc[:,value] = (ref_props_fruity_pct5rr100_cn.loc[:,value]*ref_props_fruity_pct5rr100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct5rr100_rw.loc[:,value]*ref_props_fruity_pct5rr100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct5rr100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct10rr0_gl.loc[:,value] = (ref_props_fruity_pct10rr0_cn.loc[:,value]*ref_props_fruity_pct10rr0_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct10rr0_rw.loc[:,value]*ref_props_fruity_pct10rr0_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct10rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct10rr11_gl.loc[:,value] = (ref_props_fruity_pct10rr11_cn.loc[:,value]*ref_props_fruity_pct10rr11_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct10rr11_rw.loc[:,value]*ref_props_fruity_pct10rr11_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct10rr11_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct10rr50_gl.loc[:,value] = (ref_props_fruity_pct10rr50_cn.loc[:,value]*ref_props_fruity_pct10rr50_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct10rr50_rw.loc[:,value]*ref_props_fruity_pct10rr50_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct10rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct10rr90_gl.loc[:,value] = (ref_props_fruity_pct10rr90_cn.loc[:,value]*ref_props_fruity_pct10rr90_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct10rr90_rw.loc[:,value]*ref_props_fruity_pct10rr90_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct10rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct10rr70_gl.loc[:,value] = (ref_props_fruity_pct10rr70_cn.loc[:,value]*ref_props_fruity_pct10rr70_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct10rr70_rw.loc[:,value]*ref_props_fruity_pct10rr70_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct10rr70_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)

    ref_props_ban_zeng_low_gl.loc[:,value] = (ref_props_ban_zeng_low_cn.loc[:,value]*ref_props_ban_zeng_low_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_ban_zeng_low_rw.loc[:,value]*ref_props_ban_zeng_low_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_ban_zeng_low_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_ban_zeng_mean_gl.loc[:,value] = (ref_props_ban_zeng_mean_cn.loc[:,value]*ref_props_ban_zeng_mean_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_ban_zeng_mean_rw.loc[:,value]*ref_props_ban_zeng_mean_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_ban_zeng_mean_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_ban_zeng_high_gl.loc[:,value] = (ref_props_ban_zeng_high_cn.loc[:,value]*ref_props_ban_zeng_high_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_ban_zeng_high_rw.loc[:,value]*ref_props_ban_zeng_high_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_ban_zeng_high_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    
print('Done')

# %%
for value in ref_props_fruity1rr0_gl.loc[:,'Primary CU':].columns:

    ref_props_fruity1rr0_gl.loc[:,value] = (ref_props_fruity1rr0_cn.loc[:,value]*ref_props_fruity1rr0_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity1rr0_rw.loc[:,value]*ref_props_fruity1rr0_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity1rr50_gl.loc[:,value] = (ref_props_fruity1rr50_cn.loc[:,value]*ref_props_fruity1rr50_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity1rr50_rw.loc[:,value]*ref_props_fruity1rr50_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity1rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity1rr90_gl.loc[:,value] = (ref_props_fruity1rr90_cn.loc[:,value]*ref_props_fruity1rr90_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity1rr90_rw.loc[:,value]*ref_props_fruity1rr90_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity1rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity1rr100_gl.loc[:,value] = (ref_props_fruity1rr100_cn.loc[:,value]*ref_props_fruity1rr100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity1rr100_rw.loc[:,value]*ref_props_fruity1rr100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity1rr100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct1rr0_gl.loc[:,value] = (ref_props_fruity_pct1rr0_cn.loc[:,value]*ref_props_fruity_pct1rr0_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct1rr0_rw.loc[:,value]*ref_props_fruity_pct1rr0_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct1rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct1rr50_gl.loc[:,value] = (ref_props_fruity_pct1rr50_cn.loc[:,value]*ref_props_fruity_pct1rr50_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct1rr50_rw.loc[:,value]*ref_props_fruity_pct1rr50_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct1rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct1rr90_gl.loc[:,value] = (ref_props_fruity_pct1rr90_cn.loc[:,value]*ref_props_fruity_pct1rr90_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct1rr90_rw.loc[:,value]*ref_props_fruity_pct1rr90_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct1rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct1rr100_gl.loc[:,value] = (ref_props_fruity_pct1rr100_cn.loc[:,value]*ref_props_fruity_pct1rr100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct1rr100_rw.loc[:,value]*ref_props_fruity_pct1rr100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct1rr100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct5rr0_gl.loc[:,value] = (ref_props_fruity_pct5rr0_cn.loc[:,value]*ref_props_fruity_pct5rr0_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct5rr0_rw.loc[:,value]*ref_props_fruity_pct5rr0_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct5rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct5rr50_gl.loc[:,value] = (ref_props_fruity_pct5rr50_cn.loc[:,value]*ref_props_fruity_pct5rr50_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct5rr50_rw.loc[:,value]*ref_props_fruity_pct5rr50_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct5rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct5rr90_gl.loc[:,value] = (ref_props_fruity_pct5rr90_cn.loc[:,value]*ref_props_fruity_pct5rr90_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct5rr90_rw.loc[:,value]*ref_props_fruity_pct5rr90_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct5rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct5rr100_gl.loc[:,value] = (ref_props_fruity_pct5rr100_cn.loc[:,value]*ref_props_fruity_pct5rr100_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct5rr100_rw.loc[:,value]*ref_props_fruity_pct5rr100_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct5rr100_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct10rr0_gl.loc[:,value] = (ref_props_fruity_pct10rr0_cn.loc[:,value]*ref_props_fruity_pct10rr0_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct10rr0_rw.loc[:,value]*ref_props_fruity_pct10rr0_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct10rr0_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct10rr11_gl.loc[:,value] = (ref_props_fruity_pct10rr11_cn.loc[:,value]*ref_props_fruity_pct10rr11_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct10rr11_rw.loc[:,value]*ref_props_fruity_pct10rr11_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct10rr11_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct10rr50_gl.loc[:,value] = (ref_props_fruity_pct10rr50_cn.loc[:,value]*ref_props_fruity_pct10rr50_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct10rr50_rw.loc[:,value]*ref_props_fruity_pct10rr50_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct10rr50_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct10rr90_gl.loc[:,value] = (ref_props_fruity_pct10rr90_cn.loc[:,value]*ref_props_fruity_pct10rr90_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct10rr90_rw.loc[:,value]*ref_props_fruity_pct10rr90_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct10rr90_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)
    ref_props_fruity_pct10rr70_gl.loc[:,value] = (ref_props_fruity_pct10rr70_cn.loc[:,value]*ref_props_fruity_pct10rr70_cn.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)+ref_props_fruity_pct10rr70_rw.loc[:,value]*ref_props_fruity_pct10rr70_rw.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)) / ref_props_fruity_pct10rr70_gl.loc[:,'Primary refining production':'Secondary refining production'].sum(axis=1)

# %%
fig1,(ax1,ax2) = plt.subplots(1,2)
ax1.plot(ref_props_alloyed_imports_50yoy_gl.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1) - ref_props_pir_baseline_gl.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban alloyed')
ax1.plot(ref_props_ban_no2_50yoy_gl.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1) - ref_props_pir_baseline_gl.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban No.2')
ax1.plot(ref_props_alloyed_no2_50yoy_gl.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1) - ref_props_pir_baseline_gl.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban both', color = 'tab:green')
ax1.set_title('Total refining production difference from baseline \nGlobal')

ax2.plot(ref_props_alloyed_imports_50yoy_gl.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban alloyed')
ax2.plot(ref_props_ban_no2_50yoy_gl.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban No.2')
ax2.plot(ref_props_alloyed_no2_50yoy_gl.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban both', color = 'tab:green')
ax2.plot(ref_props_pir_baseline_gl.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Baseline', color = 'darkblue')
ax2.legend()
ax2.set_title('Total refining production\nGlobal')

fig2,(ax1,ax2) = plt.subplots(1,2)
ax1.plot(ref_props_alloyed_imports_50yoy_rw.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1) - ref_props_pir_baseline_rw.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban alloyed')
ax1.plot(ref_props_ban_no2_50yoy_rw.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1) - ref_props_pir_baseline_rw.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban No.2')
ax1.plot(ref_props_alloyed_no2_50yoy_rw.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1) - ref_props_pir_baseline_rw.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban both', color = 'tab:green')
ax1.set_title('Total refining production difference from baseline \nRest of World')

ax2.plot(ref_props_alloyed_imports_50yoy_rw.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban alloyed')
ax2.plot(ref_props_ban_no2_50yoy_rw.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban No.2')
ax2.plot(ref_props_alloyed_no2_50yoy_rw.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban both', color = 'tab:green')
ax2.plot(ref_props_pir_baseline_rw.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Baseline', color = 'darkblue')
ax2.legend()
ax2.set_title('Total refining production\nRest of World')

fig3,(ax1,ax2) = plt.subplots(1,2)
ax1.plot(ref_props_alloyed_imports_50yoy_cn.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1) - ref_props_pir_baseline_cn.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban alloyed')
ax1.plot(ref_props_ban_no2_50yoy_cn.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1) - ref_props_pir_baseline_cn.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban No.2')
ax1.plot(ref_props_alloyed_no2_50yoy_cn.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1) - ref_props_pir_baseline_cn.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban both', color = 'tab:green')
ax1.set_title('Total refining production difference from baseline \nChina')

ax2.plot(ref_props_alloyed_imports_50yoy_cn.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban alloyed')
ax2.plot(ref_props_ban_no2_50yoy_cn.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban No.2')
ax2.plot(ref_props_alloyed_no2_50yoy_cn.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Ban both', color = 'tab:green')
ax2.plot(ref_props_pir_baseline_cn.loc['20180101':,'Primary refining production':'Secondary refining production'].sum(axis=1), label = 'Baseline', color = 'darkblue')
ax2.legend()
ax2.set_title('Total refining production\nChina')

# %% [markdown]
# #### Fruity refining

# %% [markdown]
# China refined demand for each market fraction and minimum recycled content

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [16, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
# %config InlineBackend.figure_format ='retina'


fig1,(ax1,ax2) = plt.subplots(1,2, frameon=0)
ax1.plot(ref_props_fruity1rr11_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1X 1% RR')
ax1.plot(ref_props_fruity1rr50_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1X 50% RR')
ax1.plot(ref_props_fruity1rr90_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1X 90% RR', color = 'tab:pink')
ax1.plot(ref_props_fruity1rr100_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1X 100% RR', color = 'tab:gray')
ax1.set_title('CN Refined demand difference from baseline \nChina, 0.08% of Copper Market')
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(ref_props_fruity1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1X 0% RR')
ax2.plot(ref_props_fruity1rr11_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1X 1% RR')
ax2.plot(ref_props_fruity1rr50_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1X 50% RR')
ax2.plot(ref_props_fruity1rr90_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1X 90% RR', color = 'tab:pink')
ax2.plot(ref_props_fruity1rr100_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1X 100% RR', color = 'tab:gray')
ax2.set_title('CN Refined Demand Evolution \nChina, 0.08% of Copper Market')
ax2.legend()
ax2.set_title('CN Refined Demand Evolution\nChina, 0.08% of Copper Market')
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig2,(ax1,ax2) = plt.subplots(1,2, frameon=0)
ax1.plot(ref_props_fruity_pct1rr11_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 1% RR')
ax1.plot(ref_props_fruity_pct1rr50_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 50% RR')
ax1.plot(ref_props_fruity_pct1rr90_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 90% RR', color = 'tab:pink')
ax1.plot(ref_props_fruity_pct1rr100_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 100% RR', color = 'tab:gray')
ax1.set_title('CN Refined demand difference from baseline\nChina, 1% of Copper Market')
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(ref_props_fruity_pct1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 0% RR')
ax2.plot(ref_props_fruity_pct1rr11_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 1% RR')
ax2.plot(ref_props_fruity_pct1rr50_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 50% RR')
ax2.plot(ref_props_fruity_pct1rr90_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 90% RR', color = 'tab:pink')
ax2.plot(ref_props_fruity_pct1rr100_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 100% RR', color = 'tab:gray')
ax2.legend()
ax2.set_title('CN Refined Demand Evolution\nChina, 1% of Copper Market')
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig3,(ax1,ax2) = plt.subplots(1,2, frameon=0)
ax1.plot(ref_props_fruity_pct5rr11_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct5rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 1% RR')
ax1.plot(ref_props_fruity_pct5rr50_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct5rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 50% RR')
ax1.plot(ref_props_fruity_pct5rr90_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct5rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 90% RR', color = 'tab:pink')
ax1.plot(ref_props_fruity_pct5rr100_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct5rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 100% RR', color = 'tab:gray')
ax1.set_title('CN Refined demand difference from baseline\nChina, 5% of Copper Market')
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(ref_props_fruity_pct5rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 0% RR')
ax2.plot(ref_props_fruity_pct5rr11_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 1% RR')
ax2.plot(ref_props_fruity_pct5rr50_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 50% RR')
ax2.plot(ref_props_fruity_pct5rr90_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 90% RR', color = 'tab:pink')
ax2.plot(ref_props_fruity_pct5rr100_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 100% RR', color = 'tab:gray')
ax2.legend()
ax2.set_title('CN Refined Demand Evolution\nChina, 5% of Copper Market')
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig4,(ax1,ax2) = plt.subplots(1,2, frameon=0)
ax1.plot(ref_props_fruity_pct10rr11_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 1% RR')
ax1.plot(ref_props_fruity_pct10rr50_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 50% RR')
ax1.plot(ref_props_fruity_pct10rr70_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 70% RR', color = 'tab:pink')
ax1.plot(ref_props_fruity_pct10rr90_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 90% RR', color = 'tab:gray')
ax1.set_title('CN Refined demand difference from baseline\nChina, 10% of Copper Market')
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(ref_props_fruity_pct10rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 0% RR')
ax2.plot(ref_props_fruity_pct10rr11_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 1% RR')
ax2.plot(ref_props_fruity_pct10rr50_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 50% RR')
ax2.plot(ref_props_fruity_pct10rr70_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 70% RR', color = 'tab:pink')
ax2.plot(ref_props_fruity_pct10rr90_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 90% RR', color = 'tab:gray')
ax2.legend()
ax2.set_title('CN Refined Demand Evolution\nChina, 10% of Copper Market')
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig5,(ax1,ax2) = plt.subplots(1,2, frameon=0)
ax1.plot(ref_props_fruity1rr90_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 0.08mrk% 90% RR')
ax1.plot(ref_props_fruity_pct1rr90_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct1rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 90% RR')
ax1.plot(ref_props_fruity_pct5rr90_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct5rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 90% RR', color = 'tab:pink')
ax1.plot(ref_props_fruity_pct10rr70_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 70% RR', color = 'tab:gray')
ax1.set_title('CN Refined demand difference from baseline\nChina, varying percentages')
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(ref_props_fruity_pct10rr90_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 0.08mrk% 90% RR')
ax2.plot(ref_props_fruity_pct1rr90_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 1mrk% 90% RR')
ax2.plot(ref_props_fruity_pct5rr90_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 5mrk% 90% RR', color = 'tab:pink')
ax2.plot(ref_props_fruity_pct10rr70_cn.loc['20180101':,'CN Refined demand'], label = 'Fruity 10mrk% 70% RR', color = 'tab:gray')
ax2.legend()
ax2.set_title('CN Refined Demand Evolution\nChina, varying percentages')
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %%
# Redoing the ones above for presentation
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
plt.axes(frameon=0)

plt.plot(ref_props_fruity1rr0_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 1X 0% RR', color=colors[2])
# plt.plot(ref_props_fruity1rr11_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 1X 1% RR')
plt.plot(ref_props_fruity1rr50_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 1X 50% RR', color=colors[0])
# plt.plot(ref_props_fruity1rr90_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 1X 90% RR', color = 'tab:pink')
plt.plot(ref_props_fruity1rr100_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 1X 100% RR', color = colors[1])
plt.title('China Refined Copper Demand Evolution \n0.08% of Copper Market')
# plt.legend()
plt.title('China Refined Copper Demand Evolution\n0.08% of Copper Market')
plt.ylabel('Refined Demand (million tonnes)')
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
# %config InlineBackend.figure_format ='retina'

plt.figure()
plt.axes(frameon=0)
plt.plot(ref_props_fruity_pct1rr0_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 1mrk% 0% RR', color = colors[2])
# plt.plot(ref_props_fruity_pct1rr11_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 1mrk% 1% RR')
plt.plot(ref_props_fruity_pct1rr50_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 1mrk% 50% RR', color = colors[0])
# plt.plot(ref_props_fruity_pct1rr90_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 1mrk% 90% RR', color = 'tab:pink')
plt.plot(ref_props_fruity_pct1rr100_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 1mrk% 100% RR', color = colors[1])
# plt.legend()
plt.title('China Refined Copper Demand Evolution\n1% of Copper Market')
plt.ylabel('Refined Demand (million tonnes)')
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
# %config InlineBackend.figure_format ='retina'

plt.figure()
plt.axes(frameon=0)
plt.plot(ref_props_fruity_pct5rr0_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 5mrk% 0% RR', color = colors[2])
# plt.plot(ref_props_fruity_pct5rr11_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 5mrk% 1% RR')
plt.plot(ref_props_fruity_pct5rr50_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 5mrk% 50% RR', color = colors[0])
# plt.plot(ref_props_fruity_pct5rr90_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 5mrk% 90% RR', color = 'tab:pink')
plt.plot(ref_props_fruity_pct5rr100_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 5mrk% 100% RR', color = colors[1])
# plt.legend()
plt.title('China Refined Copper Demand Evolution\n5% of Copper Market')
plt.ylabel('Refined Demand (million tonnes)')
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
# %config InlineBackend.figure_format ='retina'

plt.figure()
plt.axes(frameon=0)
plt.plot(ref_props_fruity_pct10rr0_cn.loc['20180101':,'CN Refined demand']/1000, label = '0% Recycled Content', color = colors[2])
# plt.plot(ref_props_fruity_pct10rr11_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 10mrk% 1% RR')
plt.plot(ref_props_fruity_pct10rr50_cn.loc['20180101':,'CN Refined demand']/1000, label = '50% Recycled Content', color = colors[0])
# plt.plot(ref_props_fruity_pct10rr70_cn.loc['20180101':,'CN Refined demand']/1000, label = 'Fruity 10mrk% 70% RR', color = 'tab:pink')
plt.plot(ref_props_fruity_pct10rr90_cn.loc['20180101':,'CN Refined demand']/1000, label = '90% Recycled Content', color = colors[1])
plt.legend()
plt.title('China Refined Copper Demand Evolution\n10% of Copper Market')
plt.ylabel('Refined Demand (million tonnes)')
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# Regional refined demand for 0.08% and 10% of market

# %%
# pplot(ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand'], label='Baseline',color='k',firstcall=1)
# pplot(100*(ref_props_fruity_pct10rr50var0_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var0',color=colors[0],firstcall=1)
pplot(100*(ref_props_fruity_pct10rr50var10_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var10',color=colors[0], firstcall = 1)
pplot(100*(ref_props_fruity_pct10rr50var30_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var30',color=colors[1])
pplot(100*(ref_props_fruity_pct10rr50var50_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var50',color=colors[2])
pplot(100*(ref_props_fruity_pct10rr50var70_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var70',color=colors[3])
# pplot(100*(ref_props_fruity_pct10rr50var90_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var90',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([-0.02,0,0.02,0.04])
plt.ylabel('Cumulative response above baseline \n(% of RoW 2020 production)')
plt.suptitle('Rest of World Cathode Consumption Response above Baseline')
plt.title('10% of Copper Market', color = color_10)
ylims_rw = plt.ylim()

# pplot(ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand'], label='Baseline',color='k',firstcall=1)
# pplot(100*(ref_props_fruity_pct10rr50var0_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var0',color=colors[0],firstcall=1)
pplot(100*(ref_props_fruity_pct10rr50var10_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var10',color=colors[0], firstcall = 1)
pplot(100*(ref_props_fruity_pct10rr50var30_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var30',color=colors[1])
pplot(100*(ref_props_fruity_pct10rr50var50_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var50',color=colors[2])
pplot(100*(ref_props_fruity_pct10rr50var70_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var70',color=colors[3])
# pplot(100*(ref_props_fruity_pct10rr50var90_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity_pct10rr0_1_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var90',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
plt.yticks([0,-50,-100,-150])
plt.ylabel('Cumulative response above baseline \n(% of China 2020 production)')
plt.suptitle('China Cathode Consumption Response above Baseline')
plt.title('10% of Copper Market', color = color_10)
ylims_cn=plt.ylim()

# pplot(ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand'], label='Baseline',color='k',firstcall=1)
# pplot(100*(ref_props_fruity1rr100var0_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity1rr0var0_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var0',color=colors[0],firstcall=1)
pplot(100*(ref_props_fruity1rr100var10_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity1rr0var0_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var10',color=colors[0], firstcall = 1)
pplot(100*(ref_props_fruity1rr100var30_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity1rr0var0_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var30',color=colors[1])
pplot(100*(ref_props_fruity1rr100var50_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity1rr0var0_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var50',color=colors[2])
pplot(100*(ref_props_fruity1rr100var70_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity1rr0var0_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var70',color=colors[3])
# pplot(100*(ref_props_fruity1rr100var90_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand']).cumsum() / ref_props_fruity1rr0var0_cn.loc['20200101','CN Refined demand'], label='0.08mrk% 100% RR, var90',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([-0.02,0,0.02,0.04])
plt.ylabel('Cumulative response above baseline \n(% of China 2020 production)')
plt.suptitle('China Cathode Consumption Response above Baseline')
plt.title('0.08% of Copper Market', color = color_08)
plt.ylim(ylims_cn)
plt.yticks([0,-50,-100,-150])

# pplot(ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand'], label='Baseline',color='k',firstcall=1)
# pplot(100*(ref_props_fruity1rr100var0_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity1rr0var0_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var0',color=colors[0],firstcall=1)
pplot(100*(ref_props_fruity1rr100var10_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity1rr0var0_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var10',color=colors[0], firstcall = 1)
pplot(100*(ref_props_fruity1rr100var30_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity1rr0var0_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var30',color=colors[1])
pplot(100*(ref_props_fruity1rr100var50_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity1rr0var0_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var50',color=colors[2])
pplot(100*(ref_props_fruity1rr100var70_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity1rr0var0_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var70',color=colors[3])
# pplot(100*(ref_props_fruity1rr100var90_rw.loc['20180101':,'RoW Refined demand'] - ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand']).cumsum() / ref_props_fruity1rr0var0_rw.loc['20200101','RoW Refined demand'], label='0.08mrk% 100% RR, var90',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([-0.02,0,0.02,0.04])
plt.ylabel('Cumulative response above baseline \n(% of RoW 2020 production)')
plt.suptitle('Rest of World Cathode Consumption Response above Baseline')
plt.title('0.08% of Copper Market', color = color_08)
plt.ylim(ylims_rw)

# %% [markdown]
# Calculating total refining production

# %%
ref_props_fruity_pct10rr0_1_gl.loc[:,'Total refining production'] = ref_props_fruity_pct10rr0_1_gl.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr0_1_gl.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var10_gl.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var10_gl.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var10_gl.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var30_gl.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var30_gl.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var30_gl.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var50_gl.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var50_gl.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var50_gl.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var70_gl.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var70_gl.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var70_gl.loc[:,'Primary refining production']

ref_props_fruity1rr0var0_gl.loc[:,'Total refining production'] = ref_props_fruity1rr0var0_gl.loc[:,'Secondary refining production'] + ref_props_fruity1rr0var0_gl.loc[:,'Primary refining production']
ref_props_fruity1rr100var10_gl.loc[:,'Total refining production'] = ref_props_fruity1rr100var10_gl.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var10_gl.loc[:,'Primary refining production']
ref_props_fruity1rr100var30_gl.loc[:,'Total refining production'] = ref_props_fruity1rr100var30_gl.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var30_gl.loc[:,'Primary refining production']
ref_props_fruity1rr100var50_gl.loc[:,'Total refining production'] = ref_props_fruity1rr100var50_gl.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var50_gl.loc[:,'Primary refining production']
ref_props_fruity1rr100var70_gl.loc[:,'Total refining production'] = ref_props_fruity1rr100var70_gl.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var70_gl.loc[:,'Primary refining production']

ref_props_fruity_pct10rr0_1_cn.loc[:,'Total refining production'] = ref_props_fruity_pct10rr0_1_cn.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr0_1_cn.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var10_cn.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var10_cn.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var10_cn.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var30_cn.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var30_cn.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var30_cn.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var50_cn.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var50_cn.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var50_cn.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var70_cn.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var70_cn.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var70_cn.loc[:,'Primary refining production']

ref_props_fruity1rr0var0_cn.loc[:,'Total refining production'] = ref_props_fruity1rr0var0_cn.loc[:,'Secondary refining production'] + ref_props_fruity1rr0var0_cn.loc[:,'Primary refining production']
ref_props_fruity1rr100var10_cn.loc[:,'Total refining production'] = ref_props_fruity1rr100var10_cn.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var10_cn.loc[:,'Primary refining production']
ref_props_fruity1rr100var30_cn.loc[:,'Total refining production'] = ref_props_fruity1rr100var30_cn.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var30_cn.loc[:,'Primary refining production']
ref_props_fruity1rr100var50_cn.loc[:,'Total refining production'] = ref_props_fruity1rr100var50_cn.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var50_cn.loc[:,'Primary refining production']
ref_props_fruity1rr100var70_cn.loc[:,'Total refining production'] = ref_props_fruity1rr100var70_cn.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var70_cn.loc[:,'Primary refining production']

ref_props_fruity_pct10rr0_1_rw.loc[:,'Total refining production'] = ref_props_fruity_pct10rr0_1_rw.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr0_1_rw.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var10_rw.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var10_rw.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var10_rw.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var30_rw.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var30_rw.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var30_rw.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var50_rw.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var50_rw.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var50_rw.loc[:,'Primary refining production']
ref_props_fruity_pct10rr50var70_rw.loc[:,'Total refining production'] = ref_props_fruity_pct10rr50var70_rw.loc[:,'Secondary refining production'] + ref_props_fruity_pct10rr50var70_rw.loc[:,'Primary refining production']

ref_props_fruity1rr0var0_rw.loc[:,'Total refining production'] = ref_props_fruity1rr0var0_rw.loc[:,'Secondary refining production'] + ref_props_fruity1rr0var0_rw.loc[:,'Primary refining production']
ref_props_fruity1rr100var10_rw.loc[:,'Total refining production'] = ref_props_fruity1rr100var10_rw.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var10_rw.loc[:,'Primary refining production']
ref_props_fruity1rr100var30_rw.loc[:,'Total refining production'] = ref_props_fruity1rr100var30_rw.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var30_rw.loc[:,'Primary refining production']
ref_props_fruity1rr100var50_rw.loc[:,'Total refining production'] = ref_props_fruity1rr100var50_rw.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var50_rw.loc[:,'Primary refining production']
ref_props_fruity1rr100var70_rw.loc[:,'Total refining production'] = ref_props_fruity1rr100var70_rw.loc[:,'Secondary refining production'] + ref_props_fruity1rr100var70_rw.loc[:,'Primary refining production']

# %%
# pplot(ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'Primary refining production'], label='Baseline',color='k',firstcall=1)
pplot(100*(ref_props_fruity_pct10rr50var10_rw.loc['20180101':,'Primary refining production'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'Primary refining production']).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101','Primary refining production'], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(100*(ref_props_fruity_pct10rr50var30_rw.loc['20180101':,'Primary refining production'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'Primary refining production']).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101','Primary refining production'], label='10mrk% 50% RR, var30',color=colors[1])
pplot(100*(ref_props_fruity_pct10rr50var50_rw.loc['20180101':,'Primary refining production'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'Primary refining production']).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101','Primary refining production'], label='10mrk% 50% RR, var50',color=colors[2])
pplot(100*(ref_props_fruity_pct10rr50var70_rw.loc['20180101':,'Primary refining production'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'Primary refining production']).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101','Primary refining production'], label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([-0.4,-0.2,0,0.2,0.4])
plt.ylabel('Refined demand response above baseline \n(% of 2020 production)')
plt.title('Rest of World Refined Demand Response above Baseline \n10% of Copper Market')

# %% [markdown]
# Loop for plotting the response for refinery parameters as % of 2020 production

# %%
for prop in ['Primary refining production', 'Secondary refining production', 'Total refining production']:
    # pplot(ref_props_fruity_pct10rr0_1_gl.loc['20180101':,prop], label='Baseline',color='k',firstcall=1)
    pplot(100*(ref_props_fruity_pct10rr50var10_gl.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_gl.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_gl.loc['20200101',prop], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
    pplot(100*(ref_props_fruity_pct10rr50var30_gl.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_gl.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_gl.loc['20200101',prop], label='10mrk% 50% RR, var30',color=colors[1])
    pplot(100*(ref_props_fruity_pct10rr50var50_gl.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_gl.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_gl.loc['20200101',prop], label='10mrk% 50% RR, var50',color=colors[2])
    pplot(100*(ref_props_fruity_pct10rr50var70_gl.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_gl.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_gl.loc['20200101',prop], label='10mrk% 50% RR, var70',color=colors[3])
    plt.legend().set_visible(False)
    # plt.xlabel('Year')
    plt.ylim(-5.2, 3.2)
    if 'demand' in prop:
        plt.ylabel('Cathode consumption response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('Global Cathode Consumption Response')
    else:
        plt.ylabel(prop+' response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('Global '+prop.title()+' Response')
    plt.title('10% of Copper Market', color = color_10)
    
    # pplot(ref_props_fruity_pct10rr0_1_cn.loc['20180101':,prop], label='Baseline',color='k',firstcall=1)
    pplot(100*(ref_props_fruity_pct10rr50var10_cn.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_cn.loc['20200101',prop], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
    pplot(100*(ref_props_fruity_pct10rr50var30_cn.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_cn.loc['20200101',prop], label='10mrk% 50% RR, var30',color=colors[1])
    pplot(100*(ref_props_fruity_pct10rr50var50_cn.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_cn.loc['20200101',prop], label='10mrk% 50% RR, var50',color=colors[2])
    pplot(100*(ref_props_fruity_pct10rr50var70_cn.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_cn.loc['20200101',prop], label='10mrk% 50% RR, var70',color=colors[3])
    plt.legend().set_visible(False)
    plt.yticks([0,-50,-100,-150])
    # plt.xlabel('Year')
    if 'demand' in prop:
        plt.ylabel('Cathode consumption response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('China Cathode Consumption Response')
    else:
        plt.ylabel(prop+' response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('China '+prop.title()+' Response')
    plt.title('10% of Copper Market', color = color_10)
    ylims_cn = plt.ylim()

    # pplot(ref_props_fruity_pct10rr0_1_rw.loc['20180101':,prop], label='Baseline',color='k',firstcall=1)
    pplot(100*(ref_props_fruity_pct10rr50var10_rw.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101',prop], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
    pplot(100*(ref_props_fruity_pct10rr50var30_rw.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101',prop], label='10mrk% 50% RR, var30',color=colors[1])
    pplot(100*(ref_props_fruity_pct10rr50var50_rw.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101',prop], label='10mrk% 50% RR, var50',color=colors[2])
    pplot(100*(ref_props_fruity_pct10rr50var70_rw.loc['20180101':,prop] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,prop]).cumsum() / ref_props_fruity_pct10rr0_1_rw.loc['20200101',prop], label='10mrk% 50% RR, var70',color=colors[3])
    plt.legend().set_visible(False)
    # plt.xlabel('Year')
    # plt.yticks([-0.4,-0.2,0,0.2,0.4])
    if 'demand' in prop:
        plt.ylabel('Cathode consumption response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('Rest of World Cathode Consumption Response')
    else:
        plt.ylabel(prop+' response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('Rest of World '+prop.title()+' Response')
    plt.title('10% of Copper Market', color = color_10)
    ylims_rw = plt.ylim()
    
    # 0.08% of market
        # pplot(ref_props_fruity1rr0var0_cn.loc['20180101':,prop], label='Baseline',color='k',firstcall=1)
    pplot(100*(ref_props_fruity1rr100var10_cn.loc['20180101':,prop] - ref_props_fruity1rr0var0_cn.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_cn.loc['20200101',prop], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
    pplot(100*(ref_props_fruity1rr100var30_cn.loc['20180101':,prop] - ref_props_fruity1rr0var0_cn.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_cn.loc['20200101',prop], label='10mrk% 50% RR, var30',color=colors[1])
    pplot(100*(ref_props_fruity1rr100var50_cn.loc['20180101':,prop] - ref_props_fruity1rr0var0_cn.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_cn.loc['20200101',prop], label='10mrk% 50% RR, var50',color=colors[2])
    pplot(100*(ref_props_fruity1rr100var70_cn.loc['20180101':,prop] - ref_props_fruity1rr0var0_cn.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_cn.loc['20200101',prop], label='10mrk% 50% RR, var70',color=colors[3])
    plt.legend().set_visible(False)
    # plt.xlabel('Year')
    if 'demand' in prop:
        plt.ylabel('Cathode consumption response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('China Cathode Consumption Response')
    else:
        plt.ylabel(prop+' response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('China '+prop.title()+' Response')    
    plt.title('0.08% of Copper Market', color = color_08)
    plt.ylim(ylims_cn)

    # pplot(ref_props_fruity1rr0var0_rw.loc['20180101':,prop], label='Baseline',color='k',firstcall=1)
    pplot(100*(ref_props_fruity1rr100var10_rw.loc['20180101':,prop] - ref_props_fruity1rr0var0_rw.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_rw.loc['20200101',prop], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
    pplot(100*(ref_props_fruity1rr100var30_rw.loc['20180101':,prop] - ref_props_fruity1rr0var0_rw.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_rw.loc['20200101',prop], label='10mrk% 50% RR, var30',color=colors[1])
    pplot(100*(ref_props_fruity1rr100var50_rw.loc['20180101':,prop] - ref_props_fruity1rr0var0_rw.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_rw.loc['20200101',prop], label='10mrk% 50% RR, var50',color=colors[2])
    pplot(100*(ref_props_fruity1rr100var70_rw.loc['20180101':,prop] - ref_props_fruity1rr0var0_rw.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_rw.loc['20200101',prop], label='10mrk% 50% RR, var70',color=colors[3])
    plt.legend().set_visible(False)
    # plt.xlabel('Year')
    # plt.yticks([-0.4,-0.2,0,0.2,0.4])
    if 'demand' in prop:
        plt.ylabel('Cathode consumption response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('Rest of World Cathode Consumption Response')
    else:
        plt.ylabel(prop+' response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('Rest of World '+prop.title()+' Response')
    plt.title('0.08% of Copper Market', color = color_08)
    plt.ylim(ylims_rw)

    # pplot(ref_props_fruity1rr0var0_gl.loc['20180101':,prop], label='Baseline',color='k',firstcall=1)
    pplot(100*(ref_props_fruity1rr100var10_gl.loc['20180101':,prop] - ref_props_fruity1rr0var0_gl.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_gl.loc['20200101',prop], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
    pplot(100*(ref_props_fruity1rr100var30_gl.loc['20180101':,prop] - ref_props_fruity1rr0var0_gl.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_gl.loc['20200101',prop], label='10mrk% 50% RR, var30',color=colors[1])
    pplot(100*(ref_props_fruity1rr100var50_gl.loc['20180101':,prop] - ref_props_fruity1rr0var0_gl.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_gl.loc['20200101',prop], label='10mrk% 50% RR, var50',color=colors[2])
    pplot(100*(ref_props_fruity1rr100var70_gl.loc['20180101':,prop] - ref_props_fruity1rr0var0_gl.loc['20180101':,prop]).cumsum() / ref_props_fruity1rr0var0_gl.loc['20200101',prop], label='10mrk% 50% RR, var70',color=colors[3])
    plt.legend().set_visible(False)
    # plt.xlabel('Year')
    # plt.yticks([-0.4,-0.2,0,0.2,0.4])
    plt.ylim(-5.2, 3.2)
    if 'demand' in prop:
        plt.ylabel('Cathode consumption response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('Global Cathode Consumption Response')
    else:
        plt.ylabel(prop+' response \n(Cumulative, % of global 2020 production)')
        plt.suptitle('Global '+prop.title()+' Response')
    plt.title('0.08% of Copper Market', color = color_08)

# %%
Cathode balance evolution

# %%
pplot((ref_props_fruity_pct10rr50var10_gl.loc['20180101':,'Total refining production'] - ref_props_fruity_pct10rr50var10_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr50var10_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity_pct10rr0_1_gl.loc['20180101':,'Total refining production'] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand']), label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot((ref_props_fruity_pct10rr50var30_gl.loc['20180101':,'Total refining production'] - ref_props_fruity_pct10rr50var30_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr50var30_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity_pct10rr0_1_gl.loc['20180101':,'Total refining production'] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand']), label='10mrk% 50% RR, var30',color=colors[1])
pplot((ref_props_fruity_pct10rr50var50_gl.loc['20180101':,'Total refining production'] - ref_props_fruity_pct10rr50var50_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr50var50_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity_pct10rr0_1_gl.loc['20180101':,'Total refining production'] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand']), label='10mrk% 50% RR, var50',color=colors[2])
pplot((ref_props_fruity_pct10rr50var70_gl.loc['20180101':,'Total refining production'] - ref_props_fruity_pct10rr50var70_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr50var70_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity_pct10rr0_1_gl.loc['20180101':,'Total refining production'] - ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand'] - ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand']), label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.ylim(-5.2, 3.2)
plt.ylabel(prop+' response (kt)')
plt.suptitle('Global refining balance response above baseline')
plt.title('10% of Copper Market', color = color_10)

# %%
Total refined demand response

# %%
pplot(((ref_props_fruity1rr100var10_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity1rr100var10_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand'])).cumsum() / (ref_props_fruity1rr0var0_cn.loc['20200101','CN Refined demand'] + ref_props_fruity1rr0var0_rw.loc['20200101','RoW Refined demand']) * 100, label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(((ref_props_fruity1rr100var30_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity1rr100var30_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand'])).cumsum() / (ref_props_fruity1rr0var0_cn.loc['20200101','CN Refined demand'] + ref_props_fruity1rr0var0_rw.loc['20200101','RoW Refined demand']) * 100, label='10mrk% 50% RR, var30',color=colors[1])
pplot(((ref_props_fruity1rr100var50_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity1rr100var50_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand'])).cumsum() / (ref_props_fruity1rr0var0_cn.loc['20200101','CN Refined demand'] + ref_props_fruity1rr0var0_rw.loc['20200101','RoW Refined demand']) * 100, label='10mrk% 50% RR, var50',color=colors[2])
pplot(((ref_props_fruity1rr100var70_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity1rr100var70_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity1rr0var0_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity1rr0var0_rw.loc['20180101':,'RoW Refined demand'])).cumsum() / (ref_props_fruity1rr0var0_cn.loc['20200101','CN Refined demand'] + ref_props_fruity1rr0var0_rw.loc['20200101','RoW Refined demand']) * 100, label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
plt.ylim(-2.4,0.9)
plt.ylabel('Refined demand response above baseline\n(Cumulative, % of 2020 demand)')
plt.suptitle('Global Refined Demand Response above Baseline')
plt.title('0.08% of Copper Market', color = color_08)


pplot(((ref_props_fruity_pct10rr50var10_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity_pct10rr50var10_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand'])).cumsum() / (ref_props_fruity_pct10rr0_1_cn.loc['20200101','CN Refined demand'] + ref_props_fruity_pct10rr0_1_rw.loc['20200101','RoW Refined demand']) * 100, label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(((ref_props_fruity_pct10rr50var30_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity_pct10rr50var30_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand'])).cumsum() / (ref_props_fruity_pct10rr0_1_cn.loc['20200101','CN Refined demand'] + ref_props_fruity_pct10rr0_1_rw.loc['20200101','RoW Refined demand']) * 100, label='10mrk% 50% RR, var30',color=colors[1])
pplot(((ref_props_fruity_pct10rr50var50_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity_pct10rr50var50_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand'])).cumsum() / (ref_props_fruity_pct10rr0_1_cn.loc['20200101','CN Refined demand'] + ref_props_fruity_pct10rr0_1_rw.loc['20200101','RoW Refined demand']) * 100, label='10mrk% 50% RR, var50',color=colors[2])
pplot(((ref_props_fruity_pct10rr50var70_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity_pct10rr50var70_rw.loc['20180101':,'RoW Refined demand']) - (ref_props_fruity_pct10rr0_1_cn.loc['20180101':,'CN Refined demand'] + ref_props_fruity_pct10rr0_1_rw.loc['20180101':,'RoW Refined demand'])).cumsum() / (ref_props_fruity_pct10rr0_1_cn.loc['20200101','CN Refined demand'] + ref_props_fruity_pct10rr0_1_rw.loc['20200101','RoW Refined demand']) * 100, label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
plt.ylim(-2.4,0.9)
plt.ylabel('Refined demand response above baseline\n(Cumulative, % of 2020 demand)')
plt.suptitle('Global Refined Demand Response above Baseline')
plt.title('10% of Copper Market', color = color_10)

# %%
pplot(ref_props_fruity_pct10rr0_1_gl.loc['20180101':,'Primary refining production'], label='Baseline',color='k')
pplot(ref_props_fruity_pct10rr50var10_gl.loc['20180101':,'Primary refining production'], label='10mrk% 50% RR, var10',color='tab:gray')
pplot(ref_props_fruity_pct10rr50var30_gl.loc['20180101':,'Primary refining production'], label='10mrk% 50% RR, var30',color='tab:blue')
pplot(ref_props_fruity_pct10rr50var50_gl.loc['20180101':,'Primary refining production'], label='10mrk% 50% RR, var50',color='tab:green')
pplot(ref_props_fruity_pct10rr50var70_gl.loc['20180101':,'Primary refining production'], label='10mrk% 50% RR, var70',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Primary refining production (kt)')
plt.title('Primary refining production\n(Fruity Alloys)')

# %% [markdown]
# #### China import Scenarios

# %% [markdown]
# Calculating response variables

# %%
this_thing_cn = pd.Series(0, index = ref_props_pir_baseline_gl.loc['20180101':].index)
this_thing_rw = pd.Series(0, index = ref_props_pir_baseline_gl.loc['20180101':].index)
for i in ref_props_pir_baseline_gl.loc['20180101':].index[:-1]:
    i_1 = i + pd.DateOffset(years=1)
    this_thing_cn.loc[i] = tcrc_series_pir_baseline.loc[i] + 100*ref_props_pir_baseline_cn.loc[i, 'Primary refining production'] / ref_props_pir_baseline_gl.loc[i, 'Primary refining production'] / (ref_props_pir_baseline_cn.loc[i_1, 'Primary refining production'] / ref_props_pir_baseline_gl.loc[i_1, 'Primary refining production'])
    this_thing_rw.loc[i] = tcrc_series_pir_baseline.loc[i] + 100*ref_props_pir_baseline_rw.loc[i, 'Primary refining production'] / ref_props_pir_baseline_gl.loc[i, 'Primary refining production'] / (ref_props_pir_baseline_rw.loc[i_1, 'Primary refining production'] / ref_props_pir_baseline_gl.loc[i_1, 'Primary refining production'])
    
pd.concat([this_thing_cn,this_thing_rw], axis=1, keys=['China','RoW']).plot()

# %%
ref_props_pir_baseline_cn.rename(columns={'Refined demand': 'CN Refined demand'}, inplace=True)
ref_props_pir_baseline_rw.rename(columns={'Refined demand': 'RoW Refined demand'}, inplace=True)

# %%
for prop in ['Primary refining production','Secondary refining production','Refined demand']:
    prop2 = prop
    ref_props_alloyed_50yoy_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc200_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec200_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()

    ref_props_no2_50yoy_gl.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc100_gl.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec100_gl.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc200_gl.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec200_gl.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()

    ref_props_both_50yoy_gl.loc['20170101':,prop+' response'] = ref_props_both_50yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc100_gl.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec100_gl.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc200_gl.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec200_gl.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()

    ref_props_alloyed_25yoy_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_25yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_25yoy_gl.loc['20170101':,prop+' response'] = ref_props_no2_25yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_25yoy_gl.loc['20170101':,prop+' response'] = ref_props_both_25yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    
    ref_props_alloyed_75yoy_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_75yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_75yoy_gl.loc['20170101':,prop+' response'] = ref_props_no2_75yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_75yoy_gl.loc['20170101':,prop+' response'] = ref_props_both_75yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    
    ref_props_ban_zeng_low_gl.loc['20170101':,prop+' response'] = ref_props_ban_zeng_low_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_mean_gl.loc['20170101':,prop+' response'] = ref_props_ban_zeng_mean_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_high_gl.loc['20170101':,prop+' response'] = ref_props_ban_zeng_high_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    
    if prop == 'Refined demand':
        prop2 = 'CN Refined demand'
    ref_props_both_50yoy_cn.loc['20170101':,prop+' response'] = ref_props_both_50yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc100_cn.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec100_cn.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc200_cn.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec200_cn.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()

    ref_props_alloyed_50yoy_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()

    ref_props_no2_50yoy_cn.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc100_cn.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec100_cn.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc200_cn.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec200_cn.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()

    ref_props_alloyed_25yoy_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_25yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_25yoy_cn.loc['20170101':,prop+' response'] = ref_props_no2_25yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_25yoy_cn.loc['20170101':,prop+' response'] = ref_props_both_25yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
   
    ref_props_alloyed_75yoy_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_75yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_75yoy_cn.loc['20170101':,prop+' response'] = ref_props_no2_75yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_75yoy_cn.loc['20170101':,prop+' response'] = ref_props_both_75yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    
    ref_props_ban_zeng_low_cn.loc['20170101':,prop+' response'] = ref_props_ban_zeng_low_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_mean_cn.loc['20170101':,prop+' response'] = ref_props_ban_zeng_mean_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_high_cn.loc['20170101':,prop+' response'] = ref_props_ban_zeng_high_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    
    if prop == 'Refined demand':
        prop2 = 'RoW Refined demand'
    ref_props_alloyed_50yoy_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_no2_50yoy_rw.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc100_rw.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec100_rw.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc200_rw.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec200_rw.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_both_50yoy_rw.loc['20170101':,prop+' response'] = ref_props_both_50yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc100_rw.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec100_rw.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc200_rw.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec200_rw.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_alloyed_25yoy_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_25yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_25yoy_rw.loc['20170101':,prop+' response'] = ref_props_no2_25yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_25yoy_rw.loc['20170101':,prop+' response'] = ref_props_both_25yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_alloyed_75yoy_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_75yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_75yoy_rw.loc['20170101':,prop+' response'] = ref_props_no2_75yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_75yoy_rw.loc['20170101':,prop+' response'] = ref_props_both_75yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_ban_zeng_low_rw.loc['20170101':,prop+' response'] = ref_props_ban_zeng_low_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_mean_rw.loc['20170101':,prop+' response'] = ref_props_ban_zeng_mean_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_high_rw.loc['20170101':,prop+' response'] = ref_props_ban_zeng_high_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    
ref_props_pir_baseline_gl.loc['20170101':,'Total refining production'] = ref_props_pir_baseline_gl.loc['20170101':,'Primary refining production'] + ref_props_pir_baseline_gl.loc['20170101':,'Secondary refining production']
ref_props_pir_baseline_cn.loc['20170101':,'Total refining production'] = ref_props_pir_baseline_cn.loc['20170101':,'Primary refining production'] + ref_props_pir_baseline_cn.loc['20170101':,'Secondary refining production']
ref_props_pir_baseline_rw.loc['20170101':,'Total refining production'] = ref_props_pir_baseline_rw.loc['20170101':,'Primary refining production'] + ref_props_pir_baseline_rw.loc['20170101':,'Secondary refining production']

ref_props_alloyed_50yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc200_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc200_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc200_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec200_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec200_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec200_gl.loc['20170101':,'Secondary refining production response']

ref_props_alloyed_50yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,'Secondary refining production response']

ref_props_alloyed_50yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,'Secondary refining production response']

ref_props_no2_50yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc100_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc100_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc100_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec100_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec100_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec100_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc200_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc200_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc200_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec200_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec200_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec200_gl.loc['20170101':,'Secondary refining production response']

ref_props_no2_50yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc100_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc100_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc100_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec100_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec100_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec100_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc200_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc200_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc200_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec200_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec200_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec200_cn.loc['20170101':,'Secondary refining production response']

ref_props_no2_50yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc100_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc100_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc100_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec100_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec100_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec100_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc200_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc200_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc200_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec200_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec200_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec200_rw.loc['20170101':,'Secondary refining production response']

ref_props_both_50yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc100_gl.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc100_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc100_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec100_gl.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec100_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec100_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc200_gl.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc200_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc200_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec200_gl.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec200_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec200_gl.loc['20170101':,'Secondary refining production response']

ref_props_both_50yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc100_cn.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc100_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc100_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec100_cn.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec100_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec100_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc200_cn.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc200_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc200_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec200_cn.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec200_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec200_cn.loc['20170101':,'Secondary refining production response']

ref_props_both_50yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc100_rw.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc100_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc100_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec100_rw.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec100_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec100_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc200_rw.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc200_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc200_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec200_rw.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec200_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec200_rw.loc['20170101':,'Secondary refining production response']

ref_props_alloyed_25yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_25yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_25yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_25yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_25yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_25yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_25yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_25yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_25yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_25yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_25yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_25yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_25yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_25yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_25yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_25yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_25yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_25yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_25yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_both_25yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_25yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_25yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_both_25yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_25yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_25yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_both_25yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_25yoy_rw.loc['20170101':,'Secondary refining production response']

ref_props_alloyed_75yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_75yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_75yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_75yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_75yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_75yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_75yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_75yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_75yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_75yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_75yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_75yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_75yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_75yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_75yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_75yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_75yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_75yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_75yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_both_75yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_75yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_75yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_both_75yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_75yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_75yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_both_75yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_75yoy_rw.loc['20170101':,'Secondary refining production response']

ref_props_ban_zeng_low_gl.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_low_gl.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_low_gl.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_mean_gl.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_mean_gl.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_mean_gl.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_high_gl.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_high_gl.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_high_gl.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_low_cn.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_low_cn.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_low_cn.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_mean_cn.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_mean_cn.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_mean_cn.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_high_cn.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_high_cn.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_high_cn.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_low_rw.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_low_rw.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_low_rw.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_mean_rw.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_mean_rw.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_mean_rw.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_high_rw.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_high_rw.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_high_rw.loc['20170101':,'Secondary refining production response']


print('Done')

# %% [markdown]
# Standard refinery imports responses (no fill between plots)

# %%
for prop in ['Primary refining production response','Secondary refining production response','Total refining production response','Refined demand response']:
    params = {
           'axes.labelsize': 12,
           'font.size': 12,
           'legend.fontsize': 12,
           'xtick.labelsize': 12,
           'ytick.labelsize': 12,
           'text.usetex': False,
           'figure.figsize': [24, 4],
           'lines.linewidth': 3
           }
    mpl.rcParams.update(params)
    mpl.rcParams['axes.spines.left'] = False
    mpl.rcParams['axes.spines.right'] = False
    mpl.rcParams['axes.spines.top'] = False
    mpl.rcParams['axes.spines.bottom'] = False
    # %config InlineBackend.figure_format ='retina'


    fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
    ax1.plot(ref_props_both_50yoy_gl.loc['20170101':,prop], label='No.2 Ban Baseline',color=colors[0])
    ax1.plot(ref_props_both_50yoy_inc100_gl.loc['20170101':,prop], label='Ref. Import +100',color=colors[1])
    ax1.plot(ref_props_both_50yoy_inc200_gl.loc['20170101':,prop], label='Ref. Import +200',color=colors[3])
    ax1.plot(ref_props_both_50yoy_dec100_gl.loc['20170101':,prop], label='Ref. Import -100',color=colors[2])
    ax1.plot(ref_props_both_50yoy_dec200_gl.loc['20170101':,prop], label='Ref. Import -200',color=colors[4])
    ax1.set_title(prop + ' Response above Baseline \nGlobal, No.2 Ban 50% YOY')
    ax1.set_ylabel(prop+'\nResponse above baseline (kt)')
    ax1.set_xlabel('Year')
    ax1.legend(loc='upper left')
    ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

    ax2.plot(ref_props_both_50yoy_cn.loc['20170101':,prop], label='No.2 Ban Baseline',color=colors[0])
    ax2.plot(ref_props_both_50yoy_inc100_cn.loc['20170101':,prop], label='Ref. Import +100',color=colors[1])
    ax2.plot(ref_props_both_50yoy_inc200_cn.loc['20170101':,prop], label='Ref. Import +200',color=colors[3])
    ax2.plot(ref_props_both_50yoy_dec100_cn.loc['20170101':,prop], label='Ref. Import -100',color=colors[2])
    ax2.plot(ref_props_both_50yoy_dec200_cn.loc['20170101':,prop], label='Ref. Import -200',color=colors[4])
    ax2.set_title(prop + ' Response above Baseline \nChina, No.2 Ban 50% YOY')
    ax2.set_ylabel(prop+'\nResponse above baseline (kt)')
    ax2.set_xlabel('Year')
    # ax2.legend()
    ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

    ax3.plot(ref_props_both_50yoy_rw.loc['20170101':,prop], label='No.2 Ban Baseline',color=colors[0])
    ax3.plot(ref_props_both_50yoy_inc100_rw.loc['20170101':,prop], label='Ref. Import +100',color=colors[1])
    ax3.plot(ref_props_both_50yoy_inc200_rw.loc['20170101':,prop], label='Ref. Import +200',color=colors[3])
    ax3.plot(ref_props_both_50yoy_dec100_rw.loc['20170101':,prop], label='Ref. Import -100',color=colors[2])
    ax3.plot(ref_props_both_50yoy_dec200_rw.loc['20170101':,prop], label='Ref. Import -200',color=colors[4])
    ax3.set_title(prop + ' Response above Baseline \nRoW, No.2 Ban 50% YOY')
    ax3.set_ylabel(prop+'\nResponse above baseline (kt)')
    ax3.set_xlabel('Year')
    # ax3.legend()
    ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Rate of ban

# %%
for prop in ['Primary refining production response','Secondary refining production response','Total refining production response','Refined demand response']:
    params = {
           'axes.labelsize': 12,
           'font.size': 12,
           'legend.fontsize': 12,
           'xtick.labelsize': 12,
           'ytick.labelsize': 12,
           'text.usetex': False,
           'figure.figsize': [24, 4],
           'lines.linewidth': 3
           }
    mpl.rcParams.update(params)
    mpl.rcParams['axes.spines.left'] = False
    mpl.rcParams['axes.spines.right'] = False
    mpl.rcParams['axes.spines.top'] = False
    mpl.rcParams['axes.spines.bottom'] = False
    # %config InlineBackend.figure_format ='retina'


    fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
    ax1.plot(ref_props_no2_50yoy_gl.cumsum().loc['20170101':,prop], label='50% YOY',color=colors[0])
    ax1.plot(ref_props_no2_25yoy_gl.cumsum().loc['20170101':,prop], label='25% YOY',color=colors[1])
    ax1.plot(ref_props_no2_75yoy_gl.cumsum().loc['20170101':,prop], label='75% YOY',color=colors[2])
    ax1.set_title(prop + ' Response above Baseline \nGlobal, No.2 Ban 50% YOY')
    ax1.set_ylabel(prop+'\nResponse above baseline (kt)')
    ax1.set_xlabel('Year')
    ax1.legend(loc='upper left')
    ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

    ax2.plot(ref_props_no2_50yoy_cn.cumsum().loc['20170101':,prop], label='50% YOY',color=colors[0])
    ax2.plot(ref_props_no2_25yoy_cn.cumsum().loc['20170101':,prop], label='25% YOY',color=colors[1])
    ax2.plot(ref_props_no2_75yoy_cn.cumsum().loc['20170101':,prop], label='75% YOY',color=colors[2])
    ax2.set_title(prop + ' Response above Baseline \nChina, No.2 Ban 50% YOY')
    ax2.set_ylabel(prop+'\nResponse above baseline (kt)')
    ax2.set_xlabel('Year')
    # ax2.legend()
    ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

    ax3.plot(ref_props_no2_50yoy_rw.cumsum().loc['20170101':,prop], label='50% YOY',color=colors[0])
    ax3.plot(ref_props_no2_25yoy_rw.cumsum().loc['20170101':,prop], label='25% YOY',color=colors[1])
    ax3.plot(ref_props_no2_75yoy_rw.cumsum().loc['20170101':,prop], label='75% YOY',color=colors[2])
    ax3.set_title(prop + ' Response above Baseline \nRoW, No.2 Ban 50% YOY')
    ax3.set_ylabel(prop+'\nResponse above baseline (kt)')
    ax3.set_xlabel('Year')
    # ax3.legend()
    ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Secondary ratios and stuff, scrap ban rates

# %%
for prop in ['Primary CU', 'Secondary CU', 'Secondary ratio']:
    params = {
           'axes.labelsize': 12,
           'font.size': 12,
           'legend.fontsize': 12,
           'xtick.labelsize': 12,
           'ytick.labelsize': 12,
           'text.usetex': False,
           'figure.figsize': [24, 4],
           'lines.linewidth': 3
           }
    mpl.rcParams.update(params)
    mpl.rcParams['axes.spines.left'] = False
    mpl.rcParams['axes.spines.right'] = False
    mpl.rcParams['axes.spines.top'] = False
    mpl.rcParams['axes.spines.bottom'] = False
    # %config InlineBackend.figure_format ='retina'
   
    fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
    ax1.plot(ref_props_pir_baseline_gl.loc['20180101':,prop], label='Baseline',color=colors[0])
    ax1.plot(ref_props_no2_50yoy_gl.loc['20180101':,prop], label='50% YOY',color=colors[1])
    ax1.plot(ref_props_no2_25yoy_gl.loc['20180101':,prop], label='25% YOY',color=colors[2])
    ax1.plot(ref_props_no2_75yoy_gl.loc['20180101':,prop], label='75% YOY',color=colors[3])
    ax1.set_title(prop + ' \nGlobal, No.2 Ban 50% YOY')
    ax1.set_ylabel(prop)
    ax1.set_xlabel('Year')
    ax1.legend(loc='upper left')
    ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

    ax2.plot(ref_props_pir_baseline_cn.loc['20180101':,prop], label='Baseline',color=colors[0])
    ax2.plot(ref_props_no2_50yoy_cn.loc['20180101':,prop], label='50% YOY',color=colors[1])
    ax2.plot(ref_props_no2_25yoy_cn.loc['20180101':,prop], label='25% YOY',color=colors[2])
    ax2.plot(ref_props_no2_75yoy_cn.loc['20180101':,prop], label='75% YOY',color=colors[3])
    ax2.set_title(prop + ' \nChina, No.2 Ban 50% YOY')
    ax2.set_ylabel(prop)
    ax2.set_xlabel('Year')
    # ax2.legend()
    ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

    ax3.plot(ref_props_pir_baseline_rw.loc['20180101':,prop], label='Baseline',color=colors[0])
    ax3.plot(ref_props_no2_50yoy_rw.loc['20180101':,prop], label='50% YOY',color=colors[1])
    ax3.plot(ref_props_no2_25yoy_rw.loc['20180101':,prop], label='25% YOY',color=colors[2])
    ax3.plot(ref_props_no2_75yoy_rw.loc['20180101':,prop], label='75% YOY',color=colors[3])
    ax3.set_title(prop + ' \nRoW, No.2 Ban 50% YOY')
    ax3.set_ylabel(prop)
    ax3.set_xlabel('Year')
    # ax3.legend()
    ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

### Switching to refined imports sensitivities

    fig2,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
    ax1.plot(ref_props_both_50yoy_inc100_gl.loc['20180101':,prop], label='Ref. Import +100',color=colors[1])
    ax1.plot(ref_props_both_50yoy_inc200_gl.loc['20180101':,prop], label='Ref. Import +200',color=colors[3])
    ax1.plot(ref_props_both_50yoy_gl.loc['20180101':,prop], label='Constant Refined Imports',color=colors[0])
    ax1.plot(ref_props_both_50yoy_dec100_gl.loc['20180101':,prop], label='Ref. Import -100',color=colors[2])
    ax1.plot(ref_props_both_50yoy_dec200_gl.loc['20180101':,prop], label='Ref. Import -200',color=colors[4])
    ax1.set_title(prop + ' \nGlobal, No.2 Ban 50% YOY')
    ax1.set_ylabel(prop)
    ax1.set_xlabel('Year')
    ax1.legend(loc='upper left')
    ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

    ax2.plot(ref_props_both_50yoy_inc100_cn.loc['20180101':,prop], label='Ref. Import +100',color=colors[1])
    ax2.plot(ref_props_both_50yoy_inc200_cn.loc['20180101':,prop], label='Ref. Import +200',color=colors[3])
    ax2.plot(ref_props_both_50yoy_cn.loc['20180101':,prop], label='Constant Refined Imports',color=colors[0])
    ax2.plot(ref_props_both_50yoy_dec100_cn.loc['20180101':,prop], label='Ref. Import -100',color=colors[2])
    ax2.plot(ref_props_both_50yoy_dec200_cn.loc['20180101':,prop], label='Ref. Import -200',color=colors[4])
    ax2.set_title(prop + ' \nChina, No.2 Ban 50% YOY')
    ax2.set_ylabel(prop)
    ax2.set_xlabel('Year')
    # ax2.legend()
    ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

    ax3.plot(ref_props_both_50yoy_inc100_rw.loc['20180101':,prop], label='Ref. Import +100',color=colors[1])
    ax3.plot(ref_props_both_50yoy_inc200_rw.loc['20180101':,prop], label='Ref. Import +200',color=colors[3])
    ax3.plot(ref_props_both_50yoy_rw.loc['20180101':,prop], label='Constant Refined Imports',color=colors[0])
    ax3.plot(ref_props_both_50yoy_dec100_rw.loc['20180101':,prop], label='Ref. Import -100',color=colors[2])
    ax3.plot(ref_props_both_50yoy_dec200_rw.loc['20180101':,prop], label='Ref. Import -200',color=colors[4])
    ax3.set_title(prop + ' \nRoW, No.2 Ban 50% YOY')
    ax3.set_ylabel(prop)
    ax3.set_xlabel('Year')
    # ax3.legend()
    ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Refined imports sensitivites (Mt)

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'

for prop in ['Total refining production response','Primary refining production response', 'Secondary refining production response','Refined demand response']:
    fig4,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
#     ax1.plot(0.001*ref_props_alloyed_50yoy_gl.loc['20170101':,prop], label='Alloyed Ban',color=colors[0])
#     ax1.plot(0.001*ref_props_no2_50yoy_gl.loc['20170101':,prop], label='No.2 Ban',color=colors[1])
    ax1.plot(0.001*ref_props_both_50yoy_gl.loc['20170101':,prop], label='Both Ban',color=colors[2])

#     ax1.fill_between(ref_props_alloyed_50yoy_gl.loc['20170101':,prop].index, 
#                      0.001*ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,prop], 
#                      0.001*ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,prop], 
#                      color = colors[0], alpha=0.2)
#     ax1.fill_between(ref_props_no2_50yoy_gl.loc['20170101':,prop].index, 
#                      0.001*ref_props_no2_50yoy_inc100_gl.loc['20170101':,prop], 
#                      0.001*ref_props_no2_50yoy_dec100_gl.loc['20170101':,prop], 
#                      color = colors[1], alpha=0.2)
    ax1.fill_between(ref_props_both_50yoy_gl.loc['20170101':,prop].index, 
                     0.001*ref_props_both_50yoy_inc100_gl.loc['20170101':,prop], 
                     0.001*ref_props_both_50yoy_dec100_gl.loc['20170101':,prop], 
                     color = colors[2], alpha=0.2)
    ax1.fill_between(ref_props_both_50yoy_gl.loc['20170101':,prop].index, 
                     0.001*ref_props_both_50yoy_inc200_gl.loc['20170101':,prop], 
                     0.001*ref_props_both_50yoy_dec200_gl.loc['20170101':,prop], 
                     color = colors[2], alpha=0.2)

    ax1.set_title(prop+'\nGlobal, 50% YOY')
    ax1.set_ylabel(prop+' (Mt)')
    ax1.set_xlabel('Year')
    # ax1.legend()
    ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax1.set_axisbelow(True)

#     ax2.plot(0.001*ref_props_alloyed_50yoy_cn.loc['20170101':,prop], label='Alloyed Ban',color=colors[0])
#     ax2.plot(0.001*ref_props_no2_50yoy_cn.loc['20170101':,prop], label='No.2 Ban',color=colors[1])
    ax2.plot(0.001*ref_props_both_50yoy_cn.loc['20170101':,prop], label='Both Ban',color=colors[2])

#     ax2.fill_between(ref_props_alloyed_50yoy_cn.loc['20170101':,prop].index, 
#                      0.001*ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,prop], 
#                      0.001*ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,prop], 
#                      color = colors[0], alpha=0.3)
#     ax2.fill_between(ref_props_no2_50yoy_cn.loc['20170101':,prop].index, 
#                      0.001*ref_props_no2_50yoy_inc100_cn.loc['20170101':,prop], 
#                      0.001*ref_props_no2_50yoy_dec100_cn.loc['20170101':,prop], 
#                      color = colors[1], alpha=0.3)
    ax2.fill_between(ref_props_both_50yoy_cn.loc['20170101':,prop].index, 
                     0.001*ref_props_both_50yoy_inc100_cn.loc['20170101':,prop], 
                     0.001*ref_props_both_50yoy_dec100_cn.loc['20170101':,prop], 
                     color = colors[2], alpha=0.3)
    # ax2.fill_between(ref_props_alloyed_50yoy_cn.loc['20170101':,prop].index, 
    #                  0.001*ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,prop], 
    #                  0.001*ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,prop], 
    #                  color = colors[0], alpha=0.3)
    # ax2.fill_between(ref_props_no2_50yoy_cn.loc['20170101':,prop].index, 
    #                  0.001*ref_props_no2_50yoy_inc200_cn.loc['20170101':,prop], 
    #                  0.001*ref_props_no2_50yoy_dec200_cn.loc['20170101':,prop], 
    #                  color = colors[1], alpha=0.3)
    ax2.fill_between(ref_props_both_50yoy_cn.loc['20170101':,prop].index, 
                     0.001*ref_props_both_50yoy_inc200_cn.loc['20170101':,prop], 
                     0.001*ref_props_both_50yoy_dec200_cn.loc['20170101':,prop], 
                     color = colors[2], alpha=0.3)


    ax2.set_title(prop+'\nChina, 50% YOY')
    ax2.set_ylabel(prop+' (Mt)')
    ax2.set_xlabel('Year')
    # ax2.legend()
    ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax2.set_axisbelow(True)

#     ax3.plot(0.001*ref_props_alloyed_50yoy_rw.loc['20170101':,prop], label='Alloyed Ban',color=colors[0])
#     ax3.plot(0.001*ref_props_no2_50yoy_rw.loc['20170101':,prop], label='No.2 Ban',color=colors[1])
    ax3.plot(0.001*ref_props_both_50yoy_rw.loc['20170101':,prop], label='Both Ban',color=colors[2])

#     ax3.fill_between(ref_props_alloyed_50yoy_rw.loc['20170101':,prop].index, 
#                      0.001*ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,prop], 
#                      0.001*ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,prop], 
#                      color = colors[0], alpha=0.3)
#     ax3.fill_between(ref_props_no2_50yoy_rw.loc['20170101':,prop].index, 
#                      0.001*ref_props_no2_50yoy_inc100_rw.loc['20170101':,prop], 
#                      0.001*ref_props_no2_50yoy_dec100_rw.loc['20170101':,prop], 
#                      color = colors[1], alpha=0.3)
    ax3.fill_between(ref_props_both_50yoy_rw.loc['20170101':,prop].index, 
                     0.001*ref_props_both_50yoy_inc100_rw.loc['20170101':,prop], 
                     0.001*ref_props_both_50yoy_dec100_rw.loc['20170101':,prop], 
                     color = colors[2], alpha=0.3)
    # ax3.fill_between(ref_props_alloyed_50yoy_rw.loc['20170101':,prop].index, 
    #                  0.001*ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,prop], 
    #                  0.001*ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,prop], 
    #                  color = colors[0], alpha=0.3)
    # ax3.fill_between(ref_props_no2_50yoy_rw.loc['20170101':,prop].index, 
    #                  0.001*ref_props_no2_50yoy_inc200_rw.loc['20170101':,prop], 
    #                  0.001*ref_props_no2_50yoy_dec200_rw.loc['20170101':,prop], 
    #                  color = colors[1], alpha=0.3)
    ax3.fill_between(ref_props_both_50yoy_rw.loc['20170101':,prop].index, 
                     0.001*ref_props_both_50yoy_inc200_rw.loc['20170101':,prop], 
                     0.001*ref_props_both_50yoy_dec200_rw.loc['20170101':,prop], 
                     color = colors[2], alpha=0.3)

    ax3.set_title(prop+'\nRoW, 50% YOY')
    ax3.set_ylabel(prop+' (Mt)')
    ax3.set_xlabel('Year')
#     ax3.legend()
    ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax3.set_axisbelow(True)

# %% [markdown]
# Refined import sensitivities, pct increase of 2020 value, better definition of max and min values, including secondary max and min

# %%
for prop in ['Total refining production response','Primary refining production response', 'Secondary refining production response','Refined demand response']:
    params = {
           'axes.labelsize': 16,
           'font.size': 16,
           'legend.fontsize': 16,
           'xtick.labelsize': 16,
           'ytick.labelsize': 16,
           'text.usetex': False,
           'figure.figsize': [18, 5],
           'lines.linewidth': 3
           }
    mpl.rcParams.update(params)
    mpl.rcParams['axes.spines.left'] = False
    mpl.rcParams['axes.spines.right'] = False
    mpl.rcParams['axes.spines.top'] = False
    mpl.rcParams['axes.spines.bottom'] = False
    # %config InlineBackend.figure_format ='retina'

    mpl.rcParams.update({'figure.figsize': [8,5]})
    fig, ax1 = plt.subplots()
    ax1.plot(100*ref_props_both_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], label='Both Ban',color=colors[2])

    # Finding lowest and highest, then second lowest and second highest values among the 5 series
    ax1.fill_between(ref_props_both_50yoy_inc100_gl.loc['20180101':, prop].index, 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production']], axis=1).values)[:,0], 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production']], axis=1).values)[:,-1], 
                     color = colors[2], alpha=0.3)
    ax1.fill_between(ref_props_both_50yoy_inc100_gl.loc['20180101':, prop].index, 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production']], axis=1).values)[:,1], 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production']], axis=1).values)[:,-2], 
                     color = colors[2], alpha=0.3)
#     ax1.plot(100*ref_props_both_50yoy_inc200_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], color='limegreen')
#     ax1.plot(100*ref_props_both_50yoy_dec200_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101','Total refining production'], color='red')
 
    ax1.set_title('Global '+prop.title())
    ax1.set_ylabel(prop+' \n(Cumulative, % of 2020 total production)')
    if len(ax1.get_yticks()) < 6:
        pass
    elif 0 in ax1.get_yticks()[::2]:
        ax1.set_yticks(ax1.get_yticks()[::2])
    else:
        ax1.set_yticks(ax1.get_yticks()[1::2])
    low, high = ax1.get_ylim()
    if low == ax1.get_yticks()[0] and low<0:
        ax1.set_ylim(low*1.1, high)
    elif low == ax1.get_yticks()[0] and low > 0:
        ax1.set_ylim(low*0.9, high)
    ax1.set_ylim(ax1.get_ylim()[0], ax1.get_ylim()[1]*1.1)
#     ax1.set_xlabel('Year')
    # ax1.legend()
    ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax1.set_axisbelow(True)
    
    
    mpl.rcParams.update({'figure.figsize': [20,6]})
    fig4,(ax2,ax3) = plt.subplots(1,2, frameon=False)
    ax2.plot(100*ref_props_both_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], label='Both Ban',color=colors[2])

    ax2.fill_between(ref_props_both_50yoy_inc100_cn.loc['20180101':, prop].index, 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production']], axis=1).values)[:,0], 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production']], axis=1).values)[:,-1], 
                     color = colors[2], alpha=0.3)
    ax2.fill_between(ref_props_both_50yoy_inc100_cn.loc['20180101':, prop].index, 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production']], axis=1).values)[:,1], 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production']], axis=1).values)[:,-2], 
                     color = colors[2], alpha=0.3)
    ax2.plot(100*ref_props_both_50yoy_inc200_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], color='limegreen')
    ax2.plot(100*ref_props_both_50yoy_dec200_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101','Total refining production'], color='red')
    

    ax2.set_title('China '+prop.title())
    ax2.set_ylabel(prop+' \n(Cumulative, % of 2020 value)')
    # ax2.legend()
    ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax2.set_axisbelow(True)

    ax3.plot(100*ref_props_both_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], label='Both Ban',color=colors[2])

    ax3.fill_between(ref_props_both_50yoy_inc100_rw.loc['20180101':, prop].index, 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production']], axis=1).values)[:,0], 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production']], axis=1).values)[:,-1], 
                     color = colors[2], alpha=0.3)
    ax3.fill_between(ref_props_both_50yoy_inc100_rw.loc['20180101':, prop].index, 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production']], axis=1).values)[:,1], 
                     np.sort(pd.concat([100*ref_props_both_50yoy_inc100_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec100_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_inc200_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_dec200_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], 100*ref_props_both_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production']], axis=1).values)[:,-2], 
                     color = colors[2], alpha=0.3)
    ax3.plot(100*ref_props_both_50yoy_inc200_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], color='limegreen')
    ax3.plot(100*ref_props_both_50yoy_dec200_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101','Total refining production'], color='red')
    
    ax3.set_title('Rest of World '+prop.title())
    ax3.set_ylabel(prop+' \n(Cumulative, % of 2020 value)')
#     ax3.set_xlabel('Year')
#     ax3.legend()
    ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax3.set_axisbelow(True)

# %% [markdown]
# Import ban rate sensitivities

# %%
params = {
       'axes.labelsize': 14,
       'font.size': 14,
       'legend.fontsize': 14,
       'xtick.labelsize': 14,
       'ytick.labelsize': 14,
       'text.usetex': False,
       'figure.figsize': [24, 6],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'

for prop in ['Total refining production response','Primary refining production response', 'Secondary refining production response','Refined demand response']:
    fig5,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
    ax1.plot(ref_props_alloyed_50yoy_gl.loc['20170101':,prop], label='Alloyed Ban',color=colors[0])
    ax1.plot(ref_props_no2_50yoy_gl.loc['20170101':,prop], label='No.2 Ban',color=colors[1])
    ax1.plot(ref_props_both_50yoy_gl.loc['20170101':,prop], label='Both Ban',color=colors[2])

    ax1.fill_between(ref_props_alloyed_50yoy_gl.loc['20170101':,prop].index, 
                     ref_props_alloyed_25yoy_gl.loc['20170101':,prop], 
                     ref_props_alloyed_75yoy_gl.loc['20170101':,prop], 
                     color = colors[0], alpha=0.2)
    ax1.fill_between(ref_props_no2_50yoy_gl.loc['20170101':,prop].index, 
                     ref_props_no2_25yoy_gl.loc['20170101':,prop], 
                     ref_props_no2_75yoy_gl.loc['20170101':,prop], 
                     color = colors[1], alpha=0.2)
    ax1.fill_between(ref_props_both_50yoy_gl.loc['20170101':,prop].index, 
                     ref_props_both_25yoy_gl.loc['20170101':,prop], 
                     ref_props_both_75yoy_gl.loc['20170101':,prop], 
                     color = colors[2], alpha=0.2)

    ax1.set_title(prop + ' \nGlobal, Import Ban Rate Sensitivity')
    ax1.set_ylabel(prop+' (kt)')
    ax1.set_xlabel('Year')
    # ax1.legend()
    ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax1.set_axisbelow(True)

    ax2.plot(ref_props_alloyed_50yoy_cn.loc['20170101':,prop], label='Alloyed Ban',color=colors[0])
    ax2.plot(ref_props_no2_50yoy_cn.loc['20170101':,prop], label='No.2 Ban',color=colors[1])
    ax2.plot(ref_props_both_50yoy_cn.loc['20170101':,prop], label='Both Ban',color=colors[2])

    ax2.fill_between(ref_props_alloyed_50yoy_cn.loc['20170101':,prop].index, 
                     ref_props_alloyed_25yoy_cn.loc['20170101':,prop], 
                     ref_props_alloyed_75yoy_cn.loc['20170101':,prop], 
                     color = colors[0], alpha=0.3)
    ax2.fill_between(ref_props_no2_50yoy_cn.loc['20170101':,prop].index, 
                     ref_props_no2_25yoy_cn.loc['20170101':,prop], 
                     ref_props_no2_75yoy_cn.loc['20170101':,prop], 
                     color = colors[1], alpha=0.3)
    ax2.fill_between(ref_props_both_50yoy_cn.loc['20170101':,prop].index, 
                     ref_props_both_25yoy_cn.loc['20170101':,prop], 
                     ref_props_both_75yoy_cn.loc['20170101':,prop], 
                     color = colors[2], alpha=0.3)

    ax2.set_title(prop + ' \nChina, Import Ban Rate Sensitivity')
    ax2.set_ylabel(prop+' (kt)')
    ax2.set_xlabel('Year')
    # ax2.legend()
    ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax2.set_axisbelow(True)

    ax3.plot(ref_props_alloyed_50yoy_rw.loc['20170101':,prop], label='Alloyed Ban',color=colors[0])
    ax3.plot(ref_props_no2_50yoy_rw.loc['20170101':,prop], label='No.2 Ban',color=colors[1])
    ax3.plot(ref_props_both_50yoy_rw.loc['20170101':,prop], label='Both Ban',color=colors[2])

    ax3.fill_between(ref_props_alloyed_50yoy_rw.loc['20170101':,prop].index, 
                     ref_props_alloyed_25yoy_rw.loc['20170101':,prop], 
                     ref_props_alloyed_75yoy_rw.loc['20170101':,prop], 
                     color = colors[0], alpha=0.3)
    ax3.fill_between(ref_props_no2_50yoy_rw.loc['20170101':,prop].index, 
                     ref_props_no2_25yoy_rw.loc['20170101':,prop], 
                     ref_props_no2_75yoy_rw.loc['20170101':,prop], 
                     color = colors[1], alpha=0.3)
    ax3.fill_between(ref_props_both_50yoy_rw.loc['20170101':,prop].index, 
                     ref_props_both_25yoy_rw.loc['20170101':,prop], 
                     ref_props_both_75yoy_rw.loc['20170101':,prop], 
                     color = colors[2], alpha=0.3)

    ax3.set_title(prop + ' \nRest of World, Import Ban Rate Sensitivity')
    ax3.set_ylabel(prop+' (kt)')
    ax3.set_xlabel('Year')
#     ax3.legend()
    ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax3.set_axisbelow(True)

# %%
ref_props_pir_baseline_gl.loc[:,'Total refining production'] = ref_props_pir_baseline_gl.loc[:,'Primary refining production'] + ref_props_pir_baseline_gl.loc[:,'Secondary refining production']
ref_props_pir_baseline_cn.loc[:,'Total refining production'] = ref_props_pir_baseline_cn.loc[:,'Primary refining production'] + ref_props_pir_baseline_cn.loc[:,'Secondary refining production']
ref_props_pir_baseline_rw.loc[:,'Total refining production'] = ref_props_pir_baseline_rw.loc[:,'Primary refining production'] + ref_props_pir_baseline_rw.loc[:,'Secondary refining production']
# ref_props_pir_baseline_cn.rename(columns = {'CN Refined demand':'Refined demand'}, inplace=True)
# ref_props_pir_baseline_rw.rename(columns = {'RoW Refined demand':'Refined demand'}, inplace=True)

for prop in ['Total refining production response','Primary refining production response', 'Secondary refining production response','Refined demand response']:
    params = {
           'axes.labelsize': 12,
           'font.size': 12,
           'legend.fontsize': 12,
           'xtick.labelsize': 12,
           'ytick.labelsize': 12,
           'text.usetex': False,
           'figure.figsize': [15, 5],
           'lines.linewidth': 3
           }
    mpl.rcParams.update(params)
    mpl.rcParams['axes.spines.left'] = False
    mpl.rcParams['axes.spines.right'] = False
    mpl.rcParams['axes.spines.top'] = False
    mpl.rcParams['axes.spines.bottom'] = False
    # %config InlineBackend.figure_format ='retina'

    if 'demand' in prop:
        prop2 = 'Refined consumption response'
    else:
        prop2 = prop
    fig5,(ax2,ax3) = plt.subplots(1,2, frameon=False)
    ax2.plot(100*ref_props_alloyed_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], label='Alloyed Ban',color=colors[0])
    ax2.plot(100*ref_props_no2_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], label='No.2 Ban',color=colors[1])
    ax2.plot(100*ref_props_both_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], label='Both Ban',color=colors[2])

    ax2.fill_between(ref_props_alloyed_50yoy_cn.loc['20180101':, prop].index, 
                     pd.concat([100*ref_props_alloyed_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_25yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_75yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: min(x), axis=1), 
                     pd.concat([100*ref_props_alloyed_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_25yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_75yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: max(x), axis=1),
                     color = colors[0], alpha=0.3)
    ax2.fill_between(ref_props_no2_50yoy_cn.loc['20180101':, prop].index, 
                     pd.concat([100*ref_props_no2_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_25yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_75yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: min(x), axis=1), 
                     pd.concat([100*ref_props_no2_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_25yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_75yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: max(x), axis=1),
                     color = colors[1], alpha=0.3)
    ax2.fill_between(ref_props_both_50yoy_cn.loc['20180101':, prop].index, 
                     pd.concat([100*ref_props_both_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_25yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_75yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: min(x), axis=1), 
                     pd.concat([100*ref_props_both_50yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_25yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_75yoy_cn.loc['20180101':, prop] / ref_props_pir_baseline_cn.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: max(x), axis=1),
                     color = colors[2], alpha=0.3)

    ax2.set_title('China '+prop2.title())
    ax2.set_ylabel(prop2+'\n(Cumulative, % of 2020 value)')

    # ax2.legend()
    if len(ax2.get_yticks()) < 6:
        pass
    elif 0 in ax2.get_yticks()[::2]:
        ax2.set_yticks(ax2.get_yticks()[::2])
    else:
        ax2.set_yticks(ax2.get_yticks()[1::2])
    low, high = ax2.get_ylim()
    if low == ax2.get_yticks()[0] and low<0:
        ax2.set_ylim(low*1.1, high)
    elif low == ax2.get_yticks()[0] and low > 0:
        ax2.set_ylim(low*0.9, high)
    ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax2.set_axisbelow(True)

    ax3.plot(100*ref_props_alloyed_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], label='Alloyed Ban',color=colors[0])
    ax3.plot(100*ref_props_no2_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], label='No.2 Ban',color=colors[1])
    ax3.plot(100*ref_props_both_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], label='Both Ban',color=colors[2])

    ax3.fill_between(ref_props_alloyed_50yoy_rw.loc['20180101':, prop].index, 
                     pd.concat([100*ref_props_alloyed_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_25yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_75yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: min(x), axis=1), 
                     pd.concat([100*ref_props_alloyed_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_25yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_75yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: max(x), axis=1),
                     color = colors[0], alpha=0.3)
    ax3.fill_between(ref_props_no2_50yoy_rw.loc['20180101':, prop].index, 
                     pd.concat([100*ref_props_no2_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_25yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_75yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: min(x), axis=1), 
                     pd.concat([100*ref_props_no2_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_25yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_75yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: max(x), axis=1),
                     color = colors[1], alpha=0.3)
    ax3.fill_between(ref_props_both_50yoy_rw.loc['20180101':, prop].index, 
                     pd.concat([100*ref_props_both_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_25yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_75yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: min(x), axis=1), 
                     pd.concat([100*ref_props_both_50yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_25yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_75yoy_rw.loc['20180101':, prop] / ref_props_pir_baseline_rw.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: max(x), axis=1),
                     color = colors[2], alpha=0.3)

    ax3.set_title('Rest of World '+prop2.title())
    ax3.set_ylabel(prop2+'\n(Cumulative, % of 2020 value)')

    # ax3.legend()
    if len(ax3.get_yticks()) < 6:
        pass
    elif 0 in ax3.get_yticks()[::2]:
        ax3.set_yticks(ax3.get_yticks()[::2])
    else:
        ax3.set_yticks(ax3.get_yticks()[1::2])
    low, high = ax3.get_ylim()
    if low == ax3.get_yticks()[0] and low<0:
        ax3.set_ylim(low*1.1, high)
    elif low == ax3.get_yticks()[0] and low > 0:
        ax3.set_ylim(low*0.9, high)
    ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax3.set_axisbelow(True)


    mpl.rcParams.update({'figure.figsize': [8, 4]})
    fig, ax1 = plt.subplots()
    ax1.plot(100*ref_props_alloyed_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], label='Alloyed Ban',color=colors[0])
    ax1.plot(100*ref_props_no2_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], label='No.2 Ban',color=colors[1])
    ax1.plot(100*ref_props_both_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], label='Both Ban',color=colors[2])

    ax1.fill_between(ref_props_alloyed_50yoy_gl.loc['20180101':, prop].index, 
                     pd.concat([100*ref_props_alloyed_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_25yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_75yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: min(x), axis=1), 
                     pd.concat([100*ref_props_alloyed_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_25yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_alloyed_75yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: max(x), axis=1),
                     color = colors[0], alpha=0.3)
    ax1.fill_between(ref_props_no2_50yoy_gl.loc['20180101':, prop].index, 
                     pd.concat([100*ref_props_no2_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_25yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_75yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: min(x), axis=1), 
                     pd.concat([100*ref_props_no2_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_25yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_no2_75yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: max(x), axis=1),
                     color = colors[1], alpha=0.3)
    ax1.fill_between(ref_props_both_50yoy_gl.loc['20180101':, prop].index, 
                     pd.concat([100*ref_props_both_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_25yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_75yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: min(x), axis=1), 
                     pd.concat([100*ref_props_both_50yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_25yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])], 100*ref_props_both_75yoy_gl.loc['20180101':, prop] / ref_props_pir_baseline_gl.loc['20200101',' '.join(prop.split()[:-1])]], axis=1).apply(lambda x: max(x), axis=1),
                     color = colors[2], alpha=0.3)

    ax1.set_title('Global '+prop2.title())
    ax1.set_ylabel(prop2+'\n(Cumulative, % of 2020 value)')
    if len(ax1.get_yticks()) < 6:
        pass
    elif 0 in ax1.get_yticks()[::2]:
        ax1.set_yticks(ax1.get_yticks()[::2])
    else:
        ax1.set_yticks(ax1.get_yticks()[1::2])
        
    low, high = ax1.get_ylim()
    if low == ax1.get_yticks()[0] and low<0:
        ax1.set_ylim(low*1.1, high)
    elif low == ax1.get_yticks()[0] and low > 0:
        ax1.set_ylim(low*0.9, high)
    # ax1.legend()
    ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
    ax1.set_axisbelow(True)

# %%
ax1.get_yticks()
ax1.get_ylim()[0] == ax1.get_yticks()[0]

# %% [markdown]
# Zeng response

# %%
for prop in ['Primary refining production response','Secondary refining production response','Total refining production response','Refined demand response']:
    plt.figure()
    pplot(0.001*ref_props_ban_zeng_mean_gl.loc['20180101':,prop], label='Global Zeng Mean', color = colors[0],firstcall=1)
    pplot(0.001*ref_props_ban_zeng_mean_cn.loc['20180101':,prop], label='China Zeng Mean', color = colors[1])
    pplot(0.001*ref_props_ban_zeng_mean_rw.loc['20180101':,prop], label='RoW Zeng Mean', color = colors[2])

    plt.fill_between(ref_props_ban_zeng_mean_gl.loc['20180101':,prop].index,
                    0.001*ref_props_ban_zeng_low_gl.loc['20180101':,prop],
                    0.001*ref_props_ban_zeng_high_gl.loc['20180101':,prop], color = colors[0], alpha=0.3)
    plt.fill_between(ref_props_ban_zeng_mean_gl.loc['20180101':,prop].index,
                    0.001*ref_props_ban_zeng_low_cn.loc['20180101':,prop],
                    0.001*ref_props_ban_zeng_high_cn.loc['20180101':,prop], color = colors[1], alpha=0.3)
    plt.fill_between(ref_props_ban_zeng_mean_gl.loc['20180101':,prop].index,
                    0.001*ref_props_ban_zeng_low_rw.loc['20180101':,prop],
                    0.001*ref_props_ban_zeng_high_rw.loc['20180101':,prop], color = colors[2], alpha=0.3)
    plt.title(prop.title()+'\nSensitivity to Zeng Paper Projections')
    plt.ylabel(prop+' (Mt)')
    plt.legend().set_visible(False)

# %% [markdown]
# Zeng other refinery parameters

# %%
for prop in ['Primary CU', 'Secondary CU', 'Secondary ratio']:
    plt.figure()
    pplot(ref_props_pir_baseline_gl.loc['20180101':,prop], label='Baseline', color = colors[0], firstcall=1)
    pplot(ref_props_ban_zeng_mean_gl.loc['20180101':,prop], label='Global Zeng Mean', color = colors[1])
    pplot(ref_props_ban_zeng_mean_cn.loc['20180101':,prop], label='China Zeng Mean', color = colors[2])
    pplot(ref_props_ban_zeng_mean_rw.loc['20180101':,prop], label='RoW Zeng Mean', color = colors[3])

    plt.fill_between(ref_props_ban_zeng_mean_gl.loc['20180101':,prop].index,
                    ref_props_ban_zeng_low_gl.loc['20180101':,prop],
                    ref_props_ban_zeng_high_gl.loc['20180101':,prop], color = colors[1], alpha=0.3)
    plt.fill_between(ref_props_ban_zeng_mean_gl.loc['20180101':,prop].index,
                    ref_props_ban_zeng_low_cn.loc['20180101':,prop],
                    ref_props_ban_zeng_high_cn.loc['20180101':,prop], color = colors[2], alpha=0.3)
    plt.fill_between(ref_props_ban_zeng_mean_gl.loc['20180101':,prop].index,
                    ref_props_ban_zeng_low_rw.loc['20180101':,prop],
                    ref_props_ban_zeng_high_rw.loc['20180101':,prop], color = colors[3], alpha=0.3)
    plt.title(prop+'\nSensitivity to Zeng Paper Projections')
    plt.ylabel(prop+' (Mt)')
#     plt.legend().set_visible(False)

# %%
# historical_ref_imports_cn.loc[i] = historical_ref_imports_cn.loc[2018] + (i-2018)*200
# 1276.206684
ref_imports=pd.read_excel('Production data compile.xlsx', sheet_name='China', index_col=0, usecols='A:O,W:X,AE').loc[1983:2018, 'Net Refined Imports']
ref_imports_i100 = ref_imports.copy()
ref_imports_i200 = ref_imports.copy()
ref_imports_d100 = ref_imports.copy()
ref_imports_d200 = ref_imports.copy()
for i in np.arange(2019,2041):
    ref_imports.loc[i] = ref_imports.loc[2018]
    ref_imports_i100.loc[i] = ref_imports.loc[2018] + (i-2018)*100
    ref_imports_i200.loc[i] = ref_imports.loc[2018] + (i-2018)*200
    ref_imports_d100.loc[i] = ref_imports.loc[2018] - (i-2018)*100
    ref_imports_d200.loc[i] = ref_imports.loc[2018] - (i-2018)*200
    
ref_imports_d100[ref_imports_d100<0] = 0
ref_imports_d200[ref_imports_d200<0] = 0

pplot(ref_imports_i200, '+200', colors[0], firstcall=1)
pplot(ref_imports_i100, '+100', colors[1])
pplot(ref_imports, 'Baseline', colors[2])
pplot(ref_imports_d100, '-100', colors[3])
pplot(ref_imports_d200, '-200', colors[4])
plt.legend().set_visible(False)
plt.title('China Refined Copper Imports')
plt.ylabel('China net refined copper imports (kt)')

# %% [markdown]
# ## Price analysis

# %% [markdown]
# Baselines

# %%
price_baseline_baseline=pd.read_excel('price baseline_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_baseline=price_baseline_baseline.loc[:, 'Cathode']
sp2_series_baseline_baseline=price_baseline_baseline.loc[:, 'No.2 spread']
tcrc_series_baseline_baseline=price_baseline_baseline.loc[:, 'TCRC']

# %% [markdown]
# SESD

# %% [markdown]
# CUE

# %% [markdown]
# PSE

# %% [markdown]
# SRE

# %% [markdown]
# Scenarios

# %%
price_baseline_sm=pd.read_excel('price baseline_sm.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_sm=price_baseline_sm.loc[:, 'Cathode']
sp2_series_baseline_sm=price_baseline_sm.loc[:, 'No.2 spread']
tcrc_series_baseline_sm=price_baseline_sm.loc[:, 'TCRC']

# %%
price_baseline_lsm=pd.read_excel('price baseline_lsm.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_lsm=price_baseline_lsm.loc[:, 'Cathode']
sp2_series_baseline_lsm=price_baseline_lsm.loc[:, 'No.2 spread']
tcrc_series_baseline_lsm=price_baseline_lsm.loc[:, 'TCRC']

# %%
price_baseline_psm=pd.read_excel('price baseline_psm.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_psm=price_baseline_psm.loc[:, 'Cathode']
sp2_series_baseline_psm=price_baseline_psm.loc[:, 'No.2 spread']
tcrc_series_baseline_psm=price_baseline_psm.loc[:, 'TCRC']

# %%
price_baseline_rs10=pd.read_excel('price baseline_rs10.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_rs10=price_baseline_rs10.loc[:, 'Cathode']
sp2_series_baseline_rs10=price_baseline_rs10.loc[:, 'No.2 spread']
tcrc_series_baseline_rs10=price_baseline_rs10.loc[:, 'TCRC']

# %%
price_baseline_rs20=pd.read_excel('price baseline_rs20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_rs20=price_baseline_rs20.loc[:, 'Cathode']
sp2_series_baseline_rs20=price_baseline_rs20.loc[:, 'No.2 spread']
tcrc_series_baseline_rs20=price_baseline_rs20.loc[:, 'TCRC']

# %%
price_baseline_rs50=pd.read_excel('price baseline_rs50.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_rs50=price_baseline_rs50.loc[:, 'Cathode']
sp2_series_baseline_rs50=price_baseline_rs50.loc[:, 'No.2 spread']
tcrc_series_baseline_rs50=price_baseline_rs50.loc[:, 'TCRC']

# %%
price_baseline_rs100=pd.read_excel('price baseline_rs100.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_rs100=price_baseline_rs100.loc[:, 'Cathode']
sp2_series_baseline_rs100=price_baseline_rs100.loc[:, 'No.2 spread']
tcrc_series_baseline_rs100=price_baseline_rs100.loc[:, 'TCRC']

# %%
price_baseline_prs10=pd.read_excel('price baseline_prs10.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_prs10=price_baseline_prs10.loc[:, 'Cathode']
sp2_series_baseline_prs10=price_baseline_prs10.loc[:, 'No.2 spread']
tcrc_series_baseline_prs10=price_baseline_prs10.loc[:, 'TCRC']

# %%
price_baseline_prs20=pd.read_excel('price baseline_prs20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_prs20=price_baseline_prs20.loc[:, 'Cathode']
sp2_series_baseline_prs20=price_baseline_prs20.loc[:, 'No.2 spread']
tcrc_series_baseline_prs20=price_baseline_prs20.loc[:, 'TCRC']

# %%
price_baseline_prs50=pd.read_excel('price baseline_prs50.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_prs50=price_baseline_prs50.loc[:, 'Cathode']
sp2_series_baseline_prs50=price_baseline_prs50.loc[:, 'No.2 spread']
tcrc_series_baseline_prs50=price_baseline_prs50.loc[:, 'TCRC']

# %%
price_baseline_prs100=pd.read_excel('price baseline_prs100.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_prs100=price_baseline_prs100.loc[:, 'Cathode']
sp2_series_baseline_prs100=price_baseline_prs100.loc[:, 'No.2 spread']
tcrc_series_baseline_prs100=price_baseline_prs100.loc[:, 'TCRC']

# %%
price_baseline_irs100=pd.read_excel('price baseline_irs100.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_baseline_irs100=price_baseline_irs100.loc[:, 'Cathode']
sp2_series_baseline_irs100=price_baseline_irs100.loc[:, 'No.2 spread']
tcrc_series_baseline_irs100=price_baseline_irs100.loc[:, 'TCRC']

# %%
price_200_de_baseline=pd.read_excel('price 200_de_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_200_de_baseline=price_200_de_baseline.loc[:, 'Cathode']
sp2_series_200_de_baseline=price_200_de_baseline.loc[:, 'No.2 spread']
tcrc_series_200_de_baseline=price_200_de_baseline.loc[:, 'TCRC']

# %%
price_400_de_baseline=pd.read_excel('price 400_de_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_400_de_baseline=price_400_de_baseline.loc[:, 'Cathode']
sp2_series_400_de_baseline=price_400_de_baseline.loc[:, 'No.2 spread']
tcrc_series_400_de_baseline=price_400_de_baseline.loc[:, 'TCRC']

# %% [markdown]
# Price Data Import - Initial Linear Approaches

# %%
# price_lin1yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock1yr20.xlsx', sheet_name='Sheet1', index_col=0)
# cathode_price_series_lin1yr20=price_lin1yr20.loc[:, 'Cathode']
# sp2_series_lin1yr20=price_lin1yr20.loc[:, 'No.2 spread']
# tcrc_series_lin1yr20=price_lin1yr20.loc[:, 'TCRC']

# price_lin5yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock5yr20.xlsx', sheet_name='Sheet1', index_col=0)
# cathode_price_series_lin5yr20=price_lin5yr20.loc[:, 'Cathode']
# sp2_series_lin5yr20=price_lin5yr20.loc[:, 'No.2 spread']
# tcrc_series_lin5yr20=price_lin5yr20.loc[:, 'TCRC']

# price_lin10yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock10yr20.xlsx', sheet_name='Sheet1', index_col=0)
# cathode_price_series_lin10yr20=price_lin10yr20.loc[:, 'Cathode']
# sp2_series_lin10yr20=price_lin10yr20.loc[:, 'No.2 spread']
# tcrc_series_lin10yr20=price_lin10yr20.loc[:, 'TCRC']

# price_lin20yr20=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock20yr20.xlsx', sheet_name='Sheet1', index_col=0)
# cathode_price_series_lin20yr20=price_lin20yr20.loc[:, 'Cathode']
# sp2_series_lin20yr20=price_lin20yr20.loc[:, 'No.2 spread']
# tcrc_series_lin20yr20=price_lin20yr20.loc[:, 'TCRC']

# %%
# Checking what happens when the constraint on scrap spread is released
price_lin1yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock1yr10-sp2.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin1yr10=price_lin1yr10.loc[:, 'Cathode']
sp2_series_lin1yr10=price_lin1yr10.loc[:, 'No.2 spread']
tcrc_series_lin1yr10=price_lin1yr10.loc[:, 'TCRC']

price_lin5yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock5yr10-sp2.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin5yr10=price_lin5yr10.loc[:, 'Cathode']
sp2_series_lin5yr10=price_lin5yr10.loc[:, 'No.2 spread']
tcrc_series_lin5yr10=price_lin5yr10.loc[:, 'TCRC']

price_lin10yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock10yr10-sp2.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin10yr10=price_lin10yr10.loc[:, 'Cathode']
sp2_series_lin10yr10=price_lin10yr10.loc[:, 'No.2 spread']
tcrc_series_lin10yr10=price_lin10yr10.loc[:, 'TCRC']

price_lin20yr10=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock20yr10-sp2.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin20yr10=price_lin20yr10.loc[:, 'Cathode']
sp2_series_lin20yr10=price_lin20yr10.loc[:, 'No.2 spread']
tcrc_series_lin20yr10=price_lin20yr10.loc[:, 'TCRC']

# %%
# Since there were extra issues (both spread and TCRC constraints violated) for 100%
price_lin1yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock1yr-sp2-1.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin1yr=price_lin1yr.loc[:, 'Cathode']
sp2_series_lin1yr=price_lin1yr.loc[:, 'No.2 spread']
tcrc_series_lin1yr=price_lin1yr.loc[:, 'TCRC']

price_lin5yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock5yr-sp2-1.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin5yr=price_lin5yr.loc[:, 'Cathode']
sp2_series_lin5yr=price_lin5yr.loc[:, 'No.2 spread']
tcrc_series_lin5yr=price_lin5yr.loc[:, 'TCRC']

price_lin10yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock10yr-sp2-1.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin10yr=price_lin10yr.loc[:, 'Cathode']
sp2_series_lin10yr=price_lin10yr.loc[:, 'No.2 spread']
tcrc_series_lin10yr=price_lin10yr.loc[:, 'TCRC']

price_lin20yr=pd.read_excel('John/00 Initial Linear Ramp Shocks/price linshock20yr-sp2-1.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_lin20yr=price_lin20yr.loc[:, 'Cathode']
sp2_series_lin20yr=price_lin20yr.loc[:, 'No.2 spread']
tcrc_series_lin20yr=price_lin20yr.loc[:, 'TCRC']

# %% [markdown]
# ###### Price Data Import - Elasticities for Linear Approach
# ###### Price Data Import - Secondary Ratio Elasticity / SP2E 100% Linear Shock

# %%
price_sp2hi_baseline=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2hi_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2hi_baseline=price_sp2hi_baseline.loc[:, 'Cathode']
sp2_series_sp2hi_baseline=price_sp2hi_baseline.loc[:, 'No.2 spread']
tcrc_series_sp2hi_baseline=price_sp2hi_baseline.loc[:, 'TCRC']

price_sp2hi1yr=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2hi1yr.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2hi1yr=price_sp2hi1yr.loc[:, 'Cathode']
sp2_series_sp2hi1yr=price_sp2hi1yr.loc[:, 'No.2 spread']
tcrc_series_sp2hi1yr=price_sp2hi1yr.loc[:, 'TCRC']

price_sp2hi5yr=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2hi5yr.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2hi5yr=price_sp2hi5yr.loc[:, 'Cathode']
sp2_series_sp2hi5yr=price_sp2hi5yr.loc[:, 'No.2 spread']
tcrc_series_sp2hi5yr=price_sp2hi5yr.loc[:, 'TCRC']

price_sp2hi10yr=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2hi10yr.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2hi10yr=price_sp2hi10yr.loc[:, 'Cathode']
sp2_series_sp2hi10yr=price_sp2hi10yr.loc[:, 'No.2 spread']
tcrc_series_sp2hi10yr=price_sp2hi10yr.loc[:, 'TCRC']

price_sp2hi20yr=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2hi20yr.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2hi20yr=price_sp2hi20yr.loc[:, 'Cathode']
sp2_series_sp2hi20yr=price_sp2hi20yr.loc[:, 'No.2 spread']
tcrc_series_sp2hi20yr=price_sp2hi20yr.loc[:, 'TCRC']

# %% [markdown]
# Price Data Import - SP2E Low 100% Linear Shock

# %%
price_sp2lo_baseline=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2lo_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2lo_baseline=price_sp2lo_baseline.loc[:, 'Cathode']
sp2_series_sp2lo_baseline=price_sp2lo_baseline.loc[:, 'No.2 spread']
tcrc_series_sp2lo_baseline=price_sp2lo_baseline.loc[:, 'TCRC']

price_sp2lo1yr=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2lo1yr.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2lo1yr=price_sp2lo1yr.loc[:, 'Cathode']
sp2_series_sp2lo1yr=price_sp2lo1yr.loc[:, 'No.2 spread']
tcrc_series_sp2lo1yr=price_sp2lo1yr.loc[:, 'TCRC']

price_sp2lo5yr=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2lo5yr.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2lo5yr=price_sp2lo5yr.loc[:, 'Cathode']
sp2_series_sp2lo5yr=price_sp2lo5yr.loc[:, 'No.2 spread']
tcrc_series_sp2lo5yr=price_sp2lo5yr.loc[:, 'TCRC']

price_sp2lo10yr=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2lo10yr.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2lo10yr=price_sp2lo10yr.loc[:, 'Cathode']
sp2_series_sp2lo10yr=price_sp2lo10yr.loc[:, 'No.2 spread']
tcrc_series_sp2lo10yr=price_sp2lo10yr.loc[:, 'TCRC']

price_sp2lo20yr=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2lo20yr.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2lo20yr=price_sp2lo20yr.loc[:, 'Cathode']
sp2_series_sp2lo20yr=price_sp2lo20yr.loc[:, 'No.2 spread']
tcrc_series_sp2lo20yr=price_sp2lo20yr.loc[:, 'TCRC']

# %% [markdown]
# ###### Price Data Import - Secondary Ratio Elasticity / SP2E 20% Linear Shock
# High sp2hi

# %%
price_sp2hi_baseline=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2hi_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2hi_baseline=price_sp2hi_baseline.loc[:, 'Cathode']
sp2_series_sp2hi_baseline=price_sp2hi_baseline.loc[:, 'No.2 spread']
tcrc_series_sp2hi_baseline=price_sp2hi_baseline.loc[:, 'TCRC']

price_sp2hi1yr20=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2hi1yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2hi1yr20=price_sp2hi1yr20.loc[:, 'Cathode']
sp2_series_sp2hi1yr20=price_sp2hi1yr20.loc[:, 'No.2 spread']
tcrc_series_sp2hi1yr20=price_sp2hi1yr20.loc[:, 'TCRC']

price_sp2hi5yr20=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2hi5yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2hi5yr20=price_sp2hi5yr20.loc[:, 'Cathode']
sp2_series_sp2hi5yr20=price_sp2hi5yr20.loc[:, 'No.2 spread']
tcrc_series_sp2hi5yr20=price_sp2hi5yr20.loc[:, 'TCRC']

price_sp2hi10yr20=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2hi10yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2hi10yr20=price_sp2hi10yr20.loc[:, 'Cathode']
sp2_series_sp2hi10yr20=price_sp2hi10yr20.loc[:, 'No.2 spread']
tcrc_series_sp2hi10yr20=price_sp2hi10yr20.loc[:, 'TCRC']

price_sp2hi20yr20=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2hi20yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2hi20yr20=price_sp2hi20yr20.loc[:, 'Cathode']
sp2_series_sp2hi20yr20=price_sp2hi20yr20.loc[:, 'No.2 spread']
tcrc_series_sp2hi20yr20=price_sp2hi20yr20.loc[:, 'TCRC']

# %% [markdown]
# Price Data Import - SP2E Low 20% Linear Shock

# %%
price_sp2lo_baseline=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2lo_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2lo_baseline=price_sp2lo_baseline.loc[:, 'Cathode']
sp2_series_sp2lo_baseline=price_sp2lo_baseline.loc[:, 'No.2 spread']
tcrc_series_sp2lo_baseline=price_sp2lo_baseline.loc[:, 'TCRC']

price_sp2lo1yr20=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2lo1yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2lo1yr20=price_sp2lo1yr20.loc[:, 'Cathode']
sp2_series_sp2lo1yr20=price_sp2lo1yr20.loc[:, 'No.2 spread']
tcrc_series_sp2lo1yr20=price_sp2lo1yr20.loc[:, 'TCRC']

price_sp2lo5yr20=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2lo5yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2lo5yr20=price_sp2lo5yr20.loc[:, 'Cathode']
sp2_series_sp2lo5yr20=price_sp2lo5yr20.loc[:, 'No.2 spread']
tcrc_series_sp2lo5yr20=price_sp2lo5yr20.loc[:, 'TCRC']

price_sp2lo10yr20=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2lo10yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2lo10yr20=price_sp2lo10yr20.loc[:, 'Cathode']
sp2_series_sp2lo10yr20=price_sp2lo10yr20.loc[:, 'No.2 spread']
tcrc_series_sp2lo10yr20=price_sp2lo10yr20.loc[:, 'TCRC']

price_sp2lo20yr20=pd.read_excel('John/01 Linear Ramp + SP2E/price sp2lo20yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_sp2lo20yr20=price_sp2lo20yr20.loc[:, 'Cathode']
sp2_series_sp2lo20yr20=price_sp2lo20yr20.loc[:, 'No.2 spread']
tcrc_series_sp2lo20yr20=price_sp2lo20yr20.loc[:, 'TCRC']

# %% [markdown]
# ###### Price Data Import - Mine Production Elasticity 20% Linear Shock
# MPE High 20%

# %%
price_mpehi_baseline=pd.read_excel('John/02 Linear Ramp + MPE/price mpehi_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_mpehi_baseline=price_mpehi_baseline.loc[:, 'Cathode']
sp2_series_mpehi_baseline=price_mpehi_baseline.loc[:, 'No.2 spread']
tcrc_series_mpehi_baseline=price_mpehi_baseline.loc[:, 'TCRC']

price_mpehi1yr20=pd.read_excel('John/02 Linear Ramp + MPE/price mpehi1yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_mpehi1yr20=price_mpehi1yr20.loc[:, 'Cathode']
sp2_series_mpehi1yr20=price_mpehi1yr20.loc[:, 'No.2 spread']
tcrc_series_mpehi1yr20=price_mpehi1yr20.loc[:, 'TCRC']

price_mpehi5yr20=pd.read_excel('John/02 Linear Ramp + MPE/price mpehi5yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_mpehi5yr20=price_mpehi5yr20.loc[:, 'Cathode']
sp2_series_mpehi5yr20=price_mpehi5yr20.loc[:, 'No.2 spread']
tcrc_series_mpehi5yr20=price_mpehi5yr20.loc[:, 'TCRC']

price_mpehi10yr20=pd.read_excel('John/02 Linear Ramp + MPE/price mpehi10yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_mpehi10yr20=price_mpehi10yr20.loc[:, 'Cathode']
sp2_series_mpehi10yr20=price_mpehi10yr20.loc[:, 'No.2 spread']
tcrc_series_mpehi10yr20=price_mpehi10yr20.loc[:, 'TCRC']

price_mpehi20yr20=pd.read_excel('John/02 Linear Ramp + MPE/price mpehi20yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_mpehi20yr20=price_mpehi20yr20.loc[:, 'Cathode']
sp2_series_mpehi20yr20=price_mpehi20yr20.loc[:, 'No.2 spread']
tcrc_series_mpehi20yr20=price_mpehi20yr20.loc[:, 'TCRC']

# %% [markdown]
# Price Data Import - MPE Low 20% Linear Shock

# %%
price_mpelo_baseline=pd.read_excel('John/02 Linear Ramp + MPE/price mpelo_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_mpelo_baseline=price_mpelo_baseline.loc[:, 'Cathode']
sp2_series_mpelo_baseline=price_mpelo_baseline.loc[:, 'No.2 spread']
tcrc_series_mpelo_baseline=price_mpelo_baseline.loc[:, 'TCRC']

price_mpelo1yr20=pd.read_excel('John/02 Linear Ramp + MPE/price mpelo1yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_mpelo1yr20=price_mpelo1yr20.loc[:, 'Cathode']
sp2_series_mpelo1yr20=price_mpelo1yr20.loc[:, 'No.2 spread']
tcrc_series_mpelo1yr20=price_mpelo1yr20.loc[:, 'TCRC']

price_mpelo5yr20=pd.read_excel('John/02 Linear Ramp + MPE/price mpelo5yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_mpelo5yr20=price_mpelo5yr20.loc[:, 'Cathode']
sp2_series_mpelo5yr20=price_mpelo5yr20.loc[:, 'No.2 spread']
tcrc_series_mpelo5yr20=price_mpelo5yr20.loc[:, 'TCRC']

price_mpelo10yr20=pd.read_excel('John/02 Linear Ramp + MPE/price mpelo10yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_mpelo10yr20=price_mpelo10yr20.loc[:, 'Cathode']
sp2_series_mpelo10yr20=price_mpelo10yr20.loc[:, 'No.2 spread']
tcrc_series_mpelo10yr20=price_mpelo10yr20.loc[:, 'TCRC']

price_mpelo20yr20=pd.read_excel('John/02 Linear Ramp + MPE/price mpelo20yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_mpelo20yr20=price_mpelo20yr20.loc[:, 'Cathode']
sp2_series_mpelo20yr20=price_mpelo20yr20.loc[:, 'No.2 spread']
tcrc_series_mpelo20yr20=price_mpelo20yr20.loc[:, 'TCRC']

# %% [markdown]
# ###### Price Data Import - Scrap Supply & Demand Elasticity 20% Linear Shock
# SSDE High 20%

# %%
price_ssdehi_baseline=pd.read_excel('John/03 Linear Ramp + SSDE/price ssdehi_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_ssdehi_baseline=price_ssdehi_baseline.loc[:, 'Cathode']
sp2_series_ssdehi_baseline=price_ssdehi_baseline.loc[:, 'No.2 spread']
tcrc_series_ssdehi_baseline=price_ssdehi_baseline.loc[:, 'TCRC']

price_ssdehi1yr20=pd.read_excel('John/03 Linear Ramp + SSDE/price ssdehi1yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_ssdehi1yr20=price_ssdehi1yr20.loc[:, 'Cathode']
sp2_series_ssdehi1yr20=price_ssdehi1yr20.loc[:, 'No.2 spread']
tcrc_series_ssdehi1yr20=price_ssdehi1yr20.loc[:, 'TCRC']

price_ssdehi5yr20=pd.read_excel('John/03 Linear Ramp + SSDE/price ssdehi5yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_ssdehi5yr20=price_ssdehi5yr20.loc[:, 'Cathode']
sp2_series_ssdehi5yr20=price_ssdehi5yr20.loc[:, 'No.2 spread']
tcrc_series_ssdehi5yr20=price_ssdehi5yr20.loc[:, 'TCRC']

price_ssdehi10yr20=pd.read_excel('John/03 Linear Ramp + SSDE/price ssdehi10yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_ssdehi10yr20=price_ssdehi10yr20.loc[:, 'Cathode']
sp2_series_ssdehi10yr20=price_ssdehi10yr20.loc[:, 'No.2 spread']
tcrc_series_ssdehi10yr20=price_ssdehi10yr20.loc[:, 'TCRC']

price_ssdehi20yr20=pd.read_excel('John/03 Linear Ramp + SSDE/price ssdehi20yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_ssdehi20yr20=price_ssdehi20yr20.loc[:, 'Cathode']
sp2_series_ssdehi20yr20=price_ssdehi20yr20.loc[:, 'No.2 spread']
tcrc_series_ssdehi20yr20=price_ssdehi20yr20.loc[:, 'TCRC']

# %% [markdown]
# Price Data Import - SSDE Low 20% Linear Shock

# %%
price_ssdelo_baseline=pd.read_excel('John/03 Linear Ramp + SSDE/price ssdelo_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_ssdelo_baseline=price_ssdelo_baseline.loc[:, 'Cathode']
sp2_series_ssdelo_baseline=price_ssdelo_baseline.loc[:, 'No.2 spread']
tcrc_series_ssdelo_baseline=price_ssdelo_baseline.loc[:, 'TCRC']

price_ssdelo1yr20=pd.read_excel('John/03 Linear Ramp + SSDE/price ssdelo1yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_ssdelo1yr20=price_ssdelo1yr20.loc[:, 'Cathode']
sp2_series_ssdelo1yr20=price_ssdelo1yr20.loc[:, 'No.2 spread']
tcrc_series_ssdelo1yr20=price_ssdelo1yr20.loc[:, 'TCRC']

price_ssdelo5yr20=pd.read_excel('John/03 Linear Ramp + SSDE/price ssdelo5yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_ssdelo5yr20=price_ssdelo5yr20.loc[:, 'Cathode']
sp2_series_ssdelo5yr20=price_ssdelo5yr20.loc[:, 'No.2 spread']
tcrc_series_ssdelo5yr20=price_ssdelo5yr20.loc[:, 'TCRC']

price_ssdelo10yr20=pd.read_excel('John/03 Linear Ramp + SSDE/price ssdelo10yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_ssdelo10yr20=price_ssdelo10yr20.loc[:, 'Cathode']
sp2_series_ssdelo10yr20=price_ssdelo10yr20.loc[:, 'No.2 spread']
tcrc_series_ssdelo10yr20=price_ssdelo10yr20.loc[:, 'TCRC']

price_ssdelo20yr20=pd.read_excel('John/03 Linear Ramp + SSDE/price ssdelo20yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_ssdelo20yr20=price_ssdelo20yr20.loc[:, 'Cathode']
sp2_series_ssdelo20yr20=price_ssdelo20yr20.loc[:, 'No.2 spread']
tcrc_series_ssdelo20yr20=price_ssdelo20yr20.loc[:, 'TCRC']

# %% [markdown]
# ###### Price Data Import - Copper Demand Elasticity to Cathode Price 20% Linear Shock
# 400% DE 20%

# %%
price_400de_baseline=pd.read_excel('John/04 Linear Ramp + DE/price 400de_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_400de_baseline=price_400de_baseline.loc[:, 'Cathode']
sp2_series_400de_baseline=price_400de_baseline.loc[:, 'No.2 spread']
tcrc_series_400de_baseline=price_400de_baseline.loc[:, 'TCRC']

price_400de1yr20=pd.read_excel('John/04 Linear Ramp + DE/price 400de1yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_400de1yr20=price_400de1yr20.loc[:, 'Cathode']
sp2_series_400de1yr20=price_400de1yr20.loc[:, 'No.2 spread']
tcrc_series_400de1yr20=price_400de1yr20.loc[:, 'TCRC']

price_400de5yr20=pd.read_excel('John/04 Linear Ramp + DE/price 400de5yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_400de5yr20=price_400de5yr20.loc[:, 'Cathode']
sp2_series_400de5yr20=price_400de5yr20.loc[:, 'No.2 spread']
tcrc_series_400de5yr20=price_400de5yr20.loc[:, 'TCRC']

price_400de10yr20=pd.read_excel('John/04 Linear Ramp + DE/price 400de10yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_400de10yr20=price_400de10yr20.loc[:, 'Cathode']
sp2_series_400de10yr20=price_400de10yr20.loc[:, 'No.2 spread']
tcrc_series_400de10yr20=price_400de10yr20.loc[:, 'TCRC']

price_400de20yr20=pd.read_excel('John/04 Linear Ramp + DE/price 400de20yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_400de20yr20=price_400de20yr20.loc[:, 'Cathode']
sp2_series_400de20yr20=price_400de20yr20.loc[:, 'No.2 spread']
tcrc_series_400de20yr20=price_400de20yr20.loc[:, 'TCRC']

# %% [markdown]
# Price Data Import - SSDE Low 20% Linear Shock

# %%
price_200de_baseline=pd.read_excel('John/04 Linear Ramp + DE/price 200de_baseline.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_200de_baseline=price_200de_baseline.loc[:, 'Cathode']
sp2_series_200de_baseline=price_200de_baseline.loc[:, 'No.2 spread']
tcrc_series_200de_baseline=price_200de_baseline.loc[:, 'TCRC']

price_200de1yr20=pd.read_excel('John/04 Linear Ramp + DE/price 200de1yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_200de1yr20=price_200de1yr20.loc[:, 'Cathode']
sp2_series_200de1yr20=price_200de1yr20.loc[:, 'No.2 spread']
tcrc_series_200de1yr20=price_200de1yr20.loc[:, 'TCRC']

price_200de5yr20=pd.read_excel('John/04 Linear Ramp + DE/price 200de5yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_200de5yr20=price_200de5yr20.loc[:, 'Cathode']
sp2_series_200de5yr20=price_200de5yr20.loc[:, 'No.2 spread']
tcrc_series_200de5yr20=price_200de5yr20.loc[:, 'TCRC']

price_200de10yr20=pd.read_excel('John/04 Linear Ramp + DE/price 200de10yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_200de10yr20=price_200de10yr20.loc[:, 'Cathode']
sp2_series_200de10yr20=price_200de10yr20.loc[:, 'No.2 spread']
tcrc_series_200de10yr20=price_200de10yr20.loc[:, 'TCRC']

price_200de20yr20=pd.read_excel('John/04 Linear Ramp + DE/price 200de20yr20.xlsx', sheet_name='Sheet1', index_col=0)
cathode_price_series_200de20yr20=price_200de20yr20.loc[:, 'Cathode']
sp2_series_200de20yr20=price_200de20yr20.loc[:, 'No.2 spread']
tcrc_series_200de20yr20=price_200de20yr20.loc[:, 'TCRC']

# %% [markdown]
# ###### Cathode price

# %%
# pplot(cathode_price_series_baseline_baseline, label='Xinkai baseline')

pplot(cathode_price_series_pir_baseline.loc['20100101':], 'Current baseline', colors[0],0,14,2,1)
pplot(cathode_price_series_ban_no2_50yoy.loc['20180101':], 'Ban No.2', colors[1])
pplot(cathode_price_series_alloyed_imports_50yoy.loc['20180101':], 'Ban Alloyed', colors[2])
pplot(cathode_price_series_alloyed_no2_50yoy.loc['20180101':], 'Ban <99%', colors[3])
# pplot(cathode_price_series_baseline_baseline, label='Baseline')

# pplot(cathode_price_series_baseline_prs10.loc['20180101':], label='10%')
# pplot(cathode_price_series_baseline_prs20.loc['20180101':], label='20%')
# pplot(cathode_price_series_baseline_prs50.loc['20180101':], label='50%')
# pplot(cathode_price_series_baseline_prs100.loc['20180101':], label='Maximum')
# pplot(cathode_price_series_baseline_baseline, label='Baseline')

# pplot(cathode_price_series_200_de_baseline.loc['20180101':], label='200%')
# pplot(cathode_price_series_400_de_baseline.loc['20180101':], label='400%')

plt.plot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [1000, 11700], 'k--')
# plt.legend()
plt.xlabel('Year')
plt.ylabel('Cathode price (USD/t)')
plt.show()

# %%
# pplot(cathode_price_series_fruity1rr0.loc['20100101':], '0% Recycled Content', colors[2],0,16,2,1)
# # pplot(cathode_price_series_fruity1rr11.loc['20180101':], 'Fruity 1X 1% RR', colors[0])
# pplot(cathode_price_series_fruity1rr50.loc['20180101':], '50% Recycled Content', colors[0])
# # pplot(cathode_price_series_fruity1rr90.loc['20180101':], 'Fruity 1X 90% RR', colors[2])
# pplot(cathode_price_series_fruity1rr100.loc['20180101':], '100% Recycled Content', colors[1])
# plt.plot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [1500, 8500], 'k--')
# plt.title('Cathode Price Evolution')
# plt.legend().set_visible(False)
# # plt.legend(loc='lower right')
# plt.yticks(np.arange(2000,12000,2000))
# plt.ylabel('Cathode Price (USD/tonne)')

# plt.figure()
# pplot(cathode_price_series_fruity_pct1rr0.loc['20100101':], 'Fruity 1mrk% 0% RR', color = 'k')
# pplot(cathode_price_series_fruity_pct1rr11.loc['20180101':], 'Fruity 1mrk% 1% RR', colors[0])
# pplot(cathode_price_series_fruity_pct1rr50.loc['20180101':], 'Fruity 1mrk% 50% RR', colors[1])
# pplot(cathode_price_series_fruity_pct1rr90.loc['20180101':], 'Fruity 1mrk% 90% RR', colors[2])
# pplot(cathode_price_series_fruity_pct1rr100.loc['20180101':], 'Fruity 1mrk% 100% RR', colors[3])
# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [1500, 8500], 'k--')
# plt.legend()
# plt.title('Cathode Price (USD/tonne)\nGlobal, 1% of market')

# plt.figure()
# pplot(cathode_price_series_fruity_pct5rr0.loc['20100101':], 'Fruity 5mrk% 0% RR', color = 'k')
# pplot(cathode_price_series_fruity_pct5rr11.loc['20180101':], 'Fruity 5mrk% 1% RR', colors[0])
# pplot(cathode_price_series_fruity_pct5rr50.loc['20180101':], 'Fruity 5mrk% 50% RR', colors[1])
# pplot(cathode_price_series_fruity_pct5rr90.loc['20180101':], 'Fruity 5mrk% 90% RR', colors[2])
# pplot(cathode_price_series_fruity_pct5rr100.loc['20180101':], 'Fruity 5mrk% 100% RR', colors[3])
# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [1500, 8500], 'k--')
# plt.legend()
# plt.title('Cathode Price (USD/tonne)\nGlobal, 5% of market')

# plt.figure()
pplot(cathode_price_series_fruity_pct10rr0.loc['20100101':], 'Fruity 10mrk% 0% RR', color = colors[2], firstcall=1)
# pplot(cathode_price_series_fruity_pct10rr11.loc['20100101':], 'Fruity 10mrk% 1% RR')
pplot(cathode_price_series_fruity_pct10rr50.loc['20180101':], 'Fruity 10mrk% 50% RR', colors[0])
# pplot(cathode_price_series_fruity_pct10rr70.loc['20180101':], 'Fruity 10mrk% 70% RR', colors[2])
pplot(cathode_price_series_fruity_pct10rr90.loc['20180101':], 'Fruity 10mrk% 90% RR', colors[1])
plt.plot([cathode_price_series_fruity_pct10rr90.loc['20180101':].index[0], cathode_price_series_fruity_pct10rr90.loc['20180101':].index[0]], [1500, 8500], 'k--')
plt.legend().set_visible(False)
plt.title('Cathode Price\nGlobal, 10% of market')
plt.yticks([2000,4000,6000,8000,10000])
plt.ylabel('Cathode price (USD/tonne)')


plt.figure()
pplot(cathode_price_series_fruity_pct10rr50var10.loc['20100101':], 'Fruity 10mrk% var10', color = colors[0], firstcall=1)
pplot(cathode_price_series_fruity_pct10rr50var30.loc['20100101':], 'Fruity 10mrk% var30', color = colors[1])
pplot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':], 'Fruity 10mrk% var50', colors[2])
pplot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':], 'Fruity 10mrk% var70', colors[3])
plt.plot([cathode_price_series_fruity_pct10rr90.loc['20180101':].index[0], cathode_price_series_fruity_pct10rr90.loc['20180101':].index[0]], [1500, 8500], 'k--')
# plt.legend().set_visible(False)
plt.title('Cathode Price\nGlobal, 10% of market')
plt.yticks([2000,4000,6000,8000,10000])
plt.ylabel('Cathode price (USD/tonne)')

# plt.figure()
# pplot(cathode_price_series_fruity_pct10rr90.loc['20180101':], 'Fruity 0.08mrk% 90% RR')
# pplot(cathode_price_series_fruity_pct1rr90.loc['20180101':], 'Fruity 1mrk% 90% RR')
# pplot(cathode_price_series_fruity_pct5rr90.loc['20180101':], 'Fruity 5mrk% 90% RR', colors[2])
# pplot(cathode_price_series_fruity_pct10rr70.loc['20180101':], 'Fruity 10mrk% 70% RR', colors[3])
# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [1500, 8500], 'k--')
# plt.legend()
# plt.title('Cathode Price (USD/tonne)\nGlobal, varying percentages')

# %%
np.log(cathode_price_series_baseline_baseline.loc[:'20180101']).diff().std()

# %%
np.log(cathode_price_series_baseline_baseline.loc['20190101':]).diff().std()

# %% [markdown]
# ###### TCRC

# %%
# pplot(tcrc_series_baseline_baseline, label='Xinkai baseline')

pplot(tcrc_series_pir_baseline.loc['20100101':], label='Current baseline')
pplot(tcrc_series_ban_no2_50yoy.loc['20180101':], label='Ban No.2')
pplot(tcrc_series_alloyed_imports_50yoy.loc['20180101':], label='Ban Alloyed')
pplot(tcrc_series_alloyed_no2_50yoy.loc['20180101':], label='Ban <99%')

pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [250, 950], 'k--')
plt.legend()
plt.xlabel('Year')
plt.ylabel('TCRC  (USD/t)')
plt.show()

# %%
pplot(tcrc_series_fruity1rr0.loc['20100101':], label = 'Fruity 1X 0% RR', color = 'k')
pplot(tcrc_series_fruity1rr11.loc['20180101':], label = 'Fruity 1X 1% RR')
pplot(tcrc_series_fruity1rr50.loc['20180101':], label = 'Fruity 1X 50% RR')
pplot(tcrc_series_fruity1rr90.loc['20180101':], label = 'Fruity 1X 90% RR', color = 'tab:green')
pplot(tcrc_series_fruity1rr100.loc['20180101':], label = 'Fruity 1X 100% RR', color = 'tab:gray')
pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [250, 950], 'k--')
plt.title('TCRC \nGlobal, 0.08% of market')
plt.legend()
plt.title('TCRC (USD/tonne)\nGlobal')

plt.figure()
pplot(tcrc_series_fruity_pct1rr0.loc['20100101':], label = 'Fruity 1mrk% 0% RR', color = 'k')
pplot(tcrc_series_fruity_pct1rr11.loc['20180101':], label = 'Fruity 1mrk% 1% RR')
pplot(tcrc_series_fruity_pct1rr50.loc['20180101':], label = 'Fruity 1mrk% 50% RR')
pplot(tcrc_series_fruity_pct1rr90.loc['20180101':], label = 'Fruity 1mrk% 90% RR', color = 'tab:green')
pplot(tcrc_series_fruity_pct1rr100.loc['20180101':], label = 'Fruity 1mrk% 100% RR', color = 'tab:gray')
pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [250, 950], 'k--')
plt.legend()
plt.title('TCRC (USD/tonne)\nGlobal, 1% of market')

plt.figure()
pplot(tcrc_series_fruity_pct5rr0.loc['20100101':], label = 'Fruity 5mrk% 0% RR', color = 'k')
pplot(tcrc_series_fruity_pct5rr11.loc['20180101':], label = 'Fruity 5mrk% 1% RR')
pplot(tcrc_series_fruity_pct5rr50.loc['20180101':], label = 'Fruity 5mrk% 50% RR')
pplot(tcrc_series_fruity_pct5rr90.loc['20180101':], label = 'Fruity 5mrk% 90% RR', color = 'tab:green')
pplot(tcrc_series_fruity_pct5rr100.loc['20180101':], label = 'Fruity 5mrk% 100% RR', color = 'tab:gray')
pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [250, 950], 'k--')
plt.legend()
plt.title('TCRC (USD/tonne)\nGlobal, 5% of market')

plt.figure()
pplot(tcrc_series_fruity_pct10rr0.loc['20100101':], label = 'Fruity 10mrk% 0% RR', color = 'k')
pplot(tcrc_series_fruity_pct10rr11.loc['20180101':], label = 'Fruity 10mrk% 1% RR')
pplot(tcrc_series_fruity_pct10rr50.loc['20180101':], label = 'Fruity 10mrk% 50% RR')
pplot(tcrc_series_fruity_pct10rr70.loc['20180101':], label = 'Fruity 10mrk% 70% RR', color = 'tab:green')
pplot(tcrc_series_fruity_pct10rr90.loc['20180101':], label = 'Fruity 10mrk% 90% RR', color = 'tab:gray')
pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [250, 950], 'k--')
plt.legend()
plt.title('TCRC (USD/tonne)\nGlobal, 10% of market')

plt.figure()
pplot(tcrc_series_fruity_pct10rr90.loc['20180101':], label = 'Fruity 0.08mrk% 90% RR')
pplot(tcrc_series_fruity_pct1rr90.loc['20180101':], label = 'Fruity 1mrk% 90% RR')
pplot(tcrc_series_fruity_pct5rr90.loc['20180101':], label = 'Fruity 5mrk% 90% RR', color = 'tab:green')
pplot(tcrc_series_fruity_pct10rr70.loc['20180101':], label = 'Fruity 10mrk% 70% RR', color = 'tab:gray')
pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [250, 950], 'k--')
plt.legend()
plt.title('TCRC (USD/tonne)\nGlobal, varying percentages')

# %%
# pplot(tcrc_series_baseline_baseline, label='Baseline')

# pplot(tcrc_series_baseline_rs10.loc['20180101':], label='10%')
# pplot(tcrc_series_baseline_rs20.loc['20180101':], label='20%')
# pplot(tcrc_series_baseline_rs50.loc['20180101':], label='50%')
# pplot(tcrc_series_baseline_rs100.loc['20180101':], label='100%')

pplot(tcrc_series_baseline_prs10.loc['20180101':], label='10%')
pplot(tcrc_series_baseline_prs20.loc['20180101':], label='20%')
pplot(tcrc_series_baseline_prs50.loc['20180101':], label='50%')
pplot(tcrc_series_baseline_prs100.loc['20180101':], label='100%')

# pplot(tcrc_series_baseline_irs100.loc['20180101':], label='100%')

pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 1000], 'k--')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Annual TCRC (USD/t)')
plt.show()

# %%
np.log(tcrc_series_baseline_baseline.loc[:'20180101']).diff().std()

# %%
np.log(tcrc_series_baseline_baseline.loc['20190101':]).diff().std()

# %% [markdown]
# ###### No.2 spread

# %%
pplot(cathode_price_series_baseline_baseline, label = 'Cathode')
pplot(cathode_price_series_baseline_baseline - sp2_series_baseline_baseline, label='No.2 Scrap')
# pplot(sp2_series_baseline_rs10.loc['20180101':], label='10%')
# pplot(sp2_series_baseline_rs20.loc['20180101':], label='20%')
# pplot(sp2_series_baseline_rs50.loc['20180101':], label='50%')
# pplot(sp2_series_baseline_rs100.loc['20180101':], label='100%')

pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 11000], 'k--')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Birch spread (USD/t)')
plt.show()

# %% [markdown]
# ###### No.2 spread and cathode corr

# %%
print(sp2_series_baseline_rs50.diff().loc[:'20180101'].corr(cathode_price_series_baseline_rs50.diff().loc[:'20180101']))
print(sp2_series_baseline_rs50.diff().loc['20190101':].corr(cathode_price_series_baseline_rs50.diff().loc['20190101':]))
print(sp2_series_baseline_rs50.loc[:'20180101'].corr(cathode_price_series_baseline_rs50.loc[:'20180101']))
print(sp2_series_baseline_rs50.loc['20190101':].corr(cathode_price_series_baseline_rs50.loc['20190101':]))

# %% [markdown]
# ### China import price response scenarios

# %%
pplot(cathode_price_series_pir_baseline, 'Cathode', 'tab:red', linewidth=2, firstcall=1)
pplot(cathode_price_series_pir_baseline-spa_series_pir_baseline_gl,'Yellow Brass', 'tab:green', linewidth=2)
pplot(cathode_price_series_pir_baseline-sp2_series_pir_baseline_gl,'No.2', 'tab:blue', linewidth=2)

# %%
# string = 'TCRC'
# pplot(tcrc_series_alloyed_imports_50yoy.loc['20180101':] - tcrc_series_pir_baseline.loc['20180101', label='<94% Cu ban TCRC',color='tab:blue')
# pplot(tcrc_series_alloyed_no2_50yoy.loc['20180101':], label='<99% Cu ban TCRC',color='tab:orange')
# pplot(tcrc_series_ban_no2_50yoy.loc['20180101':], label='No.2 ban TCRC',color='lightseagreen')
# pplot(tcrc_series_lin20yr.loc['20180101':], label='20year TCRC',color='tab:brown')

# string = 'Cathode and and TCRC\nDifference above baseline'
# pplot(cathode_price_series_pir_baseline.loc['20100101':], label='Baseline',color='tab:gray')
# pplot(cathode_price_series_alloyed_imports_50yoy.loc['20180101':], label='<94% Cu ban Cathode Price',color='tab:blue')
# pplot(cathode_price_series_alloyed_no2_50yoy.loc['20180101':], label='<99% Cu ban Cathode Price',color='tab:orange')
# pplot(cathode_price_series_ban_no2_50yoy.loc['20180101':], label='Ban No.2 Cathode price',color='lightseagreen')
# # pplot(cathode_price_series_lin20yr.loc['20180101':], label='20year Cathode Price',color='tab:brown')

string = 'No. 2 and Yellow Brass Scrap Spreads'
# pplot(sp2_series_pir_baseline_rw.loc['20160101':], label='Baseline',color='tab:gray')
pplot(sp2_series_alloyed_imports_50yoy_rw.loc['20180101':] - sp2_series_pir_baseline_rw.loc['20180101':], label='<94% Cu ban No. 2 Spread',color='tab:blue')
pplot(sp2_series_alloyed_no2_50yoy_rw.loc['20180101':] - sp2_series_pir_baseline_rw.loc['20180101':], label='<99% Cu ban No. 2 Spread',color='tab:orange')
pplot(sp2_series_ban_no2_50yoy_rw.loc['20180101':] - sp2_series_pir_baseline_rw.loc['20180101':], label='No.2 Ban No. 2 Spread',color='lightseagreen')
# pplot(spa_series_pir_baseline_rw.loc['20160101':], '--', label='Baseline',color='tab:gray')
pplot(spa_series_alloyed_imports_50yoy_rw.loc['20180101':] - spa_series_pir_baseline_rw.loc['20180101':], '--', label='<94% Cu ban No. 2 Spread',color='tab:blue')
pplot(spa_series_alloyed_no2_50yoy_rw.loc['20180101':] - spa_series_pir_baseline_rw.loc['20180101':], '--', label='<99% Cu ban No. 2 Spread',color='tab:orange')
pplot(spa_series_ban_no2_50yoy_rw.loc['20180101':] - spa_series_pir_baseline_rw.loc['20180101':], '--', label='No.2 Ban No. 2 Spread',color='lightseagreen')

# string = 'No. 2 Scrap Price'
# pplot(cathode_price_series_pir_baseline.loc['20100101':]-sp2_series_pir_baseline_rw.loc['20100101':], '--',label='Baseline',color='tab:gray')
# pplot(cathode_price_series_alloyed_imports_50yoy.loc['20180101':]-sp2_series_alloyed_imports_50yoy_rw.loc['20180101':],'--', label='<94% Cu ban No. 2 Scrap Price',color='tab:blue')
# pplot(cathode_price_series_alloyed_no2_50yoy.loc['20180101':]-sp2_series_alloyed_no2_50yoy_rw.loc['19910101':],'--', label='<99% Cu ban No. 2 Scrap Price',color='tab:orange')
# pplot(cathode_price_series_ban_no2_50yoy.loc['20180101':]-sp2_series_ban_no2_50yoy_rw.loc['19910101':],'--', label='Baseline No. 2 Scrap Price',color='lightseagreen')
# # # pplot(cathode_price_series_lin20yr.loc['20180101':]-sp2_series_lin20yr.loc['19910101':],'--', label='20year No. 2 Scrap Price',color='tab:brown')

# pplot(cathode_price_series_pir_baseline.loc['20100101':]-spa_series_pir_baseline_rw.loc['20100101':], ':',label='Baseline',color='tab:gray')
# pplot(cathode_price_series_alloyed_imports_50yoy.loc['20180101':]-spa_series_alloyed_imports_50yoy_rw.loc['20180101':],':', label='<94% Cu ban No. 2 Scrap Price',color='tab:blue')
# pplot(cathode_price_series_alloyed_no2_50yoy.loc['20180101':]-spa_series_alloyed_no2_50yoy_rw.loc['19910101':],':', label='<99% Cu ban No. 2 Scrap Price',color='tab:orange')
# pplot(cathode_price_series_ban_no2_50yoy.loc['20180101':]-spa_series_ban_no2_50yoy_rw.loc['19910101':],':', label='Baseline No. 2 Scrap Price',color='lightseagreen')

# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 3000], 'k--')
# plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='Cathode Price:\n(Dashed, Same Colors for No. 2 Scrap Price)'),\
#                     Line2D([0],[0],color='tab:blue',label='<94% Cu Ban'),\
#                     Line2D([0],[0],color='tab:orange',label='<99% Cu Ban'),\
#                     Line2D([0],[0], color='lightseagreen',label='Baseline')],\
#           prop={'size':9},loc=2)

plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Spread)'),\
                    Line2D([0],[0],color='tab:gray',label='Baseline'),\
                    Line2D([0],[0],color='tab:blue',label='<94% Cu Ban'),\
                    Line2D([0],[0],color='tab:orange',label='<99% Cu Ban'),\
                    Line2D([0],[0], color='lightseagreen',label='Ban No.2')],\
          prop={'size':9},loc=2)
# plt.legend()
# plt.title('Prices for Linear Approach to 20% Base Shock\nRelaxed Scrap Spread Constraint')
plt.title('China Import Ban Scenarios\nAnnual '+string+' (USD/t)\nRest of World, Difference above Baseline')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')
plt.show()

# %%
# string = 'TCRC'
pplot(tcrc_series_alloyed_imports_50yoy.loc['20180101':], label='<94% Cu ban TCRC',color='tab:blue')
pplot(tcrc_series_alloyed_no2_50yoy.loc['20180101':], label='<99% Cu ban TCRC',color='tab:orange')
pplot(tcrc_series_ban_no2_50yoy.loc['20180101':], label='No.2 ban TCRC',color='lightseagreen')
# pplot(tcrc_series_lin20yr.loc['20180101':], label='20year TCRC',color='tab:brown')

# string = 'Cathode and and TCRC\nDifference above baseline'
# pplot(cathode_price_series_pir_baseline.loc['20100101':], label='Baseline',color='tab:gray')
# pplot(cathode_price_series_alloyed_imports_50yoy.loc['20180101':], label='<94% Cu ban Cathode Price',color='tab:blue')
# pplot(cathode_price_series_alloyed_no2_50yoy.loc['20180101':], label='<99% Cu ban Cathode Price',color='tab:orange')
# pplot(cathode_price_series_ban_no2_50yoy.loc['20180101':], label='Ban No.2 Cathode price',color='lightseagreen')
# # pplot(cathode_price_series_lin20yr.loc['20180101':], label='20year Cathode Price',color='tab:brown')

# string = 'No. 2 and Yellow Brass Scrap Spreads'
# pplot(sp2_series_pir_baseline_gl.loc['20160101':], label='Baseline',color='tab:gray')
# pplot(sp2_series_alloyed_imports_50yoy_gl.loc['20180101':], label='<94% Cu ban No. 2 Spread',color='tab:blue')
# pplot(sp2_series_alloyed_no2_50yoy_gl.loc['20180101':], label='<99% Cu ban No. 2 Spread',color='tab:orange')
# pplot(sp2_series_ban_no2_50yoy_gl.loc['20180101':], label='No.2 Ban No. 2 Spread',color='lightseagreen')
# pplot(spa_series_pir_baseline_gl.loc['20160101':], '--', label='Baseline',color='tab:gray')
# pplot(spa_series_alloyed_imports_50yoy_gl.loc['20180101':], '--', label='<94% Cu ban No. 2 Spread',color='tab:blue')
# pplot(spa_series_alloyed_no2_50yoy_gl.loc['20180101':], '--', label='<99% Cu ban No. 2 Spread',color='tab:orange')
# pplot(spa_series_ban_no2_50yoy_gl.loc['20180101':], '--', label='No.2 Ban No. 2 Spread',color='lightseagreen')

# string = 'No. 2 Scrap Price'
# pplot(cathode_price_series_pir_baseline.loc['20100101':]-sp2_series_pir_baseline_gl.loc['20100101':], '--',label='Baseline',color='tab:gray')
# pplot(cathode_price_series_alloyed_imports_50yoy.loc['20180101':]-sp2_series_alloyed_imports_50yoy_gl.loc['20180101':],'--', label='<94% Cu ban No. 2 Scrap Price',color='tab:blue')
# pplot(cathode_price_series_alloyed_no2_50yoy.loc['20180101':]-sp2_series_alloyed_no2_50yoy_gl.loc['19910101':],'--', label='<99% Cu ban No. 2 Scrap Price',color='tab:orange')
# pplot(cathode_price_series_ban_no2_50yoy.loc['20180101':]-sp2_series_ban_no2_50yoy_gl.loc['19910101':],'--', label='Baseline No. 2 Scrap Price',color='lightseagreen')
# # # pplot(cathode_price_series_lin20yr.loc['20180101':]-sp2_series_lin20yr.loc['19910101':],'--', label='20year No. 2 Scrap Price',color='tab:brown')

# pplot(cathode_price_series_pir_baseline.loc['20100101':]-spa_series_pir_baseline_gl.loc['20100101':], ':',label='Baseline',color='tab:gray')
# pplot(cathode_price_series_alloyed_imports_50yoy.loc['20180101':]-spa_series_alloyed_imports_50yoy_gl.loc['20180101':],':', label='<94% Cu ban No. 2 Scrap Price',color='tab:blue')
# pplot(cathode_price_series_alloyed_no2_50yoy.loc['20180101':]-spa_series_alloyed_no2_50yoy_gl.loc['19910101':],':', label='<99% Cu ban No. 2 Scrap Price',color='tab:orange')
# pplot(cathode_price_series_ban_no2_50yoy.loc['20180101':]-spa_series_ban_no2_50yoy_gl.loc['19910101':],':', label='Baseline No. 2 Scrap Price',color='lightseagreen')

pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 3000], 'k--')
# plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='Cathode Price:\n(Dashed, Same Colors for No. 2 Scrap Price)'),\
#                     Line2D([0],[0],color='tab:blue',label='<94% Cu Ban'),\
#                     Line2D([0],[0],color='tab:orange',label='<99% Cu Ban'),\
#                     Line2D([0],[0], color='lightseagreen',label='Baseline')],\
#           prop={'size':9},loc=2)

plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Price)'),\
                    Line2D([0],[0],color='tab:gray',label='Baseline'),\
                    Line2D([0],[0],color='tab:blue',label='<94% Cu Ban'),\
                    Line2D([0],[0],color='tab:orange',label='<99% Cu Ban'),\
                    Line2D([0],[0], color='lightseagreen',label='Ban No.2')],\
          prop={'size':9},loc=2)
# plt.legend()
# plt.title('Prices for Linear Approach to 20% Base Shock\nRelaxed Scrap Spread Constraint')
plt.title('China Import Ban Scenarios\nAnnual '+string+' (USD/t)')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')
plt.show()

# %% [markdown]
# Refined import sensitivities, difference of scrap spread from baseline

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'


fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
# ax1.plot(sp2_series_no2_50yoy_gl.loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax1.plot(sp2_series_no2_50yoy_inc200_gl.loc['20170101':] - sp2_series_no2_50yoy_gl.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax1.plot(sp2_series_no2_50yoy_inc100_gl.loc['20170101':] - sp2_series_no2_50yoy_gl.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax1.plot(sp2_series_no2_50yoy_dec100_gl.loc['20170101':] - sp2_series_no2_50yoy_gl.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax1.plot(sp2_series_no2_50yoy_dec200_gl.loc['20170101':] - sp2_series_no2_50yoy_gl.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax1.set_title('No.2 Spread Response above Baseline \nGlobal, No.2 Ban 50% YOY')
ax1.set_ylabel('No.2 spread response above baseline (USD/tonne)')
ax1.set_xlabel('Year')
# ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# ax2.plot(sp2_series_no2_50yoy_cn.loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax2.plot(sp2_series_no2_50yoy_inc200_cn.loc['20170101':] - sp2_series_no2_50yoy_cn.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax2.plot(sp2_series_no2_50yoy_inc100_cn.loc['20170101':] - sp2_series_no2_50yoy_cn.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax2.plot(sp2_series_no2_50yoy_dec100_cn.loc['20170101':] - sp2_series_no2_50yoy_cn.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax2.plot(sp2_series_no2_50yoy_dec200_cn.loc['20170101':] - sp2_series_no2_50yoy_cn.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax2.set_title('No.2 Spread Response above Baseline \nChina, No.2 Ban 50% YOY')
ax2.set_ylabel('No.2 spread response above baseline (USD/tonne)')
ax2.set_xlabel('Year')
# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# ax3.plot(sp2_series_no2_50yoy_rw.loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax3.plot(sp2_series_no2_50yoy_inc200_rw.loc['20170101':] - sp2_series_no2_50yoy_rw.loc['20170101':], label='Ref. Import +200',color=colors[3])
ax3.plot(sp2_series_no2_50yoy_inc100_rw.loc['20170101':] - sp2_series_no2_50yoy_rw.loc['20170101':], label='Ref. Import +100',color=colors[1])
ax3.plot(sp2_series_no2_50yoy_dec100_rw.loc['20170101':] - sp2_series_no2_50yoy_rw.loc['20170101':], label='Ref. Import -100',color=colors[2])
ax3.plot(sp2_series_no2_50yoy_dec200_rw.loc['20170101':] - sp2_series_no2_50yoy_rw.loc['20170101':], label='Ref. Import -200',color=colors[4])
ax3.set_title('No.2 Spread Response above Baseline \nRoW, No.2 Ban 50% YOY')
ax3.set_ylabel('No.2 spread response above baseline (USD/tonne)')
ax3.set_xlabel('Year')
ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Cathode price and SP2 Sensitivities

# %%
pplot(cathode_price_series_pir_baseline.loc['20180101':], label='Baseline',color=colors[0], firstcall=1)
pplot(cathode_price_series_alloyed_50yoy.loc['20180101':], label='Ban Alloyed',color=colors[1])
pplot(cathode_price_series_no2_50yoy.loc['20180101':], label='Ban No.2',color=colors[2])
pplot(cathode_price_series_both_50yoy.loc['20180101':], label='Ban <99% Cu',color=colors[3])
plt.title('Cathode Prices for Baseline and 50% YOY Scrap Bans')
plt.ylabel('Cathode price (USD/tonne)')

plt.figure()
pplot(cathode_price_series_both_50yoy_inc200.loc['20180101':], label='+200 kt/yr',color=colors[1], firstcall=1)
pplot(cathode_price_series_both_50yoy_inc100.loc['20180101':], label='+100 kt/yr',color=colors[2])
pplot(cathode_price_series_both_50yoy.loc['20180101':], label='Refined imports stay constant',color=colors[0])
pplot(cathode_price_series_both_50yoy_dec100.loc['20180101':], label='-100 kt/yr',color=colors[3])
pplot(cathode_price_series_both_50yoy_dec200.loc['20180101':], label='-200 kt/yr',color=colors[4])
plt.title('Cathode Prices for <99% Cu Scrap Ban \nSensitivity to Refined Imports')
plt.ylabel('Cathode price (USD/tonne)')

plt.figure()
pplot(cathode_price_series_both_75yoy.loc['20180101':], label='25% YOY',color=colors[2])
pplot(cathode_price_series_both_50yoy.loc['20180101':], label='50% YOY',color=colors[0])
pplot(cathode_price_series_both_25yoy.loc['20180101':], label='75% YOY',color=colors[3])
plt.title('Cathode Prices for <99% Cu Scrap Ban \nSensitivity to Scrap Ban Rate')
plt.ylabel('Cathode price (USD/tonne)')

pplot(sp2_series_pir_baseline_gl.loc['20180101':], label='Baseline',color=colors[0], firstcall=1)
pplot(sp2_series_alloyed_50yoy_gl.loc['20180101':], label='Ban Alloyed',color=colors[1])
pplot(sp2_series_no2_50yoy_gl.loc['20180101':], label='Ban No.2',color=colors[2])
pplot(sp2_series_both_50yoy_gl.loc['20180101':], label='Ban <99% Cu',color=colors[3])
plt.title('No.2 Scrap Spreads for Baseline and 50% YOY Scrap Bans')
plt.ylabel('No.2 scrap spread (USD/tonne)')

plt.figure()
pplot(sp2_series_both_50yoy_inc200_gl.loc['20180101':], label='+200 kt/yr',color=colors[1], firstcall=1)
pplot(sp2_series_both_50yoy_inc100_gl.loc['20180101':], label='+100 kt/yr',color=colors[2])
pplot(sp2_series_both_50yoy_gl.loc['20180101':], label='Refined imports stay constant',color=colors[0])
pplot(sp2_series_both_50yoy_dec100_gl.loc['20180101':], label='-100 kt/yr',color=colors[3])
pplot(sp2_series_both_50yoy_dec200_gl.loc['20180101':], label='-200 kt/yr',color=colors[4])
plt.title('No.2 Scrap Spreads for <99% Cu Scrap Ban \nSensitivity to Refined Imports')
plt.ylabel('No.2 scrap spread (USD/tonne)')

plt.figure()
pplot(sp2_series_both_75yoy_gl.loc['20180101':], label='25% YOY',color=colors[2])
pplot(sp2_series_both_50yoy_gl.loc['20180101':], label='50% YOY',color=colors[0])
pplot(sp2_series_both_25yoy_gl.loc['20180101':], label='75% YOY',color=colors[3])
plt.title('No.2 Scrap Spreads for <99% Cu Scrap Ban \nSensitivity to Scrap Ban Rate')
plt.ylabel('No.2 scrap spread (USD/tonne)')

# %%
fig, [ax1,ax2] = plt.subplots(1,2)
psubplot(ax1, cathode_price_series_pir_baseline.loc['20180101':] - sp2_series_pir_baseline_cn.loc['20180101':], label='Baseline',color='k', firstcall=1, width = 20)
psubplot(ax1, cathode_price_series_alloyed_50yoy.loc['20180101':] - sp2_series_alloyed_50yoy_cn.loc['20180101':], label='Ban Alloyed',color=colors[0])
psubplot(ax1, cathode_price_series_no2_50yoy.loc['20180101':] - sp2_series_no2_50yoy_cn.loc['20180101':], label='Ban No.2',color=colors[1])
psubplot(ax1, cathode_price_series_both_50yoy.loc['20180101':] - sp2_series_both_50yoy_cn.loc['20180101':], label='Ban <99% Cu',color=colors[2])
ax1.set_title('China No.2 Prices for Baseline and 50% YOY Scrap Bans')
ax1.set_ylabel('No.2 price (USD/tonne)')

psubplot(ax2, cathode_price_series_pir_baseline.loc['20180101':] - sp2_series_pir_baseline_rw.loc['20180101':], label='Baseline',color='k')
psubplot(ax2, cathode_price_series_alloyed_50yoy.loc['20180101':] - sp2_series_alloyed_50yoy_rw.loc['20180101':], label='Ban Alloyed',color=colors[0])
psubplot(ax2, cathode_price_series_no2_50yoy.loc['20180101':] - sp2_series_no2_50yoy_rw.loc['20180101':], label='Ban No.2',color=colors[1])
psubplot(ax2, cathode_price_series_both_50yoy.loc['20180101':] - sp2_series_both_50yoy_rw.loc['20180101':], label='Ban <99% Cu',color=colors[2])
ax2.set_title('RoW No.2 Prices for Baseline and 50% YOY Scrap Bans')
ax2.set_ylabel('No.2 price (USD/tonne)')

# %% [markdown]
# ### Zeng Price

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'

fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(sp2_series_pir_baseline_gl.loc['20180101':], label='Baseline',color=colors[0])
ax1.plot(sp2_series_ban_zeng_low_gl.loc['20180101':], label='Low',color=colors[2])
ax1.plot(sp2_series_ban_zeng_mean_gl.loc['20180101':], label='Mean',color=colors[1])
ax1.plot(sp2_series_ban_zeng_high_gl.loc['20180101':], label='High',color=colors[3])
ax1.set_title('No.2 Scrap Spreads for Zeng Paper Bans\nGlobal')
ax1.set_ylabel('No.2 scrap spread (USD/tonne)')
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(sp2_series_pir_baseline_cn.loc['20180101':], label='Baseline',color=colors[0])
ax2.plot(sp2_series_ban_zeng_low_cn.loc['20180101':], label='Low',color=colors[2])
ax2.plot(sp2_series_ban_zeng_mean_cn.loc['20180101':], label='Mean',color=colors[1])
ax2.plot(sp2_series_ban_zeng_high_cn.loc['20180101':], label='High',color=colors[3])
ax2.set_title('No.2 Scrap Spreads for Zeng Paper Bans\nChina')
ax2.set_ylabel('No.2 scrap spread (USD/tonne)')
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(sp2_series_pir_baseline_rw.loc['20180101':], label='Baseline',color=colors[0])
ax3.plot(sp2_series_ban_zeng_low_rw.loc['20180101':], label='Low',color=colors[2])
ax3.plot(sp2_series_ban_zeng_mean_rw.loc['20180101':], label='Mean',color=colors[1])
ax3.plot(sp2_series_ban_zeng_high_rw.loc['20180101':], label='High',color=colors[3])
ax3.set_title('No.2 Scrap Spreads for Zeng Paper Bans\nRest of World')
ax3.set_ylabel('No.2 scrap spread (USD/tonne)')
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %%
plt.figure()
pplot(cathode_price_series_pir_baseline.loc['20180101':], label='Baseline',color=colors[0], firstcall=1)
pplot(cathode_price_series_ban_zeng_low.loc['20180101':], label='Low',color=colors[2])
pplot(cathode_price_series_ban_zeng_mean.loc['20180101':], label='Mean',color=colors[1])
pplot(cathode_price_series_ban_zeng_high.loc['20180101':], label='High',color=colors[3])
plt.title('Cathode Price for Zeng Paper Bans')
plt.ylabel('Cathode price (USD/tonne)')

# %% [markdown]
# ### Fruity price data

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
axes(frameon=0)
grid(axis='y',color='0.9',linestyle='-',linewidth=1)



string = 'No. 2 and Yellow Brass Scrap Spread'
plt.plot(sp2_series_fruity1rr0_cn.loc['20100101':], label='0% Recycled Content',color=colors[2])
# plt.plot(sp2_series_fruity1rr11_cn.loc['20180101':], label='Baseline, 1% RR',color='tab:blue')
plt.plot(sp2_series_fruity1rr50_cn.loc['20180101':], label='Baseline, 50% RR',color=colors[0])
# plt.plot(sp2_series_fruity1rr90_cn.loc['20180101':], label='No.2 Ban No. 2 Spread',color='lightseagreen')
plt.plot(sp2_series_fruity1rr100_cn.loc['20180101':], label='Fruity 100 No. 2 Spread',color=colors[1])
plt.plot(spa_series_fruity1rr0_cn.loc['20100101':], ':', label='<94% Cu ban alloyed Spread',color=colors[2])
# plt.plot(spa_series_fruity1rr11_cn.loc['20180101':], '--', label='1% alloyed Spread',color='tab:blue')
plt.plot(spa_series_fruity1rr50_cn.loc['20180101':], ':', label='<99% Cu ban alloyed Spread',color=colors[0])
# plt.plot(spa_series_fruity1rr90_cn.loc['20180101':], '--', label='No.2 Ban alloyed Spread',color='lightseagreen')
plt.plot(spa_series_fruity1rr100_cn.loc['20180101':], ':', label='Fruity 100 alloyed Spread',color=colors[1])
plt.plot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [600, 4100], 'k--')

# legend = plt.legend(loc = 'lower right',handles=[Line2D([0],[0],color='k',label='0% Rec. Content'),\
#                     Line2D([0],[0],color=colors[0],label='50% Rec. Content'),\
#                     Line2D([0],[0],color=colors[1],label='100% Rec. Content')])
# #           prop={'size':9})
# # legend = plt.legend(loc='lower right')
# frame = legend.get_frame()
# frame.set_facecolor('1.0')
# frame.set_edgecolor('1.0')
# %config InlineBackend.figure_format ='retina'
plt.title(string+' Evolution')
# plt.xlabel('Year')
plt.yticks([1000,2000,3000,4000])
plt.ylabel('Scrap Spread (USD/tonne)')

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
axes(frameon=0)
grid(axis='y',color='0.9',linestyle='-',linewidth=1)



string = 'No. 2 and Yellow Brass Scrap Spread'
plt.plot(sp2_series_fruity1rr0_cn.loc['20100101':], label='0% Recycled Content',color=colors[2])
# plt.plot(sp2_series_fruity1rr11_cn.loc['20180101':], label='Baseline, 1% RR',color='tab:blue')
plt.plot(sp2_series_fruity1rr50_cn.loc['20180101':], label='Baseline, 50% RR',color=colors[0])
# plt.plot(sp2_series_fruity1rr90_cn.loc['20180101':], label='No.2 Ban No. 2 Spread',color='lightseagreen')
plt.plot(sp2_series_fruity1rr100_cn.loc['20180101':], label='Fruity 100 No. 2 Spread',color=colors[1])
plt.plot(spa_series_fruity1rr0_cn.loc['20100101':], ':', label='<94% Cu ban alloyed Spread',color=colors[2])
# plt.plot(spa_series_fruity1rr11_cn.loc['20180101':], '--', label='1% alloyed Spread',color='tab:blue')
plt.plot(spa_series_fruity1rr50_cn.loc['20180101':], ':', label='<99% Cu ban alloyed Spread',color=colors[0])
# plt.plot(spa_series_fruity1rr90_cn.loc['20180101':], '--', label='No.2 Ban alloyed Spread',color='lightseagreen')
plt.plot(spa_series_fruity1rr100_cn.loc['20180101':], ':', label='Fruity 100 alloyed Spread',color=colors[1])
plt.plot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [600, 4100], 'k--')

# legend = plt.legend(loc = 'lower right',handles=[Line2D([0],[0],color='k',label='0% Rec. Content'),\
#                     Line2D([0],[0],color=colors[0],label='50% Rec. Content'),\
#                     Line2D([0],[0],color=colors[1],label='100% Rec. Content')])
# #           prop={'size':9})
# # legend = plt.legend(loc='lower right')
# frame = legend.get_frame()
# frame.set_facecolor('1.0')
# frame.set_edgecolor('1.0')
# %config InlineBackend.figure_format ='retina'
plt.title('China '+string+' Evolution\n0.08% of Copper Market')
# plt.xlabel('Year')
plt.yticks([1000,2000,3000,4000])
plt.ylabel('Scrap Spread (USD/tonne)')

plt.figure()
axes(frameon=0)
grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass Scrap Spread'
plt.plot(sp2_series_fruity_pct1rr0_cn.loc['20100101':], label='0% Recycled Content',color=colors[2])
# plt.plot(sp2_series_fruity_pct1rr11_cn.loc['20180101':], label='Baseline, 1% RR',color='tab:blue')
plt.plot(sp2_series_fruity_pct1rr50_cn.loc['20180101':], label='Baseline, 50% RR',color=colors[0])
# plt.plot(sp2_series_fruity_pct1rr90_cn.loc['20180101':], label='No.2 Ban No. 2 Spread',color='lightseagreen')
plt.plot(sp2_series_fruity_pct1rr100_cn.loc['20180101':], label='Fruity 100 No. 2 Spread',color=colors[1])
plt.plot(spa_series_fruity_pct1rr0_cn.loc['20100101':], ':', label='<94% Cu ban alloyed Spread',color=colors[2])
# plt.plot(spa_series_fruity_pct1rr11_cn.loc['20180101':], '--', label='1% alloyed Spread',color='tab:blue')
plt.plot(spa_series_fruity_pct1rr50_cn.loc['20180101':], ':', label='<99% Cu ban alloyed Spread',color=colors[0])
# plt.plot(spa_series_fruity_pct1rr90_cn.loc['20180101':], '--', label='No.2 Ban alloyed Spread',color='lightseagreen')
plt.plot(spa_series_fruity_pct1rr100_cn.loc['20180101':], ':', label='Fruity 100 alloyed Spread',color=colors[1])
plt.plot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [600, 4100], 'k--')

# legend = plt.legend(loc = 'lower right',handles=[Line2D([0],[0],color='k',label='0% Rec. Content'),\
#                     Line2D([0],[0],color=colors[0],label='50% Rec. Content'),\
#                     Line2D([0],[0],color=colors[1],label='100% Rec. Content')])
# #           prop={'size':9})
# # legend = plt.legend(loc='lower right')
# frame = legend.get_frame()
# frame.set_facecolor('1.0')
# frame.set_edgecolor('1.0')
# %config InlineBackend.figure_format ='retina'
plt.title('China '+string+' Evolution\n1% of Copper Market')
# plt.xlabel('Year')
plt.yticks([1000,2000,3000,4000])
plt.ylabel('Scrap Spread (USD/tonne)')

plt.figure()
axes(frameon=0)
grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass Scrap Spread'
plt.plot(sp2_series_fruity_pct5rr0_cn.loc['20100101':], label='0% Recycled Content',color=colors[2])
# plt.plot(sp2_series_fruity_pct5rr11_cn.loc['20180101':], label='Baseline, 1% RR',color='tab:blue')
plt.plot(sp2_series_fruity_pct5rr50_cn.loc['20180101':], label='Baseline, 50% RR',color=colors[0])
# plt.plot(sp2_series_fruity_pct5rr90_cn.loc['20180101':], label='No.2 Ban No. 2 Spread',color='lightseagreen')
plt.plot(sp2_series_fruity_pct5rr100_cn.loc['20180101':], label='Fruity 100 No. 2 Spread',color=colors[1])
plt.plot(spa_series_fruity_pct5rr0_cn.loc['20100101':], ':', label='<94% Cu ban alloyed Spread',color=colors[2])
# plt.plot(spa_series_fruity_pct5rr11_cn.loc['20180101':], '--', label='1% alloyed Spread',color='tab:blue')
plt.plot(spa_series_fruity_pct5rr50_cn.loc['20180101':], ':', label='<99% Cu ban alloyed Spread',color=colors[0])
# plt.plot(spa_series_fruity_pct5rr90_cn.loc['20180101':], '--', label='No.2 Ban alloyed Spread',color='lightseagreen')
plt.plot(spa_series_fruity_pct5rr100_cn.loc['20180101':], ':', label='Fruity 100 alloyed Spread',color=colors[1])
plt.plot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [600, 4100], 'k--')

# legend = plt.legend(loc = 'lower right',handles=[Line2D([0],[0],color='k',label='0% Rec. Content'),\
#                     Line2D([0],[0],color=colors[0],label='50% Rec. Content'),\
#                     Line2D([0],[0],color=colors[1],label='100% Rec. Content')])
# #           prop={'size':9})
# # legend = plt.legend(loc='lower right')
# frame = legend.get_frame()
# frame.set_facecolor('1.0')
# frame.set_edgecolor('1.0')
# %config InlineBackend.figure_format ='retina'
plt.title('China '+string+' Evolution\n5% of Copper Market')
# plt.xlabel('Year')
plt.yticks([1000,2000,3000,4000])
plt.ylabel('Scrap Spread (USD/tonne)')

plt.figure()
axes(frameon=0)
grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass Scrap Spread'
plt.plot(sp2_series_fruity_pct10rr0_cn.loc['20100101':], label='0% Recycled Content',color=colors[2])
# plt.plot(sp2_series_fruity_pct10rr11_cn.loc['20180101':], label='Baseline, 1% RR',color='tab:blue')
plt.plot(sp2_series_fruity_pct10rr50_cn.loc['20180101':], label='Baseline, 50% RR',color=colors[0])
# plt.plot(sp2_series_fruity_pct10rr90_cn.loc['20180101':], label='No.2 Ban No. 2 Spread',color='lightseagreen')
plt.plot(sp2_series_fruity_pct10rr90_cn.loc['20180101':], label='Fruity 100 No. 2 Spread',color=colors[1])
plt.plot(spa_series_fruity_pct10rr0_cn.loc['20100101':], ':', label='<94% Cu ban alloyed Spread',color=colors[2])
# plt.plot(spa_series_fruity_pct10rr11_cn.loc['20180101':], '--', label='1% alloyed Spread',color='tab:blue')
plt.plot(spa_series_fruity_pct10rr50_cn.loc['20180101':], ':', label='<99% Cu ban alloyed Spread',color=colors[0])
# plt.plot(spa_series_fruity_pct10rr90_cn.loc['20180101':], '--', label='No.2 Ban alloyed Spread',color='lightseagreen')
plt.plot(spa_series_fruity_pct10rr90_cn.loc['20180101':], ':', label='Fruity 100 alloyed Spread',color=colors[1])
plt.plot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [600, 4100], 'k--')

# legend = plt.legend(loc = 'lower right',handles=[Line2D([0],[0],color='k',label='0% Rec. Content'),\
#                     Line2D([0],[0],color=colors[0],label='50% Rec. Content'),\
#                     Line2D([0],[0],color=colors[1],label='100% Rec. Content')])
# #           prop={'size':9})
# # legend = plt.legend(loc='lower right')
# frame = legend.get_frame()
# frame.set_facecolor('1.0')
# frame.set_edgecolor('1.0')
# %config InlineBackend.figure_format ='retina'
plt.title('China '+string+' Evolution\n10% of Copper Market')
plt.yticks([1000,2000,3000,4000])
# plt.xlabel('Year')
plt.ylabel('Scrap Spread (USD/tonne)')

# %%
init_plot()

string = 'No. 2 and Yellow Brass Scrap Prices'
plt.plot(cathode_price_series_fruity1rr0.loc['20180101':] - sp2_series_fruity1rr0_cn.loc['20180101':], color='k')
plt.plot(cathode_price_series_fruity1rr11.loc['20180101':] - sp2_series_fruity1rr11_cn.loc['20180101':], color='tab:blue')
plt.plot(cathode_price_series_fruity1rr50.loc['20180101':] - sp2_series_fruity1rr50_cn.loc['20180101':], color='tab:orange')
plt.plot(cathode_price_series_fruity1rr90.loc['20180101':] - sp2_series_fruity1rr90_cn.loc['20180101':], color='lightseagreen')
plt.plot(cathode_price_series_fruity1rr100.loc['20180101':] - sp2_series_fruity1rr100_cn.loc['20180101':], color='tab:gray')
plt.plot(cathode_price_series_fruity1rr0.loc['20180101':] - spa_series_fruity1rr0_cn.loc['20180101':], '--', color='k')
plt.plot(cathode_price_series_fruity1rr11.loc['20180101':] - spa_series_fruity1rr11_cn.loc['20180101':], '--', color='tab:blue')
plt.plot(cathode_price_series_fruity1rr50.loc['20180101':] - spa_series_fruity1rr50_cn.loc['20180101':], '--', color='tab:orange')
plt.plot(cathode_price_series_fruity1rr90.loc['20180101':] - spa_series_fruity1rr90_cn.loc['20180101':], '--', color='lightseagreen')
plt.plot(cathode_price_series_fruity1rr100.loc['20180101':] - spa_series_fruity1rr100_cn.loc['20180101':], '--', color='tab:gray')

plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color='tab:blue',label='Fruity 1X 1% RR'),\
                    Line2D([0],[0],color='tab:orange',label='Fruity 1X 50% RR'),\
                    Line2D([0],[0],color='lightseagreen',label='Fruity 1X 90% RR'),\
                    Line2D([0],[0], color='tab:gray',label='Fruity 1X 100% RR')],\
          prop={'size':9})
plt.title('Fruity RR Scenarios 1X\nAnnual '+string+' (USD/t)\nRest of World, Difference above Baseline')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')

plt.figure()
string = 'No. 2 and Yellow Brass Scrap Prices'
plt.plot(cathode_price_series_fruity_pct1rr0.loc['20180101':] - sp2_series_fruity_pct1rr0_cn.loc['20180101':], color='k')
plt.plot(cathode_price_series_fruity_pct1rr11.loc['20180101':] - sp2_series_fruity_pct1rr11_cn.loc['20180101':], color='tab:blue')
plt.plot(cathode_price_series_fruity_pct1rr50.loc['20180101':] - sp2_series_fruity_pct1rr50_cn.loc['20180101':], color='tab:orange')
plt.plot(cathode_price_series_fruity_pct1rr90.loc['20180101':] - sp2_series_fruity_pct1rr90_cn.loc['20180101':], color='lightseagreen')
plt.plot(cathode_price_series_fruity_pct1rr100.loc['20180101':] - sp2_series_fruity_pct1rr100_cn.loc['20180101':], color='tab:gray')
plt.plot(cathode_price_series_fruity_pct1rr0.loc['20180101':] - spa_series_fruity_pct1rr0_cn.loc['20180101':], '--', color='k')
plt.plot(cathode_price_series_fruity_pct1rr11.loc['20180101':] - spa_series_fruity_pct1rr11_cn.loc['20180101':], '--', color='tab:blue')
plt.plot(cathode_price_series_fruity_pct1rr50.loc['20180101':] - spa_series_fruity_pct1rr50_cn.loc['20180101':], '--', color='tab:orange')
plt.plot(cathode_price_series_fruity_pct1rr90.loc['20180101':] - spa_series_fruity_pct1rr90_cn.loc['20180101':], '--', color='lightseagreen')
plt.plot(cathode_price_series_fruity_pct1rr100.loc['20180101':] - spa_series_fruity_pct1rr100_cn.loc['20180101':], '--', color='tab:gray')

plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color='tab:blue',label='Fruity 1mkt% 1% RR'),\
                    Line2D([0],[0],color='tab:orange',label='Fruity 1mkt% 50% RR'),\
                    Line2D([0],[0],color='lightseagreen',label='Fruity 1mkt% 90% RR'),\
                    Line2D([0],[0], color='tab:gray',label='Fruity 1mkt% 100% RR')],\
          prop={'size':9})
plt.title('Fruity RR Scenarios 1mkt%\nAnnual '+string+' (USD/t)\nRest of World, Difference above Baseline')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')

plt.figure()
string = 'No. 2 and Yellow Brass Scrap Prices'
plt.plot(cathode_price_series_fruity_pct5rr0.loc['20180101':] - sp2_series_fruity_pct5rr0_cn.loc['20180101':], color='k')
plt.plot(cathode_price_series_fruity_pct5rr11.loc['20180101':] - sp2_series_fruity_pct5rr11_cn.loc['20180101':], color='tab:blue')
plt.plot(cathode_price_series_fruity_pct5rr50.loc['20180101':] - sp2_series_fruity_pct5rr50_cn.loc['20180101':], color='tab:orange')
plt.plot(cathode_price_series_fruity_pct5rr90.loc['20180101':] - sp2_series_fruity_pct5rr90_cn.loc['20180101':], color='lightseagreen')
plt.plot(cathode_price_series_fruity_pct5rr100.loc['20180101':] - sp2_series_fruity_pct5rr100_cn.loc['20180101':], color='tab:gray')
plt.plot(cathode_price_series_fruity_pct5rr0.loc['20180101':] - spa_series_fruity_pct5rr0_cn.loc['20180101':], '--', color='k')
plt.plot(cathode_price_series_fruity_pct5rr11.loc['20180101':] - spa_series_fruity_pct5rr11_cn.loc['20180101':], '--', color='tab:blue')
plt.plot(cathode_price_series_fruity_pct5rr50.loc['20180101':] - spa_series_fruity_pct5rr50_cn.loc['20180101':], '--', color='tab:orange')
plt.plot(cathode_price_series_fruity_pct5rr90.loc['20180101':] - spa_series_fruity_pct5rr90_cn.loc['20180101':], '--', color='lightseagreen')
plt.plot(cathode_price_series_fruity_pct5rr100.loc['20180101':] - spa_series_fruity_pct5rr100_cn.loc['20180101':], '--', color='tab:gray')

plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color='tab:blue',label='Fruity 5mkt% 1% RR'),\
                    Line2D([0],[0],color='tab:orange',label='Fruity 5mkt% 50% RR'),\
                    Line2D([0],[0],color='lightseagreen',label='Fruity 5mkt% 90% RR'),\
                    Line2D([0],[0], color='tab:gray',label='Fruity 5mkt% 100% RR')],\
          prop={'size':9})
plt.title('Fruity RR Scenarios 5mkt%\nAnnual '+string+' (USD/t)\nRest of World, Difference above Baseline')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')

plt.figure()
string = 'No. 2 and Yellow Brass Scrap Prices'
plt.plot(cathode_price_series_fruity_pct10rr0.loc['20180101':] - sp2_series_fruity_pct10rr0_cn.loc['20180101':], color='k')
plt.plot(cathode_price_series_fruity_pct10rr11.loc['20180101':] - sp2_series_fruity_pct10rr11_cn.loc['20180101':], color='tab:blue')
plt.plot(cathode_price_series_fruity_pct10rr50.loc['20180101':] - sp2_series_fruity_pct10rr50_cn.loc['20180101':], color='tab:orange')
plt.plot(cathode_price_series_fruity_pct10rr70.loc['20180101':] - sp2_series_fruity_pct10rr70_cn.loc['20180101':], color='lightseagreen')
plt.plot(cathode_price_series_fruity_pct10rr90.loc['20180101':] - sp2_series_fruity_pct10rr90_cn.loc['20180101':], color='tab:gray')
plt.plot(cathode_price_series_fruity_pct10rr0.loc['20180101':] - spa_series_fruity_pct10rr0_cn.loc['20180101':], '--', color='k')
plt.plot(cathode_price_series_fruity_pct10rr11.loc['20180101':] - spa_series_fruity_pct10rr11_cn.loc['20180101':], '--', color='tab:blue')
plt.plot(cathode_price_series_fruity_pct10rr50.loc['20180101':] - spa_series_fruity_pct10rr50_cn.loc['20180101':], '--', color='tab:orange')
plt.plot(cathode_price_series_fruity_pct10rr70.loc['20180101':] - spa_series_fruity_pct10rr70_cn.loc['20180101':], '--', color='lightseagreen')
plt.plot(cathode_price_series_fruity_pct10rr90.loc['20180101':] - spa_series_fruity_pct10rr90_cn.loc['20180101':], '--', color='tab:gray')

plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color='tab:blue',label='Fruity 10mkt% 1% RR'),\
                    Line2D([0],[0],color='tab:orange',label='Fruity 10mkt% 50% RR'),\
                    Line2D([0],[0],color='lightseagreen',label='Fruity 10mkt% 70% RR'),\
                    Line2D([0],[0], color='tab:gray',label='Fruity 10mkt% 90% RR')],\
          prop={'size':9})
plt.title('Fruity RR Scenarios\nAnnual '+string+' (USD/t)\nRest of World, Difference above Baseline')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')

# %% [markdown]
# Fruity minimum recycled content change from baseline

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)

plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':] - sp2_series_fruity1rr0var0_gl.loc['20180101':], label = 'None', color='k')
plt.plot(cathode_price_series_fruity1rr100var0.loc['20180101':] - sp2_series_fruity1rr100var0_gl.loc['20180101':], label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':] - sp2_series_fruity1rr100var30_gl.loc['20180101':], label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':] - sp2_series_fruity1rr100var70_gl.loc['20180101':], label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var90.loc['20180101':] - sp2_series_fruity1rr100var90_gl.loc['20180101':], label = 'None', color=colors[3])
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':] - spa_series_fruity1rr0var0_gl.loc['20180101':], '--', label = 'None', color='k')
plt.plot(cathode_price_series_fruity1rr100var0.loc['20180101':] - spa_series_fruity1rr100var0_gl.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':] - spa_series_fruity1rr100var30_gl.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':] - spa_series_fruity1rr100var70_gl.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var90.loc['20180101':] - spa_series_fruity1rr100var90_gl.loc['20180101':], '--', label = 'None', color=colors[3])


legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 1X var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 1X var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 1X var70'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 1X var90')])
plt.suptitle('Global No.2 and Yellow Brass Scrap Prices')
plt.title('0.08% of Copper Market', color = color_08)
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'


plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':] - sp2_series_fruity_pct10rr0_1_gl.loc['20180101':], label = 'None', color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':] - sp2_series_fruity_pct10rr50var10_gl.loc['20180101':], label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':] - sp2_series_fruity_pct10rr50var30_gl.loc['20180101':], label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':] - sp2_series_fruity_pct10rr50var50_gl.loc['20180101':], label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':] - sp2_series_fruity_pct10rr50var70_gl.loc['20180101':], label = 'None', color=colors[3])
plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':] - spa_series_fruity_pct10rr0_1_gl.loc['20180101':], '--', label = 'None', color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':] - spa_series_fruity_pct10rr50var10_gl.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':] - spa_series_fruity_pct10rr50var30_gl.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':] - spa_series_fruity_pct10rr50var50_gl.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':] - spa_series_fruity_pct10rr50var70_gl.loc['20180101':], '--', label = 'None', color=colors[3])

legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 10mkt% var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 10mkt% var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 10mkt% var50'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 10mkt% var70')])
plt.suptitle('Global No.2 and Yellow Brass Scrap Prices')
plt.title('10% of Copper Market', color = color_10)
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# Cathode and SP2 for 0.08% of market, regional and global

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)

plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':] - sp2_series_fruity1rr0var0_gl.loc['20180101':], '--', label = 'None', color='k')
plt.plot(cathode_price_series_fruity1rr100var10.loc['20180101':] - sp2_series_fruity1rr100var10_gl.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':] - sp2_series_fruity1rr100var30_gl.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var50.loc['20180101':] - sp2_series_fruity1rr100var50_gl.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':] - sp2_series_fruity1rr100var70_gl.loc['20180101':], '--', label = 'None', color=colors[3])
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':], label = 'None', color='k')
plt.plot(cathode_price_series_fruity1rr100var10.loc['20180101':], label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':], label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var50.loc['20180101':], label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':], label = 'None', color=colors[3])

legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 10mkt% var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 10mkt% var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 10mkt% var50'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 10mkt% var70')])
plt.ylim(5000,7500)
plt.suptitle('Global Cathode and No.2 Scrap Prices')
plt.title('0.08% of Copper Market', color = color_08)
# plt.xlabel('Year')
plt.ylabel('Annual cathode and No.2 scrap prices (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'
plt.ylim(ylims_gl)

plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':] - sp2_series_fruity1rr0var0_cn.loc['20180101':], '--', label = 'None', color='k')
plt.plot(cathode_price_series_fruity1rr100var10.loc['20180101':] - sp2_series_fruity1rr100var10_cn.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':] - sp2_series_fruity1rr100var30_cn.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var50.loc['20180101':] - sp2_series_fruity1rr100var50_cn.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':] - sp2_series_fruity1rr100var70_cn.loc['20180101':], '--', label = 'None', color=colors[3])

legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 10mkt% var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 10mkt% var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 10mkt% var50'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 10mkt% var70')])
plt.suptitle('China No.2 Scrap Prices')
plt.title('0.08% of Copper Market', color = color_08)
# plt.xlabel('Year')
plt.ylabel('Annual No.2 scrap prices (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'
plt.ylim(ylims_cn)

plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':] - sp2_series_fruity1rr0var0_rw.loc['20180101':], '--', label = 'None', color='k')
plt.plot(cathode_price_series_fruity1rr100var10.loc['20180101':] - sp2_series_fruity1rr100var10_rw.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':] - sp2_series_fruity1rr100var30_rw.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var50.loc['20180101':] - sp2_series_fruity1rr100var50_rw.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':] - sp2_series_fruity1rr100var70_rw.loc['20180101':], '--', label = 'None', color=colors[3])

legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 10mkt% var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 10mkt% var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 10mkt% var50'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 10mkt% var70')])
plt.suptitle('Rest of World No.2 Scrap Prices')
plt.title('0.08% of Copper Market', color = color_08)
# plt.xlabel('Year')
plt.ylabel('Annual No.2 scrap prices (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'
plt.ylim(ylims_rw)

# %% [markdown]
# Cathode and scrap prices for 10% of market, global and regional

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)

plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':] - sp2_series_fruity_pct10rr0_1_gl.loc['20180101':], '--', label = 'None', color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':] - sp2_series_fruity_pct10rr50var10_gl.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':] - sp2_series_fruity_pct10rr50var30_gl.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':] - sp2_series_fruity_pct10rr50var50_gl.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':] - sp2_series_fruity_pct10rr50var70_gl.loc['20180101':], '--', label = 'None', color=colors[3])
plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':], label = 'None', color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':], label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':], label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':], label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':], label = 'None', color=colors[3])

legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 10mkt% var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 10mkt% var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 10mkt% var50'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 10mkt% var70')])
plt.suptitle('Global Cathode and No.2 Scrap Prices')
plt.title('10% of Copper Market', color = color_10)
# plt.xlabel('Year')
plt.ylabel('Annual cathode and No.2 scrap prices (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'
ylims_gl = plt.ylim()

plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':] - sp2_series_fruity_pct10rr0_1_cn.loc['20180101':], '--', label = 'None', color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':] - sp2_series_fruity_pct10rr50var10_cn.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':] - sp2_series_fruity_pct10rr50var30_cn.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':] - sp2_series_fruity_pct10rr50var50_cn.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':] - sp2_series_fruity_pct10rr50var70_cn.loc['20180101':], '--', label = 'None', color=colors[3])

plt.suptitle('China No.2 Scrap Prices')
plt.title('10% of Copper Market', color = color_10)
# plt.xlabel('Year')
plt.ylabel('Annual No.2 scrap prices (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'
ylims_cn = plt.ylim()

plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':] - sp2_series_fruity_pct10rr0_1_rw.loc['20180101':], '--', label = 'None', color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':] - sp2_series_fruity_pct10rr50var10_rw.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':] - sp2_series_fruity_pct10rr50var30_rw.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':] - sp2_series_fruity_pct10rr50var50_rw.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':] - sp2_series_fruity_pct10rr50var70_rw.loc['20180101':], '--', label = 'None', color=colors[3])

plt.suptitle('Rest of World No.2 Scrap Prices')
plt.title('10% of Copper Market', color = color_10)
# plt.xlabel('Year')
plt.ylabel('Annual No.2 scrap prices (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'
ylims_rw = plt.ylim()

# %% [markdown]
# Cathode and scrap prices for 10% of market, global and regional - difference from baseline

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)

### Global cathode price difference from baseline, 0.08%
plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices Difference from Baseline'
plt.plot(100*(cathode_price_series_fruity1rr100var10.loc['20180101':] - cathode_price_series_fruity1rr0var0.loc['20180101':]) / cathode_price_series_fruity1rr0var0.loc['20200101'], label = 'var10', color=colors[0])
plt.plot(100*(cathode_price_series_fruity1rr100var30.loc['20180101':] - cathode_price_series_fruity1rr0var0.loc['20180101':]) / cathode_price_series_fruity1rr0var0.loc['20200101'], label = 'var30', color=colors[1])
plt.plot(100*(cathode_price_series_fruity1rr100var50.loc['20180101':] - cathode_price_series_fruity1rr0var0.loc['20180101':]) / cathode_price_series_fruity1rr0var0.loc['20200101'], label = 'var50', color=colors[2])
plt.plot(100*(cathode_price_series_fruity1rr100var70.loc['20180101':] - cathode_price_series_fruity1rr0var0.loc['20180101':]) / cathode_price_series_fruity1rr0var0.loc['20200101'], label = 'var70', color=colors[3])

plt.ylim(-5,5)
legend = plt.legend()
plt.suptitle('Global Cathode Price Difference above Baseline')
plt.title('0.08% of Copper Market', color = color_08)
# plt.xlabel('Year')
plt.ylabel('Annual cathode prices difference above baseline \n(% of 2020 cathode price)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'

### Global cathode price difference from baseline, 10% for the rest in this cell
plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices Difference from Baseline'
plt.plot(100*(cathode_price_series_fruity_pct10rr50var10.loc['20180101':] - cathode_price_series_fruity_pct10rr0_1.loc['20180101':]) / cathode_price_series_fruity_pct10rr0_1.loc['20200101'], label = 'var10', color=colors[0])
plt.plot(100*(cathode_price_series_fruity_pct10rr50var30.loc['20180101':] - cathode_price_series_fruity_pct10rr0_1.loc['20180101':]) / cathode_price_series_fruity_pct10rr0_1.loc['20200101'], label = 'var30', color=colors[1])
plt.plot(100*(cathode_price_series_fruity_pct10rr50var50.loc['20180101':] - cathode_price_series_fruity_pct10rr0_1.loc['20180101':]) / cathode_price_series_fruity_pct10rr0_1.loc['20200101'], label = 'var50', color=colors[2])
plt.plot(100*(cathode_price_series_fruity_pct10rr50var70.loc['20180101':] - cathode_price_series_fruity_pct10rr0_1.loc['20180101':]) / cathode_price_series_fruity_pct10rr0_1.loc['20200101'], label = 'var70', color=colors[3])

plt.ylim(-5,5)
legend = plt.legend()
plt.suptitle('Global Cathode Price Difference above Baseline')
plt.title('10% of Copper Market', color = color_10)
# plt.xlabel('Year')
plt.ylabel('Annual cathode prices difference above baseline \n(% of 2020 cathode price)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'

#### Global scrap price difference from baseline
plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices Difference from Baseline'
plt.plot(sp2_series_fruity_pct10rr0_1_gl.loc['20180101':] - sp2_series_fruity_pct10rr50var10_gl.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(sp2_series_fruity_pct10rr0_1_gl.loc['20180101':] - sp2_series_fruity_pct10rr50var30_gl.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(sp2_series_fruity_pct10rr0_1_gl.loc['20180101':] - sp2_series_fruity_pct10rr50var50_gl.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(sp2_series_fruity_pct10rr0_1_gl.loc['20180101':] - sp2_series_fruity_pct10rr50var70_gl.loc['20180101':], '--', label = 'None', color=colors[3])

plt.suptitle('Global No.2 Scrap Prices Difference from Baseline')
plt.title('10% of Copper Market', color = color_10)
# plt.xlabel('Year')
plt.ylabel('Annual No.2 scrap prices difference from baseline (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'

### China scrap price difference from baseline
plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices Difference from Baseline'
plt.plot(sp2_series_fruity_pct10rr0_1_cn.loc['20180101':] - sp2_series_fruity_pct10rr50var10_cn.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(sp2_series_fruity_pct10rr0_1_cn.loc['20180101':] - sp2_series_fruity_pct10rr50var30_cn.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(sp2_series_fruity_pct10rr0_1_cn.loc['20180101':] - sp2_series_fruity_pct10rr50var50_cn.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(sp2_series_fruity_pct10rr0_1_cn.loc['20180101':] - sp2_series_fruity_pct10rr50var70_cn.loc['20180101':], '--', label = 'None', color=colors[3])

plt.suptitle('China No.2 Scrap Prices Difference from Baseline')
plt.title('10% of Copper Market', color = color_10)
# plt.xlabel('Year')
plt.ylabel('Annual No.2 scrap prices difference from baseline (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'

#### RoW scrap price difference from baseline
plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices Difference from Baseline'
plt.plot(sp2_series_fruity_pct10rr0_1_rw.loc['20180101':] - sp2_series_fruity_pct10rr50var10_rw.loc['20180101':], '--', label = 'None', color=colors[0])
plt.plot(sp2_series_fruity_pct10rr0_1_rw.loc['20180101':] - sp2_series_fruity_pct10rr50var30_rw.loc['20180101':], '--', label = 'None', color=colors[1])
plt.plot(sp2_series_fruity_pct10rr0_1_rw.loc['20180101':] - sp2_series_fruity_pct10rr50var50_rw.loc['20180101':], '--', label = 'None', color=colors[2])
plt.plot(sp2_series_fruity_pct10rr0_1_rw.loc['20180101':] - sp2_series_fruity_pct10rr50var70_rw.loc['20180101':], '--', label = 'None', color=colors[3])

plt.suptitle('Rest of World No.2 Scrap Prices Difference from Baseline')
plt.title('10% of Copper Market', color = color_10)
# plt.xlabel('Year')
plt.ylabel('Annual No.2 scrap prices difference from baseline (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# TCRC for 0.08% and 10% of market - regular and difference from baseline

# %%
### TCRC, 0.08%
plt.figure()
pplot(tcrc_series_fruity1rr0var0.loc['20180101':], label = 'Baseline', color='k', firstcall=1)
pplot(tcrc_series_fruity1rr100var10.loc['20180101':], label = 'var10', color=colors[0])
pplot(tcrc_series_fruity1rr100var30.loc['20180101':], label = 'var30', color=colors[1])
pplot(tcrc_series_fruity1rr100var50.loc['20180101':], label = 'var50', color=colors[2])
pplot(tcrc_series_fruity1rr100var70.loc['20180101':], label = 'var70', color=colors[3])

# plt.ylim(-300,300)
plt.suptitle('Global TCRC Evolution')
plt.title('0.08% of Copper Market', color = color_08)
plt.ylabel('Annual TCRC \nDifference from baseline (USD/t)')
plt.legend().set_visible(False)


### TCRC difference from baseline, 0.08%
plt.figure()
pplot((tcrc_series_fruity1rr100var10.loc['20180101':] - tcrc_series_fruity1rr0var0.loc['20180101':]) / tcrc_series_fruity1rr0var0.loc['20200101'] * 100, label = 'var10', color=colors[0], firstcall=1)
pplot((tcrc_series_fruity1rr100var30.loc['20180101':] - tcrc_series_fruity1rr0var0.loc['20180101':]) / tcrc_series_fruity1rr0var0.loc['20200101'] * 100, label = 'var30', color=colors[1])
pplot((tcrc_series_fruity1rr100var50.loc['20180101':] - tcrc_series_fruity1rr0var0.loc['20180101':]) / tcrc_series_fruity1rr0var0.loc['20200101'] * 100, label = 'var50', color=colors[2])
pplot((tcrc_series_fruity1rr100var70.loc['20180101':] - tcrc_series_fruity1rr0var0.loc['20180101':]) / tcrc_series_fruity1rr0var0.loc['20200101'] * 100, label = 'var70', color=colors[3])

plt.ylim(-5.5,13.9)
plt.yticks([-5,0,5,10])
plt.suptitle('Global TCRC Difference from Baseline')
plt.title('0.08% of Copper Market', color = color_08)
plt.ylabel('Annual TCRC \nDifference from Baseline (% of 2020 TCRC)')
plt.legend().set_visible(False)

### TCRC  10% for the rest in this cell
plt.figure()
pplot(tcrc_series_fruity_pct10rr0_1.loc['20180101':], label = 'Baseline', color='k', firstcall=1)
pplot(tcrc_series_fruity_pct10rr50var10.loc['20180101':], label = 'var10', color=colors[0])
pplot(tcrc_series_fruity_pct10rr50var30.loc['20180101':], label = 'var30', color=colors[1])
pplot(tcrc_series_fruity_pct10rr50var50.loc['20180101':], label = 'var50', color=colors[2])
pplot(tcrc_series_fruity_pct10rr50var70.loc['20180101':], label = 'var70', color=colors[3])

plt.suptitle('Global TCRC Evolution')
plt.title('10% of Copper Market', color = color_10)
plt.ylabel('Annual TCRC (USD/t)')
plt.legend().set_visible(False)

### TCRC difference from baseline, 10% 
plt.figure()
pplot((tcrc_series_fruity_pct10rr50var10.loc['20180101':] - tcrc_series_fruity_pct10rr0_1.loc['20180101':]) / tcrc_series_fruity_pct10rr0_1.loc['20200101'] * 100, label = 'var10', color=colors[0], firstcall=1)
pplot((tcrc_series_fruity_pct10rr50var30.loc['20180101':] - tcrc_series_fruity_pct10rr0_1.loc['20180101':]) / tcrc_series_fruity_pct10rr0_1.loc['20200101'] * 100, label = 'var30', color=colors[1])
pplot((tcrc_series_fruity_pct10rr50var50.loc['20180101':] - tcrc_series_fruity_pct10rr0_1.loc['20180101':]) / tcrc_series_fruity_pct10rr0_1.loc['20200101'] * 100, label = 'var50', color=colors[2])
pplot((tcrc_series_fruity_pct10rr50var70.loc['20180101':] - tcrc_series_fruity_pct10rr0_1.loc['20180101':]) / tcrc_series_fruity_pct10rr0_1.loc['20200101'] * 100, label = 'var70', color=colors[3])

plt.ylim(-5.5,13.9)
plt.yticks([-5,0,5,10])
plt.suptitle('Global TCRC Difference from Baseline')
plt.title('10% of Copper Market', color = color_10)
plt.ylabel('Annual TCRC \nDifference from baseline (% of 2020 TCRC)')
plt.legend().set_visible(False)

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)

plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':], label='None', color='k')
plt.plot(cathode_price_series_fruity1rr100var0.loc['20180101':], label='None', color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':], label='None', color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':], label='None', color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var90.loc['20180101':], label='None', color=colors[3])
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':], '--', label='None', color='k')
plt.plot(cathode_price_series_fruity1rr100var0.loc['20180101':], '--', label='None', color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':], '--', label='None', color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':], '--', label='None', color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var90.loc['20180101':], '--', label='None', color=colors[3])


legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 1X var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 1X var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 1X var70'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 1X var90')])
plt.title('Global Scrap Prices\n0.08% of Copper Market')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'


plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':], label='None', color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':], label='None', color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':], label='None', color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':], label='None', color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':], label='None', color=colors[3])
plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':], '--', label='None', color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':], '--', label='None', color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':], '--', label='None', color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':], '--', label='None', color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':], '--', label='None', color=colors[3])

legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 10mkt% var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 10mkt% var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 10mkt% var50'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 10mkt% var70')])
plt.title('Global Scrap Prices\n10% of Copper Market')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)

plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':] - sp2_series_fruity1rr0var0_cn.loc['20180101':], color='k')
plt.plot(cathode_price_series_fruity1rr100var0.loc['20180101':] - sp2_series_fruity1rr100var0_cn.loc['20180101':], color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':] - sp2_series_fruity1rr100var30_cn.loc['20180101':], color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':] - sp2_series_fruity1rr100var70_cn.loc['20180101':], color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var90.loc['20180101':] - sp2_series_fruity1rr100var90_cn.loc['20180101':], color=colors[3])
plt.plot(cathode_price_series_fruity1rr0var0.loc['20180101':] - spa_series_fruity1rr0var0_cn.loc['20180101':], '--', color='k')
plt.plot(cathode_price_series_fruity1rr100var0.loc['20180101':] - spa_series_fruity1rr100var0_cn.loc['20180101':], '--', color=colors[0])
plt.plot(cathode_price_series_fruity1rr100var30.loc['20180101':] - spa_series_fruity1rr100var30_cn.loc['20180101':], '--', color=colors[1])
plt.plot(cathode_price_series_fruity1rr100var70.loc['20180101':] - spa_series_fruity1rr100var70_cn.loc['20180101':], '--', color=colors[2])
plt.plot(cathode_price_series_fruity1rr100var90.loc['20180101':] - spa_series_fruity1rr100var90_cn.loc['20180101':], '--', color=colors[3])


legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 1X var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 1X var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 1X var70'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 1X var90')])
plt.title('           Scrap Prices\n0.08% of Copper Market')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
plt.text(pd.datetime(2024,2,1),5965,'China',fontsize=20,color='red')
# %config InlineBackend.figure_format ='retina'


plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
string = 'No. 2 and Yellow Brass \nScrap Prices'
plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':] - sp2_series_fruity_pct10rr0_1_cn.loc['20180101':], color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':] - sp2_series_fruity_pct10rr50var10_cn.loc['20180101':], color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':] - sp2_series_fruity_pct10rr50var30_cn.loc['20180101':], color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':] - sp2_series_fruity_pct10rr50var50_cn.loc['20180101':], color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':] - sp2_series_fruity_pct10rr50var70_cn.loc['20180101':], color=colors[3])
plt.plot(cathode_price_series_fruity_pct10rr0_1.loc['20180101':] - spa_series_fruity_pct10rr0_1_cn.loc['20180101':], '--', color='k')
plt.plot(cathode_price_series_fruity_pct10rr50var10.loc['20180101':] - spa_series_fruity_pct10rr50var10_cn.loc['20180101':], '--', color=colors[0])
plt.plot(cathode_price_series_fruity_pct10rr50var30.loc['20180101':] - spa_series_fruity_pct10rr50var30_cn.loc['20180101':], '--', color=colors[1])
plt.plot(cathode_price_series_fruity_pct10rr50var50.loc['20180101':] - spa_series_fruity_pct10rr50var50_cn.loc['20180101':], '--', color=colors[2])
plt.plot(cathode_price_series_fruity_pct10rr50var70.loc['20180101':] - spa_series_fruity_pct10rr50var70_cn.loc['20180101':], '--', color=colors[3])

legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 10mkt% var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 10mkt% var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 10mkt% var50'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 10mkt% var70')])
plt.title('           Scrap Prices\n10% of Copper Market')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
plt.text(pd.datetime(2024,2,1),6668,'China',fontsize=20,color='red')
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# TCRC for 0.08% and 10% of market given rest of market restrictions

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5.5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)

plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
plt.plot(tcrc_series_fruity1rr0var0.loc['20180101':], label='None', color='k')
plt.plot(tcrc_series_fruity1rr100var10.loc['20180101':], label='None', color=colors[0])
plt.plot(tcrc_series_fruity1rr100var30.loc['20180101':], label='None', color=colors[1])
plt.plot(tcrc_series_fruity1rr100var50.loc['20180101':], label='None', color=colors[2])
plt.plot(tcrc_series_fruity1rr100var70.loc['20180101':], label='None', color=colors[3])

legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 1X var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 1X var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 1X var70'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 1X var90')])
plt.suptitle('Global Treatment and Refining Charges')
plt.title('0.08% of Copper Market',color=color_08)
plt.xlabel('Year')
plt.ylabel('Annual TCRC (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'


plt.figure()
plt.axes(frameon=0)
plt.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
plt.plot(tcrc_series_fruity_pct10rr0_1.loc['20180101':], label='None', color='k')
plt.plot(tcrc_series_fruity_pct10rr50var10.loc['20180101':], label='None', color=colors[0])
plt.plot(tcrc_series_fruity_pct10rr50var30.loc['20180101':], label='None', color=colors[1])
plt.plot(tcrc_series_fruity_pct10rr50var50.loc['20180101':], label='None', color=colors[2])
plt.plot(tcrc_series_fruity_pct10rr50var70.loc['20180101':], label='None', color=colors[3])

legend = plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='No.2 Spread:\n(Dashed, Same Colors for Yellow Brass Scrap Prices)'),\
                    Line2D([0],[0],color=colors[0],label='Fruity 10mkt% var0'),\
                    Line2D([0],[0],color=colors[1],label='Fruity 10mkt% var30'),\
                    Line2D([0],[0],color=colors[2],label='Fruity 10mkt% var50'),\
                    Line2D([0],[0],color=colors[3],label='Fruity 10mkt% var70')])
plt.suptitle('Global Treatment and Refining Charges')
plt.title('10% of Copper Market',color=color_10)
plt.xlabel('Year')
plt.ylabel('Annual TCRC (USD/t)')
frame = legend.get_frame()
frame.set_facecolor('1.0')
frame.set_edgecolor('1.0')
plt.legend().set_visible(False)
# %config InlineBackend.figure_format ='retina'

# %%
sd_pir_baseline

# %%
# pplot(tcrc_series_baseline_baseline.loc['20000101':], label='Baseline TCRC')
# pplot(tcrc_series_sp2hi20yr.loc['20000101':], label='TCRC')

pplot(cathode_price_series_baseline_baseline.loc['20000101':], label='Baseline Cathode Price')
pplot(cathode_price_series_sp2hi20yr.loc['20000101':], label='Cathode Price')

# pplot(sp2_series_baseline_baseline.loc['20000101':], label='Baseline No. 2 Spread')
# pplot(sp2_series_sp2hi20yr.loc['20000101':], label='No. 2 Spread',color='b')

# pplot(tcrc_series_baseline_irs100.loc['20180101':], label='100%')

pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 10000], 'k--')
plt.legend()
# plt.title('Prices for Linear Approach to 20% Base Shock')
plt.xlabel('Year')
plt.ylabel('Annual Price (USD/t)')
plt.show()

# %% [markdown]
# ### Price Response for Linear Approaches

# %%
string = 'TCRC'
pplot(tcrc_series_lin1yr.loc['20180101':], label='1year TCRC',color='tab:blue')
pplot(tcrc_series_lin5yr.loc['20180101':], label='5year TCRC',color='tab:orange')
pplot(tcrc_series_lin10yr.loc['20180101':], label='10year TCRC',color='lightseagreen')
pplot(tcrc_series_lin20yr.loc['20180101':], label='20year TCRC',color='tab:brown')

# string = 'Cathode Price'
# pplot(cathode_price_series_lin1yr.loc['19910101':], label='1year Cathode Price',color='tab:blue')
# pplot(cathode_price_series_lin5yr.loc['20180101':], label='5year Cathode Price',color='tab:orange')
# pplot(cathode_price_series_lin10yr.loc['20180101':], label='10year Cathode Price',color='lightseagreen')
# pplot(cathode_price_series_lin20yr.loc['20180101':], label='20year Cathode Price',color='tab:brown')

# string = 'No. 2 Scrap Spread'
# pplot(sp2_series_lin1yr.loc['19910101':], label='1year No. 2 Spread',color='tab:blue')
# pplot(sp2_series_lin5yr.loc['20180101':], label='5year No. 2 Spread',color='tab:orange')
# pplot(sp2_series_lin10yr.loc['20180101':], label='10year No. 2 Spread',color='lightseagreen')
# pplot(sp2_series_lin20yr.loc['20180101':], label='20year No. 2 Spread',color='tab:brown')

# string = 'No. 2 Scrap Price'
# pplot(cathode_price_series_lin1yr.loc['19910101':]-sp2_series_lin1yr.loc['19910101':],'--', label='1year No. 2 Scrap Price',color='tab:blue')
# pplot(cathode_price_series_lin5yr.loc['20180101':]-sp2_series_lin5yr.loc['19910101':],'--', label='5year No. 2 Scrap Price',color='tab:orange')
# pplot(cathode_price_series_lin10yr.loc['20180101':]-sp2_series_lin10yr.loc['19910101':],'--', label='10year No. 2 Scrap Price',color='lightseagreen')
# pplot(cathode_price_series_lin20yr.loc['20180101':]-sp2_series_lin20yr.loc['19910101':],'--', label='20year No. 2 Scrap Price',color='tab:brown')

# pplot(tcrc_series_baseline_irs100.loc['20180101':], label='100%')

# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 10000], 'k--')
# plt.legend(handles=[Line2D([0],[0],color='k',alpha=0,label='Cathode Price:\n(Dashed, Same Colors for No. 2 Scrap Price)'),\
#                     Line2D([0],[0],color='tab:blue',label='1-Year Ramp'),\
#                     Line2D([0],[0],color='tab:orange',label='5-Year Ramp'),\
#                     Line2D([0],[0], color='lightseagreen',label='10-Year Ramp'),\
#                     Line2D([0],[0], color='tab:brown',label='20-Year Ramp')],\
#           prop={'size':9},loc=2)
plt.legend()
# plt.title('Prices for Linear Approach to 20% Base Shock\nRelaxed Scrap Spread Constraint')
plt.title('Linear Appraoch to 100% Base Shock\nAnnual '+string+' (USD/t)')
plt.xlabel('Year')
plt.ylabel('Annual  '+string+' (USD/t)')
plt.show()

# %%
# pplot(tcrc_series_baseline_baseline.loc['20000101':], label='Baseline TCRC')
# pplot(tcrc_series_sp2hi20yr.loc['20000101':], label='TCRC')

pplot(cathode_price_series_baseline_baseline.loc['20000101':], label='Baseline Cathode Price')
pplot(cathode_price_series_sp2hi20yr.loc['20000101':], label='Cathode Price')

# pplot(sp2_series_baseline_baseline.loc['20000101':], label='Baseline No. 2 Spread')
# pplot(sp2_series_sp2hi20yr.loc['20000101':], label='No. 2 Spread',color='b')

# pplot(tcrc_series_baseline_irs100.loc['20180101':], label='100%')

pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 10000], 'k--')
plt.legend()
# plt.title('Prices for Linear Approach to 20% Base Shock')
plt.xlabel('Year')
plt.ylabel('Annual Price (USD/t)')
plt.show()

# %%
# Correlation for 10-Year Linear Ramp to 20% Base Shock 
print(sp2_series_lin10yr20.diff().loc[:'20180101'].corr(cathode_price_series_lin10yr20.diff().loc[:'20180101']))
print(sp2_series_lin10yr20.diff().loc['20190101':].corr(cathode_price_series_lin10yr20.diff().loc['20190101':]))
print(sp2_series_lin10yr20.loc[:'20180101'].corr(cathode_price_series_lin10yr20.loc[:'20180101']))
print(sp2_series_lin10yr20.loc['20190101':].corr(cathode_price_series_lin10yr20.loc['20190101':]))

# %%
# Baseline baseline for comparison
print(sp2_series_baseline_baseline.diff().loc[:'20180101'].corr(cathode_price_series_baseline_baseline.diff().loc[:'20180101']))
print(sp2_series_baseline_baseline.diff().loc['20190101':].corr(cathode_price_series_baseline_baseline.diff().loc['20190101':]))
print(sp2_series_baseline_baseline.loc[:'20180101'].corr(cathode_price_series_baseline_baseline.loc[:'20180101']))
print(sp2_series_baseline_baseline.loc['20190101':].corr(cathode_price_series_baseline_baseline.loc['20190101':]))

# %% [markdown]
# ### Price Responses for SP2E High 100% Shock Linear Ramps
# prefixes: tcrc_series_, cathode_price_series_, sp2_series_

# %%
string = 'No. 2 Spread'
pplot(tcrc_series_sp2lo1yr.loc['20180101':], label='1year '+string,color='darkgreen')
pplot(tcrc_series_sp2lo5yr.loc['20180101':], label='5year No. 2 Spread',color='green')
pplot(tcrc_series_sp2lo10yr.loc['20180101':], label='10year No. 2 Spread',color='limegreen')
pplot(tcrc_series_sp2lo20yr.loc['20180101':], label='20year No. 2 Spread',color='springgreen')
low_sp2lo = fillbtw(tcrc_series_sp2lo1yr,tcrc_series_sp2lo5yr,tcrc_series_sp2lo10yr,tcrc_series_sp2lo20yr,'min')
high_sp2lo = fillbtw(tcrc_series_sp2lo1yr,tcrc_series_sp2lo5yr,tcrc_series_sp2lo10yr,tcrc_series_sp2lo20yr,'max')
plt.fill_between(tcrc_series_sp2lo1yr.loc['20180101':].index,low_sp2lo.loc['20180101':].values, \
                 high_sp2lo.loc['20180101':].values, color = 'green', alpha = 0.3)

pplot(tcrc_series_sp2hi1yr.loc['20180101':], label='1year '+string,color='darkblue')
pplot(tcrc_series_sp2hi5yr.loc['20180101':], label='5year No. 2 Spread',color='darkslateblue')
pplot(tcrc_series_sp2hi10yr.loc['20180101':], label='10year No. 2 Spread',color='blue')
pplot(tcrc_series_sp2hi20yr.loc['19910101':], label='20year No. 2 Spread',color='cornflowerblue')
low_sp2hi= fillbtw(tcrc_series_sp2hi1yr,tcrc_series_sp2hi5yr,tcrc_series_sp2hi10yr,tcrc_series_sp2hi20yr,'min')
high_sp2hi = fillbtw(tcrc_series_sp2hi1yr,tcrc_series_sp2hi5yr,tcrc_series_sp2hi10yr,tcrc_series_sp2hi20yr,'max')
plt.fill_between(tcrc_series_sp2hi1yr.loc['20180101':].index,low_sp2hi.loc['20180101':].values, \
                 high_sp2hi.loc['20180101':].values, color = 'blue', alpha = 0.3)

pplot(tcrc_series_lin1yr.loc['20180101':], label='1year '+string,color='firebrick')
pplot(tcrc_series_lin5yr.loc['20180101':], label='5year No. 2 Spread',color='red')
pplot(tcrc_series_lin10yr.loc['20180101':], label='10year No. 2 Spread',color='tomato')
pplot(tcrc_series_lin20yr.loc['20180101':], label='20year No. 2 Spread',color='salmon')
low_lin = fillbtw(tcrc_series_lin1yr,tcrc_series_lin5yr,tcrc_series_lin10yr,tcrc_series_lin20yr,'min')
high_lin = fillbtw(tcrc_series_lin1yr,tcrc_series_lin5yr,tcrc_series_lin10yr,tcrc_series_lin20yr,'max')
plt.fill_between(tcrc_series_lin1yr.loc['20180101':].index,low_lin.loc['20180101':].values, \
                 high_lin.loc['20180101':].values, color = 'red', alpha = 0.3)

# pplot(tcrc_series_baseline_irs100.loc['20180101':], label='100%')

# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 10000], 'k--')
plt.legend(handles=[Line2D([0],[0],color='k',label='Lines dark for 1yr, light for 20yr'),Patch(facecolor='mediumseagreen',edgecolor='k',label='Low Elasticity'),Patch(facecolor='lightcoral',\
    edgecolor='k',label='Original Elasticity'),Patch(facecolor='cornflowerblue',edgecolor='k',label='High Elasticity')])
# plt.title('Prices for Linear Approach to 20% Base Shock\nRelaxed Scrap Spread Constraint')
plt.title('Annual '+string+' (USD/t)')
plt.xlabel('Year')
plt.ylabel('Annual '+string+' (USD/t)')
plt.show()

# %% [markdown]
# ## Displacement

# %%
# pplot(displacement_baseline_sm.loc['20190101':], label='Marginal')
# pplot(displacement_baseline_lsm.loc['20190101':], label='2019 to 2023')
# pplot(displacement_baseline_psm.loc['20190101':], label='Permanent')

# pplot(displacement_baseline_rs10.loc['20190101':], label='10%')
# pplot(displacement_baseline_rs20.loc['20190101':], label='20%')
# pplot(displacement_baseline_rs50.loc['20190101':], label='50%')
# pplot(displacement_baseline_rs100.loc['20190101':], label='Maximum')

pplot(displacement_unalloyed_availupdate.loc['20190101':], label='No Pb Leaded Brass')
pplot(displacement_unalloyed_availupdate_Ref_Cu.loc['20190101':], label='Refinery demand from blending')
# pplot(displacement_baseline_prs50.loc['20190101':], label='P50%')
pplot(displacement_unalloyed_availupdate_Pb.loc['20190101':], label='With Pb Leaded Brass')

# pplot(displacement_baseline_irs100.loc['20190101':], label='I100%')

pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [0, 0], 'k--')
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.legend()
plt.show()

# %%
displacement_unalloyed_availupdate_Pb.loc['20400101']

# %%
# pplot(displacement_baseline_sm.loc['20190101':], label='Baseline')
# pplot(displacement_low_mpe_sm.loc['20190101':], label='Low MPE')
# pplot(displacement_high_mpe_sm.loc['20190101':], label='High MPE')

# pplot(displacement_baseline_sm.loc['20190101':], label='Baseline')
# pplot(displacement_low_rpe_sm.loc['20190101':], label='Low RPEs')
# pplot(displacement_high_rpe_sm.loc['20190101':], label='High RPEs')

# pplot(displacement_baseline_sm.loc['20190101':], label='Baseline')
# pplot(displacement_low_sre_sm.loc['20190101':], label='Low SREs')
# pplot(displacement_high_sre_sm.loc['20190101':], label='High SREs')

pplot(displacement_baseline_sm.loc['20190101':], label='Baseline')
pplot(displacement_200_de_sm.loc['20190101':], label='200% DEs')
pplot(displacement_400_de_sm.loc['20190101':], label='400% DEs')

# pplot(displacement_baseline_sm.loc['20190101':], label='Baseline')
# pplot(displacement_low_ssde_sm.loc['20190101':], label='Low SSDE')
# pplot(displacement_high_ssde_sm.loc['20190101':], label='High SSDE')

pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [0, 0], 'k--')
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.legend()
plt.show()

# %%
displacement_baseline_rs10.loc['20400101']

# %% [markdown]
# ###### Displacement for Initial-2X

# %%
plt.style.use('seaborn-colorblind')
scrap1yr = str(round((scrap_supply_1yr2X-scrap_supply_baseline_baseline)['20190101']))
scrap5yr = str(round((scrap_supply_i5yr-scrap_supply_baseline_baseline)['20190101':'20230101'].sum()))
scrap10yr = str(round((scrap_supply_i10yr-scrap_supply_baseline_baseline)['20190101':'20280101'].sum()))
scrap20yr = str(round((scrap_supply_i20yr-scrap_supply_baseline_baseline)['20190101':'20380101'].sum()))

pplot(displacement_1yr2X.loc['20190101':], label='1 year shock: '+scrap1yr+' kt')
pplot(displacement_i5yr.loc['20190101':], label='5 year shock: '+scrap5yr+' kt')
pplot(displacement_i10yr.loc['20190101':], label='10 year shock: '+scrap10yr+' kt')
pplot(displacement_i20yr.loc['20190101':], label='20 year shock: '+scrap20yr+' kt')
pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [0, 0], 'k--')
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.title('Displacement - Initial, Twice Baseline')
plt.ylim((0,0.9))
plt.legend()
plt.show()

# %%
pplot(scrap_supply_1yr2X,label='1 year shock')
pplot(scrap_supply_i20yr,label='5 year shock')
plt.legend()

# %%
print((scrap_supply_1yr2X-scrap_supply_baseline_baseline)['20190101'])
(scrap_supply_t5yr-scrap_supply_baseline_baseline)['20190101':'20230101'].sum()

# %% [markdown]
# ###### Displacement for Total-2X

# %%
plt.style.use('seaborn-colorblind')
scrap1yr = str(round((scrap_supply_1yr2X-scrap_supply_baseline_baseline)['20190101']))
scrap5yr = str(round((scrap_supply_t5yr-scrap_supply_baseline_baseline)['20190101':'20230101'].sum()))
scrap10yr = str(round((scrap_supply_t10yr-scrap_supply_baseline_baseline)['20190101':'20280101'].sum()))
scrap20yr = str(round((scrap_supply_t20yr-scrap_supply_baseline_baseline)['20190101':'20380101'].sum()))
scrapj1yr = str(round((scrap_supply_john1-scrap_supply_baseline_baseline)['20190101']))
scrapj5yr = str(round((scrap_supply_john5-scrap_supply_baseline_baseline)['20190101':'20230101'].sum()))


pplot(displacement_1yr2X.loc['20190101':], label='1 year shock: '+scrap1yr+' kt')
pplot(displacement_t5yr.loc['20190101':], label='5 year shock: '+scrap5yr+' kt')
pplot(displacement_t10yr.loc['20190101':], label='10 year shock: '+scrap10yr+' kt')
pplot(displacement_t20yr.loc['20190101':], label='20 year shock: '+scrap20yr+' kt')
pplot(displacement_john1.loc['20190101':], label='1 year shock: '+scrapj1yr+' kt')
pplot(displacement_john5.loc['20190101':], label='4 year shock: '+scrapj5yr+' kt')


pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [0, 0], 'k--')
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.title('Displacement - Total, Twice Baseline')
plt.ylim((0,0.9))
plt.legend()
plt.show()

# %% [markdown]
# ### Displacement China: Fruity recycling rates
# Displacement for 90% fruity recycling rate

# %%
pd.concat([all_scrap_available_fruity1rr0_gl.loc['20180101':,:].sum(axis=1), all_scrap_available_fruity1rr50_gl.loc['20180101':,:].sum(axis=1)],axis=1)

# %%
pplot(displacement_fruity1rr001.loc['20190101':], label='fruity 1X 0.1% recycling rate',color='tab:brown')
pplot(displacement_fruity1rr50.loc['20190101':], label='fruity 1X 50% recycling rate',color='tab:blue')
pplot(displacement_fruity1rr90.loc['20190101':], label='fruity 1X 90% recycling rate',color='tab:green')
pplot(displacement_fruity1rr100.loc['20190101':], label='fruity 1X 100% recycling rate',color='tab:red')
plt.legend()
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.title('Displacement: Fruity Alloys')
plt.show()

# %%
# scrap1yr = str(round((scrap_supply_lin1yr-scrap_supply_baseline_baseline)['20190101']))
# scrap5yr = str(round((scrap_supply_lin5yr-scrap_supply_baseline_baseline)['20190101':'20230101'].sum()))
# scrap10yr = str(round((scrap_supply_lin10yr-scrap_supply_baseline_baseline)['20190101':'20280101'].sum()))
# scrap20yr = str(round((scrap_supply_lin20yr-scrap_supply_baseline_baseline)['20190101':'20380101'].sum()))

pplot(displacement_fruity100rr100niag.loc['20190101':], label='fruity 10X 90% recycling rate',color='tab:blue')
# pplot(displacement_fruity50rr0.loc['20190101':], label='fruity 50X 90% recycling rate',color='tab:brown')
pplot(displacement_fruity10rr100niag.loc['20190101':], label='fruity 10X 100% recycling rate',color='tab:blue')
# pplot(displacement_fruity10rr50niag.loc['20190101':], label='100% recycling rate', color='lightseagreen')
# pplot(displacement_alloyed_imports_50yoy.loc['20190101':], label='Reduce CN alloyed imports 50% YOY',color='tab:green')
# pplot(displacement_alloyed_no2_50yoy.loc['20190101':], label='Reduce CN No.2+alloyed imports 50% YOY',color='tab:red')

pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [0, 0], 'k--')
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.title('Displacement - China Scenarios')
# plt.legend()
plt.show()

# %% [markdown]
# ### Displacement Fruity

# %%
pplot(demand_displacement_fruity1rr11.loc['20180101':], label='fruity 1X 0.1% recycling rate',color='tab:gray')
pplot(demand_displacement_fruity1rr50.loc['20180101':], label='fruity 1X 50% recycling rate',color='tab:blue')
pplot(demand_displacement_fruity1rr90.loc['20180101':], label='fruity 1X 90% recycling rate',color='tab:green')
pplot(demand_displacement_fruity1rr100.loc['20180101':], label='fruity 1X 100% recycling rate',color='tab:red')
plt.ylim(-5,5)
plt.xlabel('Year')
plt.ylabel('Displacement Ratio')
plt.title('Displacement Ratio \n(Fruity Alloys)')

plt.figure()
pplot(demand_displacement_fruity_pct1rr11.loc['20180101':], label='1mrk% 0.1% recycling rate',color='tab:gray')
pplot(demand_displacement_fruity_pct1rr50.loc['20180101':], label='1mrk% 50% recycling rate',color='tab:blue')
pplot(demand_displacement_fruity_pct1rr90.loc['20180101':], label='1mrk% 90% recycling rate',color='tab:green')
pplot(demand_displacement_fruity_pct1rr100.loc['20180101':], label='1mrk% 100% recycling rate',color='tab:red')
plt.ylim(-5,5)
plt.xlabel('Year')
plt.ylabel('Displacement Ratio')
plt.title('Displacement Ratio \n(Fruity Alloys)')

plt.figure()
pplot(demand_displacement_fruity_pct5rr11.loc['20180101':], label='5mrk% 0.1% recycling rate',color='tab:gray')
pplot(demand_displacement_fruity_pct5rr50.loc['20180101':], label='5mrk% 50% recycling rate',color='tab:blue')
pplot(demand_displacement_fruity_pct5rr90.loc['20180101':], label='5mrk% 90% recycling rate',color='tab:green')
pplot(demand_displacement_fruity_pct5rr100.loc['20180101':], label='5mrk% 100% recycling rate',color='tab:red')
plt.ylim(-5,5)
plt.xlabel('Year')
plt.ylabel('Displacement Ratio')
plt.title('Displacement Ratio \n(Fruity Alloys)')

plt.figure()
pplot(demand_displacement_fruity_pct10rr11.loc['20180101':], label='10mrk% 0.1% recycling rate',color='tab:gray')
pplot(demand_displacement_fruity_pct10rr50.loc['20180101':], label='10mrk% 50% recycling rate',color='tab:blue')
pplot(demand_displacement_fruity_pct10rr70.loc['20180101':], label='10mrk% 70% recycling rate',color='tab:green')
pplot(demand_displacement_fruity_pct10rr90.loc['20180101':], label='10mrk% 90% recycling rate',color='tab:red')
plt.ylim(-5,5)
plt.xlabel('Year')
plt.ylabel('Displacement Ratio')
plt.title('Displacement Ratio \n(Fruity Alloys)')

plt.figure()
pplot(demand_displacement_fruity1rr90.loc['20180101':], label='fruity 1X 90% recycling rate',color='tab:blue')
pplot(demand_displacement_fruity_pct1rr90.loc['20180101':], label='1mrk% 90% recycling rate',color='tab:green')
pplot(demand_displacement_fruity_pct5rr90.loc['20180101':], label='5mrk% 90% recycling rate',color='tab:red')
pplot(demand_displacement_fruity_pct10rr70.loc['20180101':], label='10mrk% 70% recycling rate',color='tab:gray')
plt.xlabel('Year')
plt.ylabel('Displacement Ratio')
plt.ylim(-5,5)
plt.title('Displacement Ratio \n(Fruity Alloys)')
plt.show()

# %%
pplot(demand_displacement_fruity_pct10rr50var10.loc['20190101':], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(demand_displacement_fruity_pct10rr50var30.loc['20190101':], label='10mrk% 50% RR, var30',color=colors[1])
pplot(demand_displacement_fruity_pct10rr50var50.loc['20190101':], label='10mrk% 50% RR, var50',color=colors[2])
pplot(demand_displacement_fruity_pct10rr50var70.loc['20190101':], label='10mrk% 50% RR, var70',color=colors[3])
# plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([5,0, -5,-10,-15])
plt.ylim(-5,5)
plt.ylabel('Displacement Ratio')
plt.title('Displacement Ratio \n10% of Copper Market')

# %%
pplot(demand_displacement_fruity1rr100var0.loc['20190101':], label='1X 100% RR, var0',color=colors[0],firstcall=1)
# pplot(mining_pctinc_fruity1rr100var10.loc['20190101':], label='1X 100% RR, var10',color='y')
pplot(demand_displacement_fruity1rr100var30.loc['20190101':], label='1X 100% RR, var30',color=colors[1])
# pplot(mining_pctinc_fruity1rr100var50.loc['20190101':], label='1X 100% RR, var50',color='k')
pplot(demand_displacement_fruity1rr100var70.loc['20190101':], label='1X 100% RR, var70',color=colors[2])
pplot(demand_displacement_fruity1rr100var90.loc['20190101':], label='1X 100% RR, var90',color=colors[3])
plt.legend(loc='upper left')
# plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([-0.12, -0.08, -0.04, 0, 0.04])
plt.ylim(-5,5)
plt.ylabel('Displacement Ratio (%)')
plt.title('Displacement Ratio \n0.08% of Copper Market')

# %% [markdown]
# ### Displacement for Initial Linear Approaches
# Displacement for Linear Approach to 100% Base Shock

# %%
# scrap1yr = str(round((scrap_supply_lin1yr-scrap_supply_baseline_baseline)['20190101']))
# scrap5yr = str(round((scrap_supply_lin5yr-scrap_supply_baseline_baseline)['20190101':'20230101'].sum()))
# scrap10yr = str(round((scrap_supply_lin10yr-scrap_supply_baseline_baseline)['20190101':'20280101'].sum()))
# scrap20yr = str(round((scrap_supply_lin20yr-scrap_supply_baseline_baseline)['20190101':'20380101'].sum()))

pplot(displacement_lin1yr.loc['20190101':], label='1 year ramp',color='tab:blue')
pplot(displacement_lin5yr.loc['20190101':], label='5 year ramp',color='tab:orange')
pplot(displacement_lin10yr.loc['20190101':], label='10 year ramp', color='lightseagreen')
pplot(displacement_lin20yr.loc['20190101':], label='20 year ramp',color='tab:brown')

pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [0, 0], 'k--')
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.title('Displacement - Linear Approach to 100% Base Shock')
plt.legend()
plt.show()

# %% [markdown]
# Displacement for Linear Approach to 20% Base Shock

# %%
# scrap1yr = str(round((scrap_supply_lin1yr-scrap_supply_baseline_baseline)['20190101']))
# scrap5yr = str(round((scrap_supply_lin5yr-scrap_supply_baseline_baseline)['20190101':'20230101'].sum()))
# scrap10yr = str(round((scrap_supply_lin10yr-scrap_supply_baseline_baseline)['20190101':'20280101'].sum()))
# scrap20yr = str(round((scrap_supply_lin20yr-scrap_supply_baseline_baseline)['20190101':'20380101'].sum()))

pplot(displacement_lin1yr20.loc['20190101':],'tab:red', label='1 year ramp',color='tab:blue')
pplot(displacement_lin5yr20.loc['20190101':], label='5 year ramp',color='tab:orange')
pplot(displacement_lin10yr20.loc['20190101':], label='10 year ramp', color='lightseagreen')
pplot(displacement_lin20yr20.loc['20190101':], label='20 year ramp',color='tab:brown')

pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [0, 0], 'k--')
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.title('Displacement - Linear Approach to 20% Base Shock')
plt.legend()
plt.show()

# %% [markdown]
# Displacement for Linear Approach to 50% Base Shock

# %%
# scrap1yr = str(round((scrap_supply_lin1yr-scrap_supply_baseline_baseline)['20190101']))
# scrap5yr = str(round((scrap_supply_lin5yr-scrap_supply_baseline_baseline)['20190101':'20230101'].sum()))
# scrap10yr = str(round((scrap_supply_lin10yr-scrap_supply_baseline_baseline)['20190101':'20280101'].sum()))
# scrap20yr = str(round((scrap_supply_lin20yr-scrap_supply_baseline_baseline)['20190101':'20380101'].sum()))

pplot(displacement_lin1yr50.loc['20190101':],'tab:red', label='1 year ramp',color='tab:blue')
pplot(displacement_lin5yr50.loc['20190101':], label='5 year ramp',color='tab:orange')
pplot(displacement_lin10yr50.loc['20190101':], label='10 year ramp', color='lightseagreen')
pplot(displacement_lin20yr50.loc['20190101':], label='20 year ramp',color='tab:brown')

pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [0, 0], 'k--')
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.title('Displacement - Linear Approach to 50% Base Shock')
plt.legend()
plt.show()

# %% [markdown]
# Displacement for Linear Approach to 10% Base Shock

# %%
# scrap1yr = str(round((scrap_supply_lin1yr-scrap_supply_baseline_baseline)['20190101']))
# scrap5yr = str(round((scrap_supply_lin5yr-scrap_supply_baseline_baseline)['20190101':'20230101'].sum()))
# scrap10yr = str(round((scrap_supply_lin10yr-scrap_supply_baseline_baseline)['20190101':'20280101'].sum()))
# scrap20yr = str(round((scrap_supply_lin20yr-scrap_supply_baseline_baseline)['20190101':'20380101'].sum()))

pplot(displacement_lin1yr10.loc['20190101':],'tab:red', label='1 year ramp',color='tab:blue')
pplot(displacement_lin5yr10.loc['20190101':], label='5 year ramp',color='tab:orange')
pplot(displacement_lin10yr10.loc['20190101':], label='10 year ramp', color='lightseagreen')
pplot(displacement_lin20yr10.loc['20190101':], label='20 year ramp',color='tab:brown')

pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [0, 0], 'k--')
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.title('Displacement - Linear Approach to 50% Base Shock')
plt.legend()
plt.show()

# %% [markdown]
# ### Displacement for SP2E High (100% Shock - Linear Ramp)

# %%
# scrap1yr = str(round((scrap_supply_sp2hi1yr-scrap_supply_baseline_baseline)['20190101']))
# scrap5yr = str(round((scrap_supply_sp2hi5yr-scrap_supply_baseline_baseline)['20190101':'20230101'].sum()))
# scrap10yr = str(round((scrap_supply_sp2hi10yr-scrap_supply_baseline_baseline)['20190101':'20280101'].sum()))
# scrap20yr = str(round((scrap_supply_sp2hi20yr-scrap_supply_baseline_baseline)['20190101':'20380101'].sum()))

pplot(displacement_sp2hi1yr.loc['20190101':], label='1 year ramp',color='tab:blue')
pplot(displacement_sp2hi5yr.loc['20190101':], label='5 year ramp',color='tab:orange')
pplot(displacement_sp2hi10yr.loc['20190101':], label='10 year ramp', color='lightseagreen')
pplot(displacement_sp2hi20yr.loc['20190101':], label='20 year ramp',color='tab:brown')

pplot([pd.datetime(2018,1,1), pd.datetime(2040,1,1)], [0, 0], 'k--')
plt.xlabel('Year')
plt.ylabel('Displacement ratio')
plt.title('Displacement - SP2 Elasticity Tests')
plt.legend()
plt.show()

# %%
displacement_sp2hi1yr.loc['20400101']

# %% [markdown]
# ### Fill-Between Plots

# %%
def fillbtw(df1,df2,df3,df4,m='min'):
    '''Give df1,df2,df3,df4 and either min or max as string input to get minimum for each year among the 4 dataframes'''
    df = pd.Series(0,index = df1.index)
    if m=='min':
        for yr in df1.index:
            df.loc[yr] = min([df1.loc[yr],df2.loc[yr],df3.loc[yr],df4.loc[yr]])
    if m=='max':
        for yr in df1.index:
            df.loc[yr] = max([df1.loc[yr],df2.loc[yr],df3.loc[yr],df4.loc[yr]])
    return df

# %% [markdown]
# ###### Refinery Secondary Ratio SP2 & TCRC Elasticities

# %%
pplot(displacement_sp2lo1yr.loc['20180101':], label='1year '+string,color='darkgreen')
pplot(displacement_sp2lo5yr.loc['20180101':], label='5year No. 2 Spread',color='green')
pplot(displacement_sp2lo10yr.loc['20180101':], label='10year No. 2 Spread',color='limegreen')
pplot(displacement_sp2lo20yr.loc['20180101':], label='20year No. 2 Spread',color='springgreen')
low_sp2lo = fillbtw(displacement_sp2lo1yr,displacement_sp2lo5yr,displacement_sp2lo10yr,displacement_sp2lo20yr,'min')
high_sp2lo = fillbtw(displacement_sp2lo1yr,displacement_sp2lo5yr,displacement_sp2lo10yr,displacement_sp2lo20yr,'max')
plt.fill_between(displacement_sp2lo1yr.loc['20180101':].index, low_sp2lo.loc['20180101':], \
                 high_sp2lo.loc['20180101':], color = 'green', alpha = 0.3)

pplot(displacement_sp2hi1yr.loc['20180101':], label='1year '+string,color='darkblue')
pplot(displacement_sp2hi5yr.loc['20180101':], label='5year No. 2 Spread',color='darkslateblue')
pplot(displacement_sp2hi10yr.loc['20180101':], label='10year No. 2 Spread',color='blue')
pplot(displacement_sp2hi20yr.loc['20180101':], label='20year No. 2 Spread',color='cornflowerblue')
low_sp2hi = fillbtw(displacement_sp2hi1yr,displacement_sp2hi5yr,displacement_sp2hi10yr,displacement_sp2hi20yr,'min')
high_sp2hi = fillbtw(displacement_sp2hi1yr,displacement_sp2hi5yr,displacement_sp2hi10yr,displacement_sp2hi20yr,'max')
plt.fill_between(displacement_sp2hi1yr.loc['20180101':].index, low_sp2hi.loc['20180101':], \
                 high_sp2hi.loc['20180101':],color = 'blue', alpha = 0.3)

pplot(displacement_lin1yr.loc['20180101':], label='1year '+string,color='firebrick')
pplot(displacement_lin5yr.loc['20180101':], label='5year No. 2 Spread',color='red')
pplot(displacement_lin10yr.loc['20180101':], label='10year No. 2 Spread',color='tomato')
pplot(displacement_lin20yr.loc['20180101':], label='20year No. 2 Spread',color='salmon')
low_lin = fillbtw(displacement_lin1yr,displacement_lin5yr,displacement_lin10yr,displacement_lin20yr,'min')
high_lin = fillbtw(displacement_lin1yr,displacement_lin5yr,displacement_lin10yr,displacement_lin20yr,'max')
plt.fill_between(displacement_lin1yr.loc['20180101':].index,low_lin.loc['20180101':].values, \
                 high_lin.loc['20180101':].values, color = 'red', alpha = 0.3)

# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 10000], 'k--')
plt.legend(handles=[Line2D([0],[0],color='k',label='Lines dark for 1yr, light for 20yr'),\
                    Patch(facecolor='mediumseagreen',edgecolor='k',label='Low Elasticity'),\
                    Patch(facecolor='lightcoral', edgecolor='k',label='Original Elasticity'),\
                    Patch(facecolor='cornflowerblue',edgecolor='k',label='High Elasticity')],\
          prop={'size':9})
plt.title('Displacement - Comparing SR Elasticity Results for \nLinear 100% Shocks')
plt.xlabel('Year')
plt.ylabel('Displacement Ratio')
plt.show()

# %% [markdown]
# ### Fill Between: Mine Production Elasticity

# %%
pplot(displacement_mpelo1yr20.loc['20180101':], label='1year '+string,color='darkgreen')
pplot(displacement_mpelo5yr20.loc['20180101':], label='5year No. 2 Spread',color='green')
pplot(displacement_mpelo10yr20.loc['20180101':], label='10year No. 2 Spread',color='limegreen')
pplot(displacement_mpelo20yr20.loc['20180101':], label='20year No. 2 Spread',color='springgreen')
low_mpelo = fillbtw(displacement_mpelo1yr20,displacement_mpelo5yr20,displacement_mpelo10yr20,displacement_mpelo20yr20,'min')
high_mpelo = fillbtw(displacement_mpelo1yr20,displacement_mpelo5yr20,displacement_mpelo10yr20,displacement_mpelo20yr20,'max')
plt.fill_between(displacement_mpelo1yr20.loc['20180101':].index, low_mpelo.loc['20180101':], \
                 high_mpelo.loc['20180101':], color = 'green', alpha = 0.3)

pplot(displacement_mpehi1yr20.loc['20180101':], label='1year '+string,color='darkblue')
pplot(displacement_mpehi5yr20.loc['20180101':], label='5year No. 2 Spread',color='darkslateblue')
pplot(displacement_mpehi10yr20.loc['20180101':], label='10year No. 2 Spread',color='blue')
pplot(displacement_mpehi20yr20.loc['20180101':], label='20year No. 2 Spread',color='cornflowerblue')
low_mpehi = fillbtw(displacement_mpehi1yr20,displacement_mpehi5yr20,displacement_mpehi10yr20,displacement_mpehi20yr20,'min')
high_mpehi = fillbtw(displacement_mpehi1yr20,displacement_mpehi5yr20,displacement_mpehi10yr20,displacement_mpehi20yr20,'max')
plt.fill_between(displacement_mpehi1yr20.loc['20180101':].index, low_mpehi.loc['20180101':], \
                 high_mpehi.loc['20180101':],color = 'blue', alpha = 0.3)

pplot(displacement_lin1yr20.loc['20180101':], label='1year '+string,color='firebrick')
pplot(displacement_lin5yr20.loc['20180101':], label='5year No. 2 Spread',color='red')
pplot(displacement_lin10yr20.loc['20180101':], label='10year No. 2 Spread',color='tomato')
pplot(displacement_lin20yr20.loc['20180101':], label='20year No. 2 Spread',color='salmon')
low_lin = fillbtw(displacement_lin1yr20,displacement_lin5yr20,displacement_lin10yr20,displacement_lin20yr20,'min')
high_lin = fillbtw(displacement_lin1yr20,displacement_lin5yr20,displacement_lin10yr20,displacement_lin20yr20,'max')
plt.fill_between(displacement_lin1yr20.loc['20180101':].index,low_lin.loc['20180101':].values, \
                 high_lin.loc['20180101':].values, color = 'red', alpha = 0.3)

# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 10000], 'k--')
plt.legend(handles=[Line2D([0],[0],color='k',label='Lines dark for 1yr20, light for 20yr20'),\
                    Patch(facecolor='mediumseagreen',edgecolor='k',label='Low Elasticity'),\
                    Patch(facecolor='lightcoral', edgecolor='k',label='Original Elasticity'),\
                    Patch(facecolor='cornflowerblue',edgecolor='k',label='High Elasticity')],\
          prop={'size':9})
plt.title('Displacement - Comparing Mine Production Elasticity Results \nfor Linear 100% Shocks')
plt.xlabel('Year')
plt.ylabel('Displacement Ratio')
plt.show()

# %% [markdown]
# ### Fill Between: SSDE

# %%
pplot(displacement_ssdelo1yr20.loc['20180101':], label='1year No. 2 Spread',color='darkgreen')
pplot(displacement_ssdelo5yr20.loc['20180101':], label='5year No. 2 Spread',color='green')
pplot(displacement_ssdelo10yr20.loc['20180101':], label='10year No. 2 Spread',color='limegreen')
pplot(displacement_ssdelo20yr20.loc['20180101':], label='20year No. 2 Spread',color='springgreen')
low_ssdelo = fillbtw(displacement_ssdelo1yr20,displacement_ssdelo5yr20,displacement_ssdelo10yr20,displacement_ssdelo20yr20,'min')
high_ssdelo = fillbtw(displacement_ssdelo1yr20,displacement_ssdelo5yr20,displacement_ssdelo10yr20,displacement_ssdelo20yr20,'max')
plt.fill_between(displacement_ssdelo1yr20.loc['20180101':].index, low_ssdelo.loc['20180101':], \
                 high_ssdelo.loc['20180101':], color = 'green', alpha = 0.3)

pplot(displacement_ssdehi1yr20.loc['20180101':]+0.01, label='1year No. 2 Spread',color='darkblue')
pplot(displacement_ssdehi5yr20.loc['20180101':]+0.01, label='5year No. 2 Spread',color='darkslateblue')
pplot(displacement_ssdehi10yr20.loc['20180101':]+0.01, label='10year No. 2 Spread',color='blue')
pplot(displacement_ssdehi20yr20.loc['20180101':]+0.01, label='20year No. 2 Spread',color='cornflowerblue')
low_ssdehi = fillbtw(displacement_ssdehi1yr20,displacement_ssdehi5yr20,displacement_ssdehi10yr20,displacement_ssdehi20yr20,'min')
high_ssdehi = fillbtw(displacement_ssdehi1yr20,displacement_ssdehi5yr20,displacement_ssdehi10yr20,displacement_ssdehi20yr20,'max')
plt.fill_between(displacement_ssdehi1yr20.loc['20180101':].index, low_ssdehi.loc['20180101':]+0.01, \
                 high_ssdehi.loc['20180101':]+0.01,color = 'blue', alpha = 0.3)

pplot(displacement_lin1yr20.loc['20180101':]+0.02, label='1year No. 2 Spread',color='firebrick')
pplot(displacement_lin5yr20.loc['20180101':]+0.02, label='5year No. 2 Spread',color='red')
pplot(displacement_lin10yr20.loc['20180101':]+0.02, label='10year No. 2 Spread',color='tomato')
pplot(displacement_lin20yr20.loc['20180101':]+0.02, label='20year No. 2 Spread',color='salmon')
low_lin = fillbtw(displacement_lin1yr20,displacement_lin5yr20,displacement_lin10yr20,displacement_lin20yr20,'min')
high_lin = fillbtw(displacement_lin1yr20,displacement_lin5yr20,displacement_lin10yr20,displacement_lin20yr20,'max')
plt.fill_between(displacement_lin1yr20.loc['20180101':].index,low_lin.loc['20180101':]+0.02, \
                 high_lin.loc['20180101':]+0.02, color = 'red', alpha = 0.3)

# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 10000], 'k--')
plt.legend(handles=[Line2D([0],[0],color='k',label='Lines dark for 1yr20, light for 20yr20'),\
                    Patch(facecolor='mediumseagreen',edgecolor='k',label='Low Elasticity'),\
                    Patch(facecolor='lightcoral', edgecolor='k',label='Original Elasticity'),\
                    Patch(facecolor='cornflowerblue',edgecolor='k',label='High Elasticity')],\
          prop={'size':9})
plt.title('Displacement - Comparing SSDE Results \nfor Linear 100% Shocks')
plt.xlabel('Year')
plt.ylabel('Displacement Ratio')
plt.show()

# %% [markdown]
# ### Fill Between: Demand Elasticity

# %%
pplot(displacement_200de1yr20.loc['20180101':], label='1year '+string,color='darkgreen')
pplot(displacement_200de5yr20.loc['20180101':], label='5year No. 2 Spread',color='green')
pplot(displacement_200de10yr20.loc['20180101':], label='10year No. 2 Spread',color='limegreen')
pplot(displacement_200de20yr20.loc['20180101':], label='20year No. 2 Spread',color='springgreen')
low_200de = fillbtw(displacement_200de1yr20,displacement_200de5yr20,displacement_200de10yr20,displacement_200de20yr20,'min')
high_200de = fillbtw(displacement_200de1yr20,displacement_200de5yr20,displacement_200de10yr20,displacement_200de20yr20,'max')
plt.fill_between(displacement_200de1yr20.loc['20180101':].index, low_200de.loc['20180101':], \
                 high_200de.loc['20180101':], color = 'green', alpha = 0.3)

pplot(displacement_400de1yr20.loc['20180101':], label='1year '+string,color='darkblue')
pplot(displacement_400de5yr20.loc['20180101':], label='5year No. 2 Spread',color='darkslateblue')
pplot(displacement_400de10yr20.loc['20180101':], label='10year No. 2 Spread',color='blue')
pplot(displacement_400de20yr20.loc['20180101':], label='20year No. 2 Spread',color='cornflowerblue')
low_400de = fillbtw(displacement_400de1yr20,displacement_400de5yr20,displacement_400de10yr20,displacement_400de20yr20,'min')
high_400de = fillbtw(displacement_400de1yr20,displacement_400de5yr20,displacement_400de10yr20,displacement_400de20yr20,'max')
plt.fill_between(displacement_400de1yr20.loc['20180101':].index, low_400de.loc['20180101':], \
                 high_400de.loc['20180101':],color = 'blue', alpha = 0.3)

pplot(displacement_lin1yr20.loc['20180101':], label='1year '+string,color='firebrick')
pplot(displacement_lin5yr20.loc['20180101':], label='5year No. 2 Spread',color='red')
pplot(displacement_lin10yr20.loc['20180101':], label='10year No. 2 Spread',color='tomato')
pplot(displacement_lin20yr20.loc['20180101':], label='20year No. 2 Spread',color='salmon')
low_lin = fillbtw(displacement_lin1yr20,displacement_lin5yr20,displacement_lin10yr20,displacement_lin20yr20,'min')
high_lin = fillbtw(displacement_lin1yr20,displacement_lin5yr20,displacement_lin10yr20,displacement_lin20yr20,'max')
plt.fill_between(displacement_lin1yr20.loc['20180101':].index,low_lin.loc['20180101':].values, \
                 high_lin.loc['20180101':].values, color = 'red', alpha = 0.3)

# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 10000], 'k--')
plt.legend(handles=[Line2D([0],[0],color='k',label='Lines dark for 1yr20, light for 20yr20'),\
                    Patch(facecolor='lightcoral', edgecolor='k',label='Baseline Demand Elasticity'),\
                    Patch(facecolor='mediumseagreen',edgecolor='k',label='200% Demand Elasticity'),\
                    Patch(facecolor='cornflowerblue',edgecolor='k',label='400% Demand Elasticity')],\
          prop={'size':9})
plt.title('Displacement - Comparing Demand Elasticity Results \nfor Linear 100% Shocks')
plt.xlabel('Year')
plt.ylabel('Displacement Ratio')
plt.show()

# %% [markdown]
# ## Mining response

# %%
pplot(-mining_response_fruity100rr100niag.cumsum().loc['20190101':], label='100X 100% RR')
pplot(-mining_response_fruity10rr100niag.cumsum().loc['20190101':], label='10X 100% RR')
pplot(-mining_response_fruity1rr100niag.cumsum().loc['20190101':], label='Original, 100% RR')

plt.ylabel('Mining production reduction from baseline (kt)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %%
# pplot(-mining_response_baseline_rs10.cumsum().loc['20190101':], label='10%')
# pplot(-mining_response_baseline_rs20.cumsum().loc['20190101':], label='20%')
# pplot(-mining_response_baseline_rs50.cumsum().loc['20190101':], label='50%')
# pplot(-mining_response_baseline_rs100.cumsum().loc['20190101':], label='Maximum')

pplot(-mining_response_baseline_prs10.cumsum().loc['20190101':], label='10%')
pplot(-mining_response_baseline_prs20.cumsum().loc['20190101':], label='20%')
pplot(-mining_response_baseline_prs50.cumsum().loc['20190101':], label='50%')
pplot(-mining_response_baseline_prs100.cumsum().loc['20190101':], label='Maximum')

#pplot(mining_response_baseline_irs100.cumsum().loc['20190101':], label='i100%')

plt.ylabel('Mining production reduction from baseline (kt)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %% [markdown]
# ### China Import Scenarios Mining Response

# %%
pplot(mining_response_alloyed_50yoy.cumsum().loc['20180101':], color = colors[0], label='Ban Alloyed', firstcall=1)
pplot(mining_response_no2_50yoy.cumsum().loc['20180101':], label='Ban No.2', color = colors[1])
pplot(mining_response_both_50yoy.cumsum().loc['20180101':], label='Ban <99%', color = colors[2])
plt.title('Change in Mining Production above Baseline \n50% YOY')
plt.ylabel('Change in mining production above baseline (kt)')
plt.legend().set_visible(False)

plt.figure()
pplot(0.001*mining_response_ban_zeng_mean.cumsum().loc['20180101':], label='Zeng Mean', color = colors[0], firstcall=1)
plt.fill_between(mining_response_ban_zeng_mean.cumsum().loc['20180101':].index,
                0.001*mining_response_ban_zeng_low.cumsum().loc['20180101':],
                0.001*mining_response_ban_zeng_high.cumsum().loc['20180101':], color = colors[0], alpha = 0.3)
pplot(0.001*mining_response_both_50yoy.cumsum().loc['20180101':], '<99% Cu Ban', colors[1])
plt.title('Change in Mining Production above Baseline \nSensitivity to Zeng Paper Projections')
plt.ylabel('Change in mining production above baseline (Mt)')
plt.legend().set_visible(False)
plt.show()

plt.figure()
pplot(0.001*scrap_demand_response_ban_zeng_mean_gl.loc['20180101':], label='Zeng Mean', color = colors[0], firstcall=1)
plt.fill_between(scrap_demand_response_ban_zeng_mean_gl.loc['20180101':].index,
                0.001*scrap_demand_response_ban_zeng_low_gl.loc['20180101':],
                0.001*scrap_demand_response_ban_zeng_high_gl.loc['20180101':], color = colors[0], alpha = 0.3)
pplot(0.001*scrap_demand_response_ban_zeng_mean_cn.loc['20180101':], label='Zeng Mean', color = colors[1])
plt.fill_between(scrap_demand_response_ban_zeng_mean_cn.loc['20180101':].index,
                0.001*scrap_demand_response_ban_zeng_low_cn.loc['20180101':],
                0.001*scrap_demand_response_ban_zeng_high_cn.loc['20180101':], color = colors[1], alpha = 0.3)
pplot(0.001*scrap_demand_response_ban_zeng_mean_rw.loc['20180101':], label='Zeng Mean', color = colors[2])
plt.fill_between(scrap_demand_response_ban_zeng_mean_rw.loc['20180101':].index,
                0.001*scrap_demand_response_ban_zeng_low_rw.loc['20180101':],
                0.001*scrap_demand_response_ban_zeng_high_rw.loc['20180101':], color = colors[2], alpha = 0.3)
plt.title('Change in Scrap Demand above Baseline \nSensitivity to Zeng Paper Projections')
plt.ylabel('Change in scrap demand above baseline (Mt)')
plt.legend().set_visible(False)
plt.show()

# %%
params = {
       'axes.labelsize': 12,
       'font.size': 12,
       'legend.fontsize': 12,
       'xtick.labelsize': 12,
       'ytick.labelsize': 12,
       'text.usetex': False,
       'figure.figsize': [24, 4],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'

fig1,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(mining_response_no2_50yoy.cumsum().loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax1.plot(mining_response_no2_50yoy_inc100.cumsum().loc['20170101':], label='Ref. Import +100',color=colors[1])
ax1.plot(mining_response_no2_50yoy_inc200.cumsum().loc['20170101':], label='Ref. Import +200',color=colors[3])
ax1.plot(mining_response_no2_50yoy_dec100.cumsum().loc['20170101':], label='Ref. Import -100',color=colors[2])
ax1.plot(mining_response_no2_50yoy_dec200.cumsum().loc['20170101':], label='Ref. Import -200',color=colors[4])
ax1.set_title('Mining Response above Baseline \nRefined Import Sensitivity, No.2 Ban 50% YOY')
ax1.set_ylabel('Mining response above baseline (kt)')

ax1.legend(loc='upper left')
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(mining_response_alloyed_50yoy.cumsum().loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax2.plot(mining_response_alloyed_50yoy_inc100.cumsum().loc['20170101':], label='Ref. Import +100',color=colors[1])
ax2.plot(mining_response_alloyed_50yoy_inc200.cumsum().loc['20170101':], label='Ref. Import +200',color=colors[3])
ax2.plot(mining_response_alloyed_50yoy_dec100.cumsum().loc['20170101':], label='Ref. Import -100',color=colors[2])
ax2.plot(mining_response_alloyed_50yoy_dec200.cumsum().loc['20170101':], label='Ref. Import -200',color=colors[4])
ax2.set_title('Mining Response above Baseline \nRefined Import Sensitivity, Alloyed Ban 50% YOY')
ax2.set_ylabel('Mining response above baseline (kt)')

# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(mining_response_both_50yoy.cumsum().loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax3.plot(mining_response_both_50yoy_inc100.cumsum().loc['20170101':], label='Ref. Import +100',color=colors[1])
ax3.plot(mining_response_both_50yoy_inc200.cumsum().loc['20170101':], label='Ref. Import +200',color=colors[3])
ax3.plot(mining_response_both_50yoy_dec100.cumsum().loc['20170101':], label='Ref. Import -100',color=colors[2])
ax3.plot(mining_response_both_50yoy_dec200.cumsum().loc['20170101':], label='Ref. Import -200',color=colors[4])
ax3.set_title('Mining Response above Baseline \nRefined Import Sensitivity, <99% Cu Ban 50% YOY')
ax3.set_ylabel('Mining response above baseline (kt)')

# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

fig2,(ax1,ax2,ax3) = plt.subplots(1,3, frameon=False)
ax1.plot(mining_response_no2_50yoy.cumsum().loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax1.plot(mining_response_no2_25yoy.cumsum().loc['20170101':], label='25% YOY',color=colors[1])
ax1.plot(mining_response_no2_75yoy.cumsum().loc['20170101':], label='75% YOY',color=colors[3])
ax1.set_title('Mining Response above Baseline \nImport Ban Rate Sensitivity, No.2 Banned')
ax1.set_ylabel('Mining response above baseline (kt)')

ax1.legend(loc='upper left')
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax2.plot(mining_response_alloyed_50yoy.cumsum().loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax2.plot(mining_response_alloyed_25yoy.cumsum().loc['20170101':], label='25% YOY',color=colors[1])
ax2.plot(mining_response_alloyed_75yoy.cumsum().loc['20170101':], label='75% YOY',color=colors[3])
ax2.set_title('Mining Response above Baseline \nImport Ban Rate Sensitivity, Alloyed Banned')
ax2.set_ylabel('Mining response above baseline (kt)')

# ax2.legend()
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

ax3.plot(mining_response_both_50yoy.cumsum().loc['20170101':], label='No.2 Ban Baseline',color=colors[0])
ax3.plot(mining_response_both_25yoy.cumsum().loc['20170101':], label='25% YOY',color=colors[1])
ax3.plot(mining_response_both_75yoy.cumsum().loc['20170101':], label='75% YOY',color=colors[3])
ax3.set_title('Mining Response above Baseline \nImport Ban Rate Sensitivity, <99% Cu Banned')
ax3.set_ylabel('Mining response above baseline (kt)')
# ax3.legend()
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)

# %% [markdown]
# Fill between plots, refined import senstivities

# %%
init_plot()
plt.plot(mining_pctinc2020_both_50yoy_inc200.loc['20180101':])
plt.plot(scrap_demand_pctinc2020_both_50yoy_inc200_gl.loc['20180101':])
plt.plot(100*(cathode_price_series_both_50yoy_inc200-cathode_price_series_pir_baseline).loc['20180101':]/cathode_price_series_pir_baseline.loc['20180101'])
plt.show()

# %%
plt.figure()
pplot(mining_pctinc2020_both_50yoy.loc['20180101':], '<99% Ban', colors[2], firstcall=1)
plt.fill_between(mining_pctinc2020_both_50yoy.loc['20180101':].index, 
                 np.sort(pd.concat([mining_pctinc2020_both_50yoy_inc100.loc['20180101':], mining_pctinc2020_both_50yoy_dec100.loc['20180101':], mining_pctinc2020_both_50yoy_inc200.loc['20180101':], mining_pctinc2020_both_50yoy_dec200.loc['20180101':], mining_pctinc2020_both_50yoy.loc['20180101':]], axis=1).values)[:,0], 
                 np.sort(pd.concat([mining_pctinc2020_both_50yoy_inc100.loc['20180101':], mining_pctinc2020_both_50yoy_dec100.loc['20180101':], mining_pctinc2020_both_50yoy_inc200.loc['20180101':], mining_pctinc2020_both_50yoy_dec200.loc['20180101':], mining_pctinc2020_both_50yoy.loc['20180101':]], axis=1).values)[:,-1], 
                 color = colors[2], alpha=0.3)
plt.fill_between(mining_pctinc2020_both_50yoy.loc['20180101':].index, 
                 np.sort(pd.concat([mining_pctinc2020_both_50yoy_inc100.loc['20180101':], mining_pctinc2020_both_50yoy_dec100.loc['20180101':], mining_pctinc2020_both_50yoy_inc200.loc['20180101':], mining_pctinc2020_both_50yoy_dec200.loc['20180101':], mining_pctinc2020_both_50yoy.loc['20180101':]], axis=1).values)[:,1], 
                 np.sort(pd.concat([mining_pctinc2020_both_50yoy_inc100.loc['20180101':], mining_pctinc2020_both_50yoy_dec100.loc['20180101':], mining_pctinc2020_both_50yoy_inc200.loc['20180101':], mining_pctinc2020_both_50yoy_dec200.loc['20180101':], mining_pctinc2020_both_50yoy.loc['20180101':]], axis=1).values)[:,-2], 
                 color = colors[2], alpha=0.3)
plt.title('Mining Response Above Baseline')
plt.legend().set_visible(False)
plt.ylabel('Mining response above baseline \n(Cumulative, % of 2020 value)')
plt.yticks([-5,0,5,10])
plt.show()

# %% [markdown]
# Fill between plots, import rate senstivities

# %%
params = {
       'axes.labelsize': 16,
       'font.size': 16,
       'legend.fontsize': 16,
       'xtick.labelsize': 16,
       'ytick.labelsize': 16,
       'text.usetex': False,
       'figure.figsize': [8, 5],
       'lines.linewidth': 3
       }
mpl.rcParams.update(params)
mpl.rcParams['axes.spines.left'] = False
mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False
mpl.rcParams['axes.spines.bottom'] = False
# %config InlineBackend.figure_format ='retina'

fig, ax1 = plt.subplots()
ax1.plot(mining_pctinc2020_alloyed_50yoy.loc['20180101':], label='Alloyed Ban',color=colors[0])
ax1.plot(mining_pctinc2020_no2_50yoy.loc['20180101':], label='No.2 Ban',color=colors[1])
ax1.plot(mining_pctinc2020_both_50yoy.loc['20180101':], label='Both Ban',color=colors[2])

ax1.fill_between(mining_pctinc2020_alloyed_50yoy.loc['20180101':].index, 
                 pd.concat([mining_pctinc2020_alloyed_50yoy.loc['20180101':], mining_pctinc2020_alloyed_25yoy.loc['20180101':], mining_pctinc2020_alloyed_75yoy.loc['20180101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([mining_pctinc2020_alloyed_50yoy.loc['20180101':], mining_pctinc2020_alloyed_25yoy.loc['20180101':], mining_pctinc2020_alloyed_75yoy.loc['20180101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[0], alpha=0.3)
ax1.fill_between(mining_pctinc2020_no2_50yoy.loc['20180101':].index, 
                 pd.concat([mining_pctinc2020_no2_50yoy.loc['20180101':], mining_pctinc2020_no2_25yoy.loc['20180101':], mining_pctinc2020_no2_75yoy.loc['20180101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([mining_pctinc2020_no2_50yoy.loc['20180101':], mining_pctinc2020_no2_25yoy.loc['20180101':], mining_pctinc2020_no2_75yoy.loc['20180101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[1], alpha=0.3)
ax1.fill_between(mining_pctinc2020_both_50yoy.loc['20180101':].index, 
                 pd.concat([mining_pctinc2020_both_50yoy.loc['20180101':], mining_pctinc2020_both_25yoy.loc['20180101':], mining_pctinc2020_both_75yoy.loc['20180101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([mining_pctinc2020_both_50yoy.loc['20180101':], mining_pctinc2020_both_25yoy.loc['20180101':], mining_pctinc2020_both_75yoy.loc['20180101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[2], alpha=0.3)

ax1.set_title('Global Mining Production Response')
ax1.set_ylabel('Cumulative mining production response\n(% of 2020 value)')
if len(ax1.get_yticks()) < 6:
    pass
elif 0 in ax1.get_yticks()[::2]:
    ax1.set_yticks(ax1.get_yticks()[::2])
else:
    ax1.set_yticks(ax1.get_yticks()[1::2])

low, high = ax1.get_ylim()
if low == ax1.get_yticks()[0] and low<0:
    ax1.set_ylim(low*1.1, high)
elif low == ax1.get_yticks()[0] and low > 0:
    ax1.set_ylim(low*0.9, high)
# ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
ax1.set_axisbelow(True)

# %% [markdown]
# ### COVID Scenarios

# %%
pplot(mining_pctinc2020_covid99.cumsum().loc['20180101':], '2020 Demand X 0.99', colors[0], firstcall=1)
pplot(mining_pctinc2020_covid95.cumsum().loc['20180101':], '2020 Demand X 0.95', colors[1])
pplot(mining_pctinc2020_covid90.cumsum().loc['20180101':], '2020 Demand X 0.90', colors[2])
pplot(mining_pctinc2020_covid85.cumsum().loc['20180101':], '2020 Demand X 0.85', colors[3])
pplot(mining_pctinc2020_covid80.cumsum().loc['20180101':], '2020 Demand X 0.80', colors[4])
pplot(mining_pctinc2020_covid75.cumsum().loc['20180101':], '2020 Demand X 0.75', 'gray')
plt.ylabel('Cumulative mining response \n(% of 2020 production)')
plt.title('Cumulative Mining Production Response')
plt.legend().set_visible(False)

plt.figure()
dmd_index = list([i for i in direct_melt_demand_covid_baseline_gl.columns if 'Ref' not in i])+list(['Ref_Cu'])
pplot(0.001*direct_melt_demand_covid_baseline_gl.loc['20180101':, dmd_index].sum(axis=1), 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(0.001*direct_melt_demand_covid99_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.99', colors[0])
pplot(0.001*direct_melt_demand_covid95_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.95', colors[1])
pplot(0.001*direct_melt_demand_covid90_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.90', colors[2])
pplot(0.001*direct_melt_demand_covid85_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.85', colors[3])
pplot(0.001*direct_melt_demand_covid80_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.80', colors[4])
pplot(0.001*direct_melt_demand_covid75_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.75', 'gray')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2019,1,1), pd.datetime(2019,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2020,1,1), pd.datetime(2020,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2021,1,1), pd.datetime(2021,1,1)]), '2019','k')
plt.legend().set_visible(False)
plt.ylabel('Total annual copper consumption (Mt)')
plt.title('Total Annual Copper Consumption')

plt.figure()
pplot(0.001*sd_covid_baseline_gl.loc['20180101':, 'Refined demand'], 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(0.001*sd_covid99_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.99', colors[0])
pplot(0.001*sd_covid95_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.95', colors[1])
pplot(0.001*sd_covid90_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.90', colors[2])
pplot(0.001*sd_covid85_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.85', colors[3])
pplot(0.001*sd_covid80_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.80', colors[4])
pplot(0.001*sd_covid75_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.75', 'gray')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2019,1,1), pd.datetime(2019,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2020,1,1), pd.datetime(2020,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2021,1,1), pd.datetime(2021,1,1)]), '2019','k')
plt.legend().set_visible(False)
plt.ylabel('Annual refined copper consumption (Mt)')
plt.ylim(18.2,32.9)
plt.title('Total Annual Refined Copper Consumption')

plt.figure()
pplot(cathode_price_series_covid_baseline.loc['20180101':], 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(cathode_price_series_covid99.loc['20180101':], '2020 Demand X 0.99', colors[0])
pplot(cathode_price_series_covid95.loc['20180101':], '2020 Demand X 0.95', colors[1])
pplot(cathode_price_series_covid90.loc['20180101':], '2020 Demand X 0.90', colors[2])
pplot(cathode_price_series_covid85.loc['20180101':], '2020 Demand X 0.85', colors[3])
pplot(cathode_price_series_covid80.loc['20180101':], '2020 Demand X 0.80', colors[4])
pplot(cathode_price_series_covid75.loc['20180101':], '2020 Demand X 0.75', 'gray')
plt.legend().set_visible(False)
plt.ylabel('Cathode price (USD/tonne)')
# plt.ylim(18.2,32.9)
plt.title('Annual Cathode Price')

# %% [markdown]
# Same as above but for smaller declinations

# %%
pplot(cathode_price_series_covid_baseline.loc['20180101':], 'COVID Baseline', 'k', firstcall=1, linewidth=2)
pplot(cathode_price_series_pir_baseline.loc['20180101':], 'PIR Baseline', colors[0])
pplot(cathode_price_series_covid_baseline.loc['20180101':]-spa_series_covid_baseline_gl.loc['20180101':], 'COVID Baseline', colors[1])
pplot(cathode_price_series_pir_baseline.loc['20180101':]-spa_series_pir_baseline_gl.loc['20180101':], 'PIR Baseline', colors[2])
pplot(cathode_price_series_covid_baseline.loc['20180101':]-sp2_series_covid_baseline_gl.loc['20180101':], 'COVID Baseline', colors[3])
pplot(cathode_price_series_pir_baseline.loc['20180101':]-sp2_series_pir_baseline_gl.loc['20180101':], 'PIR Baseline', colors[4])

# %%
pplot(mining_pctinc2020_covid99.cumsum().loc['20180101':], '2020 Demand X 0.99', colors[0], firstcall=1)
pplot(mining_pctinc2020_covid98.cumsum().loc['20180101':], '2020 Demand X 0.98', colors[1])
pplot(mining_pctinc2020_covid97.cumsum().loc['20180101':], '2020 Demand X 0.97', colors[2])
pplot(mining_pctinc2020_covid96.cumsum().loc['20180101':], '2020 Demand X 0.96', colors[3])
pplot(mining_pctinc2020_covid95.cumsum().loc['20180101':], '2020 Demand X 0.95', colors[4])
pplot(mining_pctinc2020_covid94.cumsum().loc['20180101':], '2020 Demand X 0.94', 'gray')
plt.ylabel('Cumulative mining response \n(% of 2020 production)')
plt.title('Cumulative Mining Production Response')
plt.legend().set_visible(False)

plt.figure()
dmd_index = list([i for i in direct_melt_demand_covid_baseline_gl.columns if 'Ref' not in i])+list(['Ref_Cu'])
pplot(0.001*direct_melt_demand_covid_baseline_gl.loc['20180101':, dmd_index].sum(axis=1), 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(0.001*direct_melt_demand_covid99_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.99', colors[0])
pplot(0.001*direct_melt_demand_covid98_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.98', colors[1])
pplot(0.001*direct_melt_demand_covid97_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.97', colors[2])
pplot(0.001*direct_melt_demand_covid96_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.96', colors[3])
pplot(0.001*direct_melt_demand_covid95_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.95', colors[4])
pplot(0.001*direct_melt_demand_covid94_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.94', 'gray')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2019,1,1), pd.datetime(2019,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2020,1,1), pd.datetime(2020,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2021,1,1), pd.datetime(2021,1,1)]), '2019','k')
plt.legend().set_visible(False)
plt.ylabel('Total annual copper consumption (Mt)')
plt.title('Total Annual Copper Consumption')

plt.figure()
pplot(0.001*sd_covid_baseline_gl.loc['20180101':, 'Refined demand'], 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(0.001*sd_covid99_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.99', colors[0])
pplot(0.001*sd_covid98_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.98', colors[1])
pplot(0.001*sd_covid97_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.97', colors[2])
pplot(0.001*sd_covid96_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.96', colors[3])
pplot(0.001*sd_covid95_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.95', colors[4])
pplot(0.001*sd_covid94_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.94', 'gray')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2019,1,1), pd.datetime(2019,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2020,1,1), pd.datetime(2020,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2021,1,1), pd.datetime(2021,1,1)]), '2019','k')
plt.legend().set_visible(False)
plt.ylabel('Annual refined copper consumption (Mt)')
plt.ylim(18.2,32.9)
plt.title('Total Annual Refined Copper Consumption')

plt.figure()
pplot(cathode_price_series_covid_baseline.loc['20180101':], 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(cathode_price_series_covid99.loc['20180101':], '2020 Demand X 0.99', colors[0])
pplot(cathode_price_series_covid98.loc['20180101':], '2020 Demand X 0.98', colors[1])
pplot(cathode_price_series_covid97.loc['20180101':], '2020 Demand X 0.97', colors[2])
pplot(cathode_price_series_covid96.loc['20180101':], '2020 Demand X 0.96', colors[3])
pplot(cathode_price_series_covid95.loc['20180101':], '2020 Demand X 0.95', colors[4])
pplot(cathode_price_series_covid94.loc['20180101':], '2020 Demand X 0.94', 'gray')
plt.legend().set_visible(False)
plt.ylabel('Cathode price (USD/tonne)')
# plt.ylim(18.2,32.9)
plt.title('Annual Cathode Price')

# %%
pplot(cathode_price_series_covid_baseline.loc['20180101':], 'COVID Baseline', 'k', firstcall=1, linewidth=2)
pplot(cathode_price_series_pir_baseline.loc['20180101':], 'PIR Baseline', colors[0])
pplot(cathode_price_series_covid_baseline.loc['20180101':]-spa_series_covid_baseline_gl.loc['20180101':], 'COVID Baseline', colors[1])
pplot(cathode_price_series_pir_baseline.loc['20180101':]-spa_series_pir_baseline_gl.loc['20180101':], 'PIR Baseline', colors[2])
pplot(cathode_price_series_covid_baseline.loc['20180101':]-sp2_series_covid_baseline_gl.loc['20180101':], 'COVID Baseline', colors[3])
pplot(cathode_price_series_pir_baseline.loc['20180101':]-sp2_series_pir_baseline_gl.loc['20180101':], 'PIR Baseline', colors[4])

# %% [markdown]
# ### COVID IMF Shock

# %%
pplot(mining_pctinc2020_covidimf_shock.loc['20180101':], 'IMF Shock Only', colors[0], firstcall=1)
pplot(mining_pctinc2020_covidimf_both_50yoy.loc['20180101':], 'Shock + Both Ban', colors[1])
pplot(mining_pctinc2020_covidimf_alloyed_50yoy.loc['20180101':], 'Shock + Alloyed Ban', colors[2])
pplot(mining_pctinc2020_covidimf_no2_50yoy.loc['20180101':], 'Shock + No.2 Ban', colors[3])
pplot(mining_pctinc2020_covidimf_both_50yoy_inc100.loc['20180101':], 'Shock + Both Ban + 100', colors[4])
pplot(mining_pctinc2020_covidimf_both_50yoy_dec100.loc['20180101':], 'Shock + Both Ban - 100')
pplot(mining_pctinc2020_covidimf_both_50yoy_inc200.loc['20180101':], 'Shock + Both Ban + 200')
pplot(mining_pctinc2020_covidimf_both_50yoy_dec200.loc['20180101':], 'Shock + Both Ban - 200')
plt.ylabel('Cumulative mining response \n(% of 2020 production)')
plt.title('Cumulative Mining Production Response')
# plt.legend().set_visible(False)

plt.figure()
dmd_index = list([i for i in direct_melt_demand_covidimf_baseline_gl.columns if 'Ref' not in i])+list(['Ref_Cu'])
pplot(0.001*direct_melt_demand_covidimf_baseline_gl.loc['20180101':, dmd_index].sum(axis=1), 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(0.001*direct_melt_demand_covidimf_shock_gl.loc['20180101':, dmd_index].sum(axis=1), 'IMF Shock Only', colors[0])
pplot(0.001*direct_melt_demand_covidimf_both_50yoy_gl.loc['20180101':, dmd_index].sum(axis=1), 'Shock + Both Ban', colors[1])
pplot(0.001*direct_melt_demand_covidimf_alloyed_50yoy_gl.loc['20180101':, dmd_index].sum(axis=1), 'Shock + Alloyed Ban', colors[2])
pplot(0.001*direct_melt_demand_covidimf_no2_50yoy_gl.loc['20180101':, dmd_index].sum(axis=1), 'Shock + No.2 Ban', colors[3])
pplot(0.001*direct_melt_demand_covidimf_both_50yoy_inc100_gl.loc['20180101':, dmd_index].sum(axis=1), 'Shock + Both Ban + 100', colors[4])
pplot(0.001*direct_melt_demand_covidimf_both_50yoy_dec100_gl.loc['20180101':, dmd_index].sum(axis=1), 'Shock + Both Ban - 100', 'gray')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2019,1,1), pd.datetime(2019,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2020,1,1), pd.datetime(2020,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2021,1,1), pd.datetime(2021,1,1)]), '2019','k')
plt.legend().set_visible(False)
plt.ylabel('Total annual copper consumption (Mt)')
plt.title('Total Annual Copper Consumption')

plt.figure()
pplot(0.001*sd_covidimf_baseline_gl.loc['20180101':, 'Refined demand'], 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(0.001*sd_covidimf_shock_gl.loc['20180101':, 'Refined demand'], 'IMF Shock Only', colors[0])
pplot(0.001*sd_covidimf_both_50yoy_gl.loc['20180101':, 'Refined demand'], 'Shock + Both Ban', colors[1])
pplot(0.001*sd_covidimf_alloyed_50yoy_gl.loc['20180101':, 'Refined demand'], 'Shock + Alloyed Ban', colors[2])
pplot(0.001*sd_covidimf_no2_50yoy_gl.loc['20180101':, 'Refined demand'], 'Shock + No.2 Ban', colors[3])
pplot(0.001*sd_covidimf_both_50yoy_inc100_gl.loc['20180101':, 'Refined demand'], 'Shock + Both Ban + 100', colors[4])
pplot(0.001*sd_covidimf_both_50yoy_dec100_gl.loc['20180101':, 'Refined demand'], 'Shock + Both Ban - 100', 'gray')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2019,1,1), pd.datetime(2019,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2020,1,1), pd.datetime(2020,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2021,1,1), pd.datetime(2021,1,1)]), '2019','k')
plt.legend().set_visible(False)
plt.ylabel('Annual refined copper consumption (Mt)')
plt.ylim(18.2,32.9)
plt.title('Total Annual Refined Copper Consumption')

plt.figure()
pplot(cathode_price_series_covidimf_baseline.loc['20180101':], 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(cathode_price_series_covidimf_shock.loc['20180101':], 'IMF Shock Only', colors[0])
pplot(cathode_price_series_covidimf_both_50yoy.loc['20180101':], 'Shock + Both Ban', colors[1])
pplot(cathode_price_series_covidimf_alloyed_50yoy.loc['20180101':], 'Shock + Alloyed Ban', colors[2])
pplot(cathode_price_series_covidimf_no2_50yoy.loc['20180101':], 'Shock + No.2 Ban', colors[3])
pplot(cathode_price_series_covidimf_both_50yoy_inc100.loc['20180101':], 'Shock + Both Ban + 100', colors[4])
pplot(cathode_price_series_covidimf_both_50yoy_dec100.loc['20180101':], 'Shock + Both Ban - 100', 'gray')
plt.legend().set_visible(False)
plt.ylabel('Cathode price (USD/tonne)')
# plt.ylim(18.2,32.9)
plt.title('Annual Cathode Price')

plt.figure()
pplot(scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':], '<99% Ban', colors[2], firstcall=1)
plt.fill_between(scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':].index, 
                 np.sort(pd.concat([scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,0], 
                 np.sort(pd.concat([scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,-1], 
                 color = colors[2], alpha=0.3)
plt.fill_between(scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':].index, 
                 np.sort(pd.concat([scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,1], 
                 np.sort(pd.concat([scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,-2], 
                 color = colors[2], alpha=0.3)
# pplot(scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_gl.loc['20180101':], '<99% Ban', 'limegreen')

plt.title('Scrap Consumption Response Above Baseline')
plt.legend().set_visible(False)
plt.ylabel('Scrap consumption response \n(Cumulative, % of 2020 value)')
# plt.yticks([-20,-10,0,10])
plt.show()

# %% [markdown]
# Same as above but for smaller declinations

# %%
pplot(cathode_price_series_covid_baseline.loc['20180101':], 'COVID Baseline', 'k', firstcall=1, linewidth=2)
pplot(cathode_price_series_pir_baseline.loc['20180101':], 'PIR Baseline', colors[0])
pplot(cathode_price_series_covid_baseline.loc['20180101':]-spa_series_covid_baseline_gl.loc['20180101':], 'COVID Baseline', colors[1])
pplot(cathode_price_series_pir_baseline.loc['20180101':]-spa_series_pir_baseline_gl.loc['20180101':], 'PIR Baseline', colors[2])
pplot(cathode_price_series_covid_baseline.loc['20180101':]-sp2_series_covid_baseline_gl.loc['20180101':], 'COVID Baseline', colors[3])
pplot(cathode_price_series_pir_baseline.loc['20180101':]-sp2_series_pir_baseline_gl.loc['20180101':], 'PIR Baseline', colors[4])

# %%
pplot(mining_pctinc2020_covid99.cumsum().loc['20180101':], '2020 Demand X 0.99', colors[0], firstcall=1)
pplot(mining_pctinc2020_covid98.cumsum().loc['20180101':], '2020 Demand X 0.98', colors[1])
pplot(mining_pctinc2020_covid97.cumsum().loc['20180101':], '2020 Demand X 0.97', colors[2])
pplot(mining_pctinc2020_covid96.cumsum().loc['20180101':], '2020 Demand X 0.96', colors[3])
pplot(mining_pctinc2020_covid95.cumsum().loc['20180101':], '2020 Demand X 0.95', colors[4])
pplot(mining_pctinc2020_covid94.cumsum().loc['20180101':], '2020 Demand X 0.94', 'gray')
plt.ylabel('Cumulative mining response \n(% of 2020 production)')
plt.title('Cumulative Mining Production Response')
plt.legend().set_visible(False)

plt.figure()
dmd_index = list([i for i in direct_melt_demand_covid_baseline_gl.columns if 'Ref' not in i])+list(['Ref_Cu'])
pplot(0.001*direct_melt_demand_covid_baseline_gl.loc['20180101':, dmd_index].sum(axis=1), 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(0.001*direct_melt_demand_covid99_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.99', colors[0])
pplot(0.001*direct_melt_demand_covid98_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.98', colors[1])
pplot(0.001*direct_melt_demand_covid97_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.97', colors[2])
pplot(0.001*direct_melt_demand_covid96_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.96', colors[3])
pplot(0.001*direct_melt_demand_covid95_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.95', colors[4])
pplot(0.001*direct_melt_demand_covid94_gl.loc['20180101':, dmd_index].sum(axis=1), '2020 Demand X 0.94', 'gray')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2019,1,1), pd.datetime(2019,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2020,1,1), pd.datetime(2020,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2021,1,1), pd.datetime(2021,1,1)]), '2019','k')
plt.legend().set_visible(False)
plt.ylabel('Total annual copper consumption (Mt)')
plt.title('Total Annual Copper Consumption')

plt.figure()
pplot(0.001*sd_covid_baseline_gl.loc['20180101':, 'Refined demand'], 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(0.001*sd_covid99_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.99', colors[0])
pplot(0.001*sd_covid98_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.98', colors[1])
pplot(0.001*sd_covid97_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.97', colors[2])
pplot(0.001*sd_covid96_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.96', colors[3])
pplot(0.001*sd_covid95_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.95', colors[4])
pplot(0.001*sd_covid94_gl.loc['20180101':, 'Refined demand'], '2020 Demand X 0.94', 'gray')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2019,1,1), pd.datetime(2019,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2020,1,1), pd.datetime(2020,1,1)]), '2019','k')
# pplot(pd.Series([26000,43000], index = [pd.datetime(2021,1,1), pd.datetime(2021,1,1)]), '2019','k')
plt.legend().set_visible(False)
plt.ylabel('Annual refined copper consumption (Mt)')
plt.ylim(18.2,32.9)
plt.title('Total Annual Refined Copper Consumption')

plt.figure()
pplot(cathode_price_series_covid_baseline.loc['20180101':], 'Baseline', 'k', firstcall=1, linewidth=2)
pplot(cathode_price_series_covid99.loc['20180101':], '2020 Demand X 0.99', colors[0])
pplot(cathode_price_series_covid98.loc['20180101':], '2020 Demand X 0.98', colors[1])
pplot(cathode_price_series_covid97.loc['20180101':], '2020 Demand X 0.97', colors[2])
pplot(cathode_price_series_covid96.loc['20180101':], '2020 Demand X 0.96', colors[3])
pplot(cathode_price_series_covid95.loc['20180101':], '2020 Demand X 0.95', colors[4])
pplot(cathode_price_series_covid94.loc['20180101':], '2020 Demand X 0.94', 'gray')
plt.legend().set_visible(False)
plt.ylabel('Cathode price (USD/tonne)')
# plt.ylim(18.2,32.9)
plt.title('Annual Cathode Price')

# %%
pplot(cathode_price_series_covid_baseline.loc['20180101':], 'COVID Baseline', 'k', firstcall=1, linewidth=2)
pplot(cathode_price_series_pir_baseline.loc['20180101':], 'PIR Baseline', colors[0])
pplot(cathode_price_series_covid_baseline.loc['20180101':]-spa_series_covid_baseline_gl.loc['20180101':], 'COVID Baseline', colors[1])
pplot(cathode_price_series_pir_baseline.loc['20180101':]-spa_series_pir_baseline_gl.loc['20180101':], 'PIR Baseline', colors[2])
pplot(cathode_price_series_covid_baseline.loc['20180101':]-sp2_series_covid_baseline_gl.loc['20180101':], 'COVID Baseline', colors[3])
pplot(cathode_price_series_pir_baseline.loc['20180101':]-sp2_series_pir_baseline_gl.loc['20180101':], 'PIR Baseline', colors[4])

# %% [markdown]
# ### Fruity mining response

# %%
# historical_ref_imports_cn.loc[i] = historical_ref_imports_cn.loc[2018] + (i-2018)*200
# 1276.206684
ref_imports=pd.read_excel('Production data compile.xlsx', sheet_name='China', index_col=0, usecols='A:O,W:X,AE').loc[1983:2018, 'Net Refined Imports']
ref_imports_i100 = ref_imports.copy()
ref_imports_i200 = ref_imports.copy()
ref_imports_d100 = ref_imports.copy()
ref_imports_d200 = ref_imports.copy()
for i in np.arange(2019,2041):
    ref_imports.loc[i] = ref_imports.loc[2018]
    ref_imports_i100.loc[i] = ref_imports.loc[2018] + (i-2018)*100
    ref_imports_i200.loc[i] = ref_imports.loc[2018] + (i-2018)*200
    ref_imports_d100.loc[i] = ref_imports.loc[2018] - (i-2018)*100
    ref_imports_d200.loc[i] = ref_imports.loc[2018] - (i-2018)*200

ref_imports_d100[ref_imports_d100<0] = 0
ref_imports_d200[ref_imports_d200<0] = 0

pplot(ref_imports_i200, '+200', colors[0], firstcall=1)
pplot(ref_imports_i100, '+100', colors[1])
pplot(ref_imports, 'Baseline', colors[2])
pplot(ref_imports_d100, '-100', colors[3])
pplot(ref_imports_d200, '-200', colors[4])
pplot(ref_imports.loc[:2018], 'Historical', 'red')
plt.plot([2018,2018],[100,4250],'k--')
plt.legend().set_visible(False)
plt.title('China Refined Copper Imports')
plt.ylabel('China net refined copper imports (kt)')

# %%
pplot(mining_pctinc2020_fruity1rr11.loc['20190101':], label='0.1% Recycled Content',color='tab:gray',firstcall=1)
pplot(mining_pctinc2020_fruity1rr50.loc['20190101':], label='50% Recycled Content',color='tab:blue')
pplot(mining_pctinc2020_fruity1rr90.loc['20190101':], label='90% Recycled Content',color='tab:green')
pplot(mining_pctinc2020_fruity1rr100.loc['20190101':], label='100% Recycled Content',color='tab:red')
plt.xlabel('Year')
plt.ylabel('Mining response above baseline (% of 2020 Production)')
plt.title('Mining Response above Baseline \n0.08% of Copper Market')

plt.figure()
pplot(mining_pctinc2020_fruity_pct1rr11.loc['20190101':], label='0.1% Recycled Content',color='tab:gray')
pplot(mining_pctinc2020_fruity_pct1rr50.loc['20190101':], label='50% Recycled Content',color='tab:blue')
pplot(mining_pctinc2020_fruity_pct1rr90.loc['20190101':], label='90% Recycled Content',color='tab:green')
pplot(mining_pctinc2020_fruity_pct1rr100.loc['20190101':], label='100% Recycled Content',color='tab:red')
plt.xlabel('Year')
plt.ylabel('Mining response above baseline (% of 2020 Production)')
plt.title('Mining Response above Baseline \n1% of Copper Market')

plt.figure()
pplot(mining_pctinc2020_fruity_pct5rr11.loc['20190101':], label='0.1% Recycled Content',color='tab:gray')
pplot(mining_pctinc2020_fruity_pct5rr50.loc['20190101':], label='50% Recycled Content',color='tab:blue')
pplot(mining_pctinc2020_fruity_pct5rr90.loc['20190101':], label='90% Recycled Content',color='tab:green')
pplot(mining_pctinc2020_fruity_pct5rr100.loc['20190101':], label='100% Recycled Content',color='tab:red')
plt.xlabel('Year')
plt.ylabel('Mining response above baseline (% of 2020 Production)')
plt.title('Mining Response above Baseline \n5% of Copper Market')

plt.figure()
pplot(mining_pctinc2020_fruity_pct10rr11.loc['20190101':], label='0.1% Recycled Content',color=colors[0], firstcall=1)
pplot(mining_pctinc2020_fruity_pct10rr50.loc['20190101':], label='50% Recycled Content',color=colors[1])
pplot(mining_pctinc2020_fruity_pct10rr70.loc['20190101':], label='70% Recycled Content',color=colors[2])
pplot(mining_pctinc2020_fruity_pct10rr90.loc['20190101':], label='90% Recycled Content',color=colors[3])
# plt.xlabel('Year')
plt.legend().set_visible(False)
plt.ylabel('Mining response above baseline \n(% of 2020 Production)')
plt.title('Cumulative Change in Mining Production Relative to Baseline \n10% of Copper Market')

plt.figure()
pplot(mining_pctinc2020_fruity1rr100.loc['20190101':], label='fruity 1X 100% Recycled Content',color='tab:blue')
pplot(mining_pctinc2020_fruity_pct1rr100.loc['20190101':], label='1mrk% 100% Recycled Content',color='tab:green')
pplot(mining_pctinc2020_fruity_pct5rr100.loc['20190101':], label='5mrk% 100% Recycled Content',color='tab:red')
pplot(mining_pctinc2020_fruity_pct10rr90.loc['20190101':], label='10mrk% 90% Recycled Content',color='tab:gray')
plt.xlabel('Year')
plt.ylabel('Mining response above baseline (% of 2020 Production)')
plt.title('Mining Response above Baseline \nVarious Market Fractions')
plt.show()

# %%
init_plot()
pplot(mining_pctinc2020_fruity_pct10rr50var10.loc['20180101':], label='10mrk% 50% RR, var10',color=colors[0],firstcall=1)
pplot(mining_pctinc2020_fruity_pct10rr50var30.loc['20180101':], label='10mrk% 50% RR, var30',color=colors[1])
pplot(mining_pctinc2020_fruity_pct10rr50var50.loc['20180101':], label='10mrk% 50% RR, var50',color=colors[2])
pplot(mining_pctinc2020_fruity_pct10rr50var70.loc['20180101':], label='10mrk% 50% RR, var70',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([5,0, -5,-10,-15])
plt.ylim(-4.1,7.5)
plt.ylabel('Mining response above baseline \n(% of 2020 production)')
plt.suptitle('Global Mining Response above Baseline')
plt.title('10% of Copper Market', color = color_10)

# %%
# pplot(mining_pctinc2020_fruity1rr100var0.loc['20180101':], label='1X 100% RR, var0',color=colors[0],firstcall=1)
pplot(mining_pctinc2020_fruity1rr100var10.loc['20180101':], label='1X 100% RR, var10',color=colors[0], firstcall=1)
pplot(mining_pctinc2020_fruity1rr100var30.loc['20180101':], label='1X 100% RR, var30',color=colors[1])
pplot(mining_pctinc2020_fruity1rr100var50.loc['20180101':], label='1X 100% RR, var50',color=colors[2])
pplot(mining_pctinc2020_fruity1rr100var70.loc['20180101':], label='1X 100% RR, var70',color=colors[3])
# pplot(mining_pctinc2020_fruity1rr100var90.loc['20180101':], label='1X 100% RR, var90',color=colors[3])
plt.legend().set_visible(False)
# plt.xlabel('Year')
# plt.yticks([0, 1, 2])
plt.ylim(-4.1,7.5)
plt.ylabel('Mining response above baseline \n(% of 2020 production)')
plt.suptitle('Global Mining Response above Baseline')
plt.title('0.08% of Copper Market', color = color_08)

# %%
pd.concat([cathode_price_series_fruity_pct10rr50var70, cathode_price_series_fruity_pct10rr50var70-sp2_series_fruity_pct10rr50var70_gl, cathode_price_series_fruity_pct10rr50var70-sp2_series_fruity_pct10rr50var70_cn, cathode_price_series_fruity_pct10rr50var70-sp2_series_fruity_pct10rr50var70_rw],keys=['Cathode','Global','China','RoW'],axis=1).plot()
price_fruity_pct10rr50var70

# %%
pplot(-mining_response_fruity1rr11.loc['20190101':].cumsum(), label = 'Fruity 1X 1% RR')
pplot(-mining_response_fruity1rr50.loc['20190101':].cumsum(), label = 'Fruity 1X 50% RR')
pplot(-mining_response_fruity1rr90.loc['20190101':].cumsum(), label = 'Fruity 1X 90% RR', color = 'tab:green')
pplot(-mining_response_fruity1rr100.loc['20190101':].cumsum(), label = 'Fruity 1X 100% RR', color = 'tab:gray')
plt.title('Mining production reduction below baseline \nGlobal, 0.08% of market')
plt.legend()
plt.title('Mining production reduction below baseline (kt)\nGlobal')

plt.figure()
pplot(-mining_response_fruity_pct1rr11.loc['20190101':].cumsum(), label = 'Fruity 1mrk% 1% RR')
pplot(-mining_response_fruity_pct1rr50.loc['20190101':].cumsum(), label = 'Fruity 1mrk% 50% RR')
pplot(-mining_response_fruity_pct1rr90.loc['20190101':].cumsum(), label = 'Fruity 1mrk% 90% RR', color = 'tab:green')
pplot(-mining_response_fruity_pct1rr100.loc['20190101':].cumsum(), label = 'Fruity 1mrk% 100% RR', color = 'tab:gray')
plt.legend()
plt.title('Mining production reduction below baseline (kt)\nGlobal, 1% of market')

plt.figure()
pplot(-mining_response_fruity_pct5rr11.loc['20190101':].cumsum(), label = 'Fruity 5mrk% 1% RR')
pplot(-mining_response_fruity_pct5rr50.loc['20190101':].cumsum(), label = 'Fruity 5mrk% 50% RR')
pplot(-mining_response_fruity_pct5rr90.loc['20190101':].cumsum(), label = 'Fruity 5mrk% 90% RR', color = 'tab:green')
pplot(-mining_response_fruity_pct5rr100.loc['20190101':].cumsum(), label = 'Fruity 5mrk% 100% RR', color = 'tab:gray')
plt.legend()
plt.title('Mining production reduction below baseline (kt)\nGlobal, 5% of market')

plt.figure()
pplot(-mining_response_fruity_pct10rr11.loc['20190101':].cumsum(), label = 'Fruity 10mrk% 1% RR')
pplot(-mining_response_fruity_pct10rr50.loc['20190101':].cumsum(), label = 'Fruity 10mrk% 50% RR')
pplot(-mining_response_fruity_pct10rr70.loc['20190101':].cumsum(), label = 'Fruity 10mrk% 70% RR', color = 'tab:green')
pplot(-mining_response_fruity_pct10rr90.loc['20190101':].cumsum(), label = 'Fruity 10mrk% 90% RR', color = 'tab:gray')
plt.legend()
plt.title('Mining production reduction below baseline (kt)\nGlobal, 10% of market')

plt.figure()
pplot(-mining_response_fruity1rr90.loc['20190101':].cumsum(), label = 'Fruity 0.08mrk% 90% RR')
pplot(-mining_response_fruity_pct1rr90.loc['20190101':].cumsum(), label = 'Fruity 1mrk% 90% RR')
pplot(-mining_response_fruity_pct5rr90.loc['20190101':].cumsum(), label = 'Fruity 5mrk% 90% RR', color = 'tab:green')
pplot(-mining_response_fruity_pct10rr70.loc['20190101':].cumsum(), label = 'Fruity 10mrk% 70% RR', color = 'tab:gray')
plt.legend()
plt.title('Mining production reduction below baseline (kt)\nGlobal, varying percentages')

# %%
# pplot(mining_pctinc_fruity1rr11.loc['20190101':], label = 'Fruity 1X 1% RR')
# pplot(mining_pctinc_fruity1rr50.loc['20190101':], label = 'Fruity 1X 50% RR')
# pplot(mining_pctinc_fruity1rr90.loc['20190101':], label = 'Fruity 1X 90% RR', color = 'tab:green')
# pplot(mining_pctinc_fruity1rr100.loc['20190101':], label = 'Fruity 1X 100% RR', color = 'tab:gray')
# plt.title('Mining production percent increase above baseline \nGlobal, 0.08% of market')
# plt.legend()
# plt.title('Mining production percent increase above baseline (kt)\nGlobal')

# plt.figure()
# pplot(mining_pctinc_fruity_pct1rr11.loc['20190101':], label = 'Fruity 1mrk% 1% RR')
# pplot(mining_pctinc_fruity_pct1rr50.loc['20190101':], label = 'Fruity 1mrk% 50% RR')
# pplot(mining_pctinc_fruity_pct1rr90.loc['20190101':], label = 'Fruity 1mrk% 90% RR', color = 'tab:green')
# pplot(mining_pctinc_fruity_pct1rr100.loc['20190101':], label = 'Fruity 1mrk% 100% RR', color = 'tab:gray')
# plt.legend()
# plt.title('Mining production percent increase above baseline (kt)\nGlobal, 1% of market')

# plt.figure()
# pplot(mining_pctinc_fruity_pct5rr11.loc['20190101':], label = 'Fruity 5mrk% 1% RR')
# pplot(mining_pctinc_fruity_pct5rr50.loc['20190101':], label = 'Fruity 5mrk% 50% RR')
# pplot(mining_pctinc_fruity_pct5rr90.loc['20190101':], label = 'Fruity 5mrk% 90% RR', color = 'tab:green')
# pplot(mining_pctinc_fruity_pct5rr100.loc['20190101':], label = 'Fruity 5mrk% 100% RR', color = 'tab:gray')
# plt.legend()
# plt.title('Mining production percent increase above baseline (kt)\nGlobal, 5% of market')

# plt.figure()
# pplot(mining_pctinc_fruity_pct10rr11.loc['20190101':], label = 'Fruity 10mrk% 1% RR')
# pplot(mining_pctinc_fruity_pct10rr50.loc['20190101':], label = 'Fruity 10mrk% 50% RR')
# pplot(mining_pctinc_fruity_pct10rr70.loc['20190101':], label = 'Fruity 10mrk% 70% RR', color = 'tab:green')
# pplot(mining_pctinc_fruity_pct10rr90.loc['20190101':], label = 'Fruity 10mrk% 90% RR', color = 'tab:gray')
# plt.legend()
# plt.title('Mining production percent increase above baseline (kt)\nGlobal, 10% of market')

plt.figure()
pplot(mining_pctinc_fruity1rr90.loc['20190101':], label = 'Fruity 0.08mrk% 90% RR')
pplot(mining_pctinc_fruity_pct1rr90.loc['20190101':], label = 'Fruity 1mrk% 90% RR')
pplot(mining_pctinc_fruity_pct5rr90.loc['20190101':], label = 'Fruity 5mrk% 90% RR', color = 'tab:green')
pplot(mining_pctinc_fruity_pct10rr90.loc['20190101':], label = 'Fruity 10mrk% 90% RR', color = 'tab:gray')
plt.legend()
plt.title('Mining production percent increase above baseline (kt)\nGlobal, varying percentages')

# %% [markdown]
# ### Mining Response for Total-2X

# %%
pplot(-mining_response_1yr2X.cumsum().loc['20190101':], label='1 year, 5200')
pplot(-mining_response_t5yr.cumsum().loc['20190101':], label='5 year, 5200')
pplot(-mining_response_t10yr.cumsum().loc['20190101':], label='10 year, 5200')
pplot(-mining_response_t20yr.cumsum().loc['20190101':], label='20 year, 5200')
pplot(-mining_response_john1.cumsum().loc['20190101':], label='1 year, 2600')
pplot(-mining_response_john5.cumsum().loc['20190101':], label='4 year, 2600')


plt.title('Mining Production Reduction from Baseline \n(Total, Twice Base Shock)')
plt.ylabel('Mining production reduction from baseline (kt)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %% [markdown]
# ### Mining Response for Initial Linear Approaches
# Linear Approach to 100% Base Shock

# %%
pplot(-mining_response_lin1yr.cumsum().loc['20190101':], label='1 year ramp',color = 'tab:blue')
pplot(-mining_response_lin5yr.cumsum().loc['20190101':], label='5 year ramp',color = 'tab:orange')
pplot(-mining_response_lin10yr.cumsum().loc['20190101':], label='10 year ramp', color='lightseagreen')
pplot(-mining_response_lin20yr.cumsum().loc['20190101':], label='20 year ramp',color='tab:brown')
# pplot(-mining_response_john1.cumsum().loc['20190101':], label='1 year, 2600')
# pplot(-mining_response_john5.cumsum().loc['20190101':], label='4 year, 2600')


plt.title('Mining Production Reduction from Baseline \n(Linear Approach to 100% Base Shock)')
plt.ylabel('Mining production reduction from baseline (kt)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %% [markdown]
# Mining Response for Linear Approach to 20% Base Shock

# %%
pplot(-mining_response_lin1yr20.cumsum().loc['20190101':], label='1 year ramp',color = 'tab:blue')
pplot(-mining_response_lin5yr20.cumsum().loc['20190101':], label='5 year ramp',color = 'tab:orange')
pplot(-mining_response_lin10yr20.cumsum().loc['20190101':], label='10 year ramp', color='lightseagreen')
pplot(-mining_response_lin20yr20.cumsum().loc['20190101':], label='20 year ramp',color='tab:brown')
# pplot(-mining_response_john1.cumsum().loc['20190101':], label='1 year, 2600')
# pplot(-mining_response_john5.cumsum().loc['20190101':], label='4 year, 2600')


plt.title('Mining Production Reduction from Baseline \n(Linear Approach to 20% Base Shock)')
plt.ylabel('Mining production reduction from baseline (kt)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %% [markdown]
# Mining Response for Linear Approach to 50% Base Shock

# %%
pplot(-mining_response_lin1yr50.cumsum().loc['20190101':], label='1 year ramp',color = 'tab:blue')
pplot(-mining_response_lin5yr50.cumsum().loc['20190101':], label='5 year ramp',color = 'tab:orange')
pplot(-mining_response_lin10yr50.cumsum().loc['20190101':], label='10 year ramp', color='lightseagreen')
pplot(-mining_response_lin20yr50.cumsum().loc['20190101':], label='20 year ramp',color='tab:brown')
# pplot(-mining_response_john1.cumsum().loc['20190101':], label='1 year, 2600')
# pplot(-mining_response_john5.cumsum().loc['20190101':], label='4 year, 2600')


plt.title('Mining Production Reduction from Baseline \n(Linear Approach to 50% Base Shock)')
plt.ylabel('Mining production reduction from baseline (kt)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %% [markdown]
# Mining Response for Linear Approach to 10% Base Shock

# %%
pplot(-mining_response_lin1yr10.cumsum().loc['20190101':], label='1 year ramp',color = 'tab:blue')
pplot(-mining_response_lin5yr10.cumsum().loc['20190101':], label='5 year ramp',color = 'tab:orange')
pplot(-mining_response_lin10yr10.cumsum().loc['20190101':], label='10 year ramp', color='lightseagreen')
pplot(-mining_response_lin20yr10.cumsum().loc['20190101':], label='20 year ramp',color='tab:brown')
# pplot(-mining_response_john1.cumsum().loc['20190101':], label='1 year, 2600')
# pplot(-mining_response_john5.cumsum().loc['20190101':], label='4 year, 2600')


plt.title('Mining Production Reduction from Baseline \n(Linear Approach to 50% Base Shock)')
plt.ylabel('Mining production reduction from baseline (kt)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %% [markdown]
# Mining Response for SP2E High (100% Shock - Linear Ramps)

# %%
pplot(-mining_response_sp2lo1yr.cumsum().loc['20190101':], label='1 year ramp',color = 'tab:blue')
pplot(-mining_response_sp2lo5yr.cumsum().loc['20190101':], label='5 year ramp',color = 'tab:orange')
pplot(-mining_response_sp2lo10yr.cumsum().loc['20190101':], label='10 year ramp', color='lightseagreen')
pplot(-mining_response_sp2lo20yr.cumsum().loc['20190101':], label='20 year ramp',color='tab:brown')

plt.title('Mining Production Reduction from Baseline \n(Linear Approach to 100% Base Shock)')
plt.ylabel('Mining production reduction from baseline (kt)')
plt.xlabel('Year')
plt.legend()
plt.show()

# %%
pplot(-mining_response_sp2lo1yr.cumsum().loc['20180101':], label='1year '+string,color='darkgreen')
pplot(-mining_response_sp2lo5yr.cumsum().loc['20180101':], label='5year No. 2 Spread',color='green')
pplot(-mining_response_sp2lo10yr.cumsum().loc['20180101':], label='10year No. 2 Spread',color='mediumseagreen')
pplot(-mining_response_sp2lo20yr.cumsum().loc['20180101':], label='20year No. 2 Spread',color='limegreen')
plt.fill_between(mining_response_sp2lo1yr.loc['20180101':].index, -mining_response_sp2lo5yr.cumsum().loc['20180101':], \
                 -mining_response_sp2lo20yr.cumsum().loc['20180101':], color = 'green', alpha = 0.3)

pplot(-mining_response_sp2hi1yr.cumsum().loc['20180101':], label='1year '+string,color='darkblue')
pplot(-mining_response_sp2hi5yr.cumsum().loc['20180101':], label='5year No. 2 Spread',color='slateblue')
pplot(-mining_response_sp2hi10yr.cumsum().loc['20180101':], label='10year No. 2 Spread',color='mediumpurple')
pplot(-mining_response_sp2hi20yr.cumsum().loc['20180101':], label='20year No. 2 Spread',color='cornflowerblue')
plt.fill_between(mining_response_sp2hi1yr.loc['20180101':].index, -mining_response_sp2hi1yr.cumsum().loc['20180101':], \
                 -mining_response_sp2hi20yr.cumsum().loc['20180101':],color = 'blue', alpha = 0.3)

pplot(-mining_response_lin1yr.cumsum().loc['20180101':], label='1year '+string,color='orangered')
pplot(-mining_response_lin5yr.cumsum().loc['20180101':], label='5year No. 2 Spread',color='tomato')
pplot(-mining_response_lin10yr.cumsum().loc['20180101':], label='10year No. 2 Spread',color='coral')
pplot(-mining_response_lin20yr.cumsum().loc['20180101':], label='20year No. 2 Spread',color='salmon')
plt.fill_between(mining_response_lin1yr.loc['20180101':].index,-mining_response_lin1yr.cumsum().loc['20180101':].values, \
                 -mining_response_lin20yr.cumsum().loc['20180101':].values, color = 'red', alpha = 0.3)

# pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [200, 10000], 'k--')
plt.legend(handles=[Line2D([0],[0],color='k',label='Lines dark for 1yr, light for 20yr'),\
                    Patch(facecolor='mediumseagreen',edgecolor='k',label='Low Elasticity'),\
                    Patch(facecolor='lightcoral', edgecolor='k',label='Original Elasticity'),\
                    Patch(facecolor='cornflowerblue',edgecolor='k',label='High Elasticity')])
plt.title('Mining Response - Comparing SP2 Elasticity Results for \nLinear 100% Shocks')
plt.xlabel('Year')
plt.ylabel('Mining Response (kt)')
plt.show()

# %%
pplot(mining_supply_baseline_baseline, label='Baseline')
# pplot(mining_supply_baseline_rs10.loc['20180101':], label='10%')
# pplot(mining_supply_baseline_rs20.loc['20180101':], label='20%')
# pplot(mining_supply_baseline_rs50.loc['20180101':], label='50%')
# pplot(mining_supply_baseline_rs100.loc['20180101':], label='100%')

pplot(mining_supply_baseline_prs10.loc['20180101':], label='p10%')
pplot(mining_supply_baseline_prs20.loc['20180101':], label='p20%')
pplot(mining_supply_baseline_prs50.loc['20180101':], label='p50%')
pplot(mining_supply_baseline_prs100.loc['20180101':], label='p100%')

# pplot(mining_supply_baseline_irs100.loc['20180101':], label='i100%')

pplot([pd.datetime(2018,1,1), pd.datetime(2018,1,1)], [0, 26000], 'k--')
plt.legend()
plt.title('Cathode price evolution (dollars per tonne)')
plt.show()

# %% [markdown]
# ## Mine level investigation

# %%
mine_life_max_sesd_baseline_header=pd.read_excel('minelife_max_sesd_baseline.xlsx', sheet_name='Sheet1', index=[0], header=None)\
.iloc[:2, 1:].ffill(axis=1)
mine_life_max_sesd_baseline=pd.read_excel('minelife_max_sesd_baseline.xlsx', sheet_name='Sheet1', index_col=0, skiprows=[0,1], 
                                          header=None)
mine_life_max_sesd_baseline.columns=pd.MultiIndex.from_arrays(mine_life_max_sesd_baseline_header.values)

# %%
mine_life_max_sesd_1_header=pd.read_excel('minelife_max_sesd_1.xlsx', sheet_name='Sheet1', index=[0], header=None)\
.iloc[:2, 1:].ffill(axis=1)
mine_life_max_sesd_1=pd.read_excel('minelife_max_sesd_1.xlsx', sheet_name='Sheet1', index_col=0, skiprows=[0,1], 
                                          header=None)
mine_life_max_sesd_1.columns=pd.MultiIndex.from_arrays(mine_life_max_sesd_1_header.values)

# %% [markdown]
# Closing?

# %%
old_mine_index=mine_life_max_sesd_baseline.columns.get_level_values(0).unique()[:374]

mine_life_max_sesd_baseline_old=mine_life_max_sesd_baseline.loc[:, idx[old_mine_index, :]]
mine_life_max_sesd_1_old=mine_life_max_sesd_1.loc[:, idx[old_mine_index, :]]

mining_supply_max_sesd_baseline_old=mine_life_max_sesd_baseline_old.loc[:, idx[:, 'Recovered metal production (kt)']].sum(axis=1)
mining_supply_max_sesd_1_old=mine_life_max_sesd_1_old.loc[:, idx[:, 'Recovered metal production (kt)']].sum(axis=1)

# %% [markdown]
# Opening?

# %%
new_mine_index_max_sesd_baseline=mine_life_max_sesd_baseline.columns.get_level_values(0).unique()[374:]
new_mine_index_max_sesd_1=mine_life_max_sesd_1.columns.get_level_values(0).unique()[374:]

mine_life_max_sesd_baseline_new=mine_life_max_sesd_baseline.loc[:, idx[new_mine_index_max_sesd_baseline, :]]
mine_life_max_sesd_1_new=mine_life_max_sesd_1.loc[:, idx[new_mine_index_max_sesd_1, :]]

mining_supply_max_sesd_baseline_new=mine_life_max_sesd_baseline_new.loc[:, idx[:, 'Recovered metal production (kt)']].sum(axis=1)
mining_supply_max_sesd_1_new=mine_life_max_sesd_1_new.loc[:, idx[:, 'Recovered metal production (kt)']].sum(axis=1)

# %%
pplot(mining_supply_max_sesd_baseline_old, 'r', label='Max SESD baseline')
pplot(mining_supply_max_sesd_1_old.loc['20180101':], 'b', label='Max SESD 1%')

pplot(mining_supply_max_sesd_baseline_new, 'r--', label='Max SESD baseline')
pplot(mining_supply_max_sesd_1_new.loc['20180101':], 'b--', label='Max SESD 1%')

plt.title('Mining supply (ktonnes)')
#plt.legend()
plt.show()

# %% [markdown]
# OK, so for closing which mines?

# %%
late_prod_max_sesd_baseline_old=\
mine_life_max_sesd_baseline_old.loc['20350101':, idx[:, 'Recovered metal production (kt)']].sum()>0
late_prod_max_sesd_1_old=\
mine_life_max_sesd_1_old.loc['20350101':, idx[:, 'Recovered metal production (kt)']].sum()>0

# %%
late_prod_index_max_sesd_baseline_old=[i for i in late_prod_max_sesd_baseline_old.index.get_level_values(0) if \
late_prod_max_sesd_baseline_old.loc[i].values]

late_prod_index_max_sesd_1_old=[i for i in late_prod_max_sesd_1_old.index.get_level_values(0) if \
late_prod_max_sesd_1_old.loc[i].values]

# %%
mine_life_late_max_sesd_baseline_old=\
mine_life_max_sesd_baseline_old.loc['20350101':, idx[late_prod_index_max_sesd_baseline_old, 'Recovered metal production (kt)']]
mine_life_late_max_sesd_1_old=\
mine_life_max_sesd_1_old.loc['20350101':, idx[late_prod_index_max_sesd_1_old, 'Recovered metal production (kt)']]

# %%
years_close_max_sesd_baseline=pd.Series(0, index=late_prod_index_max_sesd_baseline_old)
years_close_max_sesd_1=pd.Series(0, index=late_prod_index_max_sesd_1_old)

# %%
for i in late_prod_index_max_sesd_baseline_old:
    prod_i=mine_life_late_sesd_baseline_old.loc[:, idx[i, 'Recovered metal production (kt)']]
    if 0 in list(prod_i):
        years_close_max_sesd_baseline.loc[i]=prod_i.idxmin().year
        
for i in late_prod_index_max_sesd_1_old:
    prod_i=mine_life_late_sesd_1_old.loc[:, idx[i, 'Recovered metal production (kt)']]
    if 0 in list(prod_i):
        years_close_max_sesd_1.loc[i]=prod_i.idxmin().year

# %%
years_close_df=pd.DataFrame({'Max SESD 1%': years_close_max_sesd_1, 'Max SESD Baseline': years_close_max_sesd_baseline})
# years_close_df.to_excel('Years close dataframe.xlsx')

# %%
max_sesd_1_impact_index=[24470, 24518, 24673, 24733, 24783, 29853, 29924, 30678, 30768, 31528, 33190]

# %%
shiro=mine_life_max_sesd_1.loc[:, idx[max_sesd_1_impact_index, 'Recovered metal production (kt)']].sum(axis=1)-\
mine_life_max_sesd_baseline.loc[:, idx[max_sesd_1_impact_index, 'Recovered metal production (kt)']].sum(axis=1)

# %%
pplot(mine_life_max_sesd_baseline.loc[:, idx[max_sesd_1_impact_index, 'Recovered metal production (kt)']].sum(axis=1))
pplot(mine_life_max_sesd_1.loc[:, idx[max_sesd_1_impact_index, 'Recovered metal production (kt)']].sum(axis=1))

plt.title('Mining supply of selected mines (ktonnes)')
plt.show()

# %%
mine_life_baseline_baseline=pd.read_excel('Mine level info/')

# %% [markdown]
# # Plots for China Paper

# %%
dark2 = ['#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#a6761d','#666666'] # https://colorbrewer2.org/#type=qualitative&scheme=Dark2&n=8
greens = ['#025B40','#0B9367','#52bEa3','#998631','#BFA73D','#DAC046']
blues = ['#8E89D9','#7570b3','#4350B3','#53507F']
blues = ['#8E89D9','#41b6c4','#2c7fb8','#253494']
oranges = ['#fecc5c','#fd8d3c','#f03b20','#bd0026']
purples = ['#f768a1','#c51b8a','#7a0177','#df65b0','#c51b8a','#980043']
purples = ['#8c96d4','#fa2b85','#a00f7c']
reds = ['#fc9272','#de2d26']
plt.figure(figsize=(8,5))
c4a = ['#9e0142','#d53e4f','#f46d43','#fee08b','#abdda4','#66c2a5','#3288bd','#5e4fa2']
plter = blues
for i in np.arange(0,len(plter)):
    plt.plot([0,1],[0,1+i],color=plter[i],label=plter[i])
plt.legend()
plt.title('Check',fontweight=560,fontname='Arial Narrow')

# %%
def init_plot2(fontsize=20,figsize=(24,19)):
    linewidth=4
    figwidth=figsize[0]
    figheight=figsize[1]
    have_axes = True
    params = {
        'axes.labelsize': fontsize,
        'axes.labelweight': 'bold',
        'axes.titleweight': 'bold',
        'font.size': fontsize,
        'legend.fontsize': fontsize,
        'xtick.labelsize': fontsize,
        'ytick.labelsize': fontsize,
        'text.usetex': False,
        'figure.figsize': [figwidth, figheight],
        'lines.linewidth': linewidth,
        'lines.solid_capstyle': 'round',
        'legend.framealpha': 1,
        'legend.frameon': False,
        'mathtext.default': 'regular',
        'axes.linewidth': 2/3*linewidth,
        'xtick.direction': 'in', # in, out, inout
        'ytick.direction': 'in', # in, out, inout
        'xtick.major.size': 7,
        'xtick.major.width': 2,
        'xtick.major.pad': 3.5,
        'ytick.major.size': 7,
        'ytick.major.width': 2,
        'ytick.major.pad': 3.5,
        'font.sans-serif': 'Calibri'
        }


    mpl.rcParams.update(params)
    mpl.rcParams['axes.spines.left'] = have_axes
    mpl.rcParams['axes.spines.right'] = have_axes
    mpl.rcParams['axes.spines.top'] = have_axes
    mpl.rcParams['axes.spines.bottom'] = have_axes
    mpl.rcParams['axes.axisbelow'] = True
    mpl.rcParams['axes.grid'] = True
    mpl.rcParams['axes.grid.axis'] = 'y'
    mpl.rcParams['grid.color'] = '0.9'
    mpl.rcParams['grid.linewidth'] = 1
    mpl.rcParams['grid.linestyle'] = '-'
    # %config InlineBackend.figure_format ='retina'
init_plot2()

# %% [markdown]
# Refinery properties for COVID and the rest

# %%
for prop in ['Primary refining production','Secondary refining production','Refined demand']:
    prop2 = prop
    ref_props_covidimf_shock_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_shock_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_inc100_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_inc100_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_dec100_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_dec100_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_inc200_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_inc200_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_dec200_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_dec200_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()

    ref_props_covidimf_no2_50yoy_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_inc100_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_inc100_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_dec100_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_dec100_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_inc200_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_inc200_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_dec200_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_dec200_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()

    ref_props_covidimf_both_50yoy_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_inc100_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_inc100_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_dec100_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_dec100_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_inc200_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_inc200_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_dec200_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_dec200_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()

    ref_props_covidimf_both_25yoy_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_both_25yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_75yoy_gl.loc['20170101':,prop+' response'] = ref_props_covidimf_both_75yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_gl.loc['20170101':,prop2].cumsum()
    
    if prop == 'Refined demand':
        prop2 = 'CN Refined demand'
    ref_props_covidimf_shock_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_shock_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_inc100_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_inc100_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_dec100_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_dec100_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_inc200_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_inc200_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_dec200_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_dec200_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()

    ref_props_covidimf_alloyed_50yoy_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_inc100_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_inc100_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_dec100_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_dec100_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_inc200_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_inc200_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_dec200_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_dec200_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()

    ref_props_covidimf_no2_50yoy_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_inc100_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_inc100_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_dec100_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_dec100_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_inc200_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_inc200_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_dec200_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_dec200_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()

    ref_props_covidimf_both_25yoy_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_both_25yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_75yoy_cn.loc['20170101':,prop+' response'] = ref_props_covidimf_both_75yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_cn.loc['20170101':,prop2].cumsum()
    
    if prop == 'Refined demand':
        prop2 = 'RoW Refined demand'
    ref_props_covidimf_shock_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_shock_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_inc100_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_inc100_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_dec100_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_dec100_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_inc200_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_inc200_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_alloyed_50yoy_dec200_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_alloyed_50yoy_dec200_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_covidimf_no2_50yoy_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_inc100_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_inc100_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_dec100_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_dec100_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_inc200_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_inc200_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_no2_50yoy_dec200_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_no2_50yoy_dec200_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_covidimf_both_50yoy_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_inc100_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_inc100_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_dec100_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_dec100_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_inc200_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_inc200_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_50yoy_dec200_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_both_50yoy_dec200_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_covidimf_both_25yoy_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_both_25yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_covidimf_both_75yoy_rw.loc['20170101':,prop+' response'] = ref_props_covidimf_both_75yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_covidimf_baseline_rw.loc['20170101':,prop2].cumsum()

ref_props_covidimf_baseline_gl.loc['20170101':,'Total refining production'] = ref_props_covidimf_baseline_gl.loc['20170101':,'Primary refining production'] + ref_props_covidimf_baseline_gl.loc['20170101':,'Secondary refining production']
ref_props_covidimf_baseline_cn.loc['20170101':,'Total refining production'] = ref_props_covidimf_baseline_cn.loc['20170101':,'Primary refining production'] + ref_props_covidimf_baseline_cn.loc['20170101':,'Secondary refining production']
ref_props_covidimf_baseline_rw.loc['20170101':,'Total refining production'] = ref_props_covidimf_baseline_rw.loc['20170101':,'Primary refining production'] + ref_props_covidimf_baseline_rw.loc['20170101':,'Secondary refining production']
ref_props_covidimf_shock_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_shock_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_shock_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_shock_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_shock_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_shock_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_shock_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_shock_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_shock_rw.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_alloyed_50yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_inc100_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_inc100_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_inc100_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_dec100_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_dec100_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_dec100_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_inc200_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_inc200_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_inc200_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_dec200_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_dec200_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_dec200_gl.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_alloyed_50yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_inc100_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_inc100_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_inc100_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_dec100_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_dec100_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_dec100_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_inc200_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_inc200_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_inc200_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_dec200_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_dec200_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_dec200_cn.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_alloyed_50yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_inc100_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_inc100_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_inc100_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_dec100_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_dec100_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_dec100_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_inc200_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_inc200_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_inc200_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_alloyed_50yoy_dec200_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_alloyed_50yoy_dec200_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_alloyed_50yoy_dec200_rw.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_no2_50yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_inc100_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_inc100_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_inc100_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_dec100_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_dec100_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_dec100_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_inc200_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_inc200_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_inc200_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_dec200_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_dec200_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_dec200_gl.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_no2_50yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_inc100_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_inc100_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_inc100_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_dec100_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_dec100_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_dec100_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_inc200_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_inc200_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_inc200_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_dec200_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_dec200_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_dec200_cn.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_no2_50yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_inc100_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_inc100_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_inc100_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_dec100_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_dec100_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_dec100_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_inc200_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_inc200_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_inc200_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_no2_50yoy_dec200_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_no2_50yoy_dec200_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_no2_50yoy_dec200_rw.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_both_50yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_inc100_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_inc100_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_inc100_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_dec100_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_dec100_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_dec100_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_inc200_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_inc200_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_inc200_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_dec200_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_dec200_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_dec200_gl.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_both_50yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_inc100_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_inc100_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_inc100_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_dec100_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_dec100_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_dec100_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_inc200_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_inc200_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_inc200_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_dec200_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_dec200_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_dec200_cn.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_both_50yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_inc100_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_inc100_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_inc100_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_dec100_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_dec100_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_dec100_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_inc200_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_inc200_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_inc200_rw.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_50yoy_dec200_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_50yoy_dec200_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_50yoy_dec200_rw.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_both_25yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_25yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_25yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_25yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_25yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_25yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_25yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_25yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_25yoy_rw.loc['20170101':,'Secondary refining production response']

ref_props_covidimf_both_75yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_75yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_75yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_75yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_75yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_75yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_covidimf_both_75yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_covidimf_both_75yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_covidimf_both_75yoy_rw.loc['20170101':,'Secondary refining production response']

for prop in ['Primary refining production','Secondary refining production','Refined demand']:
    prop2 = prop
    ref_props_alloyed_50yoy_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc200_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec200_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()

    ref_props_no2_50yoy_gl.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc100_gl.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec100_gl.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc200_gl.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec200_gl.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()

    ref_props_both_50yoy_gl.loc['20170101':,prop+' response'] = ref_props_both_50yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc100_gl.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec100_gl.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec100_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc200_gl.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec200_gl.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec200_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()

    ref_props_alloyed_25yoy_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_25yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_25yoy_gl.loc['20170101':,prop+' response'] = ref_props_no2_25yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_25yoy_gl.loc['20170101':,prop+' response'] = ref_props_both_25yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    
    ref_props_alloyed_75yoy_gl.loc['20170101':,prop+' response'] = ref_props_alloyed_75yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_no2_75yoy_gl.loc['20170101':,prop+' response'] = ref_props_no2_75yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_both_75yoy_gl.loc['20170101':,prop+' response'] = ref_props_both_75yoy_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    
    ref_props_ban_zeng_low_gl.loc['20170101':,prop+' response'] = ref_props_ban_zeng_low_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_mean_gl.loc['20170101':,prop+' response'] = ref_props_ban_zeng_mean_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_high_gl.loc['20170101':,prop+' response'] = ref_props_ban_zeng_high_gl.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_gl.loc['20170101':,prop2].cumsum()
    
    if prop == 'Refined demand':
        prop2 = 'CN Refined demand'
    ref_props_both_50yoy_cn.loc['20170101':,prop+' response'] = ref_props_both_50yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc100_cn.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec100_cn.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc200_cn.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec200_cn.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()

    ref_props_alloyed_50yoy_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()

    ref_props_no2_50yoy_cn.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc100_cn.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec100_cn.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec100_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc200_cn.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec200_cn.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec200_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()

    ref_props_alloyed_25yoy_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_25yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_25yoy_cn.loc['20170101':,prop+' response'] = ref_props_no2_25yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_25yoy_cn.loc['20170101':,prop+' response'] = ref_props_both_25yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
   
    ref_props_alloyed_75yoy_cn.loc['20170101':,prop+' response'] = ref_props_alloyed_75yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_no2_75yoy_cn.loc['20170101':,prop+' response'] = ref_props_no2_75yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_both_75yoy_cn.loc['20170101':,prop+' response'] = ref_props_both_75yoy_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    
    ref_props_ban_zeng_low_cn.loc['20170101':,prop+' response'] = ref_props_ban_zeng_low_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_mean_cn.loc['20170101':,prop+' response'] = ref_props_ban_zeng_mean_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_high_cn.loc['20170101':,prop+' response'] = ref_props_ban_zeng_high_cn.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_cn.loc['20170101':,prop2].cumsum()
    
    if prop == 'Refined demand':
        prop2 = 'RoW Refined demand'
    ref_props_alloyed_50yoy_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_no2_50yoy_rw.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc100_rw.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec100_rw.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_inc200_rw.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_inc200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_50yoy_dec200_rw.loc['20170101':,prop+' response'] = ref_props_no2_50yoy_dec200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_both_50yoy_rw.loc['20170101':,prop+' response'] = ref_props_both_50yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc100_rw.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec100_rw.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec100_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_inc200_rw.loc['20170101':,prop+' response'] = ref_props_both_50yoy_inc200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_50yoy_dec200_rw.loc['20170101':,prop+' response'] = ref_props_both_50yoy_dec200_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_alloyed_25yoy_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_25yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_25yoy_rw.loc['20170101':,prop+' response'] = ref_props_no2_25yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_25yoy_rw.loc['20170101':,prop+' response'] = ref_props_both_25yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_alloyed_75yoy_rw.loc['20170101':,prop+' response'] = ref_props_alloyed_75yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_no2_75yoy_rw.loc['20170101':,prop+' response'] = ref_props_no2_75yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_both_75yoy_rw.loc['20170101':,prop+' response'] = ref_props_both_75yoy_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()

    ref_props_ban_zeng_low_rw.loc['20170101':,prop+' response'] = ref_props_ban_zeng_low_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_mean_rw.loc['20170101':,prop+' response'] = ref_props_ban_zeng_mean_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    ref_props_ban_zeng_high_rw.loc['20170101':,prop+' response'] = ref_props_ban_zeng_high_rw.loc['20170101':,prop2].cumsum() - ref_props_pir_baseline_rw.loc['20170101':,prop2].cumsum()
    
ref_props_pir_baseline_gl.loc['20170101':,'Total refining production'] = ref_props_pir_baseline_gl.loc['20170101':,'Primary refining production'] + ref_props_pir_baseline_gl.loc['20170101':,'Secondary refining production']
ref_props_pir_baseline_cn.loc['20170101':,'Total refining production'] = ref_props_pir_baseline_cn.loc['20170101':,'Primary refining production'] + ref_props_pir_baseline_cn.loc['20170101':,'Secondary refining production']
ref_props_pir_baseline_rw.loc['20170101':,'Total refining production'] = ref_props_pir_baseline_rw.loc['20170101':,'Primary refining production'] + ref_props_pir_baseline_rw.loc['20170101':,'Secondary refining production']

ref_props_alloyed_50yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc100_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec100_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc200_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc200_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc200_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec200_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec200_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec200_gl.loc['20170101':,'Secondary refining production response']

ref_props_alloyed_50yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc100_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec100_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc200_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec200_cn.loc['20170101':,'Secondary refining production response']

ref_props_alloyed_50yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc100_rw.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec100_rw.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_inc200_rw.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_50yoy_dec200_rw.loc['20170101':,'Secondary refining production response']

ref_props_no2_50yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc100_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc100_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc100_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec100_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec100_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec100_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc200_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc200_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc200_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec200_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec200_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec200_gl.loc['20170101':,'Secondary refining production response']

ref_props_no2_50yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc100_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc100_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc100_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec100_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec100_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec100_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc200_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc200_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc200_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec200_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec200_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec200_cn.loc['20170101':,'Secondary refining production response']

ref_props_no2_50yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc100_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc100_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc100_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec100_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec100_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec100_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_inc200_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_inc200_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_inc200_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_50yoy_dec200_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_50yoy_dec200_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_50yoy_dec200_rw.loc['20170101':,'Secondary refining production response']

ref_props_both_50yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc100_gl.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc100_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc100_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec100_gl.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec100_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec100_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc200_gl.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc200_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc200_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec200_gl.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec200_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec200_gl.loc['20170101':,'Secondary refining production response']

ref_props_both_50yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc100_cn.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc100_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc100_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec100_cn.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec100_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec100_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc200_cn.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc200_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc200_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec200_cn.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec200_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec200_cn.loc['20170101':,'Secondary refining production response']

ref_props_both_50yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc100_rw.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc100_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc100_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec100_rw.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec100_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec100_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_inc200_rw.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_inc200_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_inc200_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_50yoy_dec200_rw.loc['20170101':,'Total refining production response'] = ref_props_both_50yoy_dec200_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_50yoy_dec200_rw.loc['20170101':,'Secondary refining production response']

ref_props_alloyed_25yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_25yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_25yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_25yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_25yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_25yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_25yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_25yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_25yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_25yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_25yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_25yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_25yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_25yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_25yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_25yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_25yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_25yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_25yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_both_25yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_25yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_25yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_both_25yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_25yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_25yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_both_25yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_25yoy_rw.loc['20170101':,'Secondary refining production response']

ref_props_alloyed_75yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_alloyed_75yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_75yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_75yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_alloyed_75yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_75yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_alloyed_75yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_alloyed_75yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_alloyed_75yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_no2_75yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_no2_75yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_no2_75yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_no2_75yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_no2_75yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_no2_75yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_no2_75yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_no2_75yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_no2_75yoy_rw.loc['20170101':,'Secondary refining production response']
ref_props_both_75yoy_gl.loc['20170101':,'Total refining production response'] = ref_props_both_75yoy_gl.loc['20170101':,'Primary refining production response'] + ref_props_both_75yoy_gl.loc['20170101':,'Secondary refining production response']
ref_props_both_75yoy_cn.loc['20170101':,'Total refining production response'] = ref_props_both_75yoy_cn.loc['20170101':,'Primary refining production response'] + ref_props_both_75yoy_cn.loc['20170101':,'Secondary refining production response']
ref_props_both_75yoy_rw.loc['20170101':,'Total refining production response'] = ref_props_both_75yoy_rw.loc['20170101':,'Primary refining production response'] + ref_props_both_75yoy_rw.loc['20170101':,'Secondary refining production response']

ref_props_ban_zeng_low_gl.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_low_gl.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_low_gl.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_mean_gl.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_mean_gl.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_mean_gl.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_high_gl.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_high_gl.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_high_gl.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_low_cn.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_low_cn.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_low_cn.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_mean_cn.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_mean_cn.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_mean_cn.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_high_cn.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_high_cn.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_high_cn.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_low_rw.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_low_rw.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_low_rw.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_mean_rw.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_mean_rw.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_mean_rw.loc['20170101':,'Secondary refining production response']
ref_props_ban_zeng_high_rw.loc['20170101':,'Total refining production response'] = ref_props_ban_zeng_high_rw.loc['20170101':,'Primary refining production response'] + ref_props_ban_zeng_high_rw.loc['20170101':,'Secondary refining production response']

print('Done')

# %% [markdown]
# Environmental impacts COVID

# %%
file_name = 'covid baseline'
mine_life_stats_covidimf_baseline = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_baseline, unit_impacts_covidimf_baseline, quantities_covidimf_baseline = calculate_impacts(
    sd_covidimf_baseline_cn, sd_covidimf_baseline_rw, sd_covidimf_baseline, mine_life_stats_covidimf_baseline,
    direct_melt_demand_covidimf_baseline_cn, direct_melt_demand_covidimf_baseline_rw)

file_name = 'covid gdp imf'
mine_life_stats_covidimf_shock = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_shock, unit_impacts_covidimf_shock, quantities_covidimf_shock = calculate_impacts(
    sd_covidimf_shock_cn, sd_covidimf_shock_rw, sd_covidimf_shock, mine_life_stats_covidimf_shock,
    direct_melt_demand_covidimf_shock_cn, direct_melt_demand_covidimf_shock_rw)
impact_change_covidimf_shock = total_impacts_covidimf_shock - total_impacts_covidimf_baseline
quantity_change_covidimf_shock = quantities_covidimf_shock - quantities_covidimf_baseline

file_name = 'covid gdp alloyed 50yoy'
mine_life_stats_covidimf_alloyed_50yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_alloyed_50yoy, unit_impacts_covidimf_alloyed_50yoy, quantities_covidimf_alloyed_50yoy = calculate_impacts(
    sd_covidimf_alloyed_50yoy_cn, sd_covidimf_alloyed_50yoy_rw, sd_covidimf_alloyed_50yoy, mine_life_stats_covidimf_alloyed_50yoy,
    direct_melt_demand_covidimf_alloyed_50yoy_cn, direct_melt_demand_covidimf_alloyed_50yoy_rw)
impact_change_covidimf_alloyed_50yoy = total_impacts_covidimf_alloyed_50yoy - total_impacts_covidimf_baseline
quantity_change_covidimf_alloyed_50yoy = quantities_covidimf_alloyed_50yoy - quantities_covidimf_baseline

file_name = 'covid gdp No.2 50yoy'
mine_life_stats_covidimf_no2_50yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_no2_50yoy, unit_impacts_covidimf_no2_50yoy, quantities_covidimf_no2_50yoy = calculate_impacts(
    sd_covidimf_no2_50yoy_cn, sd_covidimf_no2_50yoy_rw, sd_covidimf_no2_50yoy, mine_life_stats_covidimf_no2_50yoy,
    direct_melt_demand_covidimf_no2_50yoy_cn, direct_melt_demand_covidimf_no2_50yoy_rw)
impact_change_covidimf_no2_50yoy = total_impacts_covidimf_no2_50yoy - total_impacts_covidimf_baseline
quantity_change_covidimf_no2_50yoy = quantities_covidimf_no2_50yoy - quantities_covidimf_baseline

file_name = 'covid gdp both 50yoy'
mine_life_stats_covidimf_both_50yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_both_50yoy, unit_impacts_covidimf_both_50yoy, quantities_covidimf_both_50yoy = calculate_impacts(
    sd_covidimf_both_50yoy_cn, sd_covidimf_both_50yoy_rw, sd_covidimf_both_50yoy, mine_life_stats_covidimf_both_50yoy,
    direct_melt_demand_covidimf_both_50yoy_cn, direct_melt_demand_covidimf_both_50yoy_rw)
impact_change_covidimf_both_50yoy = total_impacts_covidimf_both_50yoy - total_impacts_covidimf_baseline
quantity_change_covidimf_both_50yoy = quantities_covidimf_both_50yoy - quantities_covidimf_baseline

file_name = 'covid gdp both 25yoy'
mine_life_stats_covidimf_both_25yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_both_25yoy, unit_impacts_covidimf_both_25yoy, quantities_covidimf_both_25yoy = calculate_impacts(
    sd_covidimf_both_25yoy_cn, sd_covidimf_both_25yoy_rw, sd_covidimf_both_25yoy, mine_life_stats_covidimf_both_25yoy,
    direct_melt_demand_covidimf_both_25yoy_cn, direct_melt_demand_covidimf_both_25yoy_rw)
impact_change_covidimf_both_25yoy = total_impacts_covidimf_both_25yoy - total_impacts_covidimf_baseline
quantity_change_covidimf_both_25yoy = quantities_covidimf_both_25yoy - quantities_covidimf_baseline

file_name = 'covid gdp both 75yoy'
mine_life_stats_covidimf_both_75yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_both_75yoy, unit_impacts_covidimf_both_75yoy, quantities_covidimf_both_75yoy = calculate_impacts(
    sd_covidimf_both_75yoy_cn, sd_covidimf_both_75yoy_rw, sd_covidimf_both_75yoy, mine_life_stats_covidimf_both_75yoy,
    direct_melt_demand_covidimf_both_75yoy_cn, direct_melt_demand_covidimf_both_75yoy_rw)
impact_change_covidimf_both_75yoy = total_impacts_covidimf_both_75yoy - total_impacts_covidimf_baseline
quantity_change_covidimf_both_75yoy = quantities_covidimf_both_75yoy - quantities_covidimf_baseline

file_name = 'covid gdp both 50yoy inc 100'
mine_life_stats_covidimf_both_50yoy_inc100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_both_50yoy_inc100, unit_impacts_covidimf_both_50yoy_inc100, quantities_covidimf_both_50yoy_inc100 = calculate_impacts(
    sd_covidimf_both_50yoy_inc100_cn, sd_covidimf_both_50yoy_inc100_rw, sd_covidimf_both_50yoy_inc100, mine_life_stats_covidimf_both_50yoy_inc100,
    direct_melt_demand_covidimf_both_50yoy_inc100_cn, direct_melt_demand_covidimf_both_50yoy_inc100_rw)
impact_change_covidimf_both_50yoy_inc100 = total_impacts_covidimf_both_50yoy_inc100 - total_impacts_covidimf_baseline
quantity_change_covidimf_both_50yoy_inc100 = quantities_covidimf_both_50yoy_inc100 - quantities_covidimf_baseline

file_name = 'covid gdp both 50yoy inc 200'
mine_life_stats_covidimf_both_50yoy_inc200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_both_50yoy_inc200, unit_impacts_covidimf_both_50yoy_inc200, quantities_covidimf_both_50yoy_inc200 = calculate_impacts(
    sd_covidimf_both_50yoy_inc200_cn, sd_covidimf_both_50yoy_inc200_rw, sd_covidimf_both_50yoy_inc200, mine_life_stats_covidimf_both_50yoy_inc200,
    direct_melt_demand_covidimf_both_50yoy_inc200_cn, direct_melt_demand_covidimf_both_50yoy_inc200_rw)
impact_change_covidimf_both_50yoy_inc200 = total_impacts_covidimf_both_50yoy_inc200 - total_impacts_covidimf_baseline
quantity_change_covidimf_both_50yoy_inc200 = quantities_covidimf_both_50yoy_inc200 - quantities_covidimf_baseline

file_name = 'covid gdp both 50yoy dec 100'
mine_life_stats_covidimf_both_50yoy_dec100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_both_50yoy_dec100, unit_impacts_covidimf_both_50yoy_dec100, quantities_covidimf_both_50yoy_dec100 = calculate_impacts(
    sd_covidimf_both_50yoy_dec100_cn, sd_covidimf_both_50yoy_dec100_rw, sd_covidimf_both_50yoy_dec100, mine_life_stats_covidimf_both_50yoy_dec100,
    direct_melt_demand_covidimf_both_50yoy_dec100_cn, direct_melt_demand_covidimf_both_50yoy_dec100_rw)
impact_change_covidimf_both_50yoy_dec100 = total_impacts_covidimf_both_50yoy_dec100 - total_impacts_covidimf_baseline
quantity_change_covidimf_both_50yoy_dec100 = quantities_covidimf_both_50yoy_dec100 - quantities_covidimf_baseline

file_name = 'covid gdp both 50yoy dec 200'
mine_life_stats_covidimf_both_50yoy_dec200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_both_50yoy_dec200, unit_impacts_covidimf_both_50yoy_dec200, quantities_covidimf_both_50yoy_dec200 = calculate_impacts(
    sd_covidimf_both_50yoy_dec200_cn, sd_covidimf_both_50yoy_dec200_rw, sd_covidimf_both_50yoy_dec200, mine_life_stats_covidimf_both_50yoy_dec200,
    direct_melt_demand_covidimf_both_50yoy_dec200_cn, direct_melt_demand_covidimf_both_50yoy_dec200_rw)
impact_change_covidimf_both_50yoy_dec200 = total_impacts_covidimf_both_50yoy_dec200 - total_impacts_covidimf_baseline
quantity_change_covidimf_both_50yoy_dec200 = quantities_covidimf_both_50yoy_dec200 - quantities_covidimf_baseline

file_name = 'covid gdp No.2 50yoy inc 100'
mine_life_stats_covidimf_no2_50yoy_inc100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_no2_50yoy_inc100, unit_impacts_covidimf_no2_50yoy_inc100, quantities_covidimf_no2_50yoy_inc100 = calculate_impacts(
    sd_covidimf_no2_50yoy_inc100_cn, sd_covidimf_no2_50yoy_inc100_rw, sd_covidimf_no2_50yoy_inc100, mine_life_stats_covidimf_no2_50yoy_inc100,
    direct_melt_demand_covidimf_no2_50yoy_inc100_cn, direct_melt_demand_covidimf_no2_50yoy_inc100_rw)
impact_change_covidimf_no2_50yoy_inc100 = total_impacts_covidimf_no2_50yoy_inc100 - total_impacts_covidimf_baseline
quantity_change_covidimf_no2_50yoy_inc100 = quantities_covidimf_no2_50yoy_inc100 - quantities_covidimf_baseline

file_name = 'covid gdp No.2 50yoy inc 200'
mine_life_stats_covidimf_no2_50yoy_inc200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_no2_50yoy_inc200, unit_impacts_covidimf_no2_50yoy_inc200, quantities_covidimf_no2_50yoy_inc200 = calculate_impacts(
    sd_covidimf_no2_50yoy_inc200_cn, sd_covidimf_no2_50yoy_inc200_rw, sd_covidimf_no2_50yoy_inc200, mine_life_stats_covidimf_no2_50yoy_inc200,
    direct_melt_demand_covidimf_no2_50yoy_inc200_cn, direct_melt_demand_covidimf_no2_50yoy_inc200_rw)
impact_change_covidimf_no2_50yoy_inc200 = total_impacts_covidimf_no2_50yoy_inc200 - total_impacts_covidimf_baseline
quantity_change_covidimf_no2_50yoy_inc200 = quantities_covidimf_no2_50yoy_inc200 - quantities_covidimf_baseline

file_name = 'covid gdp No.2 50yoy dec 100'
mine_life_stats_covidimf_no2_50yoy_dec100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_no2_50yoy_dec100, unit_impacts_covidimf_no2_50yoy_dec100, quantities_covidimf_no2_50yoy_dec100 = calculate_impacts(
    sd_covidimf_no2_50yoy_dec100_cn, sd_covidimf_no2_50yoy_dec100_rw, sd_covidimf_no2_50yoy_dec100, mine_life_stats_covidimf_no2_50yoy_dec100,
    direct_melt_demand_covidimf_no2_50yoy_dec100_cn, direct_melt_demand_covidimf_no2_50yoy_dec100_rw)
impact_change_covidimf_no2_50yoy_dec100 = total_impacts_covidimf_no2_50yoy_dec100 - total_impacts_covidimf_baseline
quantity_change_covidimf_no2_50yoy_dec100 = quantities_covidimf_no2_50yoy_dec100 - quantities_covidimf_baseline

file_name = 'covid gdp No.2 50yoy dec 200'
mine_life_stats_covidimf_no2_50yoy_dec200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_covidimf_no2_50yoy_dec200, unit_impacts_covidimf_no2_50yoy_dec200, quantities_covidimf_no2_50yoy_dec200 = calculate_impacts(
    sd_covidimf_no2_50yoy_dec200_cn, sd_covidimf_no2_50yoy_dec200_rw, sd_covidimf_no2_50yoy_dec200, mine_life_stats_covidimf_no2_50yoy_dec200,
    direct_melt_demand_covidimf_no2_50yoy_dec200_cn, direct_melt_demand_covidimf_no2_50yoy_dec200_rw)
impact_change_covidimf_no2_50yoy_dec200 = total_impacts_covidimf_no2_50yoy_dec200 - total_impacts_covidimf_baseline
quantity_change_covidimf_no2_50yoy_dec200 = quantities_covidimf_no2_50yoy_dec200 - quantities_covidimf_baseline

categories = ['Direct Melt Scrap', 'Direct Melt Other', 'Fabrication', 'New SX-EW Mines',
                 'New Traditional Mines', 'Operating SX-EW Mines', 'Operating Traditional Mines', 
                 'Primary Refinery', 'Secondary Refinery', 'Refined Metals']
print('All Done')

# %% [markdown]
# Environmental impacts, ban rates and refined imports

# %%
file_name = 'blend CN baseline 20200414_1'
mine_life_stats_pir_baseline = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_pir_baseline, unit_impacts_pir_baseline, quantities_pir_baseline = calculate_impacts(
    sd_pir_baseline_cn, sd_pir_baseline_rw, sd_pir_baseline, mine_life_stats_pir_baseline,
    direct_melt_demand_pir_baseline_cn, direct_melt_demand_pir_baseline_rw)

file_name = 'blend CN alloyed 50yoy 20200414_1'
mine_life_stats_alloyed_50yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_50yoy, unit_impacts_alloyed_50yoy, quantities_alloyed_50yoy = calculate_impacts(
    sd_alloyed_50yoy_cn, sd_alloyed_50yoy_rw, sd_alloyed_50yoy, mine_life_stats_alloyed_50yoy,
    direct_melt_demand_alloyed_50yoy_cn, direct_melt_demand_alloyed_50yoy_rw)
impact_change_alloyed_50yoy = total_impacts_alloyed_50yoy - total_impacts_pir_baseline
quantity_change_alloyed_50yoy = quantities_alloyed_50yoy - quantities_pir_baseline

file_name = 'blend CN No.2 50yoy 20200414_1'
mine_life_stats_no2_50yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_50yoy, unit_impacts_no2_50yoy, quantities_no2_50yoy = calculate_impacts(
    sd_no2_50yoy_cn, sd_no2_50yoy_rw, sd_no2_50yoy, mine_life_stats_no2_50yoy,
    direct_melt_demand_no2_50yoy_cn, direct_melt_demand_no2_50yoy_rw)
impact_change_no2_50yoy = total_impacts_no2_50yoy - total_impacts_pir_baseline
quantity_change_no2_50yoy = quantities_no2_50yoy - quantities_pir_baseline

file_name = 'blend CN both 50yoy 20200414_1'
mine_life_stats_both_50yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_50yoy, unit_impacts_both_50yoy, quantities_both_50yoy = calculate_impacts(
    sd_both_50yoy_cn, sd_both_50yoy_rw, sd_both_50yoy, mine_life_stats_both_50yoy,
    direct_melt_demand_both_50yoy_cn, direct_melt_demand_both_50yoy_rw)
impact_change_both_50yoy = total_impacts_both_50yoy - total_impacts_pir_baseline
quantity_change_both_50yoy = quantities_both_50yoy - quantities_pir_baseline

file_name = 'blend CN both 50yoy inc 20200414'
mine_life_stats_both_50yoy_inc100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_50yoy_inc100, unit_impacts_both_50yoy_inc100, quantities_both_50yoy_inc100 = calculate_impacts(
    sd_both_50yoy_inc100_cn, sd_both_50yoy_inc100_rw, sd_both_50yoy_inc100, mine_life_stats_both_50yoy_inc100,
    direct_melt_demand_both_50yoy_inc100_cn, direct_melt_demand_both_50yoy_inc100_rw)
impact_change_both_50yoy_inc100 = total_impacts_both_50yoy_inc100 - total_impacts_pir_baseline
quantity_change_both_50yoy_inc100 = quantities_both_50yoy_inc100 - quantities_pir_baseline

file_name = 'blend CN both 50yoy 200 inc 20200414'
mine_life_stats_both_50yoy_inc200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_50yoy_inc200, unit_impacts_both_50yoy_inc200, quantities_both_50yoy_inc200 = calculate_impacts(
    sd_both_50yoy_inc200_cn, sd_both_50yoy_inc200_rw, sd_both_50yoy_inc200, mine_life_stats_both_50yoy_inc200,
    direct_melt_demand_both_50yoy_inc200_cn, direct_melt_demand_both_50yoy_inc200_rw)
impact_change_both_50yoy_inc200 = total_impacts_both_50yoy_inc200 - total_impacts_pir_baseline
quantity_change_both_50yoy_inc200 = quantities_both_50yoy_inc200 - quantities_pir_baseline

file_name = 'blend CN both 50yoy dec 20200414'
mine_life_stats_both_50yoy_dec100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_50yoy_dec100, unit_impacts_both_50yoy_dec100, quantities_both_50yoy_dec100 = calculate_impacts(
    sd_both_50yoy_dec100_cn, sd_both_50yoy_dec100_rw, sd_both_50yoy_dec100, mine_life_stats_both_50yoy_dec100,
    direct_melt_demand_both_50yoy_dec100_cn, direct_melt_demand_both_50yoy_dec100_rw)
impact_change_both_50yoy_dec100 = total_impacts_both_50yoy_dec100 - total_impacts_pir_baseline
quantity_change_both_50yoy_dec100 = quantities_both_50yoy_dec100 - quantities_pir_baseline

file_name = 'blend CN both 50yoy 200 dec 20200414'
mine_life_stats_both_50yoy_dec200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_50yoy_dec200, unit_impacts_both_50yoy_dec200, quantities_both_50yoy_dec200 = calculate_impacts(
    sd_both_50yoy_dec200_cn, sd_both_50yoy_dec200_rw, sd_both_50yoy_dec200, mine_life_stats_both_50yoy_dec200,
    direct_melt_demand_both_50yoy_dec200_cn, direct_melt_demand_both_50yoy_dec200_rw)
impact_change_both_50yoy_dec200 = total_impacts_both_50yoy_dec200 - total_impacts_pir_baseline
quantity_change_both_50yoy_dec200 = quantities_both_50yoy_dec200 - quantities_pir_baseline

file_name = 'blend CN No.2 50yoy inc 20200414'
mine_life_stats_no2_50yoy_inc100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_50yoy_inc100, unit_impacts_no2_50yoy_inc100, quantities_no2_50yoy_inc100 = calculate_impacts(
    sd_no2_50yoy_inc100_cn, sd_no2_50yoy_inc100_rw, sd_no2_50yoy_inc100, mine_life_stats_no2_50yoy_inc100,
    direct_melt_demand_no2_50yoy_inc100_cn, direct_melt_demand_no2_50yoy_inc100_rw)
impact_change_no2_50yoy_inc100 = total_impacts_no2_50yoy_inc100 - total_impacts_pir_baseline
quantity_change_no2_50yoy_inc100 = quantities_no2_50yoy_inc100 - quantities_pir_baseline

file_name = 'blend CN No.2 50yoy 200 inc 20200414'
mine_life_stats_no2_50yoy_inc200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_50yoy_inc200, unit_impacts_no2_50yoy_inc200, quantities_no2_50yoy_inc200 = calculate_impacts(
    sd_no2_50yoy_inc200_cn, sd_no2_50yoy_inc200_rw, sd_no2_50yoy_inc200, mine_life_stats_no2_50yoy_inc200,
    direct_melt_demand_no2_50yoy_inc200_cn, direct_melt_demand_no2_50yoy_inc200_rw)
impact_change_no2_50yoy_inc200 = total_impacts_no2_50yoy_inc200 - total_impacts_pir_baseline
quantity_change_no2_50yoy_inc200 = quantities_no2_50yoy_inc200 - quantities_pir_baseline

file_name = 'blend CN No.2 50yoy dec 20200414'
mine_life_stats_no2_50yoy_dec100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_50yoy_dec100, unit_impacts_no2_50yoy_dec100, quantities_no2_50yoy_dec100 = calculate_impacts(
    sd_no2_50yoy_dec100_cn, sd_no2_50yoy_dec100_rw, sd_no2_50yoy_dec100, mine_life_stats_no2_50yoy_dec100,
    direct_melt_demand_no2_50yoy_dec100_cn, direct_melt_demand_no2_50yoy_dec100_rw)
impact_change_no2_50yoy_dec100 = total_impacts_no2_50yoy_dec100 - total_impacts_pir_baseline
quantity_change_no2_50yoy_dec100 = quantities_no2_50yoy_dec100 - quantities_pir_baseline

file_name = 'blend CN No.2 50yoy 200 dec 20200414'
mine_life_stats_no2_50yoy_dec200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_50yoy_dec200, unit_impacts_no2_50yoy_dec200, quantities_no2_50yoy_dec200 = calculate_impacts(
    sd_no2_50yoy_dec200_cn, sd_no2_50yoy_dec200_rw, sd_no2_50yoy_dec200, mine_life_stats_no2_50yoy_dec200,
    direct_melt_demand_no2_50yoy_dec200_cn, direct_melt_demand_no2_50yoy_dec200_rw)
impact_change_no2_50yoy_dec200 = total_impacts_no2_50yoy_dec200 - total_impacts_pir_baseline
quantity_change_no2_50yoy_dec200 = quantities_no2_50yoy_dec200 - quantities_pir_baseline

categories = ['Direct Melt Scrap', 'Direct Melt Other', 'Fabrication', 'New SX-EW Mines',
                 'New Traditional Mines', 'Operating SX-EW Mines', 'Operating Traditional Mines', 
                 'Primary Refinery', 'Secondary Refinery', 'Refined Metals']
print('All Done')

file_name = 'blend CN alloyed 50yoy inc 20200414'
mine_life_stats_alloyed_50yoy_inc100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_50yoy_inc100, unit_impacts_alloyed_50yoy_inc100, quantities_alloyed_50yoy_inc100 = calculate_impacts(
    sd_alloyed_50yoy_inc100_cn, sd_alloyed_50yoy_inc100_rw, sd_alloyed_50yoy_inc100, mine_life_stats_alloyed_50yoy_inc100,
    direct_melt_demand_alloyed_50yoy_inc100_cn, direct_melt_demand_alloyed_50yoy_inc100_rw)
impact_change_alloyed_50yoy_inc100 = total_impacts_alloyed_50yoy_inc100 - total_impacts_pir_baseline
quantity_change_alloyed_50yoy_inc100 = quantities_alloyed_50yoy_inc100 - quantities_pir_baseline

file_name = 'blend CN alloyed 50yoy 200 inc 20200414'
mine_life_stats_alloyed_50yoy_inc200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_50yoy_inc200, unit_impacts_alloyed_50yoy_inc200, quantities_alloyed_50yoy_inc200 = calculate_impacts(
    sd_alloyed_50yoy_inc200_cn, sd_alloyed_50yoy_inc200_rw, sd_alloyed_50yoy_inc200, mine_life_stats_alloyed_50yoy_inc200,
    direct_melt_demand_alloyed_50yoy_inc200_cn, direct_melt_demand_alloyed_50yoy_inc200_rw)
impact_change_alloyed_50yoy_inc200 = total_impacts_alloyed_50yoy_inc200 - total_impacts_pir_baseline
quantity_change_alloyed_50yoy_inc200 = quantities_alloyed_50yoy_inc200 - quantities_pir_baseline

file_name = 'blend CN alloyed 50yoy dec 20200414'
mine_life_stats_alloyed_50yoy_dec100 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_50yoy_dec100, unit_impacts_alloyed_50yoy_dec100, quantities_alloyed_50yoy_dec100 = calculate_impacts(
    sd_alloyed_50yoy_dec100_cn, sd_alloyed_50yoy_dec100_rw, sd_alloyed_50yoy_dec100, mine_life_stats_alloyed_50yoy_dec100,
    direct_melt_demand_alloyed_50yoy_dec100_cn, direct_melt_demand_alloyed_50yoy_dec100_rw)
impact_change_alloyed_50yoy_dec100 = total_impacts_alloyed_50yoy_dec100 - total_impacts_pir_baseline
quantity_change_alloyed_50yoy_dec100 = quantities_alloyed_50yoy_dec100 - quantities_pir_baseline

file_name = 'blend CN alloyed 50yoy 200 dec 20200414'
mine_life_stats_alloyed_50yoy_dec200 = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_50yoy_dec200, unit_impacts_alloyed_50yoy_dec200, quantities_alloyed_50yoy_dec200 = calculate_impacts(
    sd_alloyed_50yoy_dec200_cn, sd_alloyed_50yoy_dec200_rw, sd_alloyed_50yoy_dec200, mine_life_stats_alloyed_50yoy_dec200,
    direct_melt_demand_alloyed_50yoy_dec200_cn, direct_melt_demand_alloyed_50yoy_dec200_rw)
impact_change_alloyed_50yoy_dec200 = total_impacts_alloyed_50yoy_dec200 - total_impacts_pir_baseline
quantity_change_alloyed_50yoy_dec200 = quantities_alloyed_50yoy_dec200 - quantities_pir_baseline
print('Dooo doo dooooooooo')

file_name = 'blend CN both 25yoy 20200414'
mine_life_stats_both_25yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_25yoy, unit_impacts_both_25yoy, quantities_both_25yoy = calculate_impacts(
    sd_both_25yoy_cn, sd_both_25yoy_rw, sd_both_25yoy, mine_life_stats_both_25yoy,
    direct_melt_demand_both_25yoy_cn, direct_melt_demand_both_25yoy_rw)
impact_change_both_25yoy = total_impacts_both_25yoy - total_impacts_pir_baseline
quantity_change_both_25yoy = quantities_both_25yoy - quantities_pir_baseline

file_name = 'blend CN both 75yoy 20200414'
mine_life_stats_both_75yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_both_75yoy, unit_impacts_both_75yoy, quantities_both_75yoy = calculate_impacts(
    sd_both_75yoy_cn, sd_both_75yoy_rw, sd_both_75yoy, mine_life_stats_both_75yoy,
    direct_melt_demand_both_75yoy_cn, direct_melt_demand_both_75yoy_rw)
impact_change_both_75yoy = total_impacts_both_75yoy - total_impacts_pir_baseline
quantity_change_both_75yoy = quantities_both_75yoy - quantities_pir_baseline

file_name = 'blend CN alloyed 25yoy 20200414'
mine_life_stats_alloyed_25yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_25yoy, unit_impacts_alloyed_25yoy, quantities_alloyed_25yoy = calculate_impacts(
    sd_alloyed_25yoy_cn, sd_alloyed_25yoy_rw, sd_alloyed_25yoy, mine_life_stats_alloyed_25yoy,
    direct_melt_demand_alloyed_25yoy_cn, direct_melt_demand_alloyed_25yoy_rw)
impact_change_alloyed_25yoy = total_impacts_alloyed_25yoy - total_impacts_pir_baseline
quantity_change_alloyed_25yoy = quantities_alloyed_25yoy - quantities_pir_baseline

file_name = 'blend CN alloyed 75yoy 20200414'
mine_life_stats_alloyed_75yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_alloyed_75yoy, unit_impacts_alloyed_75yoy, quantities_alloyed_75yoy = calculate_impacts(
    sd_alloyed_75yoy_cn, sd_alloyed_75yoy_rw, sd_alloyed_75yoy, mine_life_stats_alloyed_75yoy,
    direct_melt_demand_alloyed_75yoy_cn, direct_melt_demand_alloyed_75yoy_rw)
impact_change_alloyed_75yoy = total_impacts_alloyed_75yoy - total_impacts_pir_baseline
quantity_change_alloyed_75yoy = quantities_alloyed_75yoy - quantities_pir_baseline

file_name = 'blend CN No.2 25yoy 20200414'
mine_life_stats_no2_25yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_25yoy, unit_impacts_no2_25yoy, quantities_no2_25yoy = calculate_impacts(
    sd_no2_25yoy_cn, sd_no2_25yoy_rw, sd_no2_25yoy, mine_life_stats_no2_25yoy,
    direct_melt_demand_no2_25yoy_cn, direct_melt_demand_no2_25yoy_rw)
impact_change_no2_25yoy = total_impacts_no2_25yoy - total_impacts_pir_baseline
quantity_change_no2_25yoy = quantities_no2_25yoy - quantities_pir_baseline

file_name = 'blend CN No.2 75yoy 20200414'
mine_life_stats_no2_75yoy = pd.read_excel('John/05 China/Mine level info/mine '+file_name+'.xlsx', index_col=[0,1])
total_impacts_no2_75yoy, unit_impacts_no2_75yoy, quantities_no2_75yoy = calculate_impacts(
    sd_no2_75yoy_cn, sd_no2_75yoy_rw, sd_no2_75yoy, mine_life_stats_no2_75yoy,
    direct_melt_demand_no2_75yoy_cn, direct_melt_demand_no2_75yoy_rw)
impact_change_no2_75yoy = total_impacts_no2_75yoy - total_impacts_pir_baseline
quantity_change_no2_75yoy = quantities_no2_75yoy - quantities_pir_baseline
print('Done-zo')

# %% [markdown]
# Results for ban rates

# %%
for i in ['50yoy']:
    q_baseline_cn = quantities_pir_baseline.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum()

    qc_alloyed_50yoy_cn = quantity_change_alloyed_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_no2_50yoy_cn = quantity_change_no2_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_both_50yoy_cn = quantity_change_both_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    row = [i for i in quantities_pir_baseline.columns if i != 'China']

    q_baseline_rw = quantities_pir_baseline.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum()

    qc_alloyed_50yoy_rw = quantity_change_alloyed_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_no2_50yoy_rw = quantity_change_no2_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_both_50yoy_rw = quantity_change_both_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for i in ['75yoy']:
    qc_alloyed_75yoy_cn = quantity_change_alloyed_75yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_no2_75yoy_cn = quantity_change_no2_75yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_both_75yoy_cn = quantity_change_both_75yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_alloyed_75yoy_rw = quantity_change_alloyed_75yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_no2_75yoy_rw = quantity_change_no2_75yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_both_75yoy_rw = quantity_change_both_75yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for i in ['25yoy']:
    qc_alloyed_25yoy_cn = quantity_change_alloyed_25yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_no2_25yoy_cn = quantity_change_no2_25yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_both_25yoy_cn = quantity_change_both_25yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_alloyed_25yoy_rw = quantity_change_alloyed_25yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_no2_25yoy_rw = quantity_change_no2_25yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_both_25yoy_rw = quantity_change_both_25yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100


ph_series_base = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
ph_series_alloyed_25yoy = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
ph_series_alloyed_75yoy = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])
ph_series_base_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
ph_series_alloyed_25yoy_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
ph_series_alloyed_75yoy_cn = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])
ph_series_base_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
ph_series_alloyed_25yoy_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
ph_series_alloyed_75yoy_rw = pd.DataFrame(0, index = impact_change_alloyed_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])

for metric in ['Global warming (kt CO2 eq)']:#[i for i in impact_change_alloyed_50yoy.index.levels[1] if 'Renewable' not in i]:
    ph_series_alloyed_50yoy,ph_series_alloyed_50yoy_cn, ph_series_alloyed_50yoy_rw   = pct_inc(impact_change_alloyed_50yoy,metric)
    ph_series_alloyed_25yoy,ph_series_alloyed_25yoy_cn,ph_series_alloyed_25yoy_rw = pct_inc(impact_change_alloyed_25yoy,metric)
    ph_series_alloyed_75yoy,ph_series_alloyed_75yoy_cn,ph_series_alloyed_75yoy_rw = pct_inc(impact_change_alloyed_75yoy,metric)
    ph_series_no2_50yoy,    ph_series_no2_50yoy_cn,    ph_series_no2_50yoy_rw   = pct_inc(impact_change_no2_50yoy,metric)
    ph_series_no2_25yoy,    ph_series_no2_25yoy_cn,    ph_series_no2_25yoy_rw = pct_inc(impact_change_no2_25yoy,metric)
    ph_series_no2_75yoy,    ph_series_no2_75yoy_cn,    ph_series_no2_75yoy_rw = pct_inc(impact_change_no2_75yoy,metric)
    ph_series_both_50yoy,ph_series_both_50yoy_cn, ph_series_both_50yoy_rw   = pct_inc(impact_change_both_50yoy,metric)
    ph_series_both_25yoy,ph_series_both_25yoy_cn,ph_series_both_25yoy_rw = pct_inc(impact_change_both_25yoy,metric)
    ph_series_both_75yoy,ph_series_both_75yoy_cn,ph_series_both_75yoy_rw = pct_inc(impact_change_both_75yoy,metric)

    
prop = 'Total refining production'
prop1= 'Primary refining production'
prop2= 'Secondary refining production'
results = pd.concat([pd.DataFrame([[mining_pctinc2020_alloyed_25yoy.loc['20400101'],mining_pctinc2020_alloyed_50yoy.loc['20400101'],mining_pctinc2020_alloyed_75yoy.loc['20400101']],
              [scrap_demand_pctinc2020_alloyed_25yoy_gl.loc['20400101'],scrap_demand_pctinc2020_alloyed_50yoy_gl.loc['20400101'],scrap_demand_pctinc2020_alloyed_75yoy_gl.loc['20400101']],
              [(100*ref_props_alloyed_25yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20400101'],(100*ref_props_alloyed_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20400101'],(100*ref_props_alloyed_75yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20400101']],
              [(100*ref_props_alloyed_25yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20400101'],(100*ref_props_alloyed_50yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20400101'],(100*ref_props_alloyed_75yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20400101']],
              [(100*ref_props_alloyed_25yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20400101'],(100*ref_props_alloyed_50yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20400101'],(100*ref_props_alloyed_75yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20400101']],
              [ph_series_alloyed_25yoy.loc['20400101'].sum(),ph_series_alloyed_50yoy.loc['20400101'].sum(),ph_series_alloyed_75yoy.loc['20400101'].sum()]],
              index = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], columns = [25,50,75]).T,
           pd.DataFrame([[mining_pctinc2020_no2_25yoy.loc['20400101'],mining_pctinc2020_no2_50yoy.loc['20400101'],mining_pctinc2020_no2_75yoy.loc['20400101']],
              [scrap_demand_pctinc2020_no2_25yoy_gl.loc['20400101'],scrap_demand_pctinc2020_no2_50yoy_gl.loc['20400101'],scrap_demand_pctinc2020_no2_75yoy_gl.loc['20400101']],
              [(100*ref_props_no2_25yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20400101'],(100*ref_props_no2_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20400101'],(100*ref_props_no2_75yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20400101']],
              [(100*ref_props_no2_25yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20400101'],(100*ref_props_no2_50yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20400101'],(100*ref_props_no2_75yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20400101']],
              [(100*ref_props_no2_25yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20400101'],(100*ref_props_no2_50yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20400101'],(100*ref_props_no2_75yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20400101']],
              [ph_series_no2_25yoy.loc['20400101'].sum(),ph_series_no2_50yoy.loc['20400101'].sum(),ph_series_no2_75yoy.loc['20400101'].sum()]],
              index = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], columns = [25,50,75]).T,
           pd.DataFrame([[mining_pctinc2020_both_25yoy.loc['20400101'],mining_pctinc2020_both_50yoy.loc['20400101'],mining_pctinc2020_both_75yoy.loc['20400101']],
              [scrap_demand_pctinc2020_both_25yoy_gl.loc['20400101'],scrap_demand_pctinc2020_both_50yoy_gl.loc['20400101'],scrap_demand_pctinc2020_both_75yoy_gl.loc['20400101']],
              [(100*ref_props_both_25yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20400101'],(100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20400101'],(100*ref_props_both_75yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20400101']],
              [(100*ref_props_both_25yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20400101'],(100*ref_props_both_50yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20400101'],(100*ref_props_both_75yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20400101']],
              [(100*ref_props_both_25yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20400101'],(100*ref_props_both_50yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20400101'],(100*ref_props_both_75yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20400101']],
              [ph_series_both_25yoy.loc['20400101'].sum(),ph_series_both_50yoy.loc['20400101'].sum(),ph_series_both_75yoy.loc['20400101'].sum()]],
            index = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], columns = [25,50,75]).T],
          axis=0,keys=['Alloyed','No.2','Both'])

results_cn = pd.concat([pd.DataFrame([[qc_alloyed_25yoy_cn.loc['20400101'],qc_alloyed_50yoy_cn.loc['20400101'],qc_alloyed_75yoy_cn.loc['20400101']],
              [scrap_demand_pctinc2020_alloyed_25yoy_cn.loc['20400101'],scrap_demand_pctinc2020_alloyed_50yoy_cn.loc['20400101'],scrap_demand_pctinc2020_alloyed_75yoy_cn.loc['20400101']],
              [(100*ref_props_alloyed_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20400101'],(100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20400101'],(100*ref_props_alloyed_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20400101']],
              [(100*ref_props_alloyed_25yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20400101'],(100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20400101'],(100*ref_props_alloyed_75yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20400101']],
              [(100*ref_props_alloyed_25yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20400101'],(100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20400101'],(100*ref_props_alloyed_75yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20400101']],
              [ph_series_alloyed_25yoy_cn.loc['20400101'].sum(),ph_series_alloyed_50yoy_cn.loc['20400101'].sum(),ph_series_alloyed_75yoy_cn.loc['20400101'].sum()]],
              index = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], columns = [25,50,75]).T,
           pd.DataFrame([[qc_no2_25yoy_cn.loc['20400101'],qc_no2_50yoy_cn.loc['20400101'],qc_no2_75yoy_cn.loc['20400101']],
              [scrap_demand_pctinc2020_no2_25yoy_cn.loc['20400101'],scrap_demand_pctinc2020_no2_50yoy_cn.loc['20400101'],scrap_demand_pctinc2020_no2_75yoy_cn.loc['20400101']],
              [(100*ref_props_no2_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20400101'],(100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20400101'],(100*ref_props_no2_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20400101']],
              [(100*ref_props_no2_25yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20400101'],(100*ref_props_no2_50yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20400101'],(100*ref_props_no2_75yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20400101']],
              [(100*ref_props_no2_25yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20400101'],(100*ref_props_no2_50yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20400101'],(100*ref_props_no2_75yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20400101']],
              [ph_series_no2_25yoy_cn.loc['20400101'].sum(),ph_series_no2_50yoy_cn.loc['20400101'].sum(),ph_series_no2_75yoy_cn.loc['20400101'].sum()]],
              index = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], columns = [25,50,75]).T,
           pd.DataFrame([[qc_both_25yoy_cn.loc['20400101'],qc_both_50yoy_cn.loc['20400101'],qc_both_75yoy_cn.loc['20400101']],
              [scrap_demand_pctinc2020_both_25yoy_cn.loc['20400101'],scrap_demand_pctinc2020_both_50yoy_cn.loc['20400101'],scrap_demand_pctinc2020_both_75yoy_cn.loc['20400101']],
              [(100*ref_props_both_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20400101'],(100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20400101'],(100*ref_props_both_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20400101']],
              [(100*ref_props_both_25yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20400101'],(100*ref_props_both_50yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20400101'],(100*ref_props_both_75yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20400101']],
              [(100*ref_props_both_25yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20400101'],(100*ref_props_both_50yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20400101'],(100*ref_props_both_75yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20400101']],
              [ph_series_both_25yoy_cn.loc['20400101'].sum(),ph_series_both_50yoy_cn.loc['20400101'].sum(),ph_series_both_75yoy_cn.loc['20400101'].sum()]],
            index = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], columns = [25,50,75]).T],
          axis=0,keys=['Alloyed','No.2','Both'])

results_rw = pd.concat([pd.DataFrame([[qc_alloyed_25yoy_rw.loc['20400101'],qc_alloyed_50yoy_rw.loc['20400101'],qc_alloyed_75yoy_rw.loc['20400101']],
              [scrap_demand_pctinc2020_alloyed_25yoy_rw.loc['20400101'],scrap_demand_pctinc2020_alloyed_50yoy_rw.loc['20400101'],scrap_demand_pctinc2020_alloyed_75yoy_rw.loc['20400101']],
              [(100*ref_props_alloyed_25yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20400101'],(100*ref_props_alloyed_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20400101'],(100*ref_props_alloyed_75yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20400101']],
              [(100*ref_props_alloyed_25yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20400101'],(100*ref_props_alloyed_50yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20400101'],(100*ref_props_alloyed_75yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20400101']],
              [(100*ref_props_alloyed_25yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20400101'],(100*ref_props_alloyed_50yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20400101'],(100*ref_props_alloyed_75yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20400101']],
              [ph_series_alloyed_25yoy_rw.loc['20400101'].sum(),ph_series_alloyed_50yoy_rw.loc['20400101'].sum(),ph_series_alloyed_75yoy_rw.loc['20400101'].sum()]],
              index = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], columns = [25,50,75]).T,
           pd.DataFrame([[qc_no2_25yoy_rw.loc['20400101'],qc_no2_50yoy_rw.loc['20400101'],qc_no2_75yoy_rw.loc['20400101']],
              [scrap_demand_pctinc2020_no2_25yoy_rw.loc['20400101'],scrap_demand_pctinc2020_no2_50yoy_rw.loc['20400101'],scrap_demand_pctinc2020_no2_75yoy_rw.loc['20400101']],
              [(100*ref_props_no2_25yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20400101'],(100*ref_props_no2_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20400101'],(100*ref_props_no2_75yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20400101']],
              [(100*ref_props_no2_25yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20400101'],(100*ref_props_no2_50yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20400101'],(100*ref_props_no2_75yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20400101']],
              [(100*ref_props_no2_25yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20400101'],(100*ref_props_no2_50yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20400101'],(100*ref_props_no2_75yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20400101']],
              [ph_series_no2_25yoy_rw.loc['20400101'].sum(),ph_series_no2_50yoy_rw.loc['20400101'].sum(),ph_series_no2_75yoy_rw.loc['20400101'].sum()]],
              index = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], columns = [25,50,75]).T,
           pd.DataFrame([[qc_both_25yoy_rw.loc['20400101'],qc_both_50yoy_rw.loc['20400101'],qc_both_75yoy_rw.loc['20400101']],
              [scrap_demand_pctinc2020_both_25yoy_rw.loc['20400101'],scrap_demand_pctinc2020_both_50yoy_rw.loc['20400101'],scrap_demand_pctinc2020_both_75yoy_rw.loc['20400101']],
              [(100*ref_props_both_25yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20400101'],(100*ref_props_both_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20400101'],(100*ref_props_both_75yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20400101']],
              [(100*ref_props_both_25yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20400101'],(100*ref_props_both_50yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20400101'],(100*ref_props_both_75yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20400101']],
              [(100*ref_props_both_25yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20400101'],(100*ref_props_both_50yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20400101'],(100*ref_props_both_75yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20400101']],
              [ph_series_both_25yoy_rw.loc['20400101'].sum(),ph_series_both_50yoy_rw.loc['20400101'].sum(),ph_series_both_75yoy_rw.loc['20400101'].sum()]],
            index = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], columns = [25,50,75]).T],
          axis=0,keys=['Alloyed','No.2','Both'])

results.loc[idx['Columns',25],:] = [0,1,2,3,4,5]
results.loc[idx['Columns',50],:] = [0,1,2,3,4,5]
results.loc[idx['Columns',75],:] = [0,1,2,3,4,5]
results_cn.loc[idx['Columns',25],:] = [0,1,2,3,4,5]
results_cn.loc[idx['Columns',50],:] = [0,1,2,3,4,5]
results_cn.loc[idx['Columns',75],:] = [0,1,2,3,4,5]
results_rw.loc[idx['Columns',25],:] = [0,1,2,3,4,5]
results_rw.loc[idx['Columns',50],:] = [0,1,2,3,4,5]
results_rw.loc[idx['Columns',75],:] = [0,1,2,3,4,5]
print('Done')

# %% [markdown]
# Results for refined imports

# %%
for i in ['50yoy']:
    q_baseline_cn = quantities_pir_baseline.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum()

    qc_alloyed_50yoy_cn = quantity_change_alloyed_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_no2_50yoy_cn = quantity_change_no2_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_both_50yoy_cn = quantity_change_both_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    row = [i for i in quantities_pir_baseline.columns if i != 'China']

    q_baseline_rw = quantities_pir_baseline.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum()

    qc_alloyed_50yoy_rw = quantity_change_alloyed_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_no2_50yoy_rw = quantity_change_no2_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_both_50yoy_rw = quantity_change_both_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for i in ['50yoy_inc100']:
    qc_alloyed_50yoy_inc100_cn = quantity_change_alloyed_50yoy_inc100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_no2_50yoy_inc100_cn = quantity_change_no2_50yoy_inc100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_both_50yoy_inc100_cn = quantity_change_both_50yoy_inc100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_alloyed_50yoy_inc100_rw = quantity_change_alloyed_50yoy_inc100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_no2_50yoy_inc100_rw = quantity_change_no2_50yoy_inc100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_both_50yoy_inc100_rw = quantity_change_both_50yoy_inc100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for i in ['50yoy_dec100']:
    qc_alloyed_50yoy_dec100_cn = quantity_change_alloyed_50yoy_dec100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_no2_50yoy_dec100_cn = quantity_change_no2_50yoy_dec100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_both_50yoy_dec100_cn = quantity_change_both_50yoy_dec100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_alloyed_50yoy_dec100_rw = quantity_change_alloyed_50yoy_dec100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_no2_50yoy_dec100_rw = quantity_change_no2_50yoy_dec100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_both_50yoy_dec100_rw = quantity_change_both_50yoy_dec100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for i in ['50yoy_inc200']:
    qc_alloyed_50yoy_inc200_cn = quantity_change_alloyed_50yoy_inc200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_no2_50yoy_inc200_cn = quantity_change_no2_50yoy_inc200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_both_50yoy_inc200_cn = quantity_change_both_50yoy_inc200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_alloyed_50yoy_inc200_rw = quantity_change_alloyed_50yoy_inc200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_no2_50yoy_inc200_rw = quantity_change_no2_50yoy_inc200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_both_50yoy_inc200_rw = quantity_change_both_50yoy_inc200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for i in ['50yoy_dec200']:
    qc_alloyed_50yoy_dec200_cn = quantity_change_alloyed_50yoy_dec200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_no2_50yoy_dec200_cn = quantity_change_no2_50yoy_dec200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_both_50yoy_dec200_cn = quantity_change_both_50yoy_dec200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_alloyed_50yoy_dec200_rw = quantity_change_alloyed_50yoy_dec200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_no2_50yoy_dec200_rw = quantity_change_no2_50yoy_dec200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_both_50yoy_dec200_rw = quantity_change_both_50yoy_dec200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for metric in ['Global warming (kt CO2 eq)']:#[i for i in impact_change_alloyed_50yoy.index.levels[1] if 'Renewable' not in i]:
    ph_series_alloyed_50yoy,ph_series_alloyed_50yoy_cn, ph_series_alloyed_50yoy_rw   = pct_inc(impact_change_alloyed_50yoy,metric)
    ph_series_alloyed_50yoy_dec200,ph_series_alloyed_50yoy_dec200_cn,ph_series_alloyed_50yoy_dec200_rw = pct_inc(impact_change_alloyed_50yoy_dec200,metric)
    ph_series_alloyed_50yoy_dec100,ph_series_alloyed_50yoy_dec100_cn,ph_series_alloyed_50yoy_dec100_rw = pct_inc(impact_change_alloyed_50yoy_dec100,metric)
    ph_series_alloyed_50yoy_inc100,ph_series_alloyed_50yoy_inc100_cn,ph_series_alloyed_50yoy_inc100_rw = pct_inc(impact_change_alloyed_50yoy_inc100,metric)
    ph_series_alloyed_50yoy_inc200,ph_series_alloyed_50yoy_inc200_cn,ph_series_alloyed_50yoy_inc200_rw = pct_inc(impact_change_alloyed_50yoy_inc200,metric)
    ph_series_no2_50yoy,    ph_series_no2_50yoy_cn,    ph_series_no2_50yoy_rw   = pct_inc(impact_change_no2_50yoy,metric)
    ph_series_no2_50yoy_dec200,    ph_series_no2_50yoy_dec200_cn,    ph_series_no2_50yoy_dec200_rw = pct_inc(impact_change_no2_50yoy_dec200,metric)
    ph_series_no2_50yoy_dec100,    ph_series_no2_50yoy_dec100_cn,    ph_series_no2_50yoy_dec100_rw = pct_inc(impact_change_no2_50yoy_dec100,metric)
    ph_series_no2_50yoy_inc100,    ph_series_no2_50yoy_inc100_cn,    ph_series_no2_50yoy_inc100_rw = pct_inc(impact_change_no2_50yoy_inc100,metric)
    ph_series_no2_50yoy_inc200,    ph_series_no2_50yoy_inc200_cn,    ph_series_no2_50yoy_inc200_rw = pct_inc(impact_change_no2_50yoy_inc200,metric)
    ph_series_both_50yoy,ph_series_both_50yoy_cn, ph_series_both_50yoy_rw   = pct_inc(impact_change_both_50yoy,metric)
    ph_series_both_50yoy_dec200,ph_series_both_50yoy_dec200_cn,ph_series_both_50yoy_dec200_rw = pct_inc(impact_change_both_50yoy_dec200,metric)
    ph_series_both_50yoy_dec100,ph_series_both_50yoy_dec100_cn,ph_series_both_50yoy_dec100_rw = pct_inc(impact_change_both_50yoy_dec100,metric)
    ph_series_both_50yoy_inc100,ph_series_both_50yoy_inc100_cn,ph_series_both_50yoy_inc100_rw = pct_inc(impact_change_both_50yoy_inc100,metric)
    ph_series_both_50yoy_inc200,ph_series_both_50yoy_inc200_cn,ph_series_both_50yoy_inc200_rw = pct_inc(impact_change_both_50yoy_inc200,metric)

prop = 'Total refining production'
prop1= 'Primary refining production'
prop2= 'Secondary refining production'
ref_results = pd.concat([pd.concat([pd.concat([mining_pctinc2020_alloyed_50yoy_dec200.loc['20180101':],mining_pctinc2020_alloyed_50yoy_dec100.loc['20180101':],mining_pctinc2020_alloyed_50yoy.loc['20180101':],mining_pctinc2020_alloyed_50yoy_inc100.loc['20180101':],mining_pctinc2020_alloyed_50yoy_inc200.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),\
            pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_dec200_gl.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_dec100_gl.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_gl.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_inc100_gl.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_inc200_gl.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_alloyed_50yoy_dec200_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_dec100_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc100_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc200_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_alloyed_50yoy_dec200_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_dec100_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc100_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc200_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_alloyed_50yoy_dec200_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_dec100_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc100_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc200_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_alloyed_50yoy_dec200.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_dec100.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc100.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc200.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([mining_pctinc2020_no2_50yoy_dec200.loc['20180101':],mining_pctinc2020_no2_50yoy_dec100.loc['20180101':],mining_pctinc2020_no2_50yoy.loc['20180101':],mining_pctinc2020_no2_50yoy_inc100.loc['20180101':],mining_pctinc2020_no2_50yoy_inc200.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_pctinc2020_no2_50yoy_dec200_gl.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_dec100_gl.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_gl.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_inc100_gl.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_inc200_gl.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_no2_50yoy_dec200_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_dec100_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_inc100_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_inc200_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_no2_50yoy_dec200_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_dec100_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_inc100_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_inc200_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_no2_50yoy_dec200_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_dec100_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_inc100_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_inc200_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_no2_50yoy_dec200.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_dec100.loc['20180101':].sum(axis=1),ph_series_no2_50yoy.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc100.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc200.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([mining_pctinc2020_both_50yoy_dec200.loc['20180101':],mining_pctinc2020_both_50yoy_dec100.loc['20180101':],mining_pctinc2020_both_50yoy.loc['20180101':],mining_pctinc2020_both_50yoy_inc100.loc['20180101':],mining_pctinc2020_both_50yoy_inc200.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_pctinc2020_both_50yoy_dec200_gl.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_dec100_gl.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_inc100_gl.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_inc200_gl.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_both_50yoy_dec200_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_dec100_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_inc100_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_inc200_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_both_50yoy_dec200_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_dec100_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_inc100_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_inc200_gl.loc['20180101':,prop1+' response']/ref_props_pir_baseline_gl.loc['20200101',prop1]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_both_50yoy_dec200_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_dec100_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_inc100_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_inc200_gl.loc['20180101':,prop2+' response']/ref_props_pir_baseline_gl.loc['20200101',prop2]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_both_50yoy_dec200.loc['20180101':].sum(axis=1),ph_series_both_50yoy_dec100.loc['20180101':].sum(axis=1),ph_series_both_50yoy.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc100.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc200.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
            keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1)],
          axis=0,keys=['Alloyed','No.2','Both'])

ref_results_cn = pd.concat([pd.concat([pd.concat([qc_alloyed_50yoy_dec200_cn.loc['20180101':],qc_alloyed_50yoy_dec100_cn.loc['20180101':],qc_alloyed_50yoy_cn.loc['20180101':],qc_alloyed_50yoy_inc100_cn.loc['20180101':],qc_alloyed_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),\
            pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_dec200_cn.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_dec100_cn.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_cn.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_inc100_cn.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_alloyed_50yoy_dec200_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_dec100_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc100_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc200_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_alloyed_50yoy_dec200_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_dec100_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc100_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc200_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_alloyed_50yoy_dec200_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_dec100_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc100_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc200_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_alloyed_50yoy_dec200_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_dec100_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc100_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc200_cn.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([qc_no2_50yoy_dec200_cn.loc['20180101':],qc_no2_50yoy_dec100_cn.loc['20180101':],qc_no2_50yoy_cn.loc['20180101':],qc_no2_50yoy_inc100_cn.loc['20180101':],qc_no2_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_pctinc2020_no2_50yoy_dec200_cn.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_dec100_cn.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_cn.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_inc100_cn.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_no2_50yoy_dec200_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_dec100_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_inc100_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_inc200_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_no2_50yoy_dec200_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_dec100_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_inc100_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_inc200_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_no2_50yoy_dec200_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_dec100_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_inc100_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_inc200_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_no2_50yoy_dec200_cn.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_dec100_cn.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc100_cn.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc200_cn.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([qc_both_50yoy_dec200_cn.loc['20180101':],qc_both_50yoy_dec100_cn.loc['20180101':],qc_both_50yoy_cn.loc['20180101':],qc_both_50yoy_inc100_cn.loc['20180101':],qc_both_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_pctinc2020_both_50yoy_dec200_cn.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_dec100_cn.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_cn.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_inc100_cn.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_both_50yoy_dec200_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_dec100_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_inc100_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_inc200_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_both_50yoy_dec200_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_dec100_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_inc100_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_inc200_cn.loc['20180101':,prop1+' response']/ref_props_pir_baseline_cn.loc['20200101',prop1]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_both_50yoy_dec200_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_dec100_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_inc100_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_inc200_cn.loc['20180101':,prop2+' response']/ref_props_pir_baseline_cn.loc['20200101',prop2]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_both_50yoy_dec200_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_dec100_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc100_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc200_cn.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
            keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1)],
          axis=0,keys=['Alloyed','No.2','Both'])

ref_results_rw = pd.concat([pd.concat([pd.concat([qc_alloyed_50yoy_dec200_rw.loc['20180101':],qc_alloyed_50yoy_dec100_rw.loc['20180101':],qc_alloyed_50yoy_rw.loc['20180101':],qc_alloyed_50yoy_inc100_rw.loc['20180101':],qc_alloyed_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),\
            pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_dec200_rw.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_dec100_rw.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_rw.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_inc100_rw.loc['20180101':],scrap_demand_pctinc2020_alloyed_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_alloyed_50yoy_dec200_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_dec100_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc100_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc200_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_alloyed_50yoy_dec200_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_dec100_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc100_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc200_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_alloyed_50yoy_dec200_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_dec100_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc100_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_alloyed_50yoy_inc200_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_alloyed_50yoy_dec200_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_dec100_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc100_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc200_rw.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([qc_no2_50yoy_dec200_rw.loc['20180101':],qc_no2_50yoy_dec100_rw.loc['20180101':],qc_no2_50yoy_rw.loc['20180101':],qc_no2_50yoy_inc100_rw.loc['20180101':],qc_no2_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_pctinc2020_no2_50yoy_dec200_rw.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_dec100_rw.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_rw.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_inc100_rw.loc['20180101':],scrap_demand_pctinc2020_no2_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_no2_50yoy_dec200_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_dec100_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_inc100_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_no2_50yoy_inc200_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_no2_50yoy_dec200_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_dec100_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_inc100_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_no2_50yoy_inc200_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_no2_50yoy_dec200_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_dec100_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_inc100_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_no2_50yoy_inc200_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_no2_50yoy_dec200_rw.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_dec100_rw.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc100_rw.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc200_rw.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([qc_both_50yoy_dec200_rw.loc['20180101':],qc_both_50yoy_dec100_rw.loc['20180101':],qc_both_50yoy_rw.loc['20180101':],qc_both_50yoy_inc100_rw.loc['20180101':],qc_both_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_pctinc2020_both_50yoy_dec200_rw.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_dec100_rw.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_rw.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_inc100_rw.loc['20180101':],scrap_demand_pctinc2020_both_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_both_50yoy_dec200_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_dec100_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_inc100_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_both_50yoy_inc200_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_both_50yoy_dec200_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_dec100_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_inc100_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_both_50yoy_inc200_rw.loc['20180101':,prop1+' response']/ref_props_pir_baseline_rw.loc['20200101',prop1]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_both_50yoy_dec200_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_dec100_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_inc100_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_both_50yoy_inc200_rw.loc['20180101':,prop2+' response']/ref_props_pir_baseline_rw.loc['20200101',prop2]).loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_both_50yoy_dec200_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_dec100_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc100_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc200_rw.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
            keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1)],
          axis=0,keys=['Alloyed','No.2','Both'])

# ref_results.loc[idx['Columns',25],:] = [0,1,2,3,4,5]
# ref_results.loc[idx['Columns',50],:] = [0,1,2,3,4,5]
# ref_results.loc[idx['Columns',75],:] = [0,1,2,3,4,5]
# ref_results_cn.loc[idx['Columns',25],:] = [0,1,2,3,4,5]
# ref_results_cn.loc[idx['Columns',50],:] = [0,1,2,3,4,5]
# ref_results_cn.loc[idx['Columns',75],:] = [0,1,2,3,4,5]
# ref_results_rw.loc[idx['Columns',25],:] = [0,1,2,3,4,5]
# ref_results_rw.loc[idx['Columns',50],:] = [0,1,2,3,4,5]
# ref_results_rw.loc[idx['Columns',75],:] = [0,1,2,3,4,5]
print('Done')

# %% [markdown]
# Absolute rather than relative results

# %%
prop = 'Total refining production'
prop1= 'Primary refining production'
prop2= 'Secondary refining production'
abs_results = pd.concat([pd.concat([pd.concat([mining_response_alloyed_50yoy_dec200.loc['20180101':].cumsum(),mining_response_alloyed_50yoy_dec100.loc['20180101':].cumsum(),mining_response_alloyed_50yoy.loc['20180101':].cumsum(),mining_response_alloyed_50yoy_inc100.loc['20180101':].cumsum(),mining_response_alloyed_50yoy_inc200.loc['20180101':].cumsum()],keys=[-200,-100,0,+100,+200],axis=0),\
            pd.concat([scrap_demand_response_alloyed_50yoy_dec200_gl.loc['20180101':],scrap_demand_response_alloyed_50yoy_dec100_gl.loc['20180101':],scrap_demand_response_alloyed_50yoy_gl.loc['20180101':],scrap_demand_response_alloyed_50yoy_inc100_gl.loc['20180101':],scrap_demand_response_alloyed_50yoy_inc200_gl.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_alloyed_50yoy_dec200_gl.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_dec100_gl.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_gl.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_inc100_gl.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_inc200_gl.loc['20180101':,prop+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_alloyed_50yoy_dec200_gl.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_dec100_gl.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_gl.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_inc100_gl.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_inc200_gl.loc['20180101':,prop1+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_alloyed_50yoy_dec200_gl.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_dec100_gl.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_gl.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_inc100_gl.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_inc200_gl.loc['20180101':,prop2+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_alloyed_50yoy_dec200.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_dec100.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc100.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc200.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([mining_response_no2_50yoy_dec200.loc['20180101':].cumsum(),mining_response_no2_50yoy_dec100.loc['20180101':].cumsum(),mining_response_no2_50yoy.loc['20180101':].cumsum(),mining_response_no2_50yoy_inc100.loc['20180101':].cumsum(),mining_response_no2_50yoy_inc200.loc['20180101':].cumsum()],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_response_no2_50yoy_dec200_gl.loc['20180101':],scrap_demand_response_no2_50yoy_dec100_gl.loc['20180101':],scrap_demand_response_no2_50yoy_gl.loc['20180101':],scrap_demand_response_no2_50yoy_inc100_gl.loc['20180101':],scrap_demand_response_no2_50yoy_inc200_gl.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_no2_50yoy_dec200_gl.loc['20180101':,prop+' response'],ref_props_no2_50yoy_dec100_gl.loc['20180101':,prop+' response'],ref_props_no2_50yoy_gl.loc['20180101':,prop+' response'],ref_props_no2_50yoy_inc100_gl.loc['20180101':,prop+' response'],ref_props_no2_50yoy_inc200_gl.loc['20180101':,prop+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_no2_50yoy_dec200_gl.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_dec100_gl.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_gl.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_inc100_gl.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_inc200_gl.loc['20180101':,prop1+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_no2_50yoy_dec200_gl.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_dec100_gl.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_gl.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_inc100_gl.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_inc200_gl.loc['20180101':,prop2+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_no2_50yoy_dec200.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_dec100.loc['20180101':].sum(axis=1),ph_series_no2_50yoy.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc100.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc200.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([mining_response_both_50yoy_dec200.loc['20180101':].cumsum(),mining_response_both_50yoy_dec100.loc['20180101':].cumsum(),mining_response_both_50yoy.loc['20180101':].cumsum(),mining_response_both_50yoy_inc100.loc['20180101':].cumsum(),mining_response_both_50yoy_inc200.loc['20180101':].cumsum()],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_response_both_50yoy_dec200_gl.loc['20180101':],scrap_demand_response_both_50yoy_dec100_gl.loc['20180101':],scrap_demand_response_both_50yoy_gl.loc['20180101':],scrap_demand_response_both_50yoy_inc100_gl.loc['20180101':],scrap_demand_response_both_50yoy_inc200_gl.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_both_50yoy_dec200_gl.loc['20180101':,prop+' response'],ref_props_both_50yoy_dec100_gl.loc['20180101':,prop+' response'],ref_props_both_50yoy_gl.loc['20180101':,prop+' response'],ref_props_both_50yoy_inc100_gl.loc['20180101':,prop+' response'],ref_props_both_50yoy_inc200_gl.loc['20180101':,prop+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_both_50yoy_dec200_gl.loc['20180101':,prop1+' response'],ref_props_both_50yoy_dec100_gl.loc['20180101':,prop1+' response'],ref_props_both_50yoy_gl.loc['20180101':,prop1+' response'],ref_props_both_50yoy_inc100_gl.loc['20180101':,prop1+' response'],ref_props_both_50yoy_inc200_gl.loc['20180101':,prop1+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_both_50yoy_dec200_gl.loc['20180101':,prop2+' response'],ref_props_both_50yoy_dec100_gl.loc['20180101':,prop2+' response'],ref_props_both_50yoy_gl.loc['20180101':,prop2+' response'],ref_props_both_50yoy_inc100_gl.loc['20180101':,prop2+' response'],ref_props_both_50yoy_inc200_gl.loc['20180101':,prop2+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_both_50yoy_dec200.loc['20180101':].sum(axis=1),ph_series_both_50yoy_dec100.loc['20180101':].sum(axis=1),ph_series_both_50yoy.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc100.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc200.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
            keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1)],
          axis=0,keys=['Alloyed','No.2','Both'])

abs_results_cn = pd.concat([pd.concat([pd.concat([qc_alloyed_50yoy_dec200_cn.loc['20180101':],qc_alloyed_50yoy_dec100_cn.loc['20180101':],qc_alloyed_50yoy_cn.loc['20180101':],qc_alloyed_50yoy_inc100_cn.loc['20180101':],qc_alloyed_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),\
            pd.concat([scrap_demand_response_alloyed_50yoy_dec200_cn.loc['20180101':],scrap_demand_response_alloyed_50yoy_dec100_cn.loc['20180101':],scrap_demand_response_alloyed_50yoy_cn.loc['20180101':],scrap_demand_response_alloyed_50yoy_inc100_cn.loc['20180101':],scrap_demand_response_alloyed_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_alloyed_50yoy_dec200_cn.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_dec100_cn.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_inc100_cn.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_inc200_cn.loc['20180101':,prop+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_alloyed_50yoy_dec200_cn.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_dec100_cn.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_cn.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_inc100_cn.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_inc200_cn.loc['20180101':,prop1+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_alloyed_50yoy_dec200_cn.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_dec100_cn.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_cn.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_inc100_cn.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_inc200_cn.loc['20180101':,prop2+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_alloyed_50yoy_dec200_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_dec100_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc100_cn.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc200_cn.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([qc_no2_50yoy_dec200_cn.loc['20180101':],qc_no2_50yoy_dec100_cn.loc['20180101':],qc_no2_50yoy_cn.loc['20180101':],qc_no2_50yoy_inc100_cn.loc['20180101':],qc_no2_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_response_no2_50yoy_dec200_cn.loc['20180101':],scrap_demand_response_no2_50yoy_dec100_cn.loc['20180101':],scrap_demand_response_no2_50yoy_cn.loc['20180101':],scrap_demand_response_no2_50yoy_inc100_cn.loc['20180101':],scrap_demand_response_no2_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_no2_50yoy_dec200_cn.loc['20180101':,prop+' response'],ref_props_no2_50yoy_dec100_cn.loc['20180101':,prop+' response'],ref_props_no2_50yoy_cn.loc['20180101':,prop+' response'],ref_props_no2_50yoy_inc100_cn.loc['20180101':,prop+' response'],ref_props_no2_50yoy_inc200_cn.loc['20180101':,prop+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_no2_50yoy_dec200_cn.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_dec100_cn.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_cn.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_inc100_cn.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_inc200_cn.loc['20180101':,prop1+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_no2_50yoy_dec200_cn.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_dec100_cn.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_cn.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_inc100_cn.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_inc200_cn.loc['20180101':,prop2+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_no2_50yoy_dec200_cn.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_dec100_cn.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc100_cn.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc200_cn.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([qc_both_50yoy_dec200_cn.loc['20180101':],qc_both_50yoy_dec100_cn.loc['20180101':],qc_both_50yoy_cn.loc['20180101':],qc_both_50yoy_inc100_cn.loc['20180101':],qc_both_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_response_both_50yoy_dec200_cn.loc['20180101':],scrap_demand_response_both_50yoy_dec100_cn.loc['20180101':],scrap_demand_response_both_50yoy_cn.loc['20180101':],scrap_demand_response_both_50yoy_inc100_cn.loc['20180101':],scrap_demand_response_both_50yoy_inc200_cn.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_both_50yoy_dec200_cn.loc['20180101':,prop+' response'],ref_props_both_50yoy_dec100_cn.loc['20180101':,prop+' response'],ref_props_both_50yoy_cn.loc['20180101':,prop+' response'],ref_props_both_50yoy_inc100_cn.loc['20180101':,prop+' response'],ref_props_both_50yoy_inc200_cn.loc['20180101':,prop+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_both_50yoy_dec200_cn.loc['20180101':,prop1+' response'],ref_props_both_50yoy_dec100_cn.loc['20180101':,prop1+' response'],ref_props_both_50yoy_cn.loc['20180101':,prop1+' response'],ref_props_both_50yoy_inc100_cn.loc['20180101':,prop1+' response'],ref_props_both_50yoy_inc200_cn.loc['20180101':,prop1+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_both_50yoy_dec200_cn.loc['20180101':,prop2+' response'],ref_props_both_50yoy_dec100_cn.loc['20180101':,prop2+' response'],ref_props_both_50yoy_cn.loc['20180101':,prop2+' response'],ref_props_both_50yoy_inc100_cn.loc['20180101':,prop2+' response'],ref_props_both_50yoy_inc200_cn.loc['20180101':,prop2+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_both_50yoy_dec200_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_dec100_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc100_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc200_cn.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
            keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1)],
          axis=0,keys=['Alloyed','No.2','Both'])

abs_results_rw = pd.concat([pd.concat([pd.concat([qc_alloyed_50yoy_dec200_rw.loc['20180101':],qc_alloyed_50yoy_dec100_rw.loc['20180101':],qc_alloyed_50yoy_rw.loc['20180101':],qc_alloyed_50yoy_inc100_rw.loc['20180101':],qc_alloyed_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),\
            pd.concat([scrap_demand_response_alloyed_50yoy_dec200_rw.loc['20180101':],scrap_demand_response_alloyed_50yoy_dec100_rw.loc['20180101':],scrap_demand_response_alloyed_50yoy_rw.loc['20180101':],scrap_demand_response_alloyed_50yoy_inc100_rw.loc['20180101':],scrap_demand_response_alloyed_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_alloyed_50yoy_dec200_rw.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_dec100_rw.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_rw.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_inc100_rw.loc['20180101':,prop+' response'],ref_props_alloyed_50yoy_inc200_rw.loc['20180101':,prop+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_alloyed_50yoy_dec200_rw.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_dec100_rw.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_rw.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_inc100_rw.loc['20180101':,prop1+' response'],ref_props_alloyed_50yoy_inc200_rw.loc['20180101':,prop1+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_alloyed_50yoy_dec200_rw.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_dec100_rw.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_rw.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_inc100_rw.loc['20180101':,prop2+' response'],ref_props_alloyed_50yoy_inc200_rw.loc['20180101':,prop2+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_alloyed_50yoy_dec200_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_dec100_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc100_rw.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy_inc200_rw.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([qc_no2_50yoy_dec200_rw.loc['20180101':],qc_no2_50yoy_dec100_rw.loc['20180101':],qc_no2_50yoy_rw.loc['20180101':],qc_no2_50yoy_inc100_rw.loc['20180101':],qc_no2_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_response_no2_50yoy_dec200_rw.loc['20180101':],scrap_demand_response_no2_50yoy_dec100_rw.loc['20180101':],scrap_demand_response_no2_50yoy_rw.loc['20180101':],scrap_demand_response_no2_50yoy_inc100_rw.loc['20180101':],scrap_demand_response_no2_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_no2_50yoy_dec200_rw.loc['20180101':,prop+' response'],ref_props_no2_50yoy_dec100_rw.loc['20180101':,prop+' response'],ref_props_no2_50yoy_rw.loc['20180101':,prop+' response'],ref_props_no2_50yoy_inc100_rw.loc['20180101':,prop+' response'],ref_props_no2_50yoy_inc200_rw.loc['20180101':,prop+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_no2_50yoy_dec200_rw.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_dec100_rw.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_rw.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_inc100_rw.loc['20180101':,prop1+' response'],ref_props_no2_50yoy_inc200_rw.loc['20180101':,prop1+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_no2_50yoy_dec200_rw.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_dec100_rw.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_rw.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_inc100_rw.loc['20180101':,prop2+' response'],ref_props_no2_50yoy_inc200_rw.loc['20180101':,prop2+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_no2_50yoy_dec200_rw.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_dec100_rw.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc100_rw.loc['20180101':].sum(axis=1),ph_series_no2_50yoy_inc200_rw.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
              keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1),
           pd.concat([pd.concat([qc_both_50yoy_dec200_rw.loc['20180101':],qc_both_50yoy_dec100_rw.loc['20180101':],qc_both_50yoy_rw.loc['20180101':],qc_both_50yoy_inc100_rw.loc['20180101':],qc_both_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_response_both_50yoy_dec200_rw.loc['20180101':],scrap_demand_response_both_50yoy_dec100_rw.loc['20180101':],scrap_demand_response_both_50yoy_rw.loc['20180101':],scrap_demand_response_both_50yoy_inc100_rw.loc['20180101':],scrap_demand_response_both_50yoy_inc200_rw.loc['20180101':]],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_both_50yoy_dec200_rw.loc['20180101':,prop+' response'],ref_props_both_50yoy_dec100_rw.loc['20180101':,prop+' response'],ref_props_both_50yoy_rw.loc['20180101':,prop+' response'],ref_props_both_50yoy_inc100_rw.loc['20180101':,prop+' response'],ref_props_both_50yoy_inc200_rw.loc['20180101':,prop+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_both_50yoy_dec200_rw.loc['20180101':,prop1+' response'],ref_props_both_50yoy_dec100_rw.loc['20180101':,prop1+' response'],ref_props_both_50yoy_rw.loc['20180101':,prop1+' response'],ref_props_both_50yoy_inc100_rw.loc['20180101':,prop1+' response'],ref_props_both_50yoy_inc200_rw.loc['20180101':,prop1+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ref_props_both_50yoy_dec200_rw.loc['20180101':,prop2+' response'],ref_props_both_50yoy_dec100_rw.loc['20180101':,prop2+' response'],ref_props_both_50yoy_rw.loc['20180101':,prop2+' response'],ref_props_both_50yoy_inc100_rw.loc['20180101':,prop2+' response'],ref_props_both_50yoy_inc200_rw.loc['20180101':,prop2+' response']],keys=[-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_both_50yoy_dec200_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_dec100_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc100_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_inc200_rw.loc['20180101':].sum(axis=1)],keys=[-200,-100,0,+100,+200],axis=0)],
            keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1)],
          axis=0,keys=['Alloyed','No.2','Both'])

# %% [markdown]
# Results for COVID

# %%
for i in ['50yoy']:
    q_covidimf_baseline_cn = quantities_covidimf_baseline.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum()

    qc_covidimf_shock_cn = quantity_change_covidimf_shock.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_covidimf_both_50yoy_cn = quantity_change_covidimf_both_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    row = [i for i in quantities_covidimf_baseline.columns if i != 'China']

    q_covidimf_baseline_rw = quantities_covidimf_baseline.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum()

    qc_covidimf_shock_rw = quantity_change_covidimf_shock.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

    qc_covidimf_both_50yoy_rw = quantity_change_covidimf_both_50yoy.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for i in ['50yoy_inc100']:
    qc_covidimf_both_50yoy_inc100_cn = quantity_change_covidimf_both_50yoy_inc100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_covidimf_both_50yoy_inc100_rw = quantity_change_covidimf_both_50yoy_inc100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for i in ['50yoy_dec100']:
    qc_covidimf_both_50yoy_dec100_cn = quantity_change_covidimf_both_50yoy_dec100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_covidimf_both_50yoy_dec100_rw = quantity_change_covidimf_both_50yoy_dec100.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for i in ['50yoy_inc200']:
    qc_covidimf_both_50yoy_inc200_cn = quantity_change_covidimf_both_50yoy_inc200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_covidimf_both_50yoy_inc200_rw = quantity_change_covidimf_both_50yoy_inc200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for i in ['50yoy_dec200']:
    qc_covidimf_both_50yoy_dec200_cn = quantity_change_covidimf_both_50yoy_dec200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum().cumsum()/q_baseline_cn.loc['20200101']*100

    qc_covidimf_both_50yoy_dec200_rw = quantity_change_covidimf_both_50yoy_dec200.loc[
        idx[:,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        row].sum(axis=1).groupby(level=0).sum().cumsum()/q_baseline_rw.loc['20200101']*100

for metric in ['Global warming (kt CO2 eq)']:#[i for i in impact_change_alloyed_50yoy.index.levels[1] if 'Renewable' not in i]:
    ph_series_covidimf_both_50yoy,ph_series_covidimf_both_50yoy_cn, ph_series_covidimf_both_50yoy_rw   = pct_inc(impact_change_covidimf_both_50yoy,metric)
    ph_series_covidimf_both_50yoy_dec200,ph_series_covidimf_both_50yoy_dec200_cn,ph_series_covidimf_both_50yoy_dec200_rw = pct_inc(impact_change_covidimf_both_50yoy_dec200,metric,baseline=total_impacts_covidimf_baseline)
    ph_series_covidimf_both_50yoy_dec100,ph_series_covidimf_both_50yoy_dec100_cn,ph_series_covidimf_both_50yoy_dec100_rw = pct_inc(impact_change_covidimf_both_50yoy_dec100,metric,baseline=total_impacts_covidimf_baseline)
    ph_series_covidimf_both_50yoy_inc100,ph_series_covidimf_both_50yoy_inc100_cn,ph_series_covidimf_both_50yoy_inc100_rw = pct_inc(impact_change_covidimf_both_50yoy_inc100,metric,baseline=total_impacts_covidimf_baseline)
    ph_series_covidimf_both_50yoy_inc200,ph_series_covidimf_both_50yoy_inc200_cn,ph_series_covidimf_both_50yoy_inc200_rw = pct_inc(impact_change_covidimf_both_50yoy_inc200,metric,baseline=total_impacts_covidimf_baseline)
    ph_series_covidimf_base,  ph_series_covidimf_base_cn,  ph_series_covidimf_base_rw   = pct_inc(impact_change_covidimf_both_50yoy,metric,baseline=total_impacts_covidimf_baseline)
    ph_series_covidimf_shock,  ph_series_covidimf_shock_cn,  ph_series_covidimf_shock_rw   = pct_inc(impact_change_covidimf_shock,metric,baseline=total_impacts_covidimf_baseline)

prop = 'Total refining production'
prop1= 'Primary refining production'
prop2= 'Secondary refining production'
covid_results_gl = pd.concat([pd.concat([mining_pctinc2020_covidimf_shock.loc['20180101':],mining_pctinc2020_covidimf_both_50yoy_dec200.loc['20180101':],mining_pctinc2020_covidimf_both_50yoy_dec100.loc['20180101':],mining_pctinc2020_covidimf_both_50yoy.loc['20180101':],mining_pctinc2020_covidimf_both_50yoy_inc100.loc['20180101':],mining_pctinc2020_covidimf_both_50yoy_inc200.loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_pctinc2020_covidimf_shock_gl.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_gl.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_gl.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_gl.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_gl.loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_covidimf_shock_gl.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_gl.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop]).loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_covidimf_shock_gl.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_gl.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop1]).loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_covidimf_shock_gl.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_gl.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_gl.loc['20200101',prop2]).loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_covidimf_shock.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_dec200.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_dec100.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_inc100.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_inc200.loc['20180101':].sum(axis=1)],keys=['Shock',-200,-100,0,+100,+200],axis=0)],
            keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1)

covid_results_cn = pd.concat([pd.concat([qc_covidimf_shock_cn.loc['20180101':],qc_covidimf_both_50yoy_dec200_cn.loc['20180101':],qc_covidimf_both_50yoy_dec100_cn.loc['20180101':],qc_covidimf_both_50yoy_cn.loc['20180101':],qc_covidimf_both_50yoy_inc100_cn.loc['20180101':],qc_covidimf_both_50yoy_inc200_cn.loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_pctinc2020_covidimf_shock_cn.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_cn.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_cn.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_cn.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_cn.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_cn.loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_covidimf_shock_cn.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec200_cn.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec100_cn.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_cn.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc100_cn.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc200_cn.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop]).loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_covidimf_shock_cn.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec200_cn.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec100_cn.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_cn.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc100_cn.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc200_cn.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop1]).loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_covidimf_shock_cn.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec200_cn.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec100_cn.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_cn.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc100_cn.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc200_cn.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_cn.loc['20200101',prop2]).loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_covidimf_shock_cn.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_dec200_cn.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_dec100_cn.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_inc100_cn.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_inc200_cn.loc['20180101':].sum(axis=1)],keys=['Shock',-200,-100,0,+100,+200],axis=0)],
            keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1)

covid_results_rw = pd.concat([pd.concat([qc_covidimf_shock_rw.loc['20180101':],qc_covidimf_both_50yoy_dec200_rw.loc['20180101':],qc_covidimf_both_50yoy_dec100_rw.loc['20180101':],qc_covidimf_both_50yoy_rw.loc['20180101':],qc_covidimf_both_50yoy_inc100_rw.loc['20180101':],qc_covidimf_both_50yoy_inc200_rw.loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([scrap_demand_pctinc2020_covidimf_shock_rw.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_rw.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_rw.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_rw.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_rw.loc['20180101':],scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_rw.loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_covidimf_shock_rw.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec200_rw.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec100_rw.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_rw.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc100_rw.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc200_rw.loc['20180101':,prop+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop]).loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_covidimf_shock_rw.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec200_rw.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec100_rw.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_rw.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc100_rw.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop1]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc200_rw.loc['20180101':,prop1+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop1]).loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([(100*ref_props_covidimf_shock_rw.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec200_rw.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_dec100_rw.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_rw.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc100_rw.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop2]).loc['20180101':],(100*ref_props_covidimf_both_50yoy_inc200_rw.loc['20180101':,prop2+' response']/ref_props_covidimf_baseline_rw.loc['20200101',prop2]).loc['20180101':]],keys=['Shock',-200,-100,0,+100,+200],axis=0),
            pd.concat([ph_series_covidimf_shock_rw.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_dec200_rw.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_dec100_rw.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_inc100_rw.loc['20180101':].sum(axis=1),ph_series_covidimf_both_50yoy_inc200_rw.loc['20180101':].sum(axis=1)],keys=['Shock',-200,-100,0,+100,+200],axis=0)],
            keys = ['Mining','Scrap Demand','Total Refining','Primary Refining','Secondary Refining',r'$CO_2$-Equivalent Emissions'], axis=1)

# ref_results.loc[idx['Columns',25],:] = [0,1,2,3,4,5]
# ref_results.loc[idx['Columns',50],:] = [0,1,2,3,4,5]
# ref_results.loc[idx['Columns',75],:] = [0,1,2,3,4,5]
# ref_results_cn.loc[idx['Columns',25],:] = [0,1,2,3,4,5]
# ref_results_cn.loc[idx['Columns',50],:] = [0,1,2,3,4,5]
# ref_results_cn.loc[idx['Columns',75],:] = [0,1,2,3,4,5]
# ref_results_rw.loc[idx['Columns',25],:] = [0,1,2,3,4,5]
# ref_results_rw.loc[idx['Columns',50],:] = [0,1,2,3,4,5]
# ref_results_rw.loc[idx['Columns',75],:] = [0,1,2,3,4,5]
print('Done')

# %% [markdown]
# ## Figure 1: Import Changes

# %%
china_import_data=pd.read_excel('Customs high level data.xlsx', sheet_name='Sheet1', index_col=0)
china_import_data=china_import_data.iloc[6:, :]

# %%
# init_plot(figheight=5,figwidth=12.5)
plt.rcParams.update({'figure.figsize':[12.5,5]})
fig,ax = plt.subplots()
# ax.plot(china_import_data.loc[:, 'Copper import quantity (ktonnes)'][12:], label='Original')
ax.plot(china_import_data.loc[:, 'Copper import quantity (ktonnes)'].rolling(12).mean()[12:], 
         label='12 Month Moving Average',color='tab:orange')
ax.plot(china_import_data.loc[:, 'Equivalent metal ktonne'].rolling(12).mean()[12:], 
         label='12 Month Moving Average', color='tab:blue')
#ax.legend(loc=3)
ax.set_title('China Monthly Copper Scrap Imports')
ax.set_ylabel('Copper scrap imports (kt)')
ax.set_ylim(85,340)
# ax.set_yticks()
ax.grid(False)

secax = ax.twinx()
color = 'tab:red'
secax.plot(china_import_data.loc[:, 'Equivalent metal content'].rolling(12).mean().mul(100)[12:], 
         label='12 Month Moving Average', color = color)
secax.set_ylabel('Import percent copper (%)',color='red')
secax.tick_params(axis='y', labelcolor='red')
secax.set_yticks([30,40,50,60,70])
secax.grid(False)
secax.set_ylim(27,76)
ax.fill_betweenx(y=[50,400],x1=pd.datetime(2017,6,20),x2=pd.datetime(2017,7,11),alpha=0.4,color='red')
ax.fill_betweenx(y=[50,400],x1=pd.datetime(2018,3,20),x2=pd.datetime(2018,4,11),alpha=0.6,color='tab:olive')
ax.fill_betweenx(y=[50,400],x1=pd.datetime(2018,7,20),x2=pd.datetime(2018,8,11),alpha=0.5,color='royalblue')
ax.fill_betweenx(y=[50,400],x1=pd.datetime(2018,11,20),x2=pd.datetime(2018,12,11),alpha=0.5,color='seagreen')
ax.text(pd.datetime(2017,7,1), 328, 'A', fontsize=14,horizontalalignment='center',
        verticalalignment='top', bbox=dict(boxstyle='square', facecolor='white', edgecolor='k', alpha=1))
ax.text(pd.datetime(2018,4,1), 328, 'B', fontsize=14,horizontalalignment='center',
        verticalalignment='top', bbox=dict(boxstyle='square', facecolor='white', edgecolor='k', alpha=1))
ax.text(pd.datetime(2018,8,1), 328, 'C', fontsize=14,horizontalalignment='center',
        verticalalignment='top', bbox=dict(boxstyle='square', facecolor='white', edgecolor='k', alpha=1))
ax.text(pd.datetime(2018,12,1), 328, 'D', fontsize=14,horizontalalignment='center',
        verticalalignment='top', bbox=dict(boxstyle='square', facecolor='white', edgecolor='k', alpha=1))
ax.text(-0.07, 1.08, 'a.', fontsize=16,horizontalalignment='center',
        verticalalignment='top', transform = ax.transAxes, 
        bbox=dict(boxstyle='square', facecolor='white', edgecolor='white', alpha=1))


plt.show()

# %%
# apple bar chart
init_plot(figwidth=7)
fig,ax=plt.subplots()
ax.bar([1,2,3],np.multiply(0.001,[1622.414609, 2347.348233, 3262.916808]),color='#9E0142',alpha=1)
ax.bar([5,6,7],np.multiply(0.001,[3195.435298, 4939.498065, 6272.414498]),color='#9E0142',alpha=1)
ax.set_xlim([0.25999999999999995, 7.739999999999999])
ax.axes.get_xaxis().set_visible(False)
ax.set_yticks([0,2,4,6])
# ax.set_xticks([])

# %% [markdown]
# ## Figure 2: China Shock

# %%
vi

# %%
# fig,[[ax1,ax2,ax3],[ax4,ax5,ax6],[ax7,ax8,ax9]] = plt.subplots(3,3)
init_plot2(fontsize=20)
fig,[ax1,ax7,ax5] = plt.subplots(1,3,figsize=(24,6))
textfontsize=14
blueblue = ['#9ecae1','#6baed6','#4292c6','#2171b5','#084594']

for i in ['Import Scenarios, ax1']:
    # %store -r scrap_imports_cn_all
    cikirs = ['#C9714F','#7D6156','#855260']
    imports_no2 = pd.DataFrame(scrap_imports_cn_all.loc[2018].sum(), index=scrap_imports_cn_all.loc[2018:].index,
                            columns = [0.25, 0.5, 0.75])
    imports_alloyed = pd.DataFrame(scrap_imports_cn_all.loc[2018].sum(), index=scrap_imports_cn_all.loc[2018:].index,
                            columns = [0.25, 0.5, 0.75])
    imports_both = pd.DataFrame(scrap_imports_cn_all.loc[2018].sum(), index=scrap_imports_cn_all.loc[2018:].index,
                            columns = [0.25, 0.5, 0.75])
    n = -1
    for i in scrap_imports_cn_all.loc[2018:].index:
        n +=1
        imports_no2.loc[i] = imports_no2.loc[2018] - scrap_imports_cn_all.loc[2018,'No.2'] + scrap_imports_cn_all.loc[2018,'No.2'] * np.array([0.25**n, 0.5**n, 0.75**n])
        imports_alloyed.loc[i] = imports_alloyed.loc[2018] - scrap_imports_cn_all.loc[2018,'Al_Bronze':].sum() + scrap_imports_cn_all.loc[2018,'Al_Bronze':].sum() * np.array([0.25**n, 0.5**n, 0.75**n])
        imports_both.loc[i] = imports_both.loc[2018] - scrap_imports_cn_all.loc[2018,'No.2':].sum() + scrap_imports_cn_all.loc[2018,'No.2':].sum() * np.array([0.25**n, 0.5**n, 0.75**n])
    # ax1.plot(imports_no2.loc[:,0.25], label='No.2')
    ax1.plot(scrap_imports_cn_all.loc[2000:].sum(axis=1), label='Baseline', color='k')
    ax1.plot(imports_no2.loc[:,0.5],label='No.2',color=cikirs[1])
    ax1.plot(imports_alloyed.loc[:,0.5],label='Alloyed',color=cikirs[0])
    ax1.plot(imports_both.loc[:,0.5],label='Both',color=cikirs[2])
    ax1.fill_between(imports_both.loc[:,0.5].index, imports_both.loc[:,0.25],imports_both.loc[:,0.75], alpha=0.3, color=cikirs[2])
    ax1.fill_between(imports_alloyed.loc[:,0.5].index, imports_alloyed.loc[:,0.25],imports_alloyed.loc[:,0.75], alpha=0.3, color=cikirs[0])
    ax1.fill_between(imports_no2.loc[:,0.5].index, imports_no2.loc[:,0.25],imports_no2.loc[:,0.75], alpha=0.3, color=cikirs[1])
    ax1.legend().set_visible(False)
    ax1.set_ylabel('Total scrap imports (kt copper content)',fontweight='bold')
    ax1.set_title('Total China Scrap Imports',fontweight='bold')
    ax1.set_ylim(350,ax1.get_ylim()[1])

#     ax1.text(2027,1320,'Baseline',color='k',horizontalalignment='left',fontsize=textfontsize)
#     ax1.text(2027,1090,'Alloyed ban',color=cikirs[0],horizontalalignment='left',fontsize=textfontsize)
#     ax1.text(2027,790,'No.2 ban',color=cikirs[1],horizontalalignment='left',fontsize=textfontsize)
#     ax1.text(2027,530,'<99% Cu ban',color=cikirs[2],horizontalalignment='left',fontsize=textfontsize)
    ax1.set_yticks([300,600, 900,1200,1500,1800])
    ax1.set_xticks([2000,2010,2020,2030,2040])
    
for i in ['Environmental impact lines, ax5']:
    c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
    c2 = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd']
    c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
    c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#e6f598','#abdda4','#66c2a5','#3288bd','#5e4fa2']
    colorn = ['#eff3ff','#bdd7e7','#6baed6','#3182bd','#08519c'][::-1]
    plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4a)


    ax5.plot(ph_series_both_50yoy.loc['20180101':].sum(axis=1), color=blues[3], label='global')
    ax5.fill_between(ph_series_both_50yoy.loc['20180101':].index,
                     pd.concat([ph_series_both_25yoy.loc['20180101':].sum(axis=1),ph_series_both_50yoy.loc['20180101':].sum(axis=1),ph_series_both_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_both_25yoy.loc['20180101':].sum(axis=1),ph_series_both_50yoy.loc['20180101':].sum(axis=1),ph_series_both_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=blues[3], alpha=0.3)
    ax5.plot(ph_series_alloyed_50yoy.loc['20180101':].sum(axis=1), color=blues[1], label='global')
    ax5.fill_between(ph_series_alloyed_50yoy.loc['20180101':].index,
                     pd.concat([ph_series_alloyed_25yoy.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy.loc['20180101':].sum(axis=1),ph_series_alloyed_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_alloyed_25yoy.loc['20180101':].sum(axis=1),ph_series_alloyed_50yoy.loc['20180101':].sum(axis=1),ph_series_alloyed_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=blues[1], alpha=0.3)
    ax5.plot(ph_series_no2_50yoy.loc['20180101':].sum(axis=1), color=blues[2], label='global')
    ax5.fill_between(ph_series_no2_50yoy.loc['20180101':].index,
                     pd.concat([ph_series_no2_25yoy.loc['20180101':].sum(axis=1),ph_series_no2_50yoy.loc['20180101':].sum(axis=1),ph_series_no2_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_no2_25yoy.loc['20180101':].sum(axis=1),ph_series_no2_50yoy.loc['20180101':].sum(axis=1),ph_series_no2_75yoy.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=blues[2], alpha=0.3)

    ax5.plot(ph_series_both_50yoy_cn.loc['20180101':].sum(axis=1), color=greens[1], label='china')
    ax5.fill_between(ph_series_both_50yoy_cn.loc['20180101':].index,
                     pd.concat([ph_series_both_25yoy_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_both_75yoy_cn.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_both_25yoy_cn.loc['20180101':].sum(axis=1),ph_series_both_50yoy_cn.loc['20180101':].sum(axis=1),ph_series_both_75yoy_cn.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=greens[1], alpha=0.3)

    ax5.plot(ph_series_both_50yoy_rw.loc['20180101':].sum(axis=1), color=oranges[2], label='RoW')
    ax5.fill_between(ph_series_both_50yoy_rw.loc['20180101':].index,
                     pd.concat([ph_series_both_25yoy_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_both_75yoy_rw.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: min(x),axis=1),
                     pd.concat([ph_series_both_25yoy_rw.loc['20180101':].sum(axis=1),ph_series_both_50yoy_rw.loc['20180101':].sum(axis=1),ph_series_both_75yoy_rw.loc['20180101':].sum(axis=1)],axis=1).apply(lambda x: max(x),axis=1),
                     color=oranges[2], alpha=0.3)
#         ax5.text(pd.datetime(2022,1,1),6.5,'China, <99% Cu ban',color=blues[2],horizontalalignment='left',
#                 fontsize=textfontsize)
#         ax5.text(pd.datetime(2018,1,1),4.9,'Global, <99% Cu ban',color=greens[0],horizontalalignment='left',verticalalignment='top',
#                 fontsize=textfontsize)
#         ax5.text(pd.datetime(2018,1,1),3.95,'Global, No.2 ban',color=greens[2],horizontalalignment='left',verticalalignment='top',
#                 fontsize=textfontsize)
#         ax5.text(pd.datetime(2018,1,1),3,'Global, Alloyed ban',color=greens[1],horizontalalignment='left',verticalalignment='top',
#                 fontsize=textfontsize)
#         ax5.text(pd.datetime(2019,1,1),-4,'Rest of World, <99% Cu ban',color=oranges[2],horizontalalignment='left',
#                 fontsize=textfontsize)
    ax5.set_ylabel(r'$CO_2$-equivalent emissions response'+'\n(Cumulative, % of 2020 value)')
    ax5.set_title(r'Regional $CO_2$-Equivalent Emissions Responses')
        
for i in ['Assymetric response, ax7']:
    for prop in ['Primary refining production']:
        ax7.plot(100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/
                 ref_props_pir_baseline_cn.loc['20200101',prop], label='Primary',color=greens[0])
        ax7.fill_between(ref_props_both_50yoy_cn.loc['20180101':,prop+' response'].index, 
                         np.sort(pd.concat([100*ref_props_both_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,0], 
                         np.sort(pd.concat([100*ref_props_both_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,-1], 
                         color = greens[0], alpha=0.2)
        ax7.plot(100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/
                 ref_props_pir_baseline_cn.loc['20200101',prop], label='Primary',color=greens[2])
        ax7.fill_between(ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response'].index, 
                         np.sort(pd.concat([100*ref_props_alloyed_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,0], 
                         np.sort(pd.concat([100*ref_props_alloyed_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,-1], 
                         color = greens[2], alpha=0.2)
        ax7.plot(100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/
                 ref_props_pir_baseline_cn.loc['20200101',prop], label='Primary',color=greens[1])
        ax7.fill_between(ref_props_no2_50yoy_cn.loc['20180101':,prop+' response'].index, 
                         np.sort(pd.concat([100*ref_props_no2_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,0], 
                         np.sort(pd.concat([100*ref_props_no2_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,-1], 
                         color = greens[1], alpha=0.2)
    
    for prop in ['Secondary refining production']:
        ax7.plot(100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/
                 ref_props_pir_baseline_cn.loc['20200101',prop], label='Secondary',color=greens[3])
        ax7.fill_between(ref_props_both_50yoy_cn.loc['20180101':,prop+' response'].index, 
                         np.sort(pd.concat([100*ref_props_both_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,0], 
                         np.sort(pd.concat([100*ref_props_both_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,-1], 
                         color = greens[3], alpha=0.2)
        ax7.plot(100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/
                 ref_props_pir_baseline_cn.loc['20200101',prop], label='Secondary',color=greens[5])
        ax7.fill_between(ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response'].index, 
                         np.sort(pd.concat([100*ref_props_alloyed_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,0], 
                         np.sort(pd.concat([100*ref_props_alloyed_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,-1], 
                         color = greens[5], alpha=0.2)
        ax7.plot(100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/
                 ref_props_pir_baseline_cn.loc['20200101',prop], label='Secondary',color=greens[4])
        ax7.fill_between(ref_props_no2_50yoy_cn.loc['20180101':,prop+' response'].index, 
                         np.sort(pd.concat([100*ref_props_no2_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,0], 
                         np.sort(pd.concat([100*ref_props_no2_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,-1], 
                         color = greens[4], alpha=0.2)
    ax7.plot([pd.datetime(2010,1,1),pd.datetime(2050,1,1)],[0,0],color='k',linewidth=3)
#     ax7.text(pd.datetime(2026,1,1),90,'Primary refining production, <99% Cu ban',color=blues[0],horizontalalignment='left',
#             fontsize=textfontsize)
#     ax7.text(pd.datetime(2030,6,1),20,'Primary refining production, Alloyed ban',color=blues[1],horizontalalignment='left',verticalalignment='top',
#             fontsize=textfontsize)
#     ax7.text(pd.datetime(2029,1,1),-100,'Primary refining production, No.2 ban',color=blues[2],horizontalalignment='left',
#             fontsize=textfontsize)
#     ax7.text(pd.datetime(2030,1,1),-30,'Secondary refining production, <99% Cu ban',color=purples[0],horizontalalignment='left',
#             fontsize=textfontsize)
#     ax7.text(pd.datetime(2030,1,1),-40,'Secondary refining production, Alloyed ban',color=purples[1],horizontalalignment='left',
#             fontsize=textfontsize)
#     ax7.text(pd.datetime(2030,1,1),-50,'Secondary refining production, No.2 ban',color=purples[2],horizontalalignment='left',
#             fontsize=textfontsize)
    ax7.set_title('China Refining Response, Differing Bans')
    ax7.set_ylabel('Response relative to baseline\n(Cumulative, % of 2020 value)')
    ax7.set_xlim(736293.25, 745131.75)
fig.tight_layout(h_pad=0.1,w_pad=0)
plt.subplots_adjust(wspace=0.22,hspace=0.2)

################ FIGURE 2 #########################
init_plot2(fontsize=18)
fig1 = plt.figure(constrained_layout=True, figsize=(24,5.5))
gs = fig1.add_gridspec(1,7)
ax2 = fig1.add_subplot(gs[0:2])
ax8 = fig1.add_subplot(gs[2:5])
ax6 = fig1.add_subplot(gs[5:])

# [ax2,ax3,ax4,ax6]

for i in ['Mining, scrap, refining responses, ax2']:
#     ax2.plot(mining_pctinc2020_alloyed_50yoy.loc['20180101':], label='Alloyed Ban',color=colors[0])
#     ax2.plot(mining_pctinc2020_no2_50yoy.loc['20180101':], label='No.2 Ban',color=colors[1])
    ax2.plot(mining_pctinc2020_both_50yoy.loc['20180101':], label='Both Ban',color=blueblue[3])
    ax2.fill_between(mining_pctinc2020_both_50yoy.loc['20180101':].index, 
                     pd.concat([mining_pctinc2020_both_50yoy.loc['20180101':], mining_pctinc2020_both_25yoy.loc['20180101':], mining_pctinc2020_both_75yoy.loc['20180101':]], axis=1).apply(lambda x: min(x), axis=1), 
                     pd.concat([mining_pctinc2020_both_50yoy.loc['20180101':], mining_pctinc2020_both_25yoy.loc['20180101':], mining_pctinc2020_both_75yoy.loc['20180101':]], axis=1).apply(lambda x: max(x), axis=1),
                     color = blueblue[3], alpha=0.3)
    
    ax2.plot(scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':], label='Both Ban',color=blueblue[1])
    ax2.fill_between(scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':].index, 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':], scrap_demand_pctinc2020_both_25yoy_gl.loc['20180101':], scrap_demand_pctinc2020_both_75yoy_gl.loc['20180101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_gl.loc['20180101':], scrap_demand_pctinc2020_both_25yoy_gl.loc['20180101':], scrap_demand_pctinc2020_both_75yoy_gl.loc['20180101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = blueblue[1], alpha=0.3)

    
    for prop in ['Total refining production']:
        ax2.plot(100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/
                 ref_props_pir_baseline_gl.loc['20200101',prop], label='Both Ban',color=blueblue[0])
        ax2.fill_between(ref_props_both_50yoy_gl.loc['20180101':,prop+' response'].index, 
                         np.sort(pd.concat([100*ref_props_both_75yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_25yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]],axis=1).values)[:,0], 
                         np.sort(pd.concat([100*ref_props_both_75yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_25yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]],axis=1).values)[:,-1], 
                         color = blueblue[0], alpha=0.2)
        
    for prop in ['Primary refining production']:
        ax2.plot(100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/
                 ref_props_pir_baseline_gl.loc['20200101',prop], label='Both Ban',color=blueblue[4])
        ax2.fill_between(ref_props_both_50yoy_gl.loc['20180101':,prop+' response'].index, 
                         np.sort(pd.concat([100*ref_props_both_75yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_25yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]],axis=1).values)[:,0], 
                         np.sort(pd.concat([100*ref_props_both_75yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_25yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]],axis=1).values)[:,-1], 
                         color = blueblue[4], alpha=0.2)
    
    for prop in ['Secondary refining production']:
        ax2.plot(100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/
                 ref_props_pir_baseline_gl.loc['20200101',prop], label='Both Ban',color=blueblue[2])
        ax2.fill_between(ref_props_both_50yoy_gl.loc['20180101':,prop+' response'].index, 
                         np.sort(pd.concat([100*ref_props_both_75yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_25yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]],axis=1).values)[:,0], 
                         np.sort(pd.concat([100*ref_props_both_75yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_25yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop],100*ref_props_both_50yoy_gl.loc['20180101':,prop+' response']/ref_props_pir_baseline_gl.loc['20200101',prop]],axis=1).values)[:,-1], 
                         color = blueblue[2], alpha=0.2)
      
    ax2.set_title('Global Mining, Refining, & Scrap\nResponses, <99% Cu Ban')
    ax2.set_ylabel('Response relative to baseline\n(Cumulative, % of 2020 value)')
    
    if len(ax2.get_yticks()) < 6:
        pass
    elif 0 in ax2.get_yticks()[::2]:
        ax2.set_yticks(ax2.get_yticks()[::2])
    else:
        ax2.set_yticks(ax2.get_yticks()[1::2])
    ax2.set_yticks([-15,-10,-5,0,5])

#     ax2.text(pd.datetime(2035,1,1),3.5,'Mining production',color=greens[3],horizontalalignment='right',
#             fontsize=textfontsize)
#     ax2.text(pd.datetime(2023,1,1),1.8,'Primary refining production',color=greens[4],horizontalalignment='left',
#             fontsize=textfontsize)
#     ax2.text(pd.datetime(2028,1,1),-1.0,'Total refining production',color=greens[0],horizontalalignment='left',verticalalignment='top',
#             fontsize=textfontsize)
#     ax2.text(pd.datetime(2032,1,1),-3.1,'Scrap demand',color=greens[1],horizontalalignment='left',
#             fontsize=textfontsize)
#     ax2.text(pd.datetime(2037,1,1),-7.4,'Secondary refining\nproduction',color=greens[5],horizontalalignment='center',
#             fontsize=textfontsize)
    ax2.set_ylim(-16.371540753923483,6.2)
    
    
for i in ['Scrap responses, ax3']:
# #     ax3.plot(mining_pctinc2020_alloyed_50yoy.loc['20180101':], label='Alloyed Ban',color=colors[0])
# #     ax3.plot(mining_pctinc2020_no2_50yoy.loc['20180101':], label='No.2 Ban',color=colors[1])
#     ax3.plot(scrap_demand_pctinc2020_both_50yoy_cn.loc['20180101':], label='Scrap',color=blues[1])
#     ax3.fill_between(scrap_demand_pctinc2020_both_50yoy_cn.loc['20180101':].index, 
#                  pd.concat([scrap_demand_pctinc2020_both_50yoy_cn.loc['20180101':], scrap_demand_pctinc2020_both_25yoy_cn.loc['20180101':], scrap_demand_pctinc2020_both_75yoy_cn.loc['20180101':]], axis=1).apply(lambda x: min(x), axis=1), 
#                  pd.concat([scrap_demand_pctinc2020_both_50yoy_cn.loc['20180101':], scrap_demand_pctinc2020_both_25yoy_cn.loc['20180101':], scrap_demand_pctinc2020_both_75yoy_cn.loc['20180101':]], axis=1).apply(lambda x: max(x), axis=1),
#                  color = blues[1], alpha=0.3)

#     ax3.plot(scrap_demand_pctinc2020_both_50yoy_rw.loc['20180101':], label='Scrap',color=oranges[1])
#     ax3.fill_between(scrap_demand_pctinc2020_both_50yoy_rw.loc['20180101':].index, 
#                  pd.concat([scrap_demand_pctinc2020_both_50yoy_rw.loc['20180101':], scrap_demand_pctinc2020_both_25yoy_rw.loc['20180101':], scrap_demand_pctinc2020_both_75yoy_rw.loc['20180101':]], axis=1).apply(lambda x: min(x), axis=1), 
#                  pd.concat([scrap_demand_pctinc2020_both_50yoy_rw.loc['20180101':], scrap_demand_pctinc2020_both_25yoy_rw.loc['20180101':], scrap_demand_pctinc2020_both_75yoy_rw.loc['20180101':]], axis=1).apply(lambda x: max(x), axis=1),
#                  color = oranges[1], alpha=0.3)

    
      
#     ax3.set_title('China Refining & Scrap Responses\n<99% Cu Ban')
#     ax3.set_ylabel('Response relative to baseline\n(Cumulative, % of 2020 value)')
# #     ax3.text(pd.datetime(2026,1,1),90,'Primary refining production',color=blues[3],horizontalalignment='left',
# #             fontsize=textfontsize)
# #     ax3.text(pd.datetime(2030,6,1),20,'Total refining production',color=blues[0],horizontalalignment='left',verticalalignment='top',
# #             fontsize=textfontsize)
# #     ax3.text(pd.datetime(2029,1,1),-100,'Scrap demand',color=blues[1],horizontalalignment='left',
# #             fontsize=textfontsize)
# #     ax3.text(pd.datetime(2030,1,1),-30,'Secondary refining production',color=blues[2],horizontalalignment='left',
# #             fontsize=textfontsize)
#     if len(ax3.get_yticks()) < 6:
#         pass
#     elif 0 in ax3.get_yticks()[::2]:
#         ax3.set_yticks(ax3.get_yticks()[::2])
#     else:
#         ax3.set_yticks(ax3.get_yticks()[1::2])
#     ax3.set_yticks([-300,-150,0,150])
    
# for i in ['Total refining responses, ax4']:
# #     ax4.plot(mining_pctinc2020_alloyed_50yoy.loc['20180101':], label='Alloyed Ban',color=colors[0])
# #     ax4.plot(mining_pctinc2020_no2_50yoy.loc['20180101':], label='No.2 Ban',color=colors[1])
    
    
#     for prop in ['Total refining production']:
#         ax4.plot(100*ref_props_both_50yoy_rw.loc['20180101':,prop+' response']/
#                  ref_props_pir_baseline_rw.loc['20200101',prop], label='Total',color=oranges[0])
#         ax4.fill_between(ref_props_both_50yoy_rw.loc['20180101':,prop+' response'].index, 
#                          np.sort(pd.concat([100*ref_props_both_75yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_both_25yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_both_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]],axis=1).values)[:,0], 
#                          np.sort(pd.concat([100*ref_props_both_75yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_both_25yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_both_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]],axis=1).values)[:,-1], 
#                          color = oranges[0], alpha=0.2)
#         ax4.plot(100*ref_props_no2_50yoy_rw.loc['20180101':,prop+' response']/
#                  ref_props_pir_baseline_rw.loc['20200101',prop], label='Total',color=greens[1])
#         ax4.fill_between(ref_props_no2_50yoy_rw.loc['20180101':,prop+' response'].index, 
#                          np.sort(pd.concat([100*ref_props_no2_75yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_no2_25yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_no2_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]],axis=1).values)[:,0], 
#                          np.sort(pd.concat([100*ref_props_no2_75yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_no2_25yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_no2_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]],axis=1).values)[:,-1], 
#                          color = greens[1], alpha=0.2)
#         ax4.plot(100*ref_props_alloyed_50yoy_rw.loc['20180101':,prop+' response']/
#                  ref_props_pir_baseline_rw.loc['20200101',prop], label='Total',color=greens[2])
#         ax4.fill_between(ref_props_alloyed_50yoy_rw.loc['20180101':,prop+' response'].index, 
#                          np.sort(pd.concat([100*ref_props_alloyed_75yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_alloyed_25yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_alloyed_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]],axis=1).values)[:,0], 
#                          np.sort(pd.concat([100*ref_props_alloyed_75yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_alloyed_25yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop],100*ref_props_alloyed_50yoy_rw.loc['20180101':,prop+' response']/ref_props_pir_baseline_rw.loc['20200101',prop]],axis=1).values)[:,-1], 
#                          color = greens[2], alpha=0.2)
        
#         ax4.plot(100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/
#                  ref_props_pir_baseline_cn.loc['20200101',prop], label='Total',color=blues[0])
#         ax4.fill_between(ref_props_both_50yoy_cn.loc['20180101':,prop+' response'].index, 
#                          np.sort(pd.concat([100*ref_props_both_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,0], 
#                          np.sort(pd.concat([100*ref_props_both_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_both_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,-1], 
#                          color = blues[0], alpha=0.2)
#         ax4.plot(100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/
#                  ref_props_pir_baseline_cn.loc['20200101',prop], label='Total',color=greens[1])
#         ax4.fill_between(ref_props_no2_50yoy_cn.loc['20180101':,prop+' response'].index, 
#                          np.sort(pd.concat([100*ref_props_no2_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,0], 
#                          np.sort(pd.concat([100*ref_props_no2_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_no2_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,-1], 
#                          color = greens[1], alpha=0.2)
#         ax4.plot(100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/
#                  ref_props_pir_baseline_cn.loc['20200101',prop], label='Total',color=greens[2])
#         ax4.fill_between(ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response'].index, 
#                          np.sort(pd.concat([100*ref_props_alloyed_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,0], 
#                          np.sort(pd.concat([100*ref_props_alloyed_75yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_25yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop],100*ref_props_alloyed_50yoy_cn.loc['20180101':,prop+' response']/ref_props_pir_baseline_cn.loc['20200101',prop]],axis=1).values)[:,-1], 
#                          color = greens[2], alpha=0.2)
        
#     ax4.set_title('Regional Total Refining Responses')
#     ax4.set_ylabel('Response relative to baseline\n(Cumulative, % of 2020 value)')
    
# #     ax4.set_ylim(-16.371540753923483,6.2)
    
# #     ax4.text(pd.datetime(2022,1,1),-88,'Primary refining production',color=oranges[3],horizontalalignment='left',
# #             fontsize=textfontsize)
# #     ax4.text(pd.datetime(2030,1,1),-15,'Total refining production',color=oranges[0],horizontalalignment='left',verticalalignment='top',
# #             fontsize=textfontsize)
# #     ax4.text(pd.datetime(2029,1,1),50,'Scrap demand',color=oranges[1],horizontalalignment='left',
# #             fontsize=textfontsize)
# #     ax4.text(pd.datetime(2030,6,1),5,'Secondary refining production',color=oranges[2],horizontalalignment='left',
# #             fontsize=textfontsize)
# #     ax4.legend()

#     if len(ax4.get_yticks()) < 6:
#         pass
#     elif 0 in ax4.get_yticks()[::2]:
#         ax4.set_yticks(ax4.get_yticks()[::2])
#     else:
#         ax4.set_yticks(ax4.get_yticks()[1::2])
#     ax4.set_yticks([-200,-100,0,100,200])
    print(' ')

for i in ['Environmental impact stack, ax6']:
    for metric in ['Global warming (kt CO2 eq)']:#[i for i in impact_change_alloyed_50yoy.index.levels[1] if 'Renewable' not in i]:
        if 'New SX-EW Mines' in ph_series_both_50yoy_cn.columns:
            ph_series_both_50yoy_cn.drop(columns=['New SX-EW Mines','Operating SX-EW Mines'],inplace=True)
        ax6.stackplot(ph_series_both_50yoy_cn.loc['20180101':,:].index, ph_series_both_50yoy_cn[ph_series_both_50yoy_cn>0].fillna(0).loc['20180101':].transpose(), 
                  labels=ph_series_both_50yoy_cn.columns)
        ax6.plot(ph_series_both_50yoy_cn.loc['20180101':].sum(axis=1), color='k', label='Net Response')
        ax6.legend(loc='upper left',fontsize=16,ncol=1,
                  handlelength=0.8, handletextpad=0.4, labelspacing=0.2)
        ax6.stackplot(ph_series_both_50yoy_cn.loc['20180101':,:].index, ph_series_both_50yoy_cn[ph_series_both_50yoy_cn<0.1].fillna(0).loc['20180101':].transpose(), 
                  labels=ph_series_both_50yoy_cn.columns)
        ax6.set_title(r'China Sectoral $CO_2$-Equivalent Emissions'+'\nResponse, <99% Cu Ban')
        ax6.set_ylabel(r'$CO_2$-equivalent emissions response'+'\n(Cumulative, % of 2020 value)');
        ax6.set_ylim(-6.4858935012509775, 25.572236099505908)

for i in ['Distribution plot']:
    scat = results.loc[idx[:,50],:].reset_index(drop=True,level=1).T
    c5 = pd.Series([blues[1],blues[2],blues[3]],index=['Alloyed','No.2','Both'])
    pos = pd.Series([-0.2,0,0.2],index=c5.index)
    for i in c5.index:
        vi = results.loc[idx[i,:],:].reset_index(drop=True,level=0)
        parts = ax8.violinplot(vi.T,
                      positions=results.loc[idx['Columns',50],:]+pos[i],
                      widths = 0.4, showextrema=False)
        for pc in parts['bodies']:
            pc.set_facecolor(c5.loc[i])
            pc.set_alpha(0.5)

        ax8.scatter(x=results.loc[idx['Columns',50],:]+pos[i],y=vi.mean(axis=0),c=[c5.loc[i]])
#         for k in vi.columns:
#             ax8.scatter(x=np.repeat(results.loc[idx['Columns',50],k]+pos[i],len(vi.index)),y=vi.loc[:,k],c=[c5.loc[i]])
    # ax8.set_yscale('symlog')
    # ax8.set_yticks([-10,-5,-2,-1,-0.5,0,0.5])
    # ax8.set_yticklabels([-10,-5,-2,-1,-0.5,0,0.5])
    ax8.set_xticklabels(['','Mining','Scrap Demand','Total\nRefining','Primary\nRefining','Secondary\nRefining',
                       r'$CO_2$'+'-Equivalent\nEmissions']);

    ax8.set_xticks([0.5,1.5,2.5,3.5,4.5],minor=True)
    ax8.tick_params(axis='x',which='major',length=7,color='white',pad=5)
    ax8.tick_params(axis='x',which='minor',length=5,direction='in',width=3)

    ax8.set_title('Global Distribution of Responses across Bans and Rates')
    ax8.set_ylabel('Cumulative response at 2040\n(% of 2020 value)')

fig1.tight_layout(h_pad=0.1,w_pad=0.1)
plt.subplots_adjust(wspace=0.6,hspace=0.2)

# %%
# results.loc[idx['Columns',50],:]+pos[i]
impact_change_both_50yoy.index.levels[1]

# %%
pact = impact_change_both_50yoy.index.levels[1][5]
impact_change_both_50yoy.loc[idx['20180101':,pact],idx['China',:]].sum(axis=1).cumsum()/total_impacts_both_50yoy.loc[idx['20200101',pact],idx['China',:]].sum(axis=1).values[0]

# %% [markdown]
# Checking on China's concentrate imports

# %%
historical_prod_cn.index = pd.date_range('19500101','20180101',freq='AS')
quantities_pir_baseline.loc[idx['20180101','Operating Traditional Mines'],'China'] = historical_prod_cn\
    .loc['20180101','Total mining production']
quantities_both_50yoy.loc[idx['20180101','Operating Traditional Mines'],'China'] = historical_prod_cn\
    .loc['20180101','Total mining production']
quantities_both_50yoy_inc200.loc[idx['20180101','Operating Traditional Mines'],'China'] = historical_prod_cn\
    .loc['20180101','Total mining production']
quantities_both_50yoy_dec200.loc[idx['20180101','Operating Traditional Mines'],'China'] = historical_prod_cn\
    .loc['20180101','Total mining production']
(sd_pir_baseline_cn.loc['20180101':,'Primary refining production'] - quantities_pir_baseline.loc[
        idx['20180101':,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum()*.99).plot(figsize=(8,5.5))
(sd_both_50yoy_cn.loc['20180101':,'Primary refining production'] - quantities_both_50yoy.loc[
        idx['20180101':,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum()*.99).plot(figsize=(8,5.5))
(sd_both_50yoy_inc200_cn.loc['20180101':,'Primary refining production'] - quantities_both_50yoy_inc200.loc[
        idx['20180101':,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum()*.99).plot()
(sd_both_50yoy_dec200_cn.loc['20180101':,'Primary refining production'] - quantities_both_50yoy_dec200.loc[
        idx['20180101':,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum()*.99).plot()
historical_prod_cn.loc['19600101':,'Concentrate imports (kt)'].plot()
(sd_both_50yoy_cn.loc['19600101':'20180101','Primary refining production']-
 0.99*historical_prod_cn.loc['19600101':,'Total mining production']).plot().grid(axis='x')
plt.plot([pd.datetime(2018,1,1),pd.datetime(2018,1,1)],[500,13500],'k--')
plt.legend(['Projected baseline','Projected <99% Cu ban','Projected <99% Cu ban, \n+200 kt/yr refined imports',
            'Projected <99% Cu ban, \n-200 kt/yr refined imports',
            'Historical reported','Historical calculated'])
plt.title('China Concentrate Imports')

# %%
quantities_both_50yoy.loc[
        idx['20180101':,['New SX-EW Mines','New Traditional Mines','Operating SX-EW Mines','Operating Traditional Mines']],
        'China'].groupby(level=0).sum()
# %store -r historical_prod_cn

# %%
historical_prod_cn.columns

# %%
fig5,(ax2,ax3) = plt.subplots(1,2, frameon=False)
ax2.plot(scrap_demand_pctinc2020_alloyed_50yoy_cn.loc['20170101':], label='Alloyed Ban',color=colors[0])
ax2.plot(scrap_demand_pctinc2020_no2_50yoy_cn.loc['20170101':], label='No.2 Ban',color=colors[1])
ax2.plot(scrap_demand_pctinc2020_both_50yoy_cn.loc['20170101':], label='Both Ban',color=colors[2])

ax2.fill_between(scrap_demand_pctinc2020_alloyed_50yoy_cn.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[0], alpha=0.3)
ax2.fill_between(scrap_demand_pctinc2020_no2_50yoy_cn.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[1], alpha=0.3)
ax2.fill_between(scrap_demand_pctinc2020_both_50yoy_cn.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_cn.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_cn.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_cn.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[2], alpha=0.3)

ax2.set_title('China Scrap Consumption Response')
ax2.set_ylabel('Cumulative scrap response (% of 2020 value)')

# ax2.legend()
ax2.set_yticks(ax2.get_yticks()[::2])
ax2.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
ax2.set_axisbelow(True)

ax3.plot(scrap_demand_pctinc2020_alloyed_50yoy_rw.loc['20170101':], label='Alloyed Ban',color=colors[0])
ax3.plot(scrap_demand_pctinc2020_no2_50yoy_rw.loc['20170101':], label='No.2 Ban',color=colors[1])
ax3.plot(scrap_demand_pctinc2020_both_50yoy_rw.loc['20170101':], label='Both Ban',color=colors[2])

ax3.fill_between(scrap_demand_pctinc2020_alloyed_50yoy_rw.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[0], alpha=0.3)
ax3.fill_between(scrap_demand_pctinc2020_no2_50yoy_rw.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[1], alpha=0.3)
ax3.fill_between(scrap_demand_pctinc2020_both_50yoy_rw.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_rw.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_rw.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_rw.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[2], alpha=0.3)

ax3.set_title('Rest of World Scrap Consumption Response')
ax3.set_ylabel('Cumulative scrap response (% of 2020 value)')

# ax3.legend()
ax3.set_yticks(ax3.get_yticks()[1::2])
ax3.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
ax3.set_axisbelow(True)


mpl.rcParams.update({'figure.figsize': [8, 4]})
fig, ax1 = plt.subplots()
ax1.plot(scrap_demand_pctinc2020_alloyed_50yoy_gl.loc['20170101':], label='Alloyed Ban',color=colors[0])
ax1.plot(scrap_demand_pctinc2020_no2_50yoy_gl.loc['20170101':], label='No.2 Ban',color=colors[1])
ax1.plot(scrap_demand_pctinc2020_both_50yoy_gl.loc['20170101':], label='Both Ban',color=colors[2])

ax1.fill_between(scrap_demand_pctinc2020_alloyed_50yoy_gl.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_alloyed_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_alloyed_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_alloyed_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[0], alpha=0.3)
ax1.fill_between(scrap_demand_pctinc2020_no2_50yoy_gl.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_no2_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_no2_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_no2_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[1], alpha=0.3)
ax1.fill_between(scrap_demand_pctinc2020_both_50yoy_gl.loc['20170101':].index, 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: min(x), axis=1), 
                 pd.concat([scrap_demand_pctinc2020_both_50yoy_gl.loc['20170101':], scrap_demand_pctinc2020_both_25yoy_gl.loc['20170101':], scrap_demand_pctinc2020_both_75yoy_gl.loc['20170101':]], axis=1).apply(lambda x: max(x), axis=1),
                 color = colors[2], alpha=0.3)

ax1.set_title('Global Scrap Consumption Response')
ax1.set_ylabel('Cumulative scrap response (% of 2020 value)')
ax1.set_yticks(ax1.get_yticks()[::2])
# ax1.legend()
ax1.grid(axis='y',color='0.9',linestyle='-',linewidth=1)
ax1.set_axisbelow(True)

# %% [markdown]
# ## Figure 3: Import Changes

# %%
pd.concat([ref_results.loc[idx['Both',:,'20400101'],:],abs_results.loc[idx['Both',:,'20400101'],:]],keys=['relative (%)','absolute (kt)'])

# %%
# results.loc[idx['Columns',50],:]+pos[i]
impact_change_both_50yoy.index.levels[1]

# %%
impact_change_alloyed_25yoy.columns.levels[1]

# %%
pact = impact_change_both_50yoy.index.levels[1][[1,6,5,14,-3]]
row = ['Oceania','Africa','Europe','North America','Latin America','Other Asia']
world = ['Oceania','Africa','Europe','North America','Latin America','Other Asia','China']
china = ['China']
numerator = china
denominator = china
for i in pact:
    print(i)
    print('kt:',(impact_change_both_50yoy_inc200.loc[idx['20180101':,i],idx[numerator,:]].sum(axis=1).cumsum()).loc['20400101'].values[0])
    print('% of 2020:',(impact_change_both_50yoy_inc200.loc[idx['20180101':,i],idx[numerator,:]].sum(axis=1).cumsum()/total_impacts_pir_baseline.loc[idx['20200101',i],idx[denominator,:]].sum(axis=1).values[0]).loc['20400101'].values[0]*100)
    print('2020 val:', total_impacts_both_50yoy_inc200.loc[idx['20200101',i],idx[numerator,:]].sum(axis=1).values[0])
    print('')

print('COVID SHOCK:')
for i in pact:
    print(i)
    print('kt:',(impact_change_covidimf_shock.loc[idx['20180101':,i],idx[numerator,:]].sum(axis=1).cumsum()).loc['20400101'].values[0])
    print('% of 2020:',(impact_change_covidimf_shock.loc[idx['20180101':,i],idx[numerator,:]].sum(axis=1).cumsum()/total_impacts_covidimf_baseline.loc[idx['20200101',i],idx[denominator,:]].sum(axis=1).values[0]).loc['20400101'].values[0]*100)
    print('2020 val:', total_impacts_covidimf_shock.loc[idx['20200101',i],idx[numerator,:]].sum(axis=1).values[0])
    print('')

# %%
print(subset_gl.loc[:,0].idxmax())
print(colors[2])
subset_gl

# %%
# c5 = pd.Series([greens[2],greens[1],greens[0]],index=['Alloyed','No.2','Both'])

red_up_tri = matplotlib.colors.LinearSegmentedColormap.from_list('up_tri', ['red',colors[2]])
green_up_tri = matplotlib.colors.LinearSegmentedColormap.from_list('up_tri', ['green',colors[2]])
green_down_tri = matplotlib.colors.LinearSegmentedColormap.from_list('down_tri', [colors[2],'green'])
red_down_tri = matplotlib.colors.LinearSegmentedColormap.from_list('down_tri', [colors[2],'red'])

init_plot2(fontsize=24)

def triangle(ax,x=0.5,width=1,bot=0,top=1,color_map=plt.cm.RdYlGn):
    left_x = x-width/2
    right_x = x+width/2
    path = Path([[left_x,bot],[x,top],[right_x,bot],[left_x,bot]])
    patch = PathPatch(path, facecolor='none',edgecolor='none',zorder=2)
    ax.add_patch(patch) 
    Z, Z2 = np.meshgrid(np.linspace(0,0), np.linspace(0,1))
    im = ax.imshow(Z-Z2, aspect='auto',interpolation='bilinear', cmap=color_map,
                    origin='lower', extent=[ax.get_xlim()[0], ax.get_xlim()[1], ax.get_ylim()[0], ax.get_ylim()[1]],
                    clip_path=patch, clip_on=True)
    im.set_clip_path(patch)
    
fig1 = plt.figure(constrained_layout=True, figsize=(24,7))
gs = fig1.add_gridspec(1,5)
ax1 = fig1.add_subplot(gs[0:2])
ax2 = fig1.add_subplot(gs[2:])

for i in ['Imports,ax1']:
    ref_imports=pd.read_excel('Production data compile.xlsx', sheet_name='China', index_col=0, usecols='A:O,W:X,AE').loc[1983:2018, 'Net Refined Imports']
    ref_imports_i100 = ref_imports.copy()
    ref_imports_i200 = ref_imports.copy()
    ref_imports_d100 = ref_imports.copy()
    ref_imports_d200 = ref_imports.copy()
    for i in np.arange(2019,2041):
        ref_imports.loc[i] = ref_imports.loc[2018]
        ref_imports_i100.loc[i] = ref_imports.loc[2018] + (i-2018)*100
        ref_imports_i200.loc[i] = ref_imports.loc[2018] + (i-2018)*200
        ref_imports_d100.loc[i] = ref_imports.loc[2018] - (i-2018)*100
        ref_imports_d200.loc[i] = ref_imports.loc[2018] - (i-2018)*200

    ref_imports_d100[ref_imports_d100<0] = 0
    ref_imports_d200[ref_imports_d200<0] = 0

    ax1.plot(ref_imports_i200, label='+200',color= (0,0.6,0))
    ax1.plot(ref_imports_i100, label='+100',color= (0.3,0.4,0.3))
    ax1.plot(ref_imports_d100, label='-100',color= [0.6,0.1,0.0])
    ax1.plot(ref_imports_d200, label='-200',color= [.9,0.1,0])
    ax1.plot(ref_imports, label='Baseline',color= 'k')
    # plt.legend().set_visible(False)
    ax1.set_title('China Refined Copper Imports')
    ax1.set_ylabel('China net refined copper imports (kt)')

for i in ['Global,ax2']:
    subset_gl = ref_results.loc[idx['Both',:,'20400101'],:].reset_index(drop=True, level=2).reset_index(drop=True, level=0)
    subset_gl.columns = [0,1,2,3,4,5]
    parts = ax2.violinplot(subset_gl.iloc[:,:-1].T,
                  widths = 0.4, showextrema=False)
    vi_color = colors[2]
    for pc in parts['bodies']:
        pc.set_facecolor(vi_color)
        pc.set_alpha(1)
    
    parts = ax2.violinplot(subset_gl.iloc[:,-1],positions=[6],
                  widths = 0.4, showextrema=False)
    vi_color = colors[2]
    for pc in parts['bodies']:
        pc.set_facecolor((0.4588235294117647, 0.5392156862745098, 0.9019607843137254))
        pc.set_alpha(1)
    
#     tri_width = 0.2
    for i in subset_gl.columns:
        ax2.scatter(i+1,subset_gl.loc[0,i],color='#494770')
        ax2.scatter(i+1,subset_gl.loc[100,i],color='#494770')
        ax2.scatter(i+1,subset_gl.loc[200,i],color='#494770')
        ax2.scatter(i+1,subset_gl.loc[-200,i],color='#494770')
        ax2.scatter(i+1,subset_gl.loc[-100,i],color='#494770')
#         ax2.scatter(i+1,subset_gl.loc[200,i],color='green')
#         ax2.scatter(x=np.repeat(i+1,len(subset_gl.index)),y=subset_gl.loc[:,i])
#         if subset_gl.loc[:,i].idxmax() == -200:
#             triangle(ax2, x=i+1, width=tri_width, bot=subset_gl.loc[0,i], top=subset_gl.loc[-200,i], 
#                      color_map=red_up_tri)
        

    # ax2.scatter(x=subset_gl.loc[idx['Columns',50],:]+pos[i],y=vi.mean(axis=0),c=[c5.loc[i]])
    # ax2.set_yscale('symlog')
    # ax2.set_yticks([-10,-5,-2,-1,-0.5,0,0.5])
    # ax2.set_yticklabels([-10,-5,-2,-1,-0.5,0,0.5])
    ax2.set_xticklabels(['','Mining','Scrap Demand','Total\nRefining','Primary\nRefining','Secondary\nRefining',
                       r'$CO_2$'+'-Equivalent\nEmissions']);

    ax2.set_xticks([0.5,1.5,2.5,3.5,4.5,5.5],minor=True)
    ax2.tick_params(axis='x',which='major',length=7,color='white',pad=5)
    ax2.tick_params(axis='x',which='minor',length=5,direction='in',width=3)

    ax2.set_title('Distribution of Global Responses, Varying Refined Copper Imports')
    ax2.set_ylabel('Cumulative response at 2040\n(% of 2020 value)')
    
    
fig2,ax3 = plt.subplots(figsize=[24,7])

for i in ['Global,ax3']:
    pos = pd.Series([-0.2,0,0.2],index=c5.index)
    width = 0.25
    subset_cn = ref_results_cn.loc[idx['Both',:,'20400101'],'Scrap Demand':].reset_index(drop=True, level=2).reset_index(drop=True, level=0)
    subset_cn.columns = [0,1,2,3,4]
    offset = 0.22
    parts = ax3.violinplot(subset_cn.iloc[:,:-1].T,positions=np.add([1,2,3,4],np.repeat(-offset,4)),
                  widths = width, showextrema=False)
    vi_color = colors[0]
    for pc in parts['bodies']:
        pc.set_facecolor(vi_color)
        pc.set_alpha(1)
    
    parts = ax3.violinplot(subset_cn.iloc[:,-1],positions=[5-offset],
                  widths = width, showextrema=False)
    
    for pc in parts['bodies']:
        pc.set_facecolor('#16B558')
        pc.set_alpha(1)
    
   
    for i in subset_cn.columns:
        ax3.scatter(i+1-offset,subset_cn.loc[0,i],color='#106149')
        ax3.scatter(i+1-offset,subset_cn.loc[100,i],color='#106149')
        ax3.scatter(i+1-offset,subset_cn.loc[200,i],color='#106149')
        ax3.scatter(i+1-offset,subset_cn.loc[-100,i],color='#106149')
        ax3.scatter(i+1-offset,subset_cn.loc[-200,i],color='#106149')
#         ax3.scatter(x=np.repeat(i+1,len(subset_cn.index)),y=subset_cn.loc[:,i])
#         if subset_cn.loc[:,i].idxmax() == -200:
#             triangle(ax3, x=i+1, width=tri_width, bot=subset_cn.loc[0,i], top=subset_cn.loc[-200,i], 
#                      color_map=red_up_tri)
        

    # ax3.scatter(x=subset_cn.loc[idx['Columns',50],:]+pos[i],y=vi.mean(axis=0),c=[c5.loc[i]])
    
    subset_rw = ref_results_rw.loc[idx['Both',:,'20400101'],'Scrap Demand':].reset_index(drop=True, level=2).reset_index(drop=True, level=0)
    subset_rw.columns = [0,1,2,3,4]
    parts = ax3.violinplot(subset_rw.iloc[:,:-1].T,positions=np.add([1,2,3,4],np.repeat(offset,4)),
                  widths = width, showextrema=False)
    vi_color = colors[1]
    for pc in parts['bodies']:
        pc.set_facecolor(vi_color)
        pc.set_alpha(1)
    
    parts = ax3.violinplot(subset_rw.iloc[:,-1],positions=[5+offset],
                  widths = width, showextrema=False)
    
    for pc in parts['bodies']:
        pc.set_facecolor('#F08F0A')
        pc.set_alpha(1)
    
#     tri_width = 0.2
    for i in subset_rw.columns:
        ax3.scatter(i+1+offset,subset_rw.loc[0,i],color='#9C4402')
        ax3.scatter(i+1+offset,subset_rw.loc[100,i],color='#9C4402')
        ax3.scatter(i+1+offset,subset_rw.loc[-100,i],color='#9C4402')
        ax3.scatter(i+1+offset,subset_rw.loc[200,i],color='#9C4402')
        ax3.scatter(i+1+offset,subset_rw.loc[-200,i],color='#9C4402')
#         ax3.scatter(x=np.repeat(i+1,len(subset_rw.index)),y=subset_rw.loc[:,i])
#         if subset_rw.loc[:,i].idxmax() == -200:
#             triangle(ax3, x=i+1, width=tri_width, bot=subset_rw.loc[0,i], top=subset_rw.loc[-200,i], 
#                      color_map=red_up_tri)
        

    # ax3.scatter(x=subset_rw.loc[idx['Columns',50],:]+pos[i],y=vi.mean(axis=0),c=[c5.loc[i]])
    # ax3.set_yscale('symlog')
    # ax3.set_yticks([-10,-5,-2,-1,-0.5,0,0.5])
    # ax3.set_yticklabels([-10,-5,-2,-1,-0.5,0,0.5])
    ax3.set_xticklabels(['','Scrap Demand','Total\nRefining','Primary\nRefining','Secondary\nRefining',
                       r'$CO_2$'+'-Equivalent\nEmissions']);

    ax3.set_xticks([0.5,1.5,2.5,3.5,4.5,5.5],minor=True)
    ax3.tick_params(axis='x',which='major',length=7,color='white',pad=5)
    ax3.tick_params(axis='x',which='minor',length=5,direction='in',width=3)

    ax3.set_title('Distribution of Regional Responses, Varying Refined Copper Imports')
    ax3.set_ylabel('Cumulative response at 2040\n(% of 2020 value)')

# %%
ref_results_cn.loc[idx['Both',:,'20400101'],:]

# %%
fig = plt.figure(figsize=[4,4]) 
ax = fig.add_subplot(111) 
def triangle(ax,x=0.5,width=1,bot=0,top=1,color_map=plt.cm.RdYlGn):
    left_x = x-width/2
    right_x = x+width/2
    path = Path([[left_x,bot],[x,top],[right_x,bot],[left_x,bot]])
    patch = PathPatch(path, facecolor='none',edgecolor='none')
    ax.add_patch(patch) 
    Z, Z2 = np.meshgrid(np.linspace(0,0), np.linspace(0,1))
    im = ax.imshow(Z-Z2, interpolation='bilinear', cmap=color_map,
                    origin='lower', extent=[0, 1, 0, 1],
                    clip_path=patch, clip_on=True)
    im.set_clip_path(patch)
red_up_tri = matplotlib.colors.LinearSegmentedColormap.from_list('up_tri', ['red',colors[2]])
green_up_tri = matplotlib.colors.LinearSegmentedColormap.from_list('up_tri', ['green',colors[2]])
green_down_tri = matplotlib.colors.LinearSegmentedColormap.from_list('down_tri', [colors[2],'green'])
red_down_tri = matplotlib.colors.LinearSegmentedColormap.from_list('down_tri', [colors[2],'red'])
triangle(ax,0.5,1,1,0,color_map=red_down_tri)
ax.set_xlim((0,1)) 
ax.set_ylim((0,1)) 
plt.show()

# %% [markdown]
# ## Figure 4: COVID Results

# %%
covid_results_gl.columns

# %%
colors[2]
dmd_index = list([i for i in direct_melt_demand_covidimf_baseline_gl.columns if 'Ref' not in i])+list(['Ref_Cu'])
(direct_melt_demand_covidimf_shock_gl.loc['20180101':, dmd_index].sum(axis=1)-direct_melt_demand_covidimf_baseline_gl.loc['20180101':, dmd_index].sum(axis=1)).cumsum()

# %%
init_plot2(fontsize=20)
fig, [ax1,ax2,ax3] = plt.subplots(1,3, figsize=(24,6))
blueblue = ['#9ecae1','#6baed6','#4292c6','#2171b5','#084594']
ax1.set_ylabel('Heyyyy')

for i in ['Total Copper Consumption']:
    dmd_index = list([i for i in direct_melt_demand_covidimf_baseline_gl.columns if 'Ref' not in i])+list(['Ref_Cu'])
    ax2.plot(0.001*direct_melt_demand_covidimf_baseline_gl.loc['20180101':, dmd_index].sum(axis=1), label='Baseline', color='gray',linestyle='--')
    ax2.plot(0.001*direct_melt_demand_covidimf_shock_gl.loc['20180101':, dmd_index].sum(axis=1), label='IMF Shock Only', color='k')

    ax2.set_ylabel('Total annual copper consumption (Mt)')
    ax2.set_title('Total Annual Copper Consumption')

for i in ['Regional emissions response']:
    c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
    c2 = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd']
    c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
    c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#ECFC9D','#abdda4','#66c2a5','#3288bd','#5e4fa2']
    plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4)

    for metric in ['Global warming (kt CO2 eq)']:#[i for i in impact_change_covidimf_both_50yoy.index.levels[1] if 'Renewable' not in i]:
        ph_series_covid_inc100,ph_series_covid_inc100_cn,ph_series_covid_inc100_rw = pct_inc(impact_change_covidimf_both_50yoy_inc100,metric,baseline=total_impacts_covidimf_baseline)
        ph_series_covid_inc200,ph_series_covid_inc200_cn,ph_series_covid_inc200_rw = pct_inc(impact_change_covidimf_both_50yoy_inc200,metric,baseline=total_impacts_covidimf_baseline)
        ph_series_covid_dec100,ph_series_covid_dec100_cn,ph_series_covid_dec100_rw = pct_inc(impact_change_covidimf_both_50yoy_dec100,metric,baseline=total_impacts_covidimf_baseline)
        ph_series_covid_dec200,ph_series_covid_dec200_cn,ph_series_covid_dec200_rw = pct_inc(impact_change_covidimf_both_50yoy_dec200,metric,baseline=total_impacts_covidimf_baseline)
        ph_series_covid_base,  ph_series_covid_base_cn,  ph_series_covid_base_rw   = pct_inc(impact_change_covidimf_both_50yoy,metric,baseline=total_impacts_covidimf_baseline)
        ph_series_covid_shock,  ph_series_covid_shock_cn,  ph_series_covid_shock_rw   = pct_inc(impact_change_covidimf_shock,metric,baseline=total_impacts_covidimf_baseline)

        

        
        ax3.plot(ph_series_covid_shock.loc['20180101':].sum(axis=1), color=colors[2], label='Global')
        ax3.plot(ph_series_covid_shock_cn.loc['20180101':].sum(axis=1), color=colors[0], label='China')
        ax3.plot(ph_series_covid_shock_rw.loc['20180101':].sum(axis=1), color=colors[1], label='RoW')

        ax3.set_title(r'Regional $CO_2$-Equivalent'+' Emissions \nResponses, COVID-19 Scenario')
        ax3.set_ylabel('Response relative to baseline\n(Cumulative, % of 2020 value)')
        

init_plot2(fontsize=20)
fig1 = plt.figure(constrained_layout=False, figsize=(24,6))
gs = fig1.add_gridspec(1,7)
# ax4 = fig1.add_subplot(gs[0:2])
ax5 = fig1.add_subplot(gs[:4])
ax6 = fig1.add_subplot(gs[4:])

# for i in ['mining, refining, scrap']:
#     ax4.plot(covid_results_gl.loc[idx['Shock',:],'Mining'].reset_index(drop=True,level=0), color = blueblue[0])
#     ax4.plot(covid_results_gl.loc[idx['Shock',:],'Scrap Demand'].reset_index(drop=True,level=0), color = blueblue[1])
#     ax4.plot(covid_results_gl.loc[idx['Shock',:],'Total Refining'].reset_index(drop=True,level=0), color = blueblue[2])
#     ax4.plot(covid_results_gl.loc[idx['Shock',:],'Primary Refining'].reset_index(drop=True,level=0), color = blueblue[3])
#     ax4.plot(covid_results_gl.loc[idx['Shock',:],'Secondary Refining'].reset_index(drop=True,level=0), color = blueblue[4])
#     ax4.set_title('Global Mining, Refining, & Scrap\nResponses, COVID-19 Scenario')
#     ax4.set_ylabel('Response relative to baseline\n(Cumulative, % of 2020 value)')
    
    
for i in ['Distribution']:
    scat = covid_results_gl.loc[idx[:,'20400101'],:].reset_index(drop=True, level=1)
    scat.columns = [0,1,2,3,4,5]
    parts = ax5.violinplot(scat.iloc[:,:-1].T,
                  widths = 0.4, showextrema=False)
    vi_color = colors[2]
    for pc in parts['bodies']:
        pc.set_facecolor(vi_color)
        pc.set_alpha(1)
    
    parts = ax5.violinplot(scat.iloc[:,-1],positions=[6],
                  widths = 0.4, showextrema=False)
    for pc in parts['bodies']:
        pc.set_facecolor((0.4588235294117647, 0.5392156862745098, 0.9019607843137254))
        pc.set_alpha(1)
    
    for i in scat.columns[:-1]:
        ax5.scatter(i+1,scat.loc[0,i],color=(0.4588235294117647, 0.5392156862745098, 0.9019607843137254))#(0.4588235294117647, 0.4392156862745098, 0.7019607843137254))
        ax5.scatter(i+1,scat.loc[100,i],color='#595780')
        ax5.scatter(i+1,scat.loc[200,i],color='#595780')
        ax5.scatter(i+1,scat.loc[-200,i],color='#595780')
        ax5.scatter(i+1,scat.loc[-100,i],color='#595780')
        ax5.scatter(i+1,scat.loc['Shock',i],color='k')
        
    for i in [scat.columns[-1]]:
        ax5.scatter(i+1,scat.loc[0,i],color='#9CAEFF')#(0.4588235294117647, 0.4392156862745098, 0.7019607843137254))
        ax5.scatter(i+1,scat.loc[100,i],color='#687ACC')
        ax5.scatter(i+1,scat.loc[200,i],color='#687ACC')
        ax5.scatter(i+1,scat.loc[-200,i],color='#687ACC')
        ax5.scatter(i+1,scat.loc[-100,i],color='#687ACC')
        ax5.scatter(i+1,scat.loc['Shock',i],color='k')
        
    ax5.set_xticklabels(['','Mining','Scrap Demand','Total\nRefining','Primary\nRefining','Secondary\nRefining',
                       r'$CO_2$'+'-Equivalent\nEmissions']);

    ax5.set_xticks([0.5,1.5,2.5,3.5,4.5,5.5],minor=True)
    ax5.tick_params(axis='x',which='major',length=7,color='white',pad=5)
    ax5.tick_params(axis='x',which='minor',length=5,direction='in',width=3)

    ax5.set_title('Distribution of Global Responses, Varying Refined Copper Imports')
    ax5.set_ylabel('Cumulative response at 2040\n(% of 2020 value)')

for i in ['stackplot']:
    ax6.plot(ph_series_covid_shock.loc['20180101':].sum(axis=1), color='k',alpha=0.7, label='Net Response')
    ax6.stackplot(ph_series_covid_shock.loc['20180101':,:].index, ph_series_covid_shock[ph_series_covid_shock>0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_covid_inc200.columns)
    ax6.set_ylim([-15.941552999846385,22.9])
    ax6.legend(loc='upper left',fontsize=20,ncol=2,
                  handlelength=0.8, handletextpad=0.4, labelspacing=0.18, columnspacing=0.5)
    ax6.stackplot(ph_series_covid_shock.loc['20180101':,:].index, ph_series_covid_shock[ph_series_covid_shock<0].fillna(0).loc['20180101':].transpose(), 
              labels=ph_series_covid_shock.columns)
    
    ax6.set_title(r'Global $CO_2$-Equivalent'+' Emissions\nResponse, COVID-19 Scenario')
    ax6.set_ylabel('Cumulative increase, % of 2020 value');
    
# fig1.tight_layout(h_pad=0.1,w_pad=0.1)
plt.subplots_adjust(wspace=0.6,hspace=0.2)

# %%
np.multiply([0.4588235294117647, 0.5392156862745098, 0.9019607843137254],255)

# %%
mpl.rcParams['figure.figsize'] = [26,26] #width,height
fig,[[ax1,ax2,ax3],[ax4,ax5,ax6],[ax7,ax8,ax9],[ax10,ax11,ax12]] = plt.subplots(4,3)

for i in ['Total Copper Consumption']:
    dmd_index = list([i for i in direct_melt_demand_covidimf_baseline_gl.columns if 'Ref' not in i])+list(['Ref_Cu'])
    ax1.plot(0.001*direct_melt_demand_covidimf_baseline_gl.loc['20180101':, dmd_index].sum(axis=1), label='Baseline', color='gray',linestyle='--')
    ax1.plot(0.001*direct_melt_demand_covidimf_shock_gl.loc['20180101':, dmd_index].sum(axis=1), label='IMF Shock Only', color='k')
#     ax1.plot(0.001*direct_melt_demand_covidimf_both_50yoy_gl.loc['20180101':, dmd_index].sum(axis=1), label='Shock + Both Ban', color=colors[1])
#     ax1.plot(0.001*direct_melt_demand_covidimf_alloyed_50yoy_gl.loc['20180101':, dmd_index].sum(axis=1), label='Shock + Alloyed Ban', color=colors[2])
#     ax1.plot(0.001*direct_melt_demand_covidimf_no2_50yoy_gl.loc['20180101':, dmd_index].sum(axis=1), label='Shock + No.2 Ban', color=colors[3])
#     ax1.plot(0.001*direct_melt_demand_covidimf_both_50yoy_inc200_gl.loc['20180101':, dmd_index].sum(axis=1), label='Shock + Both Ban + 100', color=colors[4])
#     ax1.plot(0.001*direct_melt_demand_covidimf_both_50yoy_dec200_gl.loc['20180101':, dmd_index].sum(axis=1), label='Shock + Both Ban - 100', color='gray')
    # pplot(pd.Series([26000,43000], index = [pd.datetime(2019,1,1), pd.datetime(2019,1,1)]), label='2019',color='k')
    # pplot(pd.Series([26000,43000], index = [pd.datetime(2020,1,1), pd.datetime(2020,1,1)]), label='2019',color='k')
    # pplot(pd.Series([26000,43000], index = [pd.datetime(2021,1,1), pd.datetime(2021,1,1)]), label='2019',color='k')
#     ax1.legend()
    ax1.fill_between(direct_melt_demand_covidimf_both_50yoy_dec200_gl.loc['20180101':, dmd_index].sum(axis=1).index,
                     0.001*direct_melt_demand_covidimf_both_50yoy_inc200_gl.loc['20180101':, dmd_index].sum(axis=1),
                     0.001*direct_melt_demand_covidimf_both_50yoy_dec200_gl.loc['20180101':, dmd_index].sum(axis=1),
                     color = colors[2], alpha = 0.2)
    ax1.set_ylabel('Total annual copper consumption (Mt)')
    ax1.set_title('Total Annual Copper Consumption')

for i in ['Cathode price']:
    ax2.plot(cathode_price_series_covidimf_baseline.loc['20180101':], label='Baseline', color='gray', linestyle='--')
    ax2.plot(cathode_price_series_covidimf_shock.loc['20180101':], label='IMF Shock Only', color='k')
#     ax2.plot(cathode_price_series_covidimf_alloyed_50yoy.loc['20180101':], label='Shock + Alloyed Ban', color=colors[2])
#     ax2.plot(cathode_price_series_covidimf_no2_50yoy.loc['20180101':], label='Shock + No.2 Ban', color=colors[3])
#     ax2.plot(cathode_price_series_covidimf_both_50yoy.loc['20180101':], label='Shock + Both Ban', color=colors[1])
#     ax2.plot(cathode_price_series_covidimf_both_50yoy_inc200.loc['20180101':], label='Shock + Both Ban + 100', color=colors[4])
#     ax2.plot(cathode_price_series_covidimf_both_50yoy_dec200.loc['20180101':], label='Shock + Both Ban - 100', color='gray')
#     ax2.legend(fontsize=14)
    ax2.set_ylabel('Cathode price (USD/tonne)')
    ax2.set_title('Annual Cathode Price')

for i in ['Mining']:
    ax3.plot(mining_pctinc2020_covidimf_shock.loc['20180101':], label='IMF Shock Only', color='k')
    ax3.plot(mining_pctinc2020_covidimf_both_50yoy.loc['20180101':], label='Shock + Both Ban', color=colors[2])
#     ax3.plot(mining_pctinc2020_covidimf_alloyed_50yoy.loc['20180101':], label='Shock + Alloyed Ban', color=colors[0])
#     ax3.plot(mining_pctinc2020_covidimf_no2_50yoy.loc['20180101':], label='Shock + No.2 Ban', color=colors[1])
#     ax3.plot(mining_pctinc2020_covidimf_both_50yoy_inc100.loc['20180101':], label='Shock + Both Ban + 100', color=colors[4])
#     ax3.plot(mining_pctinc2020_covidimf_both_50yoy_dec100.loc['20180101':], label='Shock + Both Ban - 100')
#     ax3.plot(mining_pctinc2020_covidimf_both_50yoy_inc200.loc['20180101':], label='Shock + Both Ban + 200')
#     ax3.plot(mining_pctinc2020_covidimf_both_50yoy_dec200.loc['20180101':], label='Shock + Both Ban - 200')
    ax3.fill_between(mining_pctinc2020_covidimf_both_50yoy.loc['20180101':].index, 
                     np.sort(pd.concat([mining_pctinc2020_covidimf_both_50yoy_inc100.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_dec100.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_inc200.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_dec200.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy.loc['20180101':]], axis=1).values)[:,0], 
                     np.sort(pd.concat([mining_pctinc2020_covidimf_both_50yoy_inc100.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_dec100.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_inc200.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_dec200.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy.loc['20180101':]], axis=1).values)[:,-1], 
                     color = colors[2], alpha=0.3)
    ax3.fill_between(mining_pctinc2020_covidimf_both_50yoy.loc['20180101':].index, 
                     np.sort(pd.concat([mining_pctinc2020_covidimf_both_50yoy_inc100.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_dec100.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_inc200.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_dec200.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy.loc['20180101':]], axis=1).values)[:,1], 
                     np.sort(pd.concat([mining_pctinc2020_covidimf_both_50yoy_inc100.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_dec100.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_inc200.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy_dec200.loc['20180101':], mining_pctinc2020_covidimf_both_50yoy.loc['20180101':]], axis=1).values)[:,-2], 
                     color = colors[2], alpha=0.3)
    ax3.set_ylabel('Cumulative mining response \n(% of 2020 production)')
    ax3.set_title('Cumulative Mining Production Response')
#     ax3.legend()

for i in ['Scrap demand']:
    ax4.plot(scrap_demand_pctinc2020_covidimf_shock_gl.loc['20180101':], label='Shock', color='k')
    ax4.plot(scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':], label='<99% Ban', color=colors[2])
    ax4.fill_between(scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':].index, 
                     np.sort(pd.concat([scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,0], 
                     np.sort(pd.concat([scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,-1], 
                     color = colors[2], alpha=0.3)
    ax4.fill_between(scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':].index, 
                     np.sort(pd.concat([scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,1], 
                     np.sort(pd.concat([scrap_demand_pctinc2020_covidimf_both_50yoy_inc100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec100_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_inc200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_dec200_gl.loc['20180101':], scrap_demand_pctinc2020_covidimf_both_50yoy_gl.loc['20180101':]], axis=1).values)[:,-2], 
                     color = colors[2], alpha=0.3)
    ax4.set_title('Global Scrap Consumption\nResponse Above Baseline')
    # ax4.legend()
    ax4.set_ylabel('Scrap consumption response \n(Cumulative, % of 2020 value)');
    
for i in ['Primary refining production']: #GLOBAL
    ax5.plot(100*ref_props_covidimf_shock_gl.loc['20180101':,i+' response']/
             ref_props_covidimf_baseline_gl.loc['20200101',i], label='Shock',color='k')
    ax5.plot(100*ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/
             ref_props_covidimf_baseline_gl.loc['20200101',i], label='Shock',color=colors[2])
    ax5.fill_between(ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response'].index, 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,0], 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,-1], 
                     color = colors[2], alpha=0.3)
    ax5.fill_between(ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response'].index, 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,1], 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,-2], 
                     color = colors[2], alpha=0.3)
    ax5.set_title('Global Primary Refining Production \nResponse Above Baseline')
    # ax5.legend()
    ax5.set_ylabel('Primary refining production response \n(Cumulative, % of 2020 value)');
    
for i in ['Secondary refining production']: #GLOBAL
    ax6.plot(100*ref_props_covidimf_shock_gl.loc['20180101':,i+' response']/
             ref_props_covidimf_baseline_gl.loc['20200101',i], label='Shock',color='k')
    ax6.plot(100*ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/
             ref_props_covidimf_baseline_gl.loc['20200101',i], label='Shock',color=colors[2])
    ax6.fill_between(ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response'].index, 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,0], 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,-1], 
                     color = colors[2], alpha=0.3)
    ax6.fill_between(ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response'].index, 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,1], 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,-2], 
                     color = colors[2], alpha=0.3)
    ax6.set_title('Global Secondary Refining Production \nResponse Above Baseline')
    # ax6.legend()
    ax6.set_ylabel('Secondary refining production response \n(Cumulative, % of 2020 value)');
    
for i in ['Total refining production']: #GLOBAL, CHINA, ROW
    ax7.plot(100*ref_props_covidimf_shock_gl.loc['20180101':,i+' response']/
             ref_props_covidimf_baseline_gl.loc['20200101',i], label='Shock',color='k')
    ax7.plot(100*ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/
             ref_props_covidimf_baseline_gl.loc['20200101',i], label='Shock',color=colors[2])
    ax7.fill_between(ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response'].index, 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,0], 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,-1], 
                     color = colors[2], alpha=0.3)
    ax7.fill_between(ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response'].index, 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,1], 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_gl.loc['20180101':,i+' response']/ref_props_covidimf_baseline_gl.loc['20200101',i]*100], axis=1).values)[:,-2], 
                     color = colors[2], alpha=0.3)
    ax7.set_title('Global Total Refining Production \nResponse Above Baseline')
    # ax7.legend()
    ax7.set_yticks([-20,-15,-10,-5,0])
    ax7.set_ylabel('Total refining production response \n(Cumulative, % of 2020 value)');
    
    ax8.plot(100*ref_props_covidimf_shock_cn.loc['20180101':,i+' response']/
             ref_props_covidimf_baseline_cn.loc['20200101',i], label='Shock',color='k')
    ax8.plot(100*ref_props_covidimf_both_50yoy_cn.loc['20180101':,i+' response']/
             ref_props_covidimf_baseline_cn.loc['20200101',i], label='Shock',color=colors[2])
    ax8.fill_between(ref_props_covidimf_both_50yoy_cn.loc['20180101':,i+' response'].index, 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100], axis=1).values)[:,0], 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100], axis=1).values)[:,-1], 
                     color = colors[2], alpha=0.3)
    ax8.fill_between(ref_props_covidimf_both_50yoy_cn.loc['20180101':,i+' response'].index, 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100], axis=1).values)[:,1], 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_cn.loc['20180101':,i+' response']/ref_props_covidimf_baseline_cn.loc['20200101',i]*100], axis=1).values)[:,-2], 
                     color = colors[2], alpha=0.3)
    ax8.set_title('China Total Refining Production \nResponse Above Baseline')
    # ax8.legend()
    ax8.set_ylim([-19.635848057210712, 64.85454630184833])
    ax8.set_ylabel('Total refining production response \n(Cumulative, % of 2020 value)');
    
    ax9.plot(100*ref_props_covidimf_shock_rw.loc['20180101':,i+' response']/
             ref_props_covidimf_baseline_rw.loc['20200101',i], label='Shock',color='k')
    ax9.plot(100*ref_props_covidimf_both_50yoy_rw.loc['20180101':,i+' response']/
             ref_props_covidimf_baseline_rw.loc['20200101',i], label='Shock',color=colors[2])
    ax9.fill_between(ref_props_covidimf_both_50yoy_rw.loc['20180101':,i+' response'].index, 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100], axis=1).values)[:,0], 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100], axis=1).values)[:,-1], 
                     color = colors[2], alpha=0.3)
    ax9.fill_between(ref_props_covidimf_both_50yoy_rw.loc['20180101':,i+' response'].index, 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100], axis=1).values)[:,1], 
                     np.sort(pd.concat([ref_props_covidimf_both_50yoy_inc100_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec100_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_inc200_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_dec200_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100, ref_props_covidimf_both_50yoy_rw.loc['20180101':,i+' response']/ref_props_covidimf_baseline_rw.loc['20200101',i]*100], axis=1).values)[:,-2], 
                     color = colors[2], alpha=0.3)
    ax9.set_title('Rest of World Total Refining Production \nResponse Above Baseline')
    # ax9.legend()
    ax9.set_ylim([-118.85325206594044, 5.659678669806688])
    ax9.set_ylabel('Total refining production response \n(Cumulative, % of 2020 value)');
    plt.subplots_adjust(wspace=0.25,hspace=0.25)
    
for i in ['Global warming impacts']:
    c1 = ['#a6cee3','#1f78b4','#b2df8a','#33a02c','#fb9a99','#e31a1c','#fdbf6f','#ff7f00','#cab2d6','#6a3d9a']
    c2 = ['#8dd3c7','#ffffb3','#bebada','#fb8072','#80b1d3','#fdb462','#b3de69','#fccde5','#d9d9d9','#bc80bd']
    c3 = ['#543005','#8c510a','#bf812d','#dfc27d','#f6e8c3','#c7eae5','#80cdc1','#35978f','#01665e','#003c30']
    c4 = ['#9e0142','#d53e4f','#f46d43','#fdae61','#fee08b','#ECFC9D','#abdda4','#66c2a5','#3288bd','#5e4fa2']
    plt.rcParams['axes.prop_cycle'] = plt.cycler(color=c4)

    ph_series_shock = pd.DataFrame(0, index = impact_change_covidimf_shock.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
    ph_series_base = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
    ph_series_inc100 = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc100.index.levels[1])
    ph_series_inc200 = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
    ph_series_dec100 = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])
    ph_series_dec200 = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec200.index.levels[1])
    ph_series_shock_cn = pd.DataFrame(0, index = impact_change_covidimf_shock.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
    ph_series_base_cn = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
    ph_series_inc100_cn = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc100.index.levels[1])
    ph_series_inc200_cn = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
    ph_series_dec100_cn = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])
    ph_series_dec200_cn = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec200.index.levels[1])
    ph_series_shock_rw = pd.DataFrame(0, index = impact_change_covidimf_shock.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
    ph_series_base_rw = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy.index.levels[1])
    ph_series_inc100_rw = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc100.index.levels[1])
    ph_series_inc200_rw = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_inc200.index.levels[1])
    ph_series_dec100_rw = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec100.index.levels[1])
    ph_series_dec200_rw = pd.DataFrame(0, index = impact_change_covidimf_both_50yoy.index.levels[0], columns = impact_change_no2_50yoy_dec200.index.levels[1])

    for metric in ['Global warming (kt CO2 eq)']:#[i for i in impact_change_covidimf_both_50yoy.index.levels[1] if 'Renewable' not in i]:
        ph_series_inc100,ph_series_inc100_cn,ph_series_inc100_rw = pct_inc(impact_change_covidimf_both_50yoy_inc100,metric,baseline=total_impacts_covidimf_baseline)
        ph_series_inc200,ph_series_inc200_cn,ph_series_inc200_rw = pct_inc(impact_change_covidimf_both_50yoy_inc200,metric,baseline=total_impacts_covidimf_baseline)
        ph_series_dec100,ph_series_dec100_cn,ph_series_dec100_rw = pct_inc(impact_change_covidimf_both_50yoy_dec100,metric,baseline=total_impacts_covidimf_baseline)
        ph_series_dec200,ph_series_dec200_cn,ph_series_dec200_rw = pct_inc(impact_change_covidimf_both_50yoy_dec200,metric,baseline=total_impacts_covidimf_baseline)
        ph_series_base,  ph_series_base_cn,  ph_series_base_rw   = pct_inc(impact_change_covidimf_both_50yoy,metric,baseline=total_impacts_covidimf_baseline)
        ph_series_shock,  ph_series_shock_cn,  ph_series_shock_rw   = pct_inc(impact_change_covidimf_shock,metric,baseline=total_impacts_covidimf_baseline)

        ax10.plot(ph_series_shock.loc['20180101':].sum(axis=1), color='k', label='Net Response')
    #     ax10.plot(ph_series_inc200.loc['20180101':].sum(axis=1), color=colorn[0], label='Inc 200')
    #     ax10.plot(ph_series_inc100.loc['20180101':].sum(axis=1), color=colorn[1], label='Inc 100')
    #     ax10.plot(ph_series_base.loc['20180101':].sum(axis=1), color=colors[2], label='No Change')
    #     ax10.plot(ph_series_dec100.loc['20180101':].sum(axis=1), color=colorn[3], label='Dec 100')
    #     ax10.plot(ph_series_dec200.loc['20180101':].sum(axis=1), color=colorn[4], label='Dec 200')
    #     ax10.fill_between(ph_series_inc100.loc['20180101':].index,
    #                     ph_series_inc100.loc['20180101':].sum(axis=1),
    #                     ph_series_dec100.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
    #     ax10.fill_between(ph_series_inc100.loc['20180101':].index,
    #                     ph_series_inc200.loc['20180101':].sum(axis=1),
    #                     ph_series_dec200.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
        ax10.stackplot(ph_series_shock.loc['20180101':,:].index, ph_series_shock[ph_series_shock>0].fillna(0).loc['20180101':].transpose(), 
                  labels=ph_series_inc200.columns)
        ax10.set_ylim([-15.941552999846385,22.9])
        ax10.legend(loc='upper left',fontsize=16,ncol=2)
        ax10.stackplot(ph_series_shock.loc['20180101':,:].index, ph_series_shock[ph_series_shock<0].fillna(0).loc['20180101':].transpose(), 
                  labels=ph_series_shock.columns)


        ax11.plot(ph_series_shock_cn.loc['20180101':].sum(axis=1), color='k', label='Shock')
    #     ax11.plot(ph_series_inc200_cn.loc['20180101':].sum(axis=1), color=colorn[0], label='Inc 200')
    #     ax11.plot(ph_series_inc100_cn.loc['20180101':].sum(axis=1), color=colorn[1], label='Inc 100')
        ax11.plot(ph_series_base_cn.loc['20180101':].sum(axis=1), color=colors[2], label='No Change')
    #     ax11.plot(ph_series_dec100_cn.loc['20180101':].sum(axis=1), color=colorn[3], label='Dec 100')
    #     ax11.plot(ph_series_dec200_cn.loc['20180101':].sum(axis=1), color=colorn[4], label='Dec 200')
        ax11.fill_between(ph_series_inc100.loc['20180101':].index,
                        ph_series_inc100_cn.loc['20180101':].sum(axis=1),
                        ph_series_dec100_cn.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
        ax11.fill_between(ph_series_inc100.loc['20180101':].index,
                        ph_series_inc200_cn.loc['20180101':].sum(axis=1),
                        ph_series_dec200_cn.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
        ax11.set_ylim([-5.077905435281377, 11.454896825763935])

        ax12.plot(ph_series_shock_rw.loc['20180101':].sum(axis=1), color='k', label='Shock')
    #     ax12.plot(ph_series_inc200_rw.loc['20180101':].sum(axis=1), color=colorn[0], label='Inc 200')
    #     ax12.plot(ph_series_inc100_rw.loc['20180101':].sum(axis=1), color=colorn[1], label='Inc 100')
        ax12.plot(ph_series_base_rw.loc['20180101':].sum(axis=1), color=colors[2], label='No Change')
    #     ax12.plot(ph_series_dec100_rw.loc['20180101':].sum(axis=1), color=colorn[3], label='Dec 100')
    #     ax12.plot(ph_series_dec200_rw.loc['20180101':].sum(axis=1), color=colorn[4], label='Dec 200')
        ax12.fill_between(ph_series_inc100.loc['20180101':].index,
                        ph_series_inc100_rw.loc['20180101':].sum(axis=1),
                        ph_series_dec100_rw.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
        ax12.fill_between(ph_series_inc100.loc['20180101':].index,
                        ph_series_inc200_rw.loc['20180101':].sum(axis=1),
                        ph_series_dec200_rw.loc['20180101':].sum(axis=1), color=colors[2], alpha=0.3)
        ax12.set_ylim([-9.99313997704955, 2.717660650109742])

        ax10.set_title('Global '+metric.split('(')[0].title()+'Change')
        ax11.set_title('China '+metric.split('(')[0].title()+'Change')
        ax12.set_title('Rest of World '+metric.split('(')[0].title()+'Change')
        ax10.set_title(r'Global $CO_2$-Equivalent'+'\nEmissions Response')
        ax11.set_title(r'China $CO_2$-Equivalent'+'\nEmissions Response')
        ax12.set_title(r'Rest of World $CO_2$-Equivalent'+'\nEmissions Response')
        
    #     plt.xlabel('Year')
        ax10.set_ylabel('Cumulative increase, % of 2020 value')
        ax11.set_ylabel('Cumulative increase, % of 2020 value')
        ax12.set_ylabel('Cumulative increase, % of 2020 value');
    # (total_impacts_covidimf_both_50yoy - total_impacts_pir_baseline).groupby(axis=1,level=1).sum().groupby(axis=0,level=0).sum().loc['20180101':,'Global warming (kt CO2 eq)'].plot()

    
fig.tight_layout(h_pad=0.1,w_pad=0.1)
plt.subplots_adjust(wspace=0.25,hspace=0.27)

# %%
n = 'Total refining production'
100*ref_props_covidimf_both_50yoy_dec200_rw.loc['20400101',n+' response']/ref_props_covidimf_baseline_rw.loc['20200101',n]
ph_series_inc200_rw.loc['20400101'].sum()

# %%
ax3.get_ylim()
